# %% [markdown]
# ---
#
# # Tabla_de_Contenido
#
# *(Haz clic en los **enlaces** para navegar y en el **enlace de retorno** para volver a la **Tabla de Contenido**)*
#
# Unidad 1: Introducción y Configuración del Entorno
#
# 1.  [# 1_Introduccion_a_Django](#1_Introduccion_a_Django)
#     *   [# 1_1_Que_es_Django_y_su_Filosofia](#1_1_Que_es_Django_y_su_Filosofia)
#     *   [# 1_2_Arquitectura_MVT_Model_View_Template](#1_2_Arquitectura_MVT_Model_View_Template)
#     *   [# 1_3_Ventajas_y_Desventajas_de_Usar_Django](#1_3_Ventajas_y_Desventajas_de_Usar_Django)
#     *   [# 1_4_Instalacion_de_Python_y_Pip](#1_4_Instalacion_de_Python_y_Pip)
#     *   [# 1_5_Entornos_Virtuales_venv](#1_5_Entornos_Virtuales_venv)
#         *   [# 1_5_1_Creacion_y_Activacion](#1_5_1_Creacion_y_Activacion)
#         *   [# 1_5_2_Manejo_de_Dependencias_requirements_txt](#1_5_2_Manejo_de_Dependencias_requirements_txt)
#     *   [# 1_6_Instalacion_de_Django](#1_6_Instalacion_de_Django)
#     *   [# 1_7_Creacion_de_un_Proyecto_Django](#1_7_Creacion_de_un_Proyecto_Django)
#     *   [# 1_8_Estructura_del_Proyecto](#1_8_Estructura_del_Proyecto)
#     *   [# 1_9_El_Servidor_de_Desarrollo_runserver](#1_9_El_Servidor_de_Desarrollo_runserver)
#     *   [# 1_10_Creacion_de_una_Aplicacion_Django_startapp](#1_10_Creacion_de_una_Aplicacion_Django_startapp)
#     *   [# 1_11_Registro_de_Aplicaciones_INSTALLED_APPS](#1_11_Registro_de_Aplicaciones_INSTALLED_APPS)
#     *   [# 1_12_Proyectos_vs_Aplicaciones_Revisitado](#1_12_Proyectos_vs_Aplicaciones_Revisitado)
#     *   [# 1_13_Ejercicio_Practico_Crear_Proyecto_y_App_Inicial](#1_13_Ejercicio_Practico_Crear_Proyecto_y_App_Inicial)
#
# Unidad 2: Fundamentos - URLs, Vistas y Plantillas
#
# 2.  [# 2_El_Ciclo_Request_Response_en_Django](#2_El_Ciclo_Request_Response_en_Django)
# 3.  [# 3_Mapeo_de_URLs_urls_py](#3_Mapeo_de_URLs_urls_py)
#     *   [# 3_1_Funcion_path](#3_1_Funcion_path)
#     *   [# 3_2_URLs_del_Proyecto_vs_URLs_de_la_Aplicacion_include](#3_2_URLs_del_Proyecto_vs_URLs_de_la_Aplicacion_include)
#     *   [# 3_3_Conversores_de_Ruta_str_int_slug_uuid_path](#3_3_Conversores_de_Ruta_str_int_slug_uuid_path)
#     *   [# 3_4_Nombrar_Patrones_de_URL_name](#3_4_Nombrar_Patrones_de_URL_name)
#     *   [# 3_5_Namespaces_de_URL_app_name](#3_5_Namespaces_de_URL_app_name)
#     *   [# 3_6_Ejercicio_Practico_Configurar_URLs_Basicas](#3_6_Ejercicio_Practico_Configurar_URLs_Basicas)
# 4.  [# 4_Vistas_Basadas_en_Funcion_FBV](#4_Vistas_Basadas_en_Funcion_FBV)
#     *   [# 4_1_Creacion_de_Vistas_Simples_views_py](#4_1_Creacion_de_Vistas_Simples_views_py)
#     *   [# 4_2_Objeto_HttpRequest_Atributos_y_Metodos](#4_2_Objeto_HttpRequest_Atributos_y_Metodos)
#     *   [# 4_3_Retornando_HttpResponse_Tipos_de_Respuesta](#4_3_Retornando_HttpResponse_Tipos_de_Respuesta)
#     *   [# 4_4_Ejercicio_Practico_Crear_Vistas_Simples](#4_4_Ejercicio_Practico_Crear_Vistas_Simples)
# 5.  [# 5_Sistema_de_Plantillas_de_Django_DTL](#5_Sistema_de_Plantillas_de_Django_DTL)
#     *   [# 5_1_Configuracion_de_Plantillas_settings_py_TEMPLATES](#5_1_Configuracion_de_Plantillas_settings_py_TEMPLATES)
#     *   [# 5_2_Renderizando_Plantillas_render](#5_2_Renderizando_Plantillas_render)
#     *   [# 5_3_Sintaxis_Basica_Variables_y_Contexto](#5_3_Sintaxis_Basica_Variables_y_Contexto)
#     *   [# 5_4_Etiquetas_Tags_Basicas_if_for_empty](#5_4_Etiquetas_Tags_Basicas_if_for_empty)
#     *   [# 5_5_Filtros_Basicos_lower_date_length_etc](#5_5_Filtros_Basicos_lower_date_length_etc)
#     *   [# 5_6_Comentarios_en_Plantillas](#5_6_Comentarios_en_Plantillas)
#     *   [# 5_7_Generacion_de_URLs_en_Plantillas_url_tag_Revisitado](#5_7_Generacion_de_URLs_en_Plantillas_url_tag_Revisitado)
#     *   [# 5_8_Ejercicio_Practico_Crear_y_Renderizar_Plantillas](#5_8_Ejercicio_Practico_Crear_y_Renderizar_Plantillas)
#
# Unidad 3: Modelos y Bases de Datos
#
# 6.  [# 6_Introduccion_al_ORM_de_Django](#6_Introduccion_al_ORM_de_Django)
# 7.  [# 7_Definicion_de_Modelos_models_py](#7_Definicion_de_Modelos_models_py)
#     *   [# 7_1_Tipos_de_Campos_Fields](#7_1_Tipos_de_Campos_Fields)
#     *   [# 7_2_Opciones_Comunes_de_Campos_null_blank_default_unique](#7_2_Opciones_Comunes_de_Campos_null_blank_default_unique)
#     *   [# 7_3_Clave_Primaria_AutoField_primary_key](#7_3_Clave_Primaria_AutoField_primary_key)
#     *   [# 7_4_Metodos_en_Modelos_str_get_absolute_url](#7_4_Metodos_en_Modelos_str_get_absolute_url)
#     *   [# 7_5_Meta_Opciones_ordering_verbose_name_indexes_etc](#7_5_Meta_Opciones_ordering_verbose_name_indexes_etc)
#     *   [# 7_6_Ejercicio_Practico_Definir_Modelos_Simples](#7_6_Ejercicio_Practico_Definir_Modelos_Simples)
# 8.  [# 8_Migraciones](#8_Migraciones)
#     *   [# 8_1_Que_son_las_Migraciones](#8_1_Que_son_las_Migraciones)
#     *   [# 8_2_Comando_makemigrations](#8_2_Comando_makemigrations)
#     *   [# 8_3_Comando_migrate](#8_3_Comando_migrate)
#     *   [# 8_4_Comando_sqlmigrate](#8_4_Comando_sqlmigrate)
#     *   [# 8_5_Comando_showmigrations](#8_5_Comando_showmigrations)
#     *   [# 8_6_Manejo_de_Conflictos_y_Reversion_de_Migraciones](#8_6_Manejo_de_Conflictos_y_Reversion_de_Migraciones)
#     *   [# 8_7_Ejercicio_Practico_Crear_y_Aplicar_Migraciones](#8_7_Ejercicio_Practico_Crear_y_Aplicar_Migraciones)
# 9.  [# 9_Interactuando_con_la_Base_de_Datos_QuerySets](#9_Interactuando_con_la_Base_de_Datos_QuerySets)
#     *   [# 9_1_El_Manager_objects](#9_1_El_Manager_objects)
#     *   [# 9_2_Creacion_de_Objetos_create_save](#9_2_Creacion_de_Objetos_create_save)
#     *   [# 9_3_Recuperacion_de_Objetos_all_get_filter_exclude](#9_3_Recuperacion_de_Objetos_all_get_filter_exclude)
#         *   [# 9_3_1_Diferencia_entre_get_y_filter](#9_3_1_Diferencia_entre_get_y_filter)
#         *   [# 9_3_2_Manejo_de_DoesNotExist_y_MultipleObjectsReturned](#9_3_2_Manejo_de_DoesNotExist_y_MultipleObjectsReturned)
#         *   [# 9_3_3_first_last_exists_count](#9_3_3_first_last_exists_count)
#     *   [# 9_4_Encadenamiento_de_Filtros](#9_4_Encadenamiento_de_Filtros)
#     *   [# 9_5_Lookups_de_Campo_exact_iexact_contains_gt_lt_etc](#9_5_Lookups_de_Campo_exact_iexact_contains_gt_lt_etc)
#     *   [# 9_6_Objetos_Q_Consultas_OR_y_NOT_Complejas](#9_6_Objetos_Q_Consultas_OR_y_NOT_Complejas)
#     *   [# 9_7_Actualizacion_de_Objetos_save_update](#9_7_Actualizacion_de_Objetos_save_update)
#     *   [# 9_8_Eliminacion_de_Objetos_delete](#9_8_Eliminacion_de_Objetos_delete)
#     *   [# 9_9_Ordenamiento_order_by](#9_9_Ordenamiento_order_by)
#     *   [# 9_10_Limitacion_de_Resultados_Slicing](#9_10_Limitacion_de_Resultados_Slicing)
#     *   [# 9_11_Evaluacion_Perezosa_Lazy_Loading_de_QuerySets](#9_11_Evaluacion_Perezosa_Lazy_Loading_de_QuerySets)
#     *   [# 9_12_Ejercicio_Practico_Realizar_Consultas_CRUD](#9_12_Ejercicio_Practico_Realizar_Consultas_CRUD)
# 10. [# 10_Relaciones_Entre_Modelos](#10_Relaciones_Entre_Modelos)
#     *   [# 10_1_Relaciones_Uno_a_Muchos_ForeignKey](#10_1_Relaciones_Uno_a_Muchos_ForeignKey)
#         *   [# 10_1_1_Argumento_on_delete](#10_1_1_Argumento_on_delete)
#         *   [# 10_1_2_Argumento_related_name](#10_1_2_Argumento_related_name)
#     *   [# 10_2_Relaciones_Muchos_a_Muchos_ManyToManyField](#10_2_Relaciones_Muchos_a_Muchos_ManyToManyField)
#         *   [# 10_2_1_Tabla_Intermedia_Automatica](#10_2_1_Tabla_Intermedia_Automatica)
#         *   [# 10_2_2_Argumento_through_Modelos_Intermedios](#10_2_2_Argumento_through_Modelos_Intermedios)
#     *   [# 10_3_Relaciones_Uno_a_Uno_OneToOneField](#10_3_Relaciones_Uno_a_Uno_OneToOneField)
#     *   [# 10_4_Consultas_a_traves_de_Relaciones_Doble_Guion_Bajo](#10_4_Consultas_a_traves_de_Relaciones_Doble_Guion_Bajo)
#         *   [# 10_4_1_Consultas_Directas_ForeignKey_OneToOne](#10_4_1_Consultas_Directas_ForeignKey_OneToOne)
#         *   [# 10_4_2_Consultas_Inversas_related_name_o_modelo_set](#10_4_2_Consultas_Inversas_related_name_o_modelo_set)
#         *   [# 10_4_3_Consultas_ManyToMany](#10_4_3_Consultas_ManyToMany)
#     *   [# 10_5_Ejercicio_Practico_Definir_y_Consultar_Relaciones](#10_5_Ejercicio_Practico_Definir_y_Consultar_Relaciones)
# 11. [# 11_El_Shell_de_Django_manage_py_shell](#11_El_Shell_de_Django_manage_py_shell)
#     *   [# 11_1_Uso_para_Probar_Consultas_y_Modelos](#11_1_Uso_para_Probar_Consultas_y_Modelos)
#     *   [# 11_2_Shell_Plus_django_extensions](#11_2_Shell_Plus_django_extensions)
#
# Unidad 4: La Interfaz de Administración de Django
#
# 12. [# 12_Introduccion_al_Admin_de_Django](#12_Introduccion_al_Admin_de_Django)
# 13. [# 13_Activando_el_Admin](#13_Activando_el_Admin)
# 14. [# 14_Creando_un_Superusuario_createsuperuser](#14_Creando_un_Superusuario_createsuperuser)
# 15. [# 15_Registrando_Modelos_admin_py_admin_site_register](#15_Registrando_Modelos_admin_py_admin_site_register)
# 16. [# 16_Personalizacion_Basica_ModelAdmin](#16_Personalizacion_Basica_ModelAdmin)
#     *   [# 16_1_list_display](#16_1_list_display)
#     *   [# 16_2_list_filter](#16_2_list_filter)
#     *   [# 16_3_search_fields](#16_3_search_fields)
#     *   [# 16_4_date_hierarchy](#16_4_date_hierarchy)
#     *   [# 16_5_ordering](#16_5_ordering)
#     *   [# 16_6_list_editable](#16_6_list_editable)
#     *   [# 16_7_list_per_page](#16_7_list_per_page)
#     *   [# 16_8_prepopulated_fields](#16_8_prepopulated_fields)
#     *   [# 16_9_Ejercicio_Practico_Personalizar_Admin_Basico](#16_9_Ejercicio_Practico_Personalizar_Admin_Basico)
# 17. [# 17_Personalizacion_Avanzada_del_Formulario_Admin](#17_Personalizacion_Avanzada_del_Formulario_Admin)
#     *   [# 17_1_fields_y_exclude](#17_1_fields_y_exclude)
#     *   [# 17_2_fieldsets](#17_2_fieldsets)
#     *   [# 17_3_readonly_fields](#17_3_readonly_fields)
#     *   [# 17_4_raw_id_fields](#17_4_raw_id_fields)
#     *   [# 17_5_Clases_Inline_TabularInline_StackedInline](#17_5_Clases_Inline_TabularInline_StackedInline)
#     *   [# 17_6_Personalizar_QuerySets_en_el_Admin_get_queryset](#17_6_Personalizar_QuerySets_en_el_Admin_get_queryset)
#     *   [# 17_7_Ejercicio_Practico_Personalizar_Formulario_Admin_e_Inlines](#17_7_Ejercicio_Practico_Personalizar_Formulario_Admin_e_Inlines)
# 18. [# 18_Acciones_del_Admin](#18_Acciones_del_Admin)
#     *   [# 18_1_Definicion_de_Acciones_Personalizadas](#18_1_Definicion_de_Acciones_Personalizadas)
#     *   [# 18_2_Registrar_Acciones](#18_2_Registrar_Acciones)
#     *   [# 18_3_Ejercicio_Practico_Crear_Accion_de_Admin](#18_3_Ejercicio_Practico_Crear_Accion_de_Admin)
#
# Unidad 5: Formularios Django
#
# 19. [# 19_Introduccion_a_los_Formularios_HTML_y_Django](#19_Introduccion_a_los_Formularios_HTML_y_Django)
# 20. [# 20_Creacion_de_Formularios_Forms_forms_py](#20_Creacion_de_Formularios_Forms_forms_py)
#     *   [# 20_1_Campos_de_Formulario_CharField_IntegerField_etc](#20_1_Campos_de_Formulario_CharField_IntegerField_etc)
#     *   [# 20_2_Widgets_Personalizacion_HTML](#20_2_Widgets_Personalizacion_HTML)
#     *   [# 20_3_Argumentos_Comunes_required_label_initial_help_text_widget_attrs](#20_3_Argumentos_Comunes_required_label_initial_help_text_widget_attrs)
#     *   [# 20_4_Validacion_Basica_Incorporada](#20_4_Validacion_Basica_Incorporada)
#     *   [# 20_5_Ejercicio_Practico_Crear_un_Form_Simple](#20_5_Ejercicio_Practico_Crear_un_Form_Simple)
# 21. [# 21_Renderizado_de_Formularios_en_Plantillas](#21_Renderizado_de_Formularios_en_Plantillas)
#     *   [# 21_1_Renderizado_Manual_de_Campos_y_Errores](#21_1_Renderizado_Manual_de_Campos_y_Errores)
#     *   [# 21_2_Metodos_de_Renderizado_as_p_as_ul_as_table](#21_2_Metodos_de_Renderizado_as_p_as_ul_as_table)
#     *   [# 21_3_Etiqueta_csrf_token](#21_3_Etiqueta_csrf_token)
#     *   [# 21_4_Ejercicio_Practico_Renderizar_Formulario](#21_4_Ejercicio_Practico_Renderizar_Formulario)
# 22. [# 22_Procesamiento_de_Datos_del_Formulario_en_Vistas](#22_Procesamiento_de_Datos_del_Formulario_en_Vistas)
#     *   [# 22_1_Diferenciar_GET_y_POST_en_Vistas](#22_1_Diferenciar_GET_y_POST_en_Vistas)
#     *   [# 22_2_Vinculacion_Binding_de_Datos_al_Formulario_request_POST](#22_2_Vinculacion_Binding_de_Datos_al_Formulario_request_POST)
#     *   [# 22_3_Validacion_is_valid](#22_3_Validacion_is_valid)
#     *   [# 22_4_Acceso_a_Datos_Validados_cleaned_data](#22_4_Acceso_a_Datos_Validados_cleaned_data)
#     *   [# 22_5_Manejo_de_Errores_form_errors_non_field_errors](#22_5_Manejo_de_Errores_form_errors_non_field_errors)
#     *   [# 22_6_Patron_Post_Redirect_Get_PRG](#22_6_Patron_Post_Redirect_Get_PRG)
#     *   [# 22_7_Ejercicio_Practico_Procesar_Formulario_en_Vista](#22_7_Ejercicio_Practico_Procesar_Formulario_en_Vista)
# 23. [# 23_ModelForms_Formularios_Basados_en_Modelos](#23_ModelForms_Formularios_Basados_en_Modelos)
#     *   [# 23_1_Creacion_y_Uso_Basico_Meta_model_fields_exclude](#23_1_Creacion_y_Uso_Basico_Meta_model_fields_exclude)
#     *   [# 23_2_Metodo_save_commit_False_save_m2m](#23_2_Metodo_save_commit_False_save_m2m)
#     *   [# 23_3_Personalizacion_de_Campos_en_ModelForms_widgets_labels_etc](#23_3_Personalizacion_de_Campos_en_ModelForms_widgets_labels_etc)
#     *   [# 23_4_Validacion_en_ModelForms](#23_4_Validacion_en_ModelForms)
#     *   [# 23_5_Ejercicio_Practico_Crear_y_Procesar_ModelForm](#23_5_Ejercicio_Practico_Crear_y_Procesar_ModelForm)
#
# Unidad 6: Plantillas Avanzadas
#
# 24. [# 24_Herencia_de_Plantillas_extends_block_super](#24_Herencia_de_Plantillas_extends_block_super)
#     *   [# 24_1_Creacion_de_Plantilla_Base](#24_1_Creacion_de_Plantilla_Base)
#     *   [# 24_2_Extension_y_Sobrescritura_de_Bloques](#24_2_Extension_y_Sobrescritura_de_Bloques)
#     *   [# 24_3_Uso_de_block_super](#24_3_Uso_de_block_super)
#     *   [# 24_4_Ejercicio_Practico_Implementar_Herencia](#24_4_Ejercicio_Practico_Implementar_Herencia)
# 25. [# 25_Inclusion_de_Plantillas_include_with_only](#25_Inclusion_de_Plantillas_include_with_only)
#     *   [# 25_1_Reutilizacion_de_Fragmentos_HTML](#25_1_Reutilizacion_de_Fragmentos_HTML)
#     *   [# 25_2_Pasando_Contexto_Adicional_with](#25_2_Pasando_Contexto_Adicional_with)
#     *   [# 25_3_Aislando_Contexto_only](#25_3_Aislando_Contexto_only)
#     *   [# 25_4_Ejercicio_Practico_Usar_include](#25_4_Ejercicio_Practico_Usar_include)
# 26. [# 26_Filtros_de_Plantillas_Built_in_y_Personalizados](#26_Filtros_de_Plantillas_Built_in_y_Personalizados)
#     *   [# 26_1_Revision_Filtros_Comunes](#26_1_Revision_Filtros_Comunes)
#     *   [# 26_2_Creacion_de_Filtros_Personalizados_templatetags](#26_2_Creacion_de_Filtros_Personalizados_templatetags)
#     *   [# 26_3_Registro_y_Uso_load](#26_3_Registro_y_Uso_load)
#     *   [# 26_4_Ejercicio_Practico_Crear_un_Filtro](#26_4_Ejercicio_Practico_Crear_un_Filtro)
# 27. [# 27_Etiquetas_Tags_de_Plantillas_Built_in_y_Personalizadas](#27_Etiquetas_Tags_de_Plantillas_Built_in_y_Personalizadas)
#     *   [# 27_1_Revision_Tags_Comunes](#27_1_Revision_Tags_Comunes)
#     *   [# 27_2_Creacion_de_Simple_Tags](#27_2_Creacion_de_Simple_Tags)
#     *   [# 27_3_Creacion_de_Inclusion_Tags](#27_3_Creacion_de_Inclusion_Tags)
#     *   [# 27_4_Registro_y_Uso](#27_4_Registro_y_Uso)
#     *   [# 27_5_Ejercicio_Practico_Crear_Tags_Simples_e_Inclusion](#27_5_Ejercicio_Practico_Crear_Tags_Simples_e_Inclusion)
# 28. [# 28_Context_Processors](#28_Context_Processors)
#     *   [# 28_1_Anadiendo_Datos_Globales_al_Contexto](#28_1_Anadiendo_Datos_Globales_al_Contexto)
#     *   [# 28_2_Creacion_y_Registro_en_settings](#28_2_Creacion_y_Registro_en_settings)
#     *   [# 28_3_Ejercicio_Practico_Crear_un_Context_Processor](#28_3_Ejercicio_Practico_Crear_un_Context_Processor)
#
# Unidad 7: Archivos Estáticos y de Medios
#
# 29. [# 29_Concepto_de_Archivos_Estaticos_CSS_JS_Imagenes](#29_Concepto_de_Archivos_Estaticos_CSS_JS_Imagenes)
# 30. [# 30_Configuracion_STATIC_URL_STATICFILES_DIRS_STATIC_ROOT](#30_Configuracion_STATIC_URL_STATICFILES_DIRS_STATIC_ROOT)
#     *   [# 30_1_STATIC_URL_vs_STATIC_ROOT](#30_1_STATIC_URL_vs_STATIC_ROOT)
#     *   [# 30_2_Ubicacion_de_Archivos_Estaticos_Apps_vs_Global](#30_2_Ubicacion_de_Archivos_Estaticos_Apps_vs_Global)
# 31. [# 31_Uso_de_la_Etiqueta_static_en_Plantillas](#31_Uso_de_la_Etiqueta_static_en_Plantillas)
# 32. [# 32_Comando_collectstatic_para_Produccion](#32_Comando_collectstatic_para_Produccion)
# 33. [# 33_Manejo_de_Archivos_Subidos_por_el_Usuario_Media_Files](#33_Manejo_de_Archivos_Subidos_por_el_Usuario_Media_Files)
#     *   [# 33_1_Configuracion_MEDIA_URL_MEDIA_ROOT](#33_1_Configuracion_MEDIA_URL_MEDIA_ROOT)
#     *   [# 33_2_Campo_FileField_e_ImageField_upload_to](#33_2_Campo_FileField_e_ImageField_upload_to)
#     *   [# 33_3_Manejo_de_Subidas_en_Formularios_enctype](#33_3_Manejo_de_Subidas_en_Formularios_enctype)
#     *   [# 33_4_Procesamiento_en_Vistas_request_FILES](#33_4_Procesamiento_en_Vistas_request_FILES)
#     *   [# 33_5_Servir_Archivos_Media_en_Desarrollo_y_Produccion](#33_5_Servir_Archivos_Media_en_Desarrollo_y_Produccion)
#     *   [# 33_6_Ejercicio_Practico_Configurar_y_Usar_Static_y_Media](#33_6_Ejercicio_Practico_Configurar_y_Usar_Static_y_Media)
#
# Unidad 8: Vistas Basadas en Clase (CBV)
#
# 34. [# 34_Introduccion_a_las_Vistas_Basadas_en_Clase_Ventajas_y_Desventajas](#34_Introduccion_a_las_Vistas_Basadas_en_Clase_Ventajas_y_Desventajas)
# 35. [# 35_Vistas_Genericas_Basicas_View_TemplateView](#35_Vistas_Genericas_Basicas_View_TemplateView)
#     *   [# 35_1_Clase_View_dispatch_get_post](#35_1_Clase_View_dispatch_get_post)
#     *   [# 35_2_Clase_TemplateView_template_name_get_context_data](#35_2_Clase_TemplateView_template_name_get_context_data)
# 36. [# 36_Vistas_Genericas_para_Mostrar_Datos_ListView_DetailView](#36_Vistas_Genericas_para_Mostrar_Datos_ListView_DetailView)
#     *   [# 36_1_ListView_model_queryset_template_name_context_object_name_paginate_by](#36_1_ListView_model_queryset_template_name_context_object_name_paginate_by)
#     *   [# 36_2_DetailView_model_queryset_template_name_context_object_name_pk_slug](#36_2_DetailView_model_queryset_template_name_context_object_name_pk_slug)
# 37. [# 37_Vistas_Genericas_para_Edicion_CreateView_UpdateView_DeleteView](#37_Vistas_Genericas_para_Edicion_CreateView_UpdateView_DeleteView)
#     *   [# 37_1_CreateView_model_fields_form_class_template_name_success_url](#37_1_CreateView_model_fields_form_class_template_name_success_url)
#     *   [# 37_2_UpdateView_model_fields_etc_obtencion_de_objeto](#37_2_UpdateView_model_fields_etc_obtencion_de_objeto)
#     *   [# 37_3_DeleteView_model_template_name_success_url_context_object_name](#37_3_DeleteView_model_template_name_success_url_context_object_name)
# 38. [# 38_Vistas_Genericas_para_Formularios_FormView](#38_Vistas_Genericas_para_Formularios_FormView)
#     *   [# 38_1_Uso_con_forms_Form](#38_1_Uso_con_forms_Form)
#     *   [# 38_2_Metodo_form_valid](#38_2_Metodo_form_valid)
# 39. [# 39_Personalizacion_de_CBVs_Sobrescritura_de_Metodos_Comunes](#39_Personalizacion_de_CBVs_Sobrescritura_de_Metodos_Comunes)
#     *   [# 39_1_get_queryset_get_object_get_context_data](#39_1_get_queryset_get_object_get_context_data)
#     *   [# 39_2_form_valid_form_invalid_get_success_url](#39_2_form_valid_form_invalid_get_success_url)
# 40. [# 40_Mixins_en_CBVs_Reutilizacion_de_Logica](#40_Mixins_en_CBVs_Reutilizacion_de_Logica)
#     *   [# 40_1_Mixins_Incorporados_LoginRequired_PermissionRequired_UserPassesTest](#40_1_Mixins_Incorporados_LoginRequired_PermissionRequired_UserPassesTest)
#     *   [# 40_2_Creacion_de_Mixins_Personalizados](#40_2_Creacion_de_Mixins_Personalizados)
#     *   [# 40_3_Ejercicio_Practico_Refactorizar_FBVs_a_CBVs](#40_3_Ejercicio_Practico_Refactorizar_FBVs_a_CBVs)
#
# Unidad 9: Autenticación y Autorización
#
# 41. [# 41_Sistema_de_Autenticacion_de_Django_contrib_auth](#41_Sistema_de_Autenticacion_de_Django_contrib_auth)
# 42. [# 42_Modelo_User_Predeterminado](#42_Modelo_User_Predeterminado)
# 43. [# 43_Vistas_de_Autenticacion_Incorporadas_LoginView_LogoutView](#43_Vistas_de_Autenticacion_Incorporadas_LoginView_LogoutView)
#     *   [# 43_1_Configuracion_de_URLs_django_contrib_auth_urls](#43_1_Configuracion_de_URLs_django_contrib_auth_urls)
#     *   [# 43_2_Plantillas_Requeridas_registration_directory](#43_2_Plantillas_Requeridas_registration_directory)
#     *   [# 43_3_Configuraciones_LOGIN_URL_LOGIN_REDIRECT_URL_LOGOUT_REDIRECT_URL](#43_3_Configuraciones_LOGIN_URL_LOGIN_REDIRECT_URL_LOGOUT_REDIRECT_URL)
# 44. [# 44_Formularios_de_Autenticacion_AuthenticationForm_UserCreationForm](#44_Formularios_de_Autenticacion_AuthenticationForm_UserCreationForm)
#     *   [# 44_1_Vista_de_Registro_Simple](#44_1_Vista_de_Registro_Simple)
# 45. [# 45_Manejo_de_Contrasenas_Vistas_y_Formularios](#45_Manejo_de_Contrasenas_Vistas_y_Formularios)
#     *   [# 45_1_Cambio_de_Contrasena_Usuario_Logueado](#45_1_Cambio_de_Contrasena_Usuario_Logueado)
#     *   [# 45_2_Reseteo_de_Contrasena_Olvide_mi_Contrasena](#45_2_Reseteo_de_Contrasena_Olvide_mi_Contrasena)
#     *   [# 45_3_Configuracion_de_Email_para_Reseteo](#45_3_Configuracion_de_Email_para_Reseteo)
# 46. [# 46_Proteccion_de_Vistas_login_required_y_LoginRequiredMixin](#46_Proteccion_de_Vistas_login_required_y_LoginRequiredMixin)
# 47. [# 47_Sistema_de_Permisos_y_Grupos](#47_Sistema_de_Permisos_y_Grupos)
#     *   [# 47_1_Permisos_Predeterminados_y_Personalizados](#47_1_Permisos_Predeterminados_y_Personalizados)
#     *   [# 47_2_Creacion_y_Asignacion_de_Grupos](#47_2_Creacion_y_Asignacion_de_Grupos)
#     *   [# 47_3_Comprobacion_de_Permisos_has_perm_perms_en_plantilla](#47_3_Comprobacion_de_Permisos_has_perm_perms_en_plantilla)
# 48. [# 48_Decorador_permission_required_y_PermissionRequiredMixin_UserPassesTestMixin](#48_Decorador_permission_required_y_PermissionRequiredMixin_UserPassesTestMixin)
# 49. [# 49_Modelo_de_Usuario_Personalizado_AbstractUser_AbstractBaseUser](#49_Modelo_de_Usuario_Personalizado_AbstractUser_AbstractBaseUser)
#     *   [# 49_1_Cuando_y_Por_Que_Personalizar](#49_1_Cuando_y_Por_Que_Personalizar)
#     *   [# 49_2_Configuracion_AUTH_USER_MODEL](#49_2_Configuracion_AUTH_USER_MODEL)
#     *   [# 49_3_Ejercicio_Practico_Implementar_Login_Registro_y_Proteccion_de_Vistas](#49_3_Ejercicio_Practico_Implementar_Login_Registro_y_Proteccion_de_Vistas)
#
# Unidad 10: Pruebas (Testing)
#
# 50. [# 50_Importancia_de_las_Pruebas_en_Desarrollo_Web](#50_Importancia_de_las_Pruebas_en_Desarrollo_Web)
# 51. [# 51_Framework_de_Pruebas_de_Django_unittest_TestCase](#51_Framework_de_Pruebas_de_Django_unittest_TestCase)
# 52. [# 52_Escribiendo_Pruebas_Unitarias_para_Modelos](#52_Escribiendo_Pruebas_Unitarias_para_Modelos)
#     *   [# 52_1_Metodos_setUp_setUpTestData_tearDown](#52_1_Metodos_setUp_setUpTestData_tearDown)
#     *   [# 52_2_Aserciones_Comunes_assertEqual_assertTrue_etc](#52_2_Aserciones_Comunes_assertEqual_assertTrue_etc)
# 53. [# 53_Escribiendo_Pruebas_para_Vistas_Test_Client](#53_Escribiendo_Pruebas_para_Vistas_Test_Client)
#     *   [# 53_1_Simulando_Peticiones_GET_y_POST](#53_1_Simulando_Peticiones_GET_y_POST)
#     *   [# 53_2_Comprobando_Codigo_de_Estado_y_Redirecciones](#53_2_Comprobando_Codigo_de_Estado_y_Redirecciones)
#     *   [# 53_3_Comprobando_Plantilla_Usada_y_Contexto](#53_3_Comprobando_Plantilla_Usada_y_Contexto)
#     *   [# 53_4_Comprobando_Contenido_HTML_assertContains](#53_4_Comprobando_Contenido_HTML_assertContains)
#     *   [# 53_5_Simulando_Login_de_Usuario_client_login](#53_5_Simulando_Login_de_Usuario_client_login)
# 54. [# 54_Escribiendo_Pruebas_para_Formularios](#54_Escribiendo_Pruebas_para_Formularios)
#     *   [# 54_1_Probando_Validez_con_Datos_Correctos_e_Incorrectos](#54_1_Probando_Validez_con_Datos_Correctos_e_Incorrectos)
#     *   [# 54_2_Comprobando_Errores_del_Formulario](#54_2_Comprobando_Errores_del_Formulario)
# 55. [# 55_Fixtures_Carga_de_Datos_de_Prueba_JSON_YAML](#55_Fixtures_Carga_de_Datos_de_Prueba_JSON_YAML)
# 56. [# 56_Ejecucion_de_Pruebas_manage_py_test_Selectiva](#56_Ejecucion_de_Pruebas_manage_py_test_Selectiva)
# 57. [# 57_Cobertura_de_Pruebas_Coverage_py](#57_Cobertura_de_Pruebas_Coverage_py)
#     *   [# 57_1_Instalacion_y_Uso](#57_1_Instalacion_y_Uso)
#     *   [# 57_2_Interpretacion_de_Informes](#57_2_Interpretacion_de_Informes)
#     *   [# 57_3_Ejercicio_Practico_Escribir_Pruebas_para_App_Blog](#57_3_Ejercicio_Practico_Escribir_Pruebas_para_App_Blog)
#
# Unidad 11: Despliegue (Deployment)
#
# 58. [# 58_Diferencias_Entorno_Desarrollo_vs_Produccion](#58_Diferencias_Entorno_Desarrollo_vs_Produccion)
# 59. [# 59_Configuraciones_para_Produccion_DEBUG_SECRET_KEY_ALLOWED_HOSTS](#59_Configuraciones_para_Produccion_DEBUG_SECRET_KEY_ALLOWED_HOSTS)
#     *   [# 59_1_Gestion_de_Settings_Multiples_Entornos](#59_1_Gestion_de_Settings_Multiples_Entornos)
#     *   [# 59_2_Variables_de_Entorno_python_dotenv](#59_2_Variables_de_Entorno_python_dotenv)
# 60. [# 60_Servidores_WSGI_Gunicorn_uWSGI](#60_Servidores_WSGI_Gunicorn_uWSGI)
#     *   [# 60_1_Instalacion_y_Ejecucion_Basica](#60_1_Instalacion_y_Ejecucion_Basica)
#     *   [# 60_2_Configuracion_Workers_Threads](#60_2_Configuracion_Workers_Threads)
# 61. [# 61_Servidores_Web_Proxy_Inverso_Nginx_Apache](#61_Servidores_Web_Proxy_Inverso_Nginx_Apache)
#     *   [# 61_1_Por_Que_Usar_un_Proxy_Inverso](#61_1_Por_Que_Usar_un_Proxy_Inverso)
#     *   [# 61_2_Configuracion_Basica_Ejemplo_Nginx](#61_2_Configuracion_Basica_Ejemplo_Nginx)
# 62. [# 62_Servicio_de_Archivos_Estaticos_en_Produccion_collectstatic](#62_Servicio_de_Archivos_Estaticos_en_Produccion_collectstatic)
# 63. [# 63_Configuracion_de_Base_de_Datos_para_Produccion_PostgreSQL_MySQL](#63_Configuracion_de_Base_de_Datos_para_Produccion_PostgreSQL_MySQL)
# 64. [# 64_Estrategias_y_Plataformas_Comunes_Heroku_PythonAnywhere_Docker_VPS](#64_Estrategias_y_Plataformas_Comunes_Heroku_PythonAnywhere_Docker_VPS)
#     *   [# 64_1_PaaS_Ventajas_y_Desventajas](#64_1_PaaS_Ventajas_y_Desventajas)
#     *   [# 64_2_Contenedores_Docker_Concepto](#64_2_Contenedores_Docker_Concepto)
#     *   [# 64_3_VPS_Control_Total](#64_3_VPS_Control_Total)
# 65. [# 65_Consideraciones_de_Seguridad_HTTPS_Checklist_manage_py_check](#65_Consideraciones_de_Seguridad_HTTPS_Checklist_manage_py_check)
#     *   [# 65_1_Checklist_de_Despliegue_de_Django](#65_1_Checklist_de_Despliegue_de_Django)
#     *   [# 65_2_Configuracion_HTTPS_Lets_Encrypt](#65_2_Configuracion_HTTPS_Lets_Encrypt)
#     *   [# 65_3_Cabeceras_HTTP_de_Seguridad](#65_3_Cabeceras_HTTP_de_Seguridad)
#     *   [# 65_4_Ejercicio_Practico_Preparar_Proyecto_para_Despliegue_Basico](#65_4_Ejercicio_Practico_Preparar_Proyecto_para_Despliegue_Basico)
#
# Unidad 12: Temas Avanzados y Próximos Pasos
#
# 66. [# 66_Middleware_Personalizado](#66_Middleware_Personalizado)
#     *   [# 66_1_Ciclo_de_Vida_y_Hooks](#66_1_Ciclo_de_Vida_y_Hooks)
#     *   [# 66_2_Casos_de_Uso_y_Ejemplo](#66_2_Casos_de_Uso_y_Ejemplo)
# 67. [# 67_Signals_Senales_Desacoplamiento](#67_Signals_Senales_Desacoplamiento)
#     *   [# 67_1_Senales_Incorporadas_y_Personalizadas](#67_1_Senales_Incorporadas_y_Personalizadas)
#     *   [# 67_2_Definicion_y_Conexion_de_Receptores](#67_2_Definicion_y_Conexion_de_Receptores)
# 68. [# 68_Caching_Framework_Django](#68_Caching_Framework_Django)
#     *   [# 68_1_Configuracion_Backends_Memcached_Redis_DB_File_LocMem](#68_1_Configuracion_Backends_Memcached_Redis_DB_File_LocMem)
#     *   [# 68_2_API_de_Bajo_Nivel_get_set_delete](#68_2_API_de_Bajo_Nivel_get_set_delete)
#     *   [# 68_3_Cache_de_Vistas_cache_page](#68_3_Cache_de_Vistas_cache_page)
#     *   [# 68_4_Cache_de_Plantillas_cache_tag](#68_4_Cache_de_Plantillas_cache_tag)
# 69. [# 69_Creacion_de_APIs_REST_con_Django_REST_Framework_DRF_Introduccion](#69_Creacion_de_APIs_REST_con_Django_REST_Framework_DRF_Introduccion)
#     *   [# 69_1_Serializers_ModelSerializer](#69_1_Serializers_ModelSerializer)
#     *   [# 69_2_Vistas_API_Genericas](#69_2_Vistas_API_Genericas)
#     *   [# 69_3_ViewSets_y_Routers](#69_3_ViewSets_y_Routers)
#     *   [# 69_4_Autenticacion_y_Permisos_en_DRF](#69_4_Autenticacion_y_Permisos_en_DRF)
# 70. [# 70_Tareas_Asincronas_con_Celery_Introduccion](#70_Tareas_Asincronas_con_Celery_Introduccion)
#     *   [# 70_1_Necesidad_y_Arquitectura_Broker_Worker](#70_1_Necesidad_y_Arquitectura_Broker_Worker)
#     *   [# 70_2_Configuracion_Basica_con_Redis_o_RabbitMQ](#70_2_Configuracion_Basica_con_Redis_o_RabbitMQ)
#     *   [# 70_3_Definicion_y_Llamada_de_Tareas](#70_3_Definicion_y_Llamada_de_Tareas)
# 71. [# 71_WebSockets_con_Django_Channels_Introduccion](#71_WebSockets_con_Django_Channels_Introduccion)
#     *   [# 71_1_ASGI_vs_WSGI](#71_1_ASGI_vs_WSGI)
#     *   [# 71_2_Consumers_Routing_Channel_Layers](#71_2_Consumers_Routing_Channel_Layers)
# 72. [# 72_Internacionalizacion_i18n_y_Localizacion_l10n](#72_Internacionalizacion_i18n_y_Localizacion_l10n)
#     *   [# 72_1_Marcar_Textos_Traducibles_y_Compilar_Mensajes](#72_1_Marcar_Textos_Traducibles_y_Compilar_Mensajes)
#     *   [# 72_2_Formato_de_Fechas_Numeros_Monedas](#72_2_Formato_de_Fechas_Numeros_Monedas)
# 73. [# 73_Sistema_de_Mensajes_Messages_Framework](#73_Sistema_de_Mensajes_Messages_Framework)
#     *   [# 73_1_Anadir_y_Mostrar_Mensajes_Flash](#73_1_Anadir_y_Mostrar_Mensajes_Flash)
# 74. [# 74_Recursos_Adicionales_y_Comunidad_Django](#74_Recursos_Adicionales_y_Comunidad_Django)
# 75. [# 75_Conclusion_Final_del_Curso](#75_Conclusion_Final_del_Curso)
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ---
# ---
#
# ## **Unidad 1: Introducción y Configuración del Entorno**
#
# ## 1_Introduccion_a_Django
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 1_1_Que_es_Django_y_su_Filosofia
#
# Django es un **framework de desarrollo web de alto nivel**, escrito en **Python**, que permite crear aplicaciones web seguras y mantenibles de forma rápida. Fue creado originalmente por Adrian Holovaty y Simon Willison mientras trabajaban en el periódico Lawrence Journal-World en Kansas, EE.UU., para gestionar sitios de noticias y fue lanzado como proyecto open-source en 2005. Su nombre rinde homenaje al guitarrista de jazz Django Reinhardt.
#
# La filosofía principal de Django se puede resumir en varios puntos clave:
#
# *   **DRY (Don't Repeat Yourself - No te repitas):** Este es uno de los principios fundamentales del diseño de software, y Django lo adopta plenamente. El objetivo es minimizar la redundancia. Si tienes una pieza de información o lógica, debería existir en un solo lugar bien definido. Django proporciona abstracciones como el ORM y el sistema de plantillas para evitar repetir código.
# *   **Desarrollo Rápido:** Django fue diseñado explícitamente para ayudar a los desarrolladores a llevar las aplicaciones desde el concepto hasta la finalización lo más rápido posible, cumpliendo con plazos ajustados (como los de un periódico). Características como el ORM, la interfaz de administración automática, el sistema de formularios y las vistas genéricas contribuyen a esta rapidez.
# *   **Seguro por Defecto:** Django se toma la seguridad muy en serio. Proporciona herramientas y protección incorporada contra muchas vulnerabilidades web comunes, como Cross-Site Scripting (XSS), Cross-Site Request Forgery (CSRF), Inyección SQL y Clickjacking. Fomenta prácticas seguras por defecto.
# *   **Escalable:** Aunque permite un desarrollo rápido, Django está diseñado para poder escalar y manejar aplicaciones con grandes volúmenes de tráfico y datos. Sitios web muy conocidos como Instagram, Pinterest, Disqus y Mozilla utilizan Django.
# *   **"Baterías Incluidas":** A diferencia de los microframeworks, Django viene con un conjunto completo de herramientas y librerías integradas que cubren las necesidades más comunes del desarrollo web:
#     *   Un potente ORM para interactuar con bases de datos.
#     *   Una interfaz de administración automática.
#     *   Un sistema de autenticación y autorización de usuarios robusto.
#     *   Un framework de formularios para creación y validación.
#     *   Un sistema de plantillas flexible.
#     *   Un sistema de enrutamiento de URLs.
#     *   Un framework de caché.
#     *   Protección de seguridad incorporada.
#     *   Soporte para internacionalización (i18n).
#     *   Un framework de pruebas.
# *   **Mantenible y Pragmático:** Django fomenta un diseño limpio y código mantenible siguiendo patrones de diseño bien establecidos y convenciones claras.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 1_2_Arquitectura_MVT_Model_View_Template
#
# Django sigue un patrón arquitectónico conocido como **MVT (Model-View-Template)**. Es una variante del más conocido patrón MVC (Model-View-Controller) y describe cómo se separan las responsabilidades dentro de una aplicación web Django.
#
# *   **Model (Modelo):**
#     *   **Responsabilidad:** Define la estructura de los datos de la aplicación y cómo interactuar con ellos. Es la única fuente de verdad sobre tus datos.
#     *   **Implementación en Django:** Clases Python definidas en el archivo `models.py` de una aplicación, que heredan de `django.db.models.Model`.
#     *   **Interacción:** Se comunica con la base de datos a través del ORM de Django. Define campos, relaciones y lógica de negocio relacionada directamente con los datos (métodos del modelo).
#
# *   **View (Vista):**
#     *   **Responsabilidad:** Maneja la lógica de la aplicación. Recibe una petición web (`HttpRequest`), procesa los datos necesarios (a menudo interactuando con los Modelos), y decide qué respuesta (`HttpResponse`) enviar de vuelta al usuario. **Actúa como el intermediario.**
#     *   **Implementación en Django:** Funciones Python (Function-Based Views - FBVs) o Clases Python (Class-Based Views - CBVs) definidas en el archivo `views.py` de una aplicación.
#     *   **Nota:** En Django, la "Vista" es más parecida al "Controller" en el patrón MVC tradicional. Se encarga de la lógica de control.
#
# *   **Template (Plantilla):**
#     *   **Responsabilidad:** Define la presentación de los datos al usuario, generalmente en formato HTML. Separa la estructura de la interfaz de usuario de la lógica de la vista.
#     *   **Implementación en Django:** Archivos de texto (usualmente HTML) que contienen etiquetas y filtros especiales del Django Template Language (DTL) o Jinja2. Estos permiten mostrar variables pasadas desde la vista, usar estructuras de control básicas (bucles, condicionales) y reutilizar código HTML (herencia, inclusión).
#     *   **Nota:** En Django, la "Plantilla" es más parecida a la "View" en el patrón MVC tradicional. Se encarga de cómo se *ven* los datos.
#
# **¿Y el Controller?** En Django, el propio framework actúa como el controlador, manejando el enrutamiento de URLs (a través de `urls.py`) y dirigiendo la petición a la vista apropiada. La lógica que normalmente estaría en un Controller MVC se encuentra principalmente dentro de las Vistas Django.
#
# Este patrón MVT promueve una separación clara de intereses, haciendo que las aplicaciones sean más organizadas, fáciles de mantener y de probar.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 1_3_Ventajas_y_Desventajas_de_Usar_Django
#
# **Ventajas:**
#
# *   **Desarrollo Rápido:** Gracias a sus "baterías incluidas" y convenciones, permite construir funcionalidades complejas rápidamente.
# *   **Seguridad:** Fuerte enfoque en la seguridad con protecciones incorporadas.
# *   **Escalabilidad:** Diseñado para manejar crecimiento y alto tráfico.
# *   **Comunidad y Ecosistema:** Una comunidad muy grande y activa, y una vasta cantidad de paquetes de terceros (`django-packages.org`) para extender funcionalidades.
# *   **Admin Automático:** Una de sus características más destacadas, ahorra muchísimo tiempo en la creación de interfaces de gestión interna.
# *   **ORM Potente:** Simplifica enormemente la interacción con bases de datos relacionales.
# *   **Buena Documentación:** La documentación oficial es extensa, clara y bien mantenida.
# *   **Versatilidad:** Se puede usar para una amplia gama de aplicaciones web.
#
# **Desventajas:**
#
# *   **Monolítico/Pesado:** Para proyectos muy pequeños, APIs simples o microservicios, su naturaleza "baterías incluidas" puede sentirse excesiva comparada con microframeworks como Flask o FastAPI.
# *   **Opinado:** Sigue convenciones fuertes ("the Django way"). Si necesitas desviarte significativamente de ellas, puede requerir más esfuerzo o ir "contra corriente".
# *   **Curva de Aprendizaje:** Aunque fácil para empezar con lo básico, dominar todas las partes del framework (ORM avanzado, CBVs complejas, admin profundo, etc.) lleva tiempo.
# *   **Acoplamiento Implícito:** Algunas partes del framework están bastante interconectadas (ej: admin depende del ORM y del sistema de autenticación), lo que puede dificultar reemplazar componentes individuales si se desea.
# *   **No Ideal para Todo:** Aunque versátil, puede no ser la mejor opción para aplicaciones que requieran un rendimiento extremo en tiempo real sin usar Channels, o para tareas muy específicas donde un microframework daría más control granular.
#
# En general, Django es una excelente opción para la mayoría de las aplicaciones web, especialmente aquellas que requieren una base de datos, autenticación de usuarios y una interfaz de administración.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 1_4_Instalacion_de_Python_y_Pip
#
# Para usar Django, el primer requisito es tener instalado Python y su gestor de paquetes, Pip.
#
# 1.  **Verificar si Python está instalado:**
#     Abre tu terminal o símbolo del sistema (Command Prompt o PowerShell en Windows, Terminal en macOS/Linux) y ejecuta:
#     ```bash
#     python --version
#     ```
#     o, si tienes varias versiones o `python` apunta a Python 2 (en sistemas antiguos), prueba:
#     ```bash
#     python3 --version
#     ```
#     Si obtienes una versión (ej: `Python 3.10.4`), ya lo tienes. Asegúrate de que sea una versión compatible con la versión de Django que planeas usar (consulta la documentación oficial de Django). Generalmente, las versiones recientes de Python 3 (3.8+) son compatibles con las versiones recientes de Django.
#
# 2.  **Instalar Python (si no lo tienes):**
#     *   **Windows:** Descarga el instalador desde [https://www.python.org/downloads/windows/](https://www.python.org/downloads/windows/). **Importante:** Durante la instalación, asegúrate de marcar la casilla que dice "Add Python X.Y to PATH" o similar. Esto hace que los comandos `python` y `pip` estén disponibles desde cualquier directorio en la línea de comandos.
#     *   **macOS:** Puedes descargar el instalador desde [python.org](https://www.python.org/downloads/macos/). Alternativamente, si usas [Homebrew](https://brew.sh/), puedes instalarlo con: `brew install python`
#     *   **Linux:** Python suele venir preinstalado. Si no, usa el gestor de paquetes de tu distribución:
#         *   Debian/Ubuntu: `sudo apt update && sudo apt install python3 python3-pip python3-venv`
#         *   Fedora/CentOS/RHEL: `sudo dnf install python3 python3-pip` (o `yum` en versiones más antiguas)
#
# 3.  **Verificar si Pip está instalado:**
#     Pip generalmente se instala junto con Python (versiones 3.4+). Verifica ejecutando:
#     ```bash
#     pip --version
#     ```
#     o
#     ```bash
#     pip3 --version
#     ```
#     Si no está, intenta instalarlo (en algunas instalaciones de Linux puede venir separado):
#     *   Debian/Ubuntu: `sudo apt install python3-pip`
#     *   Fedora/CentOS: `sudo dnf install python3-pip`
#     *   General (asegúrate de tener Python): `python -m ensurepip --upgrade`
#
# 4.  **Actualizar Pip (Recomendado):**
#     Es buena idea tener la última versión de Pip.
#     ```bash
#     python -m pip install --upgrade pip
#     # o
#     python3 -m pip install --upgrade pip
#     ```
#
# Con Python y Pip listos, estás preparado para configurar tu entorno de proyecto.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 1_5_Entornos_Virtuales_venv
#
# Un entorno virtual es un directorio aislado que contiene una instalación específica de Python y sus paquetes correspondientes. Usar entornos virtuales es una **práctica esencial** en el desarrollo con Python y Django.
#
# **¿Por qué usarlos?**
# *   **Aislamiento de Dependencias:** Cada proyecto puede tener su propio conjunto de paquetes (como Django, Pillow, requests) con versiones específicas, sin interferir con otros proyectos o con los paquetes globales del sistema. Esto evita el "infierno de las dependencias".
# *   **Reproducibilidad:** Facilita compartir y replicar el entorno exacto del proyecto en otras máquinas (colaboradores, servidores de producción) usando un archivo `requirements.txt`.
# *   **Limpieza:** Mantiene la instalación global de Python limpia.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# #### 1_5_1_Creacion_y_Activacion
#
# El módulo `venv` viene incorporado con Python 3.3+.
#
# 1.  **Navega** en tu terminal a la carpeta donde quieres almacenar tu proyecto Django.
#     ```bash
#     mkdir MiProyectoDjango
#     cd MiProyectoDjango
#     ```
# 2.  **Crea** el entorno virtual. El nombre `venv` o `env` es una convención común.
#     ```bash
#     # Sintaxis: python -m venv <nombre_del_entorno>
#     python -m venv venv
#     # o si usas python3:
#     # python3 -m venv venv
#     ```
#     Esto creará una carpeta llamada `venv` en el directorio `MiProyectoDjango`. Esta carpeta contiene una copia del intérprete de Python, pip, y otros archivos necesarios. **Es recomendable añadir `venv/` a tu archivo `.gitignore`** si usas Git, para no incluir el entorno virtual en tu repositorio.
#
# 3.  **Activa** el entorno virtual. El comando varía según tu sistema operativo y shell:
#     *   **Windows (Símbolo del sistema - cmd.exe):**
#         ```bash
#         venv\Scripts\activate.bat
#         ```
#     *   **Windows (PowerShell):**
#         ```bash
#         venv\Scripts\Activate.ps1
#         ```
#         *Nota: Si encuentras un error de política de ejecución en PowerShell, puede que necesites ejecutar `Set-ExecutionPolicy Unrestricted -Scope Process` (solo para ese proceso de PowerShell) e intentar activar de nuevo.*
#     *   **Linux / macOS (bash, zsh, etc.):**
#         ```bash
#         source venv/bin/activate
#         ```
#     Cuando el entorno está activo, verás su nombre entre paréntesis al principio del prompt de tu terminal, por ejemplo: `(venv) ~/Proyectos/MiProyectoDjango$`. **Cualquier paquete que instales con `pip` ahora se instalará dentro de `venv`, no globalmente.**
#
# 4.  **Desactivar:** Cuando termines de trabajar en el proyecto, simplemente ejecuta:
#     ```bash
#     deactivate
#     ```
#     El prefijo `(venv)` desaparecerá del prompt.
#
# **Recuerda siempre activar el entorno virtual correspondiente antes de empezar a trabajar en tu proyecto Django.**
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# #### 1_5_2_Manejo_de_Dependencias_requirements_txt
#
# Para facilitar la gestión de las dependencias (los paquetes Python que tu proyecto necesita, como Django), se utiliza un archivo llamado `requirements.txt`.
#
# 1.  **Generar `requirements.txt`:** Una vez que has instalado los paquetes necesarios para tu proyecto (con el entorno virtual activo), puedes generar automáticamente el archivo listando los paquetes y sus versiones:
#     ```bash
#     # Asegúrate de que (venv) está activo
#     pip freeze > requirements.txt
#     ```
#     Esto crea un archivo `requirements.txt` en tu directorio actual con un contenido similar a:
#     ```
#     asgiref==3.7.2
#     Django==4.2.6
#     sqlparse==0.4.4
#     tzdata==2023.3
#     ... (otras dependencias)
#     ```
#     **Añade y commitea este archivo `requirements.txt` a tu control de versiones (Git).**
#
# 2.  **Instalar desde `requirements.txt`:** Cuando otro desarrollador clona tu proyecto, o cuando despliegas en un nuevo servidor, pueden recrear el mismo entorno virtual instalando todas las dependencias listadas en el archivo con un solo comando (después de crear y activar un nuevo entorno virtual):
#     ```bash
#     # Crear y activar nuevo venv
#     python -m venv venv
#     source venv/bin/activate # o el comando para tu SO
#     # Instalar dependencias
#     pip install -r requirements.txt
#     ```
# Esto asegura que todos trabajen con las mismas versiones de los paquetes, evitando problemas de compatibilidad. Es una práctica estándar actualizar `requirements.txt` cada vez que añades, eliminas o actualizas una dependencia importante.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 1_6_Instalacion_de_Django
#
# Con tu entorno virtual **creado y activado**, la instalación de Django es sencilla usando Pip:
#
# ```bash
# # Asegúrate de que (venv) aparece en tu prompt
# pip install Django
# ```
#
# Pip descargará e instalará la última versión estable de Django y cualquier dependencia que necesite (como `asgiref`, `sqlparse`, `tzdata`) dentro de tu entorno `venv`.
#
# **Verificar la instalación:**
# Puedes comprobar que Django se ha instalado correctamente ejecutando:
# ```bash
# django-admin --version
# ```
# Esto debería mostrar la versión de Django instalada (ej: `4.2.6`).
#
# **Instalar una versión específica:**
# Si necesitas una versión particular (por compatibilidad con otros paquetes o para seguir un tutorial específico):
# ```bash
# pip install Django==4.1.10 # Instala exactamente la versión 4.1.10
# pip install "Django>=4.0,<4.1" # Instala la última versión 4.0.x
# pip install Django~=4.2.0 # Instala versiones >= 4.2.0 pero < 5.0 (recomendado para estabilidad)
# ```
# Actualiza tu archivo `requirements.txt` después de instalar Django (`pip freeze > requirements.txt`).
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 1_7_Creacion_de_un_Proyecto_Django
#
# Ahora que tienes Django instalado en tu entorno virtual, puedes crear la estructura básica de tu proyecto web. Un **proyecto** Django es la colección de configuraciones y aplicaciones que forman un sitio web completo.
#
# Usa la utilidad de línea de comandos `django-admin` (que se instaló con Django) y el comando `startproject`.
#
# **Importante:** Ejecuta este comando en el directorio donde quieres que resida tu proyecto (ej: `MiProyectoDjango`), **no** dentro de la carpeta `venv`. Asegúrate de que tu entorno virtual esté **activo**.
#
# ```bash
# # (venv) Navega a tu carpeta principal (ej: MiProyectoDjango)
# # cd ~/Proyectos/MiProyectoDjango
#
# # Sintaxis: django-admin startproject <nombre_del_proyecto> [directorio_destino_opcional]
# django-admin startproject mi_sitio .
# ```
#
# *   `mi_sitio`: Este será el nombre de tu proyecto Django. Es importante elegir un nombre válido como identificador Python (sin espacios, guiones, etc.).
# *   `.` (el punto al final): Este argumento es **importante y recomendado**. Le dice a Django que cree los archivos y directorios del proyecto directamente en el directorio *actual* (`MiProyectoDjango` en este ejemplo). Si omites el punto, Django creará una carpeta adicional llamada `mi_sitio` y pondrá todo dentro de ella, resultando en una estructura como `MiProyectoDjango/mi_sitio/mi_sitio/`, lo cual suele ser redundante.
#
# Después de ejecutar el comando con el punto, tu estructura de carpetas debería verse así:
#
# ```
# MiProyectoDjango/
# ├── manage.py         <-- ¡Nuevo!
# ├── mi_sitio/         <-- ¡Nuevo! Directorio de configuración del proyecto
# │   ├── __init__.py
# │   ├── asgi.py
# │   ├── settings.py
# │   ├── urls.py
# │   └── wsgi.py
# └── venv/             <-- Tu entorno virtual
# ```
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 1_8_Estructura_del_Proyecto
#
# Analicemos los archivos y directorios que `startproject` acaba de crear:
#
# *   **Directorio Externo (Raíz del Proyecto - `MiProyectoDjango/`):**
#     *   Es el contenedor de tu proyecto. No forma parte de Django directamente, pero es donde vivirán `manage.py`, tus aplicaciones, `venv`, `requirements.txt`, etc.
#
# *   **`manage.py`:**
#     *   Una utilidad de línea de comandos esencial para interactuar con tu proyecto Django.
#     *   Actúa como un envoltorio delgado alrededor de `django-admin`.
#     *   Lo usarás constantemente para tareas como:
#         *   Ejecutar el servidor de desarrollo (`python manage.py runserver`).
#         *   Crear migraciones de base de datos (`python manage.py makemigrations`).
#         *   Aplicar migraciones (`python manage.py migrate`).
#         *   Crear nuevas aplicaciones (`python manage.py startapp nombre_app`).
#         *   Ejecutar pruebas (`python manage.py test`).
#         *   Abrir un shell interactivo de Python con el entorno de Django cargado (`python manage.py shell`).
#         *   Crear superusuarios (`python manage.py createsuperuser`).
#         *   Recopilar archivos estáticos (`python manage.py collectstatic`).
#     *   **Nunca edites este archivo.**
#
# *   **Directorio Interno (`mi_sitio/`):**
#     *   Este es el paquete Python real de tu proyecto. Su nombre es el que le diste a `startproject` (`mi_sitio`).
#     *   Contiene la configuración central del proyecto. Necesitarás importar cosas desde aquí (ej: `from mi_sitio.settings import ...`). Puedes renombrar esta carpeta si lo deseas, pero tendrás que actualizar las referencias en `manage.py`, `wsgi.py`, y `asgi.py`.
#     *   **`__init__.py`:** Un archivo vacío que le indica a Python que este directorio debe ser tratado como un paquete Python.
#     *   **`settings.py`:** **Archivo crucial.** Contiene toda la configuración de tu proyecto Django: base de datos, `SECRET_KEY`, `DEBUG`, `ALLOWED_HOSTS`, `INSTALLED_APPS`, `MIDDLEWARE`, configuración de plantillas, archivos estáticos (`STATIC_URL`, `STATIC_ROOT`), archivos de medios (`MEDIA_URL`, `MEDIA_ROOT`), internacionalización, etc. Pasarás mucho tiempo configurando este archivo.
#     *   **`urls.py`:** El archivo principal de configuración de URLs (URLconf) para el proyecto. Define los patrones de URL de nivel superior y cómo se mapean a las vistas o a los archivos `urls.py` de aplicaciones específicas usando `include()`.
#     *   **`wsgi.py`:** Punto de entrada para servidores web compatibles con **WSGI** (Web Server Gateway Interface), el estándar síncrono tradicional para aplicaciones web Python. Usado por servidores como Gunicorn y uWSGI en modo WSGI.
#     *   **`asgi.py`:** Punto de entrada para servidores web compatibles con **ASGI** (Asynchronous Server Gateway Interface), el estándar moderno que soporta funcionalidades asíncronas como WebSockets (usado por Django Channels). Usado por servidores como Daphne y Uvicorn.
#
# Esta estructura proporciona una organización clara para empezar a construir tu aplicación.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 1_9_El_Servidor_de_Desarrollo_runserver
#
# Django viene con un servidor web ligero incorporado, perfecto para usar durante el desarrollo. Te permite probar tu aplicación rápidamente sin tener que configurar un servidor de producción complejo como Nginx o Apache.
#
# **Características:**
# *   **Ligero y Rápido:** Se inicia rápidamente.
# *   **Recarga Automática:** Detecta cambios en tu código Python y reinicia el servidor automáticamente, permitiéndote ver los efectos de tus cambios simplemente refrescando el navegador. (No siempre detecta cambios en otros tipos de archivos como plantillas por defecto, aunque esto puede configurarse).
# *   **Depuración:** Si `DEBUG = True` en `settings.py`, muestra páginas de error detalladas con información de depuración muy útil (tracebacks, variables locales, configuración) cuando ocurre una excepción no controlada.
# *   **Servicio de Estáticos (Opcional):** Si `django.contrib.staticfiles` está en `INSTALLED_APPS`, puede servir archivos estáticos por conveniencia durante el desarrollo.
#
# **Cómo ejecutarlo:**
# 1.  Abre tu terminal.
# 2.  Navega hasta el directorio raíz de tu proyecto (el que contiene `manage.py`).
# 3.  Asegúrate de que tu entorno virtual (`venv`) esté activo.
# 4.  Ejecuta el comando:
#     ```bash
#     python manage.py runserver
#     ```
#
# **Salida esperada:**
# ```
# Watching for file changes with StatReloader
# Performing system checks...
#
# System check identified no issues (0 silenced).
# [Fecha y Hora]
# Django version X.Y.Z, using settings 'mi_sitio.settings'
# Starting development server at http://127.0.0.1:8000/
# Quit the server with CTRL-BREAK (Windows) or CTRL-C (Mac/Linux).
# ```
#
# *   **Acceso:** Abre tu navegador y ve a `http://127.0.0.1:8000/` o `http://localhost:8000/`. Verás la página de bienvenida de Django si aún no has configurado ninguna URL.
# *   **Puerto:** Por defecto usa el puerto 8000. Si está ocupado, intentará con el 8001, 8002, etc. Puedes especificar un puerto: `python manage.py runserver 8080`.
# *   **Dirección IP:** Por defecto solo escucha en la IP local (`127.0.0.1`). Si quieres acceder desde otro dispositivo en tu misma red local (ej: un móvil para probar responsive), puedes usar: `python manage.py runserver 0.0.0.0:8000` (¡Ten cuidado, esto hace tu sitio visible en la red local!).
# *   **Detener:** Presiona `CTRL + C` en la terminal donde se está ejecutando.
#
# **Importante:** El servidor de desarrollo es **solo para desarrollo**. No es seguro, eficiente ni robusto para manejar tráfico real en un entorno de producción. Para producción, usarás un servidor WSGI/ASGI (Gunicorn/uWSGI/Daphne/Uvicorn) detrás de un proxy inverso (Nginx/Apache).
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 1_10_Creacion_de_una_Aplicacion_Django_startapp
#
# En Django, un **proyecto** se compone de una o más **aplicaciones**. Una aplicación es un paquete Python que encapsula una funcionalidad específica y autocontenida del sitio web. Piensa en ellas como módulos reutilizables.
#
# **Ejemplos de Aplicaciones:**
# *   Un sistema de blog (`blog`).
# *   Una tienda online (`tienda`).
# *   Un sistema de encuestas (`encuestas`).
# *   Gestión de usuarios/perfiles (`cuentas` o `usuarios`).
# *   Un foro (`foro`).
#
# **Crear una Aplicación:**
# Se usa el comando `manage.py startapp`.
#
# 1.  Asegúrate de estar en el directorio raíz del proyecto (donde está `manage.py`).
# 2.  Asegúrate de que tu entorno virtual esté activo.
# 3.  Ejecuta:
#     ```bash
#     # Sintaxis: python manage.py startapp <nombre_de_la_app>
#     python manage.py startapp blog
#     ```
#     *   Elige un nombre corto, descriptivo y en minúsculas para tu aplicación (debe ser un nombre de paquete Python válido).
#
# Esto creará una nueva carpeta (`blog/` en este caso) con la estructura estándar de una aplicación Django:
#
# ```
# MiProyectoDjango/
# ├── blog/               <-- Directorio de la nueva app
# │   ├── __init__.py     <-- Indica que es un paquete Python
# │   ├── admin.py        <-- Configuración del admin para los modelos de esta app
# │   ├── apps.py         <-- Configuración de la propia aplicación
# │   ├── migrations/     <-- Directorio para las migraciones de BD de esta app
# │   │   └── __init__.py
# │   ├── models.py       <-- Aquí definirás los modelos de datos de la app
# │   ├── tests.py        <-- Aquí escribirás las pruebas para la app
# │   └── views.py        <-- Aquí escribirás la lógica de las vistas de la app
# ├── manage.py
# ├── mi_sitio/
# │   └── ... (Archivos de configuración del proyecto)
# └── venv/
# ```
#
# Puedes crear tantas aplicaciones como necesites para organizar tu proyecto de forma lógica.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 1_11_Registro_de_Aplicaciones_INSTALLED_APPS
#
# **Paso absolutamente crucial:** Después de crear una aplicación con `startapp`, debes **informar a tu proyecto Django** que esta nueva aplicación existe y debe ser considerada. Esto se hace añadiéndola a la lista `INSTALLED_APPS` en tu archivo `settings.py`.
#
# Edita `mi_sitio/settings.py`:
#
# ```python
# # mi_sitio/settings.py
#
# INSTALLED_APPS = [
#     # Aplicaciones incorporadas de Django (orden a veces importa)
#     'django.contrib.admin',
#     'django.contrib.auth',
#     'django.contrib.contenttypes',
#     'django.contrib.sessions',
#     'django.contrib.messages',
#     'django.contrib.staticfiles',
#
#     # Aplicaciones de terceros (si las hubiera)
#     # 'nombre_paquete_tercero',
#
#     # Mis aplicaciones (¡añadir aquí!)
#     'blog.apps.BlogConfig', # Forma moderna y recomendada (usa la clase definida en blog/apps.py)
#     # o simplemente 'blog', # Forma corta, menos explícita
# ]
# ```
#
# *   **¿Por qué registrarla?** Al registrar la app, Django sabrá:
#     *   Buscar modelos en `blog/models.py` para crear migraciones.
#     *   Buscar plantillas en `blog/templates/`.
#     *   Buscar archivos estáticos en `blog/static/`.
#     *   Buscar archivos de traducción en `blog/locale/`.
#     *   Buscar pruebas en `blog/tests.py`.
#     *   Buscar configuración del admin en `blog/admin.py`.
#     *   Ejecutar cualquier configuración inicial definida en `blog/apps.py`.
#
# **Sin registrar la aplicación en `INSTALLED_APPS`, Django la ignorará por completo.**
#
# **Forma recomendada:** Usar la ruta completa a la clase de configuración de la app (ej: `'blog.apps.BlogConfig'`). Esta clase se define automáticamente en `apps.py` cuando creas la app:
#
# ```python
# # blog/apps.py
# from django.apps import AppConfig
#
# class BlogConfig(AppConfig):
#     default_auto_field = 'django.db.models.BigAutoField'
#     name = 'blog'
#     # verbose_name = "Gestión del Blog" # Opcional: nombre legible para el admin
# ```
# Usar la clase `AppConfig` es más explícito y permite configuraciones avanzadas de la aplicación más adelante.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 1_12_Proyectos_vs_Aplicaciones_Revisitado
#
# Ahora que hemos visto cómo crear ambos, reforcemos la diferencia conceptual:
#
# *   **Proyecto (`mi_sitio`):**
#     *   Representa **un sitio web completo** o una instancia de una aplicación web.
#     *   Contiene la **configuración global** (`settings.py`) que aplica a todo el sitio (base de datos, clave secreta, apps instaladas, middleware).
#     *   Define el **enrutamiento principal** (`urls.py` del proyecto) que dirige las peticiones a las diferentes aplicaciones.
#     *   Puede contener plantillas y archivos estáticos **globales** (compartidos por todas las apps).
#     *   Un proyecto *contiene* una o más aplicaciones.
#
# *   **Aplicación (`blog`):**
#     *   Representa una **funcionalidad específica** y autocontenida (un blog, un foro, una API de usuarios).
#     *   Contiene sus propios **modelos, vistas, plantillas, URLs, formularios, pruebas y archivos estáticos** relacionados con esa funcionalidad.
#     *   Debe ser lo más **desacoplada** posible del proyecto y de otras aplicaciones para fomentar la **reutilización**. Idealmente, podrías tomar la carpeta de una aplicación Django y usarla en otro proyecto Django con mínimas modificaciones.
#
# Pensar en términos de aplicaciones reutilizables desde el principio ayuda a crear proyectos más organizados y mantenibles a largo plazo.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 1_13_Ejercicio_Practico_Crear_Proyecto_y_App_Inicial
#
# **Objetivo:** Poner en práctica los pasos iniciales de configuración de un proyecto Django.
#
# **Pasos:**
#
# 1.  **Asegúrate** de tener Python y Pip instalados correctamente.
# 2.  **Elige** un directorio en tu sistema para tu nuevo proyecto (ej: `~/Proyectos/mi_tienda_online`).
# 3.  **Navega** a ese directorio en tu terminal.
# 4.  **Crea** un entorno virtual llamado `venv` dentro de ese directorio.
#     ```bash
#     python -m venv venv
#     ```
# 5.  **Activa** el entorno virtual.
#     *   (Windows CMD): `venv\Scripts\activate.bat`
#     *   (Windows PowerShell): `venv\Scripts\Activate.ps1`
#     *   (Linux/macOS): `source venv/bin/activate`
# 6.  **Instala** Django en el entorno virtual activo.
#     ```bash
#     pip install Django
#     ```
# 7.  **Verifica** la instalación de Django.
#     ```bash
#     django-admin --version
#     ```
# 8.  **Crea** un nuevo proyecto Django llamado `tienda_config` (el nombre del directorio de configuración) dentro del directorio actual (`mi_tienda_online`). Usa el punto `.` al final.
#     ```bash
#     django-admin startproject tienda_config .
#     ```
# 9.  **Inspecciona** la estructura de archivos creada (`manage.py`, `tienda_config/`).
# 10. **Crea** tu primera aplicación Django, llámala `productos`.
#     ```bash
#     python manage.py startapp productos
#     ```
# 11. **Registra** la nueva aplicación `productos` en tu proyecto. Edita el archivo `tienda_config/settings.py`, busca la lista `INSTALLED_APPS` y añade `'productos.apps.ProductosConfig'` (o simplemente `'productos'`).
# 12. **Inicia** el servidor de desarrollo para asegurarte de que todo funciona hasta ahora.
#     ```bash
#     python manage.py runserver
#     ```
# 13. **Abre** tu navegador y visita `http://127.0.0.1:8000/`. Deberías ver la página de bienvenida de Django.
# 14. **Detén** el servidor con `CTRL + C`.
# 15. **(Opcional pero recomendado)** Crea un archivo `requirements.txt`.
#     ```bash
#     pip freeze > requirements.txt
#     ```
# 16. **(Opcional pero recomendado)** Si usas Git, inicializa un repositorio, crea un archivo `.gitignore` (puedes encontrar plantillas para Python/Django online, asegúrate de incluir `venv/`, `__pycache__/`, `db.sqlite3` si usas SQLite, etc.) y haz tu primer commit.
#
# **Solución Propuesta:**
# *(No hay código de solución como tal, ya que son comandos de terminal y edición de `settings.py`. El resultado esperado es tener la estructura de directorios descrita y poder ejecutar `runserver` sin errores después de registrar la app).*
#
# ¡Has completado la configuración inicial! Ahora tienes un proyecto Django vacío con una aplicación lista para empezar a definir modelos, vistas y URLs.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ---
# ---
#
# ## **Unidad 2: Fundamentos - URLs, Vistas y Plantillas**
#
# ## 2_El_Ciclo_Request_Response_en_Django
#
# Antes de sumergirnos en los componentes individuales, es crucial entender el flujo básico que sigue una petición web en una aplicación Django. Comprender este ciclo te ayudará a saber dónde encaja cada pieza del framework.
#
# El ciclo simplificado es el siguiente:
#
# 1.  **Petición HTTP:** Un usuario interactúa con su navegador (escribe una URL, hace clic en un enlace, envía un formulario). El navegador envía una petición HTTP al servidor donde reside tu aplicación Django.
# 2.  **Servidor Web / WSGI/ASGI:** El servidor web (como Nginx o Apache en producción, o el servidor de desarrollo de Django) recibe esta petición. Utiliza la interfaz WSGI (o ASGI para asíncrono) para pasar la petición a tu aplicación Django.
# 3.  **Middleware (Entrada):** La petición atraviesa una serie de *middlewares* configurados en `settings.py`. Estos pueden modificar la petición o realizar acciones antes de que llegue a la lógica principal (ej: añadir información de sesión, verificar tokens CSRF).
# 4.  **URL Dispatcher (Enrutador - `urls.py`):** Django toma la parte de la ruta de la URL solicitada y la compara, en orden, con los patrones definidos en el archivo `urls.py` principal de tu proyecto.
# 5.  **Inclusión de URLs (`include()`):** Si un patrón en el `urls.py` principal usa `include()`, Django delega la búsqueda de coincidencias al archivo `urls.py` de la aplicación especificada, usando la parte restante de la ruta de la URL.
# 6.  **Vista (`views.py`):** Una vez que se encuentra un patrón de URL coincidente, Django llama a la **vista** asociada (ya sea una función - FBV - o el método apropiado de una clase - CBV). A la vista se le pasa un objeto `HttpRequest` que contiene toda la información sobre la petición entrante.
# 7.  **Lógica de la Vista:** La vista ejecuta el código Python que has escrito. Esto puede incluir:
#     *   Interactuar con los **modelos** (`models.py`) para consultar o modificar datos en la base de datos a través del ORM.
#     *   Procesar datos recibidos en la petición (parámetros GET, datos POST de formularios).
#     *   Realizar cálculos o aplicar lógica de negocio.
#     *   Preparar un **contexto** (un diccionario Python) con los datos que se mostrarán al usuario.
# 8.  **Renderizado de Plantilla (`templates/`):** Si la vista necesita devolver HTML, generalmente carga un archivo de **plantilla** y lo *renderiza* usando el contexto preparado. El sistema de plantillas reemplaza las variables y ejecuta las etiquetas de la plantilla para generar el HTML final.
# 9.  **Respuesta HTTP:** La vista **debe** devolver un objeto `HttpResponse`. Este objeto contiene el contenido final (ej: el HTML renderizado) y metadatos como el código de estado HTTP y las cabeceras.
# 10. **Middleware (Salida):** La respuesta `HttpResponse` viaja de vuelta a través de los *middlewares* en orden inverso. Estos pueden modificar la respuesta antes de que se envíe (ej: añadir cabeceras de seguridad, comprimir contenido).
# 11. **Servidor Web / WSGI/ASGI:** El servidor recibe la respuesta final de Django.
# 12. **Navegador:** El servidor envía la respuesta HTTP de vuelta al navegador del usuario, que la interpreta y muestra la página web resultante.
#
# Comprender este flujo es esencial para saber dónde escribir tu código (modelos, vistas, plantillas, URLs) y cómo depurar problemas.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ## 3_Mapeo_de_URLs_urls_py
#
# El "URL dispatcher" o enrutador de Django es responsable de examinar la URL solicitada y dirigir la petición a la vista correcta. Esta configuración se realiza principalmente en los archivos `urls.py`.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 3_1_Funcion_path
#
# En Django moderno, la forma principal de definir un patrón de URL es usando la función `path()` importada desde `django.urls`.
#
# **Sintaxis:**
# `path(route, view, kwargs=None, name=None)`
#
# *   `route` (String): El patrón de la URL que se debe buscar. No incluye el dominio ni la barra inicial (`/`). Puede contener conversores para capturar partes de la URL (ver 3.3). Ejemplos: `''` (para la raíz), `'articulos/'`, `'blog/<int:post_id>/'`.
# *   `view`: La función de vista (FBV) o el resultado del método `.as_view()` de una vista basada en clase (CBV) que se ejecutará si la `route` coincide.
# *   `kwargs` (Diccionario, Opcional): Argumentos de palabra clave adicionales que se pasarán a la vista, además de los capturados en la ruta.
# *   `name` (String, Opcional pero **Muy Recomendado**): Un nombre único para identificar este patrón de URL. Permite generar URLs de forma inversa usando `{% url %}` en plantillas o `reverse()` en Python, evitando hardcodear las rutas.
#
# **Ejemplo básico (`mi_sitio/urls.py`):**
# ```python
# # mi_sitio/urls.py
# from django.contrib import admin
# from django.urls import path
# # Importar vistas desde una app (ej: 'pages')
# from pages import views as pages_views
#
# urlpatterns = [
#     path('admin/', admin.site.urls),
#     # Ruta raíz ('/') mapeada a la vista 'home_page' en pages/views.py
#     path('', pages_views.home_page, name='home'),
#     # Ruta '/about/' mapeada a la vista 'about_page'
#     path('about/', pages_views.about_page, name='about'),
#     # Ruta '/contact/' mapeada a la vista 'contact_page'
#     path('contact/', pages_views.contact_page, name='contact'),
# ]
# ```
# *Nota: Necesitarías crear una app `pages` con un archivo `views.py` que contenga las funciones `home_page`, `about_page`, y `contact_page`.*
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 3_2_URLs_del_Proyecto_vs_URLs_de_la_Aplicacion_include
#
# Para mantener la organización y la reutilización, es una práctica estándar que cada aplicación Django gestione sus propias URLs. El archivo `urls.py` principal del proyecto actúa como un índice, delegando partes del espacio de URLs a las aplicaciones correspondientes usando la función `include()`.
#
# 1.  **Crear `urls.py` en la Aplicación:**
#     Dentro de la carpeta de tu aplicación (ej: `blog/`), crea un archivo `urls.py`.
#     ```python
#     # blog/urls.py
#     from django.urls import path
#     from . import views # Importa las vistas de la app actual (blog)
#
#     app_name = 'blog' # Define un namespace para evitar colisiones de nombres de URL
#
#     urlpatterns = [
#         # La URL '' dentro de este archivo corresponderá al prefijo definido en el urls.py del proyecto
#         path('', views.lista_posts_view, name='lista_posts'),
#         path('<int:pk>/', views.detalle_post_view, name='detalle_post'), # Ejemplo con ID
#         path('nuevo/', views.crear_post_view, name='crear_post'),
#     ]
#     ```
#     *   `app_name = 'blog'` es **crucial** para crear un *namespace*. Permite referenciar estas URLs como `'blog:lista_posts'` o `'blog:detalle_post'`, distinguiéndolas de URLs con el mismo `name` en otras apps.
#
# 2.  **Incluir en `urls.py` del Proyecto:**
#     Modifica el `urls.py` principal de tu proyecto (`mi_sitio/urls.py`) para usar `include()`.
#     ```python
#     # mi_sitio/urls.py
#     from django.contrib import admin
#     from django.urls import path, include # ¡Importar include!
#
#     urlpatterns = [
#         path('admin/', admin.site.urls),
#         # Cualquier URL que empiece con 'blog/' será manejada por blog/urls.py
#         path('blog/', include('blog.urls')),
#         # Podrías tener más inclusiones para otras apps
#         # path('tienda/', include('tienda.urls')),
#         # path('', include('pages.urls')), # Quizás para la página principal y 'about'
#     ]
#     ```
# Ahora, una petición a `/blog/` buscará el patrón `''` en `blog/urls.py` y llamará a `views.lista_posts_view`. Una petición a `/blog/5/` buscará `'<int:pk>/'` en `blog/urls.py` y llamará a `views.detalle_post_view` pasándole `pk=5`.
#
# Esta estructura hace que las aplicaciones sean mucho más portables y el enrutamiento más fácil de gestionar.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 3_3_Conversores_de_Ruta_str_int_slug_uuid_path
#
# Al definir `route` en `path()`, puedes capturar segmentos de la URL y pasarlos como argumentos a tu vista usando conversores de ruta con la sintaxis `<tipo:nombre_variable>`.
#
# Conversores incorporados:
# *   **`str`:** Captura cualquier cadena no vacía, excluyendo el carácter `/`. Es el conversor por defecto si no se especifica ninguno.
# *   **`int`:** Captura un número entero (cero o positivo).
# *   **`slug`:** Captura una cadena corta que contiene solo letras ASCII, números, guiones (`-`) o guiones bajos (`_`). Comúnmente usado para URLs amigables.
# *   **`uuid`:** Captura un Identificador Único Universal (UUID) formateado.
# *   **`path`:** Captura cualquier cadena no vacía, **incluyendo** el carácter `/`. Útil para capturar rutas completas.
#
# **Ejemplo (`blog/urls.py`):**
# ```python
# # blog/urls.py
# from django.urls import path
# from . import views
#
# app_name = 'blog'
#
# urlpatterns = [
#     path('', views.lista_posts_view, name='lista_posts'),
#     # Captura un entero y lo pasa como 'pk' a la vista
#     path('<int:pk>/', views.detalle_post_view, name='detalle_post'),
#     # Captura un slug y lo pasa como 'slug_articulo'
#     path('articulo/<slug:slug_articulo>/', views.detalle_slug_view, name='detalle_slug'),
#     # Captura año y mes
#     path('archivo/<int:anio>/<int:mes>/', views.archivo_view, name='archivo'),
#     # Captura una ruta completa
#     # path('documentos/<path:ruta_documento>/', views.documento_view, name='documento'),
# ]
# ```
#
# **Vista correspondiente (`blog/views.py`):**
# ```python
# # blog/views.py
# from django.http import HttpResponse
# # ... (otros imports)
#
# def lista_posts_view(request):
#     # ...
#     return HttpResponse("Lista de Posts")
#
# def detalle_post_view(request, pk): # Recibe el argumento 'pk' de la URL
#     # ... lógica para obtener el post con id=pk ...
#     return HttpResponse(f"Viendo detalle del post con ID: {pk}")
#
# def detalle_slug_view(request, slug_articulo): # Recibe 'slug_articulo'
#     # ... lógica para obtener el post con slug=slug_articulo ...
#     return HttpResponse(f"Viendo detalle del post con Slug: {slug_articulo}")
#
# def archivo_view(request, anio, mes): # Recibe 'anio' y 'mes'
#     # ... lógica para mostrar archivo ...
#     return HttpResponse(f"Viendo archivo para: Mes {mes}, Año {anio}")
# ```
# Los nombres de las variables en la ruta (`pk`, `slug_articulo`, `anio`, `mes`) **deben** coincidir con los nombres de los parámetros en la definición de la función de vista.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 3_4_Nombrar_Patrones_de_URL_name
#
# Como ya se mencionó, asignar un nombre único a cada `path()` usando el argumento `name` es una práctica **esencial y muy recomendada**.
#
# **¿Por qué?**
# *   **Desacoplamiento:** Permite cambiar la estructura de la URL (la `route`) en `urls.py` sin tener que buscar y reemplazar esa URL en todas tus plantillas y vistas. Solo necesitas asegurarte de que el `name` siga siendo el mismo.
# *   **Legibilidad:** El código que genera URLs (`{% url %}` o `reverse()`) se vuelve más claro y semántico. `reverse('blog:detalle_post', args=[post.id])` es más informativo que construir manualmente `/blog/123/`.
# *   **Mantenibilidad:** Mucho más fácil de mantener y refactorizar a largo plazo.
#
# **Convención:** Los nombres suelen ser descriptivos, en minúsculas y usando guiones bajos. Ej: `lista_posts`, `detalle_producto`, `crear_usuario`.
#
# **Recuerda:** Si usas namespaces (con `app_name`), la referencia completa al nombre será `'namespace:nombre_url'`.
#
# **¡Siempre nombra tus URLs!**
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 3_5_Namespaces_de_URL_app_name
#
# Cuando tienes múltiples aplicaciones, es muy probable que diferentes aplicaciones quieran usar el mismo nombre para una URL (ej: ambas podrían tener una vista `detail` o `list`). Para evitar colisiones, Django permite definir **namespaces** (espacios de nombres) para las URLs de cada aplicación.
#
# Se define estableciendo la variable `app_name` al principio de tu archivo `urls.py` de la aplicación:
#
# ```python
# # blog/urls.py
# from django.urls import path
# from . import views
#
# app_name = 'blog' # <--- ESTO DEFINE EL NAMESPACE
#
# urlpatterns = [
#     path('', views.lista_posts_view, name='lista_posts'),
#     path('<int:pk>/', views.detalle_post_view, name='detalle_post'),
# ]
# ```
#
# Ahora, para referenciar estas URLs de forma inversa, **debes** prefijar el nombre con el namespace seguido de dos puntos (`:`):
#
# *   **En Plantillas:** `{% url 'blog:lista_posts' %}` , `{% url 'blog:detalle_post' pk=post.id %}`
# *   **En Vistas (Python):** `reverse('blog:lista_posts')` , `reverse('blog:detalle_post', kwargs={'pk': post.id})`
#
# Usar namespaces es fundamental en proyectos con más de una aplicación para mantener la organización y evitar conflictos.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 3_6_Ejercicio_Practico_Configurar_URLs_Basicas
#
# **Objetivo:** Configurar las URLs para la aplicación `productos` creada en la unidad anterior, incluyendo una URL para la lista de productos y otra para el detalle de un producto.
#
# **Pasos:**
#
# 1.  **Crea el archivo `urls.py`** dentro de tu aplicación `productos` (`productos/urls.py`).
# 2.  **Define el `app_name`** al principio de `productos/urls.py`.
#     ```python
#     # productos/urls.py
#     app_name = 'productos'
#     ```
# 3.  **Importa `path`** de `django.urls` y las **vistas** (aunque aún no las hayamos creado) desde `. import views`.
#     ```python
#     # productos/urls.py
#     from django.urls import path
#     from . import views
#
#     app_name = 'productos'
#     # ... urlpatterns irán aquí ...
#     ```
# 4.  **Define los `urlpatterns`:**
#     *   Crea un `path` para la raíz de la app (`''`) que apunte a una vista (inexistente por ahora) llamada `lista_productos_view` y nómbrala `lista_productos`.
#     *   Crea un `path` que capture un entero como `producto_id` (ej: `<int:producto_id>/`) que apunte a una vista (inexistente) llamada `detalle_producto_view` y nómbrala `detalle_producto`.
#     ```python
#     # productos/urls.py
#     # ... (imports y app_name) ...
#
#     urlpatterns = [
#         path('', views.lista_productos_view, name='lista_productos'),
#         path('<int:producto_id>/', views.detalle_producto_view, name='detalle_producto'),
#     ]
#     ```
# 5.  **Incluye las URLs de la app `productos`** en el `urls.py` principal del proyecto (`tienda_config/urls.py`). Haz que las URLs de productos estén bajo el prefijo `/productos/`.
#     ```python
#     # tienda_config/urls.py
#     from django.contrib import admin
#     from django.urls import path, include # ¡Asegúrate de importar include!
#
#     urlpatterns = [
#         path('admin/', admin.site.urls),
#         # Incluir las URLs de la app productos bajo /productos/
#         path('productos/', include('productos.urls')),
#         # Podrías tener otras aquí, como una página de inicio
#         # path('', include('pages.urls')),
#     ]
#     ```
# 6.  **Crea las funciones de vista placeholder** en `productos/views.py` para que Django no dé error al buscar las vistas (por ahora solo devolverán un HttpResponse simple).
#     ```python
#     # productos/views.py
#     from django.http import HttpResponse
#
#     def lista_productos_view(request):
#         return HttpResponse("<h1>Lista de Productos</h1><p>Aquí irán los productos...</p>")
#
#     def detalle_producto_view(request, producto_id):
#         return HttpResponse(f"<h1>Detalle del Producto ID: {producto_id}</h1><p>Aquí irán los detalles...</p>")
#     ```
# 7.  **Ejecuta el servidor:** `python manage.py runserver`.
# 8.  **Prueba las URLs en tu navegador:**
#     *   Visita `http://127.0.0.1:8000/productos/` (deberías ver "Lista de Productos").
#     *   Visita `http://127.0.0.1:8000/productos/5/` (deberías ver "Detalle del Producto ID: 5").
#     *   Visita `http://127.0.0.1:8000/productos/abc/` (deberías ver un error 404 porque "abc" no es un entero).
#
# **Solución Propuesta:**
# Los archivos `productos/urls.py`, `tienda_config/urls.py` y `productos/views.py` deben quedar como se muestra en los pasos 4, 5 y 6 respectivamente. El servidor debe ejecutarse sin errores y las URLs de prueba deben funcionar como se describe.
#
# ¡Has configurado con éxito el enrutamiento básico para tu aplicación de productos!
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ## 4_Vistas_Basadas_en_Funcion_FBV
#
# Las vistas son el corazón lógico de tu aplicación web. Reciben la petición, interactúan con los modelos y devuelven una respuesta. Empezaremos con las Vistas Basadas en Función (FBVs), que son la forma más sencilla y directa de escribir vistas en Django.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 4_1_Creacion_de_Vistas_Simples_views_py
#
# Una FBV es simplemente una función Python definida en el archivo `views.py` de tu aplicación.
#
# **Reglas:**
# *   Debe aceptar al menos un argumento: el objeto `HttpRequest` (por convención llamado `request`).
# *   Puede aceptar argumentos adicionales capturados desde la URL (como `producto_id` en el ejemplo anterior).
# *   **Debe** devolver un objeto `HttpResponse` (o una de sus subclases).
#
# **Revisando el ejemplo anterior (`productos/views.py`):**
# ```python
# # productos/views.py
# from django.http import HttpResponse
# import datetime # Ejemplo para contenido dinámico
#
# def lista_productos_view(request):
#     # En el futuro, aquí consultaríamos Producto.objects.all()
#     html = """
#     <!DOCTYPE html>
#     <html>
#     <head><title>Lista de Productos</title></head>
#     <body>
#         <h1>Nuestros Productos</h1>
#         <ul>
#             <li>Producto 1</li>
#             <li>Producto 2</li>
#             <li>Producto 3</li>
#         </ul>
#     </body>
#     </html>
#     """
#     return HttpResponse(html) # Devolvemos HTML directamente
#
# def detalle_producto_view(request, producto_id):
#     # En el futuro, buscaríamos Producto.objects.get(pk=producto_id)
#     # y manejaríamos DoesNotExist
#     ahora = datetime.datetime.now().strftime("%H:%M:%S") # Hora actual formateada
#     html = f"""
#     <!DOCTYPE html>
#     <html>
#     <head><title>Detalle Producto {producto_id}</title></head>
#     <body>
#         <h1>Detalles del Producto ID: {producto_id}</h1>
#         <p>Información detallada sobre este increíble producto...</p>
#         <p>Consulta realizada a las: {ahora}</p>
#     </body>
#     </html>
#     """
#     return HttpResponse(html)
# ```
# Estas vistas son funcionales, pero generar HTML directamente en Python es engorroso y viola el principio de separación de intereses. Por eso usaremos el sistema de plantillas (Sección 5).
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 4_2_Objeto_HttpRequest_Atributos_y_Metodos
#
# El objeto `request` que recibe tu vista contiene toda la información sobre la petición HTTP entrante enviada por el cliente (navegador).
#
# Atributos y métodos clave:
# *   `request.method` (String): El método HTTP (`'GET'`, `'POST'`, `'PUT'`, etc.). Fundamental para diferenciar cómo procesar la petición.
# *   `request.GET` (QueryDict): Un objeto similar a un diccionario que contiene los parámetros de la *query string* (URL). Ejemplo: para `/buscar/?q=django&page=2`, `request.GET['q']` sería `'django'`. Usa `request.GET.get('param', 'default')` para evitar errores si el parámetro no existe.
# *   `request.POST` (QueryDict): Similar a `GET`, pero contiene los datos enviados en el *cuerpo* de una petición `POST` (normalmente desde un formulario HTML). Solo se pobla si `request.method == 'POST'`.
# *   `request.FILES` (MultiValueDict): Contiene los archivos subidos en una petición POST (si el formulario tenía `enctype="multipart/form-data"`).
# *   `request.COOKIES` (Dict): Un diccionario con las cookies enviadas por el navegador.
# *   `request.session` (Session object): El objeto de sesión para el usuario actual (si el middleware de sesión está habilitado). Permite almacenar y recuperar datos específicos de la sesión del usuario entre peticiones.
# *   `request.user` (User object): El usuario autenticado actualmente asociado con la petición (una instancia de `User` o `AnonymousUser` si el middleware de autenticación está habilitado).
# *   `request.path` (String): La ruta solicitada de la URL (ej: `/productos/5/`).
# *   `request.path_info` (String): Similar a `path`, a veces útil con `include()`.
# *   `request.headers` (Dict): Un diccionario con las cabeceras HTTP de la petición (ej: `request.headers['User-Agent']`). Las claves son insensibles a mayúsculas/minúsculas.
# *   `request.is_ajax()` (Deprecado en Django 3.1+, usar `request.accepts('application/json')` o comprobar cabeceras como `HTTP_X_REQUESTED_WITH` manualmente si es necesario): Solía indicar si la petición era AJAX.
# *   `request.scheme` (String): `'http'` o `'https'`.
# *   `request.body` (bytes): El cuerpo crudo de la petición HTTP como bytes. Útil para procesar datos no estándar (ej: JSON crudo en una API), pero `request.POST` es preferible para datos de formulario.
#
# **Ejemplo de uso:**
# ```python
# def buscar_view(request):
#     query = request.GET.get('q', '') # Obtiene el parámetro 'q' de la URL, default ''
#     page = request.GET.get('page', '1') # Obtiene 'page', default '1'
#
#     if request.user.is_authenticated:
#         usuario_actual = request.user.username
#     else:
#         usuario_actual = "Visitante"
#
#     html = f"""
#     <h1>Resultados de Búsqueda</h1>
#     <p>Buscando: '{query}'</p>
#     <p>Página: {page}</p>
#     <p>Usuario: {usuario_actual}</p>
#     """
#     return HttpResponse(html)
# ```
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 4_3_Retornando_HttpResponse_Tipos_de_Respuesta
#
# Cada vista **debe** finalizar devolviendo una instancia de `HttpResponse` o una de sus subclases.
#
# *   **`HttpResponse(content='', content_type=None, status=200, reason=None, charset=None)`**
#     *   La respuesta más básica.
#     *   `content`: El cuerpo de la respuesta (string o bytes).
#     *   `content_type`: El tipo MIME (ej: `'text/html'`, `'text/plain'`, `'application/xml'`). Si no se especifica y `content` es string, usa `text/html`.
#     *   `status`: Código de estado HTTP (200, 404, 500, etc.).
#     *   Puedes añadir o modificar cabeceras como un diccionario: `response['Cache-Control'] = 'no-cache'`
#
# *   **`render(request, template_name, context=None, content_type=None, status=None, using=None)`:**
#     *   **Atajo fundamental.** Carga una plantilla Django (`template_name`), la renderiza con el diccionario `context` y devuelve un `HttpResponse` con el resultado. La forma más común de devolver HTML.
#     ```python
#     from django.shortcuts import render
#     # ...
#     def mi_vista_con_plantilla(request):
#         contexto = {'nombre': 'Mundo', 'items': [1, 2, 3]}
#         return render(request, 'mi_app/mi_plantilla.html', contexto)
#     ```
#
# *   **`HttpResponseRedirect(redirect_to)`:**
#     *   Devuelve una respuesta de redirección temporal (HTTP 302).
#     *   `redirect_to`: La URL a la que redirigir (un string o el resultado de `reverse()`).
# *   **`HttpResponsePermanentRedirect(redirect_to)`:**
#     *   Redirección permanente (HTTP 301).
# *   **`redirect(to, permanent=False, *args, **kwargs)`:**
#     *   **Atajo muy útil** para redirecciones. Puede aceptar:
#         *   Un modelo: Redirige a la URL devuelta por el método `get_absolute_url()` del modelo.
#         *   El nombre de una vista o patrón de URL: Usa `reverse()` internamente para obtener la URL.
#         *   Una URL absoluta o relativa.
#     *   `permanent=True` para hacerla 301.
#     ```python
#     from django.shortcuts import redirect, get_object_or_404
#     from django.urls import reverse
#     from .models import Producto
#     # ...
#     def procesar_algo_y_redirigir(request, producto_id):
#         producto = get_object_or_404(Producto, pk=producto_id)
#         # ... procesar ...
#         # Redirigir al detalle del producto (usando el nombre de URL)
#         return redirect('productos:detalle_producto', producto_id=producto.id)
#         # O si el modelo Producto tiene get_absolute_url():
#         # return redirect(producto)
#         # O a una URL fija:
#         # return redirect('/gracias/')
#         # O a una URL absoluta:
#         # return redirect('https://otrod sitio.com')
#     ```
#
# *   **`JsonResponse(data, encoder=DjangoJSONEncoder, safe=True, json_dumps_params=None, **kwargs)`:**
#     *   Para devolver respuestas JSON (común en APIs). Convierte el diccionario `data` a JSON y establece el `Content-Type` correcto.
#     *   `safe=False` es necesario si `data` no es un diccionario (ej: una lista).
#     ```python
#     from django.http import JsonResponse
#     # ...
#     def mi_api_simple(request):
#         datos = {'id': 1, 'nombre': 'Item'}
#         return JsonResponse(datos)
#     ```
#
# *   **Respuestas de Error:**
#     *   `HttpResponseNotFound(...)`: Devuelve 404.
#     *   `HttpResponseForbidden(...)`: Devuelve 403.
#     *   `HttpResponseBadRequest(...)`: Devuelve 400.
#     *   `HttpResponseNotAllowed(['GET', 'POST'])`: Devuelve 405 (Método no permitido).
#     *   `HttpResponseServerError(...)`: Devuelve 500.
#     *   También puedes lanzar excepciones como `Http404` desde `django.http`, que Django capturará y convertirá en la respuesta 404 apropiada (si `DEBUG=False`). `get_object_or_404()` usa esto internamente.
#
# Elegir el tipo de `HttpResponse` correcto es fundamental para comunicar el resultado de la petición al navegador o cliente API.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 4_4_Ejercicio_Practico_Crear_Vistas_Simples
#
# **Objetivo:** Crear las funciones de vista básicas para las URLs de la aplicación `productos` definidas en el ejercicio anterior, por ahora devolviendo `HttpResponse` simple.
#
# **Pasos:**
#
# 1.  **Abre `productos/views.py`**.
# 2.  **Asegúrate** de importar `HttpResponse` de `django.http`.
# 3.  **Modifica `lista_productos_view(request)`:**
#     *   Crea una cadena de texto `html` que contenga una estructura HTML básica con un `<h1>Lista de Productos</h1>` y quizás un párrafo placeholder.
#     *   Haz que la función devuelva `HttpResponse(html)`.
# 4.  **Modifica `detalle_producto_view(request, producto_id)`:**
#     *   Recuerda que recibe `producto_id` como argumento.
#     *   Crea una cadena de texto `html` que muestre un `<h1>Detalle del Producto ID: ...</h1>` usando el `producto_id` recibido.
#     *   Haz que la función devuelva `HttpResponse(html)`.
# 5.  **Ejecuta el servidor:** `python manage.py runserver`.
# 6.  **Verifica en el navegador:**
#     *   `http://127.0.0.1:8000/productos/` debe mostrar el HTML de la lista.
#     *   `http://127.0.0.1:8000/productos/10/` (o cualquier número) debe mostrar el HTML del detalle con el ID correcto.
#
# **Solución Propuesta (`productos/views.py`):**
# ```python
# # productos/views.py
# from django.http import HttpResponse
#
# def lista_productos_view(request):
#     html_content = """
#     <!DOCTYPE html>
#     <html lang="es">
#     <head><title>Lista de Productos</title></head>
#     <body>
#         <h1>Lista de Productos</h1>
#         <p>Aquí se mostrarán todos nuestros productos.</p>
#         <ul>
#             <li><a href="/productos/1/">Producto 1</a></li>
#             <li><a href="/productos/2/">Producto 2</a></li>
#         </ul>
#     </body>
#     </html>
#     """
#     return HttpResponse(html_content)
#
# def detalle_producto_view(request, producto_id):
#     html_content = f"""
#     <!DOCTYPE html>
#     <html lang="es">
#     <head><title>Producto {producto_id}</title></head>
#     <body>
#         <h1>Detalle del Producto ID: {producto_id}</h1>
#         <p>Descripción detallada del producto con ID {producto_id}...</p>
#         <p><a href="/productos/">Volver a la lista</a></p>
#     </body>
#     </html>
#     """
#     return HttpResponse(html_content)
# ```
#
# Estas vistas son el punto de partida. En las siguientes secciones, reemplazaremos la generación manual de HTML con el sistema de plantillas de Django.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ## 5_Sistema_de_Plantillas_de_Django_DTL
#
# Generar HTML directamente en las vistas es tedioso y mezcla la lógica con la presentación. El sistema de plantillas de Django (Django Template Language - DTL) permite crear archivos HTML con marcadores especiales (variables y etiquetas) que Django procesa para insertar datos dinámicos y aplicar lógica de presentación.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 5_1_Configuracion_de_Plantillas_settings_py_TEMPLATES
#
# Django necesita saber dónde encontrar tus archivos de plantilla (`.html`). La configuración principal está en la variable `TEMPLATES` dentro de `settings.py`.
#
# ```python
# # mi_sitio/settings.py (o tienda_config/settings.py)
# import os
# from pathlib import Path
#
# BASE_DIR = Path(__file__).resolve().parent.parent
#
# TEMPLATES = [
#     {
#         'BACKEND': 'django.template.backends.django.DjangoTemplates',
#         # Lista de directorios donde Django buscará plantillas GLOBALMENTE.
#         'DIRS': [
#              BASE_DIR / 'templates', # Convención: una carpeta 'templates' en la raíz del proyecto
#         ],
#         # Si es True, Django buscará una carpeta 'templates' DENTRO de cada app instalada.
#         'APP_DIRS': True,
#         'OPTIONS': {
#             'context_processors': [
#                 # Procesadores de contexto por defecto...
#                 'django.template.context_processors.debug',
#                 'django.template.context_processors.request',
#                 'django.contrib.auth.context_processors.auth',
#                 'django.contrib.messages.context_processors.messages',
#             ],
#             # 'builtins': [...] # Para añadir tags/filtros personalizados globalmente
#         },
#     },
# ]
# ```
#
# **Estrategias Comunes de Ubicación:**
#
# 1.  **Plantillas por Aplicación (Recomendado para apps reutilizables):**
#     *   Crea `mi_app/templates/mi_app/` (ej: `productos/templates/productos/`).
#     *   Coloca las plantillas específicas de la app ahí (ej: `lista_productos.html`, `detalle_producto.html`).
#     *   Asegúrate de que `APP_DIRS` sea `True` en `settings.py`.
#     *   En la vista, referencia la plantilla como: `'productos/lista_productos.html'`. El subdirectorio con el nombre de la app actúa como namespace para evitar colisiones.
# 2.  **Plantillas a Nivel de Proyecto:**
#     *   Crea una carpeta `templates` en la raíz de tu proyecto (al mismo nivel que `manage.py`).
#     *   Añade la ruta a esa carpeta en la opción `DIRS` de `TEMPLATES` en `settings.py` (ej: `BASE_DIR / 'templates'`).
#     *   Coloca aquí plantillas globales (como `base.html`) o incluso plantillas de apps (ej: `templates/productos/lista_productos.html`).
#
# Puedes combinar ambas estrategias. Django buscará primero en los directorios de `DIRS` y luego en las carpetas `templates/` de las apps (`APP_DIRS`).
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 5_2_Renderizando_Plantillas_render
#
# Como vimos en la sección de vistas, la función de atajo `render()` es la forma más común de cargar, procesar y devolver una plantilla como un `HttpResponse`.
#
# **Recordatorio (`productos/views.py`):**
# ```python
# # productos/views.py
# from django.shortcuts import render
# # from .models import Producto # Asumiremos que existe un modelo Producto
#
# def lista_productos_view(request):
#     # productos = Producto.objects.all() # Obtener datos reales
#     productos = [ # Datos de ejemplo por ahora
#         {'id': 1, 'nombre': 'Laptop Pro', 'precio': 1200},
#         {'id': 2, 'nombre': 'Teclado Mecánico', 'precio': 85},
#         {'id': 3, 'nombre': 'Monitor 4K', 'precio': 450},
#     ]
#     contexto = {
#         'lista_productos': productos,
#         'titulo_seccion': 'Nuestros Productos Estrella'
#     }
#     # Renderiza la plantilla ubicada en 'productos/templates/productos/lista_productos.html'
#     return render(request, 'productos/lista_productos.html', contexto)
#
# def detalle_producto_view(request, producto_id):
#     # producto = get_object_or_404(Producto, pk=producto_id) # Obtener real
#     producto = {'id': producto_id, 'nombre': f'Producto {producto_id}', 'descripcion': 'Una descripción detallada.', 'stock': 10} # Ejemplo
#     contexto = {
#         'producto': producto,
#     }
#     # Renderiza 'productos/templates/productos/detalle_producto.html'
#     return render(request, 'productos/detalle_producto.html', contexto)
# ```
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 5_3_Sintaxis_Basica_Variables_y_Contexto
#
# Dentro de una plantilla Django, usas marcadores especiales para insertar contenido dinámico y ejecutar lógica simple.
#
# *   **Variables:** Se encierran entre dobles llaves: `{{ nombre_variable }}`.
#     *   Django reemplazará esto con el valor de la variable `nombre_variable` pasada en el diccionario de `contexto` desde la vista.
#     *   Puedes acceder a atributos de objetos o claves de diccionarios usando la **notación de punto**: `{{ producto.nombre }}`, `{{ diccionario.clave }}`. Django intenta varios métodos de acceso (diccionario, atributo, método, índice de lista) en ese orden.
#     *   Si una variable no existe en el contexto, por defecto se renderiza como una cadena vacía (se puede configurar para lanzar error si se prefiere).
# *   **Contexto:** El diccionario Python que pasas como tercer argumento a `render()`. Las claves de este diccionario se convierten en los nombres de las variables disponibles en la plantilla.
#
# **Ejemplo (`productos/templates/productos/detalle_producto.html`):**
# ```html
# <!DOCTYPE html>
# <html lang="es">
# <head>
#     {# Accede a producto.nombre del contexto #}
#     <title>Detalle: {{ producto.nombre }}</title>
# </head>
# <body>
#     <h1>{{ producto.nombre }}</h1>
#     <p><strong>ID:</strong> {{ producto.id }}</p>
#     <p><strong>Descripción:</strong> {{ producto.descripcion }}</p>
#     {# Acceso a clave de diccionario si 'producto' fuera un dict #}
#     {# <p>Stock: {{ producto.stock }}</p> #}
#     <p>Stock: {{ producto.stock|default:"Agotado" }}</p> {# Usando un filtro (ver 5.5) #}
#
#     <hr>
#     <a href="#">Volver (URL pendiente)</a>
# </body>
# </html>
# ```
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 5_4_Etiquetas_Tags_Basicas_if_for_empty
#
# Las etiquetas se encierran entre `{%` y `%}`: `{% nombre_tag [argumentos...] %}`. Proporcionan lógica de control.
#
# *   **`{% if ... %}` / `{% elif ... %}` / `{% else %}` / `{% endif %}`:**
#     *   Evalúa condiciones booleanas.
#     *   Puedes usar variables, comparaciones (`==`, `!=`, `<`, `>`, `<=`, `>=`), operadores lógicos (`and`, `or`, `not`) y operadores de pertenencia (`in`, `not in`).
#     *   **Importante:** `endif` es obligatorio para cerrar el bloque. `elif` y `else` son opcionales.
#     ```html
#     {% if producto.stock > 10 %}
#       <p style="color: green;">¡En Stock!</p>
#     {% elif producto.stock > 0 %}
#       <p style="color: orange;">¡Últimas unidades!</p>
#     {% else %}
#       <p style="color: red;">Agotado temporalmente.</p>
#     {% endif %}
#     ```
#
# *   **`{% for ... in ... %}` / `{% empty %}` / `{% endfor %}`:**
#     *   Itera sobre los elementos de una secuencia (lista, tupla, queryset, diccionario - itera sobre claves).
#     *   La variable después de `for` toma el valor de cada elemento en cada iteración.
#     *   El bloque opcional `{% empty %}` se renderiza si la secuencia está vacía o no existe.
#     *   **Importante:** `endfor` es obligatorio para cerrar el bucle.
#     *   Variables especiales dentro del bucle: `{{ forloop.counter }}` (1-based), `{{ forloop.counter0 }}` (0-based), `{{ forloop.first }}` (True/False), `{{ forloop.last }}` (True/False), `{{ forloop.parentloop }}` (para bucles anidados).
#     ```html
#     <!-- productos/templates/productos/lista_productos.html -->
#     <h1>{{ titulo_seccion|default:"Productos" }}</h1>
#     {% if lista_productos %}
#       <ul>
#         {% for prod in lista_productos %}
#           <li>
#             <a href="#">{{ prod.nombre }}</a> - Precio: ${{ prod.precio }}
#             {% if forloop.first %} (¡El primero!) {% endif %}
#           </li>
#         {% endfor %}
#       </ul>
#     {% else %}
#       <p>No hay productos para mostrar en este momento.</p>
#     {% endif %}
#
#     {# Ejemplo con {% empty %} #}
#     <ul>
#     {% for item in mi_lista_vacia %}
#         <li>{{ item }}</li>
#     {% empty %}
#         <li>La lista está vacía.</li>
#     {% endfor %}
#     </ul>
#     ```
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 5_5_Filtros_Basicos_lower_date_length_etc
#
# Los filtros modifican la salida de las variables. Se aplican con el símbolo de tubería (`|`).
# Sintaxis: `{{ variable | filtro1 | filtro2:argumento }}`
#
# Filtros comunes (algunos ya vistos):
# *   `lower`: Convierte a minúsculas.
# *   `upper`: Convierte a mayúsculas.
# *   `capfirst`: Primera letra en mayúscula.
# *   `title`: Primera letra de cada palabra en mayúscula.
# *   `length`: Longitud de una lista o string.
# *   `date:"formato"`: Formatea fecha/hora (ver [doc](https://docs.djangoproject.com/en/stable/ref/templates/builtins/#date)). `{{ fecha | date:"d M Y" }}` -> `28 Oct 2023`
# *   `time:"formato"`: Formatea hora.
# *   `timesince`: Tiempo transcurrido desde una fecha (ej: "hace 2 horas").
# *   `timeuntil`: Tiempo hasta una fecha.
# *   `default:"valor"`: Valor por defecto si la variable es "falsy".
# *   `default_if_none:"valor"`: Valor por defecto si la variable es `None`.
# *   `truncatewords:N`: Trunca a N palabras.
# *   `truncatechars:N`: Trunca a N caracteres.
# *   `join:", "` : Une elementos de una lista con un separador. `{{ lista_tags|join:", " }}`
# *   `add:valor`: Suma (convierte a int). `{{ cantidad|add:"1" }}`
# *   `floatformat:N`: Formatea un número flotante a N decimales. `{{ precio|floatformat:2 }}` -> `85.00`
# *   `pluralize:sufijo`: Añade 's' o un `sufijo` si el valor no es 1. `{{ n }} gato{{ n|pluralize }}` / `{{ n }} fox{{ n|pluralize:"es" }}`
# *   `safe`: No escapar HTML (¡Usar con precaución!).
# *   `escape`: Escapar HTML (activado por defecto).
#
# ```html
# <p>Nombre en minúsculas: {{ producto.nombre|lower }}</p>
# <p>Publicado: {{ producto.fecha_publicacion|date:"SHORT_DATE_FORMAT" }} a las {{ producto.fecha_publicacion|time:"H:i" }}</p>
# <p>Quedan {{ producto.stock|default:0 }} unidades.</p>
# <p>Descripción corta: {{ producto.descripcion|truncatewords:15 }}</p>
# ```
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 5_6_Comentarios_en_Plantillas
#
# Para añadir comentarios que no se renderizarán en el HTML final:
#
# *   **Comentario de una línea:** `{# Esto es un comentario #}`
# *   **Comentario multilínea:** `{% comment %}` ... `{% endcomment %}`
#
# ```html
# {# Renderizando los detalles del producto #}
# <h2>{{ producto.nombre }}</h2>
#
# {% comment %}
#   Esta sección muestra información adicional.
#   Podríamos añadir más detalles aquí en el futuro.
# {% endcomment %}
# <p>Stock: {{ producto.stock }}</p>
# ```
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 5_7_Generacion_de_URLs_en_Plantillas_url_tag_Revisitado
#
# La etiqueta `{% url %}` es fundamental para generar URLs dinámicamente basadas en los nombres y namespaces definidos en tus archivos `urls.py`.
#
# **Recordatorio de Sintaxis:**
# `{% url 'namespace:nombre_url' [arg1] [arg2] ... [kwarg1=valor1] ... %}`
#
# **Ejemplo (`productos/templates/productos/lista_productos.html`):**
# ```html
# {% extends 'base.html' %} {# Asumiendo que tienes base.html #}
#
# {% block titulo %}Lista de Productos{% endblock %}
#
# {% block contenido %}
# <h1>{{ titulo_seccion|default:"Productos" }}</h1>
# {% if lista_productos %}
#   <ul>
#     {% for prod in lista_productos %}
#       <li>
#         {# Enlace al detalle del producto usando el nombre 'detalle_producto'
#            de la app 'productos' y pasando el id del producto como argumento #}
#         <a href="{% url 'productos:detalle_producto' producto_id=prod.id %}">
#             {{ prod.nombre }}
#         </a>
#          - Precio: ${{ prod.precio|floatformat:2 }}
#       </li>
#     {% endfor %}
#   </ul>
# {% else %}
#   <p>No hay productos para mostrar.</p>
# {% endif %}
#
# {# Enlace a una vista sin argumentos, por ejemplo #}
# {# <p><a href="{% url 'productos:crear_producto' %}">Añadir Producto</a></p> #}
#
# {% endblock %}
# ```
# Usar `{% url %}` es la forma robusta y mantenible de crear enlaces internos en tus plantillas Django.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 5_8_Ejercicio_Practico_Crear_y_Renderizar_Plantillas
#
# **Objetivo:** Modificar las vistas de `productos` para que usen plantillas en lugar de devolver HttpResponse con HTML hardcodeado.
#
# **Pasos:**
#
# 1.  **Crea la estructura de directorios:** Dentro de tu app `productos`, crea `templates/productos/`.
# 2.  **Crea la plantilla `lista_productos.html`** (`productos/templates/productos/lista_productos.html`):
#     *   Usa HTML básico.
#     *   Muestra un título (ej: `<h1>Lista de Productos</h1>`).
#     *   Itera sobre la variable `lista_productos` (que pasarás desde la vista) usando `{% for %}`.
#     *   Dentro del bucle, muestra el nombre de cada producto (`{{ prod.nombre }}`). Haz que el nombre sea un enlace que *apunte* a la URL de detalle de ese producto usando la etiqueta `{% url %}` y el `id` del producto (o `pk`).
#     *   Añade un bloque `{% empty %}` por si la lista está vacía.
# 3.  **Crea la plantilla `detalle_producto.html`** (`productos/templates/productos/detalle_producto.html`):
#     *   Usa HTML básico.
#     *   Muestra el nombre del producto (`{{ producto.nombre }}`) en un `<h1>`.
#     *   Muestra otras propiedades del producto (ej: `{{ producto.descripcion }}`, `{{ producto.id }}`).
#     *   Añade un enlace para volver a la lista de productos usando `{% url %}`.
# 4.  **Modifica `productos/views.py`:**
#     *   Importa `render` de `django.shortcuts`.
#     *   En `lista_productos_view`:
#         *   Crea un diccionario `contexto` con los datos de ejemplo (o consulta la BD si ya tienes modelos). Asegúrate de que la clave coincida con la variable usada en la plantilla (ej: `'lista_productos'`).
#         *   Reemplaza `return HttpResponse(...)` por `return render(request, 'productos/lista_productos.html', contexto)`.
#     *   En `detalle_producto_view`:
#         *   Crea un diccionario `contexto` con los datos del producto de ejemplo. La clave debe coincidir (ej: `'producto'`).
#         *   Reemplaza `return HttpResponse(...)` por `return render(request, 'productos/detalle_producto.html', contexto)`.
# 5.  **Ejecuta el servidor y prueba:**
#     *   Visita `/productos/`. Deberías ver la lista renderizada desde la plantilla, con enlaces funcionales.
#     *   Haz clic en un enlace de producto. Deberías ver la página de detalle renderizada desde la otra plantilla, con la información correcta y el enlace de vuelta.
#
# **Solución Propuesta:**
#
# **`productos/templates/productos/lista_productos.html`:**
# ```html
# <!DOCTYPE html>
# <html lang="es">
# <head>
#     <meta charset="UTF-8">
#     <title>Lista de Productos</title>
# </head>
# <body>
#     <h1>{{ titulo_seccion|default:"Nuestros Productos" }}</h1>
#
#     {% if lista_productos %}
#         <ul>
#             {% for prod in lista_productos %}
#                 <li>
#                     <a href="{% url 'productos:detalle_producto' producto_id=prod.id %}">
#                         {{ prod.nombre }}
#                     </a>
#                     (Precio: ${{ prod.precio|floatformat:2 }})
#                 </li>
#             {% endfor %}
#         </ul>
#     {% else %}
#         <p>No hay productos disponibles en este momento.</p>
#     {% endif %}
# </body>
# </html>
# ```
#
# **`productos/templates/productos/detalle_producto.html`:**
# ```html
# <!DOCTYPE html>
# <html lang="es">
# <head>
#     <meta charset="UTF-8">
#     <title>Detalle: {{ producto.nombre }}</title>
# </head>
# <body>
#     <h1>{{ producto.nombre }}</h1>
#     <p><strong>ID:</strong> {{ producto.id }}</p>
#     <p><strong>Descripción:</strong> {{ producto.descripcion|linebreaksbr }}</p> {# Usando filtro linebreaksbr #}
#     <p><strong>Stock:</strong> {{ producto.stock|default:"N/A" }}</p>
#
#     <hr>
#     <a href="{% url 'productos:lista_productos' %}">Volver a la lista</a>
# </body>
# </html>
# ```
#
# **`productos/views.py`:**
# ```python
# from django.shortcuts import render
# # from .models import Producto, get_object_or_404 # Importar si usas modelos reales
#
# def lista_productos_view(request):
#     # productos = Producto.objects.all()
#     productos_ejemplo = [
#         {'id': 1, 'nombre': 'Laptop Pro X', 'precio': 1350.99},
#         {'id': 2, 'nombre': 'Teclado Retroiluminado', 'precio': 75.50},
#         {'id': 3, 'nombre': 'Monitor Curvo 32"', 'precio': 520.00},
#     ]
#     contexto = {
#         'lista_productos': productos_ejemplo,
#         'titulo_seccion': 'Productos Destacados'
#     }
#     return render(request, 'productos/lista_productos.html', contexto)
#
# def detalle_producto_view(request, producto_id):
#     # producto = get_object_or_404(Producto, pk=producto_id)
#     producto_ejemplo = {
#         'id': producto_id,
#         'nombre': f'Producto Ejemplo {producto_id}',
#         'descripcion': f'Esta es la descripción del producto {producto_id}.\nEs realmente fantástico.',
#         'stock': producto_id * 3 # Stock de ejemplo
#     }
#     contexto = {
#         'producto': producto_ejemplo,
#     }
#     return render(request, 'productos/detalle_producto.html', contexto)
# ```
#
# ¡Has conectado con éxito tus vistas con el sistema de plantillas de Django!
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ---
# ---
#
# ## **Unidad 3: Modelos y Bases de Datos**
#
# ## 6_Introduccion_al_ORM_de_Django
#
# En el corazón de la interacción de Django con las bases de datos se encuentra su **ORM (Object-Relational Mapper - Mapeador Objeto-Relacional)**. El ORM es una capa de abstracción que te permite definir la estructura de tus datos y manipularlos usando código Python orientado a objetos, en lugar de escribir directamente sentencias SQL.
#
# **¿Cómo funciona?**
# 1.  **Defines Modelos:** Creas clases Python en `models.py` que representan las tablas de tu base de datos.
# 2.  **Defines Campos:** Dentro de esas clases, defines atributos que representan las columnas de las tablas, usando los tipos de campo que proporciona Django (`CharField`, `IntegerField`, `ForeignKey`, etc.).
# 3.  **Django Genera SQL:** Basándose en tus modelos, Django es capaz de generar las sentencias SQL DDL (`CREATE TABLE`, `ALTER TABLE`) necesarias para crear o modificar la estructura de la base de datos. Esto se gestiona a través del sistema de **migraciones**.
# 4.  **Interactúas con Objetos:** En lugar de escribir `SELECT`, `INSERT`, `UPDATE`, `DELETE`, interactúas con instancias de tus clases de modelo y usas el API de **QuerySets** de Django para consultar y manipular los datos. Django traduce estas operaciones Python a las sentencias SQL DML (`SELECT`, `INSERT`, etc.) apropiadas para la base de datos configurada.
#
# **Principales Ventajas:**
# *   **Abstracción de la Base de Datos:** Te permite cambiar de sistema de base de datos (ej: de SQLite a PostgreSQL) con mínimos o ningún cambio en tu código Python de modelos/consultas. Django se encarga de las diferencias de sintaxis SQL.
# *   **Productividad:** Escribir y leer código Python suele ser más rápido y natural para los desarrolladores Python que escribir SQL complejo. El ORM maneja muchas tareas repetitivas.
# *   **Seguridad:** Ayuda a prevenir vulnerabilidades comunes como la inyección SQL, ya que parametriza las consultas correctamente.
# *   **Mantenibilidad:** El código es más legible y está más integrado con el resto de tu aplicación Python/Django.
# *   **Reutilización:** La lógica relacionada con los datos puede encapsularse en métodos dentro de los propios modelos.
#
# Aunque el ORM abstrae la mayor parte del SQL, sigue siendo útil tener conocimientos básicos de SQL y de cómo funcionan las bases de datos relacionales para optimizar consultas complejas o entender mejor lo que hace el ORM por debajo.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ## 7_Definicion_de_Modelos_models_py
#
# Los modelos son la fuente única y definitiva de información sobre tus datos. Contienen los campos y comportamientos esenciales de los datos que estás almacenando. Cada modelo se mapea, generalmente, a una única tabla de base de datos.
#
# Se definen como clases Python dentro del archivo `models.py` de tu aplicación Django, heredando de la clase base `django.db.models.Model`.
#
# **Ejemplo Básico (`productos/models.py`):**
# ```python
# # productos/models.py
# from django.db import models
# from django.utils import timezone # Para campos de fecha/hora
# from django.conf import settings # Para referenciar al modelo User
#
# # Es buena práctica obtener el modelo User desde settings
# # por si se usa un modelo de usuario personalizado
# User = settings.AUTH_USER_MODEL
#
# class Categoria(models.Model):
#     nombre = models.CharField(max_length=100, unique=True, db_index=True) # Nombre único e indexado
#     descripcion = models.TextField(blank=True) # Descripción opcional
#
#     class Meta:
#         verbose_name = "Categoría"
#         verbose_name_plural = "Categorías"
#         ordering = ['nombre'] # Ordenar por nombre por defecto
#
#     def __str__(self):
#         return self.nombre
#
# class Producto(models.Model):
#     # Campos del modelo
#     nombre = models.CharField(max_length=255)
#     slug = models.SlugField(max_length=255, unique=True, help_text="Versión amigable para URL, única.")
#     descripcion = models.TextField(blank=True)
#     precio = models.DecimalField(max_digits=10, decimal_places=2) # Ideal para dinero
#     stock = models.PositiveIntegerField(default=0) # Entero no negativo
#     disponible = models.BooleanField(default=True)
#     fecha_creacion = models.DateTimeField(auto_now_add=True) # Se establece solo al crear
#     fecha_actualizacion = models.DateTimeField(auto_now=True) # Se actualiza cada vez que se guarda
#
#     # Relación Uno-a-Muchos con Categoria
#     categoria = models.ForeignKey(
#         Categoria,
#         on_delete=models.SET_NULL, # Si se borra la categoría, poner este campo a NULL
#         null=True, # Permitir NULL en la BD para esta ForeignKey
#         blank=True, # Permitir que esté vacío en formularios/admin
#         related_name='productos' # Acceso inverso: categoria.productos.all()
#     )
#
#     # Relación Uno-a-Muchos con User (quién añadió el producto, opcional)
#     creado_por = models.ForeignKey(
#         User,
#         on_delete=models.SET_NULL,
#         null=True,
#         blank=True,
#         related_name='productos_creados'
#     )
#
#     # Campo de imagen (requiere Pillow)
#     imagen = models.ImageField(upload_to='productos/%Y/%m/', blank=True, null=True)
#
#     class Meta:
#         ordering = ['-fecha_creacion'] # Ordenar por fecha de creación descendente
#         verbose_name = "Producto"
#         verbose_name_plural = "Productos"
#         indexes = [
#             models.Index(fields=['slug']),
#             models.Index(fields=['nombre']),
#         ]
#
#     def __str__(self):
#         return self.nombre
#
#     # Método personalizado (ejemplo)
#     def rebajar_precio(self, porcentaje):
#         if 0 < porcentaje < 100:
#             descuento = (self.precio * porcentaje) / 100
#             self.precio -= descuento
#             self.save() # Guardar el cambio en la BD
#             return True
#         return False
#
# ```
# Este ejemplo muestra dos modelos, `Categoria` y `Producto`, con varios tipos de campos, opciones, relaciones y una clase `Meta`.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 7_1_Tipos_de_Campos_Fields
#
# Django proporciona una clase `Field` para cada tipo de dato que quieras almacenar. Aquí algunos de los más importantes:
#
# *   **Campos de Texto:**
#     *   `CharField(max_length=...)`: Para cadenas cortas. `max_length` es obligatorio.
#     *   `TextField()`: Para textos largos, sin límite de longitud (a nivel de Django, la BD puede tener límites).
#     *   `SlugField(max_length=...)`: Para almacenar "slugs" (texto corto para URLs, generalmente con `db_index=True` o `unique=True`).
#     *   `EmailField()`: `CharField` con validación de email.
#     *   `URLField()`: `CharField` con validación de URL.
# *   **Campos Numéricos:**
#     *   `IntegerField()`: Enteros.
#     *   `PositiveIntegerField()`: Enteros positivos o cero.
#     *   `SmallIntegerField()`, `BigIntegerField()`: Enteros con diferentes rangos.
#     *   `FloatField()`: Números de punto flotante.
#     *   `DecimalField(max_digits=..., decimal_places=...)`: Números decimales de precisión fija (obligatorio `max_digits` y `decimal_places`). **Preferido para valores monetarios.**
# *   **Campos Booleanos:**
#     *   `BooleanField()`: Almacena `True` o `False`. Si necesitas permitir `NULL`, usa `NullBooleanField()` (aunque a partir de Django 3.1, `BooleanField(null=True)` es posible con la mayoría de BBDD).
# *   **Campos de Fecha y Hora:**
#     *   `DateField()`: Almacena una fecha (`datetime.date`).
#     *   `TimeField()`: Almacena una hora (`datetime.time`).
#     *   `DateTimeField()`: Almacena fecha y hora (`datetime.datetime`).
#     *   `DurationField()`: Almacena una duración de tiempo (`datetime.timedelta`).
#     *   Opciones `auto_now` (actualiza al guardar) y `auto_now_add` (establece al crear) son comunes para `DateField` y `DateTimeField`.
# *   **Campos de Relación:** (Se detallan en Sección 10)
#     *   `ForeignKey()`: Uno a Muchos.
#     *   `ManyToManyField()`: Muchos a Muchos.
#     *   `OneToOneField()`: Uno a Uno.
# *   **Otros Campos:**
#     *   `UUIDField()`: Para identificadores UUID.
#     *   `FileField(upload_to=...)`: Para subir archivos genéricos.
#     *   `ImageField(upload_to=...)`: Para subir imágenes (requiere `Pillow`).
#     *   `JSONField()` (Django 3.1+): Para almacenar datos JSON directamente en la base de datos (si la BD lo soporta, como PostgreSQL).
#
# Consulta la [referencia de campos de modelo](https://docs.djangoproject.com/en/stable/ref/models/fields/) en la documentación oficial para la lista completa y todas sus opciones.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 7_2_Opciones_Comunes_de_Campos_null_blank_default_unique
#
# La mayoría de los tipos de campo aceptan argumentos opcionales que modifican su comportamiento y representación:
#
# *   **`null`** (Booleano, defecto `False`):
#     *   Afecta a la **base de datos**.
#     *   Si `True`, permite que la columna en la base de datos almacene el valor `NULL`.
#     *   Si `False` (defecto), la base de datos requerirá un valor (no puede ser `NULL`).
# *   **`blank`** (Booleano, defecto `False`):
#     *   Afecta a la **validación de formularios** (incluyendo el Admin de Django).
#     *   Si `True`, el campo puede dejarse vacío en un formulario.
#     *   Si `False` (defecto), el formulario requerirá que el campo tenga un valor.
#     *   **Relación `null` y `blank`:**
#         *   Para campos de texto (`CharField`, `TextField`): Es común usar `blank=True` para campos opcionales. Usar `null=True` es menos común para texto, ya que Django prefiere almacenar strings vacíos (`''`) en lugar de `NULL`. Si necesitas permitir `NULL` explícitamente (raro para texto), pon ambos a `True`.
#         *   Para otros campos (números, fechas, booleanos, relaciones): Si quieres que sean opcionales, normalmente necesitarás `null=True, blank=True`. `null=True` permite el `NULL` en la BD, y `blank=True` permite que el formulario se envíe vacío.
# *   **`default=valor`:**
#     *   Establece un valor por defecto para el campo a nivel de base de datos o a nivel de Django cuando se crea una instancia.
#     *   El `valor` puede ser un literal (ej: `0`, `True`, `'pendiente'`) o un objeto callable (como una función) que se llamará cada vez que se necesite un valor por defecto (ej: `default=timezone.now`).
# *   **`unique=True/False`** (defecto `False`):
#     *   Si `True`, crea una restricción `UNIQUE` en la base de datos para esa columna. Asegura que no haya dos filas con el mismo valor en ese campo.
# *   **`choices=[(valor_almacenado, 'Texto Leíble'), ...]`:**
#     *   Proporciona una lista de opciones predefinidas. Django usará un widget `<select>` en formularios.
#     *   El primer elemento de cada tupla es el valor que se almacena en la BD, el segundo es el texto que ve el usuario.
# *   **`db_index=True/False`** (defecto `False`):
#     *   Si `True`, crea un índice en la base de datos para esta columna. Mejora el rendimiento de las consultas que filtran u ordenan por este campo, pero puede ralentizar ligeramente las inserciones/actualizaciones. Los campos `unique=True` y `ForeignKey` tienen un índice por defecto.
# *   **`verbose_name="Nombre Leíble"`:**
#     *   Un nombre descriptivo para el campo, usado en el admin, formularios y mensajes de error. Si no se da, Django usa el nombre del atributo con `_` reemplazados por espacios.
# *   **`help_text="Texto de ayuda"`:**
#     *   Texto adicional mostrado junto al campo en formularios y el admin.
# *   **`editable=True/False`** (defecto `True`):
#     *   Si `False`, el campo no se mostrará en el admin ni en `ModelForms` (a menos que se incluya explícitamente). Útil para campos gestionados automáticamente como `auto_now` o `auto_now_add`.
#
# Elegir las opciones correctas para cada campo es crucial para la integridad de los datos y la usabilidad de los formularios.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 7_3_Clave_Primaria_AutoField_primary_key
#
# Cada modelo en Django necesita tener exactamente un campo que actúe como **clave primaria (Primary Key - PK)**. La PK es un valor único que identifica inequívocamente cada fila en la tabla de la base de datos.
#
# *   **Comportamiento por Defecto:** Si **no** defines explícitamente una clave primaria en tu modelo, Django añade automáticamente un campo llamado `id` que es un `AutoField` (o `BigAutoField` en versiones más recientes, que es un entero de 64 bits).
#     ```python
#     # Esto es lo que Django añade implícitamente si no hay primary_key=True:
#     id = models.BigAutoField(primary_key=True)
#     ```
#     `AutoField` / `BigAutoField` es un campo entero que se incrementa automáticamente cada vez que se inserta una nueva fila.
#
# *   **Definir una PK Personalizada:** Puedes designar cualquier otro campo como clave primaria añadiendo `primary_key=True` a su definición. Si haces esto, Django **no** añadirá el campo `id` automático.
#     *   Es común usar `UUIDField` como PK si necesitas identificadores únicos universales que no sean secuenciales.
#     *   Puedes usar un `CharField` o `SlugField` si tienes un identificador natural único (ej: código de producto).
#
#     ```python
#     import uuid
#     from django.db import models
#
#     class Pedido(models.Model):
#         # Usar UUID como clave primaria
#         id = models.UUIDField(primary_key=True, default=uuid.uuid4, editable=False)
#         fecha_pedido = models.DateTimeField(auto_now_add=True)
#         total = models.DecimalField(max_digits=10, decimal_places=2)
#         # ... otros campos ...
#
#     class Pais(models.Model):
#          # Usar código ISO como PK
#         codigo_iso = models.CharField(max_length=2, primary_key=True)
#         nombre = models.CharField(max_length=100)
#         # ...
#     ```
# *   **Acceso a la PK:** Puedes acceder al valor de la clave primaria de una instancia usando `instancia.pk`, independientemente de cómo se llame el campo PK (`id`, `id_unico`, `codigo_iso`, etc.). `instancia.pk` es un alias conveniente.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 7_4_Metodos_en_Modelos_str_get_absolute_url
#
# Además de definir campos (datos), puedes definir métodos (comportamiento) dentro de tus clases de modelo.
#
# *   **`__str__(self)`:** (Esencial)
#     *   Este método especial de Python debe devolver una **representación en string legible por humanos** del objeto.
#     *   Django lo usa extensivamente, sobre todo en la **interfaz de administración** para mostrar los objetos en listas y desplegables.
#     *   Si no lo defines, Django mostrará algo genérico como `<Producto object (1)>`, lo cual no es útil.
#     *   **Siempre define un `__str__` significativo** para tus modelos.
#     ```python
#     class Producto(models.Model):
#         nombre = models.CharField(max_length=255)
#         # ... otros campos ...
#
#         def __str__(self):
#             return self.nombre # Devuelve el nombre del producto
#     ```
#
# *   **`get_absolute_url(self)`:** (Convención muy útil)
#     *   Este método (si lo defines) debe devolver la **URL canónica** (la URL "oficial") para ver la página de detalle de una instancia específica de este modelo.
#     *   El Admin de Django y otras partes del framework (como algunas vistas genéricas) buscan y usan este método si existe (ej: un botón "Ver en el sitio" en el admin).
#     *   Utiliza la función `reverse()` para generar la URL basada en el nombre del patrón de URL definido en `urls.py`.
#     ```python
#     # productos/models.py
#     from django.db import models
#     from django.urls import reverse # Importar reverse
#
#     class Producto(models.Model):
#         nombre = models.CharField(max_length=255)
#         slug = models.SlugField(max_length=255, unique=True)
#         # ... otros campos ...
#
#         def __str__(self):
#             return self.nombre
#
#         def get_absolute_url(self):
#             # Asume que tienes una URL llamada 'detalle_producto' en la app 'productos'
#             # que acepta un slug como argumento.
#             return reverse('productos:detalle_producto', kwargs={'slug': self.slug})
#             # O si usas PK:
#             # return reverse('productos:detalle_producto', kwargs={'pk': self.pk})
#     ```
#     Definir `get_absolute_url()` es una buena práctica DRY, ya que centraliza la lógica para obtener la URL de un objeto.
#
# *   **Métodos Personalizados:**
#     *   Puedes añadir cualquier método que encapsule lógica relacionada con ese modelo.
#     *   Pueden realizar cálculos, comprobaciones, o interactuar con otros campos del mismo objeto.
#     ```python
#     # productos/models.py
#     from django.db import models
#     from django.utils import timezone
#     import datetime
#
#     class Evento(models.Model):
#         nombre = models.CharField(max_length=100)
#         fecha_inicio = models.DateTimeField()
#         fecha_fin = models.DateTimeField()
#
#         def __str__(self):
#             return self.nombre
#
#         def duracion(self):
#             """Devuelve la duración del evento como timedelta."""
#             return self.fecha_fin - self.fecha_inicio
#
#         def esta_activo(self):
#             """Devuelve True si el evento está ocurriendo ahora."""
#             ahora = timezone.now()
#             return self.fecha_inicio <= ahora <= self.fecha_fin
#
#         def limpiar_nombre(self):
#             """Ejemplo de método que modifica el propio objeto."""
#             self.nombre = self.nombre.strip().title()
#             # ¡Ojo! Esto NO guarda el cambio en la BD automáticamente.
#             # Necesitarías llamar a self.save() explícitamente después si quieres persistirlo.
#     ```
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 7_5_Meta_Opciones_ordering_verbose_name_indexes_etc
#
# La clase interna `Meta` dentro de un modelo permite configurar metadatos y opciones que afectan al comportamiento del modelo.
#
# ```python
# # productos/models.py
# from django.db import models
#
# class Producto(models.Model):
#     nombre = models.CharField(max_length=255)
#     slug = models.SlugField(max_length=255, unique=True)
#     precio = models.DecimalField(max_digits=10, decimal_places=2)
#     fecha_creacion = models.DateTimeField(auto_now_add=True)
#     # ... otros campos ...
#
#     class Meta:
#         # --- Opciones Comunes ---
#
#         # Orden por defecto para los QuerySets de este modelo
#         # (si no se especifica order_by() en la consulta)
#         # Guion indica descendente.
#         ordering = ['nombre', '-fecha_creacion']
#
#         # Nombre legible singular para el modelo (usado en admin, etc.)
#         verbose_name = "Producto"
#         # Nombre legible plural
#         verbose_name_plural = "Productos"
#
#         # --- Opciones de Base de Datos ---
#
#         # Especificar manualmente el nombre de la tabla en la BD
#         # (Por defecto: 'productos_producto')
#         # db_table = 'catalogo_productos'
#
#         # Crear índices explícitos en la BD para mejorar consultas
#         indexes = [
#             models.Index(fields=['slug']), # Índice en el campo slug
#             models.Index(fields=['nombre', '-fecha_creacion'], name='idx_prod_nombre_fecha'), # Índice compuesto
#         ]
#
#         # Definir restricciones a nivel de BD
#         constraints = [
#             # Ejemplo: Precio debe ser mayor que cero
#             models.CheckConstraint(check=models.Q(precio__gt=0), name='precio_positivo'),
#             # Ejemplo: Combinación de nombre y categoría (si hubiera) debe ser única
#             # models.UniqueConstraint(fields=['nombre', 'categoria'], name='nombre_categoria_unico')
#         ]
#
#         # --- Otras Opciones ---
#
#         # Marcar como modelo abstracto (no se crea tabla, solo para herencia)
#         # abstract = True
#
#         # Especificar un manager personalizado por defecto
#         # objects = MiManagerPersonalizado()
#
#         # Permisos personalizados (además de add, change, delete, view)
#         # permissions = [
#         #     ("can_change_stock", "Puede cambiar el stock del producto"),
#         # ]
#
#         # etc. (ver documentación para la lista completa)
# ```
# Configurar `Meta` adecuadamente ayuda a definir el comportamiento por defecto, mejorar el rendimiento de la base de datos y hacer que la interfaz de administración sea más clara.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 7_6_Ejercicio_Practico_Definir_Modelos_Simples
#
# **Objetivo:** Definir los modelos `Categoria` y `Producto` en la aplicación `productos`.
#
# **Pasos:**
#
# 1.  **Abre `productos/models.py`**.
# 2.  **Importa `models`** de `django.db`.
# 3.  **Define la clase `Categoria`** que herede de `models.Model`:
#     *   Añade un campo `nombre` (`CharField`, `max_length=100`, `unique=True`).
#     *   Añade un campo `slug` (`SlugField`, `max_length=100`, `unique=True`).
#     *   Define una clase `Meta` con `verbose_name` y `verbose_name_plural` apropiados ("Categoría", "Categorías") y un `ordering` por `nombre`.
#     *   Define el método `__str__` para que devuelva el `nombre`.
# 4.  **Define la clase `Producto`** que herede de `models.Model`:
#     *   Añade campos:
#         *   `nombre` (`CharField`, `max_length=255`).
#         *   `slug` (`SlugField`, `max_length=255`, `unique=True`).
#         *   `descripcion` (`TextField`, `blank=True`).
#         *   `precio` (`DecimalField`, `max_digits=10`, `decimal_places=2`).
#         *   `stock` (`PositiveIntegerField`, `default=0`).
#         *   `disponible` (`BooleanField`, `default=True`).
#         *   `fecha_creacion` (`DateTimeField`, `auto_now_add=True`).
#         *   `categoria` (`ForeignKey` a `Categoria`, `on_delete=models.SET_NULL`, `null=True`, `blank=True`, `related_name='productos'`).
#         *   (Opcional) `imagen` (`ImageField`, `upload_to='productos/'`, `blank=True`, `null=True`). *Recuerda instalar Pillow (`pip install Pillow`) si añades este campo.*
#     *   Define una clase `Meta` con `verbose_name`, `verbose_name_plural`, `ordering` (`-fecha_creacion`) e `indexes` para `slug` y `nombre`.
#     *   Define el método `__str__` para que devuelva el `nombre`.
#     *   (Opcional) Define el método `get_absolute_url` asumiendo que tendrás una URL llamada `'productos:detalle_producto'` que usa el `slug`.
#
# **Solución Propuesta (`productos/models.py`):**
# ```python
# from django.db import models
# from django.urls import reverse
# # from django.conf import settings
# # User = settings.AUTH_USER_MODEL # No lo usamos en este ejemplo simple
#
# class Categoria(models.Model):
#     nombre = models.CharField(max_length=100, unique=True, db_index=True)
#     slug = models.SlugField(max_length=100, unique=True)
#     descripcion = models.TextField(blank=True)
#
#     class Meta:
#         verbose_name = "Categoría"
#         verbose_name_plural = "Categorías"
#         ordering = ['nombre']
#
#     def __str__(self):
#         return self.nombre
#
#     # Opcional: URL para ver productos de esta categoría (si tuvieras esa vista)
#     # def get_absolute_url(self):
#     #     return reverse('productos:lista_por_categoria', kwargs={'slug_categoria': self.slug})
#
# class Producto(models.Model):
#     nombre = models.CharField(max_length=255)
#     slug = models.SlugField(max_length=255, unique=True, help_text="Versión amigable para URL, única.")
#     descripcion = models.TextField(blank=True)
#     precio = models.DecimalField(max_digits=10, decimal_places=2)
#     stock = models.PositiveIntegerField(default=0)
#     disponible = models.BooleanField(default=True)
#     fecha_creacion = models.DateTimeField(auto_now_add=True)
#     # Omitimos fecha_actualizacion por simplicidad ahora
#     categoria = models.ForeignKey(
#         Categoria,
#         on_delete=models.SET_NULL,
#         null=True,
#         blank=True,
#         related_name='productos'
#     )
#     # Opcional:
#     # imagen = models.ImageField(upload_to='productos/%Y/%m/', blank=True, null=True)
#
#     class Meta:
#         ordering = ['-fecha_creacion']
#         verbose_name = "Producto"
#         verbose_name_plural = "Productos"
#         indexes = [
#             models.Index(fields=['slug']),
#             models.Index(fields=['nombre']),
#             models.Index(fields=['-fecha_creacion']), # Índice para el orden por defecto
#         ]
#
#     def __str__(self):
#         return self.nombre
#
#     def get_absolute_url(self):
#         # Asume una URL 'detalle_producto' que usa slug
#         # Si usas PK, cambia kwargs={'pk': self.pk}
#         return reverse('productos:detalle_producto', kwargs={'slug': self.slug}) # Necesitarás ajustar la URL conf para usar slug en lugar de id
#
# ```
# *Nota: Para que `get_absolute_url` funcione con slug, necesitarás cambiar la URL en `productos/urls.py` de `<int:producto_id>/` a `<slug:slug>/` y ajustar la vista `detalle_producto_view` para aceptar `slug` en lugar de `producto_id`.*
#
# Con los modelos definidos, el siguiente paso es crear las migraciones para aplicar estos cambios a la base de datos.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ## 8_Migraciones
#
# El sistema de migraciones de Django es la forma de propagar los cambios que realizas en tus modelos (añadir un campo, eliminar un modelo, cambiar opciones) al esquema de tu base de datos de forma estructurada y controlada.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 8_1_Que_son_las_Migraciones
#
# Son archivos Python (`.py`) que Django genera automáticamente cuando detecta cambios en tus `models.py`. Cada archivo representa un conjunto de operaciones DDL (Data Definition Language) que transforman el esquema de la base de datos de un estado a otro.
#
# **Ventajas Clave:**
# *   **Consistencia:** Aseguran que la estructura de la base de datos coincida con tus modelos Python.
# *   **Control de Versiones:** Las migraciones son código y se guardan en tu repositorio (Git). Puedes ver el historial de cambios del esquema y revertirlos si es necesario.
# *   **Colaboración:** Permiten a múltiples desarrolladores aplicar cambios de esquema de forma segura y coordinada.
# *   **Despliegue:** Facilitan la actualización del esquema de la base de datos en diferentes entornos (desarrollo, staging, producción).
# *   **Abstracción:** No necesitas escribir SQL DDL (como `CREATE TABLE`, `ALTER TABLE ADD COLUMN`) manualmente para diferentes bases de datos; Django genera el SQL apropiado.
#
# Las migraciones se almacenan en la carpeta `migrations/` dentro de cada aplicación Django.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 8_2_Comando_makemigrations
#
# Este es el comando que **detecta los cambios** en tus modelos (comparando el estado actual de `models.py` con el estado registrado en los archivos de migración existentes) y **genera los nuevos archivos de migración** `.py` necesarios para reflejar esos cambios.
#
# **Sintaxis:**
# `python manage.py makemigrations [nombre_app_opcional]`
#
# *   Ejecútalo **después** de haber modificado `models.py`.
# *   Si no especificas `nombre_app`, buscará cambios en todas las apps de `INSTALLED_APPS`. Es recomendable especificar la app si solo has cambiado una (`python manage.py makemigrations productos`).
# *   Django nombrará el archivo de migración automáticamente (ej: `0001_initial.py`, `0002_add_campo_descripcion.py`).
# *   **Este comando NO aplica los cambios a la base de datos**, solo crea el archivo con las instrucciones.
#
# **Ejemplo (después de crear los modelos `Categoria` y `Producto`):**
# ```bash
# # (venv) Asegúrate de estar en el directorio con manage.py
# python manage.py makemigrations productos
# ```
# **Salida esperada:**
# ```
# Migrations for 'productos':
#   productos/migrations/0001_initial.py
#     - Create model Categoria
#     - Create model Producto
# ```
# Se ha creado el archivo `productos/migrations/0001_initial.py`. Puedes (y a veces debes) inspeccionar este archivo para ver las operaciones que Django realizará (`CreateModel`, `AddField`, etc.).
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 8_3_Comando_migrate
#
# Este comando es el que realmente **lee los archivos de migración** (tanto los de Django incorporados como los tuyos) que aún no se han aplicado a la base de datos y **ejecuta las sentencias SQL** necesarias para actualizar el esquema de la base de datos.
#
# **Sintaxis:**
# `python manage.py migrate [nombre_app_opcional] [nombre_migracion_opcional]`
#
# *   Si se ejecuta sin argumentos, aplica **todas** las migraciones pendientes de **todas** las aplicaciones (incluyendo las de `django.contrib.auth`, `admin`, etc.). Esto es lo que harás la primera vez y la mayoría de las veces después de `makemigrations`.
# *   Especificar `nombre_app` aplica las migraciones pendientes solo para esa app.
# *   Especificar `nombre_app` y `nombre_migracion` aplica (o revierte) hasta esa migración específica. Usar `zero` como nombre de migración revierte todas las migraciones de esa app (`python manage.py migrate productos zero`).
#
# **Ejemplo (después de `makemigrations`):**
# ```bash
# # (venv) Aplicar las migraciones pendientes a la BD
# python manage.py migrate
# ```
# **Salida esperada (la primera vez será más larga):**
# ```
# Operations to perform:
#   Apply all migrations: admin, auth, contenttypes, productos, sessions
# Running migrations:
#   Applying contenttypes.0001_initial... OK
#   Applying auth.0001_initial... OK
#   Applying admin.0001_initial... OK
#   ... (otras migraciones de Django) ...
#   Applying productos.0001_initial... OK  <-- Aplica nuestra migración
#   Applying sessions.0001_initial... OK
# ```
# Ahora las tablas `productos_categoria` y `productos_producto` (o como Django las haya nombrado) existen en tu base de datos.
#
# **Flujo de trabajo estándar:**
# 1.  Modificar `models.py`.
# 2.  `python manage.py makemigrations <app_name>`
# 3.  `python manage.py migrate`
# 4.  Commitear los cambios en `models.py` y el nuevo archivo de migración `.py` a Git.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 8_4_Comando_sqlmigrate
#
# Como vimos brevemente, este comando te permite **ver el SQL exacto** que Django generaría y ejecutaría para una migración específica, **sin** aplicarlo realmente. Es muy útil para:
# *   Entender qué cambios hará Django en la base de datos.
# *   Depurar problemas con migraciones.
# *   Adaptar el SQL para sistemas de base de datos específicos o para revisiones por parte de un DBA (Administrador de Base de Datos).
#
# **Sintaxis:**
# `python manage.py sqlmigrate <nombre_app> <nombre_migracion>`
#
# ```bash
# # Ver el SQL para la primera migración de la app 'productos'
# python manage.py sqlmigrate productos 0001_initial
# ```
# La salida mostrará las sentencias `CREATE TABLE`, `ALTER TABLE`, `CREATE INDEX`, etc., específicas para la base de datos configurada en tu `settings.py` (la sintaxis puede variar entre SQLite, PostgreSQL, MySQL).
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 8_5_Comando_showmigrations
#
# Muestra el estado de las migraciones para todas las aplicaciones en el proyecto. Indica qué migraciones existen y cuáles han sido aplicadas a la base de datos actual.
#
# **Sintaxis:**
# `python manage.py showmigrations`
#
# **Salida de ejemplo:**
# ```
# admin
#  [X] 0001_initial
#  [X] 0002_logentry_remove_auto_add
#  [X] 0003_logentry_add_action_flag_choices
# auth
#  [X] 0001_initial
#  ... (más migraciones de auth) ...
#  [X] 0012_alter_user_first_name_max_length
# contenttypes
#  [X] 0001_initial
#  [X] 0002_remove_content_type_name
# productos  <-- Nuestra app
#  [X] 0001_initial  <-- Marcada como aplicada (después de migrate)
# sessions
#  [X] 0001_initial
# ```
# *   `[X]` indica que la migración ha sido aplicada.
# *   `[ ]` indicaría una migración pendiente (generada con `makemigrations` pero no aplicada con `migrate`).
#
# Es útil para verificar el estado antes o después de ejecutar `migrate` o al cambiar entre ramas de Git que puedan tener diferentes migraciones.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 8_6_Manejo_de_Conflictos_y_Reversion_de_Migraciones
#
# *   **Conflictos:** Pueden ocurrir si varios desarrolladores trabajan en ramas diferentes y ambos modifican los modelos y generan migraciones (ej: ambos crean una migración `0002`). Cuando intentan fusionar (merge) sus ramas, Git puede detectar un conflicto en la carpeta `migrations/` o Django puede detectar migraciones con el mismo número pero diferente contenido.
#     *   **Solución:** Generalmente implica:
#         1.  Revertir las migraciones locales en conflicto (`python manage.py migrate <app> <migracion_anterior>`).
#         2.  Resolver el conflicto de Git (puede requerir eliminar uno de los archivos de migración en conflicto y ajustar el código).
#         3.  Volver a ejecutar `makemigrations` para generar una nueva migración que combine los cambios (o una migración de fusión si Django lo sugiere).
#         4.  Volver a ejecutar `migrate`.
#     *   Es complejo y requiere cuidado. Comunicarse con el equipo es clave.
# *   **Reversión:** Puedes revertir migraciones aplicadas usando `migrate` con el nombre de la migración *anterior* a la que quieres volver, o usando `zero` para revertir todas las de una app.
#     ```bash
#     # Revertir la migración 0002_... de la app 'blog' (volver al estado de 0001)
#     python manage.py migrate blog 0001_initial
#
#     # Revertir todas las migraciones de la app 'blog'
#     python manage.py migrate blog zero
#     ```
#     **¡Cuidado!** Revertir migraciones puede implicar **pérdida de datos** si la migración eliminó tablas o columnas que contenían información. Asegúrate de entender las consecuencias antes de revertir, especialmente en entornos de producción (donde generalmente se avanza, no se retrocede, o se crean migraciones de datos para mover información antes de eliminar esquemas).
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 8_7_Ejercicio_Practico_Crear_y_Aplicar_Migraciones
#
# **Objetivo:** Crear y aplicar la migración inicial para los modelos `Categoria` y `Producto` definidos en el ejercicio anterior.
#
# **Pasos:**
#
# 1.  **Verifica** que tienes los modelos `Categoria` y `Producto` definidos en `productos/models.py` (como en la solución del Ejercicio 7.6).
# 2.  **Asegúrate** de que la aplicación `productos` (o `productos.apps.ProductosConfig`) esté registrada en `INSTALLED_APPS` en `tienda_config/settings.py`.
# 3.  **Asegúrate** de que tu entorno virtual esté activo y estés en el directorio raíz del proyecto (el que contiene `manage.py`).
# 4.  **Genera** el archivo de migración para la aplicación `productos`.
#     ```bash
#     python manage.py makemigrations productos
#     ```
#     *   Deberías ver una salida indicando que se creó un archivo como `productos/migrations/0001_initial.py`.
# 5.  **(Opcional)** Ejecuta `showmigrations` para ver que la nueva migración aparece como no aplicada (`[ ]`).
#     ```bash
#     python manage.py showmigrations
#     ```
# 6.  **(Opcional)** Ejecuta `sqlmigrate` para ver el SQL que se generará para tu base de datos configurada (probablemente SQLite por defecto en este punto).
#     ```bash
#     python manage.py sqlmigrate productos 0001
#     ```
#     *   Deberías ver sentencias `CREATE TABLE` para `productos_categoria` y `productos_producto`, junto con `CREATE INDEX`.
# 7.  **Aplica** todas las migraciones pendientes (incluyendo las de Django y las de tu app `productos`) a la base de datos.
#     ```bash
#     python manage.py migrate
#     ```
#     *   Deberías ver mensajes "OK" para todas las migraciones, incluyendo `productos.0001_initial`.
# 8.  **(Opcional)** Ejecuta `showmigrations` de nuevo. Ahora la migración `0001_initial` de `productos` debería aparecer como aplicada (`[X]`).
#
# **Solución Propuesta:**
# La ejecución exitosa de los comandos `makemigrations productos` y `migrate` sin errores es la solución. Después de `migrate`, las tablas correspondientes a tus modelos existirán en el archivo de base de datos (`db.sqlite3` por defecto).
#
# ¡Has definido tus modelos y sincronizado tu base de datos con ellos usando el sistema de migraciones! Ahora estás listo para empezar a interactuar con los datos.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ## 9_Interactuando_con_la_Base_de_Datos_QuerySets
#
# Una vez que tus modelos están definidos y las migraciones aplicadas, necesitas una forma de crear, leer, actualizar y eliminar (CRUD) datos en tu base de datos usando Python. Django proporciona un API potente y elegante para esto a través de los **Managers** y **QuerySets**.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 9_1_El_Manager_objects
#
# Cada modelo Django tiene al menos un atributo especial llamado **Manager** (Administrador). Es la interfaz principal a través de la cual se realizan las operaciones de consulta a la base de datos para ese modelo.
#
# *   **Nombre por Defecto:** Por convención y por defecto, este manager se llama `objects`.
# *   **Acceso:** Accedes a él a través de la *clase* del modelo: `NombreModelo.objects`.
# *   **Funcionalidad:** Proporciona métodos que devuelven QuerySets (`all()`, `filter()`, `exclude()`, etc.) o que realizan operaciones directas en la base de datos (`create()`, `get()`, `update()`, `delete()` en QuerySets).
#
# ```python
# from .models import Producto
#
# # Usando el manager por defecto 'objects'
# todos_los_productos = Producto.objects.all()
# productos_disponibles = Producto.objects.filter(disponible=True)
# try:
#     producto_uno = Producto.objects.get(pk=1)
# except Producto.DoesNotExist:
#     producto_uno = None
# ```
# Puedes definir managers personalizados si necesitas añadir métodos de consulta específicos para un modelo o modificar el QuerySet base que devuelven.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 9_2_Creacion_de_Objetos_create_save
#
# Vimos esto brevemente al probar el shell, pero repasemos las formas de añadir nuevos registros (filas) a la base de datos:
#
# 1.  **`NombreModelo.objects.create(**kwargs)`:**
#     *   La forma más directa y común.
#     *   Toma argumentos de palabra clave (`kwargs`) donde las claves son los nombres de los campos del modelo.
#     *   Crea la instancia, la guarda en la base de datos (ejecuta `INSERT INTO ...`) y devuelve la instancia del modelo recién creada y guardada.
#     ```python
#     from .models import Categoria, Producto
#     # from django.contrib.auth.models import User # Si usas el campo autor
#     # autor = User.objects.get(pk=1) # Necesitas una instancia real de User o Categoria
#
#     cat_nueva = Categoria.objects.create(nombre="Electrónica", slug="electronica")
#
#     prod_nuevo = Producto.objects.create(
#         nombre="Smartphone X1",
#         slug="smartphone-x1",
#         precio=Decimal("699.99"), # Usa Decimal para DecimalField
#         stock=50,
#         categoria=cat_nueva, # Pasa la instancia de Categoria
#         # creado_por=autor # Pasa la instancia de User
#     )
#     print(f"Producto creado: {prod_nuevo.nombre} con ID: {prod_nuevo.pk}")
#     ```
#
# 2.  **Instanciar y luego llamar a `.save()`:**
#     *   Permite crear la instancia en memoria, modificarla o asignarle valores, y luego guardarla explícitamente.
#     ```python
#     from decimal import Decimal
#
#     # Crear instancia sin guardar
#     prod_ram = Producto(
#         nombre="Memoria RAM 16GB",
#         slug="ram-16gb",
#         precio=Decimal("75.00"),
#         disponible=False # Empieza no disponible
#     )
#     # Asignar categoría (si existe)
#     try:
#         cat_comps = Categoria.objects.get(slug="componentes")
#         prod_ram.categoria = cat_comps
#     except Categoria.DoesNotExist:
#         print("Categoría 'componentes' no encontrada.")
#
#     # Establecer stock
#     prod_ram.stock = 100
#     prod_ram.disponible = True # Ahora está disponible
#
#     # Guardar en la base de datos (ejecuta INSERT)
#     prod_ram.save()
#     print(f"Producto RAM guardado con ID: {prod_ram.pk}")
#     ```
#     *   El método `save()` es inteligente: si la instancia tiene una clave primaria (`pk`) asignada (porque ya existía en la BD), ejecutará un `UPDATE`. Si no tiene `pk` (o `force_insert=True`), ejecutará un `INSERT`.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 9_3_Recuperacion_de_Objetos_all_get_filter_exclude
#
# Estos son los métodos fundamentales para obtener objetos de la base de datos. Todos ellos se llaman sobre el manager (`objects`) o sobre un QuerySet existente.
#
# *   **`all()`:** Devuelve un **QuerySet** con *todos* los objetos del modelo.
#     ```python
#     todos_productos = Producto.objects.all()
#     ```
# *   **`filter(**kwargs)`:** Devuelve un **QuerySet** con los objetos que *coinciden* con los criterios de búsqueda (argumentos de palabra clave).
#     ```python
#     # Productos de la categoría 'Electrónica' que están disponibles
#     electronica_disponible = Producto.objects.filter(categoria__slug='electronica', disponible=True)
#     ```
# *   **`exclude(**kwargs)`:** Devuelve un **QuerySet** con los objetos que *no coinciden* con los criterios.
#     ```python
#     # Todos los productos excepto los de la categoría 'Electrónica'
#     no_electronica = Producto.objects.exclude(categoria__slug='electronica')
#     ```
# *   **`get(**kwargs)`:** Devuelve **una única instancia** del modelo que coincide *exactamente* con los criterios.
#     *   Lanza `Modelo.DoesNotExist` si no encuentra ningún objeto.
#     *   Lanza `Modelo.MultipleObjectsReturned` si encuentra más de uno.
#     *   Úsalo principalmente para buscar por `pk` o campos `unique`.
#     ```python
#     try:
#         producto_especifico = Producto.objects.get(pk=1) # O get(id=1)
#     except Producto.DoesNotExist:
#         print("Producto no encontrado")
#     ```
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)[Volver a la Tabla de Contenido](#Tabla_de_Contenido)
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)[Volver a la Tabla de Contenido](#Tabla_de_Contenido)
# #### 9_3_1_Diferencia_entre_get_y_filter
#
# *   `get()`:
#     *   Devuelve **un objeto** (instancia del modelo).
#     *   Espera **exactamente un** resultado.
#     *   Lanza excepciones si no encuentra 0 o más de 1.
#     *   No se puede encadenar más (`.filter()`, `.order_by()` después de `get()`).
# *   `filter()`:
#     *   Devuelve un **QuerySet** (una colección, potencialmente vacía, de objetos).
#     *   Puede devolver 0, 1 o muchos resultados.
#     *   No lanza excepciones si no encuentra nada (devuelve un QuerySet vacío).
#     *   **Se puede encadenar** con otros métodos de QuerySet (`.filter()`, `.exclude()`, `.order_by()`, etc.).
#
# Usa `get()` cuando necesites un objeto específico y estés seguro de que existe. Usa `filter()` para buscar conjuntos de objetos o cuando no estés seguro de cuántos resultados habrá.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# #### 9_3_2_Manejo_de_DoesNotExist_y_MultipleObjectsReturned
#
# Como `get()` puede lanzar excepciones, es común envolverlo en un bloque `try...except`:
#
# ```python
# from .models import Producto
#
# def mi_vista(request, id_producto):
#     try:
#         producto = Producto.objects.get(pk=id_producto)
#         # ... usar el producto ...
#         return render(...)
#     except Producto.DoesNotExist:
#         # Opción 1: Lanzar Http404 para que Django muestre la página 404
#         from django.http import Http404
#         raise Http404("Producto no encontrado")
#         # Opción 2: Redirigir o mostrar un mensaje personalizado
#         # messages.error(request, "El producto solicitado no existe.")
#         # return redirect('productos:lista_productos')
# ```
#
# **Atajo:** `get_object_or_404(ClaseModelo, **kwargs)`:
# Esta función de `django.shortcuts` combina `get()` y el manejo de `DoesNotExist` lanzando `Http404` automáticamente. Es la forma preferida en vistas:
#
# ```python
# from django.shortcuts import render, get_object_or_404
# from .models import Producto
#
# def detalle_producto_view(request, pk): # Asumiendo que la URL pasa 'pk'
#     producto = get_object_or_404(Producto, pk=pk, disponible=True) # Busca por PK y que esté disponible
#     contexto = {'producto': producto}
#     return render(request, 'productos/detalle_producto.html', contexto)
# ```
#
# `MultipleObjectsReturned` es más raro y suele indicar un problema en tu lógica o diseño (ej: buscar con `get()` por un campo que no es `unique`).
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# #### 9_3_3_first_last_exists_count
#
# Métodos útiles que operan sobre QuerySets:
#
# *   `mi_queryset.first()`: Devuelve el **primer objeto** del QuerySet (según el orden definido), o `None` si el QuerySet está vacío. No lanza excepción. Alternativa segura a `mi_queryset[0]`.
# *   `mi_queryset.last()`: Devuelve el **último objeto** del QuerySet, o `None` si está vacío.
# *   `mi_queryset.exists()`: Devuelve `True` si el QuerySet contiene **al menos un objeto**, `False` si está vacío. Es más eficiente que `len(mi_queryset) > 0` o `mi_queryset.count() > 0` porque intenta optimizar la consulta SQL (a menudo usa `SELECT 1 ... LIMIT 1`).
# *   `mi_queryset.count()`: Devuelve el **número total de objetos** en el QuerySet. Realiza un `SELECT COUNT(*)...` en la base de datos, que suele ser más eficiente que obtener todos los objetos (`len(mi_queryset)`) si solo necesitas la cantidad.
#
# ```python
# productos_caros = Producto.objects.filter(precio__gte=1000)
#
# if productos_caros.exists():
#     print(f"Hay {productos_caros.count()} productos caros.")
#     primer_caro = productos_caros.order_by('precio').first() # El más barato de los caros
#     print(f"El más barato de los caros es: {primer_caro}")
# else:
#     print("No hay productos caros.")
#
# ```
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 9_4_Encadenamiento_de_Filtros
#
# Los métodos que devuelven QuerySets (`filter`, `exclude`, `order_by`, etc.) se pueden encadenar para construir consultas complejas de forma incremental y legible. Cada llamada refina el QuerySet anterior.
#
# ```python
# # Productos electrónicos, disponibles, con precio menor a 500, ordenados por precio ascendente
# resultado = Producto.objects.filter(categoria__slug='electronica') \
#                             .filter(disponible=True) \
#                             .exclude(precio__gte=500) \
#                             .order_by('precio')
#
# # Equivalente en una sola llamada a filter (a menudo preferible si es simple)
# resultado_alt = Producto.objects.filter(
#     categoria__slug='electronica',
#     disponible=True,
#     precio__lt=500
# ).order_by('precio')
#
# print(resultado)
# ```
# La consulta a la base de datos no se realiza hasta que el QuerySet final (`resultado` o `resultado_alt`) se evalúa.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 9_5_Lookups_de_Campo_exact_iexact_contains_gt_lt_etc
#
# Como vimos brevemente, los lookups (sufijos con `__`) permiten realizar comparaciones más complejas que la igualdad exacta al filtrar.
#
# **Repaso de Lookups Comunes:**
# *   `__exact`: Coincidencia exacta (sensible a mayúsculas). Es el default.
# *   `__iexact`: Exacta (insensible a mayúsculas).
# *   `__contains`: Contiene subcadena (sensible).
# *   `__icontains`: Contiene subcadena (insensible).
# *   `__startswith` / `__istartswith`: Empieza con...
# *   `__endswith` / `__iendswith`: Termina con...
# *   `__in`: El valor está en una lista/tupla/queryset dada.
# *   `__gt` / `__gte`: Mayor que / Mayor o igual que.
# *   `__lt` / `__lte`: Menor que / Menor o igual que.
# *   `__range`: El valor está dentro de un rango (tupla `(inicio, fin)`).
# *   `__isnull`: El valor es `NULL` (`True`) o no (`False`).
# *   `__year` / `__month` / `__day` / `__week_day`: Para campos Date/DateTimeField.
# *   `__hour` / `__minute` / `__second`: Para campos DateTimeField/TimeField.
# *   `__regex` / `__iregex`: Coincidencia con expresión regular.
#
# ```python
# from datetime import date
#
# # Productos creados hoy
# hoy = date.today()
# productos_hoy = Producto.objects.filter(fecha_creacion__date=hoy) # Usando __date en DateTimeField
#
# # Productos cuyo nombre empieza con 'L' (insensible) y tienen stock > 0
# laptops_stock = Producto.objects.filter(nombre__istartswith='L', stock__gt=0)
#
# # Productos con ID 1, 3 o 5
# productos_seleccion = Producto.objects.filter(pk__in=[1, 3, 5])
#
# # Productos creados en 2023
# productos_2023 = Producto.objects.filter(fecha_creacion__year=2023)
# ```
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 9_6_Objetos_Q_Consultas_OR_y_NOT_Complejas
#
# Por defecto, los argumentos pasados a `filter()` se combinan con un operador `AND` lógico. Para realizar consultas `OR` o `NOT` más complejas, se usan los objetos `Q` importados de `django.db.models`.
#
# *   **OR (`|`):** `Q(condicion1) | Q(condicion2)`
# *   **AND (`&`):** `Q(condicion1) & Q(condicion2)` (Equivalente a pasar argumentos separados a `filter`, pero útil para agrupar)
# *   **NOT (`~`):** `~Q(condicion)` (Equivalente a `exclude`)
#
# ```python
# from django.db.models import Q
# from .models import Producto
#
# # Productos cuyo nombre empiece con 'L' O cuyo precio sea menor a 100
# resultado_or = Producto.objects.filter(
#     Q(nombre__istartswith='L') | Q(precio__lt=100)
# )
#
# # Productos que NO estén disponibles Y cuyo stock sea 0
# resultado_not_and = Producto.objects.filter(
#     ~Q(disponible=True) & Q(stock=0)
#     # Equivalente a: Producto.objects.filter(disponible=False, stock=0)
# )
#
# # Consulta más compleja: (Electrónicos Y caros (>=1000)) O (disponibles Y sin stock)
# resultado_complejo = Producto.objects.filter(
#     (Q(categoria__slug='electronica') & Q(precio__gte=1000)) |
#     (Q(disponible=True) & Q(stock=0))
# )
#
# print(resultado_or)
# ```
# Los objetos `Q` permiten construir condiciones lógicas muy flexibles.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 9_7_Actualizacion_de_Objetos_save_update
#
# **Repaso:**
#
# *   **Actualizar una instancia:**
#     1.  Obtenerla (`get()`).
#     2.  Modificar atributos.
#     3.  Llamar a `instancia.save()`.
#     *   Ejecuta el método `save()` del modelo (si lo has personalizado).
#     *   Dispara señales `pre_save` y `post_save`.
#     *   Realiza una consulta `UPDATE` a la BD.
#
# *   **Actualizar múltiples objetos (`QuerySet.update(**kwargs)`):**
#     1.  Filtrar el QuerySet.
#     2.  Llamar a `.update(campo1=valor1, ...)` sobre el QuerySet.
#     *   **Más eficiente** para actualizaciones masivas (una sola consulta `UPDATE`).
#     *   **NO** llama al método `save()` de cada instancia.
#     *   **NO** dispara señales `pre_save`/`post_save`.
#     *   **NO** actualiza campos `auto_now`.
#     *   Usar cuando la eficiencia es clave y no dependes de la lógica personalizada en `save()` o de las señales.
#
# ```python
# # Ejemplo: Aumentar el precio de todos los productos electrónicos en un 10%
# productos_electronicos = Producto.objects.filter(categoria__slug='electronica')
# num_actualizados = productos_electronicos.update(precio=models.F('precio') * 1.10)
# # Nota: Usamos F() para referenciar el valor actual del campo en la BD y evitar race conditions.
# print(f"Precios de {num_actualizados} productos electrónicos actualizados.")
# ```
# **Objeto `F()`:** Importado de `django.db.models`. Permite realizar operaciones directamente en la base de datos usando los valores actuales de los campos, sin tener que traerlos primero a Python. Es útil para incrementos, decrementos o actualizaciones basadas en otros campos.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 9_8_Eliminacion_de_Objetos_delete
#
# **Repaso:**
#
# *   **Eliminar una instancia:**
#     1.  Obtenerla (`get()`).
#     2.  Llamar a `instancia.delete()`.
#     *   Elimina el objeto de la BD.
#     *   Maneja las relaciones según `on_delete`.
#     *   Dispara señales `pre_delete` y `post_delete`.
#     *   Devuelve una tupla `(num_eliminados, diccionario_detalles)`.
#
# *   **Eliminar múltiples objetos (`QuerySet.delete()`):**
#     1.  Filtrar el QuerySet.
#     2.  Llamar a `.delete()` sobre el QuerySet.
#     *   **Más eficiente** para eliminaciones masivas (una o pocas consultas `DELETE`).
#     *   **NO** llama al método `delete()` de cada instancia.
#     *   **SÍ** dispara señales `pre_delete`/`post_delete` (pero para el QuerySet, no para cada objeto individualmente si la BD soporta borrado en cascada eficiente).
#     *   Maneja `on_delete`.
#     *   Devuelve una tupla `(num_eliminados, diccionario_detalles)`.
#
# ```python
# # Eliminar todos los productos con stock 0
# num_eliminados, _ = Producto.objects.filter(stock=0).delete()
# print(f"Se eliminaron {num_eliminados} productos sin stock.")
# ```
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 9_9_Ordenamiento_order_by
#
# Permite especificar el orden en que se devuelven los resultados de un QuerySet.
#
# *   Llamado sobre un manager o QuerySet: `MiModelo.objects.order_by('campo')`.
# *   Argumentos: Nombres de campos como strings.
# *   Prefijo `-` para orden descendente: `order_by('-fecha_creacion')`.
# *   Múltiples campos para desempate: `order_by('categoria__nombre', 'precio')` (ordena por nombre de categoría, y dentro de cada categoría, por precio).
# *   Llamar a `order_by()` sin argumentos elimina cualquier ordenamiento previo (incluido el de `Meta.ordering`).
# *   Llamar a `order_by('?')` ordena aleatoriamente (costoso en BDs grandes).
#
# ```python
# # Productos ordenados por precio descendente
# mas_caros_primero = Producto.objects.all().order_by('-precio')
#
# # Productos ordenados por nombre de categoría, luego por nombre de producto
# orden_cat_nombre = Producto.objects.order_by('categoria__nombre', 'nombre')
# ```
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 9_10_Limitacion_de_Resultados_Slicing
#
# Puedes obtener un subconjunto de los resultados de un QuerySet usando la sintaxis de slicing de Python, que Django traduce a cláusulas `LIMIT` y `OFFSET` en SQL, haciéndolo eficiente.
#
# *   `queryset[N]`: Obtiene el N-ésimo objeto (índice 0). Lanza `IndexError` si no existe.
# *   `queryset[:N]`: Obtiene los primeros N objetos (`LIMIT N`).
# *   `queryset[N:M]`: Obtiene objetos desde el índice N hasta M-1 (`LIMIT M-N OFFSET N`).
# *   `queryset[N:]`: Obtiene objetos desde el índice N hasta el final (`OFFSET N`).
#
# ```python
# # Los 10 productos más baratos
# top_10_baratos = Producto.objects.order_by('precio')[:10]
#
# # Productos del 11 al 20 (para paginación - página 2 si van de 10 en 10)
# pagina_2 = Producto.objects.order_by('nombre')[10:20]
#
# # El quinto producto añadido más recientemente
# quinto_mas_reciente = Producto.objects.order_by('-fecha_creacion')[4] # Índice 4
# ```
# El slicing **no** evalúa el QuerySet completo si aún no ha sido evaluado. Es eficiente para paginación.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 9_11_Evaluacion_Perezosa_Lazy_Loading_de_QuerySets
#
# Un concepto clave del ORM de Django es que los **QuerySets son perezosos (lazy)**.
#
# *   **Crear un QuerySet no ejecuta la consulta:** Cuando escribes `productos = Producto.objects.filter(disponible=True).order_by('nombre')`, **no** se realiza ninguna consulta a la base de datos en ese momento. Simplemente has construido un objeto QuerySet que representa esa consulta.
# *   **La Evaluación Ocurre Cuando es Necesario:** La consulta a la base de datos solo se ejecuta cuando intentas **acceder a los datos** del QuerySet. Esto ocurre al:
#     *   Iterar sobre él (`for p in productos:`).
#     *   Aplicarle slicing (`productos[:5]`).
#     *   Convertirlo a lista (`list(productos)`).
#     *   Llamar a `len()` sobre él (menos eficiente que `count()`).
#     *   Llamar a `count()` o `exists()`.
#     *   Imprimirlo directamente (`print(productos)`).
# *   **Caching de Resultados:** Una vez que un QuerySet ha sido evaluado (ha ido a la BD), Django **guarda en caché** los resultados dentro del objeto QuerySet. Si vuelves a iterar sobre el *mismo* objeto QuerySet, usará los resultados cacheados en lugar de volver a consultar la base de datos.
#
# **Implicaciones:**
# *   **Eficiencia:** Puedes construir consultas complejas encadenando filtros sin golpear la base de datos en cada paso.
# *   **Precaución con la Evaluación Múltiple:** Si necesitas los resultados varias veces, asegúrate de guardarlos en una variable después de la primera evaluación (ej: `lista_productos = list(productos_queryset)`) si quieres evitar consultas repetidas (a menos que necesites datos actualizados).
#
# ```python
# # 1. Construcción (SIN consulta a BD)
# productos_qs = Producto.objects.filter(stock__gt=0)
#
# # 2. Evaluación (PRIMERA consulta a BD)
# print("Iterando por primera vez:")
# for prod in productos_qs:
#     print(f"- {prod.nombre}")
#
# # 3. Re-evaluación (USA CACHÉ, SIN consulta a BD)
# print("\nIterando por segunda vez (usa caché):")
# if productos_qs: # Esto también evalúa (usa exists() implícitamente)
#     for prod in productos_qs:
#         print(f"- {prod.nombre}")
#
# # 4. Forzar nueva consulta (si necesitas datos frescos)
# print("\nObteniendo una nueva copia:")
# productos_frescos_qs = Producto.objects.filter(stock__gt=0) # Nuevo QuerySet
# # La siguiente línea hará otra consulta a la BD
# lista_productos_frescos = list(productos_frescos_qs)
# print(f"Obtenidos {len(lista_productos_frescos)} productos frescos.")
# ```
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 9_12_Ejercicio_Practico_Realizar_Consultas_CRUD
#
# **Objetivo:** Usar el shell de Django para practicar la creación, lectura, actualización y eliminación de objetos `Categoria` y `Producto`.
#
# **Pasos:**
#
# 1.  **Abre el shell de Django:**
#     ```bash
#     python manage.py shell
#     ```
# 2.  **Importa los modelos:**
#     ```python
#     from productos.models import Categoria, Producto
#     from decimal import Decimal # Para los precios
#     ```
# 3.  **Crear Categorías:**
#     *   Crea una categoría "Tecnología".
#     *   Crea una categoría "Hogar".
#     ```python
#     cat_tec = Categoria.objects.create(nombre="Tecnologia", slug="tecnologia")
#     cat_hog = Categoria.objects.create(nombre="Hogar", slug="hogar")
#     ```
# 4.  **Crear Productos:**
#     *   Crea un "Televisor LED 55 pulgadas" en la categoría "Tecnología", precio 799.95, stock 15.
#     *   Crea una "Cafetera Express" en la categoría "Hogar", precio 89.90, stock 30, disponible=False.
#     *   Crea un "Ratón Inalámbrico" (sin categoría asignada inicialmente), precio 25.00, stock 50.
#     ```python
#     tv = Producto.objects.create(nombre="Televisor LED 55 pulgadas", slug="tv-led-55", categoria=cat_tec, precio=Decimal("799.95"), stock=15)
#     cafetera = Producto.objects.create(nombre="Cafetera Express", slug="cafetera-express", categoria=cat_hog, precio=Decimal("89.90"), stock=30, disponible=False)
#     raton = Producto.objects.create(nombre="Raton Inalambrico", slug="raton-inalambrico", precio=Decimal("25.00"), stock=50)
#     ```
# 5.  **Leer/Consultar:**
#     *   Obtén todos los productos y muéstralos.
#     *   Obtén solo los productos de la categoría "Tecnología".
#     *   Obtén el producto con el slug "cafetera-express".
#     *   Obtén los productos con precio menor a 100.
#     *   Cuenta cuántos productos no están disponibles.
#     ```python
#     print("Todos:", Producto.objects.all())
#     print("\nTecnología:", Producto.objects.filter(categoria=cat_tec))
#     # O por slug de categoría: Producto.objects.filter(categoria__slug='tecnologia')
#     print("\nCafetera:", Producto.objects.get(slug='cafetera-express'))
#     print("\nBaratos:", Producto.objects.filter(precio__lt=100))
#     print("\nNo disponibles:", Producto.objects.filter(disponible=False).count())
#     ```
# 6.  **Actualizar:**
#     *   Actualiza el stock del "Ratón Inalámbrico" a 45 y ponle la categoría "Tecnología".
#     *   Usa `update()` para poner todos los productos de "Hogar" como disponibles.
#     ```python
#     raton_db = Producto.objects.get(slug='raton-inalambrico')
#     raton_db.stock = 45
#     raton_db.categoria = cat_tec
#     raton_db.save()
#     print("\nRatón actualizado:", Producto.objects.get(slug='raton-inalambrico').stock, Producto.objects.get(slug='raton-inalambrico').categoria)
#
#     num_hogar_upd = Producto.objects.filter(categoria=cat_hog).update(disponible=True)
#     print(f"\n{num_hogar_upd} productos de hogar actualizados a disponible=True")
#     print("Cafetera ahora disponible:", Producto.objects.get(slug='cafetera-express').disponible)
#     ```
# 7.  **Eliminar:**
#     *   Elimina el "Televisor LED 55 pulgadas".
#     ```python
#     tv_a_borrar = Producto.objects.get(slug='tv-led-55')
#     resultado_del = tv_a_borrar.delete()
#     print("\nResultado borrado TV:", resultado_del)
#     print("Productos restantes:", Producto.objects.count())
#     ```
# 8.  **Sal del shell:** `exit()`
#
# **Solución Propuesta:**
# La ejecución de los comandos anteriores en el shell de Django y la verificación de las salidas impresas constituyen la solución.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ## 10_Relaciones_Entre_Modelos
#
# Los modelos raramente existen aislados. Las relaciones permiten conectar diferentes modelos para representar cómo se vinculan los datos en el mundo real. Django ofrece campos específicos para los tres tipos principales de relaciones en bases de datos relacionales.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 10_1_Relaciones_Uno_a_Muchos_ForeignKey
#
# Representa una relación donde una instancia de un modelo (el lado "uno") puede estar relacionada con *muchas* instancias de otro modelo (el lado "muchos"), pero cada instancia del lado "muchos" solo puede estar relacionada con *una* instancia del lado "uno".
#
# **Ejemplos:**
# *   Un `Autor` (User) puede escribir muchos `Post`s. Un `Post` tiene un solo `Autor`.
# *   Una `Categoria` puede tener muchos `Producto`s. Un `Producto` pertenece (generalmente) a una sola `Categoria`. (Aunque a veces se usa ManyToMany para esto).
# *   Un `Post` puede tener muchos `Comentario`s. Un `Comentario` pertenece a un solo `Post`.
#
# **Implementación:** Se usa `models.ForeignKey()` en el modelo del lado **"muchos"**, apuntando al modelo del lado "uno".
#
# ```python
# # productos/models.py (ejemplo ya visto)
# from django.db import models
# # from .models import Categoria # Asumiendo importación si está en el mismo archivo
#
# class Producto(models.Model):
#     # ... otros campos ...
#     # Lado "Muchos" (Producto) apunta al lado "Uno" (Categoria)
#     categoria = models.ForeignKey(
#         Categoria,                 # Modelo del lado "Uno"
#         on_delete=models.SET_NULL, # Qué hacer si se borra la Categoria
#         null=True,                 # Permitir que sea NULL en BD
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)[Volver a la Tabla de Contenido](#Tabla_de_Contenido)[Volver a la Tabla de Contenido](#Tabla_de_Contenido)    blank=True,                # Permitir vacío en formularios
#         related_name='productos'   # Nombre para acceso inverso (categoria.productos)
#     )
# ```
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
# #### 10_1_1_Argumento_on_delete
#
# Este argumento es **obligatorio** para `ForeignKey` (y `OneToOneField`) y define la integridad referencial: ¿Qué debe pasar con los objetos de *este* modelo (ej: Producto) si se elimina el objeto relacionado del otro modelo (ej: Categoria)?
#
# Opciones Principales:
# *   `models.CASCADE`: **Elimina en cascada.** Si se borra la Categoría, todos los Productos asociados a ella también se borran. Comportamiento común.
# *   `models.PROTECT`: **Impide la eliminación.** Si intentas borrar una Categoría que todavía tiene Productos asociados, Django lanzará un error `ProtectedError`. Útil para evitar borrados accidentales de datos importantes.
# *   `models.SET_NULL`: **Establece la FK a NULL.** Si se borra la Categoría, el campo `categoria` en los Productos asociados se pondrá a `NULL`. Requiere que el campo ForeignKey tenga `null=True`. Útil si la relación es opcional.
# *   `models.SET_DEFAULT`: **Establece la FK al valor `default`.** Requiere que el campo ForeignKey tenga un atributo `default` definido.
# *   `models.SET(valor_o_callable)`: Establece la FK a un valor específico o al resultado de llamar a una función.
# *   `models.DO_NOTHING`: No hace nada a nivel de Django. Depende del comportamiento de la base de datos subyacente (puede causar errores de integridad si la BD tiene restricciones). Generalmente se evita.
#
# La elección de `on_delete` depende de la lógica de negocio de tu aplicación.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# #### 10_1_2_Argumento_related_name
#
# Permite definir cómo acceder a la relación *inversa* (desde el modelo "uno" hacia el conjunto de objetos del modelo "muchos").
#
# *   **Sin `related_name`:** Django crea automáticamente un nombre inverso: `nombremodeloenminuscula_set` (ej: si `Producto.categoria` es FK a `Categoria`, desde una instancia `cat` de `Categoria` accederías a sus productos con `cat.producto_set.all()`).
# *   **Con `related_name`:** Proporcionas un nombre más legible y explícito. En el ejemplo anterior, `related_name='productos'`, por lo que accederías con `cat.productos.all()`.
#
# Usar `related_name` es **muy recomendable** para claridad y para evitar el `_set` por defecto. El `related_name` debe ser único entre todas las relaciones inversas que apuntan a un mismo modelo desde diferentes ForeignKeys. Si no quieres una relación inversa, puedes usar `related_name='+'`.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 10_2_Relaciones_Muchos_a_Muchos_ManyToManyField
#
# Representa una relación donde una instancia de un modelo puede estar relacionada con *muchas* instancias de otro modelo, y viceversa.
#
# **Ejemplos:**
# *   Un `Post` puede tener muchos `Tag`s. Un `Tag` puede aplicarse a muchos `Post`s.
# *   Un `Estudiante` puede inscribirse en muchos `Curso`s. Un `Curso` puede tener muchos `Estudiante`s.
# *   Un `Producto` puede estar en varias `Promocion`es. Una `Promocion` puede aplicar a varios `Producto`s.
#
# **Implementación:** Se usa `models.ManyToManyField()` en **uno** de los dos modelos relacionados (generalmente en el que parezca más lógico definirlo).
#
# ```python
# # blog/models.py (ejemplo)
# from django.db import models
#
# class Tag(models.Model):
#     nombre = models.CharField(max_length=50, unique=True)
#     def __str__(self): return self.nombre
#
# class Post(models.Model):
#     titulo = models.CharField(max_length=200)
#     # ... otros campos ...
#     # Relación Muchos a Muchos con Tag
#     tags = models.ManyToManyField(
#         Tag,
#         related_name='posts', # Acceso inverso: tag.posts.all()
#         blank=True            # Permitir que no tenga tags
#     )
#     def __str__(self): return self.titulo
# ```
#
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
# #### 10_2_1_Tabla_Intermedia_Automatica
#
# Django maneja las relaciones ManyToMany creando automáticamente una **tabla intermedia** en la base de datos. Esta tabla tendrá (al menos) tres columnas: una `id` propia, una `ForeignKey` al primer modelo (ej: `post_id`) y una `ForeignKey` al segundo modelo (ej: `tag_id`). Cada fila en esta tabla representa una conexión entre un Post y un Tag.
#
# Normalmente, no necesitas interactuar directamente con esta tabla intermedia; el ORM de Django gestiona las adiciones (`.add()`), eliminaciones (`.remove()`, `.clear()`) y consultas (`.all()`, `.filter()`) a través del manager del campo ManyToMany (ej: `post.tags`).
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# #### 10_2_2_Argumento_through_Modelos_Intermedios
#
# A veces, necesitas almacenar **información adicional sobre la relación misma**. Por ejemplo, en una relación entre `Estudiante` y `Curso`, podrías querer guardar la fecha de inscripción o la nota del estudiante *en ese curso específico*. La tabla intermedia automática no permite esto.
#
# En estos casos, puedes crear **manualmente** un **modelo intermedio** y usar el argumento `through` en el `ManyToManyField` para indicarle a Django que use tu modelo personalizado en lugar de crear uno automáticamente.
#
# ```python
# # ejemplo/models.py
# from django.db import models
#
# class Estudiante(models.Model):
#     nombre = models.CharField(max_length=100)
#     cursos = models.ManyToManyField(
#         'Curso', # Puede ser string si Curso se define después
#         through='Inscripcion', # Especifica el modelo intermedio
#         related_name='estudiantes'
#     )
#     def __str__(self): return self.nombre
#
# class Curso(models.Model):
#     nombre = models.CharField(max_length=100)
#     def __str__(self): return self.nombre
#
# # Modelo intermedio personalizado
# class Inscripcion(models.Model):
#     estudiante = models.ForeignKey(Estudiante, on_delete=models.CASCADE)
#     curso = models.ForeignKey(Curso, on_delete=models.CASCADE)
#     fecha_inscripcion = models.DateField(auto_now_add=True)
#     nota = models.FloatField(null=True, blank=True)
#
#     class Meta:
#         unique_together = [['estudiante', 'curso']] # Un estudiante solo se inscribe una vez por curso
#         ordering = ['-fecha_inscripcion']
#
#     def __str__(self):
#         return f'{self.estudiante} inscrito en {self.curso}'
# ```
# *   El modelo intermedio (`Inscripcion`) **debe** tener exactamente una `ForeignKey` a cada uno de los modelos relacionados (`Estudiante`, `Curso`). Pueden ser más si el ManyToMany usa `through_fields`.
# *   Puedes añadir cualquier campo adicional que necesites (`fecha_inscripcion`, `nota`).
# *   Al usar `through`, algunas operaciones directas del manager ManyToMany (`.add()`, `.remove()`, `.set()`) se **deshabilitan**. Debes crear/eliminar instancias del modelo intermedio (`Inscripcion`) directamente. Sin embargo, las consultas inversas (`estudiante.cursos.all()`, `curso.estudiantes.all()`) siguen funcionando.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 10_3_Relaciones_Uno_a_Uno_OneToOneField
#
# Garantiza que una instancia de un modelo solo puede estar relacionada con **una única** instancia de otro modelo, y viceversa. Conceptualmente, es como una `ForeignKey` con `unique=True`, pero la relación inversa devuelve el objeto directamente (no un manager `_set`).
#
# **Usos Comunes:**
# *   **Extender el Modelo `User`:** Crear un modelo `Perfil` con campos adicionales, vinculado uno a uno con el `User` de Django.
# *   Representar una relación donde algo solo puede tener *una* instancia de otra cosa (ej: un `Coche` tiene un solo `Motor`, un `Pais` tiene una sola `Capital`).
#
# **Implementación:** Se usa `models.OneToOneField()` en uno de los modelos.
#
# ```python
# # ejemplo/models.py
# from django.db import models
# from django.conf import settings
# User = settings.AUTH_USER_MODEL
#
# class Perfil(models.Model):
#     # Vincula este perfil a un único usuario.
#     # Si se borra el User, se borra el Perfil.
#     # Usar el campo user como PK es común y eficiente.
#     user = models.OneToOneField(User, on_delete=models.CASCADE, primary_key=True)
#     bio = models.TextField(blank=True)
#     ciudad = models.CharField(max_length=100, blank=True)
#
#     def __str__(self):
#         return f'Perfil de {self.user.username}'
#
# # --- Acceso ---
# # user = User.objects.get(pk=1)
# # perfil = Perfil.objects.get(user=user) # O Perfil.objects.get(pk=user.pk) si user es PK
#
# # Acceso inverso (Django lo crea automáticamente):
# # perfil_de_user = user.perfil # (Nombre del modelo en minúscula)
# # usuario_de_perfil = perfil.user
# ```
# *   `on_delete` es obligatorio.
# *   `primary_key=True` es opcional pero común si el modelo "extiende" a otro, usando la PK del modelo principal como propia.
# *   `related_name` también se puede usar para personalizar el acceso inverso (ej: `related_name='mi_perfil'` permitiría `user.mi_perfil`).
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 10_4_Consultas_a_traves_de_Relaciones_Doble_Guion_Bajo
#
# El ORM de Django permite realizar consultas que "cruzan" las relaciones definidas entre modelos usando la notación de doble guion bajo (`__`) para acceder a campos de modelos relacionados. Esto genera consul
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)[Volver a la Tabla de Contenido](#Tabla_de_Contenido)tas SQL con `JOIN`s de forma automática y eficiente.
#
# #### 10_4_1_Consultas_Directas_ForeignKey_OneToOne
#
# Desde el modelo que tiene el campo `ForeignKey` o `OneToOneField`, puedes filtrar o referenciar campos del modelo relacionado usando `nombre_del_campo_relacion__campo_relacionado`.
#
# ```python
# # Obtener todos los Productos de la categoría con slug 'electronica'
# productos_electronica = Producto.objects.filter(categoria__slug='electronica')
#
# # Obtener todos los Productos creados por el usuario 'admin'
# productos_admin = Producto.objects.filter(creado_por__username='admin')
#
# # Obtener el Perfil cuyo usuario tiene el email 'test@example.com'
# perfil_test = Perfil.objects.filter(user__email='test@example
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)[Volver a la Tabla de Contenido](#Tabla_de_Contenido)[Volver a la Tabla de Contenido](#Tabla_de_Contenido)[Volver a la Tabla de Contenido](#Tabla_de_Contenido)[Volver a la Tabla de Contenido](#Tabla_de_Contenido)[Volver a la Tabla de Contenido](#Tabla_de_Contenido)[Volver a la Tabla de Contenido](#Tabla_de_Contenido)[Volver a la Tabla de Contenido](#Tabla_de_Contenido).com')
#
# # Ordenar Productos por el nombre de su categoría, luego por precio
# productos_ordenados = Producto.objects.order_by('categoria__nombre', 'precio')
# ```
#
# #### 10_4_2_Consultas_Inversas_related_name_o_modelo_set
#
# Desde el modelo del lado "uno", puedes filtrar basándote en las propiedades de los objetos relacionados del lado "muchos" usando el `related_name` definido (o el `nombremodelo_set` por defecto) seguido de `__`.
#
# ```python
# # Obtener todas las Categorías que tienen al menos un producto con stock > 0
# categorias_con_stock = Categoria.objects.filter(productos__stock__gt=0).distinct()
# # .distinct() es necesario para evitar categorías duplicadas si tienen varios productos con stock
#
# # Obtener todos los Users que han creado algún Producto llamado 'Laptop Pro X'
# autores_laptop = User.objects.filter(productos_creados__nombre='Laptop Pro X')
#
# # Obtener todas las Categorías que NO
# tienen ningún producto asociado
# categorias_vacias = Categoria.objects.filter(productos__isnull=True)
# ```
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
# #### 10_4_3_Consultas_ManyToMany
#
# Las consultas a través de relaciones `ManyToManyField` funcionan de manera similar a las inversas de `ForeignKey`, usando el nombre del campo ManyToMany o su `related_name`.
#
# ```python
# # Obtener todos los Posts que tienen el Tag con slug 'python'
# posts_python = Post.objects.filter(tags__slug='python')
#
# # Obtener todos los Tags asociados a Posts publicados
# tags_posts_publicados = Tag.objects.filter(posts__publicado=True).distinct()
#
# # Obtener Posts que tienen la categoría 'Tecnologia' Y el tag 'Django'
# posts_tec_django = Post.objects.filter(categorias__slug='tecnologia').filter(tags__slug='django')
# ```
# Dominar las consultas a través de relaciones es clave para aprovechar la potencia del ORM de Django.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 10_5_Ejercicio_Practico_Definir_y_Consultar_Relaciones
#
# **Objetivo:** Añadir un modelo `Comentario` relacionado con `Producto` y practicar consultas a través de relaciones usando el shell.
#
# **Pasos:**
#
# 1.  **Modifica `productos/models.py`:**
#     *   Añade un nuevo modelo `Comentario`.
#     *   Debe tener un campo `producto` (`ForeignKey` a `Producto`, `on_delete=models.CASCADE`, `related_name='comentarios'`).
#     *   Debe tener un campo `autor` (`CharField`, `max_length=100`).
#     *   Debe tener un campo `texto` (`TextField`).
#     *   Debe tener un campo `fecha_creacion` (`DateTimeField`, `auto_now_add=True`).
#     *   Define un método `__str__` apropiado.
# 2.  **Crea la migración:**
#     ```bash
#     python manage.py makemigrations productos
#     ```
# 3.  **Aplica la migración:**
#     ```bash
#     python manage.py migrate
#     ```
# 4.  **Abre el shell:**
#     ```bash
#     python manage.py shell
#     ```
# 5.  **Importa modelos:**
#     ```python
#     from productos.models import Producto, Categoria, Comentario
#     ```
# 6.  **Realiza las siguientes consultas:**
#     *   Obtén el primer producto (o uno que sepas que existe).
#     *   Crea dos o tres comentarios para ese producto.
#     *   Obtén todos los comentarios para ese producto usando la relación inversa (`producto.comentarios.all()`).
#     *   Obtén todos los productos que tengan al menos un comentario.
#     *   Obtén todos los productos de la categoría "Tecnología" que tengan comentarios.
#     *   Obtén todos los comentarios cuyo autor sea "Ana".
#     *   Obtén todos los productos que tengan comentarios del autor "Ana".
#
# **Solución Propuesta:**
#
# **`productos/models.py` (añadir Comentario):**
# ```python
# # ... (Categoria y Producto definidos antes) ...
#
# class Comentario(models.Model):
#     producto = models.ForeignKey(
#         Producto,
#         on_delete=models.CASCADE,
#         related_name='comentarios'
#     )
#     autor = models.CharField(max_length=100)
#     texto = models.TextField()
#     fecha_creacion = models.DateTimeField(auto_now_add=True)
#
#     class Meta:
#         ordering = ['-fecha_creacion']
#         verbose_name = "Comentario"
#         verbose_name_plural = "Comentarios"
#
#     def __str__(self):
#         # Trunca el texto para el __str__ si es muy largo
#         texto_corto = (self.texto[:75] + '...') if len(self.texto) > 75 else self.texto
#         return f'Comentario de {self.autor} en "{self.producto.nombre}": "{texto_corto}"'
# ```
#
# **En el Shell:**
# ```python
# from productos.models import Producto, Categoria, Comentario
# from decimal import Decimal
#
# # Crear categoría y producto si no existen del ejercicio anterior
# cat_tec, _ = Categoria.objects.get_or_create(nombre="Tecnologia", slug="tecnologia")
# prod1, _ = Producto.objects.get_or_create(
#     slug="raton-inalambrico",
#     defaults={
#         'nombre': "Raton Inalambrico",
#         'precio': Decimal("25.00"),
#         'stock': 50,
#         'categoria': cat_tec
#     }
# )
# prod2, _ = Producto.objects.get_or_create(
#     slug="cafetera-express",
#     defaults={
#         'nombre': "Cafetera Express",
#         'precio': Decimal("89.90"),
#         'stock': 30,
#         'disponible': True # Asumiendo que se actualizó
#     }
# )
#
#
# # Obtener primer producto
# # producto_base = Producto.objects.first()
# producto_base = prod1 # Usemos el ratón
# print(f"\nProducto base: {producto_base}")
#
# # Crear comentarios
# c1 = Comentario.objects.create(producto=producto_base, autor="Ana", texto="¡Me encanta este ratón, muy cómodo!")
# c2 = Comentario.objects.create(producto=producto_base, autor="Luis", texto="La batería dura bastante.")
# c3 = Comentario.objects.create(producto=prod2, autor="Ana", texto="Hace un café excelente.") # Comentario en otro producto
# print("\nComentarios creados.")
#
# # Obtener comentarios del producto base
# comentarios_prod_base = producto_base.comentarios.all()
# print(f"\nComentarios para '{producto_base.nombre}':")
# for c in comentarios_prod_base:
#     print(f"- {c.autor}: {c.texto}")
#
# # Productos con al menos un comentario
# prods_con_comentarios = Producto.objects.filter(comentarios__isnull=False).distinct()
# # OJO: filter(comentarios__isnull=False) funciona bien. distinct() es por si acaso.
# print("\nProductos con comentarios:")
# for p in prods_con_comentarios:
#     print(f"- {p.nombre}")
#
# # Productos de Tecnología con comentarios
# prods_tec_con_comentarios = Producto.objects.filter(categoria__slug='tecnologia', comentarios__isnull=False).distinct()
# print("\nProductos de Tecnología con comentarios:")
# for p in prods_tec_con_comentarios:
#     print(f"- {p.nombre}")
#
# # Comentarios de Ana
# comentarios_ana = Comentario.objects.filter(autor="Ana")
# print("\nComentarios de Ana:")
# for c in comentarios_ana:
#     print(f"- En '{c.producto.nombre}': {c.texto}")
#
# # Productos con comentarios de Ana
# prods_con_comentarios_ana = Producto.objects.filter(comentarios__autor="Ana").distinct()
# print("\nProductos con comentarios de Ana:")
# for p in prods_con_comentarios_ana:
#     print(f"- {p.nombre}")
#
# exit()
# ```
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ## 11_El_Shell_de_Django_manage_py_shell
#
# El shell interactivo de Django es una herramienta indispensable para el desarrollo y la depuración. Te permite ejecutar código Python dentro del contexto de tu proyecto Django, con acceso a tus modelos, configuraciones y el API de Django.
#
# **Cómo lanzarlo:**
# ```bash
# python manage.py shell
# ```
#
# **Ventajas:**
# *   **Entorno Configurado:** Carga automáticamente la configuración de tu proyecto (`settings.py`), por lo que puedes importar tus modelos (`from mi_app.models import MiModelo`) y usar el ORM directamente.
# *   **Pruebas Rápidas:** Ideal para probar consultas del ORM (`MiModelo.objects.filter(...)`) antes de escribirlas en tus vistas.
# *   **Manipulación de Datos:** Puedes crear, modificar o eliminar objetos de la base de datos interactivamente.
# *   **Depuración:** Ejecutar fragmentos de código o llamar a funciones para ver cómo se comportan o qué devuelven.
# *   **Experimentación:** Probar APIs de Django o librerías de terceros en el contexto de tu proyecto.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 11_1_Uso_para_Probar_Consultas_y_Modelos
#
# El caso de uso más frecuente es experimentar con el ORM:
#
# ```python
# >>> from productos.models import Producto, Categoria
# >>> # ¿Cuántos productos hay?
# >>> Producto.objects.count()
# 2
# >>> # Obtener categoría 'Tecnologia'
# >>> tec = Categoria.objects.get(slug='tecnologia')
# >>> # Productos de esa categoría
# >>> prods_tec = Producto.objects.filter(categoria=tec)
# >>> prods_tec
# <QuerySet [<Producto: Raton Inalambrico>]>
# >>> # Crear un producto nuevo (ejemplo rápido)
# >>> Producto.objects.create(nombre="Nuevo Gadget", slug="nuevo-gadget", precio=Decimal("19.99"), categoria=tec)
# <Producto: Nuevo Gadget>
# >>> # Verificar consulta compleja
# >>> from django.db.models import Q
# >>> resultado = Producto.objects.filter(Q(stock__lt=50) | Q(disponible=False))
# >>> resultado
# <QuerySet [<Producto: Raton Inalambrico>, <Producto: Cafetera Express>]> # (Asumiendo datos de ejercicios previos)
# ```
# Puedes probar toda la funcionalidad del ORM cubierta en la Sección 9 directamente en el shell.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 11_2_Shell_Plus_django_extensions
#
# La librería de terceros `django-extensions` proporciona un comando `shell_plus` que mejora enormemente la experiencia del shell estándar.
#
# **Características de `shell_plus`:**
# *   **Auto-importación:** Importa automáticamente todos tus modelos, el modelo User y otras utilidades comunes de Django al iniciar el shell, ahorrándote escribir los imports repetidamente.
# *   **Mejor Intérprete:** Usa automáticamente intérpretes mejorados como IPython o bpython si están instalados, proporcionando autocompletado, resaltado de sintaxis, historial mejorado, etc.
#
# **Instalación:**
# 1.  `pip install django-extensions ipython` (IPython es opcional pero recomendado)
# 2.  Añade `'django_extensions'` a tu `INSTALLED_APPS` en `settings.py`.
# 3.  Ejecuta:
#     ```bash
#     python manage.py shell_plus
#     ```
#
# Verás que al iniciar, `shell_plus` imprime una lista de todo lo que ha importado automáticamente. Ahora puedes usar `Producto`, `Categoria`, `User`, etc., directamente sin necesidad de `from productos.models import ...`.
#
# ```python
# # (Usando shell_plus)
# >>> Producto.objects.count() # Producto ya está importado
# 2
# >>> mi_prod = Producto.objects.get(pk=1) # Asumiendo que existe
# >>> mi_prod.nombre
# 'Raton Inalambrico'
# ```
# `shell_plus` es altamente recomendado para mejorar la productividad al trabajar con el shell de Django.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ---
# ---
#
# ## **Unidad 4: La Interfaz de Administración de Django**
#
# ## 12_Introduccion_al_Admin_de_Django
#
# Una de las características más aclamadas y productivas de Django es su **interfaz de administración automática**. Es una aplicación web incorporada (`django.contrib.admin`) que lee los metadatos de los modelos de tu aplicación (definidos en `models.py`) y genera una interfaz de usuario completa y lista para usar, permitiendo a los administradores del sitio gestionar el contenido de la base de datos de forma visual e intuitiva.
#
# **Características Principales:**
# *   **Generación Automática:** Crea automáticamente interfaces CRUD (Crear, Leer, Actualizar, Eliminar) para los modelos que registres.
# *   **Interfaz Web:** Proporciona páginas de lista con filtros, búsqueda y paginación, así como formularios detallados para la edición de objetos individuales.
# *   **Basada en Modelos:** La interfaz se adapta a los tipos de campo, relaciones y opciones definidas en tus modelos.
# *   **Segura:** Utiliza el sistema de autenticación y permisos de Django para controlar quién puede acceder y qué acciones puede realizar cada usuario administrador.
# *   **Altamente Personalizable:** Aunque es funcional por defecto, ofrece numerosas opciones para personalizar la apariencia, el comportamiento y las funcionalidades.
# *   **Introspección:** Examina tus modelos para determinar cómo presentar los datos y los formularios.
#
# **Propósito Principal:**
# El admin de Django está diseñado principalmente como una herramienta **interna** para administradores de contenido, editores o desarrolladores del sitio. **No está pensado como un panel de control para los usuarios finales** de tu aplicación pública. Para eso, normalmente construirás tus propias vistas y plantillas. Sin embargo, para gestionar los datos *detrás de escena*, es increíblemente eficiente.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ## 13_Activando_el_Admin
#
# Para utilizar la interfaz de administración, necesitas realizar unos pocos pasos de configuración inicial (muchos de los cuales ya vienen preconfigurados al crear un proyecto con `startproject`):
#
# 1.  **Verificar `INSTALLED_APPS`:** Asegúrate de que `'django.contrib.admin'` esté presente en la lista `INSTALLED_APPS` dentro de tu archivo `settings.py` (ej: `mi_sitio/settings.py`). También son necesarias sus dependencias como `'django.contrib.auth'`, `'django.contrib.contenttypes'`, `'django.contrib.sessions'`, `'django.contrib.messages'`.
#     ```python
#     # mi_sitio/settings.py
#     INSTALLED_APPS = [
#         'django.contrib.admin', # Necesario
#         'django.contrib.auth',
#         'django.contrib.contenttypes',
#         'django.contrib.sessions',
#         'django.contrib.messages',
#         'django.contrib.staticfiles',
#         'productos', # Tu app
#         # ...
#     ]
#     ```
# 2.  **Configurar URL:** Asegúrate de tener una ruta en tu `urls.py` principal del proyecto que apunte a `admin.site.urls`. Por convención, esta ruta suele ser `admin/`.
#     ```python
#     # mi_sitio/urls.py
#     from django.contrib import admin
#     from django.urls import path, include
#
#     urlpatterns = [
#         path('admin/', admin.site.urls), # Esta línea activa el admin
#         path('productos/', include('productos.urls')),
#         # ...
#     ]
#     ```
# 3.  **Aplicar Migraciones:** El admin y sus dependencias (como `auth`) necesitan tablas en la base de datos. Si no lo has hecho ya, ejecuta las migraciones.
#     ```bash
#     python manage.py migrate
#     ```
#     Esto creará las tablas necesarias para `admin`, `auth`, `contenttypes`, `sessions`, etc.
#
# Una vez completados estos pasos, la estructura básica del admin estará lista, pero aún necesitas una cuenta para acceder.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ## 14_Creando_un_Superusuario_createsuperuser
#
# Para poder iniciar sesión en la interfaz `/admin/`, necesitas un usuario que tenga privilegios de administrador. Django distingue entre usuarios normales, *staff* (pueden acceder al admin) y *superusuarios* (tienen todos los permisos sin necesidad de asignárselos explícitamente).
#
# Para crear un superusuario, utiliza el comando `manage.py createsuperuser`:
#
# 1.  Asegúrate de que tu entorno virtual esté activo.
# 2.  Navega al directorio raíz de tu proyecto (donde está `manage.py`).
# 3.  Ejecuta el comando:
#     ```bash
#     python manage.py createsuperuser
#     ```
# 4.  **Sigue las instrucciones:** Django te pedirá:
#     *   **Username:** Introduce el nombre de usuario para el administrador (ej: `admin`). Si lo dejas en blanco, usará el nombre de usuario de tu sistema.
#     *   **Email address:** Introduce una dirección de correo electrónico.
#     *   **Password:** Introduce una contraseña segura. Por seguridad, no verás los caracteres mientras escribes.
#     *   **Password (again):** Confirma la contraseña.
#     Django validará la contraseña. Si es demasiado común o insegura, te advertirá, pero te permitirá continuar si insistes.
#
#     ```
#     Username (leave blank to use 'tu_usuario_sistema'): admin
#     Email address: admin@ejemplo.com
#     Password:
#     Password (again):
#     Superuser created successfully.
#     ```
#
# Ahora tienes un usuario que puede iniciar sesión en `/admin/`. Inicia el servidor de desarrollo (`python manage.py runserver`) y visita `http://127.0.0.1:8000/admin/`. Introduce el nombre de usuario y contraseña que acabas de crear.
#
# Al entrar, verás la interfaz principal del admin. Inicialmente, solo mostrará los modelos incorporados que vienen con Django, como "Groups" y "Users" de la aplicación `auth`. Tus propios modelos (como `Producto` y `Categoria`) no aparecerán todavía.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ## 15_Registrando_Modelos_admin_py_admin_site_register
#
# Para que tus modelos (`Producto`, `Categoria`, etc.) sean visibles y gestionables a través de la interfaz de administración, debes **registrarlos** explícitamente. Esta registración se hace en el archivo `admin.py` dentro de cada aplicación cuyos modelos quieras exponer.
#
# 1.  **Abre el archivo `admin.py`** de tu aplicación (ej: `productos/admin.py`). Si no existe, créalo.
# 2.  **Importa** el módulo `admin` de `django.contrib` y los modelos que quieres registrar desde `.models`.
# 3.  **Usa `admin.site.register()`** para cada modelo.
#
# **Ejemplo (`productos/admin.py`):**
# ```python
# # productos/admin.py
# from django.contrib import admin
# from .models import Producto, Categoria # Importa tus modelos
#
# # Registro simple: le dice a Django que cree una interfaz por defecto para estos modelos
# admin.site.register(Producto)
# admin.site.register(Categoria)
#
# # También podrías registrar una lista de modelos:
# # admin.site.register([Producto, Categoria])
# ```
#
# **Importante:** Después de guardar cambios en `admin.py`, **detén y reinicia el servidor de desarrollo** (`CTRL+C` y luego `python manage.py runserver`) para que Django reconozca los cambios en el registro del admin.
#
# Ahora, si accedes a `/admin/` de nuevo, verás una nueva sección correspondiente a tu aplicación (`PRODUCTOS` en este caso, basado en el nombre de la app o su `verbose_name` en `apps.py`) y dentro de ella, enlaces para gestionar "Productos" y "Categorías" (o los `verbose_name_plural` que definiste en la `Meta` de tus modelos).
#
# Puedes hacer clic en ellos para ver una lista de objetos existentes (si los hay) y usar los botones "Add..." para crear nuevas instancias a través de formularios generados automáticamente.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ## 16_Personalizacion_Basica_ModelAdmin
#
# La registración simple (`admin.site.register(Modelo)`) funciona, pero la interfaz por defecto es muy básica. Para personalizar cómo se muestra y se interactúa con un modelo en el admin, creas una clase que herede de `admin.ModelAdmin` y la pasas como segundo argumento a `admin.site.register()`, o usas el decorador `@admin.register()`.
#
# Esta clase `ModelAdmin` te permite configurar muchas opciones para las páginas de **lista (changelist)** y de **edición/creación (changeform)** de tus modelos.
#
# **Ejemplo (`productos/admin.py` con personalización):**
# ```python
# # productos/admin.py
# from django.contrib import admin
# from .models import Producto, Categoria
#
# # --- Personalización para Categoria ---
# @admin.register(Categoria) # Usando decorador (forma moderna)
# class CategoriaAdmin(admin.ModelAdmin):
#     list_display = ('nombre', 'slug') # Columnas a mostrar en la lista de categorías
#     search_fields = ('nombre',)      # Habilitar búsqueda por nombre
#     # Autocompletar 'slug' basado en 'nombre' en el formulario
#     prepopulated_fields = {'slug': ('nombre',)}
#
# # --- Personalización para Producto ---
# # @admin.register(Producto) # Alternativa al registro de abajo
# class ProductoAdmin(admin.ModelAdmin):
#     # Opciones para la página de LISTA (changelist)
#     list_display = ('nombre', 'categoria', 'precio', 'stock', 'disponible', 'fecha_creacion') # Columnas
#     list_filter = ('disponible', 'categoria', 'fecha_creacion') # Filtros en sidebar
#     search_fields = ('nombre', 'descripcion', 'slug') # Campos de búsqueda
#     list_editable = ('precio', 'stock', 'disponible') # Campos editables en la lista
#     list_per_page = 25 # Items por página
#
#     # Opciones para la página de EDICIÓN/CREACIÓN (changeform)
#     # Controla qué campos y en qué orden aparecen en el formulario
#     # fields = ('categoria', 'nombre', 'slug', 'precio', 'stock', 'disponible', 'descripcion', 'imagen') # O usar fieldsets
#     fieldsets = ( # Organizar en secciones
#         (None, { # Sección sin título
#             'fields': ('nombre', 'slug', 'categoria')
#         }),
#         ('Detalles del Producto', {
#             'fields': ('descripcion', 'precio', 'stock', 'disponible', 'imagen')
#         }),
#         # ('Información Adicional', { # Ejemplo de sección colapsada
#         #    'fields': ('fecha_creacion', 'fecha_actualizacion'),
#         #    'classes': ('collapse',), # Añade clase CSS para colapsar
#         #    'description': "Metadatos del producto."
#         # }),
#     )
#     readonly_fields = ('fecha_creacion', 'fecha_actualizacion') # Campos no editables
#     prepopulated_fields = {'slug': ('nombre',)} # Autocompletar slug
#     # raw_id_fields = ('categoria',) # Útil si hay muchas categorías (muestra input con lupa)
#
# # Registrar Producto con su ModelAdmin (forma clásica)
# admin.site.register(Producto, ProductoAdmin)
#
# # Categoria ya está registrada con el decorador @admin.register(Categoria)
# # admin.site.register(Categoria, CategoriaAdmin) # No es necesario si se usó decorador
# ```
#
# **Reinicia el servidor** y explora las páginas de lista y edición de Categorías y Productos en `/admin/` para ver los efectos de estas personalizaciones.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 16_1_list_display
#
# Una tupla o lista de strings que especifica qué **columnas** mostrar en la página de **lista** (changelist) de objetos.
# *   Cada string puede ser el nombre de un campo del modelo.
# *   Puede ser el nombre de un método del modelo (que no acepte argumentos).
# *   Puede ser el nombre de un método definido en la propia clase `ModelAdmin`.
# *   El primer elemento suele ser el enlace a la página de edición del objeto (a menos que se configure `list_display_links`).
#
# ```python
# # admin.py (dentro de ModelAdmin)
# list_display = ('nombre', 'categoria', 'precio', 'es_caro')
#
# # models.py (dentro del modelo Producto)
# # def es_caro(self):
# #    return self.precio > 100
# # es_caro.boolean = True # Para mostrar icono True/False en admin
# # es_caro.short_description = "Es Caro?" # Título de la columna
# ```
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 16_2_list_filter
#
# Una tupla o lista de campos por los cuales se podrán **filtrar** los resultados en la página de lista. Django genera una barra lateral con las opciones de filtro apropiadas según el tipo de campo.
# *   Campos `BooleanField`: Filtro Sí/No/Todos.
# *   Campos `DateField`/`DateTimeField`: Filtros por rangos de fecha (Hoy, Últimos 7 días, Este mes, Este año).
# *   Campos `ForeignKey`/`ManyToManyField`: Filtro por los objetos relacionados.
# *   Campos `CharField`/`TextField`: No generan filtro por defecto (requiere personalización si se desea).
#
# ```python
# # admin.py (dentro de ModelAdmin)
# list_filter = ('disponible', 'categoria', 'fecha_creacion')
# ```
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 16_3_search_fields
#
# Una tupla o lista de campos en los que buscará el cuadro de búsqueda del admin. Django realiza una búsqueda `icontains` (contiene, insensible a mayúsculas/minúsculas) por defecto.
# *   Solo aplica a campos de texto (`CharField`, `TextField`).
# *   Puedes buscar en campos relacionados usando `__`: `'categoria__nombre'`.
# *   Puedes cambiar el tipo de lookup: `'^nombre'` (empieza con), `'=slug'` (exacto).
#
# ```python
# # admin.py (dentro de ModelAdmin)
# search_fields = ('nombre', 'descripcion', 'slug', 'categoria__nombre')
# ```
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 16_4_date_hierarchy
#
# Especifica el nombre de un campo `DateField` o `DateTimeField`. Django añadirá controles de navegación jerárquica por fecha (Año > Mes > Día) en la parte superior de la página de lista. Solo se puede especificar un campo.
#
# ```python
# # admin.py (dentro de ModelAdmin)
# date_hierarchy = 'fecha_creacion'
# ```
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 16_5_ordering
#
# Una tupla o lista que define el orden por defecto de los objetos en la página de lista del admin. Sobrescribe el `ordering` definido en la `Meta` del modelo, pero solo para el admin. Usa la misma sintaxis (ej: `'-campo'` para descendente).
#
# ```python
# # admin.py (dentro de ModelAdmin)
# ordering = ('nombre',) # Ordenar por nombre ascendente en el admin
# ```
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 16_6_list_editable
#
# Una tupla o lista de nombres de campos que se podrán editar **directamente en la página de lista**, sin necesidad de entrar al formulario de edición de cada objeto.
# *   **Importante:** Cualquier campo listado aquí **debe** estar también en `list_display`.
# *   El **primer** campo en `list_display` **no** puede estar en `list_editable` (porque se usa como enlace a la página de edición).
#
# ```python
# # admin.py (dentro de ModelAdmin)
# list_display = ('nombre', 'precio', 'stock', 'disponible')
# list_editable = ('precio', 'stock', 'disponible') # nombre no puede estar aquí
# ```
# Esto mostrará campos de formulario directamente en la tabla de la lista para `precio`, `stock` y `disponible`, con un botón "Guardar" al final para aplicar los cambios a todos los objetos modificados en esa página. Úsalo con cuidado, especialmente con muchos objetos por página.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 16_7_list_per_page
#
# Un entero que especifica cuántos objetos mostrar por página en la lista del admin. El valor por defecto es 100.
#
# ```python
# # admin.py (dentro de ModelAdmin)
# list_per_page = 50
# ```
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 16_8_prepopulated_fields
#
# Un diccionario que mapea un campo de destino (normalmente un `SlugField`) a una lista o tupla de campos origen (`CharField`, `TextField`). El JavaScript del admin rellenará automáticamente el campo de destino basándose en los valores introducidos en los campos origen, creando una versión "slugificada" (minúsculas, espacios por guiones). Muy útil para generar slugs a partir de títulos.
#
# ```python
# # admin.py (dentro de ModelAdmin)
# prepopulated_fields = {'slug': ('nombre',)} # Rellena 'slug' a partir de 'nombre'
# ```
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 16_9_Ejercicio_Practico_Personalizar_Admin_Basico
#
# **Objetivo:** Aplicar personalizaciones básicas a las interfaces de admin para los modelos `Categoria` y `Producto`.
#
# **Pasos:**
#
# 1.  **Abre `productos/admin.py`**.
# 2.  **Crea la clase `CategoriaAdmin`** (si no la creaste antes o si usaste el registro simple) y regístrala usando el decorador `@admin.register(Categoria)`.
#     *   Define `list_display` para mostrar `nombre` y `slug`.
#     *   Define `search_fields` para buscar por `nombre`.
#     *   Define `prepopulated_fields` para autocompletar `slug` desde `nombre`.
# 3.  **Crea (o modifica) la clase `ProductoAdmin`** y regístrala con `Producto` (con decorador o `admin.site.register`).
#     *   Define `list_display` para mostrar `nombre`, `categoria`, `precio`, `stock`, `disponible`.
#     *   Define `list_filter` para filtrar por `disponible` y `categoria`.
#     *   Define `search_fields` para buscar por `nombre` y `descripcion`.
#     *   Define `list_editable` para poder editar `precio` y `disponible` directamente en la lista. (Recuerda que `nombre` no puede estar aquí si es el primer campo en `list_display`).
#     *   Define `prepopulated_fields` para `slug` desde `nombre`.
# 4.  **Reinicia el servidor de desarrollo.**
# 5.  **Accede al admin** (`/admin/`) y navega a las secciones de Categorías y Productos. Observa las nuevas columnas, filtros, la barra de búsqueda, el autocompletado del slug (al añadir/editar) y los campos editables en la lista de productos.
#
# **Solución Propuesta (`productos/admin.py`):**
# ```python
# from django.contrib import admin
# from .models import Producto, Categoria
#
# @admin.register(Categoria)
# class CategoriaAdmin(admin.ModelAdmin):
#     list_display = ('nombre', 'slug')
#     search_fields = ('nombre',)
#     prepopulated_fields = {'slug': ('nombre',)}
#
# @admin.register(Producto)
# class ProductoAdmin(admin.ModelAdmin):
#     list_display = ('nombre', 'categoria', 'precio', 'stock', 'disponible')
#     list_filter = ('disponible', 'categoria')
#     search_fields = ('nombre', 'descripcion')
#     list_editable = ('precio', 'disponible') # 'stock' también podría ir aquí
#     prepopulated_fields = {'slug': ('nombre',)}
#     list_per_page = 20 # Opcional
# ```
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ## 17_Personalizacion_Avanzada_del_Formulario_Admin
#
# Además de la página de lista, puedes personalizar en detalle cómo se presenta y organiza el **formulario de creación y edición** de objetos en el admin.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 17_1_fields_y_exclude
#
# Estas opciones controlan qué campos se muestran en el formulario y en qué orden.
#
# *   **`fields`:** Una tupla o lista de nombres de campos. **Solo** los campos listados aquí aparecerán en el formulario, y lo harán en el orden especificado. Es útil para reordenar u ocultar campos simples. **No se puede usar junto con `fieldsets`.**
#     ```python
#     # admin.py (dentro de ProductoAdmin)
#     # Mostrar solo estos campos y en este orden:
#     # fields = ('nombre', 'slug', 'categoria', 'precio', 'stock', 'disponible')
#     ```
# *   **`exclude`:** Una tupla o lista de nombres de campos que **no** quieres que aparezcan en el formulario. Todos los demás campos del modelo se mostrarán en su orden predeterminado. Es útil para ocultar campos gestionados automáticamente o que no deben ser editados por el admin.
#     ```python
#     # admin.py (dentro de ProductoAdmin)
#     # Ocultar estos campos (si no fueran readonly ya)
#     # exclude = ('fecha_creacion', 'fecha_actualizacion')
#     ```
#     Generalmente, se usa `fields` o `fieldsets`, pero no ambos. `exclude` se puede combinar con cualquiera de ellos (o usarse solo).
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 17_2_fieldsets
#
# Proporciona un control mucho más granular sobre la organización del formulario, permitiendo agrupar campos en **secciones** con títulos opcionales, descripciones y clases CSS para estilizado. Reemplaza la opción `fields`.
#
# Es una **lista o tupla de tuplas**. Cada tupla interna representa un fieldset y tiene la siguiente estructura:
# `( 'Título del Fieldset | None' , { 'fields': ('campo1', 'campo2', ...), 'classes': ('clase1', ...), 'description': 'Texto...' } )`
#
# *   **Primer elemento:** El título del fieldset (string) o `None` para una sección sin título visible.
# *   **Segundo elemento:** Un diccionario con opciones para ese fieldset:
#     *   `'fields'`: Tupla/lista de campos a incluir en esta sección, en orden.
#     *   `'classes'` (Opcional): Tupla/lista de clases CSS para aplicar al fieldset (ej: `'collapse'` para que empiece cerrado, `'wide'` para más ancho).
#     *   `'description'` (Opcional): Un texto descriptivo que aparece debajo del título del fieldset.
#
# ```python
# # admin.py (dentro de ProductoAdmin)
# fieldsets = (
#     # Primer fieldset (sin título)
#     (None, {
#         'fields': ('nombre', 'slug', 'categoria') # Campos principales
#     }),
#     # Segundo fieldset (con título y colapsado)
#     ('Descripción y Disponibilidad', {
#         'fields': ('descripcion', 'disponible', 'imagen'),
#         'classes': ('collapse',), # Empieza colapsado
#         'description': 'Añade una descripción detallada y gestiona la disponibilidad.'
#     }),
#     # Tercer fieldset (para precios y stock)
#     ('Precio y Stock', {
#         'fields': ('precio', 'stock')
#     }),
#     # Cuarto fieldset (campos no editables)
#     ('Metadatos', {
#         'fields': ('fecha_creacion', 'fecha_actualizacion'),
#         'classes': ('collapse',)
#     }),
# )
# # Asegúrate de que 'readonly_fields' incluya 'fecha_creacion', 'fecha_actualizacion'
# readonly_fields = ('fecha_creacion', 'fecha_actualizacion')
# ```
# `fieldsets` es la forma preferida de organizar formularios de admin complejos.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 17_3_readonly_fields
#
# Una tupla o lista de campos que se mostrarán en el formulario de edición/creación, pero **no serán editables** (se mostrarán como texto simple).
# *   Útil para mostrar información generada automáticamente (`fecha_creacion`, `id`), campos calculados, o campos que solo deben modificarse mediante acciones específicas.
# *   También puedes incluir nombres de métodos del modelo o del `ModelAdmin` para mostrar información calculada.
#
# ```python
# # admin.py (dentro de ProductoAdmin)
# list_display = ('nombre', 'categoria', 'precio', 'stock', 'disponible', 'fecha_creacion')
# # ...
# readonly_fields = ('fecha_creacion', 'fecha_actualizacion', 'mostrar_url_imagen') # Incluye fechas y un método
#
# # Asegúrate de que estos campos estén en 'fields' o 'fieldsets' si los usas,
# # de lo contrario no se mostrarán.
# fieldsets = (
#     (None, {'fields': ('nombre', 'slug', 'categoria')}),
#     # ... otros fieldsets ...
#     ('Metadatos', {
#         'fields': ('fecha_creacion', 'fecha_actualizacion', 'mostrar_url_imagen'), # Añadido el método
#         'classes': ('collapse',)
#     }),
# )
#
# # Método en ProductoAdmin para mostrar algo calculado
# def mostrar_url_imagen(self, obj):
#     from django.utils.html import format_html
#     if obj.imagen:
#         return format_html('<a href="{0}" target="_blank">{0}</a>', obj.imagen.url)
#     return "(Sin imagen)"
# mostrar_url_imagen.short_description = "URL de Imagen" # Título para el campo readonly
# ```
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 17_4_raw_id_fields
#
# Para campos de relación (`ForeignKey`, `ManyToManyField`) que pueden tener *muchos* objetos relacionados (ej: seleccionar un `User` entre miles), mostrar un desplegable `<select>` es inviable y muy lento. `raw_id_fields` soluciona esto.
#
# Es una tupla o lista de nombres de campos de relación. Para estos campos, el admin mostrará:
# *   Un campo de texto simple donde se muestra (o se puede introducir) el ID del objeto relacionado.
# *   Un icono de lupa (`🔍`) al lado. Al hacer clic, se abre una ventana emergente (popup) con la lista del admin para el modelo relacionado, permitiendo buscar y seleccionar el objeto deseado. El ID seleccionado se rellena automáticamente en el campo de texto.
#
# ```python
# # admin.py (dentro de ProductoAdmin)
# # Asumiendo que 'categoria' y 'creado_por' (ForeignKey a User) pueden tener muchos elementos
# raw_id_fields = ('categoria', 'creado_por')
# ```
# Esto mejora drásticamente el rendimiento y la usabilidad del admin cuando se trabaja con relaciones a modelos con muchos registros.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 17_5_Clases_Inline_TabularInline_StackedInline
#
# Permiten editar objetos relacionados (a través de `ForeignKey` o `ManyToManyField` usando `through`) **directamente en la misma página** del objeto principal. Por ejemplo, editar los `Comentario`s de un `Producto` mientras editas el `Producto`.
#
# 1.  **Define una clase Inline:** Crea una clase que herede de:
#     *   `admin.TabularInline`: Muestra los objetos relacionados en un formato de tabla compacto. Ideal para relaciones con pocos campos.
#     *   `admin.StackedInline`: Muestra cada objeto relacionado en su propio bloque de formulario, apilados verticalmente. Mejor si el modelo relacionado tiene muchos campos.
# 2.  **Configura la clase Inline:**
#     *   `model`: El modelo relacionado que quieres editar inline (ej: `Comentario`).
#     *   `fk_name` (Opcional): Si hay más de una ForeignKey al modelo principal, especifica cuál usar.
#     *   `fields`, `readonly_fields`, `fieldsets`, `raw_id_fields`: Puedes usar estas opciones dentro de la clase Inline para personalizar cómo se muestran sus campos.
#     *   `extra` (Entero, defecto 3): Cuántos formularios vacíos mostrar por defecto para añadir nuevos objetos relacionados. Ponlo a `0` o `1` si no quieres tantos.
#     *   `max_num`, `min_num`: Limitar el número máximo o mínimo de formularios inline.
#     *   `verbose_name_plural`: Título para la sección inline.
# 3.  **Añade la clase Inline a la opción `inlines`** del `ModelAdmin` principal. `inlines` es una lista o tupla de las clases Inline a incluir.
#
# **Ejemplo (Editar `Comentario`s en la página de `Producto`):**
# ```python
# # productos/admin.py
# from django.contrib import admin
# from .models import Producto, Categoria, Comentario # Importar Comentario
#
# # --- Inline para Comentarios ---
# class ComentarioInline(admin.TabularInline): # O admin.StackedInline
#     model = Comentario
#     fields = ('autor', 'texto', 'fecha_creacion') # Campos del Comentario a mostrar/editar
#     readonly_fields = ('fecha_creacion',) # Fecha no editable
#     extra = 1 # Mostrar 1 formulario vacío para añadir
#     # raw_id_fields = ('autor_fk',) # Si 'autor' fuera una FK a User con muchos usuarios
#
# @admin.register(Categoria)
# class CategoriaAdmin(admin.ModelAdmin):
#     # ... (configuración de CategoriaAdmin) ...
#     pass
#
# @admin.register(Producto)
# class ProductoAdmin(admin.ModelAdmin):
#     list_display = ('nombre', 'categoria', 'precio', 'stock', 'disponible')
#     list_filter = ('disponible', 'categoria')
#     search_fields = ('nombre', 'descripcion')
#     list_editable = ('precio', 'disponible')
#     prepopulated_fields = {'slug': ('nombre',)}
#     readonly_fields = ('fecha_creacion', 'fecha_actualizacion')
#     fieldsets = (
#         (None, {'fields': ('nombre', 'slug', 'categoria')}),
#         ('Descripción y Disponibilidad', {'fields': ('descripcion', 'disponible', 'imagen')}),
#         ('Precio y Stock', {'fields': ('precio', 'stock')}),
#         ('Metadatos', {'fields': ('fecha_creacion', 'fecha_actualizacion'), 'classes': ('collapse',)}),
#     )
#
#     # Añadir el inline a la lista 'inlines'
#     inlines = [ComentarioInline]
#
# # No es necesario registrar Comentario explícitamente si solo se usa como inline
# # admin.site.register(Comentario)
# ```
# Ahora, al editar un `Producto`, verás una sección adicional ("Comentarios") donde puedes gestionar los comentarios asociados a ese producto específico.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 17_6_Personalizar_QuerySets_en_el_Admin_get_queryset
#
# A veces necesitas filtrar los objetos que se muestran en la lista del admin o en los desplegables de relaciones más allá de lo que permite `list_filter`. Puedes sobrescribir el método `get_queryset(self, request)` en tu `ModelAdmin` (o `InlineModelAdmin`).
#
# Este método recibe el `request` y debe devolver el QuerySet base que usará el admin para esa vista.
#
# ```python
# # admin.py (dentro de ProductoAdmin)
# def get_queryset(self, request):
#     # 1. Obtener el queryset base original
#     qs = super().get_queryset(request)
#     # 2. Si el usuario no es superusuario, solo mostrarle los productos disponibles
#     if not request.user.is_superuser:
#         return qs.filter(disponible=True)
#     # 3. Los superusuarios ven todos
#     return qs
# ```
# Esto permite implementar lógica de permisos o filtrado más compleja directamente en el admin.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 17_7_Ejercicio_Practico_Personalizar_Formulario_Admin_e_Inlines
#
# **Objetivo:** Organizar el formulario de `Producto` usando `fieldsets`, hacer campos `readonly` y añadir la gestión inline de `Comentario`s.
#
# **Pasos:**
#
# 1.  **Abre `productos/admin.py`**.
# 2.  **Asegúrate** de tener el modelo `Comentario` definido y migrado (del ejercicio 10.5).
# 3.  **Modifica (o crea) la clase `ProductoAdmin`:**
#     *   Define `readonly_fields` para incluir `fecha_creacion` y `fecha_actualizacion`.
#     *   Define `fieldsets` para organizar los campos en secciones (puedes copiar/adaptar el ejemplo de la sección 17.2): una sección principal (nombre, slug, categoría), una para descripción/disponibilidad/imagen, una para precio/stock, y una colapsada para los metadatos (incluyendo los readonly).
#     *   Asegúrate de que *todos* los campos que quieres mostrar (incluidos los `readonly_fields`) estén presentes en alguna tupla `fields` dentro de `fieldsets`.
# 4.  **Crea la clase `ComentarioInline`:**
#     *   Haz que herede de `admin.TabularInline`.
#     *   Establece `model = Comentario`.
#     *   Define `fields = ('autor', 'texto', 'fecha_creacion')`.
#     *   Define `readonly_fields = ('fecha_creacion',)`.
#     *   Establece `extra = 1`.
# 5.  **Añade el inline a `ProductoAdmin`:**
#     *   Añade el atributo `inlines = [ComentarioInline]` a la clase `ProductoAdmin`.
# 6.  **Verifica el registro:** Asegúrate de que `Producto` esté registrado con `ProductoAdmin` y `Categoria` con `CategoriaAdmin`. No registres `Comentario` por separado.
# 7.  **Reinicia el servidor.**
# 8.  **Accede al admin** y edita un `Producto` existente (o crea uno nuevo). Observa la nueva organización del formulario en secciones y la aparición de la sección inline para añadir/editar comentarios en la parte inferior. Verifica que los campos de fecha son de solo lectura.
#
# **Solución Propuesta (`productos/admin.py`):**
# ```python
# from django.contrib import admin
# from .models import Producto, Categoria, Comentario
#
# class ComentarioInline(admin.TabularInline):
#     model = Comentario
#     fields = ('autor', 'texto', 'fecha_creacion')
#     readonly_fields = ('fecha_creacion',)
#     extra = 1
#     # Podrías añadir ordering, etc. aquí también
#
# @admin.register(Categoria)
# class CategoriaAdmin(admin.ModelAdmin):
#     list_display = ('nombre', 'slug')
#     search_fields = ('nombre',)
#     prepopulated_fields = {'slug': ('nombre',)}
#
# @admin.register(Producto)
# class ProductoAdmin(admin.ModelAdmin):
#     list_display = ('nombre', 'categoria', 'precio', 'stock', 'disponible', 'fecha_creacion')
#     list_filter = ('disponible', 'categoria')
#     search_fields = ('nombre', 'descripcion')
#     list_editable = ('precio', 'disponible')
#     prepopulated_fields = {'slug': ('nombre',)}
#     readonly_fields = ('fecha_creacion', 'fecha_actualizacion') # Definir aquí
#     list_per_page = 25
#
#     fieldsets = (
#         (None, {
#             'fields': ('nombre', 'slug', 'categoria')
#         }),
#         ('Descripción y Medios', {
#             'fields': ('descripcion', 'imagen') # Añadido imagen aquí si existe
#         }),
#         ('Inventario y Precio', {
#             'fields': ('precio', 'stock', 'disponible')
#         }),
#         ('Metadatos', {
#             'fields': ('fecha_creacion', 'fecha_actualizacion'), # Incluir readonly aquí
#             'classes': ('collapse',) # Hacer colapsable
#         }),
#     )
#
#     inlines = [ComentarioInline] # Añadir el inline
#
# # No es necesario registrar Comentario explícitamente
# ```
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ## 18_Acciones_del_Admin
#
# Las acciones del admin permiten aplicar una operación a **múltiples objetos seleccionados** directamente desde la página de lista (changelist). Django incluye la acción "Eliminar seleccionados" por defecto. Puedes crear tus propias acciones personalizadas para realizar tareas comunes en lote.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 18_1_Definicion_de_Acciones_Personalizadas
#
# Una acción personalizada es un **método** definido dentro de tu clase `ModelAdmin`.
#
# *   **Firma del Método:** El método debe aceptar tres argumentos:
#     1.  `self`: La instancia del `ModelAdmin`.
#     2.  `request`: El objeto `HttpRequest` actual.
#     3.  `queryset`: Un QuerySet que contiene los objetos que el usuario ha seleccionado en la lista del admin.
# *   **Decorador `@admin.action` (Recomendado):** Se usa para marcar el método como una acción y proporcionar metadatos:
#     *   `description`: El texto legible que aparecerá en el desplegable de acciones del admin (ej: `'Marcar como publicado'`).
#     *   `permissions`: (Opcional) Una lista de permisos que el usuario debe tener para poder ejecutar esta acción.
#
# ```python
# # admin.py (dentro de ProductoAdmin)
# from django.contrib import messages # Para mostrar mensajes
#
# @admin.action(description="Marcar productos seleccionados como DISPONIBLES", permissions=['change'])
# def marcar_como_disponible(self, request, queryset):
#     # queryset contiene los Productos seleccionados
#     rows_updated = queryset.update(disponible=True) # Actualiza en lote
#
#     # Mostrar mensaje de éxito
#     if rows_updated == 1:
#         message = "1 producto marcado como disponible."
#     else:
#         message = f"{rows_updated} productos marcados como disponibles."
#     self.message_user(request, message, messages.SUCCESS) # Usa messages.SUCCESS, .WARNING, .ERROR
#
# @admin.action(description="Marcar productos seleccionados como NO DISPONIBLES", permissions=['change'])
# def marcar_como_no_disponible(self, request, queryset):
#     rows_updated = queryset.update(disponible=False)
#     if rows_updated == 1:
#         message = "1 producto marcado como no disponible."
#     else:
#         message = f"{rows_updated} productos marcados como no disponibles."
#     self.message_user(request, message, messages.SUCCESS) # O messages.INFO
# ```
# *   El decorador `@admin.action` es preferible a la forma antigua de asignar atributos (`marcar_como_disponible.short_description = ...`).
# *   Usar `queryset.update()` es eficiente para cambios masivos. Si necesitas lógica más compleja o llamar a `save()`/señales para cada objeto, tendrías que iterar sobre el `queryset`, pero ten cuidado con el rendimiento en selecciones grandes.
# *   `self.message_user(request, mensaje, nivel)` es la forma estándar de mostrar mensajes flash al usuario en el admin.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 18_2_Registrar_Acciones
#
# Una vez definidas las funciones de acción (métodos decorados), debes añadirlas a la lista o tupla `actions` de tu clase `ModelAdmin`.
#
# ```python
# # admin.py (dentro de ProductoAdmin)
# @admin.register(Producto)
# class ProductoAdmin(admin.ModelAdmin):
#     # ... (list_display, list_filter, etc.) ...
#     inlines = [ComentarioInline]
#
#     # Lista de acciones disponibles
#     actions = ['marcar_como_disponible', 'marcar_como_no_disponible']
#
#     # --- Definiciones de los métodos de acción ---
#     @admin.action(description="Marcar productos seleccionados como DISPONIBLES", permissions=['change'])
#     def marcar_como_disponible(self, request, queryset):
#         # ... (código de la acción) ...
#         rows_updated = queryset.update(disponible=True)
#         # ... (mensaje) ...
#         self.message_user(request, f"{rows_updated} marcados como disponibles.", messages.SUCCESS)
#
#     @admin.action(description="Marcar productos seleccionados como NO DISPONIBLES", permissions=['change'])
#     def marcar_como_no_disponible(self, request, queryset):
#         # ... (código de la acción) ...
#         rows_updated = queryset.update(disponible=False)
#         # ... (mensaje) ...
#         self.message_user(request, f"{rows_updated} marcados como no disponibles.", messages.SUCCESS)
#
# ```
# Ahora, en la página de lista de Productos, el desplegable "Acciones" incluirá las nuevas opciones junto con la de "Eliminar seleccionados". El usuario puede seleccionar varios productos y aplicar la acción elegida.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 18_3_Ejercicio_Practico_Crear_Accion_de_Admin
#
# **Objetivo:** Añadir una acción personalizada al admin de `Producto` para poner el stock de los productos seleccionados a cero.
#
# **Pasos:**
#
# 1.  **Abre `productos/admin.py`**.
# 2.  **Dentro de la clase `ProductoAdmin`**, define un nuevo método llamado `poner_stock_a_cero`.
#     *   Decóralo con `@admin.action(description='Poner stock a CERO para seleccionados')`. Puedes añadir `permissions=['change']` si quieres restringirlo.
#     *   El método debe aceptar `self`, `request`, y `queryset`.
#     *   Dentro del método, usa `queryset.update(stock=0)` para actualizar el stock. Guarda el número de filas actualizadas.
#     *   Usa `self.message_user()` para mostrar un mensaje de éxito indicando cuántos productos se actualizaron.
# 3.  **Añade el nombre del método** (`'poner_stock_a_cero'`) a la lista `actions` de `ProductoAdmin`.
# 4.  **Reinicia el servidor.**
# 5.  **Ve al admin**, selecciona algunos productos en la lista, elige la nueva acción "Poner stock a CERO para seleccionados" del desplegable y haz clic en "Ir". Verifica que el stock se actualice y aparezca el mensaje de éxito.
#
# **Solución Propuesta (dentro de `ProductoAdmin` en `productos/admin.py`):**
# ```python
# # ... (otros imports y clases admin) ...
# from django.contrib import messages
#
# @admin.register(Producto)
# class ProductoAdmin(admin.ModelAdmin):
#     # ... (list_display, list_filter, search_fields, etc.) ...
#     inlines = [ComentarioInline]
#
#     # Lista de acciones
#     actions = ['marcar_como_disponible', 'marcar_como_no_disponible', 'poner_stock_a_cero']
#
#     # --- Métodos de Acción ---
#     @admin.action(description="Marcar productos seleccionados como DISPONIBLES", permissions=['change'])
#     def marcar_como_disponible(self, request, queryset):
#         rows_updated = queryset.update(disponible=True)
#         self.message_user(request, f"{rows_updated} productos marcados como disponibles.", messages.SUCCESS)
#
#     @admin.action(description="Marcar productos seleccionados como NO DISPONIBLES", permissions=['change'])
#     def marcar_como_no_disponible(self, request, queryset):
#         rows_updated = queryset.update(disponible=False)
#         self.message_user(request, f"{rows_updated} productos marcados como no disponibles.", messages.SUCCESS)
#
#     # --- NUEVA ACCIÓN ---
#     @admin.action(description="Poner stock a CERO para seleccionados", permissions=['change'])
#     def poner_stock_a_cero(self, request, queryset):
#         rows_updated = queryset.update(stock=0)
#         if rows_updated == 1:
#             message = "Stock de 1 producto puesto a cero."
#         else:
#             message = f"Stock de {rows_updated} productos puesto a cero."
#         self.message_user(request, message, messages.SUCCESS)
#
# ```
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ---
# ---
#
# ## **Unidad 5: Formularios Django**
#
# ## 19_Introduccion_a_los_Formularios_HTML_y_Django
#
# Los formularios son la principal interfaz para que los usuarios envíen datos a tu aplicación web. Un formulario HTML estándar se construye con la etiqueta `<form>` y varios elementos de entrada (`<input>`, `<textarea>`, `<select>`, `<button>`).
#
# **Componentes clave de un formulario HTML:**
# *   **`<form>`:** Contenedor principal. Atributos importantes:
#     *   `action`: URL del servidor que procesará los datos.
#     *   `method`: Método HTTP (`GET` o `POST`). `POST` es el estándar para enviar datos que modifican el estado o son sensibles.
#     *   `enctype`: Cómo se codifican los datos. Es `'multipart/form-data'` si se suben archivos, `'application/x-www-form-urlencoded'` por defecto.
# *   **Elementos de Entrada:** (`<input>`, `<textarea>`, `<select>`)
#     *   Atributo `name`: Identifica el dato cuando se envía al servidor. **Esencial.**
#     *   Atributo `id`: Identificador único para asociar con `<label>`.
#     *   Atributo `type` (para `<input>`): Define el tipo de control (text, email, password, checkbox, radio, file, etc.).
#     *   Otros atributos: `value`, `placeholder`, `required`, `checked`, `selected`, etc.
# *   **`<label>`:** Etiqueta descriptiva asociada a un control mediante el atributo `for` (que coincide con el `id` del control). Mejora usabilidad y accesibilidad.
# *   **Botón de Envío:** (`<button type="submit">` o `<input type="submit">`) Inicia el envío del formulario.
# *   **Protección CSRF (en Django):** La etiqueta `{% csrf_token %}` dentro del `<form>` es **obligatoria** para formularios `POST` para proteger contra ataques Cross-Site Request Forgery.
#
# **El Rol de Django Forms:**
# Crear, renderizar y validar formularios HTML manualmente puede ser repetitivo y propenso a errores. El sistema de formularios de Django (`django.forms`) automatiza y simplifica este proceso:
#
# 1.  **Definición en Python:** Define la estructura y validación del formulario como una clase Python en `forms.py`.
# 2.  **Renderizado HTML:** Django puede generar automáticamente el HTML para los campos del formulario.
# 3.  **Limpieza y Validación de Datos:** Convierte los datos enviados (que siempre llegan como strings desde HTML) a tipos de datos Python apropiados y ejecuta reglas de validación (campos requeridos, formato de email, longitud máxima, validaciones personalizadas).
# 4.  **Manejo de Errores:** Asocia errores de validación a campos específicos o al formulario en general, facilitando mostrarlos al usuario.
# 5.  **Separación de Intereses:** Mantiene la lógica de validación en Python, separada de la presentación en la plantilla HTML.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ## 20_Creacion_de_Formularios_Forms_forms_py
#
# Los formularios Django se definen como clases que heredan de `django.forms.Form` (para formularios genéricos) o `django.forms.ModelForm` (para formularios basados directamente en modelos, ver Unidad 5, Sección 23).
#
# Convencionalmente, estas clases se definen en un archivo `forms.py` dentro de cada aplicación.
#
# **Ejemplo (`productos/forms.py` - Formulario de contacto simple):**
# ```python
# # productos/forms.py
# from django import forms
#
# class ContactoForm(forms.Form):
#     # Definir cada campo como un atributo de clase,
#     # asignándole una instancia de un Field de django.forms.
#     nombre = forms.CharField(
#         label="Tu Nombre Completo",
#         max_length=100,
#         required=True, # Campo obligatorio
#         widget=forms.TextInput(attrs={'placeholder': 'Ej: Juan Pérez', 'class': 'form-control'}) # Widget con atributos HTML
#     )
#     email = forms.EmailField(
#         label="Correo Electrónico",
#         required=True,
#         help_text="Usaremos este email para responderte.",
#         widget=forms.EmailInput(attrs={'class': 'form-control'})
#     )
#     asunto = forms.CharField(
#         max_length=200,
#         required=True,
#         initial="Consulta General", # Valor inicial
#         widget=forms.TextInput(attrs={'class': 'form-control'})
#     )
#     mensaje = forms.CharField(
#         label="Tu Mensaje",
#         required=True,
#         widget=forms.Textarea(attrs={'rows': 5, 'class': 'form-control'}) # Usar <textarea>
#     )
#     recibir_copia = forms.BooleanField(
#         label="Enviarme una copia a mi correo",
#         required=False # Checkbox no suele ser requerido
#     )
#
#     # --- Validación Personalizada (Ejemplo) ---
#     def clean_mensaje(self):
#         """Validación específica para el campo 'mensaje'."""
#         mensaje = self.cleaned_data.get('mensaje', '')
#         if len(mensaje) < 10:
#             # Lanzar error de validación si es muy corto
#             raise forms.ValidationError("El mensaje debe tener al menos 10 caracteres.", code='mensaje_corto')
#         # Siempre devolver el dato limpio
#         return mensaje
#
#     def clean(self):
#         """Validación que involucra múltiples campos."""
#         cleaned_data = super().clean() # Obtener datos ya limpios por campos individuales
#         nombre = cleaned_data.get('nombre')
#         asunto = cleaned_data.get('asunto')
#
#         # Ejemplo: No permitir que el nombre esté en el asunto
#         if nombre and asunto and nombre.lower() in asunto.lower():
#             # Añadir error a un campo específico
#             # self.add_error('asunto', 'Por favor, no incluyas tu nombre en el asunto.')
#             # O añadir error general (non-field error)
#             raise forms.ValidationError("El nombre no debe aparecer en el asunto.", code='nombre_en_asunto')
#
#         # Siempre devolver cleaned_data al final de clean()
#         return cleaned_data
# ```
# *   Cada atributo (`nombre`, `email`, etc.) es una instancia de una clase `Field`.
# *   Estas clases `Field` manejan la validación inicial y definen el widget HTML por defecto.
# *   Se pueden añadir métodos `clean_<nombrecampo>()` para validaciones específicas de un campo.
# *   Se puede añadir un método `clean()` para validaciones que involucren múltiples campos.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 20_1_Campos_de_Formulario_CharField_IntegerField_etc
#
# Django ofrece una amplia variedad de `Field`s en `django.forms`, similares pero distintos a los campos de modelo:
#
# *   **Texto:** `CharField`, `EmailField`, `URLField`, `SlugField`, `RegexField`.
# *   **Números:** `IntegerField`, `FloatField`, `DecimalField`.
# *   **Booleanos:** `BooleanField`, `NullBooleanField`.
# *   **Fechas/Horas:** `DateField`, `TimeField`, `DateTimeField`, `DurationField`, `SplitDateTimeField`.
# *   **Selección:**
#     *   `ChoiceField`: Para seleccionar una opción de una lista (`choices`). Renderiza como `<select>`.
#     *   `TypedChoiceField`: Como `ChoiceField` pero coacciona los valores a un tipo específico.
#     *   `MultipleChoiceField`: Para seleccionar múltiples opciones (`choices`). Renderiza como `<select multiple>` o checkboxes.
#     *   `TypedMultipleChoiceField`: Igual que `MultipleChoiceField` con coerción.
#     *   `ModelChoiceField`: Un `ChoiceField` cuyas opciones son instancias de un modelo QuerySet.
#     *   `ModelMultipleChoiceField`: Igual que `ModelChoiceField` pero para selección múltiple.
# *   **Archivos:** `FileField`, `ImageField`.
# *   **Otros:** `GenericIPAddressField`, `UUIDField`, `FilePathField`.
#
# Cada campo tiene argumentos específicos para validación (ej: `max_length`, `min_length`, `max_value`, `min_value`) además de los argumentos comunes.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 20_2_Widgets_Personalizacion_HTML
#
# Los Widgets controlan cómo se renderiza un campo de formulario en HTML. Cada `Field` tiene un `widget` por defecto, pero puedes especificar uno diferente usando el argumento `widget` al definir el campo.
#
# **Ejemplos:**
# ```python
# # forms.py
# class EjemploWidgetsForm(forms.Form):
#     descripcion = forms.CharField(widget=forms.Textarea) # Usa <textarea> en lugar de <input type="text">
#     fecha_nac = forms.DateField(widget=forms.DateInput(attrs={'type': 'date'})) # Usa <input type="date">
#     opcion = forms.ChoiceField(
#         choices=[('A','Opción A'), ('B','Opción B')],
#         widget=forms.RadioSelect # Usa <input type="radio"> en lugar de <select>
#     )
#     colores = forms.MultipleChoiceField(
#         choices=[('R','Rojo'), ('V','Verde'), ('A','Azul')],
#         widget=forms.CheckboxSelectMultiple # Usa checkboxes en lugar de <select multiple>
#     )
#     password = forms.CharField(widget=forms.PasswordInput) # Usa <input type="password">
# ```
# Puedes pasar un diccionario `attrs` al inicializar el widget para añadir atributos HTML (como `class`, `placeholder`, `rows`, `cols`, etc.).
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 20_3_Argumentos_Comunes_required_label_initial_help_text_widget_attrs
#
# Repaso de los argumentos más comunes al definir un campo `Field`:
#
# *   `required` (Boolean, defecto `True`): ¿Es obligatorio?
# *   `label` (String): Texto para la etiqueta `<label>`.
# *   `label_suffix` (String, defecto `':'`): Sufijo añadido al label.
# *   `initial` (Valor): Valor inicial para el campo en formularios no vinculados.
# *   `widget` (Widget instance): Widget a usar para renderizar.
# *   `help_text` (String): Texto de ayuda adicional.
# *   `error_messages` (Dict): Para personalizar mensajes de error.
# *   `validators` (List): Lista de validadores adicionales.
# *   `disabled` (Boolean, defecto `False`): Renderizar el campo como deshabilitado.
# *   `localize` (Boolean): Para formatear la entrada/salida según la localización actual.
#
# ```python
# # forms.py
# comentario = forms.CharField(
#     label="Tu Comentario",
#     required=False, # No es obligatorio
#     initial="Escribe algo...",
#     widget=forms.Textarea(attrs={'rows': 4, 'class':'comentario-input'}),
#     help_text="Sé respetuoso.",
#     error_messages={'max_length': 'El comentario es demasiado largo.'},
#     # validators=[mi_validador_custom] # Si tuvieras uno
# )
# ```
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ## 21_Renderizado_de_Formularios_en_Plantillas
#
# Una vez que pasas una instancia del formulario (`form = MiFormulario()`) a la plantilla a través del contexto, Django te ofrece varias formas de renderizar el HTML correspondiente.
#
# **Recordatorio de la Vista (`views.py`):**
# ```python
# # views.py
# from django.shortcuts import render
# from .forms import ContactoForm # O el formulario que sea
#
# def mi_vista_formulario(request):
#     # (Lógica GET/POST omitida por brevedad, ver sección 22)
#     if request.method == 'POST':
#          form = ContactoForm(request.POST)
#          if form.is_valid():
#              # ... procesar y redirigir ...
#              pass # Volverá a renderizar con errores si no es válido
#     else:
#          form = ContactoForm() # Instancia vacía para GET
#
#     return render(request, 'mi_app/mi_plantilla_form.html', {'form': form})
# ```
#
# **En la Plantilla (`mi_app/templates/mi_app/mi_plantilla_form.html`):**
# ```html
# <form action="" method="post">
#     {% csrf_token %} {# ¡No olvidar! #}
#
#     {# --- Método 1: Renderizado Automático como Párrafos --- #}
#     {{ form.as_p }}
#
#     {# --- Método 2: Renderizado Automático como Lista --- #}
#     {# <ul>{{ form.as_ul }}</ul> #}
#
#     {# --- Método 3: Renderizado Automático como Tabla --- #}
#     {# <table>{{ form.as_table }}</table> #}
#
#     <button type="submit">Enviar</button>
# </form>
# ```
# Estos métodos automáticos (`as_p`, `as_ul`, `as_table`) son rápidos pero limitan el control sobre el HTML y el estilado.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 21_1_Renderizado_Manual_de_Campos_y_Errores
#
# Para un control total, puedes renderizar cada parte del formulario manualmente iterando sobre los campos o accediendo a ellos directamente.
#
# ```html
# <form action="" method="post">
#     {% csrf_token %}
#
#     {# Mostrar errores no ligados a campos específicos #}
#     {% if form.non_field_errors %}
#         <div class="errorlist nonfield">
#             {% for error in form.non_field_errors %}
#                 <p>{{ error }}</p>
#             {% endfor %}
#         </div>
#     {% endif %}
#
#     {# Iterar sobre todos los campos (visibles) #}
#     {% for field in form.visible_fields %}
#         <div class="form-group {% if field.errors %}has-error{% endif %}">
#             {# Etiqueta del campo #}
#             {{ field.label_tag }}
#
#             {# El widget HTML del campo #}
#             {{ field }}
#
#             {# Errores específicos de este campo #}
#             {% if field.errors %}
#                 <div class="errorlist field-error">
#                     {% for error in field.errors %}
#                         <span>{{ error }}</span>
#                     {% endfor %}
#                 </div>
#             {% endif %}
#
#             {# Texto de ayuda del campo #}
#             {% if field.help_text %}
#                 <small class="helptext">{{ field.help_text|safe }}</small>
#             {% endif %}
#         </div>
#     {% endfor %}
#
#     {# Si tienes campos ocultos, deberías renderizarlos también #}
#     {% for hidden_field in form.hidden_fields %}
#         {{ hidden_field }}
#     {% endfor %}
#
#     <button type="submit">Enviar</button>
# </form>
# ```
# **Acceso a propiedades del campo (`field` en el bucle):**
# *   `field.label_tag`: Renderiza `<label for="id_del_campo">Texto Label:</label>`.
# *   `field`: Renderiza el widget HTML (`<input>`, `<textarea>`, etc.).
# *   `field.id_for_label`: El ID usado para el `for` del label y el `id` del widget.
# *   `field.label`: El texto del label.
# *   `field.help_text`: El texto de ayuda.
# *   `field.errors`: Lista de errores de validación para este campo.
# *   `field.value`: El valor actual del campo (útil para lógica en plantilla).
# *   `field.field`: El objeto `Field` original de `forms.py`.
# *   `field.name`: El nombre del campo (string).
#
# El renderizado manual te permite integrar perfectamente los formularios con tu CSS (ej: Bootstrap, Tailwind) y estructura HTML deseada.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 21_2_Metodos_de_Renderizado_as_p_as_ul_as_table
#
# *   **`form.as_p()`:** Renderiza cada campo (su etiqueta, widget y errores) envuelto en una etiqueta `<p>`. Rápido para empezar.
# *   **`form.as_ul()`:** Renderiza cada campo envuelto en `<li>`. Necesitas añadir las etiquetas `<ul>...</ul>` externamente.
# *   **`form.as_table()`:** Renderiza cada campo envuelto en `<tr>`, con la etiqueta en un `<th>` y el widget/errores en un `<td>`. Necesitas añadir `<table>...</table>` externamente.
#
# Estos métodos son menos flexibles que el renderizado manual pero pueden ser útiles para prototipado rápido o formularios muy simples.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 21_3_Etiqueta_csrf_token
#
# Como se mencionó, `{% csrf_token %}` es **indispensable** dentro de cualquier `<form>` que use `method="post"`.
#
# *   Genera un `<input type="hidden" name="csrfmiddlewaretoken" value="token_unico_y_secreto">`.
# *   El middleware `CsrfViewMiddleware` (activado por defecto) busca este token en las peticiones POST.
# *   Compara el token recibido con uno almacenado en la sesión/cookie del usuario.
# *   Si los tokens no coinciden o falta el token, la petición POST es rechazada con un error 403 Forbidden.
# *   Esto protege contra ataques Cross-Site Request Forgery, donde un sitio malicioso intenta engañar a un usuario para que envíe una petición a tu sitio sin su consentimiento.
#
# **Siempre incluye `{% csrf_token %}` justo después de la etiqueta `<form>` en formularios POST.**
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ## 22_Procesamiento_de_Datos_del_Formulario_en_Vistas
#
# La vista que renderiza el formulario también es responsable de recibir y procesar los datos cuando el usuario lo envía.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 22_1_Diferenciar_GET_y_POST_en_Vistas
#
# Es fundamental distinguir si la vista está siendo accedida mediante `GET` (normalmente, la primera vez que se carga la página para *mostrar* el formulario) o `POST` (cuando el usuario *envía* los datos del formulario). Esto se hace comprobando `request.method`.
#
# ```python
# # views.py
# from django.shortcuts import render, redirect
# from .forms import MiFormulario
#
# def mi_vista_formulario(request):
#     if request.method == 'POST':
#         # --- Lógica para procesar datos enviados ---
#         # ... (ver secciones siguientes) ...
#         pass
#     else: # request.method == 'GET' (o cualquier otro método)
#         # --- Lógica para mostrar el formulario vacío ---
#         form = MiFormulario() # Instancia vacía
#         return render(request, 'mi_app/mi_plantilla_form.html', {'form': form})
# ```
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 22_2_Vinculacion_Binding_de_Datos_al_Formulario_request_POST
#
# Cuando recibes una petición `POST`, necesitas crear una instancia del formulario **vinculada** a los datos enviados. Esto se hace pasando `request.POST` como primer argumento al constructor del formulario. Si el formulario incluye campos de archivo (`FileField`, `ImageField`), también debes pasar `request.FILES`.
#
# ```python
# # views.py (dentro del bloque if request.method == 'POST':)
# form = MiFormulario(request.POST, request.FILES or None) # Pasa request.POST y request.FILES
# ```
# Un formulario vinculado (bound form) conoce los datos enviados y puede realizar la validación sobre ellos. Un formulario no vinculado (unbound form), como el creado en el bloque `else` (GET), no tiene datos asociados y siempre será `is_valid() == False`.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 22_3_Validacion_is_valid
#
# Una vez que tienes una instancia vinculada del formulario, llamas a su método `is_valid()` para activar el proceso de validación.
#
# `form.is_valid()` realiza lo siguiente:
# 1.  Ejecuta las validaciones incorporadas de cada campo (¿es requerido?, ¿es un email válido?, ¿es un número?, ¿longitud máxima?).
# 2.  Ejecuta cualquier validador personalizado añadido al argumento `validators` de un campo.
# 3.  Llama a los métodos `clean_<nombrecampo>()` definidos en la clase del formulario para validaciones específicas de campo.
# 4.  Llama al método `clean()` general de la clase del formulario para validaciones que involucran múltiples campos.
# 5.  Si **todas** las validaciones pasan, `is_valid()` devuelve `True` y puebla el diccionario `form.cleaned_data`.
# 6.  Si **alguna** validación falla, `is_valid()` devuelve `False` y puebla el diccionario `form.errors` con los mensajes de error.
#
# ```python
# # views.py (dentro del bloque if request.method == 'POST':)
# form = MiFormulario(request.POST)
# if form.is_valid():
#     # --- Los datos son válidos ---
#     # Acceder a form.cleaned_data
#     # Realizar acciones (guardar en BD, enviar email, etc.)
#     # Redirigir
#     pass
# else:
#     # --- Los datos son inválidos ---
#     # Renderizar de nuevo la plantilla, pasando la misma instancia 'form'
#     # La plantilla mostrará los errores automáticamente si está configurada para ello
#     return render(request, 'mi_app/mi_plantilla_form.html', {'form': form})
# ```
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 22_4_Acceso_a_Datos_Validados_cleaned_data
#
# Si `form.is_valid()` devuelve `True`, **siempre** debes acceder a los datos enviados a través del diccionario `form.cleaned_data`.
#
# *   `form.cleaned_data` contiene los datos que han pasado **todas** las validaciones.
# *   Los datos están **limpios y normalizados** al tipo Python correcto (ej: un `IntegerField` contendrá un `int`, un `DateField` contendrá un `datetime.date`).
# *   Es seguro usar estos datos para interactuar con tus modelos o realizar otras operaciones.
#
# ```python
# # views.py (dentro del bloque if form.is_valid():)
# nombre_limpio = form.cleaned_data['nombre']
# email_limpio = form.cleaned_data.get('email') # .get() es más seguro si no estás seguro si existe
# edad_limpia = form.cleaned_data.get('edad', 0) # Con valor por defecto
#
# print(f"Nombre: {nombre_limpio}, Email: {email_limpio}, Edad: {edad_limpia}")
# # ... guardar en BD, enviar email ...
# ```
# **Nunca uses `request.POST` directamente después de la validación**, ya que contiene los datos crudos como strings y sin validar.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 22_5_Manejo_de_Errores_form_errors_non_field_errors
#
# Si `form.is_valid()` devuelve `False`, la instancia `form` contiene los errores de validación. Simplemente necesitas volver a pasar esa misma instancia `form` al contexto cuando renderices la plantilla de nuevo.
#
# ```python
# # views.py
# # ...
# if request.method == 'POST':
#     form = MiFormulario(request.POST)
#     if form.is_valid():
#         # ... procesar éxito y redirigir ...
#         pass
#     # else: # form NO es válido
#     #   No hacer nada aquí, simplemente caer al final
# else: # GET
#     form = MiFormulario()
#
# # Renderizar plantilla con el 'form' (que estará vacío en GET, o con errores en POST inválido)
# return render(request, 'mi_app/mi_plantilla_form.html', {'form': form})
# ```
#
# La plantilla, si está configurada para mostrar errores (ver sección 21.1), los mostrará automáticamente:
# *   `{{ form.nombre_campo.errors }}`: Muestra errores específicos del campo.
# *   `{{ form.non_field_errors }}`: Muestra errores generales del formulario (los lanzados desde `clean()` o añadidos con `form.add_error(None, ...)`).
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 22_6_Patron_Post_Redirect_Get_PRG
#
# Es un patrón de diseño web fundamental para manejar envíos de formularios `POST`. **Siempre** debes redirigir al usuario después de procesar exitosamente una petición `POST`.
#
# **¿Por qué?**
# Si devuelves directamente una respuesta HTML desde la vista POST exitosa, y el usuario luego **recarga** esa página de éxito (con F5 o el botón de recargar), el navegador **reenviará la misma petición POST**, causando que la acción (guardar en BD, enviar email) se realice **de nuevo**, lo cual suele ser indeseado (ej: crear posts duplicados, enviar emails múltiples).
#
# **El patrón PRG lo evita:**
# 1.  **POST:** El usuario envía el formulario (POST).
# 2.  **Procesar:** La vista procesa el POST. Si es válido, realiza la acción (guarda, envía email).
# 3.  **Redirect:** La vista devuelve una respuesta **HTTP Redirect (302)** a una nueva URL (ej: una página de "éxito" o de vuelta a la lista).
# 4.  **GET:** El navegador del usuario recibe la redirección y automáticamente realiza una **petición GET** a la nueva URL.
# 5.  **Mostrar:** La vista que maneja la nueva URL (GET) muestra la página de éxito o la lista actualizada.
#
# Ahora, si el usuario recarga esta última página, simplemente está recargando la petición `GET`, lo cual es seguro y no repite la acción POST original.
#
# **Implementación en Django:**
# ```python
# # views.py
# from django.shortcuts import render, redirect
# # ...
#
# def mi_vista_formulario(request):
#     if request.method == 'POST':
#         form = MiFormulario(request.POST)
#         if form.is_valid():
#             # ... procesar form.cleaned_data ...
#             # ¡Redirigir SIEMPRE después de POST exitoso!
#             return redirect('nombre_url_exito') # O reverse(...) o un objeto
#     else:
#         form = MiFormulario()
#     return render(request, 'mi_app/mi_plantilla_form.html', {'form': form})
#
# def vista_exito(request):
#     # Vista simple que muestra la página de éxito
#     return render(request, 'mi_app/exito.html')
# ```
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 22_7_Ejercicio_Practico_Procesar_Formulario_en_Vista
#
# **Objetivo:** Crear una vista y plantilla para el `ContactoForm` definido anteriormente, implementando el flujo GET/POST y el patrón PRG.
#
# **Pasos:**
#
# 1.  **Crea `productos/forms.py`** (si no existe) y define la clase `ContactoForm` (puedes copiarla de la sección 20).
# 2.  **Crea una plantilla `productos/templates/productos/contacto.html`:**
#     *   Incluye un `<form method="post">`.
#     *   Añade `{% csrf_token %}`.
#     *   Renderiza el formulario (puedes usar `{{ form.as_p }}` por simplicidad o renderizado manual para practicar). Asegúrate de mostrar los errores si los hubiera (`form.errors`, `form.non_field_errors`).
#     *   Añade un botón `<button type="submit">`.
# 3.  **Crea una plantilla simple `productos/templates/productos/contacto_exito.html`:**
#     *   Solo necesita un mensaje como `<h1>¡Mensaje Enviado!</h1><p>Gracias por contactarnos.</p>`.
# 4.  **Define las vistas en `productos/views.py`:**
#     *   Crea `contacto_view(request)`:
#         *   Si `request.method == 'POST'`:
#             *   Crea `form = ContactoForm(request.POST)`.
#             *   Si `form.is_valid()`:
#                 *   Obtén los datos de `form.cleaned_data`.
#                 *   (Simulado) Imprime los datos en la consola del servidor (`print(...)`).
#                 *   Redirige a una nueva URL de éxito (que crearemos a continuación) usando `redirect()`.
#             *   (Si no es válido, la ejecución continuará y renderizará el form con errores).
#         *   Si `request.method == 'GET'`:
#             *   Crea `form = ContactoForm()`.
#         *   Renderiza `productos/contacto.html` pasando `{'form': form}`.
#     *   Crea `contacto_exito_view(request)`:
#         *   Simplemente renderiza `productos/contacto_exito.html`.
# 5.  **Define las URLs en `productos/urls.py`:**
#     *   Añade un `path` para `/contacto/` que apunte a `views.contacto_view` con `name='contacto'`.
#     *   Añade un `path` para `/contacto/exito/` que apunte a `views.contacto_exito_view` con `name='contacto_exito'`.
# 6.  **Incluye las URLs de `productos` en `tienda_config/urls.py`** si no lo has hecho (ej: `path('', include('productos.urls'))` para que `/contacto/` funcione).
# 7.  **Ejecuta `runserver` y prueba:**
#     *   Ve a `/contacto/`. Deberías ver el formulario vacío.
#     *   Intenta enviarlo vacío. Deberías ver los errores de campos requeridos.
#     *   Rellena el formulario correctamente y envíalo. Deberías ser redirigido a `/contacto/exito/` y ver el mensaje de éxito. Verifica la consola del servidor para ver los datos impresos.
#     *   Recarga la página de éxito (`/contacto/exito/`). No debería pasar nada más (no se reenvía el formulario).
#
# **Solución Propuesta:**
#
# **`productos/forms.py`:** (Como en sección 20)
# ```python
# from django import forms
# # ... (definición de ContactoForm) ...
# ```
#
# **`productos/templates/productos/contacto.html`:**
# ```html
# <!DOCTYPE html>
# <html lang="es">
# <head><title>Contacto</title></head>
# <body>
#     <h1>Contacto</h1>
#     <form method="post">
#         {% csrf_token %}
#         {{ form.as_p }} {# Usando as_p para simplicidad #}
#         <button type="submit">Enviar Mensaje</button>
#     </form>
# </body>
# </html>
# ```
#
# **`productos/templates/productos/contacto_exito.html`:**
# ```html
# <!DOCTYPE html>
# <html lang="es">
# <head><title>Éxito</title></head>
# <body>
#     <h1>¡Mensaje Enviado!</h1>
#     <p>Gracias por contactarnos, te responderemos pronto.</p>
#     <p><a href="{% url 'productos:lista_productos' %}">Volver a productos</a></p> {# Asumiendo que existe #}
# </body>
# </html>
# ```
#
# **`productos/views.py`:**
# ```python
# from django.shortcuts import render, redirect
# from django.urls import reverse # Para generar URL de éxito
# from .forms import ContactoForm
#
# # ... (otras vistas como lista_productos_view, etc.) ...
#
# def contacto_view(request):
#     if request.method == 'POST':
#         form = ContactoForm(request.POST)
#         if form.is_valid():
#             nombre = form.cleaned_data['nombre']
#             email = form.cleaned_data['email']
#             asunto = form.cleaned_data['asunto']
#             mensaje = form.cleaned_data['mensaje']
#             copia = form.cleaned_data['recibir_copia']
#
#             # Simulación de acción (enviar email, guardar, etc.)
#             print("----- FORMULARIO CONTACTO RECIBIDO -----")
#             print(f"Nombre: {nombre}")
#             print(f"Email: {email}")
#             print(f"Asunto: {asunto}")
#             print(f"Mensaje: {mensaje}")
#             print(f"Enviar Copia: {copia}")
#             print("---------------------------------------")
#
#             # Redirigir a la página de éxito usando el nombre de la URL
#             return redirect('productos:contacto_exito')
#         # Si el form no es válido, se caerá al render final
#     else: # GET
#         form = ContactoForm()
#
#     return render(request, 'productos/contacto.html', {'form': form})
#
# def contacto_exito_view(request):
#     return render(request, 'productos/contacto_exito.html')
#
# ```
#
# **`productos/urls.py`:**
# ```python
# from django.urls import path
# from . import views
#
# app_name = 'productos'
#
# urlpatterns = [
#     # ... (urls de lista y detalle) ...
#     path('contacto/', views.contacto_view, name='contacto'),
#     path('contacto/exito/', views.contacto_exito_view, name='contacto_exito'),
# ]
# ```
#
# **`tienda_config/urls.py`:** (Asegúrate de incluir las urls de productos)
# ```python
# from django.contrib import admin
# from django.urls import path, include
#
# urlpatterns = [
#     path('admin/', admin.site.urls),
#     # Incluir urls de productos en la raíz o bajo un prefijo
#     path('', include('productos.urls')), # Ejemplo en la raíz
# ]
# ```
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ## 23_ModelForms_Formularios_Basados_en_Modelos
#
# Cuando necesitas un formulario para crear o editar directamente instancias de un modelo Django, escribir un `forms.Form` puede ser repetitivo, ya que tienes que volver a declarar campos que ya están definidos en tu `models.py`. Django proporciona una clase `ModelForm` para simplificar esto enormemente.
#
# Un `ModelForm` es una subclase de `forms.Form` que **genera automáticamente los campos del formulario a partir de un modelo especificado**. También incluye un método `.save()` para guardar fácilmente los datos en la base de datos.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 23_1_Creacion_y_Uso_Basico_Meta_model_fields_exclude
#
# Para crear un `ModelForm`:
# 1.  Hereda de `django.forms.ModelForm`.
# 2.  Define una clase interna `Meta`.
# 3.  Dentro de `Meta`, especifica **obligatoriamente** el atributo `model` con la clase del modelo al que está vinculado.
# 4.  Especifica **obligatoriamente** qué campos del modelo incluir usando `fields` o `exclude`:
#     *   `fields = ['campo1', 'campo2', ...]` : Lista o tupla de los nombres de campo del modelo a incluir en el formulario.
#     *   `exclude = ['campo_a', 'campo_b', ...]` : Lista o tupla de los nombres de campo del modelo a **excluir**. Todos los demás campos editables del modelo se incluirán.
#     *   `fields = '__all__'` : Incluye **todos** los campos editables del modelo. Útil para formularios simples, pero **menos seguro** si añades nuevos campos al modelo más tarde que no quieres exponer accidentalmente. **Es preferible ser explícito con `fields` o `exclude`.**
#
# **Ejemplo (`productos/forms.py`):**
# ```python
# # productos/forms.py
# from django import forms
# from .models import Producto, Categoria # Importa los modelos
#
# # ... (ContactoForm si lo tienes) ...
#
# class ProductoForm(forms.ModelForm):
#     # Puedes añadir campos extra que NO estén en el modelo
#     confirmacion_terminos = forms.BooleanField(required=True, label="Acepto los términos")
#
#     class Meta:
#         model = Producto # El modelo asociado
#         # Incluir estos campos del modelo Producto
#         fields = ['nombre', 'slug', 'categoria', 'descripcion', 'precio', 'stock', 'disponible', 'imagen']
#         # O alternativamente, excluir los gestionados automáticamente:
#         # exclude = ['fecha_creacion', 'fecha_actualizacion', 'creado_por'] # Si tuvieras creado_por
#
#         # Puedes personalizar widgets, labels, help_texts aquí también
#         widgets = {
#             'descripcion': forms.Textarea(attrs={'rows': 5}),
#             # 'categoria': forms.RadioSelect, # Ejemplo: usar radios para la categoría
#             'imagen': forms.ClearableFileInput, # Widget recomendado para ImageField/FileField
#         }
#         labels = {
#             'slug': 'URL Amigable',
#             'disponible': '¿Está disponible para la venta?',
#         }
#         help_texts = {
#             'slug': 'Generado automáticamente si se deja en blanco.',
#             'precio': 'Precio en EUR.',
#         }
#         # error_messages = { ... } # También puedes personalizar errores
# ```
# Django `ModelForm` inspeccionará el modelo `Producto` y creará automáticamente los campos de formulario correspondientes (`CharField` para `nombre`, `SlugField` para `slug`, `ModelChoiceField` para `categoria`, `TextField` para `descripcion` con el widget `Textarea`, etc.), aplicando las validaciones básicas del modelo (`max_length`, `blank`, etc.).
#
# Usar un `ModelForm` en una vista es idéntico a usar un `forms.Form` (se pasa `request.POST`, se llama a `is_valid()`, se accede a `cleaned_data`, se pasa al contexto). La principal diferencia está en el método `.save()`.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 23_2_Metodo_save_commit_False_save_m2m
#
# La gran ventaja de `ModelForm` es el método `.save()`.
#
# *   **`form.save(commit=True)`:** (Comportamiento por defecto)
#     1.  Si el formulario está vinculado a una **instancia existente** (pasada con `instance=...` al crear el form), actualiza esa instancia con los datos de `cleaned_data` y la guarda (ejecuta `UPDATE`).
#     2.  Si el formulario **no** está vinculado a una instancia (es un formulario de creación), crea una **nueva instancia** del modelo con los datos de `cleaned_data` y la guarda (ejecuta `INSERT`).
#     3.  **Devuelve la instancia** del modelo guardada (ya sea la actualizada o la nueva).
#     4.  Si el modelo tiene campos `ManyToManyField`, guarda también esas relaciones.
#
# *   **`form.save(commit=False)`:**
#     1.  Realiza los mismos pasos 1 o 2 anteriores para crear o actualizar la instancia del modelo en memoria, **pero no la guarda en la base de datos**.
#     2.  **Devuelve la instancia sin guardar**.
#     3.  Es **necesario** usar `commit=False` si necesitas:
#         *   Modificar la instancia antes de guardarla (ej: asignar un campo que no está en el formulario, como el `autor` basado en `request.user`).
#         *   Realizar alguna operación adicional antes del guardado final.
#     4.  **¡Importante!** Si usas `commit=False` y tu modelo tiene campos `ManyToManyField`, debes llamar a `form.save_m2m()` **después** de haber guardado la instancia principal (`instancia.save()`) para guardar las relaciones ManyToMany. Esto se debe a que la instancia principal debe existir en la BD (tener una PK) antes de poder crear las relaciones en la tabla intermedia.
#
# **Ejemplo de Vista de Creación con `ModelForm`:**
# ```python
# # productos/views.py
# from django.shortcuts import render, redirect, get_object_or_404
# from django.contrib.auth.decorators import login_required
# # from django.contrib import messages
# from .models import Producto
# from .forms import ProductoForm # Importa el ModelForm
#
# @login_required
# def crear_producto_view(request):
#     if request.method == 'POST':
#         # Pasar request.POST y request.FILES (si hay campos de archivo)
#         form = ProductoForm(request.POST, request.FILES or None)
#         if form.is_valid():
#             # Guardar pero sin commit para asignar el autor (si lo tuvieras)
#             # nuevo_producto = form.save(commit=False)
#             # nuevo_producto.creado_por = request.user # Asignar usuario logueado
#             # nuevo_producto.save() # Guardar instancia principal
#
#             # Si no necesitas modificar antes de guardar:
#             nuevo_producto = form.save() # commit=True por defecto
#
#             # Si había M2M y usaste commit=False, necesitarías:
#             # form.save_m2m()
#
#             # messages.success(request, f"Producto '{nuevo_producto.nombre}' creado.")
#             return redirect(nuevo_producto.get_absolute_url()) # Redirigir al detalle
#     else: # GET
#         form = ProductoForm()
#     return render(request, 'productos/producto_form.html', {'form': form})
#
# @login_required
# def editar_producto_view(request, slug): # Asumiendo que usamos slug
#     producto = get_object_or_404(Producto, slug=slug)
#     # Opcional: Verificar permisos (ej: request.user == producto.creado_por)
#
#     if request.method == 'POST':
#         # Pasar 'instance' para indicar que estamos editando
#         form = ProductoForm(request.POST, request.FILES or None, instance=producto)
#         if form.is_valid():
#             form.save() # commit=True actualiza la instancia
#             # messages.success(request, f"Producto '{producto.nombre}' actualizado.")
#             return redirect(producto.get_absolute_url())
#     else: # GET
#         # Precargar el formulario con los datos de la instancia
#         form = ProductoForm(instance=producto)
#
#     return render(request, 'productos/producto_form.html', {'form': form, 'producto': producto})
# ```
# **Plantilla (`productos/templates/productos/producto_form.html`):**
# ```html
# {% extends 'base.html' %}
#
# {% block titulo %}{% if producto %}Editar Producto{% else %}Crear Producto{% endif %}{% endblock %}
#
# {% block contenido %}
#   <h1>{% if producto %}Editar {{ producto.nombre }}{% else %}Crear Nuevo Producto{% endif %}</h1>
#
#   {# ¡IMPORTANTE para subida de archivos! #}
#   <form method="post" enctype="multipart/form-data">
#       {% csrf_token %}
#       {{ form.as_p }}
#       <button type="submit">{% if producto %}Actualizar{% else %}Crear{% endif %} Producto</button>
#   </form>
#
#   <p><a href="{% url 'productos:lista_productos' %}">Cancelar</a></p>
# {% endblock %}
# ```
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 23_3_Personalizacion_de_Campos_en_ModelForms_widgets_labels_etc
#
# Como se vio en el ejemplo de `ProductoForm`, puedes personalizar los campos generados por `ModelForm` de varias maneras dentro de la clase `Meta`:
#
# *   **`widgets`:** Un diccionario que mapea nombres de campo a instancias de Widget para anular el widget por defecto.
# *   **`labels`:** Un diccionario que mapea nombres de campo a strings para anular la etiqueta generada.
# *   **`help_texts`:** Un diccionario que mapea nombres de campo a strings para el texto de ayuda.
# *   **`error_messages`:** Un diccionario anidado para personalizar mensajes de error por campo y por tipo de error.
# *   **`field_classes`:** Un diccionario para especificar una clase `Field` de formulario diferente para un campo de modelo.
#
# También puedes **sobrescribir un campo completamente** declarándolo explícitamente en la clase `ModelForm` (fuera de `Meta`), igual que harías en un `forms.Form`. Esto te da control total sobre ese campo específico, incluyendo sus validadores, `required`, etc., anulando lo generado desde el modelo para ese campo.
#
# ```python
# # forms.py
# class ProductoFormPersonalizado(forms.ModelForm):
#     # Sobrescribir el campo 'descripcion' para hacerlo no requerido
#     # y usar un widget con menos filas
#     descripcion = forms.CharField(required=False, widget=forms.Textarea(attrs={'rows': 3}))
#
#     class Meta:
#         model = Producto
#         fields = ['nombre', 'slug', 'categoria', 'descripcion', 'precio', 'stock']
#         # El 'descripcion' definido arriba anula el generado desde el modelo
# ```
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 23_4_Validacion_en_ModelForms
#
# `ModelForm` ejecuta varios niveles de validación:
#
# 1.  **Validación de Campos del Formulario:** Las validaciones básicas definidas en las clases `Field` del formulario (generadas o sobrescritas).
# 2.  **Validación de Campos del Modelo:** Ejecuta las validaciones inherentes a los campos del modelo (`max_length`, `unique`, etc.).
# 3.  **Método `clean_<nombrecampo>()` del Formulario:** Si defines estos métodos en tu `ModelForm`, se ejecutan para validaciones específicas de campo.
# 4.  **Método `clean()` del Modelo:** Si tu clase de modelo tiene un método `clean()`, `ModelForm` lo llamará para validaciones que involucran múltiples campos del *modelo*. **Nota:** Este método `clean()` del modelo **no** se llama automáticamente cuando llamas a `instancia.save()` directamente, pero sí se llama durante la validación del `ModelForm`.
# 5.  **Método `clean()` del Formulario:** Si defines `clean()` en tu `ModelForm`, se ejecuta al final para validaciones que involucran múltiples campos del *formulario*.
#
# Esto proporciona un sistema de validación robusto y en capas.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 23_5_Ejercicio_Practico_Crear_y_Procesar_ModelForm
#
# **Objetivo:** Crear un `ModelForm` para el modelo `Producto` y las vistas correspondientes para crear y editar productos.
#
# **Pasos:**
#
# 1.  **Crea `productos/forms.py`** (si no existe) e importa `forms` y el modelo `Producto`.
# 2.  **Define `ProductoForm(forms.ModelForm)`:**
#     *   Define la clase `Meta`.
#     *   Establece `model = Producto`.
#     *   Usa `fields` o `exclude` para seleccionar los campos editables (ej: excluye `fecha_creacion`, `fecha_actualizacion`).
#     *   (Opcional) Personaliza algún `widget` o `label`.
# 3.  **Crea/Modifica las vistas en `productos/views.py`:**
#     *   Crea `crear_producto_view(request)`:
#         *   Debe manejar GET y POST.
#         *   En POST, instancia `ProductoForm` con `request.POST` y `request.FILES`.
#         *   Si es válido, llama a `form.save()` (puedes usar `commit=False` si necesitas asignar `creado_por` a `request.user`, por ejemplo, y luego `instancia.save()` y `form.save_m2m()`).
#         *   Redirige al `get_absolute_url()` del producto creado (o a la lista).
#         *   En GET, instancia `ProductoForm()` vacío.
#         *   Renderiza una plantilla `productos/producto_form.html` con el formulario.
#     *   Crea `editar_producto_view(request, slug)` (o `pk`):
#         *   Obtén el `producto` a editar usando `get_object_or_404`.
#         *   (Opcional) Añade comprobación de permisos (ej: solo el creador puede editar).
#         *   En POST, instancia `ProductoForm` con `request.POST`, `request.FILES` **e `instance=producto`**.
#         *   Si es válido, llama a `form.save()`.
#         *   Redirige al `get_absolute_url()` del producto editado.
#         *   En GET, instancia `ProductoForm(instance=producto)`.
#         *   Renderiza la misma plantilla `productos/producto_form.html` con el formulario y opcionalmente el objeto `producto`.
# 4.  **Crea la plantilla `productos/templates/productos/producto_form.html`:**
#     *   Debe incluir `<form method="post" enctype="multipart/form-data">`.
#     *   Incluye `{% csrf_token %}`.
#     *   Renderiza el formulario (ej: `{{ form.as_p }}`).
#     *   Añade un botón submit.
#     *   (Opcional) Puedes variar el título (`<h1>`) o el texto del botón si estás creando o editando (comprobando si la variable `producto` existe en el contexto).
# 5.  **Define/Ajusta las URLs en `productos/urls.py`:**
#     *   Asegúrate de tener URLs con nombres (ej: `'crear_producto'`, `'editar_producto'`) que apunten a tus nuevas vistas y acepten los parámetros necesarios (slug o pk para editar).
#     *   Asegúrate de que tu modelo `Producto` tenga el método `get_absolute_url()` definido correctamente para que las redirecciones funcionen.
# 6.  **Prueba:**
#     *   Ejecuta `runserver`.
#     *   Navega a la URL de crear producto. Rellena y envía. Verifica que se cree y redirija.
#     *   Navega a la URL de editar un producto existente. Modifica datos y envía. Verifica que se actualice y redirija.
#     *   Prueba las validaciones (ej: dejar un campo requerido vacío).
#
# **Solución Propuesta:** (Se basa en el código de las secciones 23.1, 23.2 y las vistas/plantilla mostradas allí, adaptando nombres de URL y vistas si es necesario).
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ---
# ---
#
# ## **Unidad 6: Plantillas Avanzadas**
#
# ## 24_Herencia_de_Plantillas_extends_block_super
#
# La herencia de plantillas es una de las características más poderosas y fundamentales del sistema de plantillas de Django (DTL). Permite definir una estructura HTML base común (esqueleto) y luego crear plantillas "hijas" que heredan esa estructura pero sobrescriben o añaden contenido en bloques específicos. Esto promueve enormemente la reutilización de código (DRY) y facilita el mantenimiento de la apariencia consistente en todo un sitio web.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 24_1_Creacion_de_Plantilla_Base
#
# El primer paso es crear una plantilla base. Esta plantilla contiene el HTML común a la mayoría (o todas) las páginas de tu sitio.
#
# 1.  **Ubicación:** Generalmente se coloca en un directorio de plantillas a nivel de proyecto (el que definiste en `settings.TEMPLATES['DIRS']`, por ejemplo `mi_proyecto/templates/base.html`) o, si es una base específica para una sección grande del sitio, podría estar en `mi_app/templates/mi_app/base_app.html`.
# 2.  **Contenido:** Incluye la estructura HTML principal (`<!DOCTYPE html>`, `<html>`, `<head>`, `<body>`), elementos comunes como la cabecera (`<header>`), navegación (`<nav>`), pie de página (`<footer>`), y enlaces a CSS/JS globales.
# 3.  **Bloques `{% block %}`:** La clave de la herencia son las etiquetas `{% block nombre_del_bloque %}` ... `{% endblock %}`. Estas definen "agujeros" o secciones que las plantillas hijas pueden rellenar. Debes darles nombres descriptivos. Puedes incluir contenido por defecto dentro de un bloque, que se usará si la plantilla hija no lo sobrescribe.
#
# **Ejemplo (`templates/base.html`):**
# ```html
# {% load static %} {# Carga la etiqueta static si la usas #}
# <!DOCTYPE html>
# <html lang="es">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     {# Bloque para el título - con valor por defecto #}
#     <title>{% block titulo %}Mi Tienda Online{% endblock titulo %}</title>
#     {# CSS Base #}
#     <link rel="stylesheet" href="{% static 'css/base.css' %}">
#     {# Bloque para añadir CSS específico de cada página #}
#     {% block css_adicional %}{% endblock css_adicional %}
# </head>
# <body>
#     <header class="sitio-header">
#         <div class="contenedor-header">
#             <div class="logo">
#                 <a href="{% url 'home' %}">MiTienda</a> {# Asume URL 'home' #}
#             </div>
#             <nav class="navegacion-principal">
#                 <ul>
#                     <li><a href="{% url 'home' %}">Inicio</a></li>
#                     <li><a href="{% url 'productos:lista_productos' %}">Productos</a></li>
#                     {# ... más enlaces ... #}
#                     {% if user.is_authenticated %}
#                         <li><a href="#">Mi Cuenta ({{ user.username }})</a></li>
#                         <li><form action="{% url 'logout' %}" method="post" style="display:inline;">{% csrf_token %}<button type="submit" class="link-button">Salir</button></form></li>
#                     {% else %}
#                         <li><a href="{% url 'login' %}">Entrar</a></li>
#                     {% endif %}
#                 </ul>
#             </nav>
#         </div>
#     </header>
#
#     <main class="contenido-principal">
#         {# Bloque principal para el contenido específico de la página #}
#         {% block contenido %}
#             <p>Bienvenido a nuestro sitio.</p> {# Contenido por defecto #}
#         {% endblock contenido %}
#     </main>
#
#     <footer class="sitio-footer">
#         <p>&copy; {% now "Y" %} Mi Tienda Online. Todos los derechos.</p> {# Tag 'now' para año actual #}
#     </footer>
#
#     {# Bloque para añadir JS específico de cada página #}
#     {% block scripts %}
#     {# <script src="{% static 'js/base.js' %}"></script> #}
#     {% endblock scripts %}
# </body>
# </html>
# ```
# *Nombres de bloque comunes:* `titulo`, `contenido`, `sidebar`, `scripts`, `css_adicional`.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 24_2_Extension_y_Sobrescritura_de_Bloques
#
# Para usar la plantilla base, una plantilla hija debe:
#
# 1.  **Extender la Base:** La **primera** línea de la plantilla hija debe ser `{% extends 'ruta/a/base.html' %}`. La ruta es relativa a los directorios de plantillas configurados.
# 2.  **Sobrescribir Bloques:** Define los bloques `{% block nombre_del_bloque %}` ... `{% endblock nombre_del_bloque %}` que deseas rellenar o modificar. El contenido de la plantilla hija **solo** debe estar dentro de estos bloques (y opcionalmente etiquetas `{% load %}` al principio después de `extends`). Cualquier contenido fuera de un `{% block %}` en la hija será ignorado.
#
# **Ejemplo (`productos/templates/productos/lista_productos.html`):**
# ```html
# {# 1. Extender la plantilla base #}
# {% extends 'base.html' %}
# {% load static %} {# Cargar si es necesario aquí también #}
#
# {# 2. Sobrescribir el bloque 'titulo' #}
# {% block titulo %}Nuestros Productos - Mi Tienda Online{% endblock titulo %}
#
# {# 3. (Opcional) Sobrescribir 'css_adicional' #}
# {% block css_adicional %}
#     <link rel="stylesheet" href="{% static 'productos/css/lista_productos.css' %}">
# {% endblock css_adicional %}
#
# {# 4. Sobrescribir el bloque 'contenido' principal #}
# {% block contenido %}
#     <h1>{{ titulo_seccion|default:"Catálogo de Productos" }}</h1>
#
#     {% if lista_productos %}
#         <div class="grid-productos">
#             {% for prod in lista_productos %}
#                 <div class="tarjeta-producto">
#                     <h2>
#                         <a href="{% url 'productos:detalle_producto' producto_id=prod.id %}">
#                             {{ prod.nombre }}
#                         </a>
#                     </h2>
#                     <p>Precio: ${{ prod.precio|floatformat:2 }}</p>
#                     {# ... más detalles del producto ... #}
#                 </div>
#             {% endfor %}
#         </div>
#     {% else %}
#         <p>No hay productos que coincidan con tu búsqueda.</p>
#     {% endif %}
# {% endblock contenido %}
#
# {# 5. (Opcional) Sobrescribir 'scripts' #}
# {% block scripts %}
#     {# {{ block.super }} - Si quisieras incluir los scripts de la base Y añadir más #}
#     {# <script src="{% static 'productos/js/filtros_productos.js' %}"></script> #}
# {% endblock scripts %}
#
# ```
# Cuando Django renderice `lista_productos.html`, cargará `base.html`, encontrará los bloques y los reemplazará con el contenido definido en la plantilla hija. Si un bloque de la base no se define en la hija, se usará el contenido por defecto de la base (si lo tiene).
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 24_3_Uso_de_block_super
#
# A veces, no quieres reemplazar completamente el contenido de un bloque padre, sino **añadir** contenido antes o después de él. Para ello, puedes usar la variable especial `{{ block.super }}` dentro de un bloque hijo. Esto insertará el contenido renderizado del bloque con el mismo nombre de la plantilla padre.
#
# **Ejemplo (Añadir una clase CSS al body y un script extra):**
#
# **`base.html`:**
# ```html
# ...
# <body class="{% block clase_body %}base{% endblock clase_body %}">
# ...
# {% block scripts %}
#     <script src="{% static 'js/jquery.min.js' %}"></script> {# Script base #}
# {% endblock scripts %}
# ...
# ```
#
# **`pagina_especifica.html`:**
# ```html
# {% extends 'base.html' %}
# {% load static %}
#
# {% block clase_body %}{{ block.super }} pagina-con-sidebar{% endblock clase_body %} {# Añade clase #}
#
# {% block contenido %}
#     {# ... contenido específico ... #}
# {% endblock contenido %}
#
# {% block scripts %}
#     {{ block.super }} {# Incluye jquery.min.js de la base #}
#     <script src="{% static 'js/mi_script_especifico.js' %}"></script> {# Añade script específico #}
# {% endblock scripts %}
# ```
# El `<body>` renderizado tendrá `class="base pagina-con-sidebar"` y se cargarán ambos scripts.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 24_4_Ejercicio_Practico_Implementar_Herencia
#
# **Objetivo:** Crear una plantilla base simple y hacer que las plantillas de lista y detalle de productos hereden de ella.
#
# **Pasos:**
#
# 1.  **Crea `templates/base.html`** en la raíz del proyecto (si configuraste `DIRS` en `settings.py`) o en `productos/templates/productos/base_productos.html` (si usas `APP_DIRS`).
# 2.  **Define la estructura básica en `base.html`:** `DOCTYPE`, `html`, `head` (con `<title>`, `meta charset`, `meta viewport`), `body`.
# 3.  **Añade bloques:** Como mínimo, define `{% block titulo %}` dentro de `<title>` y `{% block contenido %}` dentro de `<body>`. Añade un título por defecto al bloque `titulo`.
# 4.  **Modifica `productos/templates/productos/lista_productos.html`:**
#     *   Añade `{% extends 'base.html' %}` (o la ruta correcta a tu base) al principio.
#     *   Envuelve el título existente (`<h1>...`) dentro de `{% block contenido %}` ... `{% endblock contenido %}`.
#     *   Envuelve el título de la página (`<title>...`) dentro de `{% block titulo %}` ... `{% endblock titulo %}`. Puedes usar `{{ block.super }}` si quieres.
#     *   Elimina las etiquetas `<html>`, `<head>`, `<body>` que ya no son necesarias porque se heredan.
# 5.  **Modifica `productos/templates/productos/detalle_producto.html`:**
#     *   Realiza los mismos pasos que para `lista_productos.html` (extender la base, envolver contenido en bloques, eliminar HTML redundante).
# 6.  **Ejecuta `runserver` y verifica:**
#     *   Visita la lista de productos (`/productos/`). Debería verse igual que antes, pero ahora usando la estructura de `base.html`. Revisa el código fuente HTML en el navegador para confirmarlo.
#     *   Visita la página de detalle de un producto. También debería usar la estructura base.
#
# **Solución Propuesta:**
#
# **`templates/base.html` (Ejemplo simple):**
# ```html
# <!DOCTYPE html>
# <html lang="es">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>{% block titulo %}Mi Tienda{% endblock titulo %}</title>
#     <style> body { font-family: sans-serif; margin: 20px; } </style> {# Estilo simple inline #}
# </head>
# <body>
#     <header>
#         <h1><a href="/">Mi Tienda Online</a></h1>
#         <hr>
#     </header>
#     <main>
#         {% block contenido %}
#             <p>Contenido por defecto.</p>
#         {% endblock contenido %}
#     </main>
#     <footer>
#         <hr>
#         <p>&copy; {% now "Y" %}</p>
#     </footer>
# </body>
# </html>
# ```
#
# **`productos/templates/productos/lista_productos.html` (Modificado):**
# ```html
# {% extends 'base.html' %}
#
# {% block titulo %}Productos - {{ block.super }}{% endblock titulo %}
#
# {% block contenido %}
#     <h1>{{ titulo_seccion|default:"Nuestros Productos" }}</h1>
#
#     {% if lista_productos %}
#         <ul>
#             {% for prod in lista_productos %}
#                 <li>
#                     <a href="{% url 'productos:detalle_producto' producto_id=prod.id %}">
#                         {{ prod.nombre }}
#                     </a>
#                     (Precio: ${{ prod.precio|floatformat:2 }})
#                 </li>
#             {% endfor %}
#         </ul>
#     {% else %}
#         <p>No hay productos disponibles en este momento.</p>
#     {% endif %}
# {% endblock contenido %}
# ```
#
# **`productos/templates/productos/detalle_producto.html` (Modificado):**
# ```html
# {% extends 'base.html' %}
#
# {% block titulo %}Detalle: {{ producto.nombre }} - Mi Tienda{% endblock titulo %}
#
# {% block contenido %}
#     <h1>{{ producto.nombre }}</h1>
#     <p><strong>ID:</strong> {{ producto.id }}</p>
#     <p><strong>Descripción:</strong> {{ producto.descripcion|linebreaksbr }}</p>
#     <p><strong>Stock:</strong> {{ producto.stock|default:"N/A" }}</p>
#
#     <hr>
#     <a href="{% url 'productos:lista_productos' %}">Volver a la lista</a>
# {% endblock contenido %}
# ```
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ## 25_Inclusion_de_Plantillas_include_with_only
#
# Mientras que `{% extends %}` es para la estructura principal, `{% include %}` se usa para insertar el contenido de *otra* plantilla (un fragmento reutilizable) dentro de la plantilla actual. Es perfecto para componentes como barras laterales, cabeceras parciales, formularios comunes, tarjetas de producto, etc.
#
# **Sintaxis:**
# `{% include 'ruta/al/fragmento.html' [with var1=valor1 var2=valor2 ...] [only] %}`
#
# *   `'ruta/al/fragmento.html'`: Ruta a la plantilla a incluir.
# *   `with var1=valor1 ...` (Opcional): Permite pasar variables *específicas* al contexto de la plantilla incluida. Las variables de la plantilla actual **no** están disponibles automáticamente en la incluida si usas `with`, a menos que las pases explícitamente.
# *   `only` (Opcional): Si se usa `only` (generalmente junto con `with`), la plantilla incluida **solo** tendrá acceso a las variables pasadas explícitamente con `with`. Si se omite `only` (y `with`), la plantilla incluida hereda el contexto completo de la plantilla actual.
#
# **Ejemplo: Crear una tarjeta de producto reutilizable.**
#
# **`productos/templates/productos/includes/tarjeta_producto.html`:**
# ```html
# {# Recibe una variable 'prod' en el contexto #}
# <div class="tarjeta-producto" style="border: 1px solid #eee; margin-bottom: 15px; padding: 10px;">
#     {% if prod.imagen %}
#         {# Asumiendo que tienes MEDIA_URL configurado para las imágenes #}
#         <img src="{{ prod.imagen.url }}" alt="{{ prod.nombre }}" style="max-width: 100px; float: left; margin-right: 10px;">
#     {% endif %}
#     <h3>
#         <a href="{{ prod.get_absolute_url }}">{{ prod.nombre }}</a>
#     </h3>
#     <p>Precio: ${{ prod.precio|floatformat:2 }}</p>
#     <p style="clear: both;">{{ prod.descripcion|truncatewords:15 }}</p>
#     {# Podrías añadir un botón "Añadir al carrito" aquí #}
# </div>
# ```
#
# **Uso en `productos/templates/productos/lista_productos.html`:**
# ```html
# {% extends 'base.html' %}
#
# {% block titulo %}Productos - {{ block.super }}{% endblock titulo %}
#
# {% block contenido %}
#     <h1>{{ titulo_seccion|default:"Catálogo de Productos" }}</h1>
#
#     {% if lista_productos %}
#         <div class="grid-productos">
#             {% for p in lista_productos %}
#                 {# Incluir la tarjeta, pasando el producto actual como 'prod' #}
#                 {% include 'productos/includes/tarjeta_producto.html' with prod=p %}
#             {% endfor %}
#         </div>
#     {% else %}
#         <p>No hay productos que coincidan con tu búsqueda.</p>
#     {% endif %}
# {% endblock contenido %}
# ```
# Ahora, el HTML para mostrar cada producto está encapsulado en `tarjeta_producto.html`, haciéndolo reutilizable y más fácil de mantener.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 25_1_Reutilizacion_de_Fragmentos_HTML
#
# El principal beneficio de `{% include %}` es la reutilización. Si tienes un fragmento de HTML que aparece en múltiples páginas (un formulario de búsqueda, un banner de cookies, información de contacto), ponlo en su propio archivo e inclúyelo donde lo necesites. Si necesitas cambiar ese fragmento, solo lo editas en un lugar.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 25_2_Pasando_Contexto_Adicional_with
#
# La cláusula `with` es útil cuando la plantilla incluida necesita datos específicos que no necesariamente están en el contexto principal, o cuando quieres pasar una variable del contexto principal con un *nombre diferente* dentro de la plantilla incluida.
#
# ```html
# {# Plantilla principal #}
# {% with item_actual=producto total_items=lista_productos|length %}
#     {% include 'includes/info_resumen.html' %}
# {% endwith %}
#
# {# En includes/info_resumen.html #}
# <p>Mostrando {{ item_actual.nombre }}. Total: {{ total_items }}.</p>
# ```
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 25_3_Aislando_Contexto_only
#
# Usar `only` asegura que la plantilla incluida no pueda acceder accidentalmente a variables del contexto principal que no le pasaste explícitamente con `with`. Esto mejora el encapsulamiento y hace que el fragmento incluido sea más predecible y verdaderamente reutilizable, ya que no depende del contexto externo.
#
# ```html
# {# Plantilla principal #}
# {% include 'includes/componente_aislado.html' with dato_necesario=valor only %}
#
# {# En includes/componente_aislado.html #}
# {# Solo la variable 'dato_necesario' está disponible aquí #}
# <p>El dato es: {{ dato_necesario }}</p>
# {# {{ alguna_otra_variable_del_contexto_principal }} -> Esto daría vacío #}
# ```
# Se recomienda usar `only` si el fragmento incluido está pensado para ser un componente verdaderamente independiente.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 25_4_Ejercicio_Practico_Usar_include
#
# **Objetivo:** Crear un fragmento HTML reutilizable para mostrar los detalles de una categoría y usar `{% include %}` para mostrarlo en alguna plantilla.
#
# **Pasos:**
#
# 1.  **Crea un archivo de plantilla** para el fragmento, por ejemplo: `productos/templates/productos/includes/detalle_categoria.html`.
# 2.  **Dentro de `detalle_categoria.html`:**
#     *   Asume que recibirá una variable llamada `categoria_obj` en el contexto.
#     *   Muestra el nombre de la categoría (`<h1>` o `<h2>`).
#     *   Muestra la descripción de la categoría (`<p>`), si existe.
#     *   (Opcional) Muestra un enlace a la lista de productos de esa categoría (si tuvieras esa URL).
# 3.  **Modifica una plantilla existente** (ej: `productos/lista_productos.html` o `productos/detalle_producto.html`) donde quieras mostrar esta información.
# 4.  **Carga una categoría** en la vista correspondiente (o usa una de ejemplo) y pásala al contexto con la clave `categoria_actual` (o el nombre que prefieras).
# 5.  **En la plantilla principal**, usa `{% include %}` para insertar el fragmento, pasando la categoría del contexto a la variable `categoria_obj` que espera el fragmento:
#     ```html
#     {% include 'productos/includes/detalle_categoria.html' with categoria_obj=categoria_actual %}
#     ```
# 6.  **Prueba** cargando la página en el navegador para ver si la información de la categoría se incluye correctamente.
#
# **Solución Propuesta:**
#
# **`productos/templates/productos/includes/detalle_categoria.html`:**
# ```html
# {# Espera una variable 'categoria_obj' #}
# <div class="info-categoria" style="background-color: #f8f8f8; border: 1px solid #ddd; padding: 15px; margin-bottom: 20px;">
#     <h2>Categoría: {{ categoria_obj.nombre }}</h2>
#     {% if categoria_obj.descripcion %}
#         <p>{{ categoria_obj.descripcion }}</p>
#     {% endif %}
#     {# Asumiendo una URL 'productos:lista_por_categoria' que acepta slug_categoria #}
#     {# <p><a href="{% url 'productos:lista_por_categoria' slug_categoria=categoria_obj.slug %}">Ver todos los productos de esta categoría</a></p> #}
# </div>
# ```
#
# **`productos/views.py` (Modificar `detalle_producto_view`):**
# ```python
# # productos/views.py
# from django.shortcuts import render, get_object_or_404
# from .models import Producto, Categoria # Asegúrate de importar Categoria
#
# # ... (lista_productos_view) ...
#
# def detalle_producto_view(request, producto_id): # O usa slug si lo cambiaste
#     # producto = get_object_or_404(Producto, pk=producto_id)
#     producto_ejemplo = { # Usando ejemplo
#         'id': producto_id,
#         'nombre': f'Producto Ejemplo {producto_id}',
#         'descripcion': f'Esta es la descripción del producto {producto_id}.\nEs realmente fantástico.',
#         'stock': producto_id * 3,
#         'categoria': Categoria(id=1, nombre="Tecnologia", slug="tecnologia", descripcion="Artículos electrónicos") # Objeto Categoria de ejemplo
#     }
#     contexto = {
#         'producto': producto_ejemplo,
#         # Pasar la categoría al contexto (obtenida del producto)
#         'categoria_actual': producto_ejemplo.get('categoria')
#     }
#     return render(request, 'productos/detalle_producto.html', contexto)
# ```
#
# **`productos/templates/productos/detalle_producto.html` (Añadir include):**
# ```html
# {% extends 'base.html' %}
#
# {% block titulo %}Detalle: {{ producto.nombre }} - Mi Tienda{% endblock titulo %}
#
# {% block contenido %}
#
#     {# Incluir la información de la categoría si existe #}
#     {% if categoria_actual %}
#         {% include 'productos/includes/detalle_categoria.html' with categoria_obj=categoria_actual %}
#     {% endif %}
#
#     <h1>{{ producto.nombre }}</h1>
#     <p><strong>ID:</strong> {{ producto.id }}</p>
#     <p><strong>Descripción:</strong> {{ producto.descripcion|linebreaksbr }}</p>
#     <p><strong>Stock:</strong> {{ producto.stock|default:"N/A" }}</p>
#
#     <hr>
#     <a href="{% url 'productos:lista_productos' %}">Volver a la lista</a>
# {% endblock contenido %}
# ```
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ## 26_Filtros_de_Plantillas_Built_in_y_Personalizados
#
# Los filtros modifican la apariencia o el formato de las variables antes de que se muestren en la plantilla. Se aplican usando el símbolo `|`.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 26_1_Revision_Filtros_Comunes
#
# Django proporciona muchos filtros útiles incorporados. Algunos ejemplos adicionales a los ya vistos:
#
# *   `addslashes`: Añade barras invertidas antes de comillas.
# *   `cut:" "` : Elimina todas las ocurrencias del argumento (ej: espacios).
# *   `dictsort:"clave"`: Ordena una lista de diccionarios por una clave dada.
# *   `filesizeformat`: Formatea un número de bytes en un tamaño legible (KB, MB, GB).
# *   `first`: Devuelve el primer elemento de una lista.
# *   `last`: Devuelve el último elemento de una lista.
# *   `make_list`: Convierte un valor (ej: string, int) en una lista de sus componentes.
# *   `random`: Devuelve un elemento aleatorio de una lista.
# *   `slice:":N"`: Obtiene una porción (slice) de una lista o string.
# *   `striptags`: Elimina todas las etiquetas [X]HTML.
# *   `time:"formato"`: Formatea una hora.
# *   `timesince`: Muestra el tiempo transcurrido desde una fecha.
# *   `urlencode`: Codifica un texto para usarlo en una URL.
# *   `wordcount`: Devuelve el número de palabras.
#
# Consulta siempre la [documentación oficial](https://docs.djangoproject.com/en/stable/ref/templates/builtins/#built-in-filter-reference) para la lista completa y detalles de uso.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 26_2_Creacion_de_Filtros_Personalizados_templatetags
#
# Si necesitas una transformación que no existe, puedes crear tus propios filtros.
#
# 1.  **Crea `mi_app/templatetags/`** (si no existe) con un `__init__.py` vacío.
# 2.  **Crea un archivo Python** para tus filtros (ej: `mi_app/templatetags/mis_filtros.py`).
# 3.  **Importa `template` y define/registra tu función:**
#
# **Ejemplo (`productos/templatetags/filtros_productos.py`):**
# ```python
# from django import template
# from decimal import Decimal, InvalidOperation # Para manejar precios
#
# register = template.Library() # Necesario para registrar
#
# @register.filter(name='anadir_iva') # 'name' es opcional, si no se usa el nombre de la func.
# def anadir_iva(valor, porcentaje_iva=21):
#     """
#     Añade un porcentaje de IVA a un valor numérico (precio).
#     Uso: {{ precio_base | anadir_iva }} o {{ precio_base | anadir_iva:10 }}
#     """
#     try:
#         valor_decimal = Decimal(valor)
#         porcentaje_decimal = Decimal(porcentaje_iva)
#         iva = (valor_decimal * porcentaje_decimal) / 100
#         return (valor_decimal + iva).quantize(Decimal("0.01")) # Redondear a 2 decimales
#     except (TypeError, ValueError, InvalidOperation):
#         return valor # Devolver el valor original si no es un número válido
#
# @register.filter
# def reemplazar(valor, args):
#     """
#     Reemplaza ocurrencias en un string.
#     Uso: {{ mi_texto | reemplazar:"viejo,nuevo" }}
#     """
#     if isinstance(valor, str) and isinstance(args, str):
#         try:
#             antiguo, nuevo = args.split(',', 1)
#             return valor.replace(antiguo, nuevo)
#         except ValueError:
#             # No se pudo separar el argumento
#             pass
#     return valor
# ```
# *   La función de filtro debe aceptar al menos un argumento (el valor al que se aplica).
# *   Puede aceptar un segundo argumento opcional (pasado después de `:` en la plantilla). Si necesitas más argumentos, pásalos como un string y pársalo dentro del filtro (como en `reemplazar`).
# *   El decorador `@register.filter` registra la función. `name=` permite darle un nombre diferente en la plantilla.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 26_3_Registro_y_Uso_load
#
# Para usar tus filtros personalizados en una plantilla:
#
# 1.  **Carga** el archivo de la librería de template tags al principio de la plantilla (después de `{% extends %}` si lo hay):
#     `{% load nombre_del_archivo_py %}` (sin la extensión `.py`).
#     ```html
#     {% extends 'base.html' %}
#     {% load filtros_productos %} {# Carga los filtros definidos en filtros_productos.py #}
#     ```
# 2.  **Aplica** el filtro usando la sintaxis `|`:
#     ```html
#     <p>Precio sin IVA: ${{ producto.precio|floatformat:2 }}</p>
#     <p>Precio con IVA (21%): ${{ producto.precio|anadir_iva|floatformat:2 }}</p> {# IVA por defecto #}
#     <p>Precio con IVA (10%): ${{ producto.precio|anadir_iva:10|floatformat:2 }}</p> {# IVA específico #}
#
#     {% with descripcion_modificada=producto.descripcion|reemplazar:"fantástico,genial" %}
#         <p>Descripción Modificada: {{ descripcion_modificada }}</p>
#     {% endwith %}
#     ```
#
# *Recuerda reiniciar el servidor de desarrollo después de crear o modificar archivos en `templatetags`.*
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 26_4_Ejercicio_Practico_Crear_un_Filtro
#
# **Objetivo:** Crear un filtro personalizado que convierta un string a "tipo título" pero manteniendo ciertas preposiciones/artículos en minúscula (ej: "un titulo de ejemplo" -> "Un Titulo de Ejemplo").
#
# **Pasos:**
#
# 1.  **Crea (si no existe) `productos/templatetags/`** y un `__init__.py` vacío dentro.
# 2.  **Crea `productos/templatetags/filtros_titulos.py`**.
# 3.  **Dentro de `filtros_titulos.py`:**
#     *   Importa `template`.
#     *   Crea `register = template.Library()`.
#     *   Define una función `titulo_inteligente(valor)`.
#     *   Dentro de la función:
#         *   Define una lista de palabras pequeñas a mantener en minúscula (ej: `['a', 'un', 'una', 'de', 'del', 'el', 'la', 'los', 'las', 'en', 'por', 'para', 'con', 'y', 'o', 'e']`).
#         *   Convierte el `valor` a string y a minúsculas (`lower()`).
#         *   Separa el string en palabras (`split()`).
#         *   Itera sobre las palabras: pon la primera letra de cada palabra en mayúscula (`capitalize()`) **a menos que** la palabra esté en tu lista de palabras pequeñas **y no sea** la primera palabra de la frase.
#         *   Une las palabras de nuevo en un string (`join(' ')`).
#         *   Devuelve el string resultante.
#     *   Registra la función como filtro: `@register.filter`.
# 4.  **En una plantilla** (ej: `productos/detalle_producto.html`):
#     *   Carga la librería: `{% load filtros_titulos %}`.
#     *   Aplica el filtro al nombre del producto: `{{ producto.nombre|titulo_inteligente }}`.
# 5.  **Prueba** con nombres de producto que incluyan preposiciones o artículos para ver el resultado.
#
# **Solución Propuesta (`productos/templatetags/filtros_titulos.py`):**
# ```python
# from django import template
#
# register = template.Library()
#
# @register.filter(name='titulo_inteligente')
# def titulo_inteligente(valor):
#     """Convierte un string a formato título, manteniendo artículos/preposiciones cortas en minúscula (excepto al inicio)."""
#     if not isinstance(valor, str):
#         return valor
#
#     palabras_pequenas = ['a', 'un', 'una', 'de', 'del', 'el', 'la', 'los', 'las', 'en', 'por', 'para', 'con', 'y', 'o', 'e', 'que']
#     palabras = valor.lower().split()
#     resultado = []
#
#     for i, palabra in enumerate(palabras):
#         if i == 0 or palabra not in palabras_pequenas:
#             resultado.append(palabra.capitalize())
#         else:
#             resultado.append(palabra)
#
#     return " ".join(resultado)
#
# ```
# **Uso en plantilla:**
# ```html
# {% load filtros_titulos %}
# ...
# <h1>{{ producto.nombre | titulo_inteligente }}</h1>
# ...
# ```
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ## 27_Etiquetas_Tags_de_Plantillas_Built_in_y_Personalizadas
#
# Las etiquetas (`{% tag %}`) son más potentes que los filtros y controlan el flujo, cargan datos o generan salidas complejas.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 27_1_Revision_Tags_Comunes
#
# Ya hemos usado muchas etiquetas incorporadas esenciales:
# *   **Control de Flujo:** `if/elif/else/endif`, `for/empty/endfor`.
# *   **Herencia/Inclusión:** `extends`, `block/endblock`, `include`.
# *   **Carga:** `load`.
# *   **URLs:** `url`.
# *   **Estáticos:** `static`.
# *   **Formularios:** `csrf_token`.
# *   **Comentarios:** `comment/endcomment`.
#
# Otras etiquetas útiles:
# *   `with ... as ...`: Crea una variable temporal dentro de un bloque. `{% with total=items.count %}{{ total }} item{{ total|pluralize }}{% endwith %}`.
# *   `now "formato"`: Muestra la fecha/hora actual formateada. `{% now "d/m/Y H:i" %}`.
# *   `cycle`: Alterna entre una serie de valores en cada iteración de un bucle. `{% for obj in object_list %}<tr class="{% cycle 'row1' 'row2' %}">...</tr>{% endfor %}`.
# *   `firstof`: Muestra la primera variable de una lista que no sea "falsy". `{% firstof var1 var2 var3 "Valor por defecto" %}`.
# *   `filter`: Aplica filtros a un bloque de texto. `{% filter lower|capfirst %}Texto a filtrar{% endfilter %}`.
# *   `autoescape on/off`: Controla el autoescapado de HTML dentro de un bloque.
#
# Consulta la [documentación oficial](https://docs.djangoproject.com/en/stable/ref/templates/builtins/#built-in-tag-reference) para la lista completa.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 27_2_Creacion_de_Simple_Tags
#
# Permiten definir funciones Python que aceptan argumentos (posicionales o de palabra clave) desde la plantilla, realizan alguna lógica y devuelven un **string** que se inserta en la salida HTML.
#
# **Ejemplo (Obtener posts recientes de una categoría):**
# ```python
# # productos/templatetags/tags_productos.py
# from django import template
# from ..models import Producto, Categoria
#
# register = template.Library()
#
# @register.simple_tag(name="productos_recientes_categoria")
# def obtener_productos_recientes_por_categoria(slug_categoria, cantidad=3):
#     """
#     Devuelve una lista (QuerySet) de los 'cantidad' productos más recientes
#     de una categoría específica por su slug.
#     ¡OJO! Devolver QuerySets directamente puede ser ineficiente si se usa mal.
#     A menudo es mejor para tags que devuelven strings o valores simples.
#     Para renderizar HTML complejo, usa inclusion_tag.
#     """
#     try:
#         categoria = Categoria.objects.get(slug=slug_categoria)
#         # ¡Esto devuelve un QuerySet! La plantilla tendrá que iterarlo.
#         return Producto.objects.filter(categoria=categoria, disponible=True).order_by('-fecha_creacion')[:cantidad]
#     except Categoria.DoesNotExist:
#         return Producto.objects.none() # Devuelve QuerySet vacío si no existe
#
# @register.simple_tag
# def formato_precio_especial(precio):
#     """Devuelve un string HTML formateado para el precio."""
#     from django.utils.html import format_html
#     from decimal import Decimal
#     try:
#         precio_decimal = Decimal(precio)
#         return format_html('<span style="color: green; font-weight: bold;">${:.2f}</span>', precio_decimal)
#     except:
#         return "" # O algún valor por defecto
# ```
#
# **Uso en plantilla:**
# ```html
# {% load tags_productos %}
#
# {# Ejemplo 1: Obtener queryset y luego iterar (menos ideal para simple_tag) #}
# {% productos_recientes_categoria 'electronica' 5 as prods_tec_recientes %}
# {% if prods_tec_recientes %}
#     <ul>
#     {% for prod in prods_tec_recientes %}
#         <li>{{ prod.nombre }}</li>
#     {% endfor %}
#     </ul>
# {% endif %}
#
# {# Ejemplo 2: Devolver HTML formateado #}
# <p>Precio Ofertado: {% formato_precio_especial producto.precio %}</p>
# ```
# *   Usar `as nombre_variable` permite guardar el resultado de la `simple_tag` en una variable de contexto en lugar de imprimirlo directamente.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 27_3_Creacion_de_Inclusion_Tags
#
# Son más adecuadas cuando necesitas generar un **fragmento de HTML renderizando otra plantilla** con un contexto específico. Son perfectas para componentes de UI reutilizables que requieren lógica o consultas a la BD.
#
# **Pasos:**
# 1.  Define la función Python (que acepta argumentos y devuelve un **diccionario de contexto**).
# 2.  Crea la plantilla HTML separada que será renderizada.
# 3.  Registra la función usando `@register.inclusion_tag('ruta/a/la/plantilla.html')`.
#
# **Ejemplo (Mostrar una lista de categorías como enlaces):**
#
# **`productos/templatetags/tags_productos.py`:**
# ```python
# # productos/templatetags/tags_productos.py (continuación)
# # ... (imports y register) ...
#
# @register.inclusion_tag('productos/includes/lista_categorias_tag.html')
# def mostrar_menu_categorias(categoria_activa=None):
#     """
#     Renderiza una lista de enlaces de categorías,
#     marcando opcionalmente la categoría activa.
#     """
#     categorias = Categoria.objects.all() # Obtener todas las categorías
#     # Devuelve el contexto para la plantilla 'lista_categorias_tag.html'
#     return {
#         'lista_categorias': categorias,
#         'categoria_activa': categoria_activa # Puede ser None o una instancia de Categoria
#     }
# ```
#
# **`productos/templates/productos/includes/lista_categorias_tag.html`:**
# ```html
# {# Recibe 'lista_categorias' y 'categoria_activa' del contexto de la tag #}
# <ul class="menu-categorias">
#     {% for cat in lista_categorias %}
#         <li {% if categoria_activa and cat.slug == categoria_activa.slug %}class="activo"{% endif %}>
#             {# Asumiendo URL 'productos:lista_por_categoria' con slug #}
#             <a href="#">{{ cat.nombre }}</a>
#             {# <a href="{% url 'productos:lista_por_categoria' slug_categoria=cat.slug %}">{{ cat.nombre }}</a> #}
#         </li>
#     {% empty %}
#         <li>No hay categorías.</li>
#     {% endfor %}
# </ul>
# ```
#
# **Uso en plantilla (ej: `base.html` o `sidebar.html`):**
# ```html
# {% load tags_productos %}
#
# <div class="widget-categorias">
#     <h3>Explorar Categorías</h3>
#     {# Llamar a la tag. 'categoria_actual' sería una variable pasada desde la vista si existe #}
#     {% mostrar_menu_categorias categoria_actual %}
# </div>
# ```
# La `inclusion_tag` ejecutará la función, obtendrá las categorías, renderizará `lista_categorias_tag.html` con ese contexto, y el HTML resultante se insertará donde se llamó a la tag.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 27_4_Registro_y_Uso
#
# **Recordatorio:**
# *   Los archivos de tags/filtros deben estar en `mi_app/templatetags/`.
# *   Debe existir `mi_app/templatetags/__init__.py`.
# *   Se usa `{% load nombre_archivo_tags %}` en la plantilla para cargar las definiciones.
# *   Se reinicia el servidor de desarrollo al crear/modificar estos archivos.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 27_5_Ejercicio_Practico_Crear_Tags_Simples_e_Inclusion
#
# **Objetivo:** Crear una `simple_tag` que muestre el número total de productos disponibles y una `inclusion_tag` que muestre los N productos más caros.
#
# **Pasos:**
#
# 1.  **Crea/Abre `productos/templatetags/tags_productos.py`** (y el `__init__.py` en la carpeta).
# 2.  **Define `total_productos_disponibles()`:**
#     *   Decórala con `@register.simple_tag`.
#     *   Consulta `Producto.objects.filter(disponible=True).count()` y devuelve el resultado.
# 3.  **Define `mostrar_productos_caros(cantidad)`:**
#     *   Decórala con `@register.inclusion_tag('productos/includes/productos_caros.html')`.
#     *   Acepta un argumento `cantidad` (default a 3 o 5).
#     *   Consulta los `cantidad` productos disponibles ordenados por precio descendente (`order_by('-precio')`).
#     *   Devuelve un diccionario de contexto, ej: `{'productos_caros': queryset_resultado}`.
# 4.  **Crea la plantilla `productos/templates/productos/includes/productos_caros.html`:**
#     *   Recibe la variable `productos_caros`.
#     *   Itera sobre ella con `{% for %}`.
#     *   Muestra el nombre y precio de cada producto caro en una lista `<ul>`.
#     *   Incluye un bloque `{% empty %}`.
# 5.  **En una plantilla principal (ej: `base.html` o `lista_productos.html`):**
#     *   Carga la librería: `{% load tags_productos %}`.
#     *   Llama a la `simple_tag`: `Total disponibles: {% total_productos_disponibles %}`.
#     *   Llama a la `inclusion_tag`: `{% mostrar_productos_caros 5 %}`.
# 6.  **Prueba** en el navegador.
#
# **Solución Propuesta:**
#
# **`productos/templatetags/tags_productos.py`:**
# ```python
# from django import template
# from ..models import Producto
#
# register = template.Library()
#
# @register.simple_tag
# def total_productos_disponibles():
#     """Devuelve el número total de productos disponibles."""
#     return Producto.objects.filter(disponible=True).count()
#
# @register.inclusion_tag('productos/includes/productos_caros.html')
# def mostrar_productos_caros(cantidad=3):
#     """Renderiza una lista con los N productos disponibles más caros."""
#     productos = Producto.objects.filter(disponible=True).order_by('-precio')[:cantidad]
#     return {'productos_caros': productos}
# ```
#
# **`productos/templates/productos/includes/productos_caros.html`:**
# ```html
# <ul>
#     {% for prod in productos_caros %}
#         <li>{{ prod.nombre }} (${{ prod.precio|floatformat:2 }})</li>
#     {% empty %}
#         <li>No hay productos destacados.</li>
#     {% endfor %}
# </ul>
# ```
#
# **Uso en plantilla (ej: `base.html`):**
# ```html
# {% load tags_productos %}
# ...
# <footer>
#     <hr>
#     <p>Total productos disponibles: {% total_productos_disponibles %}</p>
#     <div>
#         <h3>Top Productos</h3>
#         {% mostrar_productos_caros 5 %} {# Muestra los 5 más caros #}
#     </div>
#     <p>&copy; {% now "Y" %}</p>
# </footer>
# ...
# ```
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ## 28_Context_Processors
#
# Los procesadores de contexto son una forma de hacer que ciertas variables estén disponibles **automáticamente** en el contexto de **todas** las plantillas que se renderizan usando `RequestContext` (que es lo que `render()` usa por defecto). Evitan tener que añadir manualmente datos comunes (como categorías del menú, número de items en el carrito, etc.) al diccionario de contexto en cada una de tus vistas.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 28_1_Anadiendo_Datos_Globales_al_Contexto
#
# El objetivo es definir una función que calcule o recupere ciertos datos y devuelva un diccionario. Las claves de ese diccionario se añadirán al contexto global.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 28_2_Creacion_y_Registro_en_settings
#
# 1.  **Crea la función:** Define una función Python que acepte `request` como argumento y devuelva un diccionario. Puedes colocarla en cualquier lugar, pero una convención es crear un archivo `context_processors.py` dentro de una aplicación relevante.
#     ```python
#     # productos/context_processors.py
#     from .models import Categoria
#
#     def menu_categorias(request):
#         """
#         Hace que la lista de todas las categorías esté disponible
#         en todas las plantillas.
#         """
#         categorias = Categoria.objects.all().order_by('nombre')
#         return {'menu_categorias': categorias} # La clave 'menu_categorias' será la variable global
#     ```
# 2.  **Registra la función en `settings.py`:** Añade la ruta punteada a tu función dentro de la lista `'context_processors'` en la configuración `TEMPLATES`.
#     ```python
#     # tienda_config/settings.py
#     TEMPLATES = [
#         {
#             'BACKEND': 'django.template.backends.django.DjangoTemplates',
#             'DIRS': [BASE_DIR / 'templates'],
#             'APP_DIRS': True,
#             'OPTIONS': {
#                 'context_processors': [
#                     'django.template.context_processors.debug',
#                     'django.template.context_processors.request', # Necesario
#                     'django.contrib.auth.context_processors.auth',
#                     'django.contrib.messages.context_processors.messages',
#                     # ---- Tu procesador ----
#                     'productos.context_processors.menu_categorias', # Ruta a la función
#                 ],
#             },
#         },
#     ]
#     ```
# 3.  **Usa la variable global en cualquier plantilla:** Ahora, la variable `menu_categorias` estará disponible en todas las plantillas renderizadas con `render()`, sin necesidad de pasarla explícitamente desde la vista.
#     ```html
#     {# base.html (o cualquier plantilla) #}
#     <nav>
#         <h4>Categorías Globales</h4>
#         <ul>
#             {% for cat in menu_categorias %} {# Acceso directo a la variable global #}
#                 <li><a href="#">{{ cat.nombre }}</a></li>
#             {% endfor %}
#         </ul>
#     </nav>
#     ```
#
# Django ya incluye procesadores útiles por defecto que añaden `request`, `user`, `perms`, y `messages` al contexto.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 28_3_Ejercicio_Practico_Crear_un_Context_Processor
#
# **Objetivo:** Crear un context processor que añada el año actual al contexto global para mostrarlo fácilmente en el pie de página.
#
# **Pasos:**
#
# 1.  **Crea (si no existe) `productos/context_processors.py`**.
# 2.  **Define una función** `datos_globales(request)` dentro de ese archivo.
#     *   Importa `datetime` de `datetime`.
#     *   Haz que la función devuelva un diccionario con una clave, por ejemplo `'anio_actual'`, y el valor `datetime.date.today().year`.
# 3.  **Registra** la ruta a esta función (`'productos.context_processors.datos_globales'`) en la lista `context_processors` de `settings.py`.
# 4.  **Modifica tu plantilla base (`base.html`)**: Reemplaza `{% now "Y" %}` en el footer por `{{ anio_actual }}`.
# 5.  **Reinicia el servidor y verifica** que el año actual sigue apareciendo correctamente en el pie de página, ahora obtenido a través del context processor.
#
# **Solución Propuesta:**
#
# **`productos/context_processors.py`:**
# ```python
# import datetime
#
# def datos_globales(request):
#     """Añade datos globales al contexto de las plantillas."""
#     return {
#         'anio_actual': datetime.date.today().year,
#         # Podrías añadir más variables globales aquí
#     }
# ```
#
# **`tienda_config/settings.py` (añadir a `context_processors`):**
# ```python
# # ... (dentro de TEMPLATES[0]['OPTIONS']['context_processors'])
# 'productos.context_processors.datos_globales',
# # ...
# ```
#
# **`templates/base.html` (modificar footer):**
# ```html
# ...
# <footer>
#     <hr>
#     <p>&copy; {{ anio_actual }} Mi Tienda Online. Todos los derechos.</p> {# Usando la variable global #}
# </footer>
# ...
# ```
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ---
# ---
#
# ## **Unidad 7: Archivos Estáticos y de Medios**
#
# ## 29_Concepto_de_Archivos_Estaticos_CSS_JS_Imagenes
#
# En una aplicación web, además del HTML generado dinámicamente por Django, necesitas servir otros archivos que son parte fundamental de la presentación y funcionalidad del frontend. Estos se clasifican en dos tipos principales en Django:
#
# 1.  **Archivos Estáticos (Static Files):**
#     *   **Definición:** Son archivos que forman parte de tu aplicación y **no cambian** mientras la aplicación se ejecuta (o cambian solo cuando actualizas el código). No son generados por los usuarios.
#     *   **Ejemplos:** Hojas de estilo CSS (`.css`), código JavaScript del lado del cliente (`.js`), imágenes fijas del diseño (logos, iconos, fondos - `.png`, `.jpg`, `.svg`), fuentes web (`.woff2`, `.ttf`).
#     *   **Gestión:** Django proporciona la aplicación `django.contrib.staticfiles` para ayudar a encontrarlos y gestionarlos durante el desarrollo y para recopilarlos para producción.
#     *   **Servicio en Producción:** Deben ser servidos directamente por el servidor web (Nginx, Apache) por eficiencia, no por la aplicación Django/WSGI.
#
# 2.  **Archivos de Medios (Media Files):**
#     *   **Definición:** Son archivos que son **subidos por los usuarios** de tu aplicación o generados dinámicamente por la aplicación y que necesitan ser almacenados.
#     *   **Ejemplos:** Fotos de perfil de usuario, imágenes de productos subidas por administradores, documentos adjuntos en formularios, archivos generados (PDFs, etc.).
#     *   **Gestión:** Django gestiona su almacenamiento a través de los campos `FileField` e `ImageField` en los modelos y las configuraciones `MEDIA_ROOT` y `MEDIA_URL`.
#     *   **Servicio en Producción:** Al igual que los estáticos, generalmente deben ser servidos por el servidor web o, en aplicaciones más grandes, a través de servicios de almacenamiento dedicados (como Amazon S3, Google Cloud Storage).
#
# Esta unidad se centrará en cómo configurar Django para manejar ambos tipos de archivos correctamente tanto en desarrollo como en preparación para producción.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ## 30_Configuracion_STATIC_URL_STATICFILES_DIRS_STATIC_ROOT
#
# La configuración para los archivos *estáticos* se realiza en tu archivo `settings.py`.
#
# ```python
# # mi_sitio/settings.py (o el nombre de tu carpeta de proyecto)
# import os
# from pathlib import Path
#
# BASE_DIR = Path(__file__).resolve().parent.parent
#
# # ... otras settings ...
#
# # --- Configuración de Archivos Estáticos ---
#
# # URL para referenciar archivos estáticos en plantillas y HTML generado.
# # Debe terminar en '/'. Comúnmente '/static/'.
# STATIC_URL = 'static/'
#
# # Lista de directorios donde Django buscará archivos estáticos ADEMÁS
# # de las carpetas 'static/' dentro de cada app en INSTALLED_APPS.
# # Útil para estáticos globales del proyecto o de librerías externas.
# STATICFILES_DIRS = [
#     BASE_DIR / 'static', # Convención: una carpeta 'static' en la raíz del proyecto
# ]
#
# # Ruta ABSOLUTA al directorio donde `collectstatic` COPIARÁ TODOS
# # los archivos estáticos para el despliegue en producción.
# # ¡NUNCA pongas archivos aquí directamente en desarrollo!
# # Debe ser una ruta fuera de tu código fuente y servible por tu servidor web.
# STATIC_ROOT = BASE_DIR / 'staticfiles_produccion'
#
# # Finder que busca en las carpetas 'static/' de las apps instaladas.
# # Finder que busca en los directorios listados en STATICFILES_DIRS.
# # (Estos suelen ser los valores por defecto y suficientes)
# STATICFILES_FINDERS = [
#     'django.contrib.staticfiles.finders.FileSystemFinder',
#     'django.contrib.staticfiles.finders.AppDirectoriesFinder',
# ]
#
# # Asegúrate de que 'django.contrib.staticfiles' esté en INSTALLED_APPS
# INSTALLED_APPS = [
#     # ...
#     'django.contrib.staticfiles', # <--- Esencial
#     # ...
#     'productos', # Tu app
# ]
# ```
#
# **Explicación Detallada:**
#
# *   **`STATIC_URL`:** Es la **base de la URL** que se usará en el navegador para acceder a los archivos estáticos (ej: `/static/blog/css/estilo_blog.css`). No es una ruta del sistema de archivos.
# *   **`STATICFILES_DIRS`:** Es una **lista de rutas del sistema de archivos** donde guardas archivos estáticos que *no* pertenecen a una aplicación específica (ej: CSS/JS global, logos del sitio). Django buscará archivos aquí *además* de buscar en la carpeta `static/` de cada aplicación listada en `INSTALLED_APPS` (gracias a `AppDirectoriesFinder`). La convención común es crear una carpeta `static/` en la raíz del proyecto (al mismo nivel que `manage.py`) y añadirla aquí.
# *   **`STATIC_ROOT`:** Es la **ruta del sistema de archivos** donde el comando `manage.py collectstatic` **copiará** todos los archivos estáticos encontrados (tanto los de `STATICFILES_DIRS` como los de las carpetas `static/` de las apps) en un solo lugar para facilitar el servicio en producción. **No debes poner ningún archivo aquí manualmente**, y este directorio **no** debe ser uno de los listados en `STATICFILES_DIRS`. Es únicamente el destino de `collectstatic`. En producción, configurarás Nginx o Apache para servir los archivos que se encuentren en esta carpeta `STATIC_ROOT` cuando la URL solicitada comience con `STATIC_URL`.
#
# **Importante:** Para que el servidor de desarrollo (`runserver`) sirva automáticamente los archivos estáticos (desde `STATICFILES_DIRS` y las carpetas `static/` de las apps), solo necesitas tener `django.contrib.staticfiles` en `INSTALLED_APPS` y `DEBUG = True`. No utiliza `STATIC_ROOT` en desarrollo.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 30_1_STATIC_URL_vs_STATIC_ROOT
#
# Es fundamental entender la diferencia:
# *   `STATIC_URL`: Es una **URL** (relativa o absoluta) usada en el navegador. Define *cómo* se accede a los archivos estáticos desde la web.
# *   `STATIC_ROOT`: Es una **ruta del sistema de archivos** en el servidor. Define *dónde* se encuentran *todos* los archivos estáticos recopilados para ser servidos en producción.
#
# En **desarrollo** (`DEBUG=True`), Django mapea mágicamente `STATIC_URL` a los archivos encontrados en `STATICFILES_DIRS` y las carpetas `static/` de las apps.
#
# En **producción** (`DEBUG=False`), Django **no** sirve archivos estáticos. Tu servidor web (Nginx/Apache) debe configurarse para interceptar las peticiones a `STATIC_URL` y servir los archivos correspondientes desde el directorio `STATIC_ROOT` (que previamente llenaste con `collectstatic`).
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 30_2_Ubicacion_de_Archivos_Estaticos_Apps_vs_Global
#
# Tienes dos lugares principales para organizar tus archivos estáticos:
#
# 1.  **Dentro de cada Aplicación:**
#     *   Crea `nombre_app/static/nombre_app/`. El subdirectorio extra con el nombre de la app es crucial para evitar colisiones (namespacing).
#     *   Ejemplo: `productos/static/productos/css/estilos_productos.css`.
#     *   **Ventaja:** Mantiene los estáticos relacionados con una app junto a su código, haciendo la app más autocontenida y reutilizable.
#     *   Django los encuentra automáticamente si `APP_DIRS` es `True` en la configuración `TEMPLATES` y `'django.contrib.staticfiles'` está en `INSTALLED_APPS`.
#
# 2.  **Directorio Global (a nivel de Proyecto):**
#     *   Crea una carpeta en la raíz del proyecto (ej: `static/`).
#     *   Añade esta carpeta a `STATICFILES_DIRS` en `settings.py`.
#     *   Ejemplo: `static/css/base.css`, `static/images/logo.png`.
#     *   **Ventaja:** Útil para archivos compartidos por todo el proyecto o que no pertenecen lógicamente a ninguna app específica.
#
# **¿Cómo referenciarlos en plantillas?**
# Independientemente de dónde esté guardado el archivo, siempre usas la etiqueta `static` con la ruta *relativa* a partir de la carpeta `static/` (incluyendo el namespace de la app si está dentro de una app):
#
# *   `{% static 'productos/css/estilos_productos.css' %}` (Para archivo en `productos/static/productos/css/`)
# *   `{% static 'css/base.css' %}` (Para archivo en `proyecto_raiz/static/css/`)
#
# Django buscará en todas las ubicaciones configuradas (`STATICFILES_DIRS` y `app/static/`) hasta encontrar el archivo.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ## 31_Uso_de_la_Etiqueta_static_en_Plantillas
#
# Para generar correctamente la URL de un archivo estático, **siempre** debes usar la etiqueta de plantilla `{% static %}`.
#
# **Pasos:**
#
# 1.  **Cargar la etiqueta:** Asegúrate de tener `{% load static %}` en la parte superior de tu plantilla (normalmente después de `{% extends %}` si lo usas).
# 2.  **Usar la etiqueta:** Pasa la ruta relativa al archivo (desde una de las carpetas `static` configuradas) como un string a la etiqueta.
#
# ```html
# {% load static %}
#
# <!DOCTYPE html>
# <html lang="es">
# <head>
#     <meta charset="UTF-8">
#     <title>Ejemplo Estáticos</title>
#     {# CSS de la app 'productos' #}
#     <link rel="stylesheet" href="{% static 'productos/css/detalle.css' %}">
#     {# CSS global desde STATICFILES_DIRS #}
#     <link rel="stylesheet" href="{% static 'css/theme.css' %}">
# </head>
# <body>
#     {# Imagen global #}
#     <img src="{% static 'images/logo_principal.png' %}" alt="Logo">
#
#     {# Imagen de la app 'productos' #}
#     <img src="{% static 'productos/img/icono.svg' %}" alt="Icono Producto">
#
#     {# JavaScript al final #}
#     <script src="{% static 'js/main.js' %}"></script>
# </body>
# </html>
# ```
#
# **Beneficios de usar `{% static %}`:**
# *   **Correctitud:** Genera la URL correcta basada en tu `STATIC_URL`.
# *   **Almacenamiento:** Funciona con diferentes backends de almacenamiento de archivos estáticos (como los que añaden hashes a los nombres de archivo para invalidación de caché, ej: `ManifestStaticFilesStorage`).
# *   **Mantenibilidad:** Si cambias `STATIC_URL`, no necesitas modificar tus plantillas.
#
# **Nunca hardcodees rutas como `/static/mi/archivo.css`.** Usa siempre `{% static 'mi/archivo.css' %}`.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ## 32_Comando_collectstatic_para_Produccion
#
# Este comando es un paso **obligatorio antes de desplegar en producción**. Su función es encontrar **todos** los archivos estáticos de tu proyecto (buscando en `STATICFILES_DIRS` y en las carpetas `static/` de todas las `INSTALLED_APPS`) y **copiarlos** en un único directorio: el especificado por `STATIC_ROOT` en `settings.py`.
#
# **Cómo usarlo:**
#
# 1.  Asegúrate de tener `STATIC_ROOT` definido en `settings.py` apuntando a un directorio **vacío** o inexistente (Django lo creará). Esta ruta debe ser accesible por tu servidor web en producción.
# 2.  Ejecuta el comando en tu terminal (con el entorno virtual activo):
#     ```bash
#     python manage.py collectstatic
#     ```
# 3.  Django te mostrará cuántos archivos encontró y te preguntará si quieres copiarlos a la ruta `STATIC_ROOT`. Escribe `yes` y presiona Enter.
#     ```
#     You have requested to collect static files at the destination
#     location as specified in your settings:
#
#         /ruta/completa/a/tu/proyecto/staticfiles_produccion
#
#     This will overwrite existing files!
#     Are you sure you want to do this?
#
#     Type 'yes' to continue, or 'no' to cancel: yes
#     ```
# 4.  Django copiará los archivos, manteniendo la estructura de directorios (incluyendo los namespaces de las apps).
#
# **¿Por qué es necesario?**
# En producción, tu servidor web (Nginx/Apache) debe servir los archivos estáticos directamente. Es mucho más eficiente configurar el servidor web para servir todo desde *una única* carpeta (`STATIC_ROOT`) que configurarlo para buscar en múltiples directorios (`STATICFILES_DIRS` y las carpetas de cada app). `collectstatic` centraliza todo para ti.
#
# **Flujo de Despliegue (simplificado):**
# 1.  Sube tu código al servidor de producción.
# 2.  Instala dependencias (`pip install -r requirements.txt`).
# 3.  Ejecuta `python manage.py collectstatic`.
# 4.  Asegúrate de que tu Nginx/Apache esté configurado para servir `STATIC_URL` desde `STATIC_ROOT`.
# 5.  Inicia/reinicia tu servidor WSGI (Gunicorn/uWSGI).
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ## 33_Manejo_de_Archivos_Subidos_por_el_Usuario_Media_Files
#
# Los archivos de medios (media) son aquellos que los usuarios suben a través de tu aplicación (imágenes de perfil, documentos, etc.) utilizando campos `FileField` o `ImageField` en tus modelos. Estos archivos **no** son parte del código fuente y deben gestionarse de forma separada a los archivos estáticos.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 33_1_Configuracion_MEDIA_URL_MEDIA_ROOT
#
# Necesitas definir dos constantes en `settings.py` para manejar los archivos de medios:
#
# ```python
# # mi_sitio/settings.py
# # ... (BASE_DIR ya definido) ...
#
# # --- Configuración Archivos Estáticos (como antes) ---
# STATIC_URL = 'static/'
# # ... (STATICFILES_DIRS, STATIC_ROOT) ...
#
# # --- Configuración Archivos de Medios ---
#
# # URL base pública desde la que se accederán los archivos subidos.
# # Debe ser diferente de STATIC_URL. Debe terminar en '/'.
# MEDIA_URL = '/media/'
#
# # Ruta ABSOLUTA en el sistema de archivos donde Django guardará
# # físicamente los archivos subidos por los usuarios.
# # El proceso del servidor (WSGI/web) debe tener permisos de ESCRITURA aquí.
# MEDIA_ROOT = BASE_DIR / 'mediafiles' # Nombre común para la carpeta
# ```
#
# *   **`MEDIA_URL`:** La **URL** pública para acceder a estos archivos (ej: `/media/avatars/user_1/foto.jpg`).
# *   **`MEDIA_ROOT`:** La **ruta del sistema de archivos** donde se almacenarán los archivos físicos subidos. Asegúrate de que esta carpeta exista y tenga los permisos de escritura correctos para el usuario con el que corre tu servidor WSGI/web.
#
# **Servir Archivos de Medios en Desarrollo (`DEBUG=True`):**
# Al igual que con los estáticos, `runserver` **no** sirve archivos de medios por defecto. Para habilitarlo **solo durante el desarrollo**, necesitas añadir una configuración de URL en tu `urls.py` principal del proyecto:
#
# ```python
# # mi_sitio/urls.py
# from django.conf import settings
# from django.conf.urls.static import static
# from django.contrib import admin
# from django.urls import path, include
#
# urlpatterns = [
#     path('admin/', admin.site.urls),
#     path('productos/', include('productos.urls')),
#     # ... otras urls ...
# ]
#
# # Añadir esto al FINAL del archivo urls.py
# # SOLO PARA DESARROLLO (DEBUG=True)
# if settings.DEBUG:
#     urlpatterns += static(settings.MEDIA_URL, document_root=settings.MEDIA_ROOT)
# ```
# Esto le indica a Django que sirva los archivos desde `MEDIA_ROOT` cuando se soliciten URLs que empiecen con `MEDIA_URL`, pero solo si `DEBUG` es `True` en `settings.py`. **Nunca uses esto en producción.**
#
# **Servir Archivos de Medios en Producción (`DEBUG=False`):**
# En producción, **nunca** uses la configuración anterior. Debes configurar tu servidor web (Nginx/Apache) para que sirva los archivos directamente desde el directorio `MEDIA_ROOT` cuando se soliciten URLs que empiecen con `MEDIA_URL`. La configuración es similar a la de `STATIC_ROOT`/`STATIC_URL`.
#
# ```nginx
# # Ejemplo Nginx (dentro del bloque server)
# location /media/ { # Coincide con MEDIA_URL
#     alias /ruta/absoluta/a/tu/mediafiles/; # Coincide con MEDIA_ROOT
# }
# ```
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 33_2_Campo_FileField_e_ImageField_upload_to
#
# Para permitir subidas en tus modelos, usa estos campos:
#
# *   **`FileField(upload_to=..., max_length=100, **options)`:**
#     *   Almacena una referencia al archivo subido. No guarda el archivo en la base de datos (salvo BBDD muy específicas), guarda la ruta relativa dentro de `MEDIA_ROOT`.
#     *   `upload_to`: **Obligatorio.** Define el subdirectorio dentro de `MEDIA_ROOT` donde se guardará el archivo. Puede ser:
#         *   Un string simple: `'documentos/'`
#         *   Un string con formato de fecha: `'uploads/%Y/%m/%d/'`
#         *   Una función callable que recibe `(instance, filename)` y devuelve la ruta completa (relativa a `MEDIA_ROOT`). Esto permite rutas dinámicas, ej: `def user_directory_path(instance, filename): return f'user_{instance.user.id}/{filename}'`.
# *   **`ImageField(upload_to=..., height_field=None, width_field=None, **options)`:**
#     *   Hereda de `FileField`, pero añade validación para asegurar que el archivo subido sea una imagen reconocida por Pillow.
#     *   **Requiere `Pillow` instalado:** `pip install Pillow`.
#     *   `height_field` y `width_field` (Opcional): Nombres de otros campos en el *mismo modelo* que se rellenarán automáticamente con el alto y ancho de la imagen al guardarla.
#
# **Ejemplo en `models.py`:**
# ```python
# # productos/models.py
# from django.db import models
#
# def ruta_imagen_producto(instance, filename):
#     # Guarda en mediafiles/productos/<slug_producto>/<filename>
#     return f'productos/{instance.slug}/{filename}'
#
# class Producto(models.Model):
#     # ... otros campos ...
#     nombre = models.CharField(max_length=255)
#     slug = models.SlugField(max_length=255, unique=True)
#     imagen = models.ImageField(
#         upload_to=ruta_imagen_producto, # Usa la función para ruta dinámica
#         blank=True,
#         null=True,
#         verbose_name="Imagen Principal"
#     )
#     # Podrías tener campos para guardar dimensiones
#     # imagen_ancho = models.PositiveIntegerField(null=True, blank=True, editable=False)
#     # imagen_alto = models.PositiveIntegerField(null=True, blank=True, editable=False)
#     # Y luego en ImageField: height_field='imagen_alto', width_field='imagen_ancho'
#
#     # ... resto del modelo ...
# ```
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 33_3_Manejo_de_Subidas_en_Formularios_enctype
#
# Para que un formulario HTML pueda subir archivos, **debe** cumplir dos condiciones:
# 1.  `method="post"`
# 2.  `enctype="multipart/form-data"`
#
# ```html
# {# plantilla_con_subida.html #}
# <form method="post" enctype="multipart/form-data"> {# ¡enctype ESENCIAL! #}
#     {% csrf_token %}
#     {{ form.as_p }} {# Asumiendo que 'form' tiene un FileField o ImageField #}
#     <button type="submit">Subir Archivo / Guardar</button>
# </form>
# ```
# Sin `enctype="multipart/form-data"`, los datos del archivo no se incluirán en la petición POST y `request.FILES` estará vacío.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 33_4_Procesamiento_en_Vistas_request_FILES
#
# Cuando un formulario con el `enctype` correcto se envía vía POST, los datos de los archivos subidos **no** están en `request.POST`, sino en el diccionario `request.FILES`.
#
# Al instanciar un formulario Django (`Form` o `ModelForm`) que maneja archivos, debes pasar **ambos** `request.POST` (para los datos normales) y `request.FILES` (para los archivos) al constructor del formulario.
#
# ```python
# # productos/views.py
# from django.shortcuts import render, redirect, get_object_or_404
# # ... (imports de modelos, forms)
#
# def editar_producto_con_imagen(request, slug):
#     producto = get_object_or_404(Producto, slug=slug)
#     if request.method == 'POST':
#         # Pasar request.POST Y request.FILES al formulario
#         form = ProductoForm(request.POST, request.FILES, instance=producto)
#         if form.is_valid():
#             form.save() # ModelForm se encarga de guardar el archivo
#             return redirect(producto.get_absolute_url())
#     else: # GET
#         form = ProductoForm(instance=producto)
#
#     return render(request, 'productos/producto_form.html', {'form': form, 'producto': producto})
# ```
# Si usas un `ModelForm` con un `FileField` o `ImageField`, llamar a `form.save()` se encargará automáticamente de guardar el archivo subido en la ubicación correcta (definida por `upload_to` y `MEDIA_ROOT`). Si usas un `forms.Form` normal, tendrás que manejar manualmente el archivo obtenido de `form.cleaned_data['nombre_campo']` (que será un objeto `UploadedFile`) y guardarlo en el sistema de archivos.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 33_5_Servir_Archivos_Media_en_Desarrollo_y_Produccion
#
# **Repaso:**
#
# *   **Desarrollo (`DEBUG=True`):** Añade la configuración `static(settings.MEDIA_URL, document_root=settings.MEDIA_ROOT)` a tu `urls.py` principal para que `runserver` los sirva.
# *   **Producción (`DEBUG=False`):** **Nunca** uses la configuración de desarrollo. Configura tu servidor web (Nginx/Apache) para mapear `MEDIA_URL` al directorio `MEDIA_ROOT` y servir los archivos directamente. Asegúrate de que los permisos del directorio `MEDIA_ROOT` sean correctos para que Django (el proceso WSGI) pueda escribir y el servidor web pueda leer.
#
# **Acceso en Plantillas:**
# Para generar la URL a un archivo subido almacenado en un `FileField` o `ImageField`, usa el atributo `.url` del campo en la instancia del modelo.
#
# ```html
# {% if producto.imagen %}
#     <img src="{{ producto.imagen.url }}" alt="{{ producto.nombre }}">
#     <p><small>Ruta archivo: {{ producto.imagen.path }}</small></p> {# Ruta completa en servidor #}
#     <p><small>URL: {{ producto.imagen.url }}</small></p> {# URL pública #}
# {% else %}
#     <p>(Sin imagen)</p>
# {% endif %}
# ```
# Django construirá la URL completa usando `MEDIA_URL` y la ruta relativa guardada en la base de datos para ese campo.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 33_6_Ejercicio_Practico_Configurar_y_Usar_Static_y_Media
#
# **Objetivo:** Configurar archivos estáticos y de medios, añadir un campo de imagen al modelo `Producto`, y mostrar la imagen y un CSS básico.
#
# **Pasos:**
#
# 1.  **Configurar `settings.py`:**
#     *   Asegúrate de que `'django.contrib.staticfiles'` esté en `INSTALLED_APPS`.
#     *   Define `STATIC_URL = 'static/'`.
#     *   Define `STATICFILES_DIRS = [BASE_DIR / 'static']` (crea la carpeta `static` en la raíz si no existe).
#     *   Define `STATIC_ROOT = BASE_DIR / 'staticfiles_produccion'`.
#     *   Define `MEDIA_URL = '/media/'`.
#     *   Define `MEDIA_ROOT = BASE_DIR / 'mediafiles'` (Django no crea esta carpeta, puede que necesites crearla tú manualmente la primera vez o asegurarte de que los permisos permitan a Django crearla).
# 2.  **Configurar `urls.py` del proyecto:** Añade el bloque `if settings.DEBUG:` para servir archivos de medios en desarrollo (copia de la sección 33.1).
# 3.  **Crear archivos estáticos:**
#     *   Crea `static/css/base.css` en la raíz del proyecto. Añade alguna regla simple (ej: `body { background-color: #f0f8ff; }`).
#     *   (Opcional) Crea `productos/static/productos/css/productos.css` con alguna regla específica.
# 4.  **Modificar `templates/base.html`:**
#     *   Añade `{% load static %}` al principio.
#     *   Enlaza el archivo `base.css`: `<link rel="stylesheet" href="{% static 'css/base.css' %}">`.
# 5.  **Modificar `productos/models.py`:**
#     *   Añade el campo `imagen = models.ImageField(upload_to='productos/', blank=True, null=True)`.
#     *   *Recuerda instalar Pillow:* `pip install Pillow`.
# 6.  **Crear y aplicar migraciones:**
#     ```bash
#     python manage.py makemigrations productos
#     python manage.py migrate
#     ```
# 7.  **Modificar `productos/admin.py`:** Añade `'imagen'` a `list_display` y a `fieldsets` (o `fields`) en `ProductoAdmin` para poder subirla desde el admin.
# 8.  **Modificar `productos/forms.py` (si usas ModelForm):** Asegúrate de que `'imagen'` esté en `fields` o no esté en `exclude` en la `Meta` de `ProductoForm`.
# 9.  **Modificar `productos/templates/productos/detalle_producto.html`:**
#     *   Muestra la imagen si existe:
#         ```html
#         {% if producto.imagen %}
#             <img src="{{ producto.imagen.url }}" alt="{{ producto.nombre }}" style="max-width: 300px; height: auto;">
#         {% endif %}
#         ```
# 10. **Modificar `productos/views.py`:** Asegúrate de que la vista `editar_producto_view` (o la que uses para el formulario) pase `request.FILES` al instanciar el `ModelForm` en el `POST`.
# 11. **Modificar `productos/templates/productos/producto_form.html`:** Asegúrate de que el `<form>` tenga `enctype="multipart/form-data"`.
# 12. **Ejecuta `runserver`.**
# 13. **Prueba:**
#     *   Verifica que el fondo de las páginas haya cambiado (aplicando `base.css`).
#     *   Ve al admin, edita un producto y sube una imagen. Guarda.
#     *   Ve a la página de detalle de ese producto en el frontend. Deberías ver la imagen mostrada.
#
# **Solución Propuesta:**
# La solución implica modificar los archivos `settings.py`, `tienda_config/urls.py`, `productos/models.py`, `productos/admin.py`, `productos/forms.py` (si existe), `templates/base.html`, `productos/templates/productos/detalle_producto.html`, `productos/templates/productos/producto_form.html` como se describe en los pasos y ejemplos anteriores. Además, crear las carpetas y el archivo CSS. La clave es verificar que el CSS se aplique y que puedas subir y ver imágenes a través del admin y el frontend.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ---
# ---
#
# ## **Unidad 8: Vistas Basadas en Clase (CBV)**
#
# ## 34_Introduccion_a_las_Vistas_Basadas_en_Clase_Ventajas_y_Desventajas
#
# Hasta ahora, hemos utilizado principalmente Vistas Basadas en Función (FBVs), que son funciones Python que toman `request` y devuelven `HttpResponse`. Django también ofrece una forma alternativa y potente de escribir vistas utilizando clases Python: las Vistas Basadas en Clase (Class-Based Views o CBVs).
#
# Las CBVs agrupan la lógica relacionada con una vista dentro de una clase, utilizando métodos específicos para manejar diferentes acciones (como responder a peticiones GET o POST) y atributos para configurar su comportamiento. Django proporciona un conjunto de vistas base y vistas genéricas que encapsulan patrones comunes, permitiendo escribir menos código para tareas repetitivas.
#
# **Ventajas Potenciales de las CBVs:**
#
# *   **Reutilización de Código (DRY):** La herencia de clases y los *mixins* permiten compartir y reutilizar lógica común entre múltiples vistas de manera elegante (ej: manejo de permisos, paginación, obtención de objetos).
# *   **Organización:** Para vistas con lógica compleja o que manejan múltiples métodos HTTP (GET, POST, PUT, etc.), separar esta lógica en métodos de clase (`get()`, `post()`, etc.) puede resultar más organizado que un único `if request.method == ...` largo en una FBV.
# *   **Extensibilidad:** Puedes heredar de vistas genéricas y sobrescribir solo los métodos o atributos necesarios para personalizar el comportamiento, en lugar de reescribir toda la lógica.
# *   **Vistas Genéricas Incorporadas:** Django ofrece un rico conjunto de vistas genéricas para tareas CRUD (Crear, Leer, Actualizar, Eliminar), mostrar listas, detalles, manejar formularios, etc., que reducen drásticamente la cantidad de código repetitivo.
#
# **Desventajas Potenciales:**
#
# *   **Curva de Aprendizaje:** El flujo de ejecución (qué métodos se llaman y en qué orden) y el uso de herencia/mixins pueden ser menos intuitivos al principio que el flujo lineal de una FBV. Requiere entender la jerarquía de clases genéricas.
# *   **Menos Explícitas:** A veces, la lógica está "oculta" en métodos heredados, haciendo que el código sea menos explícito que una FBV donde todo está en una sola función. Depurar puede requerir investigar la clase base.
# *   **Excesivas para Vistas Simples:** Para una vista muy sencilla que solo renderiza una plantilla o devuelve una respuesta simple, una FBV suele ser más corta y directa.
#
# La elección entre FBV y CBV a menudo depende de la complejidad de la vista, las preferencias personales o las convenciones del equipo. Es bueno conocer ambas formas. Las vistas genéricas basadas en clase son particularmente útiles para acelerar el desarrollo de operaciones CRUD estándar.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ## 35_Vistas_Genericas_Basicas_View_TemplateView
#
# Empezamos con las CBVs más fundamentales.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 35_1_Clase_View_dispatch_get_post
#
# `django.views.View` es la clase base para todas las vistas en Django.
#
# *   **Funcionamiento:** Cuando una URL se mapea a una CBV (usando `MiVista.as_view()`), Django llama al método `dispatch(request, *args, **kwargs)` de la vista.
# *   **`dispatch()`:** Este método examina `request.method` (ej: 'GET', 'POST') y busca un método en la instancia de la clase con ese nombre exacto en minúsculas (ej: `get()`, `post()`). Si encuentra el método, lo llama pasándole `request`, `*args` y `**kwargs`. Si no lo encuentra, lanza una excepción `HttpResponseNotAllowed`.
# *   **Implementación:** Heredas de `View` y defines métodos para los verbos HTTP que quieres soportar (`get`, `post`, `put`, `delete`, etc.).
#
# **Ejemplo (Rehaciendo el formulario de contacto como CBV):**
# ```python
# # productos/views.py
# from django.views import View
# from django.shortcuts import render, redirect
# from django.urls import reverse # O reverse_lazy
# from .forms import ContactoForm # Asumiendo que existe
#
# class ContactoSimpleView(View):
#     form_class = ContactoForm
#     template_name = 'productos/contacto.html' # Reutilizamos la plantilla
#     success_url_name = 'productos:contacto_exito' # Nombre de la URL de éxito
#
#     def get(self, request, *args, **kwargs):
#         """Maneja peticiones GET: muestra el formulario vacío."""
#         form = self.form_class()
#         return render(request, self.template_name, {'form': form})
#
#     def post(self, request, *args, **kwargs):
#         """Maneja peticiones POST: procesa el formulario."""
#         form = self.form_class(request.POST)
#         if form.is_valid():
#             # Aquí iría la lógica para enviar el email o procesar datos
#             nombre = form.cleaned_data['nombre']
#             print(f"Formulario de contacto (CBV) recibido de: {nombre}")
#             # ... (enviar email) ...
#
#             # Redirigir a la URL de éxito
#             return redirect(reverse(self.success_url_name))
#         else:
#             # Si no es válido, renderizar de nuevo con errores
#             return render(request, self.template_name, {'form': form})
#
# ```
# **En `productos/urls.py`:**
# ```python
# # productos/urls.py
# from django.urls import path
# from .views import ContactoSimpleView, contacto_exito_view # Importar la clase
# # ... (app_name = 'productos') ...
#
# urlpatterns = [
#     # ... (otras urls) ...
#     path('contacto-cbv/', ContactoSimpleView.as_view(), name='contacto_simple'),
#     path('contacto/exito/', contacto_exito_view, name='contacto_exito'), # Reutilizamos la vista de éxito FBV
# ]
# ```
# Nota cómo la lógica para GET y POST está claramente separada en sus respectivos métodos.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 35_2_Clase_TemplateView_template_name_get_context_data
#
# `django.views.generic.TemplateView` hereda de `View` y está especializada en una tarea muy común: **renderizar una plantilla**.
#
# *   **Atributo Principal:** `template_name` (string): Especifica la ruta a la plantilla HTML que debe renderizar.
# *   **Manejo GET:** Por defecto, su método `get()` simplemente renderiza la `template_name` especificada.
# *   **Añadir Contexto:** Para pasar datos a la plantilla, sobrescribes el método `get_context_data(self, **kwargs)`. Este método debe devolver un diccionario que se usará como contexto de la plantilla. Es **importante** llamar a `super().get_context_data(**kwargs)` dentro de tu método sobrescrito para incluir cualquier contexto añadido por clases padre o mixins.
#
# **Ejemplo (Una página "Acerca de" simple):**
# ```python
# # productos/views.py
# from django.views.generic import TemplateView
# import datetime
#
# class AcercaDePaginaView(TemplateView):
#     template_name = "productos/acerca_de.html" # Ruta a la plantilla
#
#     def get_context_data(self, **kwargs):
#         # 1. Obtener contexto base de la clase padre
#         context = super().get_context_data(**kwargs)
#         # 2. Añadir tus propios datos
#         context['fecha'] = datetime.date.today()
#         context['version_app'] = '1.2.0'
#         context['equipo'] = ['Alice', 'Bob', 'Charlie']
#         # 3. Devolver el contexto completo
#         return context
# ```
#
# **En `productos/urls.py`:**
# ```python
# # productos/urls.py
# from django.urls import path
# from .views import AcercaDePaginaView # Importar la clase
# # ... (app_name = 'productos') ...
#
# urlpatterns = [
#     # ... (otras urls) ...
#     path('acerca-de/', AcercaDePaginaView.as_view(), name='acerca_de'),
# ]
# ```
#
# **Plantilla (`productos/templates/productos/acerca_de.html`):**
# ```html
# {% extends 'base.html' %} {# Asumiendo que tienes base.html #}
#
# {% block titulo %}Acerca de Nosotros{% endblock %}
#
# {% block contenido %}
#     <h1>Acerca de Mi Tienda Online</h1>
#     <p>Versión actual: {{ version_app }}</p>
#     <p>Fecha: {{ fecha|date:"d F, Y" }}</p>
#
#     <h2>Nuestro Equipo</h2>
#     <ul>
#         {% for miembro in equipo %}
#             <li>{{ miembro }}</li>
#         {% empty %}
#             <li>No hay información del equipo disponible.</li>
#         {% endfor %}
#     </ul>
# {% endblock %}
# ```
# `TemplateView` es ideal para páginas con contenido mayormente estático o que solo requieren pasar unos pocos datos dinámicos calculados en `get_context_data`.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ## 36_Vistas_Genericas_para_Mostrar_Datos_ListView_DetailView
#
# Django proporciona vistas genéricas específicamente diseñadas para los patrones comunes de mostrar listas de objetos y los detalles de un objeto individual. Estas heredan de `View` y `ContextMixin`, añadiendo funcionalidades para interactuar con modelos.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 36_1_ListView_model_queryset_template_name_context_object_name_paginate_by
#
# `django.views.generic.ListView` está diseñada para mostrar una lista de objetos de un modelo.
#
# **Atributos/Métodos Clave:**
# *   **`model`:** La clase del modelo cuyos objetos quieres listar (ej: `Producto`). Django hará `Producto.objects.all()` por defecto.
# *   **`queryset`:** Alternativamente a `model`, puedes especificar un QuerySet base personalizado (ej: `Producto.objects.filter(disponible=True)`). Si defines `queryset`, no necesitas `model`. Es más flexible.
# *   **`template_name`:** Ruta a la plantilla a renderizar. Por defecto, busca en `<app_label>/<model_name>_list.html` (ej: `productos/producto_list.html`). Es muy recomendable definirla explícitamente.
# *   **`context_object_name`:** El nombre de la variable que contendrá la lista de objetos en el contexto de la plantilla. Por defecto es `'object_list'`. Es buena práctica cambiarlo a algo más descriptivo (ej: `'lista_productos'`).
# *   **`paginate_by`:** Un entero que habilita la paginación automática. Si se establece (ej: `paginate_by = 10`), la vista solo mostrará ese número de objetos por página y añadirá objetos de paginación (`paginator`, `page_obj`, `is_paginated`) al contexto para que puedas construir controles de paginación en la plantilla.
# *   **`ordering`:** Para especificar un orden diferente al del `Meta` del modelo.
# *   **`get_queryset(self)`:** Método que puedes sobrescribir para personalizar dinámicamente el queryset base (ej: filtrar por usuario, por parámetros GET).
# *   **`get_context_data(self, **kwargs)`:** Para añadir contexto adicional a la plantilla (además de `object_list` y los objetos de paginación).
#
# **Ejemplo (`productos/views.py`):**
# ```python
# # productos/views.py
# from django.views.generic import ListView
# from .models import Producto
#
# class ProductoListView(ListView):
#     # model = Producto # Opción 1: Usar el modelo directamente
#     queryset = Producto.objects.filter(disponible=True) # Opción 2: Usar queryset base (preferido para filtrar)
#     template_name = 'productos/producto_lista.html' # Nombre explícito
#     context_object_name = 'productos' # Nombre en plantilla
#     paginate_by = 12 # Mostrar 12 productos por página
#
#     def get_queryset(self):
#         # Ejemplo de refinamiento dinámico del queryset
#         queryset = super().get_queryset() # Obtiene el queryset base (el de arriba o Model.objects.all())
#         # Filtrar por categoría si se pasa como parámetro GET (?categoria=...)
#         categoria_slug = self.request.GET.get('categoria')
#         if categoria_slug:
#             queryset = queryset.filter(categoria__slug=categoria_slug)
#         return queryset.order_by('nombre') # Ordenar alfabéticamente
#
#     def get_context_data(self, **kwargs):
#         context = super().get_context_data(**kwargs)
#         context['titulo_pagina'] = "Nuestro Catálogo"
#         # Podrías añadir la lista de categorías aquí para un menú de filtro
#         # context['categorias'] = Categoria.objects.all()
#         return context
# ```
#
# **En `productos/urls.py`:**
# ```python
# # productos/urls.py
# from .views import ProductoListView # Importar
# # ...
# urlpatterns = [
#     path('', ProductoListView.as_view(), name='lista_productos'), # Mapear a la CBV
#     # ...
# ]
# ```
#
# **Plantilla (`productos/templates/productos/producto_lista.html`):**
# ```html
# {% extends 'base.html' %}
# {% block titulo %}{{ titulo_pagina|default:"Productos" }}{% endblock %}
#
# {% block contenido %}
#     <h1>{{ titulo_pagina|default:"Productos" }}</h1>
#
#     {# Aquí podrías poner filtros basados en context['categorias'] si lo añadiste #}
#
#     {% if productos %} {# Usa el context_object_name definido #}
#         <div class="lista-grid">
#             {% for producto in productos %} {# Itera sobre la lista (ya paginada si paginate_by está activo) #}
#                 {# Incluir tarjeta de producto (ejemplo) #}
#                 {% include 'productos/includes/tarjeta_producto.html' with prod=producto %}
#             {% endfor %}
#         </div>
#
#         {# Controles de Paginación (si paginate_by está activo) #}
#         {% if is_paginated %}
#             <div class="paginacion">
#                 <span class="step-links">
#                     {% if page_obj.has_previous %}
#                         <a href="?page=1">&laquo; Primera</a>
#                         <a href="?page={{ page_obj.previous_page_number }}">Anterior</a>
#                     {% endif %}
#
#                     <span class="current">
#                         Página {{ page_obj.number }} de {{ paginator.num_pages }}.
#                     </span>
#
#                     {% if page_obj.has_next %}
#                         <a href="?page={{ page_obj.next_page_number }}">Siguiente</a>
#                         <a href="?page={{ paginator.num_pages }}">Última &raquo;</a>
#                     {% endif %}
#                 </span>
#             </div>
#         {% endif %}
#
#     {% else %}
#         <p>No se encontraron productos.</p>
#     {% endif %}
# {% endblock %}
# ```
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 36_2_DetailView_model_queryset_template_name_context_object_name_pk_slug
#
# `django.views.generic.DetailView` se usa para mostrar la información detallada de **una única instancia** de un modelo.
#
# **Atributos/Métodos Clave:**
# *   **`model` o `queryset`:** Especifica el modelo del cual obtener el objeto.
# *   **`template_name`:** Plantilla a renderizar. Por defecto: `<app_label>/<model_name>_detail.html` (ej: `productos/producto_detail.html`).
# *   **`context_object_name`:** Nombre de la variable en la plantilla que contendrá la instancia del objeto recuperado. Por defecto es `'object'` y también `'nombremodelo'` en minúsculas (ej: `'producto'`).
# *   **Identificación del Objeto:** `DetailView` necesita saber qué objeto específico mostrar. Por defecto, busca un argumento llamado `pk` o `slug` en los parámetros capturados por la URL.
#     *   `pk_url_kwarg`: Nombre del argumento en la URL que contiene la clave primaria (defecto `'pk'`).
#     *   `slug_url_kwarg`: Nombre del argumento en la URL que contiene el slug (defecto `'slug'`).
#     *   `slug_field`: Nombre del campo en el modelo que contiene el slug (defecto `'slug'`).
# *   **`get_object(self, queryset=None)`:** Método que obtiene el objeto. Puedes sobrescribirlo si necesitas lógica de obtención personalizada (ej: comprobar permisos antes de devolver el objeto).
# *   **`get_context_data(self, **kwargs)`:** Para añadir contexto adicional.
#
# **Ejemplo (`productos/views.py`):**
# ```python
# # productos/views.py
# from django.views.generic import DetailView
# from .models import Producto
#
# class ProductoDetailView(DetailView):
#     model = Producto # O queryset = Producto.objects.filter(disponible=True)
#     template_name = 'productos/producto_detalle.html' # Nombre explícito
#     context_object_name = 'producto' # Nombre en plantilla
#
#     # Si la URL usa 'producto_slug' en lugar de 'slug'
#     # slug_url_kwarg = 'producto_slug'
#     # slug_field = 'slug' # Asegurarse de que busca en el campo correcto
#
#     def get_context_data(self, **kwargs):
#         context = super().get_context_data(**kwargs)
#         context['titulo_pagina'] = self.object.nombre # Usa el objeto recuperado (self.object)
#         # Podrías añadir productos relacionados aquí
#         # context['relacionados'] = Producto.objects.filter(categoria=self.object.categoria).exclude(pk=self.object.pk)[:4]
#         return context
# ```
#
# **En `productos/urls.py`:**
# ```python
# # productos/urls.py
# from .views import ProductoDetailView # Importar
# # ... (app_name = 'productos') ...
#
# urlpatterns = [
#     # ... (url de lista) ...
#     # URL usando PK
#     path('<int:pk>/', ProductoDetailView.as_view(), name='detalle_producto_pk'),
#     # URL alternativa usando Slug (necesita el campo slug en el modelo)
#     path('item/<slug:slug>/', ProductoDetailView.as_view(), name='detalle_producto'), # Asumiendo que usamos esta en get_absolute_url
# ]
# ```
#
# **Plantilla (`productos/templates/productos/producto_detalle.html`):**
# ```html
# {% extends 'base.html' %}
#
# {% block titulo %}{{ producto.nombre }} - Mi Tienda{% endblock %}
#
# {% block contenido %}
#     {# Asumiendo include para la categoría #}
#     {% if producto.categoria %}
#         {% include 'productos/includes/detalle_categoria.html' with categoria_obj=producto.categoria %}
#     {% endif %}
#
#     <h1>{{ producto.nombre }}</h1>
#
#     {% if producto.imagen %}
#         <img src="{{ producto.imagen.url }}" alt="{{ producto.nombre }}" style="max-width: 400px; height: auto;">
#     {% endif %}
#
#     <p><strong>Precio:</strong> ${{ producto.precio|floatformat:2 }}</p>
#     <p><strong>Stock:</strong> {% if producto.stock > 0 %}{{ producto.stock }}{% else %}Agotado{% endif %}</p>
#     <p><strong>Descripción:</strong></p>
#     <div>{{ producto.descripcion|linebreaks }}</div>
#
#     {# Mostrar productos relacionados si se pasaron en el contexto #}
#     {% if relacionados %}
#         <hr>
#         <h2>Productos Relacionados</h2>
#         <div class="lista-relacionados">
#             {% for rel in relacionados %}
#                 <p><a href="{{ rel.get_absolute_url }}">{{ rel.nombre }}</a></p>
#             {% endfor %}
#         </div>
#     {% endif %}
#
#     <hr>
#     <p><a href="{% url 'productos:lista_productos' %}">Volver a la lista</a></p>
# {% endblock %}
#
# ```
#
# `ListView` y `DetailView` cubren una gran parte de las necesidades para mostrar datos en una aplicación web típica.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ## 37_Vistas_Genericas_para_Edicion_CreateView_UpdateView_DeleteView
#
# Estas vistas basadas en clase simplifican la implementación de operaciones CRUD (Crear, Leer -ya visto-, Actualizar, Eliminar) que involucran formularios, especialmente `ModelForm`.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 37_1_CreateView_model_fields_form_class_template_name_success_url
#
# `django.views.generic.edit.CreateView` se usa para mostrar un formulario vacío para crear una nueva instancia de un modelo y para procesar los datos enviados por ese formulario.
#
# **Atributos/Métodos Clave:**
# *   **`model`:** El modelo del que se creará una instancia.
# *   **`fields`:** Lista o tupla de campos del modelo a incluir en el formulario generado automáticamente (si no usas `form_class`).
# *   **`form_class`:** Alternativa a `model`/`fields`. Puedes especificar una clase `ModelForm` (o `Form`) personalizada que se usará en lugar de la generada automáticamente.
# *   **`template_name`:** Plantilla para mostrar el formulario. Por defecto: `<app_label>/<model_name>_form.html` (ej: `productos/producto_form.html`).
# *   **`success_url`:** **Obligatorio.** La URL (como string o generada con `reverse_lazy`) a la que se redirigirá al usuario después de crear exitosamente el objeto. `reverse_lazy` es necesario aquí porque las URLs pueden no estar cargadas completamente cuando se define la clase.
# *   **`get_form_kwargs(self)`:** Para pasar argumentos extra al inicializar el formulario.
# *   **`form_valid(self, form)`:** Se ejecuta si el formulario enviado es válido. Por defecto, llama a `form.save()` y redirige a `success_url`. Puedes sobrescribirlo para añadir lógica antes o después de guardar (ej: asignar `request.user` a un campo `autor`). **Debe devolver una `HttpResponseRedirect`.**
# *   **`get_context_data(self, **kwargs)`:** Para añadir contexto extra a la plantilla del formulario.
#
# **Ejemplo (`productos/views.py`):**
# ```python
# # productos/views.py
# from django.views.generic.edit import CreateView
# from django.urls import reverse_lazy
# from django.contrib.auth.mixins import LoginRequiredMixin
# from .models import Producto
# from .forms import ProductoForm # Asumiendo que existe un ModelForm
#
# class ProductoCreateView(LoginRequiredMixin, CreateView):
#     model = Producto
#     form_class = ProductoForm # Usar nuestro ModelForm personalizado
#     # O si no tuviéramos form_class:
#     # fields = ['nombre', 'slug', 'categoria', 'descripcion', 'precio', 'stock', 'disponible', 'imagen']
#     template_name = 'productos/producto_form.html' # Usaremos la misma plantilla para crear/editar
#     success_url = reverse_lazy('productos:lista_productos') # Redirigir a la lista después de crear
#
#     def form_valid(self, form):
#         # Opcional: Modificar la instancia antes de guardar
#         # form.instance.creado_por = self.request.user # Asignar usuario actual
#         # messages.success(self.request, "Producto creado exitosamente.") # Mensaje flash
#         # Llamar al método padre para guardar y obtener la redirección
#         return super().form_valid(form)
#
#     def get_context_data(self, **kwargs):
#         context = super().get_context_data(**kwargs)
#         context['titulo_pagina'] = "Crear Nuevo Producto"
#         return context
# ```
#
# **En `productos/urls.py`:**
# ```python
# # productos/urls.py
# from .views import ProductoCreateView # Importar
# # ... (app_name = 'productos') ...
# urlpatterns = [
#     # ... (otras urls) ...
#     path('nuevo/', ProductoCreateView.as_view(), name='crear_producto'),
# ]
# ```
# La plantilla `productos/producto_form.html` sería como la que vimos en la sección de `ModelForm`, mostrando `{{ form.as_p }}` o similar.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 37_2_UpdateView_model_fields_etc_obtencion_de_objeto
#
# `django.views.generic.edit.UpdateView` se usa para mostrar un formulario pre-rellenado con los datos de una instancia *existente* de un modelo y procesar el envío para guardar los cambios.
#
# **Atributos/Métodos Clave:**
# *   Similar a `CreateView`: `model`, `fields`, `form_class`, `template_name`, `success_url`.
# *   **Obtención del Objeto:** Funciona como `DetailView` para encontrar el objeto a editar, buscando `pk` o `slug` en los argumentos de la URL. Puedes usar `pk_url_kwarg`, `slug_url_kwarg`, `slug_field`. También puedes sobrescribir `get_object()` o `get_queryset()`.
# *   **Instancia en Formulario:** Automáticamente pasa la instancia encontrada al constructor del formulario (`form = MiForm(instance=objeto_encontrado)` en GET, `form = MiForm(request.POST, request.FILES, instance=objeto_encontrado)` en POST).
# *   **`form_valid(self, form)`:** Por defecto, llama a `form.save()` (que ejecutará `UPDATE`) y redirige a `success_url`.
#
# **Ejemplo (`productos/views.py`):**
# ```python
# # productos/views.py
# from django.views.generic.edit import UpdateView
# from django.urls import reverse_lazy
# from django.contrib.auth.mixins import LoginRequiredMixin #, UserPassesTestMixin
# from .models import Producto
# from .forms import ProductoForm
#
# class ProductoUpdateView(LoginRequiredMixin, UpdateView): # Podríamos añadir UserPassesTestMixin
#     model = Producto
#     form_class = ProductoForm
#     template_name = 'productos/producto_form.html'
#     # No necesita pk_url_kwarg o slug_url_kwarg si la URL usa 'pk' o 'slug'
#     # slug_field = 'slug' # Si buscas por slug
#
#     # Redirigir al detalle del producto editado
#     def get_success_url(self):
#         # self.object contiene la instancia guardada
#         return reverse_lazy('productos:detalle_producto', kwargs={'slug': self.object.slug})
#
#     def get_context_data(self, **kwargs):
#         context = super().get_context_data(**kwargs)
#         context['titulo_pagina'] = f"Editar Producto: {self.object.nombre}"
#         # self.object está disponible en el contexto por defecto
#         return context
#
#     # Ejemplo de test de permiso (requeriría UserPassesTestMixin)
#     # def test_func(self):
#     #     return self.request.user == self.get_object().creado_por
# ```
#
# **En `productos/urls.py`:**
# ```python
# # productos/urls.py
# from .views import ProductoUpdateView # Importar
# # ... (app_name = 'productos') ...
# urlpatterns = [
#     # ... (otras urls) ...
#     # Asumiendo que usamos slug para identificar el producto a editar
#     path('editar/<slug:slug>/', ProductoUpdateView.as_view(), name='editar_producto'),
# ]
# ```
# La plantilla `productos/producto_form.html` se reutiliza. `UpdateView` se encargará de rellenarla con los datos de la instancia existente en peticiones GET.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 37_3_DeleteView_model_template_name_success_url_context_object_name
#
# `django.views.generic.edit.DeleteView` maneja la eliminación de una instancia de modelo. Típicamente muestra una página de confirmación (GET) y procesa la eliminación real en una petición POST.
#
# **Atributos/Métodos Clave:**
# *   **`model` o `queryset`:** Especifica el modelo a eliminar.
# *   **`template_name`:** Plantilla de confirmación. Por defecto: `<app_label>/<model_name>_confirm_delete.html` (ej: `productos/producto_confirm_delete.html`).
# *   **`success_url`:** **Obligatorio.** URL a la que redirigir después de eliminar el objeto con éxito.
# *   **Obtención del Objeto:** Funciona como `DetailView` y `UpdateView` (usando `pk` o `slug` de la URL).
# *   **`context_object_name`:** Nombre de la variable en la plantilla que contiene el objeto a eliminar (defecto `'object'` o `'nombremodelo'`).
# *   **`get(self, request, *args, **kwargs)`:** Muestra la plantilla de confirmación.
# *   **`post(self, request, *args, **kwargs)`:** Realiza la eliminación (`self.object.delete()`) y redirige a `success_url`. Puedes sobrescribir `form_valid` (aunque no hay formulario por defecto) o `post` si necesitas lógica extra antes/después de eliminar.
#
# **Ejemplo (`productos/views.py`):**
# ```python
# # productos/views.py
# from django.views.generic.edit import DeleteView
# from django.urls import reverse_lazy
# from django.contrib.auth.mixins import LoginRequiredMixin #, UserPassesTestMixin
# from .models import Producto
# # from django.contrib import messages
#
# class ProductoDeleteView(LoginRequiredMixin, DeleteView): # Podríamos añadir UserPassesTestMixin
#     model = Producto
#     template_name = 'productos/producto_confirm_delete.html'
#     context_object_name = 'producto' # Nombre para usar en plantilla
#     success_url = reverse_lazy('productos:lista_productos') # Ir a la lista después de borrar
#
#     # Ejemplo de test de permiso
#     # def test_func(self):
#     #     return self.request.user == self.get_object().creado_por
#
#     # Ejemplo de añadir mensaje flash (sobrescribiendo post)
#     # def post(self, request, *args, **kwargs):
#     #     nombre_producto = self.get_object().nombre
#     #     messages.success(request, f"Producto '{nombre_producto}' eliminado.")
#     #     return super().post(request, *args, **kwargs) # Llama a la lógica de borrado y redirección base
# ```
#
# **En `productos/urls.py`:**
# ```python
# # productos/urls.py
# from .views import ProductoDeleteView # Importar
# # ... (app_name = 'productos') ...
# urlpatterns = [
#     # ... (otras urls) ...
#     path('eliminar/<slug:slug>/', ProductoDeleteView.as_view(), name='eliminar_producto'),
# ]
# ```
#
# **Plantilla (`productos/templates/productos/producto_confirm_delete.html`):**
# ```html
# {% extends 'base.html' %}
#
# {% block titulo %}Confirmar Eliminación{% endblock %}
#
# {% block contenido %}
#     <h1>Eliminar Producto</h1>
#     <p>¿Estás seguro de que quieres eliminar el producto "{{ producto.nombre }}"?</p> {# Usa context_object_name #}
#
#     <form method="post">
#         {% csrf_token %}
#         <button type="submit">Sí, eliminar</button>
#         <a href="{{ producto.get_absolute_url }}">Cancelar</a> {# Enlace para volver al detalle #}
#     </form>
# {% endblock %}
# ```
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ## 38_Vistas_Genericas_para_Formularios_FormView
#
# ¿Qué pasa si tienes un formulario que **no** está directamente vinculado a un modelo (como nuestro `ContactoForm` inicial)? Para estos casos, Django ofrece `FormView`.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 38_1_Uso_con_forms_Form
#
# `django.views.generic.edit.FormView` es similar a `CreateView` pero diseñada para trabajar con `django.forms.Form` (en lugar de `ModelForm`).
#
# **Atributos/Métodos Clave:**
# *   **`template_name`:** Plantilla que muestra el formulario.
# *   **`form_class`:** La clase que hereda de `forms.Form` a utilizar.
# *   **`success_url`:** URL a la que redirigir después de un envío válido.
# *   **`get_form_kwargs(self)`:** Para pasar argumentos extra al inicializar el formulario.
# *   **`get_context_data(self, **kwargs)`:** Para añadir contexto extra.
# *   **`form_valid(self, form)`:** **Debes implementar este método.** Se llama cuando `form.is_valid()` es `True`. Aquí es donde realizas la acción deseada con los datos de `form.cleaned_data` (enviar email, procesar datos, etc.). **Debe devolver una `HttpResponseRedirect`** (normalmente llamando a `super().form_valid(form)` que usa `success_url`, o creando una redirección manualmente).
# *   **`form_invalid(self, form)`:** Se llama si el formulario no es válido. Por defecto, vuelve a renderizar `template_name` con el `form` que contiene los errores.
#
# **Ejemplo (Rehaciendo `ContactoSimpleView` con `FormView`):**
# ```python
# # productos/views.py
# from django.views.generic.edit import FormView
# from django.urls import reverse_lazy
# from django.shortcuts import redirect # O HttpResponseRedirect
# # from django.core.mail import send_mail
# # from django.conf import settings
# # from django.contrib import messages
# from .forms import ContactoForm # Nuestro forms.Form normal
#
# class ContactoFormViewGeneric(FormView):
#     template_name = 'productos/contacto.html' # Reutilizar plantilla
#     form_class = ContactoForm
#     success_url = reverse_lazy('productos:contacto_exito') # Nombre de URL de éxito
#
#     def form_valid(self, form):
#         # El formulario es válido, cleaned_data está listo
#         nombre = form.cleaned_data['nombre']
#         email = form.cleaned_data['email']
#         asunto = form.cleaned_data['asunto']
#         mensaje = form.cleaned_data['mensaje']
#
#         # Realizar la acción (ej: simular envío de email)
#         print(f"---- EMAIL (FormView) ----")
#         print(f"De: {nombre} <{email}>")
#         print(f"Asunto: {asunto}")
#         print(f"Mensaje: {mensaje}")
#         print(f"-------------------------")
#         # send_mail(...)
#
#         # messages.success(self.request, "¡Mensaje enviado desde FormView!")
#
#         # Devolver la redirección (la clase base lo hace si llamas a super)
#         return super().form_valid(form)
#
#     # No necesitamos definir get() o post() explícitamente aquí,
#     # FormView los maneja para mostrar/validar el form_class.
# ```
#
# **En `productos/urls.py`:**
# ```python
# # productos/urls.py
# from .views import ContactoFormViewGeneric, contacto_exito_view # Importar
# # ... (app_name = 'productos') ...
# urlpatterns = [
#     # ... (otras urls) ...
#     path('contacto-formview/', ContactoFormViewGeneric.as_view(), name='contacto_formview'),
#     # Reutilizamos la vista de éxito FBV, o podríamos crear una TemplateView
#     path('contacto/exito/', contacto_exito_view, name='contacto_exito'),
# ]
# ```
# `FormView` simplifica el flujo GET/POST y la validación para formularios no asociados a modelos.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 38_2_Metodo_form_valid
#
# Como se vio en el ejemplo, el método **`form_valid(self, form)`** es el lugar clave donde implementas la lógica que debe ocurrir *después* de que el formulario (`forms.Form` o `ModelForm`) haya sido validado con éxito.
#
# *   Recibe la instancia del formulario `form` validado como argumento.
# *   Puedes acceder a los datos limpios con `form.cleaned_data`.
# *   Aquí realizas las acciones correspondientes (guardar en BD - aunque `CreateView`/`UpdateView` lo hacen por defecto-, enviar emails, llamar a otras APIs, etc.).
# *   **Importante:** Este método **debe devolver un `HttpResponse`**, que casi siempre será una redirección a la `success_url` para seguir el patrón PRG. La forma más fácil es llamar a `return super().form_valid(form)`, ya que la implementación base en `FormMixin` (de la que heredan `FormView`, `CreateView`, `UpdateView`) se encarga de la redirección. Si necesitas una redirección personalizada, usa `return redirect(...)`.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ## 39_Personalizacion_de_CBVs_Sobrescritura_de_Metodos_Comunes
#
# La verdadera flexibilidad de las CBVs genéricas proviene de la capacidad de sobrescribir métodos específicos para ajustar su comportamiento sin tener que reescribir toda la lógica.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 39_1_get_queryset_get_object_get_context_data
#
# Estos son métodos clave para controlar los datos que maneja y muestra la vista:
#
# *   **`get_queryset(self)`:**
#     *   Usado por: `ListView`, `DetailView`, `UpdateView`, `DeleteView`.
#     *   Propósito: Devolver el QuerySet base sobre el que operará la vista. Por defecto, usa `self.model.objects.all()` o `self.queryset` si está definido.
#     *   Sobrescríbelo para:
#         *   Filtrar resultados basados en el usuario (`request.user`).
#         *   Filtrar basados en parámetros GET (`request.GET`).
#         *   Aplicar ordenamiento por defecto diferente.
#     *   **Ejemplo:** Mostrar solo productos disponibles en `ListView`.
#         ```python
#         # views.py (dentro de ProductoListView)
#         def get_queryset(self):
#             # Llama al padre por si acaso (aunque aquí no es estrictamente necesario)
#             # queryset = super().get_queryset()
#             # return queryset.filter(disponible=True)
#             return Producto.objects.filter(disponible=True).order_by('nombre')
#         ```
#
# *   **`get_object(self, queryset=None)`:**
#     *   Usado por: `DetailView`, `UpdateView`, `DeleteView`.
#     *   Propósito: Obtener la instancia única del modelo que la vista mostrará/editará/eliminará. Por defecto, usa `self.get_queryset().get(pk=...)` o `get(slug=...)`.
#     *   Sobrescríbelo para:
#         *   Buscar el objeto usando un criterio diferente.
#         *   Añadir comprobaciones de permisos antes de devolver el objeto (aunque los Mixins suelen ser mejores para esto).
#         *   Manejar `DoesNotExist` de forma personalizada (aunque por defecto lanza `Http404`).
#     *   **Ejemplo:** Obtener producto por slug y verificar disponibilidad.
#         ```python
#         # views.py (dentro de ProductoDetailView, asumiendo URL con slug)
#         # from django.http import Http404
#         # def get_object(self, queryset=None):
#         #     if queryset is None:
#         #         queryset = self.get_queryset() # Usa el queryset base (puede tener filtros)
#         #     slug = self.kwargs.get(self.slug_url_kwarg) # Obtener slug de la URL
#         #     if slug is not None:
#         #         try:
#         #             obj = queryset.get(slug=slug)
#         #         except queryset.model.DoesNotExist:
#         #             raise Http404("Producto no encontrado")
#         #         # Aquí podríamos añadir más lógica si fuera necesario
#         #         if not obj.disponible and not self.request.user.is_staff:
#         #              raise Http404("Producto no disponible") # Ejemplo de lógica extra
#         #         return obj
#         #     else:
#         #         # Lógica si no se proporcionó slug (quizás error o comportamiento por defecto)
#         #         raise Http404("No se proporcionó slug")
#
#         ```
#         *Nota: A menudo es más simple filtrar en `get_queryset` que sobrescribir `get_object`.*
#
# *   **`get_context_data(self, **kwargs)`:**
#     *   Usado por: Todas las vistas genéricas que renderizan plantillas (`TemplateView`, `ListView`, `DetailView`, `CreateView`, `UpdateView`, `DeleteView`, `FormView`).
#     *   Propósito: Añadir variables adicionales al diccionario de contexto que se pasará a la plantilla.
#     *   **MUY IMPORTANTE:** Siempre obtén el contexto base llamando a `context = super().get_context_data(**kwargs)` al principio de tu método sobrescrito y devuelve `context` al final.
#     *   **Ejemplo:** Añadir lista de categorías a la vista de detalle de producto.
#         ```python
#         # views.py (dentro de ProductoDetailView)
#         # from .models import Categoria
#         # def get_context_data(self, **kwargs):
#         #     context = super().get_context_data(**kwargs)
#         #     context['categorias'] = Categoria.objects.all()
#         #     # self.object ya está en el contexto (añadido por DetailView)
#         #     # context['producto'] también está por defecto
#         #     return context
#         ```
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 39_2_form_valid_form_invalid_get_success_url
#
# Estos métodos son clave para personalizar el flujo de procesamiento de formularios en `FormView`, `CreateView`, `UpdateView`, `DeleteView`.
#
# *   **`form_valid(self, form)`:**
#     *   Se llama **solo si** el formulario enviado (`request.POST`) es válido.
#     *   Recibe la instancia del formulario `form` validado.
#     *   **Tu lugar para:** Realizar acciones *después* de la validación pero *antes* de la redirección (ej: enviar email, asignar `request.user`, mostrar mensaje flash).
#     *   **Debe devolver un `HttpResponseRedirect`.** La forma más fácil es `return super().form_valid(form)`, que maneja el guardado (en `Create/UpdateView`) y la redirección a `success_url`.
# *   **`form_invalid(self, form)`:**
#     *   Se llama **solo si** el formulario enviado no es válido.
#     *   Recibe la instancia del formulario `form` inválido (con `form.errors` poblado).
#     *   Por defecto, simplemente vuelve a renderizar la plantilla (`template_name`) pasándole el `form` inválido para mostrar los errores.
#     *   Puedes sobrescribirlo si necesitas lógica especial cuando falla la validación (ej: añadir un mensaje flash de error general, loguear el intento fallido). Asegúrate de devolver una `HttpResponse` (normalmente el `render` de la plantilla).
# *   **`get_success_url(self)`:**
#     *   Devuelve la URL (string) a la que se redirigirá después de un `form_valid` exitoso.
#     *   Por defecto, devuelve el valor del atributo `success_url`.
#     *   Sobrescríbelo si la URL de éxito depende del objeto recién creado/editado (accesible como `self.object` después de que `form_valid` base haya llamado a `save`).
#     ```python
#     # views.py (dentro de ProductoCreateView o ProductoUpdateView)
#     # from django.urls import reverse_lazy
#
#     # success_url = reverse_lazy('productos:lista_productos') # Opción 1: URL fija
#
#     # Opción 2: URL dinámica basada en el objeto
#     def get_success_url(self):
#         print("Objeto guardado:", self.object) # self.object es la instancia guardada
#         # Redirigir al detalle del producto recién creado/editado
#         return reverse_lazy('productos:detalle_producto', kwargs={'slug': self.object.slug})
#     ```
#
# Dominar estos métodos de sobrescritura te permite adaptar las vistas genéricas a casi cualquier necesidad sin reescribir todo desde cero.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ## 40_Mixins_en_CBVs_Reutilizacion_de_Logica
#
# Los Mixins son clases diseñadas para **añadir funcionalidades específicas** a otras clases mediante **herencia múltiple**, sin ser una clase base completa por sí mismas. Son una forma clave de lograr reutilización de código y composición en las CBVs de Django.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 40_1_Mixins_Incorporados_LoginRequired_PermissionRequired_UserPassesTest
#
# Django (`django.contrib.auth.mixins`) y las vistas genéricas utilizan muchos mixins internamente y proporcionan algunos muy útiles para control de acceso:
#
# *   **`LoginRequiredMixin`:**
#     *   Asegura que solo usuarios autenticados puedan acceder a la vista.
#     *   Si el usuario no está logueado, lo redirige a `settings.LOGIN_URL` (o al `login_url` definido en el mixin).
#     *   **Importante:** Debe colocarse **antes** de la clase `View` base en la lista de herencia.
#     ```python
#     from django.contrib.auth.mixins import LoginRequiredMixin
#     from django.views.generic import TemplateView
#
#     class MiVistaProtegida(LoginRequiredMixin, TemplateView):
#         template_name = 'secreto.html'
#         # login_url = '/mi_login/' # Opcional: personalizar URL de login
#     ```
# *   **`PermissionRequiredMixin`:**
#     *   Requiere que el usuario autenticado tenga un permiso específico (o varios).
#     *   Define el atributo `permission_required` con el nombre del permiso (`'app.codename'`) o una tupla/lista de permisos (el usuario debe tener *todos*).
#     *   Si falla, redirige a login o lanza `PermissionDenied` (403 Forbidden) si se establece `raise_exception = True`.
#     ```python
#     from django.contrib.auth.mixins import PermissionRequiredMixin
#
#     class CrearProductoPermisoView(LoginRequiredMixin, PermissionRequiredMixin, CreateView):
#         model = Producto
#         fields = '__all__'
#         template_name = '...'
#         permission_required = 'productos.add_producto' # Requiere este permiso
#         # raise_exception = True # Para mostrar 403 si no tiene permiso
#     ```
# *   **`UserPassesTestMixin`:**
#     *   La más flexible. Restringe el acceso basado en el resultado de una función de prueba personalizada.
#     *   Debes implementar el método `test_func(self)` en tu vista. Este método recibe `self` y debe devolver `True` si el usuario debe tener acceso, `False` si no.
#     ```python
#     from django.contrib.auth.mixins import UserPassesTestMixin
#
#     class EditarProductoAutorView(LoginRequiredMixin, UserPassesTestMixin, UpdateView):
#         model = Producto
#         fields = '__all__'
#         template_name = '...'
#
#         def test_func(self):
#             # Obtener el producto que se intenta editar
#             producto = self.get_object()
#             # Permitir solo si el usuario logueado es el autor
#             # Asumiendo que Producto tiene un campo 'autor' ForeignKey a User
#             return self.request.user == producto.autor
#
#         # def handle_no_permission(self): # Opcional: qué hacer si test_func es False
#         #     return redirect('home') # O devolver HttpResponseForbidden()
#     ```
#
# Otros mixins importantes (a menudo usados internamente por las vistas genéricas): `ContextMixin` (añade `get_context_data`), `FormMixin` (añade manejo de formularios), `ModelFormMixin` (añade `form_valid` que guarda el modelo), `SingleObjectMixin` (añade `get_object`), `MultipleObjectMixin` (añade `get_queryset`, paginación).
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 40_2_Creacion_de_Mixins_Personalizados
#
# Puedes crear tus propios mixins para encapsular lógica o comportamiento que quieres reutilizar en varias CBVs. Un mixin es simplemente una clase Python.
#
# **Ejemplo: Un Mixin para añadir un conjunto de categorías al contexto.**
# ```python
# # productos/mixins.py (nuevo archivo)
# from .models import Categoria
#
# class CategoriaContextMixin:
#     """Mixin para añadir todas las categorías al contexto."""
#     def get_context_data(self, **kwargs):
#         # Llama primero al get_context_data de la clase base
#         context = super().get_context_data(**kwargs)
#         # Añade tu contexto adicional
#         context['todas_las_categorias'] = Categoria.objects.all()
#         return context
#
# # productos/views.py
# from django.views.generic import ListView, DetailView
# from .models import Producto
# from .mixins import CategoriaContextMixin # Importar el Mixin
#
# class ProductoListViewConCategorias(CategoriaContextMixin, ListView): # Añadir Mixin
#     model = Producto
#     template_name = 'productos/producto_lista.html'
#     context_object_name = 'productos'
#     # Ahora 'todas_las_categorias' estará disponible en la plantilla automáticamente
#
# class ProductoDetailViewConCategorias(CategoriaContextMixin, DetailView): # Añadir Mixin
#     model = Producto
#     template_name = 'productos/producto_detalle.html'
#     context_object_name = 'producto'
#     # También tendrá 'todas_las_categorias'
# ```
# El orden de herencia importa (Resolución de Métodos - MRO). Los mixins suelen ir *antes* de la vista genérica base (`ListView`, `DetailView`) para que sus métodos (como `get_context_data`) puedan ser llamados por `super()` desde la vista principal o anular métodos de la vista base si es necesario.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 40_3_Ejercicio_Practico_Refactorizar_FBVs_a_CBVs
#
# **Objetivo:** Convertir las vistas basadas en función `lista_productos_view` y `detalle_producto_view` (creadas en la Unidad 2 y modificadas para usar plantillas) a sus equivalentes basadas en clase (`ListView` y `DetailView`).
#
# **Pasos:**
#
# 1.  **Abre `productos/views.py`**.
# 2.  **Importa** `ListView` y `DetailView` de `django.views.generic`.
# 3.  **Crea `ProductoListView(ListView)`:**
#     *   Define `model = Producto`.
#     *   Define `template_name = 'productos/lista_productos.html'`.
#     *   Define `context_object_name = 'lista_productos'` (para que coincida con la variable usada en tu plantilla actual).
#     *   (Opcional) Añade `paginate_by = 10`.
# 4.  **Crea `ProductoDetailView(DetailView)`:**
#     *   Define `model = Producto`.
#     *   Define `template_name = 'productos/detalle_producto.html'`.
#     *   Define `context_object_name = 'producto'`.
#     *   (Opcional) Define `pk_url_kwarg = 'producto_id'` si tu URL todavía usa `producto_id` en lugar de `pk`. O mejor, cambia la URL para que use `pk` o `slug`.
# 5.  **Abre `productos/urls.py`**.
# 6.  **Importa** las nuevas clases CBV.
# 7.  **Modifica los `urlpatterns`:** Cambia las entradas para la lista y el detalle para que apunten a `NombreClaseView.as_view()` en lugar de las funciones FBV. Asegúrate de que los nombres (`name=...`) y los parámetros de URL (`<int:pk>` o `<slug:slug>`) sean correctos para que las CBVs funcionen.
#     *   Para `DetailView`, es estándar usar `<int:pk>/` o `<slug:slug>/` en la URL.
# 8.  **(Opcional)** Puedes comentar o eliminar las antiguas funciones FBV (`lista_productos_view`, `detalle_producto_view`).
# 9.  **Ejecuta `runserver` y prueba:**
#     *   Visita la URL de la lista de productos. Debería funcionar igual que antes, pero ahora servida por `ProductoListView`. Si añadiste paginación, prueba los enlaces.
#     *   Visita la URL de detalle de un producto (asegúrate de que la URL coincida con lo que espera `DetailView`, ej: `/productos/1/` si usa `pk`, o `/productos/item/mi-slug/` si usa `slug`). Debería funcionar igual que antes.
#
# **Solución Propuesta:**
#
# **`productos/views.py`:**
# ```python
# from django.shortcuts import render, get_object_or_404
# # from django.http import HttpResponse # Ya no es necesario para estas vistas
# from django.views.generic import ListView, DetailView
# from .models import Producto
#
# # --- Vistas Basadas en Clase ---
#
# class ProductoListView(ListView):
#     model = Producto
#     # Podríamos filtrar aquí directamente si quisiéramos:
#     # queryset = Producto.objects.filter(disponible=True)
#     template_name = 'productos/lista_productos.html'
#     context_object_name = 'lista_productos' # Coincide con la plantilla existente
#     paginate_by = 10 # Opcional: añadir paginación
#
# class ProductoDetailView(DetailView):
#     model = Producto
#     template_name = 'productos/detalle_producto.html'
#     context_object_name = 'producto'
#     # Asumiendo que la URL usará 'pk' o 'slug'. Si usa 'producto_id', añade:
#     # pk_url_kwarg = 'producto_id'
#
# # --- (FBVs antiguas comentadas o eliminadas) ---
# # def lista_productos_view(request): ...
# # def detalle_producto_view(request, producto_id): ...
#
# # --- (Otras vistas como contacto, etc. pueden seguir siendo FBVs o también refactorizarse) ---
# ```
#
# **`productos/urls.py`:**
# ```python
# from django.urls import path
# # from . import views # Ya no importamos las FBV para lista/detalle
# from .views import ProductoListView, ProductoDetailView # Importar CBVs
# # ... (otras vistas como contacto_view, etc.) ...
#
# app_name = 'productos'
#
# urlpatterns = [
#     # Usar las CBVs .as_view()
#     path('', ProductoListView.as_view(), name='lista_productos'),
#     # Cambiar a <int:pk> que es el default esperado por DetailView
#     path('<int:pk>/', ProductoDetailView.as_view(), name='detalle_producto'),
#     # O si prefieres usar slug (requiere campo slug en modelo y URL)
#     # path('item/<slug:slug>/', ProductoDetailView.as_view(), name='detalle_producto'),
#
#     # ... (URLs de contacto, etc.) ...
# ]
# ```
# **Nota:** Si cambiaste la URL de detalle para usar `pk` o `slug`, asegúrate de actualizar también la etiqueta `{% url %}` en la plantilla `lista_productos.html` y el método `get_absolute_url()` en el modelo `Producto` si lo tenías definido.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ---
# ---
#
# ## **Unidad 9: Autenticación y Autorización**
#
# ## 41_Sistema_de_Autenticacion_de_Django_contrib_auth
#
# La mayoría de las aplicaciones web complejas necesitan gestionar usuarios: permitirles registrarse, iniciar sesión, cerrar sesión y controlar a qué partes de la aplicación pueden acceder. Django viene con un sistema de autenticación y autorización robusto y seguro incorporado en la aplicación `django.contrib.auth`.
#
# Este sistema proporciona:
# *   **Gestión de Usuarios:** Un modelo `User` predeterminado con campos comunes (nombre de usuario, contraseña, email, nombre, apellido, etc.).
# *   **Hashing de Contraseñas:** Almacenamiento seguro de contraseñas utilizando algoritmos de hash fuertes con *salt*. Nunca almacena contraseñas en texto plano.
# *   **Sistema de Sesiones:** Integración con el framework de sesiones de Django para mantener al usuario conectado entre peticiones.
# *   **Vistas y Formularios:** Vistas basadas en clase y formularios listos para usar para tareas comunes como login, logout, cambio de contraseña y reseteo de contraseña.
# *   **Framework de Permisos:** Un sistema para asignar permisos específicos a usuarios o grupos de usuarios, permitiendo controlar el acceso a ciertas acciones o vistas (autorización).
# *   **Integración con el Admin:** El modelo `User` y `Group` son gestionables a través de la interfaz de administración por defecto.
#
# Para utilizarlo, `django.contrib.auth` y su dependencia `django.contrib.contenttypes` deben estar incluidas en `INSTALLED_APPS` (normalmente lo están por defecto), y las migraciones iniciales deben haberse aplicado (`python manage.py migrate`).
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ## 42_Modelo_User_Predeterminado
#
# El modelo estándar `User` se encuentra en `django.contrib.auth.models.User`. Sus campos principales son:
#
# *   `username`: (CharField, único) El nombre de usuario para iniciar sesión.
# *   `password`: (CharField) La contraseña hasheada. Django se encarga del hashing/verificación.
# *   `email`: (EmailField, opcionalmente único) Dirección de correo.
# *   `first_name`: (CharField, opcional) Nombre.
# *   `last_name`: (CharField, opcional) Apellido.
# *   `is_active`: (BooleanField, defecto `True`) Indica si la cuenta está activa. Los usuarios inactivos no pueden iniciar sesión.
# *   `is_staff`: (BooleanField, defecto `False`) Indica si el usuario puede acceder a la interfaz de administración (`/admin/`).
# *   `is_superuser`: (BooleanField, defecto `False`) Indica si el usuario tiene *todos* los permisos sin necesidad de asignárselos explícitamente.
# *   `date_joined`: (DateTimeField) Fecha y hora de creación de la cuenta.
# *   `last_login`: (DateTimeField) Fecha y hora del último inicio de sesión exitoso.
# *   `groups`: Relación ManyToMany con el modelo `Group`.
# *   `user_permissions`: Relación ManyToMany para permisos asignados directamente.
#
# Puedes acceder a este modelo en tu código importándolo:
# ```python
# from django.contrib.auth.models import User
# ```
# Para obtener el usuario actualmente autenticado en una vista, usas `request.user` (si el middleware de autenticación está activo). Si no hay nadie logueado, `request.user` será una instancia de `AnonymousUser`.
#
# Aunque este modelo es suficiente para muchos casos, si necesitas almacenar información adicional sobre los usuarios (ej: fecha de nacimiento, avatar, biografía), la práctica recomendada es crear un modelo de "Perfil" separado con una relación `OneToOneField` al modelo `User` (como vimos en la Unidad 3) o, si necesitas modificar campos fundamentales como usar el email para login, crear un **Modelo de Usuario Personalizado** (ver sección 49), preferiblemente al inicio del proyecto.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ## 43_Vistas_de_Autenticacion_Incorporadas_LoginView_LogoutView
#
# Django te ahorra escribir la lógica para las vistas de autenticación más comunes proporcionando Vistas Basadas en Clase (CBVs) listas para usar en `django.contrib.auth.views`.
#
# *   **`LoginView`:**
#     *   **Propósito:** Maneja el proceso de inicio de sesión. Muestra el formulario en GET y valida las credenciales en POST.
#     *   **Formulario Usado:** `AuthenticationForm` por defecto.
#     *   **Plantilla:** Busca `registration/login.html` por defecto. Puedes cambiarla con el atributo `template_name`.
#     *   **Redirección Éxito:** Redirige a `settings.LOGIN_REDIRECT_URL` o al parámetro `next` de la URL.
#     *   **Contexto:** Pasa `form` a la plantilla.
#
# *   **`LogoutView`:**
#     *   **Propósito:** Cierra la sesión del usuario actual. Generalmente se usa con una petición POST por seguridad (para evitar CSRF en logout vía GET).
#     *   **Plantilla (Opcional):** Si se accede vía GET o si `next_page` no está definido, busca `registration/logged_out.html`. Puedes cambiarla con `template_name`.
#     *   **Redirección:** Redirige a `settings.LOGOUT_REDIRECT_URL` después de cerrar sesión. Puedes especificar una URL diferente con el atributo `next_page`.
#
# *   **Otras Vistas:**
#     *   `PasswordChangeView`, `PasswordChangeDoneView`
#     *   `PasswordResetView`, `PasswordResetDoneView`, `PasswordResetConfirmView`, `PasswordResetCompleteView`
#     (Se verán en la sección 45).
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 43_1_Configuracion_de_URLs_django_contrib_auth_urls
#
# Tienes dos formas principales de usar estas vistas en tus `urls.py`:
#
# **Opción 1: Mapeo Manual (Más control individual)**
# ```python
# # en urls.py (del proyecto o de una app 'accounts')
# from django.urls import path
# from django.contrib.auth import views as auth_views
#
# urlpatterns = [
#     path('login/', auth_views.LoginView.as_view(template_name='mi_app/mi_login.html'), name='login'),
#     path('logout/', auth_views.LogoutView.as_view(next_page='home'), name='logout'), # Redirige a 'home'
#     # ... mapeo manual para otras vistas de auth si las necesitas ...
# ]
# ```
#
# **Opción 2: Usar `include('django.contrib.auth.urls')` (Más rápido)**
# Este método incluye automáticamente patrones de URL para *todas* las vistas de autenticación incorporadas (`login`, `logout`, `password_change`, `password_reset`, etc.) bajo un prefijo común.
#
# ```python
# # urls.py del proyecto (ej: mi_sitio/urls.py)
# from django.urls import path, include
#
# urlpatterns = [
#     path('admin/', admin.site.urls),
#     # ... otras urls ...
#     # Incluir todas las URLs de auth bajo el prefijo 'cuentas/'
#     path('cuentas/', include('django.contrib.auth.urls')),
# ]
# ```
# Esto creará URLs como:
# *   `/cuentas/login/` (apunta a `LoginView`) -> `name='login'`
# *   `/cuentas/logout/` (apunta a `LogoutView`) -> `name='logout'`
# *   `/cuentas/password_change/` -> `name='password_change'`
# *   `/cuentas/password_change/done/` -> `name='password_change_done'`
# *   `/cuentas/password_reset/` -> `name='password_reset'`
# *   `/cuentas/password_reset/done/` -> `name='password_reset_done'`
# *   `/cuentas/reset/<uidb64>/<token>/` -> `name='password_reset_confirm'`
# *   `/cuentas/reset/done/` -> `name='password_reset_complete'`
#
# **Nota:** Si usas `include('django.contrib.auth.urls')`, las vistas buscarán las plantillas dentro de un subdirectorio `registration/` (ver sección siguiente).
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 43_2_Plantillas_Requeridas_registration_directory
#
# Las vistas de autenticación incorporadas esperan encontrar sus plantillas dentro de un directorio llamado `registration` en una de las ubicaciones donde Django busca plantillas (ej: `templates/registration/` en la raíz del proyecto, o `mi_app/templates/registration/`).
#
# Plantillas comunes que necesitarás crear si usas `django.contrib.auth.urls`:
# *   `registration/login.html`: Para el formulario de `LoginView`.
# *   `registration/logged_out.html`: Página mostrada después de `LogoutView`.
# *   `registration/password_change_form.html`: Formulario para cambiar contraseña.
# *   `registration/password_change_done.html`: Éxito al cambiar contraseña.
# *   `registration/password_reset_form.html`: Formulario para solicitar reseteo (pide email).
# *   `registration/password_reset_done.html`: Info después de solicitar reseteo.
# *   `registration/password_reset_email.html`: Plantilla (formato texto) para el email de reseteo.
# *   `registration/password_reset_subject.txt`: Asunto del email de reseteo.
# *   `registration/password_reset_confirm.html`: Formulario para introducir la nueva contraseña (accedido desde el enlace del email).
# *   `registration/password_reset_complete.html`: Éxito al resetear la contraseña.
#
# Puedes copiar las plantillas por defecto desde el código fuente de Django (`django/contrib/admin/templates/registration/`) como punto de partida y personalizarlas.
#
# **Ejemplo `templates/registration/login.html`:**
# ```html
# {% extends "base.html" %} {# Asume que tienes base.html #}
#
# {% block titulo %}Iniciar Sesión{% endblock %}
#
# {% block contenido %}
#   <h2>Iniciar Sesión</h2>
#
#   {% if form.errors %}
#     <p style="color:red;">Usuario o contraseña incorrectos.</p>
#   {% endif %}
#
#   {% if next %}
#     {% if user.is_authenticated %}
#       <p>Tu cuenta no tiene acceso a esta página. Intenta con otra cuenta.</p>
#     {% else %}
#       <p>Por favor, inicia sesión para ver esta página.</p>
#     {% endif %}
#   {% endif %}
#
#   <form method="post" action="{% url 'login' %}">
#     {% csrf_token %}
#     <table>
#       <tr>
#         <td>{{ form.username.label_tag }}</td>
#         <td>{{ form.username }}</td>
#       </tr>
#       <tr>
#         <td>{{ form.password.label_tag }}</td>
#         <td>{{ form.password }}</td>
#       </tr>
#     </table>
#     <input type="submit" value="Iniciar Sesión">
#     <input type="hidden" name="next" value="{{ next }}"> {# Importante para redirigir #}
#   </form>
#
#   <p><a href="{% url 'password_reset' %}">¿Olvidaste tu contraseña?</a></p>
#   <p><a href="#">Registrarse</a></p> {# Enlace a tu vista de registro si la tienes #}
#
# {% endblock %}
# ```
# *   La variable `next` contiene la URL a la que el usuario intentaba acceder antes de ser redirigido al login (si aplica). `LoginView` la usa para redirigir de vuelta después de un login exitoso.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 43_3_Configuraciones_LOGIN_URL_LOGIN_REDIRECT_URL_LOGOUT_REDIRECT_URL
#
# Estas constantes en `settings.py` definen el comportamiento de redirección por defecto para el sistema de autenticación:
#
# *   **`LOGIN_URL`:**
#     *   La URL (o el nombre del patrón de URL) a la que se redirige al usuario cuando intenta acceder a una vista protegida por `@login_required` o `LoginRequiredMixin` pero no está autenticado.
#     *   Valor por defecto: `'/accounts/login/'`.
#     *   Ejemplo: `LOGIN_URL = 'login'` (si tu URL de login tiene `name='login'`) o `LOGIN_URL = '/mi/login/'`.
#
# *   **`LOGIN_REDIRECT_URL`:**
#     *   La URL (o nombre de patrón) a la que se redirige al usuario *después* de un inicio de sesión exitoso, si el parámetro `next` no está presente en la URL de login.
#     *   Valor por defecto: `'/accounts/profile/'`.
#     *   Ejemplo: `LOGIN_REDIRECT_URL = 'dashboard'` o `LOGIN_REDIRECT_URL = '/'` (a la página principal).
#
# *   **`LOGOUT_REDIRECT_URL`:**
#     *   La URL (o nombre de patrón) a la que se redirige al usuario *después* de cerrar sesión exitosamente usando `LogoutView`. Si no se define, `LogoutView` renderiza la plantilla `registration/logged_out.html`.
#     *   Valor por defecto: `None`.
#     *   Ejemplo: `LOGOUT_REDIRECT_URL = 'home'` o `LOGOUT_REDIRECT_URL = '/'`.
#
# Configurar estas variables simplifica el flujo de autenticación en tu sitio.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ## 44_Formularios_de_Autenticacion_AuthenticationForm_UserCreationForm
#
# Django proporciona formularios específicos para autenticación en `django.contrib.auth.forms`.
#
# *   **`AuthenticationForm`:**
#     *   Usado por `LoginView`.
#     *   Tiene campos `username` y `password`.
#     *   **No** es un `ModelForm`. Su método `clean()` valida que las credenciales sean correctas y que el usuario esté activo.
#     *   Devuelve el objeto `User` autenticado a través del método `get_user()` después de `is_valid()`.
#
# *   **`UserCreationForm`:**
#     *   Hereda de `ModelForm` y está vinculado al modelo `User`.
#     *   Diseñado para el registro de **nuevos** usuarios.
#     *   Incluye campos para `username`, `password` (con confirmación `password2`) y realiza la validación necesaria (complejidad de contraseña, coincidencia, unicidad de username).
#     *   Su método `.save()` crea el nuevo usuario con la contraseña correctamente hasheada.
#
# *   **`UserChangeForm`:**
#     *   `ModelForm` para **editar** un usuario existente. Usado por el admin de Django. Más complejo, ya que maneja permisos y campos sensibles.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 44_1_Vista_de_Registro_Simple
#
# Puedes crear fácilmente una vista de registro usando `UserCreationForm`.
#
# **Ejemplo (`accounts/views.py` o donde corresponda):**
# ```python
# # accounts/views.py
# from django.shortcuts import render, redirect
# from django.contrib.auth.forms import UserCreationForm
# from django.urls import reverse_lazy
# # from django.contrib import messages
#
# def vista_registro(request):
#     if request.method == 'POST':
#         form = UserCreationForm(request.POST)
#         if form.is_valid():
#             form.save() # Crea y guarda el nuevo usuario
#             username = form.cleaned_data.get('username')
#             # messages.success(request, f'¡Cuenta creada para {username}! Ya puedes iniciar sesión.')
#             return redirect('login') # Redirige a la página de login
#         # else: # Si no es válido, renderiza de nuevo con errores
#         #     messages.error(request, 'Por favor, corrige los errores en el formulario.')
#     else: # GET
#         form = UserCreationForm()
#     return render(request, 'registration/registro.html', {'form': form})
#
# ```
# **URL (`accounts/urls.py` o `mi_sitio/urls.py`):**
# ```python
# # accounts/urls.py
# from django.urls import path
# from . import views
#
# urlpatterns = [
#     path('registro/', views.vista_registro, name='registro'),
#     # ... (otras urls de accounts como login, logout, etc.)
# ]
#
# # O en mi_sitio/urls.py:
# # path('cuentas/registro/', accounts_views.vista_registro, name='registro'),
# ```
#
# **Plantilla (`templates/registration/registro.html`):**
# ```html
# {% extends 'base.html' %}
#
# {% block titulo %}Registro de Nuevo Usuario{% endblock %}
#
# {% block contenido %}
#   <h2>Crear Cuenta</h2>
#   <form method="post">
#     {% csrf_token %}
#     {{ form.as_p }} {# Renderiza UserCreationForm (username, password1, password2) #}
#     <button type="submit">Registrarme</button>
#   </form>
# {% endblock %}
# ```
# Esta es una implementación básica. Podrías querer un formulario más personalizado (heredando de `UserCreationForm` para añadir email, por ejemplo) o usar paquetes de terceros como `django-allauth` para funcionalidades de registro más avanzadas (verificación de email, login social).
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ## 45_Manejo_de_Contrasenas_Vistas_y_Formularios
#
# Django se encarga del hashing seguro, pero proporciona vistas y formularios para que los usuarios gestionen sus contraseñas.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 45_1_Cambio_de_Contrasena_Usuario_Logueado
#
# Para que un usuario **autenticado** cambie su propia contraseña.
#
# *   **Vista:** `PasswordChangeView` (`django.contrib.auth.views`).
# *   **Formulario:** `PasswordChangeForm` (`django.contrib.auth.forms`). Requiere la contraseña *antigua* y la nueva (con confirmación).
# *   **Plantilla:** `registration/password_change_form.html`.
# *   **URL Éxito:** Redirige a la URL nombrada `'password_change_done'`.
# *   **Vista Éxito:** `PasswordChangeDoneView`.
# *   **Plantilla Éxito:** `registration/password_change_done.html`.
#
# **Configuración URL (si usas `include('django.contrib.auth.urls')`, ya está hecho):**
# ```python
# # urls.py
# from django.contrib.auth import views as auth_views
#
# urlpatterns += [
#     path('password_change/', auth_views.PasswordChangeView.as_view(), name='password_change'),
#     path('password_change/done/', auth_views.PasswordChangeDoneView.as_view(), name='password_change_done'),
# ]
# ```
# Necesitas crear las plantillas `password_change_form.html` y `password_change_done.html`.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 45_2_Reseteo_de_Contrasena_Olvide_mi_Contrasena
#
# Para usuarios que han olvidado su contraseña y **no están autenticados**. Es un flujo más complejo que involucra el envío de un email con un enlace seguro.
#
# *   **Paso 1: Solicitar Reseteo**
#     *   **Vista:** `PasswordResetView`.
#     *   **Formulario:** `PasswordResetForm` (pide el email del usuario).
#     *   **Plantilla:** `registration/password_reset_form.html`.
#     *   **Acción:** Busca el usuario por email, genera un token único y temporal, crea un enlace de reseteo y envía un email al usuario usando las plantillas `password_reset_email.html` (cuerpo) y `password_reset_subject.txt` (asunto).
#     *   **Redirección:** Redirige a la URL `'password_reset_done'`.
# *   **Paso 2: Confirmación de Solicitud**
#     *   **Vista:** `PasswordResetDoneView`.
#     *   **Plantilla:** `registration/password_reset_done.html`. Muestra un mensaje informando que se ha enviado el email (si el email existía).
# *   **Paso 3: Confirmar Nueva Contraseña (desde enlace email)**
#     *   **URL:** Patrón complejo con `uidb64` (ID de usuario codificado) y `token`.
#     *   **Vista:** `PasswordResetConfirmView`.
#     *   **Formulario:** `SetPasswordForm` (pide nueva contraseña y confirmación).
#     *   **Plantilla:** `registration/password_reset_confirm.html`.
#     *   **Acción:** Verifica el `uidb64` y el `token`. Si son válidos y no han expirado, muestra el formulario. En POST, guarda la nueva contraseña (hasheada).
#     *   **Redirección:** Redirige a la URL `'password_reset_complete'`.
# *   **Paso 4: Confirmación de Reseteo Exitoso**
#     *   **Vista:** `PasswordResetCompleteView`.
#     *   **Plantilla:** `registration/password_reset_complete.html`. Informa que la contraseña se ha reseteado y sugiere iniciar sesión.
#
# **Configuración URL (si usas `include('django.contrib.auth.urls')`, ya está hecho):**
# ```python
# # urls.py
# from django.contrib.auth import views as auth_views
#
# urlpatterns += [
#     path('password_reset/', auth_views.PasswordResetView.as_view(), name='password_reset'),
#     path('password_reset/done/', auth_views.PasswordResetDoneView.as_view(), name='password_reset_done'),
#     path('reset/<uidb64>/<token>/', auth_views.PasswordResetConfirmView.as_view(), name='password_reset_confirm'),
#     path('reset/done/', auth_views.PasswordResetCompleteView.as_view(), name='password_reset_complete'),
# ]
# ```
# Necesitas crear todas las plantillas mencionadas (`form`, `done`, `email`, `subject`, `confirm`, `complete`).
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 45_3_Configuracion_de_Email_para_Reseteo
#
# Para que el reseteo de contraseña funcione, Django necesita poder **enviar emails**. Debes configurar el backend de email en `settings.py`.
#
# *   **Para Desarrollo (Consola):** La forma más fácil de probar sin un servidor de email real. Los emails se imprimirán en la consola donde ejecutas `runserver`.
#     ```python
#     # settings.py
#     EMAIL_BACKEND = 'django.core.mail.backends.console.EmailBackend'
#     ```
# *   **Para Producción (SMTP):** Necesitarás configurar los detalles de un servidor SMTP (como Gmail, SendGrid, Mailgun, etc.). **Nunca pongas contraseñas directamente en `settings.py`**, usa variables de entorno.
#     ```python
#     # settings.py
#     import os
#
#     EMAIL_BACKEND = 'django.core.mail.backends.smtp.EmailBackend'
#     EMAIL_HOST = 'smtp.example.com' # Servidor SMTP
#     EMAIL_PORT = 587 # Puerto (587 para TLS, 465 para SSL)
#     EMAIL_USE_TLS = True # Usar TLS (True para puerto 587)
#     # EMAIL_USE_SSL = False # Usar SSL (True para puerto 465)
#     EMAIL_HOST_USER = os.environ.get('EMAIL_USER') # Leer de variable de entorno
#     EMAIL_HOST_PASSWORD = os.environ.get('EMAIL_PASSWORD') # Leer de variable de entorno
#     DEFAULT_FROM_EMAIL = EMAIL_HOST_USER # Email remitente por defecto
#     ```
# Consulta la documentación de Django y de tu proveedor de email para los detalles específicos de configuración SMTP.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ## 46_Proteccion_de_Vistas_login_required_y_LoginRequiredMixin
#
# Es fundamental restringir el acceso a ciertas partes de tu sitio web solo a usuarios que hayan iniciado sesión.
#
# *   **Para Vistas Basadas en Función (FBVs):**
#     *   Usa el decorador `@login_required` de `django.contrib.auth.decorators`.
#     *   Colócalo justo *antes* de la definición de la función de tu vista.
#     *   Si el usuario no está autenticado, lo redirige a `settings.LOGIN_URL`.
#     *   Puedes personalizar la URL de redirección: `@login_required(login_url='/acceso/')`.
#
#     ```python
#     # views.py
#     from django.contrib.auth.decorators import login_required
#     from django.http import HttpResponse
#
#     @login_required
#     def mi_panel_usuario(request):
#         return HttpResponse(f"Panel privado para {request.user.username}")
#     ```
#
# *   **Para Vistas Basadas en Clase (CBVs):**
#     *   Usa el `LoginRequiredMixin` de `django.contrib.auth.mixins`.
#     *   Añádelo a la lista de clases base de tu CBV, **preferiblemente como la primera** (o antes de `View`).
#     *   Hace lo mismo que el decorador: redirige a `settings.LOGIN_URL` si el usuario no está autenticado.
#     *   Puedes personalizar la URL de redirección definiendo el atributo `login_url` en la clase.
#
#     ```python
#     # views.py
#     from django.contrib.auth.mixins import LoginRequiredMixin
#     from django.views.generic import TemplateView
#
#     class PanelUsuarioView(LoginRequiredMixin, TemplateView):
#         template_name = "mi_app/panel.html"
#         # login_url = '/acceso/' # Opcional
#     ```
#
# Estos mecanismos son la forma estándar de asegurar que solo los usuarios registrados accedan a secciones protegidas.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ## 47_Sistema_de_Permisos_y_Grupos
#
# Además de saber *si* un usuario está autenticado, a menudo necesitas saber *qué* puede hacer (autorización). Django incluye un sistema de permisos flexible.
#
# *   **Permisos:** Son banderas asociadas a los modelos que indican si un usuario tiene autorización para realizar ciertas acciones sobre los objetos de ese modelo.
#     *   **Permisos Predeterminados:** Para cada modelo registrado en el admin, Django crea automáticamente cuatro permisos:
#         *   `add_<nombremodelo>` (ej: `productos.add_producto`)
#         *   `change_<nombremodelo>` (ej: `productos.change_producto`)
#         *   `delete_<nombremodelo>` (ej: `productos.delete_producto`)
#         *   `view_<nombremodelo>` (ej: `productos.view_producto`) - Añadido en Django 2.1+
#     *   **Permisos Personalizados:** Puedes definir permisos adicionales en la clase `Meta` de tu modelo.
#         ```python
#         # models.py
#         class Factura(models.Model):
#             # ... campos ...
#             class Meta:
#                 permissions = [
#                     ("can_marcar_como_pagada", "Puede marcar facturas como pagadas"),
#                     ("can_ver_reporte_facturacion", "Puede ver el reporte de facturación"),
#                 ]
#         ```
#         *Después de añadir/cambiar permisos personalizados, **debes ejecutar `python manage.py migrate`** para que se registren en la base de datos.*
#
# *   **Grupos (`django.contrib.auth.models.Group`):** Son una forma de agrupar usuarios y asignarles permisos colectivamente. Un usuario puede pertenecer a múltiples grupos.
#     *   Se gestionan a través del Admin de Django. Creas un grupo (ej: "Editores", "Ventas") y le asignas los permisos deseados.
#
# *   **Asignación de Permisos/Grupos:**
#     *   Puedes asignar permisos directamente a un usuario específico a través del Admin.
#     *   Puedes añadir usuarios a uno o más grupos a través del Admin.
#     *   Un usuario tiene el conjunto de **todos** los permisos asignados directamente a él **más** todos los permisos de **todos** los grupos a los que pertenece.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 47_1_Permisos_Predeterminados_y_Personalizados
#
# Como se describió anteriormente, Django crea `add`, `change`, `delete`, `view` por defecto. Los permisos personalizados se definen en `Meta.permissions` con una tupla `('nombre_codigo', 'Descripción legible')`.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 47_2_Creacion_y_Asignacion_de_Grupos
#
# La forma más sencilla de gestionar grupos y asignarles permisos, y de asignar usuarios a grupos, es a través de la **interfaz de administración de Django (`/admin/`)**.
# 1.  Ve a la sección "Authentication and Authorization" (o similar).
# 2.  Haz clic en "Groups" y luego en "Add group +".
# 3.  Dale un nombre al grupo (ej: "Editores").
# 4.  Selecciona los permisos disponibles que quieres asignar a este grupo en el cuadro de selección múltiple.
# 5.  Guarda el grupo.
# 6.  Ve a la sección "Users".
# 7.  Selecciona un usuario para editarlo.
# 8.  En la sección de permisos/grupos, selecciona el grupo "Editores" en el cuadro de grupos disponibles y muévelo al cuadro de grupos elegidos.
# 9.  Guarda los cambios del usuario. Ahora ese usuario tendrá todos los permisos asociados al grupo "Editores".
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 47_3_Comprobacion_de_Permisos_has_perm_perms_en_plantilla
#
# Puedes verificar si el usuario actual (`request.user`) tiene un permiso específico:
#
# *   **En Vistas (Python):** Usa el método `user.has_perm('app_label.codename')`. Devuelve `True` o `False`.
#     ```python
#     # views.py
#     from django.core.exceptions import PermissionDenied
#
#     def vista_solo_publicadores(request):
#         if not request.user.has_perm('blog.can_publish_post'):
#             raise PermissionDenied # Lanza error 403
#         # ... resto de la lógica ...
#         return HttpResponse("Contenido para publicadores")
#     ```
#     *   `app_label`: El nombre de la aplicación donde se define el modelo/permiso (en minúsculas).
#     *   `codename`: El código del permiso (`add_post`, `change_post`, `can_publish_post`, etc.).
#     *   `user.has_perms(['app.perm1', 'app.perm2'])` verifica si tiene *todos* los permisos de la lista.
#
# *   **En Plantillas (HTML):** Si tienes el context processor `django.contrib.auth.context_processors.auth` activo (por defecto), tienes acceso a la variable `perms`. Úsala como `perms.app_label.codename`.
#     ```html
#     {% if user.is_authenticated %}
#         <p>Usuario: {{ user.username }}</p>
#
#         {# Comprobar permiso específico #}
#         {% if perms.blog.add_post %}
#             <a href="{% url 'blog:crear_post' %}">Nuevo Post</a>
#         {% endif %}
#
#         {# Comprobar múltiples permisos (implícitamente AND) #}
#         {% if perms.blog.change_post and perms.blog.delete_post %}
#             <p>(Tienes permisos para editar y borrar posts)</p>
#         {% endif %}
#
#         {# Comprobar pertenencia a un grupo (menos común en plantillas) #}
#         {# {% if 'Editores' in user.groups.all|join:", " %} ... {% endif %} #}
#     {% endif %}
#     ```
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ## 48_Decorador_permission_required_y_PermissionRequiredMixin_UserPassesTestMixin
#
# Para simplificar la protección de vistas basada en permisos:
#
# *   **Para FBVs:** Usa el decorador `@permission_required`.
#     *   `@permission_required('app_label.codename', login_url=None, raise_exception=False)`
#     *   `login_url`: A dónde redirigir si el usuario no está logueado (usa `settings.LOGIN_URL` por defecto).
#     *   `raise_exception=True`: Lanza `PermissionDenied` (403) en lugar de redirigir si el usuario está logueado pero no tiene el permiso.
#     *   Puedes pasar una lista/tupla de permisos; el usuario debe tener *todos*.
#
#     ```python
#     # views.py
#     from django.contrib.auth.decorators import permission_required
#
#     @permission_required('productos.add_producto', raise_exception=True)
#     def vista_anadir_producto(request):
#         # ...
#         pass
#     ```
#
# *   **Para CBVs:** Usa `PermissionRequiredMixin`.
#     *   Define el atributo `permission_required` (string o tupla/lista).
#     *   Opcionalmente define `login_url` y `raise_exception`.
#     *   Asegúrate de que también hereda de `LoginRequiredMixin` (o que la lógica de `PermissionRequiredMixin` se ejecute solo para usuarios logueados).
#
#     ```python
#     # views.py
#     from django.contrib.auth.mixins import LoginRequiredMixin, PermissionRequiredMixin
#     from django.views.generic.edit import CreateView
#     # ...
#
#     class ProductoCreatePermView(LoginRequiredMixin, PermissionRequiredMixin, CreateView):
#         model = Producto
#         # ...
#         permission_required = 'productos.add_producto'
#         # raise_exception = True
#     ```
#
# *   **`UserPassesTestMixin` / `@user_passes_test`:** (Como vimos antes) Para comprobaciones más complejas que un simple permiso. Define una función que toma `user` y devuelve `True`/`False`.
#
#     ```python
#     # views.py
#     from django.contrib.auth.mixins import UserPassesTestMixin
#     # ...
#
#     def es_miembro_vip(user):
#         return user.is_authenticated and user.groups.filter(name='VIP').exists()
#
#     class VistaVip(UserPassesTestMixin, TemplateView):
#         template_name = 'vip.html'
#         def test_func(self):
#             return es_miembro_vip(self.request.user)
#     ```
#
# Estos mixins y decoradores son la forma estándar de implementar la autorización a nivel de vista.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ## 49_Modelo_de_Usuario_Personalizado_AbstractUser_AbstractBaseUser
#
# Si el modelo `User` incorporado no es suficiente, puedes reemplazarlo. **Hazlo al inicio del proyecto.**
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 49_1_Cuando_y_Por_Que_Personalizar
#
# *   **Necesitas campos adicionales:** Fecha de nacimiento, avatar, número de teléfono, etc. (Aunque esto también se puede lograr con un modelo de Perfil separado con `OneToOneField`).
# *   **Quieres usar el email como identificador principal** en lugar de `username`.
# *   Necesitas modificar el comportamiento fundamental del modelo `User`.
#
# **¿Perfil vs. Usuario Personalizado?**
# *   **Perfil (OneToOneField):** Más simple si solo necesitas añadir campos *opcionales* o relacionados. Mantienes el `User` de Django intacto.
# *   **Usuario Personalizado (AbstractUser):** Mejor si necesitas añadir campos *requeridos* al registrarse, quieres integrar esos campos directamente en formularios/admin de usuario, o quieres cambiar `USERNAME_FIELD`. Es la opción más común para personalización.
# *   **Usuario Personalizado (AbstractBaseUser):** Máxima flexibilidad, pero más trabajo. Úsalo si necesitas un modelo de autenticación muy diferente al de Django (ej: sin username, sistema de permisos completamente distinto).
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 49_2_Configuracion_AUTH_USER_MODEL
#
# **Paso Crítico:** Si decides usar un modelo de usuario personalizado, **ANTES** de ejecutar tu primera migración (`migrate`) o cualquier migración que cree tablas que dependan del usuario, debes indicar a Django cuál es tu modelo de usuario personalizado en `settings.py`:
#
# ```python
# # settings.py
# AUTH_USER_MODEL = 'nombre_app.NombreClaseModeloUsuario'
# # Ejemplo:
# # AUTH_USER_MODEL = 'accounts.Usuario'
# ```
# *   `nombre_app`: El nombre de la aplicación donde definiste tu modelo personalizado.
# *   `NombreClaseModeloUsuario`: El nombre de la clase de tu modelo personalizado.
#
# **¡Si no haces esto al principio, cambiarlo después es muy difícil y requiere migraciones de datos complejas!**
#
# **Referenciar al Modelo User en el Código:**
# Una vez que configuras `AUTH_USER_MODEL`, **no** importes el `User` predeterminado directamente (`from django.contrib.auth.models import User`). En su lugar, usa:
# *   **`settings.AUTH_USER_MODEL`:** Para relaciones `ForeignKey`, `OneToOneField`, `ManyToManyField` en `models.py`.
#     ```python
#     # models.py
#     from django.conf import settings
#     from django.db import models
#
#     class MiModelo(models.Model):
#         # Correcto: usa el string definido en settings
#         creador = models.ForeignKey(settings.AUTH_USER_MODEL, on_delete=models.CASCADE)
#     ```
# *   **`get_user_model()`:** Para obtener la *clase* del modelo de usuario actual en código Python (vistas, formularios, etc.).
#     ```python
#     # views.py
#     from django.contrib.auth import get_user_model
#
#     User = get_user_model() # Obtiene la clase de usuario actual (sea la default o la tuya)
#
#     def mi_vista(request):
#         todos_los_usuarios = User.objects.all()
#         # ...
#     ```
# Usar estas referencias asegura que tu código funcionará correctamente tanto con el `User` predeterminado como con uno personalizado.
#
# **Heredando de `AbstractUser`:** (El método más común)
# ```python
# # accounts/models.py
# from django.contrib.auth.models import AbstractUser
# from django.db import models
#
# class Usuario(AbstractUser):
#     # Hereda: username, first_name, last_name, email, password, groups,
#     # user_permissions, is_staff, is_active, is_superuser, last_login, date_joined
#
#     # Añade tus campos personalizados:
#     bio = models.TextField("Biografía", blank=True)
#     web = models.URLField("Sitio Web", blank=True)
#     fecha_nacimiento = models.DateField("Fecha de Nacimiento", null=True, blank=True)
#
#     # Si quieres usar email como username:
#     # USERNAME_FIELD = 'email'
#     # REQUIRED_FIELDS = ['username'] # Campos requeridos al crear superusuario (además de USERNAME_FIELD y password)
#     # email = models.EmailField(('email address'), unique=True) # Hacer email único si es USERNAME_FIELD
#
#     def __str__(self):
#         return self.username # O self.get_full_name() o self.email
# ```
# Recuerda también crear/personalizar el `UserAdmin` para tu modelo personalizado si quieres gestionarlo bien en el admin.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 49_3_Ejercicio_Practico_Implementar_Login_Registro_y_Proteccion_de_Vistas
#
# **Objetivo:** Configurar las URLs y plantillas básicas para login, logout y registro, y proteger una vista simple.
#
# **Pasos:**
#
# 1.  **Configurar `settings.py`:**
#     *   Define `LOGIN_URL = 'login'`.
#     *   Define `LOGIN_REDIRECT_URL = 'home'` (asume que tienes una URL con `name='home'`, si no, usa `'/'` o el nombre de tu lista de productos).
#     *   Define `LOGOUT_REDIRECT_URL = 'home'`.
# 2.  **Configurar `urls.py` del proyecto:**
#     *   Asegúrate de incluir las URLs de autenticación: `path('cuentas/', include('django.contrib.auth.urls'))`.
#     *   Crea una URL para el registro: `path('cuentas/registro/', accounts_views.vista_registro, name='registro')` (asumiendo que la vista está en `accounts/views.py`).
#     *   Crea una URL para una página principal simple (ej: `/`, `name='home'`) y una página protegida (ej: `/privado/`, `name='privado'`).
# 3.  **Crear Vistas:**
#     *   Crea una vista simple `home_view` (FBV o TemplateView) para la página principal.
#     *   Crea la vista `vista_registro` (FBV) usando `UserCreationForm` como se mostró en la sección 44.1.
#     *   Crea una vista simple `vista_privada` (FBV) protegida con `@login_required` que muestre un mensaje de bienvenida al usuario.
# 4.  **Crear Plantillas:**
#     *   Crea `templates/base.html` (si no la tienes) con enlaces básicos de navegación (Inicio, Productos, Login/Logout).
#     *   Crea `templates/home.html` (o como llames a tu plantilla de inicio).
#     *   Crea `templates/privado.html` para la vista protegida.
#     *   Crea las plantillas necesarias dentro de `templates/registration/`:
#         *   `login.html` (puedes copiar/adaptar el ejemplo de 43.2).
#         *   `logged_out.html` (mensaje simple "Has cerrado sesión").
#         *   `registro.html` (puedes copiar/adaptar el de 44.1).
# 5.  **Probar Flujo:**
#     *   Ejecuta `runserver`.
#     *   Intenta acceder a `/privado/`. Deberías ser redirigido a `/cuentas/login/?next=/privado/`.
#     *   Ve a `/cuentas/registro/`. Crea una nueva cuenta.
#     *   Después del registro, deberías ser redirigido a `/cuentas/login/`.
#     *   Inicia sesión con la nueva cuenta. Deberías ser redirigido a la página principal (`/`).
#     *   Ahora intenta acceder a `/privado/` de nuevo. Deberías poder ver la página.
#     *   Haz clic en el enlace de Logout (si lo añadiste en `base.html`). Deberías ser redirigido a la página principal.
#
# **Solución Propuesta:**
# La solución implica crear/modificar los archivos `settings.py`, `urls.py` (proyecto), `accounts/views.py` (o donde pongas las vistas), `accounts/urls.py` (si creas app separada), y las plantillas `base.html`, `home.html`, `privado.html`, `registration/login.html`, `registration/logged_out.html`, `registration/registro.html` siguiendo los ejemplos y descripciones de las secciones anteriores. El resultado se verifica probando el flujo descrito.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ---
# ---
#
# ## **Unidad 10: Pruebas (Testing)**
#
# ## 50_Importancia_de_las_Pruebas_en_Desarrollo_Web
#
# Escribir código es solo una parte del desarrollo; asegurarse de que ese código funciona correctamente, ahora y en el futuro, es igualmente crucial. Las **pruebas automatizadas** son la herramienta principal para lograr esto. En lugar de probar manualmente cada funcionalidad cada vez que haces un cambio (lo cual es tedioso, propenso a errores y no escalable), escribes código (pruebas) que verifica automáticamente el comportamiento de otro código.
#
# **Beneficios Clave de las Pruebas:**
#
# *   **Detección de Regresiones:** Cuando modificas una parte del código o añades una nueva funcionalidad, las pruebas existentes pueden detectar si has roto algo que antes funcionaba. Esto es vital en proyectos que evolucionan.
# *   **Confianza y Refactorización:** Con una buena suite de pruebas, puedes refactorizar (mejorar la estructura interna del código sin cambiar su comportamiento externo) con mucha más confianza, sabiendo que las pruebas te avisarán si introduces errores.
# *   **Documentación Ejecutable:** Las pruebas describen cómo se espera que funcione tu código. Sirven como documentación que siempre está actualizada (porque si el código cambia y la prueba no, esta fallará).
# *   **Mejor Diseño:** Pensar en cómo probar una pieza de código a menudo te obliga a diseñarla de forma más modular, desacoplada y con responsabilidades claras, lo cual mejora la calidad general.
# *   **Colaboración:** En equipos, las pruebas aseguran que los cambios de un desarrollador no rompan el trabajo de otros y establecen un estándar de calidad.
# *   **Integración Continua (CI/CD):** Las pruebas automatizadas son un pilar fundamental de los pipelines de CI/CD, permitiendo verificar automáticamente cada cambio antes de integrarlo o desplegarlo.
#
# **Tipos Comunes de Pruebas (en el contexto de Django):**
#
# *   **Pruebas Unitarias:** Prueban la unidad más pequeña de código de forma aislada (una función, un método de un modelo, un método de un formulario). Son rápidas de ejecutar.
# *   **Pruebas de Integración:** Prueban la interacción entre varios componentes (ej: una vista que usa un formulario y un modelo). Usan herramientas como el Test Client de Django.
# *   **Pruebas Funcionales/End-to-End (E2E):** Prueban el flujo completo de la aplicación desde la perspectiva del usuario, a menudo simulando interacciones en el navegador (ej: usando Selenium o Cypress). Son más lentas pero verifican la integración de todo el sistema.
#
# Este capítulo se centrará principalmente en las pruebas unitarias y de integración utilizando el framework incorporado de Django.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ## 51_Framework_de_Pruebas_de_Django_unittest_TestCase
#
# Django extiende la librería estándar de Python `unittest` para facilitar la escritura de pruebas para aplicaciones web. Proporciona herramientas específicas para manejar bases de datos, simular peticiones HTTP y realizar aserciones comunes en el contexto de Django.
#
# **Componentes Clave:**
#
# *   **Descubrimiento de Pruebas:** Django busca automáticamente archivos de prueba que sigan ciertas convenciones (normalmente archivos `tests.py` dentro de las aplicaciones, o archivos que empiecen con `test_` en cualquier lugar) y clases que hereden de `django.test.TestCase` (o `unittest.TestCase`), y métodos dentro de esas clases que empiecen con `test_`.
# *   **Ejecutor de Pruebas (`manage.py test`):** El comando que descubre y ejecuta las pruebas.
# *   **Base de Datos de Prueba:** Para cada ejecución de pruebas, Django crea una **base de datos separada y temporal**. Ejecuta todas las migraciones para crear el esquema y luego ejecuta las pruebas contra esta base de datos limpia. Al finalizar, **destruye** la base de datos de prueba, asegurando que tus datos reales no se vean afectados y que cada ejecución de pruebas sea independiente.
# *   **`django.test.TestCase`:** La clase base más común para escribir pruebas en Django. Hereda de `unittest.TestCase` pero añade funcionalidades:
#     *   Cada método de prueba se ejecuta dentro de una **transacción de base de datos** que se revierte (rollback) al finalizar el método. Esto asegura que cada prueba comience con una base de datos limpia (la creada al inicio de la ejecución de la clase) sin afectar a otras pruebas.
#     *   Proporciona un atributo `self.client`, una instancia del **Test Client**.
#     *   Incluye aserciones específicas de Django (ej: `assertTemplateUsed`, `assertRedirects`, `assertContains`).
# *   **Test Client (`django.test.Client`):** Una clase que permite simular peticiones GET, POST, etc., a tu aplicación Django directamente desde tus pruebas, sin necesidad de ejecutar un servidor web. Devuelve un objeto `response` que puedes inspeccionar (código de estado, contexto, HTML renderizado).
# *   **Fixtures:** Mecanismos para cargar datos iniciales en la base de datos de prueba (ver sección 55).
#
# La estructura básica de un archivo de pruebas suele ser:
#
# ```python
# # mi_app/tests.py
# from django.test import TestCase, Client
# from django.urls import reverse
# from .models import MiModelo # Importa tus modelos, forms, etc.
# # from django.contrib.auth.models import User
#
# class MiModeloTestCase(TestCase):
#     # Métodos de configuración opcionales (setUpTestData, setUp, tearDown)
#
#     def test_algun_metodo_del_modelo(self):
#         # Crear instancias, llamar al método, hacer aserciones
#         # self.assertEqual(...)
#         pass
#
#     def test_otra_funcionalidad_modelo(self):
#         # ...
#         pass
#
# class MiVistaTestCase(TestCase):
#     def setUp(self):
#         # Crear cliente y quizás datos necesarios para las pruebas de vista
#         self.client = Client()
#         # self.user = User.objects.create_user(...)
#         # self.objeto = MiModelo.objects.create(...)
#
#     def test_vista_get_status_code(self):
#         url = reverse('mi_app:nombre_url')
#         response = self.client.get(url)
#         self.assertEqual(response.status_code, 200)
#
#     def test_vista_usa_plantilla_correcta(self):
#         url = reverse('mi_app:nombre_url')
#         response = self.client.get(url)
#         self.assertTemplateUsed(response, 'mi_app/plantilla_correcta.html')
#
#     # ... más pruebas para vistas (POST, contexto, etc.) ...
# ```
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ## 52_Escribiendo_Pruebas_Unitarias_para_Modelos
#
# Las pruebas unitarias para modelos se centran en verificar la lógica definida dentro de la clase del modelo y su interacción básica con la base de datos (creación, representación).
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 52_1_Metodos_setUp_setUpTestData_tearDown
#
# Estos métodos de `TestCase` permiten configurar el estado necesario para las pruebas y limpiarlo después.
#
# *   **`setUpTestData(cls)`:**
#     *   Método de clase (`@classmethod`).
#     *   Se ejecuta **una sola vez** al inicio de la ejecución de *todos* los tests de esa clase.
#     *   Ideal para crear objetos que **no serán modificados** por ninguna de las pruebas (ej: usuarios base, categorías fijas). Es más eficiente que crearlos en `setUp` porque la creación en BD solo ocurre una vez.
#     *   Las instancias creadas aquí se asignan a atributos de clase (`cls.objeto = ...`).
#
# *   **`setUp(self)`:**
#     *   Se ejecuta **antes de cada método `test_*`** dentro de la clase.
#     *   Ideal para crear objetos que cada prueba necesita en un estado "fresco" o que podrían ser modificados por la prueba. Recuerda que `TestCase` envuelve cada test en una transacción, por lo que los cambios hechos en `setUp` y en el test se revierten antes del siguiente test.
#     *   Las instancias se asignan a atributos de instancia (`self.objeto = ...`).
#
# *   **`tearDown(self)`:**
#     *   Se ejecuta **después de cada método `test_*`**.
#     *   Menos usado con `TestCase` debido al rollback automático de la transacción, pero puede ser útil si `setUp` realizó acciones externas que necesitan limpieza (ej: crear archivos temporales).
#
# **Ejemplo:**
# ```python
# # tests.py
# from django.test import TestCase
# from .models import Categoria, Producto
#
# class ProductoModelTests(TestCase):
#
#     @classmethod
#     def setUpTestData(cls):
#         # Crear una categoría que no cambiará en los tests
#         cls.categoria_fija = Categoria.objects.create(nombre="Fija", slug="fija")
#         print("(setUpTestData ejecutado)")
#
#     def setUp(self):
#         # Crear un producto nuevo para cada test
#         self.producto_test = Producto.objects.create(
#             nombre="Producto Test", slug="producto-test", precio="10.00", categoria=self.categoria_fija
#         )
#         print("(setUp ejecutado)")
#
#     def tearDown(self):
#         print("(tearDown ejecutado)")
#
#     def test_producto_str(self):
#         print("-> Ejecutando test_producto_str")
#         self.assertEqual(str(self.producto_test), "Producto Test")
#
#     def test_producto_categoria(self):
#         print("-> Ejecutando test_producto_categoria")
#         self.assertEqual(self.producto_test.categoria.nombre, "Fija")
#         # self.producto_test.precio = Decimal("20.00") # Modificarlo aquí no afecta al siguiente test
#         # self.producto_test.save()
#
#     def test_producto_categoria_de_nuevo(self):
#         # Esta prueba recibe una instancia 'fresca' de producto_test gracias al rollback
#         print("-> Ejecutando test_producto_categoria_de_nuevo")
#         self.assertEqual(self.producto_test.categoria.nombre, "Fija")
#         # self.assertEqual(self.producto_test.precio, Decimal("10.00")) # Verificaría que no cambió
# ```
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 52_2_Aserciones_Comunes_assertEqual_assertTrue_etc
#
# Las aserciones son la forma de verificar si el resultado de tu código es el esperado. Si una aserción falla, la prueba falla. `TestCase` proporciona muchas (heredadas de `unittest` y algunas propias de Django).
#
# **Aserciones Comunes (`unittest`):**
# *   `assertEqual(a, b)`: Verifica si `a == b`.
# *   `assertNotEqual(a, b)`: Verifica si `a != b`.
# *   `assertTrue(x)`: Verifica si `x` es verdadero (evalúa a `True`).
# *   `assertFalse(x)`: Verifica si `x` es falso.
# *   `assertIsNone(x)`: Verifica si `x` es `None`.
# *   `assertIsNotNone(x)`: Verifica si `x` no es `None`.
# *   `assertIn(a, b)`: Verifica si `a` está contenido en `b` (`a in b`).
# *   `assertNotIn(a, b)`: Verifica si `a` no está contenido en `b`.
# *   `assertIsInstance(a, b)`: Verifica si `a` es una instancia de la clase `b`.
# *   `assertRaises(Excepcion, funcion, *args, **kwargs)`: Verifica si llamar a `funcion` con los argumentos dados lanza la `Excepcion` especificada.
# *   `assertAlmostEqual(a, b, places=7)`: Para comparar números flotantes con cierta precisión.
#
# **Aserciones Específicas de Django (en `django.test.TestCase`):**
# *   `assertContains(response, texto, status_code=200)`: Verifica si el `texto` está en el cuerpo de la `response` y opcionalmente si el código de estado es el esperado.
# *   `assertNotContains(response, texto, status_code=200)`: Verifica que el `texto` no esté en la respuesta.
# *   `assertQuerysetEqual(qs, valores, transform=repr, ordered=True)`: Compara un QuerySet `qs` con una lista de `valores` esperados. Útil pero a veces complejo de usar correctamente.
# *   `assertTemplateUsed(response, 'nombre_plantilla.html')`: Verifica si se usó una plantilla específica para renderizar la `response`.
# *   `assertTemplateNotUsed(response, 'nombre_plantilla.html')`: Verifica que no se usó una plantilla.
# *   `assertRedirects(response, url_esperada, status_code=302, target_status_code=200)`: Verifica si `response` es una redirección a la `url_esperada` con el código de estado correcto, y opcionalmente verifica el código de estado de la página a la que redirige.
# *   `assertFormError(response, 'nombre_form', 'nombre_campo', 'mensaje_error')`: Verifica si un formulario específico en el contexto de la respuesta tiene un error particular en un campo.
#
# Elige la aserción más específica y clara para lo que quieres probar.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ## 53_Escribiendo_Pruebas_para_Vistas_Test_Client
#
# Probar las vistas es crucial porque verifican la integración de URLs, lógica de vista, interacción con modelos y renderizado de plantillas. El **Test Client** (`self.client` dentro de `TestCase`) es la herramienta principal.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 53_1_Simulando_Peticiones_GET_y_POST
#
# El Test Client tiene métodos para simular diferentes peticiones HTTP:
#
# *   **`self.client.get(path, data=None, follow=False, **extra)`:**
#     *   `path`: La URL a solicitar (usa `reverse()` para obtenerla a partir del nombre).
#     *   `data`: Un diccionario para pasar parámetros GET (query string).
#     *   `follow=True`: Si la respuesta es una redirección, sigue automáticamente la redirección y devuelve la respuesta final.
#     *   `**extra`: Para pasar cabeceras HTTP personalizadas (ej: `HTTP_USER_AGENT='TestClient'`).
#     *   Devuelve un objeto `response`.
#
# *   **`self.client.post(path, data=None, content_type='application/x-www-form-urlencoded', follow=False, **extra)`:**
#     *   `path`: La URL.
#     *   `data`: Un diccionario con los datos a enviar en el cuerpo POST (simulando un formulario).
#     *   `content_type`: El tipo de contenido (importante si envías JSON: `'application/json'`).
#     *   `follow=True`: Para seguir redirecciones.
#     *   `**extra`: Para cabeceras.
#     *   Devuelve un objeto `response`.
#
# *   Existen métodos análogos para otros verbos HTTP: `self.client.head()`, `self.client.put()`, `self.client.patch()`, `self.client.delete()`, `self.client.options()`.
#
# **Ejemplo:**
# ```python
# # tests.py (dentro de una clase que hereda de TestCase)
# from django.urls import reverse
#
# def test_peticion_get_lista(self):
#     url_lista = reverse('productos:lista_productos')
#     response = self.client.get(url_lista)
#     self.assertEqual(response.status_code, 200)
#
# def test_peticion_post_contacto(self):
#     url_contacto = reverse('productos:contacto') # Asumiendo URL de contacto
#     datos_form = {
#         'nombre': 'Usuario Prueba',
#         'email': 'prueba@test.com',
#         'asunto': 'Test POST',
#         'mensaje': 'Mensaje de prueba POST.'
#     }
#     # Simula el envío del formulario
#     response = self.client.post(url_contacto, data=datos_form)
#     # Verificar redirección a la página de éxito (asumiendo patrón PRG)
#     url_exito = reverse('productos:contacto_exito')
#     self.assertRedirects(response, url_exito)
# ```
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 53_2_Comprobando_Codigo_de_Estado_y_Redirecciones
#
# El objeto `response` devuelto por el cliente tiene atributos útiles:
#
# *   `response.status_code`: El código de estado HTTP (200, 302, 404, etc.). Usa `assertEqual` para verificarlo.
# *   `response.url` (después de redirección): Si usaste `follow=True` y hubo redirección, esta es la URL final.
# *   `response.redirect_chain`: Una lista de tuplas `(url, status_code)` si hubo una o más redirecciones (cuando `follow=True`).
#
# **Aserciones:**
# *   `self.assertEqual(response.status_code, 200)` (o 404, 403, etc.)
# *   `self.assertRedirects(response, url_esperada, status_code=302, target_status_code=200)`: La forma más robusta de verificar redirecciones. Comprueba el código 3xx inicial y, opcionalmente, el código de la página final.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 53_3_Comprobando_Plantilla_Usada_y_Contexto
#
# *   **`self.assertTemplateUsed(response, 'nombre_plantilla.html')`:** Verifica que la respuesta haya utilizado la plantilla especificada para renderizarse. Muy útil para asegurar que se está mostrando la vista correcta.
# *   **`response.context`:** Un diccionario que contiene el contexto pasado por la vista a la plantilla. Puedes inspeccionar las variables presentes y sus valores.
#     ```python
#     def test_contexto_lista_productos(self):
#         url = reverse('productos:lista_productos')
#         response = self.client.get(url)
#         self.assertEqual(response.status_code, 200)
#         self.assertTrue('productos' in response.context) # Verifica si la variable existe
#         # Suponiendo que creaste un producto en setUpTestData o setUp
#         # self.assertEqual(len(response.context['productos']), 1)
#         # self.assertEqual(response.context['productos'][0].nombre, self.producto.nombre)
#     ```
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 53_4_Comprobando_Contenido_HTML_assertContains
#
# Para verificar si cierto texto o HTML está presente en la respuesta renderizada:
#
# *   **`self.assertContains(response, texto, count=None, status_code=200)`:**
#     *   Verifica si `texto` (string) está en `response.content`.
#     *   `count` (Opcional): Número exacto de veces que debe aparecer el texto.
#     *   `status_code`: Código de estado esperado (defecto 200).
#     *   Es sensible a mayúsculas/minúsculas.
#
# *   **`self.assertNotContains(response, texto, status_code=200)`:** Verifica que el `texto` **no** esté en la respuesta.
#
# ```python
# # tests.py
# from .models import Producto
#
# class DetalleProductoViewTest(TestCase):
#     @classmethod
#     def setUpTestData(cls):
#         cls.producto = Producto.objects.create(nombre="Producto Visible", slug="visible", precio="50.00")
#         cls.url = reverse('productos:detalle_producto', kwargs={'slug': cls.producto.slug})
#
#     def test_contenido_detalle_producto(self):
#         response = self.client.get(self.url)
#         self.assertEqual(response.status_code, 200)
#         self.assertContains(response, "Producto Visible") # Verifica el título
#         self.assertContains(response, "$50.00") # Verifica el precio formateado (depende de tu plantilla)
#         self.assertNotContains(response, "Producto Oculto")
# ```
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 53_5_Simulando_Login_de_Usuario_client_login
#
# Para probar vistas que requieren autenticación (`@login_required`, `LoginRequiredMixin`), necesitas simular un inicio de sesión con el Test Client.
#
# 1.  **Crea un usuario** en tu `setUp` o `setUpTestData`.
# 2.  Usa `self.client.login(username='...', password='...')`.
#
# ```python
# # tests.py
# from django.test import TestCase, Client
# from django.urls import reverse
# from django.contrib.auth.models import User
#
# class VistaPrivadaTest(TestCase):
#     def setUp(self):
#         self.client = Client()
#         self.user = User.objects.create_user('test', 'test@test.com', 'password')
#         self.url_privada = reverse('mi_app:vista_privada') # Asume esta URL existe
#         self.url_login = reverse('login')
#
#     def test_acceso_sin_login_redirige(self):
#         """Verifica que sin login, se redirige al login."""
#         response = self.client.get(self.url_privada)
#         self.assertRedirects(response, f'{self.url_login}?next={self.url_privada}')
#
#     def test_acceso_con_login_ok(self):
#         """Verifica que con login, se accede (status 200)."""
#         # Iniciar sesión
#         login_success = self.client.login(username='test', password='password')
#         self.assertTrue(login_success) # Verificar que el login fue exitoso
#
#         # Acceder a la página privada
#         response = self.client.get(self.url_privada)
#         self.assertEqual(response.status_code, 200)
#         self.assertTemplateUsed(response, 'mi_app/privado.html') # Asumiendo plantilla
#         self.assertContains(response, "Bienvenido, test") # Asumiendo mensaje
#
#     def test_logout(self):
#         """Verifica el cierre de sesión."""
#         self.client.login(username='test', password='password')
#         # Verificar que está logueado (accediendo a algo protegido)
#         response = self.client.get(self.url_privada)
#         self.assertEqual(response.status_code, 200)
#
#         # Cerrar sesión
#         url_logout = reverse('logout')
#         response_logout = self.client.get(url_logout) # O post si tu logout requiere POST
#         # Verificar redirección después de logout
#         url_redirect_logout = reverse('home') # Asumiendo LOGOUT_REDIRECT_URL='home'
#         self.assertRedirects(response_logout, url_redirect_logout, status_code=302, target_status_code=200, fetch_redirect_response=True)
#
#         # Verificar que ya no puede acceder a la página privada
#         response_despues = self.client.get(self.url_privada)
#         self.assertRedirects(response_despues, f'{self.url_login}?next={self.url_privada}')
# ```
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ## 54_Escribiendo_Pruebas_para_Formularios
#
# Probar las clases `forms.Form` o `forms.ModelForm` directamente (pruebas unitarias) te permite verificar la lógica de validación de forma aislada, sin necesidad de simular peticiones HTTP.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 54_1_Probando_Validez_con_Datos_Correctos_e_Incorrectos
#
# Instancia el formulario pasándole un diccionario `data` y luego llama a `is_valid()`. Usa `assertTrue` o `assertFalse` para verificar el resultado.
#
# ```python
# # tests.py
# from django.test import TestCase
# from .forms import ContactoForm # Asumiendo que existe
#
# class ContactoFormTests(TestCase):
#
#     def test_form_contacto_valido_datos_minimos(self):
#         """Verifica validez con todos los campos requeridos."""
#         data = {
#             'nombre': 'Nombre Válido',
#             'email': 'valido@email.com',
#             'asunto': 'Asunto Válido',
#             'mensaje': 'Mensaje suficientemente largo.'
#             # 'recibir_copia' es opcional, no se necesita aquí
#         }
#         form = ContactoForm(data=data)
#         self.assertTrue(form.is_valid(), f"Errores: {form.errors.as_json()}") # Muestra errores si falla
#
#     def test_form_contacto_invalido_email_incorrecto(self):
#         """Verifica invalidez con email mal formado."""
#         data = {
#             'nombre': 'Nombre', 'email': 'invalido', 'asunto': 'A', 'mensaje': 'Mensaje largo'
#         }
#         form = ContactoForm(data=data)
#         self.assertFalse(form.is_valid())
#
#     def test_form_contacto_invalido_mensaje_corto(self):
#         """Verifica invalidez por validación clean_mensaje."""
#         data = {
#             'nombre': 'Nombre', 'email': 'a@b.com', 'asunto': 'A', 'mensaje': 'Corto' # Menos de 10 chars
#         }
#         form = ContactoForm(data=data)
#         self.assertFalse(form.is_valid())
# ```
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 54_2_Comprobando_Errores_del_Formulario
#
# Cuando `is_valid()` es `False`, puedes inspeccionar el diccionario `form.errors`.
#
# *   `form.errors`: Un diccionario donde las claves son nombres de campo y los valores son listas de strings con los mensajes de error para ese campo. También puede tener la clave `NON_FIELD_ERRORS` (o `__all__`) para errores generales.
# *   `'nombre_campo' in form.errors`: Verifica si un campo tiene errores.
# *   `self.assertEqual(form.errors['nombre_campo'], ['Mensaje de error esperado'])`: Verifica el mensaje exacto.
#
# ```python
# # tests.py (continuación de ContactoFormTests)
#
#     def test_form_contacto_errores_requeridos(self):
#         """Verifica los mensajes de error para campos requeridos."""
#         form = ContactoForm(data={}) # Formulario vacío
#         self.assertFalse(form.is_valid())
#         self.assertIn('nombre', form.errors)
#         self.assertIn('email', form.errors)
#         self.assertIn('asunto', form.errors)
#         self.assertIn('mensaje', form.errors)
#         # Verificar un mensaje específico si lo deseas
#         self.assertEqual(form.errors['nombre'], ['Este campo es obligatorio.'])
#
#     def test_form_contacto_error_mensaje_corto(self):
#         """Verifica el mensaje de error de la validación personalizada."""
#         data = {'nombre': 'N', 'email': 'e@e.c', 'asunto': 'A', 'mensaje': 'Corto'}
#         form = ContactoForm(data=data)
#         self.assertFalse(form.is_valid())
#         self.assertIn('mensaje', form.errors)
#         self.assertEqual(form.errors['mensaje'], ['El mensaje debe tener al menos 10 caracteres.'])
# ```
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ## 55_Fixtures_Carga_de_Datos_de_Prueba_JSON_YAML
#
# Cuando necesitas un conjunto consistente de datos iniciales para tus pruebas (especialmente pruebas de vistas o de integración), crearlos manualmente en `setUpTestData` puede ser repetitivo. Las **fixtures** permiten cargar datos en la base de datos de prueba desde archivos externos.
#
# **Formatos Comunes:** JSON, YAML, XML. JSON es el más usado.
#
# **Ubicación:** La convención es colocar los archivos de fixture dentro de una carpeta `fixtures/` en tu aplicación: `mi_app/fixtures/mi_fixture.json`.
#
# **Creación del Archivo JSON:**
# El archivo debe ser una lista de objetos JSON. Cada objeto representa una instancia de modelo y debe tener tres claves:
# *   `model`: El nombre completo del modelo (`"app_label.ModelName"`).
# *   `pk`: La clave primaria que quieres asignar a este objeto.
# *   `fields`: Un diccionario con los nombres de campo y sus valores correspondientes. Las relaciones ForeignKey se especifican con la PK del objeto relacionado. ManyToMany se especifican con una lista de PKs.
#
# ```json
# // productos/fixtures/productos_test.json
# [
#   {
#     "model": "productos.categoria",
#     "pk": 1,
#     "fields": {
#       "nombre": "Electrónica Test",
#       "slug": "electronica-test",
#       "descripcion": "Categoría para fixtures"
#     }
#   },
#   {
#     "model": "productos.producto",
#     "pk": 101,
#     "fields": {
#       "nombre": "Producto Fixture 1",
#       "slug": "producto-fixture-1",
#       "descripcion": "",
#       "precio": "19.99",
#       "stock": 5,
#       "disponible": true,
#       "fecha_creacion": "2023-10-01T10:00:00Z",
#       "categoria": 1, {# Referencia a la PK de la Categoria de arriba #}
#       "imagen": null
#     }
#   },
#   {
#     "model": "productos.producto",
#     "pk": 102,
#     "fields": {
#       "nombre": "Producto Fixture 2",
#       "slug": "producto-fixture-2",
#       "descripcion": "Otro producto",
#       "precio": "150.50",
#       "stock": 0,
#       "disponible": false,
#       "fecha_creacion": "2023-10-05T12:00:00Z",
#       "categoria": 1
#     }
#   }
# ]
# ```
#
# **Uso en `TestCase`:**
# Añade el atributo `fixtures` a tu clase `TestCase` con una lista de los nombres de archivo de fixture (sin la ruta completa, Django los busca en las carpetas `fixtures/` de las apps).
#
# ```python
# # tests.py
# from django.test import TestCase, Client
# from django.urls import reverse
# from .models import Producto # Importante tener los modelos
#
# class VistasConFixturesTest(TestCase):
#     # Django cargará 'productos_test.json' en la BD de prueba
#     # ANTES de ejecutar cada método test_* de esta clase.
#     fixtures = ['productos_test.json']
#
#     def setUp(self):
#         self.client = Client()
#
#     def test_lista_muestra_productos_fixture(self):
#         url = reverse('productos:lista_productos')
#         response = self.client.get(url)
#         self.assertEqual(response.status_code, 200)
#         # Verificar que los productos de la fixture aparecen
#         self.assertContains(response, "Producto Fixture 1")
#         self.assertContains(response, "Producto Fixture 2")
#         # Verificar el número de productos en el contexto (puede depender de filtros)
#         # self.assertEqual(len(response.context['lista_productos']), 2)
#
#     def test_detalle_producto_fixture(self):
#         # Acceder a un producto cargado por la fixture usando su PK
#         url = reverse('productos:detalle_producto_pk', kwargs={'pk': 101}) # Usando la PK de la fixture
#         response = self.client.get(url)
#         self.assertEqual(response.status_code, 200)
#         self.assertContains(response, "Producto Fixture 1")
#
#     # ... otras pruebas que dependen de los datos de la fixture ...
# ```
#
# **Ventajas:** Datos consistentes y reutilizables, separa datos de prueba del código de prueba.
# **Desventajas:** Menos flexible que crear objetos en `setUpTestData`/`setUp` si necesitas datos dinámicos; mantener los archivos JSON puede ser tedioso.
#
# **`dumpdata`:** Puedes generar archivos fixture a partir de tu base de datos actual usando `python manage.py dumpdata app_label.ModelName --indent 4 > mi_app/fixtures/mi_fixture.json`.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ## 56_Ejecucion_de_Pruebas_manage_py_test_Selectiva
#
# El comando `manage.py test` es la forma de ejecutar tu suite de pruebas.
#
# *   **Ejecutar todas las pruebas del proyecto:**
#     ```bash
#     python manage.py test
#     ```
# *   **Ejecutar pruebas de una aplicación específica:**
#     ```bash
#     python manage.py test nombre_app
#     # Ejemplo:
#     python manage.py test productos
#     ```
# *   **Ejecutar pruebas de un módulo de pruebas específico:** (Si tienes varios archivos de test dentro de una app)
#     ```bash
#     python manage.py test nombre_app.tests_modulo
#     # Ejemplo: python manage.py test productos.test_modelos
#     ```
# *   **Ejecutar pruebas de una clase `TestCase` específica:**
#     ```bash
#     python manage.py test nombre_app.tests.NombreClaseTest
#     # Ejemplo:
#     python manage.py test productos.tests.ProductoModelTests
#     ```
# *   **Ejecutar un método `test_*` específico:**
#     ```bash
#     python manage.py test nombre_app.tests.NombreClaseTest.nombre_metodo_test
#     # Ejemplo:
#     python manage.py test productos.tests.ProductoModelTests.test_producto_str
#     ```
# *   **Opciones Útiles:**
#     *   `-v N` / `--verbosity=N`: Nivel de detalle de la salida (0, 1, 2, 3). `verbosity=2` muestra el resultado de cada test individual.
#     *   `--failfast`: Detiene la ejecución de pruebas inmediatamente después del primer fallo o error.
#     *   `--keepdb`: Preserva la base de datos de prueba entre ejecuciones (acelera si las migraciones son lentas, pero las pruebas no empiezan totalmente limpias).
#     *   `--pattern="patron*.py"`: Para descubrir archivos de prueba con un patrón diferente a `test*.py`.
#
# Ejecutar pruebas de forma selectiva es muy útil durante el desarrollo para centrarte en la parte que estás modificando.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ## 57_Cobertura_de_Pruebas_Coverage_py
#
# La cobertura de pruebas mide qué porcentaje de tu código fuente (líneas, ramas condicionales) es ejecutado por tu suite de pruebas automatizadas. Ayuda a identificar partes de tu código que no están siendo probadas.
#
# Se utiliza una herramienta externa, la más común es `coverage.py`.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 57_1_Instalacion_y_Uso
#
# 1.  **Instalar:** (En tu entorno virtual)
#     ```bash
#     pip install coverage
#     ```
# 2.  **Ejecutar Pruebas *con* Coverage:** En lugar de llamar directamente a `manage.py test`, lo llamas a través de `coverage run`.
#     ```bash
#     # Ejecuta las pruebas y registra qué líneas de código se ejecutan
#     coverage run manage.py test
#     # O para una app específica:
#     # coverage run manage.py test nombre_app
#     ```
#     Esto ejecutará tus pruebas normalmente, pero `coverage` registrará la información de ejecución en un archivo oculto (`.coverage`).
# 3.  **Generar Informes:** Después de la ejecución, puedes generar informes:
#     *   **Informe Resumido en Consola:**
#         ```bash
#         coverage report
#         ```
#         Muestra un resumen por archivo con el número de sentencias (Stmts), las no ejecutadas (Miss), las excluidas (Cover) y el porcentaje de cobertura.
#         ```
#         Name                           Stmts   Miss  Cover
#         --------------------------------------------------
#         manage.py                         12      2    83%
#         mi_sitio/__init__.py               0      0   100%
#         mi_sitio/settings.py              25      0   100%
#         mi_sitio/urls.py                   4      0   100%
#         mi_sitio/wsgi.py                   4      4     0%
#         productos/__init__.py              0      0   100%
#         productos/admin.py                20      2    90%
#         productos/apps.py                  4      0   100%
#         productos/forms.py                15      1    93%
#         productos/models.py               30      3    90%
#         productos/urls.py                  6      0   100%
#         productos/views.py                40     10    75%
#         productos/migrations/__init__.py   0      0   100%
#         --------------------------------------------------
#         TOTAL                            160     22    86%
#         ```
#     *   **Informe HTML Detallado:** (Muy útil)
#         ```bash
#         coverage html
#         ```
#         Esto crea una carpeta `htmlcov/` en tu proyecto. Abre el archivo `index.html` dentro de esa carpeta en tu navegador. Verás un informe interactivo que te permite navegar por tus archivos y ver exactamente qué líneas están cubiertas (en verde) y cuáles no (en rojo).
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 57_2_Interpretacion_de_Informes
#
# *   **Porcentaje de Cobertura:** Es la métrica principal (ej: 86%). Indica qué proporción de tu código se ejercitó.
# *   **Líneas Faltantes (Miss):** Lo más importante es identificar las líneas marcadas en rojo en el informe HTML. Estas son las líneas que ninguna de tus pruebas ejecutó. Analiza por qué:
#     *   ¿Es una rama `if/else` que nunca se probó?
#     *   ¿Es una función o método que nunca se llamó?
#     *   ¿Es una línea dentro de un `except` que nunca se alcanzó?
# *   **Objetivo:** No te obsesiones con alcanzar el 100% (a veces es difícil o no práctico probar ciertas líneas, como bloques `except` muy raros). Un objetivo razonable suele ser >85-90%, pero lo fundamental es asegurar que la **lógica crítica y compleja** de tu aplicación esté bien cubierta por pruebas significativas. Un 100% de cobertura no garantiza la ausencia de bugs, solo que cada línea fue ejecutada al menos una vez.
#
# Usa la cobertura como una **guía** para encontrar puntos ciegos en tus pruebas, no como un objetivo absoluto por sí mismo. Escribe pruebas para la lógica importante que falta.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 57_3_Ejercicio_Practico_Escribir_Pruebas_para_App_Blog
#
# **Objetivo:** Escribir pruebas unitarias y de integración básicas para la aplicación `blog` (o `productos` si es la que has estado desarrollando).
#
# **Pasos:**
#
# 1.  **Abre el archivo `tests.py`** de tu aplicación (`blog/tests.py` o `productos/tests.py`).
# 2.  **Pruebas de Modelo:**
#     *   Crea una clase `TestModeloPrincipal(TestCase)` (ej: `TestPost` o `TestProducto`).
#     *   En `setUpTestData`, crea las instancias relacionadas necesarias (ej: `User`, `Categoria`).
#     *   En `setUp`, crea una instancia del modelo principal (ej: `Post`, `Producto`).
#     *   Escribe un método `test_metodo_str` que verifique si `str(instancia)` devuelve lo esperado (ej: el título).
#     *   Escribe un método que pruebe algún campo con valor por defecto (ej: `test_campo_publicado_default`).
#     *   Escribe un método que pruebe un método personalizado del modelo (ej: `test_get_absolute_url` si lo tienes, verificando que devuelve la URL correcta usando `reverse`).
# 3.  **Pruebas de Vista:**
#     *   Crea una clase `TestVistaPrincipal(TestCase)` (ej: `TestPostViews` o `TestProductoViews`).
#     *   En `setUp`, crea `self.client` y cualquier objeto de modelo necesario para las pruebas (puede que necesites reutilizar los de `setUpTestData` de la clase de modelo o crear nuevos). Define las URLs usando `reverse`.
#     *   Escribe un método `test_vista_lista_status_code` que haga un GET a la URL de la lista y verifique `status_code == 200`.
#     *   Escribe un método `test_vista_lista_usa_plantilla` que verifique que se usa la plantilla correcta (`assertTemplateUsed`).
#     *   Escribe un método `test_vista_lista_muestra_contenido` que verifique que el nombre/título de un objeto creado aparece en la respuesta (`assertContains`).
#     *   Escribe un método `test_vista_detalle_status_code` para un objeto existente (200) y uno inexistente (404).
#     *   Escribe un método `test_vista_detalle_usa_plantilla`.
#     *   Escribe un método `test_vista_detalle_muestra_contenido`.
# 4.  **(Opcional) Pruebas de Formulario:**
#     *   Crea una clase `TestFormulario(TestCase)`.
#     *   Escribe un método que pruebe el formulario con datos válidos (`assertTrue(form.is_valid())`).
#     *   Escribe un método que pruebe el formulario con datos inválidos (ej: campo requerido vacío) y verifique `assertFalse(form.is_valid())` y que `form.errors` contiene el error esperado.
# 5.  **Ejecuta las pruebas:**
#     ```bash
#     python manage.py test nombre_app
#     ```
#     Verifica que todas las pruebas pasen (`OK`).
# 6.  **(Opcional)** Ejecuta con cobertura:
#     ```bash
#     coverage run manage.py test nombre_app
#     coverage report
#     coverage html # y abre htmlcov/index.html
#     ```
#     Analiza qué partes de tu código de modelos y vistas están cubiertas.
#
# **Solución Propuesta:**
# La solución consiste en implementar los métodos de prueba descritos dentro de las clases `TestCase` en el archivo `tests.py` de tu aplicación, siguiendo los patrones mostrados en las secciones 52, 53 y 54. El resultado final es que `manage.py test nombre_app` se ejecute sin fallos.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ---
# ---
#
# ## **Unidad 11: Despliegue (Deployment)**
#
# ## 58_Diferencias_Entorno_Desarrollo_vs_Produccion
#
# Hasta ahora, hemos trabajado principalmente en un entorno de *desarrollo* local, utilizando el servidor incorporado de Django (`manage.py runserver`) y configuraciones orientadas a la facilidad de uso y depuración (como `DEBUG = True`). El despliegue (deployment) es el proceso de llevar tu aplicación a un servidor público (*producción*) para que los usuarios reales puedan acceder a ella. Los requisitos y configuraciones para producción son muy diferentes a los de desarrollo.
#
# **Comparativa Clave:**
#
# | Característica        | Entorno de Desarrollo (`runserver`)                     | Entorno de Producción                                   | **Razón**                                      |
# | :-------------------- | :------------------------------------------------------ | :------------------------------------------------------ | :--------------------------------------------- |
# | **Servidor Web**      | Servidor ligero Python (no robusto, 1 hilo)           | Servidor Web (Nginx, Apache) + Servidor WSGI/ASGI     | Rendimiento, escalabilidad, seguridad        |
# | **`DEBUG` setting**   | `True`                                                  | **`False`**                                             | Seguridad (no exponer info sensible)           |
# | **`SECRET_KEY`**      | Puede estar en `settings.py` (no ideal)                 | **Secreta**, fuera del código (env var, archivo)      | Seguridad criptográfica                      |
# | **`ALLOWED_HOSTS`**   | Flexible (ej: `[]`, `['*']` si `DEBUG=True`)          | **Lista explícita** de dominios/IPs permitidos        | Seguridad (prevenir ataques Host header)      |
# | **Archivos Estáticos**| Servidos por `django.staticfiles` (si `DEBUG=True`)     | Servidos por Nginx/Apache desde `STATIC_ROOT`           | Eficiencia (Nginx/Apache son más rápidos)    |
# | **Archivos de Medios** | Servidos por Django (con config URL si `DEBUG=True`)    | Servidos por Nginx/Apache desde `MEDIA_ROOT`            | Eficiencia                                   |
# | **Base de Datos**     | SQLite (común), PostgreSQL/MySQL local                | PostgreSQL, MySQL (robustas, escalables, backups)     | Rendimiento, concurrencia, fiabilidad        |
# | **Rendimiento**       | No optimizado, recarga de código                      | Optimizado (múltiples workers/threads, caché)         | Manejar tráfico real                         |
# | **Seguridad General** | Baja                                                    | Alta (HTTPS, firewall, actualizaciones, etc.)         | Proteger datos y aplicación                  |
# | **Manejo Errores**    | Página detallada de error Django                      | Páginas de error personalizadas (404, 500), Logging   | Experiencia de usuario, seguridad            |
# | **Email Backend**     | `console.EmailBackend` (común)                        | `smtp.EmailBackend` (real) o servicio externo (SendGrid) | Funcionalidad real                             |
#
# **Conclusión:** Nunca uses la configuración de desarrollo (especialmente `runserver` y `DEBUG=True`) en un entorno de producción real. Necesitas configurar un stack de servidor adecuado y ajustar `settings.py` para seguridad y rendimiento.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ## 59_Configuraciones_para_Produccion_DEBUG_SECRET_KEY_ALLOWED_HOSTS
#
# Ajustar estas configuraciones en `settings.py` es el primer paso y el más crítico para preparar tu aplicación para producción.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 59_1_Gestion_de_Settings_Multiples_Entornos
#
# Es muy común tener diferentes configuraciones para desarrollo, pruebas, staging y producción. En lugar de tener un solo `settings.py` y modificarlo manualmente o usar muchos `if DEBUG: ... else: ...`, existen patrones para gestionar esto:
#
# **Patrón Común: Paquete de Settings**
#
# 1.  **Renombrar/Mover `settings.py`:** Convierte el directorio `mi_sitio/` en un paquete `settings/` (o mantenlo como `mi_sitio/` pero crea un subdirectorio `settings/`).
# 2.  **Crear `base.py`:** Mueve todas las configuraciones *comunes* a todos los entornos a `settings/base.py`.
# 3.  **Crear `development.py`, `production.py`, `testing.py`:** Crea archivos separados para cada entorno.
# 4.  **Importar Base:** En cada archivo específico del entorno (ej: `production.py`), importa todo desde la base: `from .base import *`.
# 5.  **Sobrescribir/Añadir:** Define o sobrescribe solo las variables específicas de ese entorno (ej: `DEBUG = False`, `ALLOWED_HOSTS`, `DATABASES` con credenciales de producción) en el archivo correspondiente.
# 6.  **Gestionar `SECRET_KEY`:** La `SECRET_KEY` **nunca** debe estar en `base.py` ni commiteada. Cárgala desde una variable de entorno o un archivo secreto en `production.py` y quizás genera una por defecto solo en `development.py` (advirtiendo que no es segura).
# 7.  **Indicar a Django qué settings usar:**
#     *   **Variable de Entorno:** Establece la variable de entorno `DJANGO_SETTINGS_MODULE` antes de ejecutar `manage.py` o el servidor WSGI. Ej: `export DJANGO_SETTINGS_MODULE='mi_sitio.settings.production'` (Linux/macOS) o `set DJANGO_SETTINGS_MODULE=mi_sitio.settings.production` (Windows CMD).
#     *   **Argumento en `manage.py`/WSGI:** Puedes pasar `--settings=mi_sitio.settings.production`.
#     *   **En `manage.py`, `wsgi.py`, `asgi.py`:** Puedes establecer el valor por defecto `os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'mi_sitio.settings.development')` y cambiarlo con una variable de entorno para producción.
#
# **Ejemplo `settings/production.py`:**
# ```python
# from .base import * # Importar toda la configuración base
# import os
# # import dj_database_url # Útil para PaaS
#
# # --- Configuraciones de Producción ---
#
# DEBUG = False # ¡MUY IMPORTANTE!
#
# # Cargar desde variable de entorno (lanza error si no existe)
# SECRET_KEY = os.environ['DJANGO_SECRET_KEY']
#
# # Dominios permitidos (leer de variable de entorno si es necesario)
# ALLOWED_HOSTS = ['www.misitio.com', 'misitio.com']
# # CSRF_TRUSTED_ORIGINS = ['https://www.misitio.com', 'https://misitio.com'] # Para HTTPS
#
# # Configuración de Base de Datos (ejemplo PostgreSQL desde env vars)
# DATABASES = {
#     'default': {
#         'ENGINE': 'django.db.backends.postgresql',
#         'NAME': os.environ.get('DB_NAME'),
#         'USER': os.environ.get('DB_USER'),
#         'PASSWORD': os.environ.get('DB_PASSWORD'),
#         'HOST': os.environ.get('DB_HOST'),
#         'PORT': os.environ.get('DB_PORT', '5432'),
#     }
#     # O usando dj_database_url
#     # 'default': dj_database_url.config(default=os.environ.get('DATABASE_URL'), conn_max_age=600)
# }
#
# # Configuración Email (ejemplo SMTP desde env vars)
# EMAIL_BACKEND = 'django.core.mail.backends.smtp.EmailBackend'
# EMAIL_HOST = os.environ.get('EMAIL_HOST')
# EMAIL_PORT = int(os.environ.get('EMAIL_PORT', 587))
# EMAIL_USE_TLS = os.environ.get('EMAIL_USE_TLS', 'true').lower() == 'true'
# EMAIL_HOST_USER = os.environ.get('EMAIL_USER')
# EMAIL_HOST_PASSWORD = os.environ.get('EMAIL_PASSWORD')
# DEFAULT_FROM_EMAIL = EMAIL_HOST_USER
#
# # Configuración de Logging para producción...
# # Configuración de Caching para producción...
#
# # Configuración de Seguridad Adicional (HTTPS)
# # SECURE_PROXY_SSL_HEADER = ('HTTP_X_FORWARDED_PROTO', 'https')
# # SECURE_SSL_REDIRECT = True
# # SESSION_COOKIE_SECURE = True
# # CSRF_COOKIE_SECURE = True
# # SECURE_HSTS_SECONDS = 31536000 # 1 año
# # SECURE_HSTS_INCLUDE_SUBDOMAINS = True
# # SECURE_HSTS_PRELOAD = True
# # SECURE_CONTENT_TYPE_NOSNIFF = True
# # SECURE_BROWSER_XSS_FILTER = True # Deprecado en favor de CSP
# # X_FRAME_OPTIONS = 'DENY'
#
# # STATIC_ROOT debe estar definido en base.py o aquí si varía
# # MEDIA_ROOT debe estar definido en base.py o aquí si varía
#
# ```
# Este enfoque mantiene las configuraciones separadas y seguras.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 59_2_Variables_de_Entorno_python_dotenv
#
# Como vimos, almacenar configuraciones sensibles (SECRET_KEY, contraseñas de BD, claves API) directamente en `settings.py` es una mala práctica de seguridad, especialmente si el código está en un repositorio Git. La solución estándar es usar **variables de entorno**.
#
# **¿Cómo establecerlas?**
# *   **Directamente en el Sistema Operativo:** Depende de tu SO y método de despliegue (ej: usando `export` en Linux, configuración del panel de control en PaaS, secretos en Kubernetes/Docker).
# *   **Usando un archivo `.env` (Para Desarrollo Local):** Es muy común usar una librería como `python-dotenv` para cargar variables desde un archivo `.env` en la raíz de tu proyecto *solo* durante el desarrollo local. **Asegúrate de añadir `.env` a tu `.gitignore`** para no commitearlo.
#
# 1.  **Instalar `python-dotenv`:**
#     ```bash
#     pip install python-dotenv
#     ```
#     (Añádelo a `requirements.txt`).
# 2.  **Crear archivo `.env`** en la raíz del proyecto (junto a `manage.py`):
#     ```dotenv
#     # .env - ¡AÑADIR A .gitignore!
#     DEBUG=True
#     DJANGO_SECRET_KEY='tu-clave-secreta-muy-larga-y-aleatoria-para-desarrollo'
#     DATABASE_URL='sqlite:///db.sqlite3' # Ejemplo SQLite
#     # O para PostgreSQL local:
#     # DB_NAME=mi_db_local
#     # DB_USER=mi_usuario_local
#     # DB_PASSWORD=mi_password_local
#     # DB_HOST=localhost
#     # DB_PORT=5432
#     EMAIL_USER=tu_email@ejemplo.com
#     EMAIL_PASSWORD=tu_password_email # O mejor, una app password
#     ```
# 3.  **Cargar variables en `settings.py` (o `manage.py`, `wsgi.py`, `asgi.py`):** Añade esto al principio de tu archivo de settings *base* o principal:
#     ```python
#     # settings/base.py (o mi_sitio/settings.py)
#     from pathlib import Path
#     import os
#     from dotenv import load_dotenv # Importar
#
#     BASE_DIR = Path(__file__).resolve().parent.parent.parent # Ajusta según tu estructura
#
#     # Cargar variables desde .env (buscará en el directorio actual o superiores)
#     load_dotenv()
#
#     # Ahora puedes acceder a las variables con os.environ.get() o os.environ[...]
#     SECRET_KEY = os.environ.get('DJANGO_SECRET_KEY')
#     DEBUG = os.environ.get('DEBUG', 'False').lower() == 'true' # Convertir string a boolean
#
#     # ... resto de tus settings usando os.environ.get() ...
#     ```
# En **producción**, **no** usarás el archivo `.env`. En su lugar, configurarás las variables de entorno directamente en el servidor o plataforma de despliegue. `os.environ.get()` leerá esas variables del entorno del sistema operativo.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ## 60_Servidores_WSGI_Gunicorn_uWSGI
#
# El servidor de desarrollo (`runserver`) no es adecuado para producción. Necesitas un **servidor de aplicaciones WSGI** dedicado para ejecutar tu código Django de manera eficiente y escalable. Estos servidores actúan como intermediarios entre un servidor web (como Nginx) y tu aplicación Django.
#
# *   **WSGI (Web Server Gateway Interface):** El estándar de facto en Python para la comunicación síncrona entre servidores web y aplicaciones/frameworks. Tu archivo `mi_sitio/wsgi.py` contiene el punto de entrada WSGI (`application`).
# *   **ASGI (Asynchronous Server Gateway Interface):** El sucesor de WSGI, diseñado para soportar aplicaciones Python asíncronas (usando `async`/`await`), necesario para funcionalidades como WebSockets con Django Channels. Tu archivo `mi_sitio/asgi.py` contiene el punto de entrada ASGI.
#
# **Servidores WSGI Populares:**
#
# *   **Gunicorn (Green Unicorn):**
#     *   Muy popular, relativamente simple de configurar.
#     *   Escrito en Python.
#     *   Modelo de workers pre-fork (un proceso maestro gestiona múltiples procesos trabajadores).
#     *   Fácil integración con Nginx.
#     *   Instalación: `pip install gunicorn`
#
# *   **uWSGI:**
#     *   Extremadamente potente, rápido y configurable.
#     *   Escrito en C.
#     *   Muchas opciones de configuración (archivos `.ini` o `.yaml`).
#     *   Puede ser más complejo de configurar inicialmente.
#     *   Funciona bien con Nginx y Apache (mod_uwsgi).
#     *   Instalación: `pip install uwsgi` (puede requerir herramientas de compilación C).
#
# **Servidores ASGI Populares (si usas funcionalidades asíncronas o Channels):**
#
# *   **Daphne:** Servidor ASGI mantenido por los creadores de Django/Channels.
# *   **Uvicorn:** Servidor ASGI de alto rendimiento, popularizado por frameworks como FastAPI, pero también usable con Django ASGI.
# *   **Hypercorn:** Otro servidor ASGI compatible.
#
# **Gunicorn + Uvicorn (Configuración común para ASGI):** A menudo se usa Gunicorn como gestor de procesos y Uvicorn como la clase de worker ASGI dentro de Gunicorn para ejecutar aplicaciones ASGI Django.
# ```bash
# pip install gunicorn uvicorn
# # Ejecutar:
# gunicorn mi_sitio.asgi:application -k uvicorn.workers.UvicornWorker --bind 0.0.0.0:8000
# ```
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 60_1_Instalacion_y_Ejecucion_Basica
#
# **Gunicorn:**
# 1.  `pip install gunicorn`
# 2.  Ejecutar (desde el directorio con `manage.py`):
#     ```bash
#     # (venv)
#     gunicorn --workers 3 --bind 0.0.0.0:8000 mi_sitio.wsgi:application
#     # --workers 3: Ejemplo, ajusta según tus cores (2*cores+1 es un inicio)
#     # --bind 0.0.0.0:8000: Escucha en el puerto 8000 en todas las interfaces
#     # mi_sitio.wsgi:application: Ruta al objeto WSGI
#     ```
#
# **uWSGI:**
# 1.  `pip install uwsgi`
# 2.  Crear archivo de configuración (ej: `uwsgi.ini`):
#     ```ini
#     # uwsgi.ini
#     [uwsgi]
#     # Variables
#     project = mi_sitio
#     base = /ruta/absoluta/a/tu/proyecto # Cambia esto
#
#     # Configuración principal
#     chdir = %(base)
#     module = %(project).wsgi:application # O .asgi:application para ASGI
#
#     master = true
#     processes = 4 # Número de workers
#     # threads = 2 # Si usas multithreading
#
#     # Socket para Nginx/Apache (preferido sobre puerto HTTP)
#     socket = %(base)/%(project).sock
#     # O socket http:
#     # http = 0.0.0.0:8000
#
#     chmod-socket = 664 # Permisos para que Nginx pueda leer/escribir
#     vacuum = true # Elimina el socket al salir
#
#     die-on-term = true # Salir limpiamente con SIGTERM
#
#     # Archivos de log (opcional)
#     # logto = /var/log/uwsgi/%(project).log
#     ```
# 3.  Ejecutar:
#     ```bash
#     # (venv)
#     uwsgi --ini uwsgi.ini
#     ```
#
# **Gestión de Procesos:** En producción, no ejecutarás Gunicorn/uWSGI directamente en la terminal. Usarás un **supervisor de procesos** como `systemd` (estándar en la mayoría de distros Linux modernas) o `supervisor` para:
# *   Iniciar Gunicorn/uWSGI automáticamente cuando el servidor arranque.
# *   Reiniciarlo si falla.
# *   Gestionar logs.
# *   Controlarlo (start, stop, restart).
#
# Configurar `systemd` o `supervisor` está fuera del alcance de este curso, pero es un paso esencial en producción.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 60_2_Configuracion_Workers_Threads
#
# *   **Workers (Procesos):** Gunicorn/uWSGI usan un modelo multi-proceso para manejar peticiones concurrentes. Cada worker es un proceso Python independiente que puede manejar una petición a la vez (en el modo síncrono estándar).
#     *   **Ventaja:** Aprovechan múltiples cores de CPU. Si un worker se bloquea o falla, los otros pueden seguir funcionando.
#     *   **Desventaja:** Consumen más memoria (cada worker carga la aplicación).
#     *   **Número:** Una regla común es `(2 * número_de_cores_CPU) + 1`. Necesitarás experimentar para encontrar el óptimo para tu carga y memoria disponible.
# *   **Threads (Hilos - Opcional/Avanzado):** Algunos tipos de workers (ej: `gthread` en Gunicorn, opción `threads` en uWSGI) permiten que cada proceso worker maneje múltiples peticiones simultáneamente usando hilos.
#     *   **Ventaja:** Menor consumo de memoria que añadir más procesos para la misma concurrencia. Puede ser bueno si tu aplicación pasa mucho tiempo esperando I/O (red, base de datos).
#     *   **Desventaja:** Sujeto al [GIL (Global Interpreter Lock)](https://wiki.python.org/moin/GlobalInterpreterLock) de Python, que limita el paralelismo real de CPU en código Python puro. La gestión de concurrencia con hilos puede ser más compleja.
# *   **Workers Asíncronos (para ASGI):** Si usas ASGI (con Uvicorn, Daphne, Hypercorn), el modelo es diferente. Se basa en `asyncio` y un solo proceso puede manejar muchas conexiones concurrentes esperando I/O de forma no bloqueante. A menudo se ejecutan múltiples procesos worker también para aprovechar los cores.
#
# La configuración óptima de workers/threads depende mucho de la naturaleza de tu aplicación (CPU-bound vs I/O-bound) y de los recursos de tu servidor.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ## 61_Servidores_Web_Proxy_Inverso_Nginx_Apache
#
# Como se mencionó en la Unidad 11, Sección 58, nunca expones tu servidor WSGI/ASGI (Gunicorn, uWSGI) directamente a Internet. Siempre colocas un servidor web robusto delante actuando como **proxy inverso**. Los más comunes son **Nginx** y **Apache**.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 61_1_Por_Que_Usar_un_Proxy_Inverso
#
# *   **Manejo de Conexiones:** Son extremadamente eficientes manejando miles de conexiones concurrentes de clientes.
# *   **Servir Archivos Estáticos/Medios:** Lo hacen mucho más rápido que Django/Python.
# *   **Terminación SSL/TLS (HTTPS):** Gestionan el cifrado/descifrado, liberando a la aplicación Python.
# *   **Balanceo de Carga:** Pueden distribuir el tráfico entre múltiples instancias de tu aplicación Django/WSGI.
# *   **Compresión (Gzip/Brotli):** Comprimen las respuestas para acelerar la entrega.
# *   **Caching:** Pueden cachear respuestas estáticas o dinámicas.
# *   **Seguridad:** Actúan como primera línea de defensa, pueden filtrar peticiones maliciosas, limitar tasas de acceso, etc.
# *   **Enrutamiento:** Pueden dirigir peticiones a diferentes aplicaciones o servicios basados en el dominio o la ruta.
#
# El servidor WSGI se enfoca en ejecutar tu código Python, mientras que el servidor web se enfoca en manejar las conexiones de red y servir contenido estático eficientemente.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 61_2_Configuracion_Basica_Ejemplo_Nginx
#
# La configuración exacta varía, pero aquí un ejemplo conceptual de un bloque `server` en Nginx (`/etc/nginx/sites-available/mi_sitio`) para actuar como proxy inverso para Gunicorn/uWSGI escuchando en un socket Unix (preferido sobre puerto local por eficiencia y seguridad).
#
# ```nginx
# upstream app_server {
#     # Apunta al socket Unix creado por Gunicorn/uWSGI
#     # (Debe coincidir con la configuración de Gunicorn/uWSGI)
#     server unix:/ruta/a/tu/proyecto/mi_sitio.sock fail_timeout=0;
#     # O si Gunicorn/uWSGI escucha en un puerto:
#     # server 127.0.0.1:8000 fail_timeout=0;
# }
#
# server {
#     listen 80;                  # Escucha en HTTP
#     # listen 443 ssl http2;    # Escucha en HTTPS (requiere config SSL abajo)
#     server_name misitio.com www.misitio.com; # Tus dominios
#
#     # Configuración SSL (Ejemplo - Necesitas certificados reales)
#     # ssl_certificate /etc/letsencrypt/live/misitio.com/fullchain.pem;
#     # ssl_certificate_key /etc/letsencrypt/live/misitio.com/privkey.pem;
#     # include /etc/letsencrypt/options-ssl-nginx.conf;
#     # ssl_dhparam /etc/letsencrypt/ssl-dhparams.pem;
#
#     # Redirección HTTP a HTTPS (si usas SSL)
#     # if ($scheme != "https") {
#     #     return 301 https://$host$request_uri;
#     # }
#
#     client_max_body_size 4G; # Límite para subida de archivos (ajustar)
#     keepalive_timeout 5;
#
#     # --- Rutas de Archivos ---
#     # ¡IMPORTANTE! Asegúrate de que estas rutas coincidan con tus settings.py
#     # y que Nginx tenga permisos de lectura.
#     root /ruta/a/tu/proyecto/raiz; # Ruta base (a menudo no se usa directamente)
#     static_root_path = /ruta/a/tu/proyecto/staticfiles_produccion; # = STATIC_ROOT
#     media_root_path = /ruta/a/tu/proyecto/mediafiles; # = MEDIA_ROOT
#
#     # --- Servir Archivos de Medios ---
#     location /media/ { # Coincide con MEDIA_URL
#         alias $media_root_path/;
#     }
#
#     # --- Servir Archivos Estáticos ---
#     location /static/ { # Coincide con STATIC_URL
#         alias $static_root_path/;
#         expires 1y; # Cache largo para estáticos
#         access_log off;
#         add_header Cache-Control "public";
#     }
#
#     # --- Pasar Peticiones a Django/Gunicorn/uWSGI ---
#     location / {
#         proxy_set_header X-Forwarded-For $proxy_add_x_forwarded_for;
#         proxy_set_header X-Forwarded-Proto $scheme; # Importante para HTTPS
#         proxy_set_header Host $http_host;
#         proxy_redirect off;
#
#         # Intentar servir archivo estático directamente si existe (opcional, mejora rendimiento)
#         # try_files $uri $uri/ @proxy_to_app;
#
#         # Pasar la petición al upstream definido arriba (Gunicorn/uWSGI)
#         proxy_pass http://app_server;
#     }
#
#     # --- (Opcional, si usas try_files) ---
#     # location @proxy_to_app {
#     #    proxy_pass http://app_server;
#     # }
#
#     # --- Archivos de Log ---
#     access_log /var/log/nginx/misitio.com.access.log;
#     error_log /var/log/nginx/misitio.com.error.log;
#
#     # --- Otras directivas (seguridad, compresión gzip, etc.) ---
#     # gzip on;
#     # gzip_types text/plain text/css application/json ...;
# }
# ```
# **Pasos Clave en la Configuración del Proxy Inverso:**
# 1.  **Escuchar** en los puertos correctos (80/443).
# 2.  **Configurar SSL/TLS** para HTTPS (muy recomendado).
# 3.  Definir bloques `location` para `STATIC_URL` y `MEDIA_URL` que usen `alias` para apuntar a `STATIC_ROOT` y `MEDIA_ROOT` respectivamente. Esto hace que Nginx sirva estos archivos directamente.
# 4.  Definir un bloque `location /` (o un `@proxy_to_app` si usas `try_files`) que use `proxy_pass` para reenviar el resto de las peticiones al socket o puerto donde escucha tu servidor WSGI (Gunicorn/uWSGI).
# 5.  Configurar las **cabeceras `proxy_set_header`** correctamente para que Django reciba la información correcta sobre la petición original (Host, IP del cliente, protocolo).
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ## 62_Servicio_de_Archivos_Estaticos_en_Produccion_collectstatic
#
# **Resumen del Proceso:**
#
# 1.  **Desarrollo:**
#     *   Organiza tus archivos estáticos en `mi_app/static/mi_app/` y/o en directorios globales listados en `STATICFILES_DIRS`.
#     *   Usa `{% static 'ruta/relativa/archivo.css' %}` en tus plantillas.
#     *   Asegúrate de que `django.contrib.staticfiles` esté en `INSTALLED_APPS`.
#     *   El servidor de desarrollo (`runserver` con `DEBUG=True`) los sirve automáticamente.
# 2.  **Antes del Despliegue:**
#     *   Define `STATIC_ROOT` en `settings.py` (un directorio vacío fuera de tu código fuente).
# 3.  **Durante el Despliegue:**
#     *   Ejecuta `python manage.py collectstatic`. Esto copia **todos** los archivos estáticos encontrados al directorio `STATIC_ROOT`.
# 4.  **Configuración del Servidor de Producción (Nginx/Apache):**
#     *   Configura el servidor web para interceptar las peticiones a la URL definida en `STATIC_URL` (ej: `/static/`).
#     *   Haz que sirva los archivos directamente desde el directorio del sistema de archivos definido en `STATIC_ROOT` (ej: `/var/www/misitio/staticfiles/`).
#     *   Asegúrate de que Nginx/Apache tenga permisos de lectura para `STATIC_ROOT`.
#     *   Configura cabeceras de caché (`expires`, `Cache-Control`) para los archivos estáticos para mejorar el rendimiento del cliente.
#
# **Django NO debe servir archivos estáticos en producción.**
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ## 63_Configuracion_de_Base_de_Datos_para_Produccion_PostgreSQL_MySQL
#
# SQLite es genial para desarrollo, pero para producción, necesitas una base de datos más robusta diseñada para concurrencia y mayor volumen de datos. Las opciones más comunes con Django son **PostgreSQL** y **MySQL/MariaDB**.
#
# **Pasos Generales:**
#
# 1.  **Instalar y Configurar el Servidor de BD:** Instala el servidor de base de datos elegido (PostgreSQL o MySQL/MariaDB) en tu servidor de producción o utiliza un servicio de base de datos gestionado (como AWS RDS, Google Cloud SQL, Azure Database).
# 2.  **Crear Base de Datos y Usuario:** Crea una base de datos específica para tu aplicación Django y un usuario de base de datos dedicado con una contraseña segura. Otorga los permisos necesarios a ese usuario sobre esa base de datos (crear tablas, leer, escribir, etc.).
# 3.  **Instalar el Adaptador Python:** Instala la librería Python necesaria en tu entorno virtual de producción para que Django pueda comunicarse con la base de datos:
#     *   PostgreSQL: `pip install psycopg2-binary` (o `psycopg2`)
#     *   MySQL/MariaDB: `pip install mysqlclient`
#     *   (Asegúrate de incluirlos en `requirements.txt`).
# 4.  **Configurar `settings.py` (en producción):** Modifica la entrada `'default'` del diccionario `DATABASES`. **NUNCA** hardcodees las credenciales. Usa variables de entorno o un sistema de gestión de secretos.
#     ```python
#     # settings/production.py (ejemplo PostgreSQL)
#     import os
#     DATABASES = {
#         'default': {
#             'ENGINE': 'django.db.backends.postgresql',
#             'NAME': os.environ.get('DB_NAME'),
#             'USER': os.environ.get('DB_USER'),
#             'PASSWORD': os.environ.get('DB_PASSWORD'),
#             'HOST': os.environ.get('DB_HOST', 'localhost'), # Puede ser IP o 'localhost' si está en el mismo server
#             'PORT': os.environ.get('DB_PORT', '5432'),      # Puerto de PostgreSQL
#         }
#     }
#     ```
#     ```python
#     # settings/production.py (ejemplo MySQL)
#     import os
#     DATABASES = {
#         'default': {
#             'ENGINE': 'django.db.backends.mysql',
#             'NAME': os.environ.get('DB_NAME'),
#             'USER': os.environ.get('DB_USER'),
#             'PASSWORD': os.environ.get('DB_PASSWORD'),
#             'HOST': os.environ.get('DB_HOST', 'localhost'),
#             'PORT': os.environ.get('DB_PORT', '3306'), # Puerto de MySQL/MariaDB
#             'OPTIONS': {
#                 'init_command': "SET sql_mode='STRICT_TRANS_TABLES'", # Recomendado para MySQL
#             },
#         }
#     }
#     ```
# 5.  **Aplicar Migraciones:** Una vez configurado, ejecuta `python manage.py migrate` en el servidor de producción para crear todas las tablas en la nueva base de datos.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ## 64_Estrategias_y_Plataformas_Comunes_Heroku_PythonAnywhere_Docker_VPS
#
# Existen diversas formas de alojar y desplegar tu aplicación Django, cada una con sus pros y contras.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 64_1_PaaS_Ventajas_y_Desventajas
#
# **Plataformas como Servicio (Platform as a Service - PaaS):** Abstraen gran parte de la gestión de la infraestructura (servidores, sistemas operativos, bases de datos, balanceadores de carga). Te centras más en tu código.
#
# *   **Ejemplos:** Heroku, PythonAnywhere, Google App Engine, AWS Elastic Beanstalk, Render, Fly.io.
# *   **Ventajas:**
#     *   **Facilidad de Despliegue:** A menudo, tan simple como `git push`.
#     *   **Escalabilidad (Gestionada):** Muchas plataformas facilitan escalar la aplicación (añadir más instancias) a través de un panel de control o comandos simples.
#     *   **Mantenimiento Reducido:** La plataforma gestiona el SO, parches de seguridad, backups de BD (a menudo), etc.
#     *   **Integración:** Suelen ofrecer add-ons fáciles de integrar para bases de datos, caché, logging, etc.
#     *   **Planes Gratuitos/Baratos:** Buenas opciones para empezar o para proyectos pequeños.
# *   **Desventajas:**
#     *   **Menos Control:** Tienes menos control sobre la configuración del servidor subyacente, SO, o versiones específicas de software.
#     *   **Coste a Escala:** Pueden volverse más caras que soluciones IaaS (VPS) a medida que la aplicación crece significativamente.
#     *   **Vendor Lock-in (Potencial):** Depender de los servicios específicos de una plataforma puede dificultar la migración a otra.
#     *   **Limitaciones:** Los planes gratuitos o más baratos suelen tener limitaciones en recursos (CPU, memoria, almacenamiento, conexiones).
#
# **Ideal para:** Prototipos, startups, aplicaciones pequeñas/medianas, equipos que quieren enfocarse en el código y no en la infraestructura.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 64_2_Contenedores_Docker_Concepto
#
# **Docker** permite empaquetar tu aplicación y *todas* sus dependencias (incluyendo Python, librerías del sistema, el servidor WSGI, etc.) en una unidad estandarizada llamada **imagen**. Esta imagen se puede ejecutar como un **contenedor** en cualquier máquina que tenga Docker instalado, garantizando que el entorno sea **idéntico** al de desarrollo.
#
# **Flujo Básico:**
# 1.  **Dockerfile:** Creas un archivo `Dockerfile` que describe los pasos para construir la imagen (empezar desde una imagen base de Python, copiar tu código, instalar dependencias de `requirements.txt`, definir cómo ejecutar Gunicorn/uWSGI).
# 2.  **Construir Imagen:** `docker build -t mi-app-django .`
# 3.  **Ejecutar Contenedor:** `docker run -p 8000:8000 mi-app-django` (mapea el puerto 8000 del contenedor al 8000 del host).
# 4.  **Orquestación (Producción):** Para manejar múltiples contenedores, redes, volúmenes, escalado y actualizaciones en producción, se usan **orquestadores** como:
#     *   **Docker Compose:** Para definir y ejecutar aplicaciones multi-contenedor en una sola máquina (útil en desarrollo y despliegues simples).
#     *   **Kubernetes (K8s):** El estándar de facto para orquestación a gran escala en clústeres de servidores (local, cloud).
#     *   **Servicios Cloud:** AWS ECS/EKS/Fargate, Google GKE/Cloud Run, Azure AKS/Container Instances.
#
# **Ventajas:**
# *   **Consistencia de Entorno:** Elimina el "funciona en mi máquina".
# *   **Portabilidad:** La imagen corre igual en cualquier lugar con Docker.
# *   **Aislamiento:** Los contenedores están aislados entre sí.
# *   **Escalabilidad:** Fácil de escalar horizontalmente (lanzar más contenedores) con orquestadores.
# *   **Despliegues Rápidos y Fiables:** Las imágenes pre-construidas aceleran el despliegue.
#
# **Desventajas:**
# *   **Curva de Aprendizaje:** Requiere aprender conceptos de Docker y, potencialmente, de orquestación.
# *   **Overhead:** Puede haber un pequeño overhead de rendimiento comparado con correr directamente en el host (aunque generalmente mínimo).
# *   **Gestión de Datos Persistentes:** Requiere configurar volúmenes Docker para almacenar datos de base de datos o archivos de medios fuera del contenedor efímero.
#
# **Ideal para:** Entornos de producción modernos, microservicios, CI/CD, asegurar consistencia.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 64_3_VPS_Control_Total
#
# **Servidores Privados Virtuales (VPS) o Servidores Dedicados:** Alquilas una máquina virtual o física completa sobre la cual tienes control total del sistema operativo.
#
# *   **Proveedores:** DigitalOcean, Linode, Vultr, Hetzner, OVH, AWS EC2, Google Compute Engine, Azure VMs.
# *   **Ventajas:**
#     *   **Control Total:** Instalas y configuras exactamente el software y las versiones que necesitas (SO, Python, BD, Nginx, Gunicorn, etc.).
#     *   **Flexibilidad Máxima:** Puedes optimizar cada componente para tu aplicación específica.
#     *   **Coste Potencialmente Menor (a escala):** A menudo, el coste por recursos es menor que en PaaS si gestionas tú mismo la infraestructura.
# *   **Desventajas:**
#     *   **Mayor Complejidad:** Eres **responsable de todo**: instalación, configuración, seguridad (firewall, parches del SO, hardening), actualizaciones, backups, monitorización.
#     *   **Más Tiempo de Gestión:** Requiere conocimientos y tiempo dedicado a la administración de sistemas Linux/Windows.
#     *   **Escalabilidad Manual:** Escalar (aumentar recursos del servidor o añadir más servidores con balanceo de carga) requiere configuración manual.
#
# **Ideal para:** Equipos con experiencia en administración de sistemas, aplicaciones con requisitos de configuración muy específicos, cuando se necesita control total o cuando el coste de PaaS a escala se vuelve prohibitivo.
#
# La elección de la estrategia de despliegue depende de factores técnicos (conocimientos del equipo), de negocio (presupuesto, tiempo de lanzamiento) y de los requisitos de la aplicación (escala, control).
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ## 65_Consideraciones_de_Seguridad_HTTPS_Checklist_manage_py_check
#
# La seguridad en producción no es opcional. Descuidarla puede llevar a pérdida de datos, compromiso de cuentas de usuario y daño a la reputación.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 65_1_Checklist_de_Despliegue_de_Django
#
# Antes de lanzar, revisa la **checklist de despliegue** oficial de Django. Es un comando de `manage.py` que verifica muchas configuraciones comunes de seguridad y rendimiento para producción.
#
# ```bash
# # Ejecútalo en tu entorno de producción o con los settings de producción
# python manage.py check --deploy
# ```
#
# Este comando te dará **advertencias** sobre configuraciones potencialmente inseguras o no óptimas para producción, como:
# *   `DEBUG` siendo `True`.
# *   `SECRET_KEY` insegura o conocida.
# *   `ALLOWED_HOSTS` vacío o con `*`.
# *   Falta de configuración de seguridad HTTPS (`SECURE_SSL_REDIRECT`, etc.).
# *   Uso de backends de caché inseguros o ineficientes para producción.
# *   Y más...
#
# **Revisa y corrige todas las advertencias** que te dé este comando antes de lanzar tu sitio al público.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 65_2_Configuracion_HTTPS_Lets_Encrypt
#
# **HTTPS (HTTP sobre SSL/TLS)** es **esencial** en producción. Cifra la comunicación entre el navegador del usuario y tu servidor, protegiendo datos sensibles como contraseñas, información personal y cookies de sesión. Los navegadores modernos marcan los sitios HTTP como "No seguros".
#
# **Pasos Generales:**
#
# 1.  **Obtener un Certificado SSL/TLS:**
#     *   **Let's Encrypt:** Es una Autoridad de Certificación (CA) **gratuita, automatizada y abierta**. Es la opción más popular y recomendada para la mayoría. Herramientas como `Certbot` ([https://certbot.eff.org/](https://certbot.eff.org/)) automatizan la obtención e instalación de certificados Let's Encrypt en Nginx y Apache.
#     *   **Certificados Comerciales:** Comprados a CAs como DigiCert, Comodo, etc. Pueden ofrecer diferentes niveles de validación o garantías.
# 2.  **Instalar el Certificado en el Servidor Web:** Configura Nginx o Apache para usar los archivos del certificado (el certificado en sí y la clave privada). `Certbot` a menudo puede hacer esto automáticamente.
# 3.  **Configurar Redirección HTTP a HTTPS:** Configura tu servidor web para redirigir automáticamente todo el tráfico del puerto 80 (HTTP) al puerto 443 (HTTPS).
# 4.  **Configurar Django para HTTPS:** En `settings.py` (para producción), habilita las configuraciones de seguridad relacionadas con SSL:
#     ```python
#     # settings/production.py
#     # Asume que tu proxy inverso (Nginx/Apache) maneja SSL y envía la cabecera correcta
#     SECURE_PROXY_SSL_HEADER = ('HTTP_X_FORWARDED_PROTO', 'https')
#     SECURE_SSL_REDIRECT = True # Redirige HTTP a HTTPS a nivel de Django (defensa en profundidad)
#     SESSION_COOKIE_SECURE = True # Envía cookie de sesión solo sobre HTTPS
#     CSRF_COOKIE_SECURE = True # Envía cookie CSRF solo sobre HTTPS
#     # Opcional: HSTS (Strict Transport Security) - Le dice al navegador que SIEMPRE use HTTPS
#     SECURE_HSTS_SECONDS = 31536000 # 1 año - ¡Activar solo cuando estés SEGURO de que HTTPS funciona siempre!
#     SECURE_HSTS_INCLUDE_SUBDOMAINS = True
#     SECURE_HSTS_PRELOAD = True # Permite enviar tu sitio a listas de preload HSTS
#     ```
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 65_3_Cabeceras_HTTP_de_Seguridad
#
# Además de HTTPS, configurar cabeceras HTTP adicionales en tu servidor web (Nginx/Apache) añade capas importantes de protección contra ataques comunes del lado del cliente:
#
# *   **`Strict-Transport-Security` (HSTS):** (Configurada por `SECURE_HSTS_...` en Django o directamente en Nginx/Apache). Le dice al navegador que solo se comunique con tu sitio usando HTTPS durante un período especificado, previniendo ataques de *SSL stripping*.
# *   **`Content-Security-Policy` (CSP):** Define de dónde puede cargar el navegador recursos (scripts, estilos, imágenes, fuentes, etc.). Ayuda a prevenir ataques XSS al restringir la ejecución de scripts no autorizados. Su configuración puede ser compleja pero muy efectiva.
# *   **`X-Content-Type-Options: nosniff`:** Evita que el navegador intente "adivinar" el tipo MIME de un recurso si el servidor no lo especificó correctamente, previniendo ciertos ataques XSS. (Configurada por `SECURE_CONTENT_TYPE_NOSNIFF = True` en Django o en Nginx/Apache).
# *   **`X-Frame-Options: DENY` o `SAMEORIGIN`:** Previene ataques de *Clickjacking* al controlar si tu página puede ser incrustada en un `<iframe>` en otros sitios. `DENY` lo prohíbe completamente, `SAMEORIGIN` solo lo permite desde tu propio dominio. (Configurada por `X_FRAME_OPTIONS = 'DENY'` en Django o en Nginx/Apache).
# *   **`Referrer-Policy`:** Controla cuánta información de referencia (la URL de la página anterior) se envía al navegar a otros sitios. `strict-origin-when-cross-origin` o `no-referrer` son opciones comunes para mejorar la privacidad.
#
# Estas cabeceras se configuran típicamente en la configuración de tu servidor Nginx o Apache.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 65_4_Ejercicio_Practico_Preparar_Proyecto_para_Despliegue_Basico
#
# **Objetivo:** Revisar y ajustar las configuraciones clave de `settings.py` para un entorno de producción simulado.
#
# **Pasos:**
#
# 1.  **(Simulado)** Imagina que vas a desplegar. Crea un archivo `settings_production.py` (o modifica tu `settings.py` temporalmente, **¡pero no commitees secretos!**).
# 2.  **Importa** todo desde tu settings base si usas ese patrón: `from .base import *`.
# 3.  **Establece `DEBUG = False`**.
# 4.  **Establece `SECRET_KEY`:** Idealmente, léela desde una variable de entorno (`os.environ['DJANGO_SECRET_KEY']`). Si no puedes, genera una clave larga y aleatoria y ponla aquí **temporalmente** (y NUNCA la commitees). Puedes usar utilidades online o Django mismo para generar una.
# 5.  **Establece `ALLOWED_HOSTS`:** Añade los dominios donde se alojará tu aplicación (ej: `['.misitio.com', 'localhost']` el punto inicial permite subdominios). **No** uses `['*']`.
# 6.  **(Opcional)** Configura `DATABASES` para usar PostgreSQL o MySQL (si tienes una base de datos de prueba configurada). Si no, puedes dejar SQLite por ahora para este ejercicio, pero recuerda que no es ideal para producción real.
# 7.  **Verifica `STATIC_ROOT`:** Asegúrate de que apunta a una ruta válida donde `collectstatic` pueda escribir.
# 8.  **Verifica `MEDIA_ROOT`:** Asegúrate de que apunta a una ruta válida y que tendría permisos de escritura en producción.
# 9.  **Ejecuta el checklist de despliegue:**
#     ```bash
#     python manage.py check --settings=mi_sitio.settings_production --deploy
#     # O si modificaste settings.py directamente y estableciste la variable de entorno:
#     # export DJANGO_SETTINGS_MODULE='mi_sitio.settings'
#     # python manage.py check --deploy
#     ```
# 10. **Analiza las advertencias:** Revisa cualquier advertencia que `check --deploy` te dé y considera cómo la solucionarías en un despliegue real (ej: configurar HTTPS, HSTS, etc.).
#
# **Solución Propuesta:**
# La solución consiste en tener un archivo `settings_production.py` (o similar) con `DEBUG=False`, una `SECRET_KEY` segura (obtenida idealmente de forma externa) y una lista explícita en `ALLOWED_HOSTS`. La ejecución de `check --deploy` no debería mostrar advertencias críticas sobre estas tres configuraciones (aunque puede mostrar otras sobre HTTPS si no las has configurado).
#
# Este ejercicio te prepara mentalmente para los ajustes críticos necesarios antes de poner tu aplicación en línea.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ---
# ---
#
# ## **Unidad 12: Temas Avanzados y Próximos Pasos**
#
# ## 66_Middleware
#
# El middleware en Django es un sistema de "hooks" (ganchos) ligero y de bajo nivel para intervenir en el procesamiento global de peticiones y respuestas. Imagina capas por las que pasan la petición antes de llegar a la vista y la respuesta antes de llegar al cliente. Cada capa puede realizar una acción.
#
# Django incluye varios middlewares por defecto (manejo de sesiones, seguridad CSRF, autenticación) que configuras en la lista `MIDDLEWARE` de `settings.py`. El **orden** en esta lista es crucial:
# *   En la **petición** (request), los middlewares se ejecutan **de arriba abajo**.
# *   En la **respuesta** (response), los middlewares se ejecutan **de abajo arriba**.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 66_1_Ciclo_de_Vida_y_Hooks
#
# Un middleware puede ser una función o, más comúnmente, una clase. Las clases de middleware modernas (desde Django 1.10) suelen implementar el método `__init__(self, get_response)` y `__call__(self, request)`.
#
# *   **`__init__(self, get_response)`:** Se llama una sola vez cuando se inicia el servidor. `get_response` es una referencia a la siguiente capa de middleware o a la vista final. Debes guardarla (`self.get_response = get_response`).
# *   **`__call__(self, request)`:** Se llama **una vez por cada petición**.
#     *   El código **antes** de llamar a `response = self.get_response(request)` se ejecuta durante la fase de **petición** (viaje hacia la vista). Aquí puedes modificar `request`.
#     *   La línea `response = self.get_response(request)` pasa la petición a la siguiente capa (otro middleware o la vista).
#     *   El código **después** de esa línea se ejecuta durante la fase de **respuesta** (viaje hacia el cliente). Aquí puedes modificar `response`.
#     *   Debes devolver el objeto `response`.
#
# **Hooks más antiguos (aún funcionales pero menos recomendados que `__call__` para middlewares nuevos):**
# *   `process_request(self, request)`: Se ejecuta antes de decidir la vista. Puede devolver `None` (continúa) o un `HttpResponse` (corta el ciclo).
# *   `process_view(self, request, view_func, view_args, view_kwargs)`: Justo antes de llamar a la vista. Puede devolver `None` o `HttpResponse`.
# *   `process_template_response(self, request, response)`: Si la respuesta es un `TemplateResponse`. Permite modificarla antes del renderizado final. Debe devolver un objeto response.
# *   `process_exception(self, request, exception)`: Si una vista lanza una excepción. Puede devolver `None` o `HttpResponse` (para manejar el error).
# *   `process_response(self, request, response)`: Se ejecuta para todas las respuestas antes de enviarlas al navegador. Debe devolver un objeto `response`.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 66_2_Casos_de_Uso_y_Ejemplo
#
# **Casos de Uso Comunes:**
# *   Añadir cabeceras de seguridad a todas las respuestas.
# *   Realizar logging de todas las peticiones.
# *   Gestionar mantenimiento del sitio (mostrar página "en mantenimiento").
# *   Procesar datos de subdominios.
# *   Comprobaciones de permisos globales.
# *   Modificar el objeto `request` o `response` de forma global.
#
# **Ejemplo: Middleware simple para medir tiempo de procesamiento**
# ```python
# # mi_app/middleware.py (nuevo archivo)
# import time
# from django.utils.deprecation import MiddlewareMixin # Para compatibilidad si usas hooks antiguos
#
# class TimingMiddleware:
#     def __init__(self, get_response):
#         self.get_response = get_response
#         # Configuración única al inicio
#
#     def __call__(self, request):
#         # Código a ejecutar antes de la vista (request)
#         start_time = time.time()
#
#         response = self.get_response(request) # Llama a la siguiente capa/vista
#
#         # Código a ejecutar después de la vista (response)
#         end_time = time.time()
#         duration = end_time - start_time
#         # Añadir cabecera personalizada a la respuesta
#         response['X-Processing-Time-Ms'] = str(int(duration * 1000))
#         print(f"Processing time for {request.path}: {duration:.4f}s")
#
#         return response
#
# # Registro en settings.py (añadir la ruta a la clase en la lista MIDDLEWARE)
# # MIDDLEWARE = [
# #     # ... otros middlewares ...
# #     'mi_app.middleware.TimingMiddleware', # Añadir al final o donde corresponda
# #     # ...
# # ]
# ```
# *Recuerda reiniciar el servidor después de añadir o modificar middlewares y registrarlos.*
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ## 67_Signals_Senales_Desacoplamiento
#
# Las señales permiten que ciertas partes de tu aplicación (remitentes - *senders*) envíen notificaciones cuando ocurren eventos específicos, y que otras partes (receptores - *receivers*) escuchen y reaccionen a esas notificaciones sin que remitente y receptor necesiten conocerse directamente. Es un patrón de diseño que promueve el **desacoplamiento**.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 67_1_Senales_Incorporadas_y_Personalizadas
#
# Django proporciona un conjunto de señales incorporadas para eventos comunes:
#
# *   **Señales de Modelos (`django.db.models.signals`):**
#     *   `pre_init`, `post_init`: Antes/después de que `__init__` del modelo se ejecute.
#     *   `pre_save`, `post_save`: Antes/después de que el método `save()` del modelo se llame. `post_save` recibe `created=True/False`.
#     *   `pre_delete`, `post_delete`: Antes/después de que el método `delete()` se llame.
#     *   `m2m_changed`: Cuando un `ManyToManyField` cambia (se añaden/eliminan relaciones).
# *   **Señales de Petición/Respuesta (`django.core.signals`):**
#     *   `request_started`, `request_finished`: Al inicio/final de una petición HTTP.
#     *   `got_request_exception`: Cuando ocurre una excepción durante el procesamiento de la petición.
# *   **Señales de Autenticación (`django.contrib.auth.signals`):**
#     *   `user_logged_in`, `user_logged_out`, `user_login_failed`.
# *   **Señales del Framework de Pruebas (`django.test.signals`):**
#     *   `setting_changed`, `template_rendered`.
#
# **Señales Personalizadas:**
# Puedes definir tus propias señales si necesitas un sistema de notificación específico para tu aplicación.
# ```python
# # mi_app/signals.py
# import django.dispatch
#
# # Definir una señal personalizada
# producto_fuera_de_stock = django.dispatch.Signal()
# # Podrías pasar argumentos específicos:
# # producto_fuera_de_stock = django.dispatch.Signal(providing_args=["producto", "tienda"])
#
# # --- En algún lugar de tu código (ej: models.py save()) ---
# # from .signals import producto_fuera_de_stock
# #
# # class Producto(models.Model):
# #     # ...
# #     def save(self, *args, **kwargs):
# #         stock_anterior = Producto.objects.get(pk=self.pk).stock if self.pk else self.stock
# #         super().save(*args, **kwargs) # Guarda primero
# #         if stock_anterior > 0 and self.stock == 0:
# #             # Enviar la señal si el stock llega a cero
# #             producto_fuera_de_stock.send(sender=self.__class__, producto=self)
# ```
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 67_2_Definicion_y_Conexion_de_Receptores
#
# Un receptor es una función Python que se ejecutará cuando se envíe una señal a la que está conectado.
#
# *   **Firma del Receptor:** La función debe aceptar `sender` y `**kwargs` como argumentos. Puede aceptar argumentos específicos enviados por la señal (como `instance` y `created` para `post_save`).
# *   **Conexión:** Hay dos formas de conectar un receptor a una señal:
#     1.  **Decorador `@receiver` (Recomendado):** Importa `receiver` de `django.dispatch` y decora tu función receptora.
#     2.  **Método `Signal.connect()`:** Llama explícitamente a `mi_senal.connect(mi_receptor_func, sender=ModeloEspecifico)`.
#
# **Importante:** El código que conecta las señales (ya sea el decorador o la llamada a `connect()`) debe ejecutarse cuando Django carga las aplicaciones. La forma recomendada es:
# 1.  Crear un archivo `signals.py` (o `handlers.py`) en tu app.
# 2.  Definir tus receptores y conectarlos ahí.
# 3.  **Importar** ese módulo de señales dentro del método `ready()` de la clase `AppConfig` de tu aplicación en `apps.py`.
#
# **Ejemplo (`blog/signals.py`):**
# ```python
# # blog/signals.py
# from django.db.models.signals import post_save
# from django.contrib.auth.models import User
# from django.dispatch import receiver
# from .models import Post # Asume modelo Post
# # from mi_otra_app.models import Notificacion # Para crear notificaciones
#
# @receiver(post_save, sender=Post) # Conectar a post_save para el modelo Post
# def notificar_nuevo_post(sender, instance, created, **kwargs):
#     """
#     Envía una notificación (simulada) cuando se crea un nuevo Post.
#     """
#     if created: # Solo si es un post nuevo
#         print(f"*** SEÑAL RECIBIDA: Nuevo post creado! ***")
#         print(f"  Título: {instance.titulo}")
#         print(f"  Autor: {instance.autor.username}")
#         # Aquí podrías:
#         # - Enviar un email a suscriptores
#         # - Crear un objeto Notificacion en la BD
#         # - Llamar a una tarea Celery para procesar algo
#         # Notificacion.objects.create(mensaje=f"Nuevo post: {instance.titulo}")
#
# @receiver(post_save, sender=User)
# def log_guardado_usuario(sender, instance, created, **kwargs):
#     if created:
#         print(f"Señal: Nuevo usuario registrado: {instance.username}")
#     else:
#         print(f"Señal: Usuario actualizado: {instance.username}")
#
# # Si definiste una señal personalizada:
# # from .signals import producto_fuera_de_stock
# #
# # @receiver(producto_fuera_de_stock)
# # def manejar_stock_cero(sender, producto, **kwargs):
# #     print(f"¡ALERTA! Producto {producto.nombre} (ID: {producto.id}) sin stock.")
# #     # Enviar email al admin, etc.
# ```
#
# **Registro en `blog/apps.py`:**
# ```python
# # blog/apps.py
# from django.apps import AppConfig
#
# class BlogConfig(AppConfig):
#     default_auto_field = 'django.db.models.BigAutoField'
#     name = 'blog'
#
#     def ready(self):
#         # Importar las señales para que los receptores se conecten
#         import blog.signals
# ```
# Las señales son una herramienta poderosa para lógica desacoplada y basada en eventos, pero como los middlewares, un uso excesivo puede dificultar el seguimiento del flujo de ejecución.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ## 68_Caching_Framework_Django
#
# El caching consiste en almacenar los resultados de operaciones costosas (consultas a BD, renderizado de fragmentos complejos, resultados de APIs externas) para poder reutilizarlos rápidamente en peticiones futuras, reduciendo la carga en la base de datos y acelerando los tiempos de respuesta.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 68_1_Configuracion_Backends_Memcached_Redis_DB_File_LocMem
#
# Django ofrece un sistema de caché flexible que soporta diferentes *backends* (lugares donde se almacena la caché). La configuración se realiza en `settings.py` en el diccionario `CACHES`.
#
# ```python
# # settings.py
# CACHES = {
#     # Configuración por defecto (puedes tener varias con nombres diferentes)
#     'default': {
#         # ---- OPCIONES COMUNES ----
#
#         # 1. EN MEMORIA POR PROCESO (Simple, Rápido, NO COMPARTIDO entre workers)
#         # 'BACKEND': 'django.core.cache.backends.locmem.LocMemCache',
#         # 'LOCATION': 'mi-cache-unica', # Un nombre para identificarla
#
#         # 2. SISTEMA DE ARCHIVOS (Simple, Persistente, Más lento que en memoria)
#         # 'BACKEND': 'django.core.cache.backends.filebased.FileBasedCache',
#         # 'LOCATION': '/var/tmp/django_cache', # Ruta donde guardar archivos (asegurar permisos)
#
#         # 3. BASE DE DATOS (Simple de configurar, Persistente, El más lento)
#         # 'BACKEND': 'django.core.cache.backends.db.DatabaseCache',
#         # 'LOCATION': 'mi_tabla_de_cache', # Nombre de la tabla a crear (ejecutar manage.py createcachetable)
#
#         # 4. MEMCACHED (Muy Rápido, En memoria, Distribuido, Volátil)
#         # Requiere servidor Memcached corriendo y librería Python.
#         # 'BACKEND': 'django.core.cache.backends.memcached.PyMemcacheCache', # Recomendado: pip install pymemcache
#         # 'LOCATION': '127.0.0.1:11211', # Host y puerto
#         # O para múltiples servidores:
#         # 'LOCATION': [
#         #     '172.19.26.240:11211',
#         #     '172.19.26.242:11211',
#         # ]
#         # O socket Unix:
#         # 'LOCATION': 'unix:/tmp/memcached.sock'
#
#         # 5. REDIS (Muy Rápido, En memoria, Persistencia opcional, Versátil)
#         # Requiere servidor Redis corriendo y librería Python (ej: django-redis).
#         'BACKEND': 'django_redis.cache.RedisCache', # Necesita: pip install django-redis
#         'LOCATION': 'redis://127.0.0.1:6379/1', # URL Conexión: redis://[password@]host:port/db_number
#         'OPTIONS': {
#             'CLIENT_CLASS': 'django_redis.client.DefaultClient',
#             # Otras opciones de conexión/serialización/compresión
#         }
#     },
#     # --- Puedes definir CACHES adicionales ---
#     # 'sesiones_redis': {
#     #     'BACKEND': 'django_redis.cache.RedisCache',
#     #     'LOCATION': 'redis://127.0.0.1:6379/2', # DB diferente para sesiones
#     #     'OPTIONS': { ... }
#     # }
# }
#
# # Opcional: Configurar caché para sesiones (más rápido que la BD)
# # SESSION_ENGINE = "django.contrib.sessions.backends.cache"
# # SESSION_CACHE_ALIAS = "default" # O el alias de la caché que quieras usar
# ```
# La elección del backend depende de tus necesidades:
# *   `locmem`: Solo para desarrollo o sitios muy simples.
# *   `db`: Fácil pero lento.
# *   `filebased`: Fácil pero más lento que en memoria, útil si la persistencia es clave y no quieres un servidor extra.
# *   `memcached`: Opción clásica de alto rendimiento para caché volátil distribuida.
# *   `redis`: Muy popular, rápido, versátil (puede usarse para más cosas como colas Celery, sessions), con persistencia opcional.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 68_2_API_de_Bajo_Nivel_get_set_delete
#
# La API de bajo nivel te da control granular sobre qué cachear y cómo. Se accede a través de `django.core.cache.cache` (que usa la entrada `'default'` de `CACHES`) o `caches['nombre_alias']`.
#
# Métodos Principales:
# *   `cache.set(key, value, timeout=None)`: Guarda `value` en caché con la clave `key`. `timeout` es la duración en segundos (usa el default de `CACHES` si es `None`). Sobrescribe si la clave existe.
# *   `cache.get(key, default=None)`: Obtiene el valor asociado a `key`. Devuelve `default` (que es `None` por defecto) si la clave no existe o ha expirado.
# *   `cache.add(key, value, timeout=None)`: Guarda `value` solo si la clave `key` **no** existe ya. Útil para evitar race conditions. Devuelve `True` si se añadió, `False` si ya existía.
# *   `cache.get_or_set(key, default_callable_or_value, timeout=None)`: Intenta obtener `key`. Si no existe, llama a `default_callable_or_value` (si es una función) o usa el valor directamente, lo guarda en caché con `timeout` y lo devuelve. Conveniente para el patrón "get-if-not-exists-then-compute-and-set".
# *   `cache.delete(key)`: Elimina una clave de la caché.
# *   `cache.delete_many([key1, key2, ...])`: Elimina múltiples claves.
# *   `cache.clear()`: **¡Vacía toda la caché!** Usar con precaución.
# *   `cache.incr(key, delta=1)`, `cache.decr(key, delta=1)`: Incrementa/decrementa atómicamente un valor entero en caché (si el backend lo soporta).
#
# **Ejemplo:**
# ```python
# # views.py
# from django.core.cache import cache
# from django.shortcuts import render
# # from .utils import funcion_muy_costosa
#
# def vista_con_cache_manual(request):
#     user_id = request.user.id if request.user.is_authenticated else 'anonimo'
#     cache_key = f'datos_panel_usuario_{user_id}'
#     tiempo_cache_segundos = 60 * 10 # 10 minutos
#
#     # Intenta obtener los datos de la caché
#     datos_panel = cache.get(cache_key)
#
#     if datos_panel is None:
#         # No está en caché, calcula/obtén los datos
#         print(f"Calculando datos para el panel (key: {cache_key})")
#         # datos_panel = funcion_muy_costosa(user_id)
#         datos_panel = {'nombre': f'Usuario {user_id}', 'items_recientes': [1,2,3]} # Ejemplo
#         # Guarda en caché
#         cache.set(cache_key, datos_panel, tiempo_cache_segundos)
#         origen = "Calculado"
#     else:
#         print(f"Obteniendo datos del panel desde caché (key: {cache_key})")
#         origen = "Caché"
#
#     contexto = {
#         'datos': datos_panel,
#         'origen_datos': origen
#     }
#     return render(request, 'mi_app/panel.html', contexto)
#
# # Ejemplo con get_or_set
# def obtener_stats_globales():
#     cache_key = 'estadisticas_globales'
#     def _calcular_stats():
#         print("Calculando estadísticas globales...")
#         # ... consulta costosa ...
#         return {'usuarios': 1000, 'posts': 5000}
#
#     # Intenta obtener, si no, llama a _calcular_stats y guarda por 1 hora
#     stats = cache.get_or_set(cache_key, _calcular_stats, timeout=3600)
#     return stats
# ```
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 68_3_Cache_de_Vistas_cache_page
#
# Para cachear la **salida completa** de una vista (la respuesta `HttpResponse`), Django proporciona el decorador `@cache_page`. Es útil para vistas cuyo contenido no cambia muy frecuentemente para todos los usuarios.
#
# **Sintaxis:** `@cache_page(timeout, cache='default', key_prefix='')`
#
# *   `timeout`: Duración en segundos que la respuesta permanecerá en caché.
# *   `cache` (Opcional): El alias de la caché a usar (de `settings.CACHES`).
# *   `key_prefix` (Opcional): Prefijo para la clave de caché generada.
#
# Django genera una clave de caché basada en la URL de la petición y las cabeceras `Vary` (ver abajo).
#
# ```python
# # views.py
# from django.views.decorators.cache import cache_page
# from django.shortcuts import render
# import time
#
# @cache_page(60 * 15) # Cachear esta vista por 15 minutos
# def vista_muy_popular(request):
#     # Simular algún cálculo o consulta
#     ahora = time.time()
#     print("Ejecutando vista_muy_popular...")
#     # ... obtener datos ...
#     contexto = {'tiempo': ahora}
#     return render(request, 'mi_app/popular.html', contexto)
# ```
# La primera vez que se accede a `/url/de/vista_popular/`, la vista se ejecuta y su respuesta se guarda en caché. Las siguientes peticiones a la misma URL dentro de los 15 minutos recibirán la respuesta cacheada directamente, sin ejecutar el código de la vista.
#
# **Importante - Cabecera `Vary`:** El caching de vistas a menudo depende de las cabeceras HTTP para determinar si diferentes peticiones deben tener respuestas cacheadas separadas. Por ejemplo, si el contenido depende del idioma del usuario (`Accept-Language`) o de si está comprimido (`Accept-Encoding`), o de una cookie, necesitas indicarlo. Django añade automáticamente `Vary: Cookie, Accept-Language` si usas sesiones, i18n. Puedes añadir más con el decorador `@vary_on_headers('User-Agent', ...)` o `@vary_on_cookie`.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 68_4_Cache_de_Plantillas_cache_tag
#
# Permite cachear **fragmentos** específicos dentro de una plantilla, lo cual es útil si solo una parte de la página es costosa de renderizar y el resto cambia con más frecuencia.
#
# **Sintaxis:**
# `{% load cache %}`
# `{% cache <timeout_segundos> <nombre_fragmento> [identificador1] [identificador2] ... %}`
#    ... Contenido HTML a cachear ...
# `{% endcache %}`
#
# *   `timeout_segundos`: Duración de la caché para este fragmento.
# *   `nombre_fragmento`: Un nombre único para identificar este fragmento cacheado.
# *   `identificador1, identificador2, ...` (Opcionales): Variables cuyo valor se usará para crear una clave de caché única. Si el contenido cacheado depende de estas variables (ej: ID de usuario, slug de categoría), **debes** incluirlas para que se generen versiones cacheadas diferentes para cada combinación de valores.
#
# **Ejemplo (Cachear una sidebar con categorías):**
# ```html
# {% load cache %}
#
# <div class="sidebar">
#     <h2>Navegación</h2>
#     {# ... menú principal ... #}
#
#     <hr>
#     <h3>Categorías</h3>
#     {# Cachear esta sección por 1 hora (3600s) #}
#     {# El nombre 'sidebar_categorias' identifica este bloque #}
#     {% cache 3600 sidebar_categorias %}
#         <ul>
#             {# Asumiendo que 'todas_las_categorias' viene de un context processor
#                o se añade en get_context_data de una CBV #}
#             {% for cat in todas_las_categorias %}
#                 <li><a href="#">{{ cat.nombre }}</a></li>
#             {% empty %}
#                 <li>(Sin categorías)</li>
#             {% endfor %}
#         </ul>
#         <p><small>Categorías cacheadas a las {% now "H:i:s" %}</small></p> {# Hora de cacheo #}
#     {% endcache %}
#
#     <hr>
#     {# Otro contenido de la sidebar que no se cachea o se cachea diferente #}
# </div>
# ```
# La primera vez que se renderice, el bloque `{% cache %}` se ejecutará, se generará el HTML de la lista de categorías y se guardará en caché con una clave basada en `'sidebar_categorias'`. Las siguientes veces (dentro de 1 hora), se servirá directamente el HTML cacheado. Si añades identificadores (ej: `{% cache 3600 sidebar_categorias request.user.id %}`), se creará una versión cacheada diferente para cada ID de usuario.
#
# Elegir la estrategia de caching adecuada (bajo nivel, vista completa, fragmento de plantilla) depende de la naturaleza de los datos y la frecuencia con la que cambian.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ## 69_Creacion_de_APIs_REST_con_Django_REST_Framework_DRF_Introduccion
#
# Mientras que Django es excelente para renderizar HTML (aplicaciones web tradicionales), a menudo necesitas exponer los datos y la lógica de tu aplicación para que sean consumidos por otros clientes: aplicaciones móviles nativas, frontends JavaScript modernos (React, Vue, Angular), otros servicios backend, etc. Para esto se construyen **APIs (Application Programming Interfaces)**, y el estilo arquitectónico predominante para APIs web es **REST (Representational State Transfer)**.
#
# **Django REST Framework (DRF)** es una librería de terceros extremadamente popular y potente, diseñada específicamente para construir APIs web RESTful sobre Django. Simplifica enormemente tareas como la serialización de datos, autenticación de API, permisos, enrutamiento, etc.
#
# **Instalación:**
# ```bash
# pip install djangorestframework markdown django-filter # Opcionales pero recomendados
# # Añade 'rest_framework' a INSTALLED_APPS en settings.py
# ```
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 69_1_Serializers_ModelSerializer
#
# Los **Serializers** son el corazón de DRF. Se encargan de dos tareas principales:
# 1.  **Serialización:** Convertir objetos Python complejos (como instancias de modelos Django o QuerySets) en representaciones de datos simples y nativas que puedan ser fácilmente renderizadas en formatos como JSON o XML.
# 2.  **Deserialización y Validación:** Convertir datos recibidos (ej: JSON en una petición POST o PUT) de vuelta a objetos Python complejos (o diccionarios), después de validar que los datos recibidos sean correctos según las reglas definidas.
#
# **`ModelSerializer`:** Es una clase de conveniencia (similar a `ModelForm`) que genera automáticamente campos de serializador y validadores basados en un modelo Django.
#
# **Ejemplo (`productos/serializers.py` - nuevo archivo):**
# ```python
# # productos/serializers.py
# from rest_framework import serializers
# from .models import Producto, Categoria
# from django.contrib.auth.models import User # O tu modelo de usuario
#
# class CategoriaSerializer(serializers.ModelSerializer):
#     class Meta:
#         model = Categoria
#         fields = ['id', 'nombre', 'slug'] # Campos del modelo a incluir
#
# class AutorSerializer(serializers.ModelSerializer):
#     """Serializador simple para mostrar info básica del autor."""
#     class Meta:
#         model = User # O tu modelo de usuario personalizado
#         fields = ['id', 'username', 'first_name', 'last_name']
#
# class ProductoSerializer(serializers.ModelSerializer):
#     # --- Personalizaciones ---
#     # Campo ReadOnly para mostrar el username del autor (no editable vía API)
#     autor_info = AutorSerializer(source='creado_por', read_only=True)
#     # Usar el serializador de Categoría para mostrar detalles, no solo el ID
#     categoria = CategoriaSerializer(read_only=True)
#     # Campo personalizado calculado por un método
#     es_caro = serializers.SerializerMethodField()
#     # Campo para la URL (si tienes get_absolute_url)
#     url_detalle = serializers.HyperlinkedIdentityField(view_name='productos_api:producto-detail') # Asume URL name
#
#     class Meta:
#         model = Producto
#         # Campos a incluir en la representación JSON/API
#         fields = [
#             'id', 'url_detalle', 'nombre', 'slug', 'descripcion', 'precio',
#             'stock', 'disponible', 'fecha_creacion', 'categoria',
#             'autor_info', 'es_caro', #'imagen' # Podrías incluir imagen.url
#         ]
#         # Campos que no se pueden establecer al crear/actualizar vía API
#         read_only_fields = ['fecha_creacion', 'autor_info']
#
#     # Método para el SerializerMethodField
#     def get_es_caro(self, obj):
#         # obj es la instancia de Producto
#         return obj.precio > 100 # Devuelve True si es caro
#
#     # --- Validación (Ejemplo) ---
#     def validate_nombre(self, value):
#         """Validación específica para el campo nombre."""
#         if len(value) < 5:
#             raise serializers.ValidationError("El nombre debe tener al menos 5 caracteres.")
#         return value
#
#     def validate(self, data):
#         """Validación que involucra múltiples campos."""
#         if data.get('stock', 0) == 0 and data.get('disponible', False):
#             raise serializers.ValidationError("Un producto sin stock no puede estar disponible.")
#         return data
#
# ```
# *   Se definen clases que heredan de `serializers.Serializer` o `serializers.ModelSerializer`.
# *   `ModelSerializer` requiere una clase `Meta` con `model` y `fields` (o `exclude`).
# *   Se pueden anidar serializadores (`CategoriaSerializer` dentro de `ProductoSerializer`).
# *   Se pueden añadir campos calculados (`SerializerMethodField`).
# *   Se pueden añadir validaciones (`validate_<campo>`, `validate`).
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 69_2_Vistas_API_Genericas
#
# DRF proporciona vistas genéricas basadas en clase, análogas a las de Django, pero diseñadas para APIs REST. Operan sobre modelos y serializadores.
#
# Vistas Comunes (`rest_framework.generics`):
# *   `ListAPIView`: Para listar un queryset (GET).
# *   `RetrieveAPIView`: Para obtener una única instancia (GET).
# *   `CreateAPIView`: Para crear nuevas instancias (POST).
# *   `UpdateAPIView`: Para actualizar instancias existentes (PUT/PATCH).
# *   `DestroyAPIView`: Para eliminar instancias (DELETE).
# *   **Combinadas:**
#     *   `ListCreateAPIView`: Maneja GET (lista) y POST (crear).
#     *   `RetrieveUpdateAPIView`: Maneja GET (detalle), PUT, PATCH.
#     *   `RetrieveDestroyAPIView`: Maneja GET (detalle), DELETE.
#     *   `RetrieveUpdateDestroyAPIView`: Maneja GET (detalle), PUT, PATCH, DELETE.
#
# **Atributos Clave:**
# *   `queryset`: El QuerySet base para la vista.
# *   `serializer_class`: La clase Serializer a usar para representar/validar datos.
# *   `permission_classes`: Lista de clases de permiso para controlar el acceso.
# *   `authentication_classes`: Lista de clases para autenticar al cliente API.
# *   `lookup_field`: El campo a usar para buscar instancias individuales (defecto `'pk'`). Se puede usar `'slug'`, etc.
# *   `pagination_class`: Para habilitar paginación.
# *   `filter_backends`: Para habilitar filtrado y búsqueda (ej: `django_filters.rest_framework.DjangoFilterBackend`, `rest_framework.filters.SearchFilter`).
#
# **Ejemplo (`productos/views_api.py` - nuevo archivo):**
# ```python
# # productos/views_api.py
# from rest_framework import generics, permissions
# from .models import Producto, Categoria
# from .serializers import ProductoSerializer, CategoriaSerializer
# # from .permissions import EsAutorOReadOnly # Ejemplo permiso personalizado
#
# class ProductoListCreateAPIView(generics.ListCreateAPIView):
#     queryset = Producto.objects.filter(disponible=True) # Solo listar disponibles
#     serializer_class = ProductoSerializer
#     permission_classes = [permissions.IsAuthenticatedOrReadOnly] # Cualquiera puede leer, solo logueados pueden crear
#
#     def perform_create(self, serializer):
#         # Asignar creador automáticamente (si el modelo tuviera 'creado_por')
#         # serializer.save(creado_por=self.request.user)
#         serializer.save() # Guardar el nuevo producto
#
# class ProductoDetailAPIView(generics.RetrieveUpdateDestroyAPIView):
#     queryset = Producto.objects.all()
#     serializer_class = ProductoSerializer
#     # permission_classes = [EsAutorOReadOnly] # Ejemplo: solo el autor puede modificar/borrar
#     permission_classes = [permissions.IsAuthenticatedOrReadOnly] # Simplificado por ahora
#     lookup_field = 'slug' # Buscar por slug en lugar de pk
#
# class CategoriaListAPIView(generics.ListAPIView):
#     queryset = Categoria.objects.all()
#     serializer_class = CategoriaSerializer
#     permission_classes = [permissions.AllowAny] # Cualquiera puede ver categorías
#
# class CategoriaDetailAPIView(generics.RetrieveAPIView): # Solo lectura para detalle
#     queryset = Categoria.objects.all()
#     serializer_class = CategoriaSerializer
#     permission_classes = [permissions.AllowAny]
#     lookup_field = 'slug'
# ```
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 69_3_ViewSets_y_Routers
#
# Los **ViewSets** (`rest_framework.viewsets`) combinan la lógica para múltiples vistas relacionadas con un mismo recurso (lista, detalle, creación, etc.) en una **única clase**. No definen métodos `get`, `post` directamente, sino métodos como `list()`, `retrieve()`, `create()`, `update()`, `partial_update()`, `destroy()`.
#
# Los **Routers** (`rest_framework.routers`) generan automáticamente los patrones de URL para un ViewSet, mapeando los métodos HTTP a las acciones correspondientes del ViewSet.
#
# *   **`ModelViewSet`:** Proporciona la implementación completa de las acciones CRUD (list, retrieve, create, update, partial_update, destroy) para un modelo.
#
# **Ejemplo (Rehaciendo Productos con ViewSet y Router):**
#
# **`productos/views_api.py`:**
# ```python
# # productos/views_api.py
# from rest_framework import viewsets, permissions
# from .models import Producto
# from .serializers import ProductoSerializer
# # from .permissions import EsAutorOReadOnly
#
# class ProductoViewSet(viewsets.ModelViewSet):
#     """
#     Este ViewSet proporciona automáticamente acciones `list`, `create`,
#     `retrieve`, `update`, `partial_update`, y `destroy`.
#     """
#     queryset = Producto.objects.all().order_by('-fecha_creacion')
#     serializer_class = ProductoSerializer
#     permission_classes = [permissions.IsAuthenticatedOrReadOnly] # Ejemplo
#     # permission_classes = [IsAutorOrReadOnly] # Si tuvieras permiso personalizado
#     lookup_field = 'slug' # Usar slug para retrieve/update/destroy
#
#     def perform_create(self, serializer):
#         # Asignar creador automáticamente si el modelo lo tiene
#         # serializer.save(creado_por=self.request.user)
#         serializer.save()
# ```
#
# **`productos/urls_api.py` (o un `api_router.py` global):**
# ```python
# # productos/urls_api.py
# from django.urls import path, include
# from rest_framework.routers import DefaultRouter
# from . import views_api # Importa la vista del ViewSet
#
# # Crear un router
# router = DefaultRouter()
# # Registrar el ViewSet. 'productos' es el prefijo de URL, 'producto' es el basename para nombres de URL
# router.register(r'productos', views_api.ProductoViewSet, basename='producto')
# # router.register(r'categorias', views_api.CategoriaViewSet, basename='categoria') # Si tuvieras CategoriaViewSet
#
# app_name = 'productos_api'
#
# # Los urlpatterns ahora incluyen las URLs generadas por el router
# urlpatterns = [
#     path('', include(router.urls)),
#     # Puedes añadir otras URLs API no gestionadas por el router aquí si es necesario
# ]
#
# # router.urls generará URLs como:
# # /productos/ -> GET (list), POST (create) -> name='producto-list'
# # /productos/{lookup_field}/ -> GET (retrieve), PUT (update), PATCH (partial_update), DELETE (destroy) -> name='producto-detail'
# # (Donde lookup_field es 'slug' en este caso)
# ```
#
# **Incluir en `mi_sitio/urls.py`:**
# ```python
# # mi_sitio/urls.py
# urlpatterns = [
#     # ...
#     path('api/', include('productos.urls_api')), # Prefijo para todas las URLs de la API
# ]
# ```
# ViewSets y Routers reducen drásticamente el código necesario para APIs CRUD estándar.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 69_4_Autenticacion_y_Permisos_en_DRF
#
# DRF tiene su propio sistema de autenticación y permisos, separado pero integrable con el de Django, diseñado específicamente para APIs.
#
# *   **Autenticación (`authentication_classes`):** Determina *quién* es el usuario que realiza la petición API. Métodos comunes:
#     *   `SessionAuthentication`: Usa las sesiones estándar de Django (útil si tu frontend y backend están en el mismo dominio).
#     *   `TokenAuthentication`: Autenticación simple basada en un token único por usuario (requiere añadir `'rest_framework.authtoken'` a `INSTALLED_APPS` y ejecutar `migrate`). El cliente envía el token en la cabecera `Authorization: Token <tu_token>`.
#     *   `BasicAuthentication`: Autenticación HTTP básica (usuario/contraseña, generalmente solo para pruebas).
#     *   Paquetes externos para OAuth2, JWT (JSON Web Tokens), etc.
# *   **Permisos (`permission_classes`):** Determina *si* el usuario autenticado tiene permiso para realizar la acción solicitada en el recurso.
#     *   `AllowAny`: Permite acceso a cualquiera (incluso anónimos).
#     *   `IsAuthenticated`: Solo usuarios autenticados.
#     *   `IsAdminUser`: Solo usuarios con `is_staff=True`.
#     *   `IsAuthenticatedOrReadOnly`: Usuarios autenticados pueden realizar cualquier acción (POST, PUT, DELETE), usuarios anónimos solo pueden leer (GET, HEAD, OPTIONS). Muy común para APIs públicas con creación/edición restringida.
#     *   `DjangoModelPermissions`: Usa los permisos estándar de modelo de Django (`app.add_model`, `app.change_model`, etc.).
#     *   `DjangoModelPermissionsOrAnonReadOnly`: Igual que el anterior, pero permite lectura a anónimos.
#     *   **Permisos Personalizados:** Puedes crear tus propias clases de permiso heredando de `permissions.BasePermission` e implementando `has_permission(self, request, view)` (a nivel de vista) y/o `has_object_permission(self, request, view, obj)` (a nivel de objeto específico).
#
# La configuración se puede establecer globalmente en `settings.REST_FRAMEWORK` o específicamente en cada vista/viewset.
#
# DRF es fundamental para exponer tu lógica Django a otros clientes de forma estandarizada y segura.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ## 70_Tareas_Asincronas_con_Celery_Introduccion
#
# Para operaciones que toman tiempo y no deberían bloquear la respuesta HTTP al usuario (enviar emails, procesar imágenes, generar reportes, interactuar con APIs externas lentas), se utilizan sistemas de **colas de tareas asíncronas**. **Celery** es la solución más popular y robusta en el ecosistema Python/Django.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 70_1_Necesidad_y_Arquitectura_Broker_Worker
#
# **Necesidad:** Evitar que una petición web espere a que una tarea larga termine. La vista debe responder rápidamente al usuario ("Hemos recibido tu pedido, te notificaremos") y la tarea larga se ejecuta en segundo plano.
#
# **Arquitectura Básica de Celery:**
# 1.  **Aplicación Django (Productor):** Cuando necesita ejecutar una tarea larga, en lugar de ejecutarla directamente, **envía un mensaje** describiendo la tarea y sus argumentos a una cola de mensajes (Broker).
# 2.  **Broker de Mensajes:** Un sistema intermediario que almacena los mensajes de tareas pendientes. Actúa como un buffer. Opciones comunes:
#     *   **Redis:** Almacén de datos en memoria, muy rápido y popular como broker Celery. Relativamente fácil de configurar.
#     *   **RabbitMQ:** Un broker de mensajes AMQP dedicado, muy robusto y con más funcionalidades, pero puede ser más complejo de configurar y gestionar.
# 3.  **Workers Celery (Consumidores):** Son **procesos Python separados** (que ejecutas independientemente de tu servidor web Django) que están constantemente conectados al Broker, esperando nuevos mensajes de tareas.
# 4.  **Ejecución:** Cuando un worker toma un mensaje de la cola, ejecuta la función Python (la "tarea") asociada a ese mensaje con los argumentos proporcionados.
# 5.  **Backend de Resultados (Opcional):** Celery puede configurarse para almacenar el estado (pendiente, en progreso, éxito, fallo) y el resultado (o el error) de cada tarea en un backend (puede ser Redis, la base de datos Django, etc.). Esto permite consultar el estado de las tareas desde tu aplicación Django.
#
# ![Arquitectura Celery Simplificada](https://docs.celeryq.dev/en/stable/_images/celery_vector_transparent.png) *(Diagrama conceptual)*
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 70_2_Configuracion_Basica_con_Redis_o_RabbitMQ
#
# Configurar Celery con Django implica varios pasos:
#
# 1.  **Instalar Dependencias:**
#     ```bash
#     pip install celery redis # Para usar Redis como broker y backend (recomendado empezar)
#     # o pip install celery "celery[librabbitmq]" # Para RabbitMQ
#     ```
#     (Añadir a `requirements.txt`).
# 2.  **Instalar y Ejecutar el Broker:** Necesitas tener Redis o RabbitMQ instalado y ejecutándose en tu sistema o accesible en la red.
#     *   Redis: `sudo apt install redis-server` o `brew install redis`, luego `sudo systemctl start redis-server`.
#     *   RabbitMQ: Requiere instalación y configuración más detallada (ver su documentación).
# 3.  **Crear Archivo de Configuración Celery (`celery.py`):** Crea un archivo `celery.py` junto a tu `settings.py` (ej: `mi_sitio/celery.py`).
#     ```python
#     # mi_sitio/celery.py
#     import os
#     from celery import Celery
#
#     # Establecer el módulo de settings de Django para el programa 'celery'.
#     os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'mi_sitio.settings')
#
#     # Crear instancia de Celery (nombre del proyecto como primer argumento)
#     app = Celery('mi_sitio')
#
#     # Usar un namespace 'CELERY' para todas las keys de configuración en settings.py
#     app.config_from_object('django.conf:settings', namespace='CELERY')
#
#     # Cargar automáticamente archivos tasks.py de todas las apps registradas en Django
#     app.autodiscover_tasks()
#
#     # Tarea de ejemplo (opcional, para probar)
#     @app.task(bind=True)
#     def debug_task(self):
#         print(f'Request: {self.request!r}')
#     ```
# 4.  **Importar la app Celery en `mi_sitio/__init__.py`:** Esto asegura que la app Celery se cargue cuando Django se inicie.
#     ```python
#     # mi_sitio/__init__.py
#     from .celery import app as celery_app
#
#     __all__ = ('celery_app',)
#     ```
# 5.  **Configurar Broker y Backend en `settings.py`:** Añade las configuraciones con el prefijo `CELERY_`.
#     ```python
#     # settings.py
#
#     # --- Configuración Celery (Ejemplo con Redis) ---
#     CELERY_BROKER_URL = 'redis://localhost:6379/0' # URL del Broker (DB 0 de Redis)
#     CELERY_RESULT_BACKEND = 'redis://localhost:6379/0' # URL del Backend de Resultados (misma DB)
#     CELERY_ACCEPT_CONTENT = ['json'] # Formato de serialización de tareas
#     CELERY_TASK_SERIALIZER = 'json'
#     CELERY_RESULT_SERIALIZER = 'json'
#     CELERY_TIMEZONE = TIME_ZONE # Usar la timezone de Django
#     # CELERY_TASK_TRACK_STARTED = True # Opcional: registrar estado 'STARTED'
#     # CELERY_BEAT_SCHEDULER = 'django_celery_beat.schedulers:DatabaseScheduler' # Si usas tareas periódicas con django-celery-beat
#     ```
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 70_3_Definicion_y_Llamada_de_Tareas
#
# Las tareas Celery son funciones Python normales decoradas con `@shared_task` (si la tarea se define en `tasks.py` de una app y quieres que sea reutilizable) o `@app.task` (si usas la instancia `app` de `celery.py`).
#
# 1.  **Crear `tasks.py` en tu aplicación:** (ej: `productos/tasks.py`)
#     ```python
#     # productos/tasks.py
#     from celery import shared_task
#     import time
#     # from django.core.mail import send_mail
#
#     @shared_task # Decorador para tareas descubiertas automáticamente
#     def enviar_email_bienvenida_async(user_id):
#         """Tarea asíncrona para enviar email de bienvenida."""
#         from django.contrib.auth import get_user_model
#         User = get_user_model()
#         try:
#             user = User.objects.get(pk=user_id)
#             print(f"Enviando email de bienvenida a {user.email}...")
#             time.sleep(5) # Simular tarea larga (envío real de email)
#             # send_mail(
#             #     'Bienvenido a Mi Tienda!',
#             #     f'Hola {user.username},\n\nGracias por registrarte.',
#             #     'noreply@mitienda.com',
#             #     [user.email],
#             #     fail_silently=False,
#             # )
#             print(f"Email de bienvenida enviado a {user.email}")
#             return f"Email enviado a {user.email}" # Valor de retorno opcional
#         except User.DoesNotExist:
#             print(f"Error: Usuario con ID {user_id} no encontrado para email.")
#             return "Usuario no encontrado"
#         except Exception as e:
#             print(f"Error al enviar email: {e}")
#             # Podrías reintentar la tarea aquí con raise self.retry(exc=e)
#             return f"Error: {e}"
#
#     @shared_task
#     def procesar_imagen_producto_async(producto_id):
#         from .models import Producto
#         try:
#             producto = Producto.objects.get(pk=producto_id)
#             if producto.imagen:
#                 print(f"Procesando imagen para {producto.nombre}...")
#                 time.sleep(10) # Simular procesamiento largo (redimensionar, marcas de agua...)
#                 # ... lógica de procesamiento de imagen ...
#                 print(f"Imagen procesada para {producto.nombre}")
#                 return "Procesada"
#             return "Sin imagen"
#         except Producto.DoesNotExist:
#             return "Producto no encontrado"
#     ```
# 2.  **Llamar a la Tarea desde tu Código (ej: Vistas, Señales):**
#     *   Usa el método `.delay()` o `.apply_async()` del nombre de la tarea importada. Esto **no** ejecuta la función directamente, sino que envía el mensaje al broker.
#     *   `.delay(*args, **kwargs)`: Atajo simple para enviar la tarea con argumentos posicionales y de palabra clave.
#     *   `.apply_async(args=[...], kwargs={...}, countdown=N, eta=datetime, ...)`: Más flexible, permite especificar opciones como `countdown` (retraso en segundos antes de ejecutar) o `eta` (fecha/hora exacta de ejecución).
#
#     ```python
#     # accounts/signals.py (Ejemplo: enviar email al crear usuario)
#     from django.db.models.signals import post_save
#     from django.contrib.auth import get_user_model
#     from django.dispatch import receiver
#     # Importa la tarea desde donde la definiste
#     from productos.tasks import enviar_email_bienvenida_async
#
#     User = get_user_model()
#
#     @receiver(post_save, sender=User)
#     def usuario_creado_enviar_email(sender, instance, created, **kwargs):
#         if created:
#             print(f"Usuario {instance.username} creado. Enviando tarea de bienvenida...")
#             # Llama a la tarea Celery de forma asíncrona
#             enviar_email_bienvenida_async.delay(instance.pk) # Pasa el ID del usuario
#
#     # --- Ejemplo en una vista ---
#     # productos/views.py
#     # ... (importar tarea procesar_imagen_producto_async) ...
#     # def alguna_vista_que_sube_imagen(request):
#     #     # ... (guardar producto con imagen) ...
#     #     if nuevo_producto.imagen:
#     #         # Llamar a la tarea para procesar en segundo plano
#     #         procesar_imagen_producto_async.delay(nuevo_producto.pk)
#     #     # ... (redirigir o renderizar) ...
#     ```
# 3.  **Ejecutar el Worker Celery:** Necesitas tener al menos un worker ejecutándose en segundo plano para procesar las tareas de la cola.
#     ```bash
#     # Desde el directorio raíz del proyecto (con venv activo)
#     # -A mi_sitio: Apunta a la instancia Celery 'app' en mi_sitio/celery.py
#     celery -A mi_sitio worker --loglevel=info
#     ```
#     Verás cómo el worker detecta las tareas definidas y espera mensajes del broker. Cuando llames a `.delay()`, el worker recogerá la tarea y ejecutará la función correspondiente, imprimiendo los logs que pusiste en ella.
#
# Celery es esencial para escalar aplicaciones Django y mejorar la experiencia del usuario al mover operaciones lentas fuera del ciclo de petición-respuesta.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ## 71_WebSockets_con_Django_Channels_Introduccion
#
# HTTP, el protocolo base de la web, es fundamentalmente un protocolo de petición-respuesta: el cliente pide, el servidor responde. Para funcionalidades que requieren comunicación en **tiempo real** o **bidireccional** (el servidor empuja datos al cliente sin una petición previa), como chats, notificaciones instantáneas, juegos multijugador o actualizaciones en vivo, HTTP no es ideal. **WebSockets** solucionan esto proporcionando una conexión persistente y bidireccional sobre una única conexión TCP.
#
# **Django Channels** es el proyecto que extiende Django para manejar protocolos más allá de HTTP, notablemente WebSockets, utilizando la interfaz **ASGI**.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 71_1_ASGI_vs_WSGI
#
# *   **WSGI (Web Server Gateway Interface):** Estándar síncrono para Python web. Maneja un ciclo de petición/respuesta corto. Ideal para HTTP tradicional. Servidores: Gunicorn (modo sync), uWSGI (modo sync).
# *   **ASGI (Asynchronous Server Gateway Interface):** Estándar **asíncrono**. Diseñado para manejar conexiones de larga duración (como WebSockets) y un gran número de conexiones concurrentes de forma eficiente usando `asyncio`. También puede manejar HTTP. Servidores: Daphne, Uvicorn, Hypercorn.
#
# Para usar Channels, necesitas configurar tu proyecto para que se ejecute como una aplicación ASGI y usar un servidor ASGI.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 71_2_Consumers_Routing_Channel_Layers
#
# Channels introduce varios conceptos nuevos:
#
# 1.  **Aplicación ASGI (`asgi.py`):** El punto de entrada principal (similar a `wsgi.py`). Define cómo se manejarán diferentes protocolos (HTTP, WebSocket).
#     ```python
#     # mi_sitio/asgi.py
#     import os
#     from channels.routing import ProtocolTypeRouter, URLRouter
#     from django.core.asgi import get_asgi_application
#     # Importa tu enrutador de WebSocket (ver abajo)
#     import mi_app.routing
#
#     os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'mi_sitio.settings')
#
#     # Aplicación ASGI principal de Django para manejar HTTP normal
#     django_asgi_app = get_asgi_application()
#
#     application = ProtocolTypeRouter({
#         # Manejará peticiones HTTP(S) usando la app ASGI estándar de Django
#         "http": django_asgi_app,
#
#         # Manejará conexiones WebSocket usando nuestro enrutador personalizado
#         "websocket": AuthMiddlewareStack( # Opcional: Añade manejo de sesión/usuario
#             URLRouter(
#                 mi_app.routing.websocket_urlpatterns # Ruta a tus patrones URL WebSocket
#             )
#         ),
#     })
#     # Nota: Necesitarás importar AuthMiddlewareStack de channels.auth
#     ```
# 2.  **Routing (`routing.py`):** Similar a `urls.py`, pero para protocolos ASGI como WebSocket. Define patrones de ruta y a qué **Consumer** deben dirigirse las conexiones que coincidan.
#     ```python
#     # mi_app/routing.py
#     from django.urls import re_path # O path
#     from . import consumers # Importa tus consumers
#
#     websocket_urlpatterns = [
#         # Mapea la ruta 'ws/chat/<room_name>/' al ChatConsumer
#         re_path(r'ws/chat/(?P<room_name>\w+)/$', consumers.ChatConsumer.as_asgi()),
#         re_path(r'ws/notificaciones/$', consumers.NotificationConsumer.as_asgi()),
#     ]
#     ```
# 3.  **Consumers (`consumers.py`):** Son el equivalente a las vistas de Django, pero para conexiones ASGI de larga duración como WebSockets. Son clases (a menudo `AsyncWebsocketConsumer`) que definen métodos para manejar eventos del ciclo de vida de la conexión y los mensajes:
#     *   `connect()`: Se llama cuando un cliente intenta conectarse. Puedes aceptar (`self.accept()`) o rechazar la conexión.
#     *   `disconnect(close_code)`: Se llama cuando la conexión se cierra. Para limpieza.
#     *   `receive(text_data=None, bytes_data=None)`: Se llama cuando se recibe un mensaje del cliente. Aquí procesas el mensaje y puedes enviar respuestas.
#     *   `self.send(text_data=..., bytes_data=...)`: Método para enviar mensajes de vuelta al cliente conectado.
#     ```python
#     # mi_app/consumers.py
#     import json
#     from channels.generic.websocket import AsyncWebsocketConsumer
#
#     class ChatConsumer(AsyncWebsocketConsumer):
#         async def connect(self):
#             self.room_name = self.scope['url_route']['kwargs']['room_name']
#             self.room_group_name = f'chat_{self.room_name}'
#
#             # Unirse al grupo de la sala (requiere Channel Layer)
#             await self.channel_layer.group_add(
#                 self.room_group_name,
#                 self.channel_name
#             )
#             await self.accept() # Aceptar la conexión WebSocket
#             print(f"WebSocket conectado a sala: {self.room_name}")
#
#         async def disconnect(self, close_code):
#             print(f"WebSocket desconectado de sala: {self.room_name}")
#             # Salir del grupo de la sala
#             await self.channel_layer.group_discard(
#                 self.room_group_name,
#                 self.channel_name
#             )
#
#         # Recibir mensaje del WebSocket (cliente)
#         async def receive(self, text_data):
#             text_data_json = json.loads(text_data)
#             message = text_data_json['message']
#             user = self.scope.get("user", "Anonimo") # Acceder al user si usas AuthMiddlewareStack
#
#             print(f"Mensaje recibido en {self.room_name} de {user}: {message}")
#
#             # Enviar mensaje a TODOS en el grupo de la sala (broadcasting)
#             await self.channel_layer.group_send(
#                 self.room_group_name,
#                 {
#                     'type': 'chat.message', # Llama al método chat_message en otros consumers del grupo
#                     'message': message,
#                     'sender': str(user)
#                 }
#             )
#
#         # Recibir mensaje del grupo de la sala
#         async def chat_message(self, event):
#             message = event['message']
#             sender = event['sender']
#
#             # Enviar mensaje de vuelta al WebSocket (cliente individual)
#             await self.send(text_data=json.dumps({
#                 'message': message,
#                 'sender': sender
#             }))
#     ```
# 4.  **Channel Layers (Capas de Canales):** Un sistema de comunicación opcional pero a menudo necesario que permite a diferentes instancias de Consumers (potencialmente en diferentes procesos o máquinas) hablar entre sí. Es esencial para broadcasting (enviar un mensaje a múltiples clientes, como en un chat).
#     *   Se configura en `settings.py` (`CHANNEL_LAYERS`).
#     *   **Redis** es el backend más común (`channels_redis`).
#     ```python
#     # settings.py
#     ASGI_APPLICATION = 'mi_sitio.asgi.application' # Apuntar a tu aplicación ASGI
#     CHANNEL_LAYERS = {
#         'default': {
#             'BACKEND': 'channels_redis.core.RedisChannelLayer',
#             'CONFIG': {
#                 "hosts": [('localhost', 6379)], # O la URL de tu Redis
#             },
#         },
#     }
#     ```
#
# Channels es un tema avanzado que introduce la programación asíncrona en Django, pero es la forma estándar de implementar WebSockets y otras funcionalidades en tiempo real.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ## 72_Internacionalizacion_i18n_y_Localizacion_l10n
#
# Django tiene un excelente soporte para crear sitios web multilingües y adaptados a diferentes regiones.
#
# *   **Internacionalización (i18n):** El proceso de diseñar tu aplicación para que *pueda* ser traducida fácilmente. Implica marcar los textos visibles al usuario para su traducción.
# *   **Localización (l10n):** El proceso de *adaptar* tu aplicación para un idioma y región específicos. Esto incluye no solo traducir los textos, sino también formatear fechas, horas, números y monedas según las convenciones locales.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 72_1_Marcar_Textos_Traducibles_y_Compilar_Mensajes
#
# **1. Marcar Textos:**
# *   **En Python (`views.py`, `models.py`, etc.):**
#     *   Importa `gettext` o `gettext_lazy` (para textos en definiciones de modelos/formularios que se evalúan más tarde):
#       `from django.utils.translation import gettext as _`
#       `from django.utils.translation import gettext_lazy as _lazy`
#     *   Envuelve los strings traducibles con `_()` o `_lazy()`.
#       ```python
#       mensaje = _("Este es un mensaje traducible.")
#       class MiModelo(models.Model):
#           campo = models.CharField(max_length=100, verbose_name=_lazy("Nombre del Campo"))
#       ```
# *   **En Plantillas (`.html`):**
#     *   Carga la librería i18n: `{% load i18n %}`
#     *   Usa la etiqueta `{% trans "Texto a traducir" %}` para strings simples.
#     *   Usa `{% blocktrans %}` ... `{% endblocktrans %}` para bloques que contienen variables. Puedes usar `with` o `count` dentro.
#       ```html
#       {% load i18n %}
#       <h1>{% trans "Bienvenido" %}</h1>
#       <p>{% blocktrans %}Tienes {{ num_mensajes }} mensaje nuevo.{% plural %}Tienes {{ num_mensajes }} mensajes nuevos.{% endblocktrans %}</p>
#       <p>{% blocktrans with nombre_usuario=user.username %}Hola, {{ nombre_usuario }}{% endblocktrans %}</p>
#       <input type="submit" value="{% trans 'Guardar' %}">
#       ```
#
# **2. Generar Archivos de Mensajes (`.po`):**
# Desde el directorio raíz del proyecto, ejecuta `makemessages` para cada idioma que quieras soportar. Esto crea/actualiza archivos `.po` en `locale/<codigo_idioma>/LC_MESSAGES/django.po`.
# ```bash
# # Crear/actualizar archivos para español y francés
# python manage.py makemessages -l es -l fr
# # O para un idioma específico
# python manage.py makemessages -l de
# ```
#
# **3. Traducir:**
# Edita los archivos `.po` generados. Son archivos de texto con pares `msgid` (el texto original en inglés o como lo hayas escrito) y `msgstr` (la traducción). Rellena las `msgstr` con las traducciones.
# ```po
# #: .\mi_app\views.py:10
# msgid "Welcome to our site!"
# msgstr "¡Bienvenido a nuestro sitio!"  # <- Tu traducción
#
# #: .\mi_app\templates\mi_app\pagina.html:5
# msgid "Page Title"
# msgstr "Título de la Página"
# ```
#
# **4. Compilar Mensajes (`.mo`):**
# Una vez traducidos los `.po`, compílalos a archivos binarios `.mo` que Django usa eficientemente.
# ```bash
# python manage.py compilemessages
# ```
#
# **5. Configurar Idiomas en `settings.py`:**
# ```python
# # settings.py
# LANGUAGE_CODE = 'es' # Idioma por defecto si no se detecta otro
#
# # Lista de idiomas soportados (tupla de tuplas: codigo, nombre legible)
# LANGUAGES = [
#     ('es', 'Español'),
#     ('en', 'English'),
#     ('fr', 'Français'),
# ]
# # Habilitar i18n y l10n
# USE_I18N = True
# USE_L10N = True # Para formatos localizados
# USE_TZ = True # Recomendado: habilitar soporte de zonas horarias
#
# # Directorios donde buscar archivos de traducción (además de locale/ en cada app)
# # LOCALE_PATHS = [ BASE_DIR / 'locale', ]
#
# # Añadir middleware para detección de idioma
# MIDDLEWARE = [
#     # ...
#     'django.contrib.sessions.middleware.SessionMiddleware',
#     'django.middleware.locale.LocaleMiddleware', # Importante: después de Session, antes de Common
#     'django.middleware.common.CommonMiddleware',
#     # ...
# ]
# ```
# `LocaleMiddleware` intenta determinar el idioma del usuario basándose en: 1) Prefijo de URL (si configuras `i18n_patterns` en urls), 2) Cookie de sesión/idioma, 3) Cabecera `Accept-Language` del navegador, 4) `LANGUAGE_CODE` por defecto.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 72_2_Formato_de_Fechas_Numeros_Monedas
#
# Cuando `USE_L10N = True` en `settings.py`, Django intentará automáticamente formatear fechas, horas y números según la configuración regional (locale) activa.
#
# *   **En Plantillas:** Usa los filtros `date`, `time` sin un argumento de formato específico, o usa filtros como `floatformat` con el argumento `use_l10n=True`. Django usará los formatos definidos para el idioma actual.
#     ```html
#     {# Usará el formato corto de fecha para 'es' o 'en' según el locale #}
#     {{ mi_fecha | date:"SHORT_DATE_FORMAT" }}
#
#     {# Formateará el número con separador decimal/miles local #}
#     {{ mi_numero | floatformat:2:True }} {# El segundo True habilita l10n #}
#     ```
# *   **En Formularios:** Los campos como `DateField`, `DecimalField` también usarán formatos localizados para mostrar y aceptar la entrada.
#
# Puedes encontrar formatos específicos para diferentes locales en la configuración de Django o personalizarlos.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ## 73_Sistema_de_Mensajes_Messages_Framework
#
# El framework de mensajes (`django.contrib.messages`) proporciona una forma sencilla de mostrar notificaciones temporales (mensajes "flash") al usuario. Son útiles para confirmar acciones (ej: "Producto guardado") o mostrar errores después de una redirección.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ### 73_1_Anadir_y_Mostrar_Mensajes_Flash
#
# **1. Configuración:**
# *   Asegúrate de que `'django.contrib.messages'` esté en `INSTALLED_APPS`.
# *   Asegúrate de que `'django.contrib.sessions.middleware.SessionMiddleware'` y `'django.contrib.messages.middleware.MessageMiddleware'` estén en `MIDDLEWARE`.
# *   Asegúrate de que `'django.contrib.messages.context_processors.messages'` esté en `OPTIONS['context_processors']` dentro de `TEMPLATES`.
# (Todo esto suele estar configurado por defecto).
#
# **2. Añadir Mensajes en Vistas:**
# Importa `messages` de `django.contrib` y usa sus funciones de nivel: `debug`, `info`, `success`, `warning`, `error`.
# ```python
# # views.py
# from django.contrib import messages
# from django.shortcuts import redirect
#
# def mi_vista_con_accion(request):
#     # ... realizar alguna acción ...
#     if exito:
#         messages.success(request, '¡La operación se completó exitosamente!')
#     else:
#         messages.error(request, 'Hubo un problema al realizar la operación.')
#         messages.warning(request, 'Revisa los datos introducidos.') # Ejemplo warning
#     return redirect('alguna_otra_vista')
#
# def otra_vista(request):
#     messages.info(request, 'Bienvenido a esta página.')
#     return render(request, 'pagina.html')
# ```
# Los mensajes se almacenan asociados a la sesión del usuario (u otro backend configurable) y están diseñados para mostrarse **una sola vez** en la siguiente petición donde se renderice una plantilla que los muestre.
#
# **3. Mostrar Mensajes en Plantillas:**
# En tu plantilla base (`base.html`) o en cualquier plantilla donde quieras que aparezcan, itera sobre la variable `messages` (añadida por el context processor) y muéstralos.
# ```html
# {# base.html u otra plantilla #}
# {% if messages %}
#   <ul class="messages" style="list-style-type: none; padding: 0; margin: 1em 0;">
#     {% for message in messages %}
#       {# message.tags contiene el nivel (debug, info, success, warning, error) como clase CSS #}
#       <li{% if message.tags %} class="alert alert-{{ message.tags }}"{% endif %}
#          style="padding: 10px; border: 1px solid; margin-bottom: 5px;">
#         {{ message }}
#       </li>
#     {% endfor %}
#   </ul>
# {% endif %}
#
# {# Ejemplo de estilo básico para los niveles (requiere CSS real) #}
# <style>
#   .alert-debug { border-color: gray; background-color: #f0f0f0; }
#   .alert-info { border-color: blue; background-color: #e7f3fe; color: #0056b3; }
#   .alert-success { border-color: green; background-color: #d4edda; color: #155724; }
#   .alert-warning { border-color: orange; background-color: #fff3cd; color: #856404; }
#   .alert-error { border-color: red; background-color: #f8d7da; color: #721c24; }
# </style>
# ```
# El framework de mensajes es una forma estándar y fácil de dar feedback temporal al usuario a través de diferentes peticiones.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ## 74_Recursos_Adicionales_y_Comunidad_Django
#
# Dominar Django es un proceso continuo. Afortunadamente, el ecosistema ofrece muchísimos recursos:
#
# *   **Documentación Oficial de Django:** ([https://docs.djangoproject.com/](https://docs.djangoproject.com/)) - La fuente definitiva. Es excelente, completa y bien organizada. ¡Conviértela en tu referencia principal!
# *   **Tutorial Oficial:** ([https://docs.djangoproject.com/en/stable/intro/tutorial01/](https://docs.djangoproject.com/en/stable/intro/tutorial01/)) - Si no lo has hecho, es un gran punto de partida práctico para construir una aplicación de encuestas.
# *   **Django REST Framework:** ([https://www.django-rest-framework.org/](https://www.django-rest-framework.org/)) - Documentación esencial si vas a construir APIs.
# *   **Django Packages:** ([https://djangopackages.org/](https://djangopackages.org/)) - Un repositorio masivo de aplicaciones y paquetes de terceros reutilizables para casi cualquier funcionalidad que puedas imaginar (autenticación avanzada, gestión de contenido, APIs, etc.). Busca aquí antes de reinventar la rueda.
# *   **Comunidades Online:**
#     *   **Foro Oficial de Django:** ([https://forum.djangoproject.com/](https://forum.djangoproject.com/))
#     *   **Stack Overflow:** Etiqueta `[django]`. Millones de preguntas y respuestas. Busca antes de preguntar.
#     *   **Reddit:** `r/django`. Discusiones, noticias, preguntas.
#     *   **Servidor de Discord de Django:** Para chat en tiempo real.
# *   **Libros:**
#     *   "Two Scoops of Django" (Greenfeld & Roy): Un clásico sobre buenas prácticas y patrones.
#     *   Serie de William S. Vincent ("Django for Beginners", "Django for APIs", "Django for Professionals"): Muy prácticos y actualizados.
# *   **Boletines y Blogs:** Django News, blogs de desarrolladores Django reconocidos.
# *   **Cursos Online:** Udemy, Coursera, Real Python, TestDriven.io, etc., ofrecen cursos específicos sobre Django y temas relacionados.
#
# La clave es la práctica constante y no tener miedo de consultar la documentación y pedir ayuda (después de haber investigado) en las comunidades.
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ## 75_Conclusion_Final_del_Curso
#
# ¡Felicidades por llegar al final de este curso completo de Django! Has cubierto una enorme cantidad de terreno, desde los conceptos más básicos hasta funcionalidades avanzadas necesarias para construir aplicaciones web robustas, seguras y escalables.
#
# **Has aprendido sobre:**
# *   La filosofía y arquitectura MVT de Django.
# *   Configuración del entorno con Python, Pip y venv.
# *   Creación de proyectos y aplicaciones.
# *   El ciclo Request/Response.
# *   Mapeo de URLs y vistas (FBVs y CBVs).
# *   El sistema de plantillas (DTL), incluyendo herencia, includes, filtros y tags.
# *   El ORM de Django: definición de modelos, migraciones y el potente API de QuerySets.
# *   La interfaz de administración automática y su personalización.
# *   El framework de formularios para creación, validación y procesamiento de datos.
# *   Gestión de archivos estáticos y de medios.
# *   El sistema de autenticación y autorización incorporado.
# *   La importancia y las técnicas para escribir pruebas automatizadas.
# *   Los conceptos y herramientas clave para el despliegue en producción.
# *   Temas avanzados como Middleware, Signals, Caching, DRF, Celery y Channels.
#
# **¿Y ahora qué?**
# El desarrollo web es un campo vasto y en constante cambio. Django te proporciona una base increíblemente sólida, pero el viaje continúa:
#
# 1.  **¡CONSTRUYE!** La teoría es necesaria, pero la habilidad se forja con la práctica. Empieza un proyecto personal, por pequeño que sea. Intenta construir un blog, un portfolio, una pequeña tienda, un clon simple de alguna aplicación que uses. Enfrentarte a problemas reales es la mejor forma de aprender.
# 2.  **Profundiza:** Elige un área que te haya interesado especialmente (APIs con DRF, Tiempo Real con Channels, Frontend con JavaScript, Testing Avanzado, Despliegue en Cloud) y explórala más a fondo.
# 3.  **Frontend Moderno:** Aprende un framework/librería JavaScript como React, Vue o Svelte. La combinación de un backend Django (a menudo sirviendo una API con DRF) y un frontend JS moderno es muy común y demandada.
# 4.  **Bases de Datos:** Profundiza tus conocimientos de SQL y de la base de datos que uses (PostgreSQL, MySQL). Aprende sobre optimización de consultas, índices avanzados, etc.
# 5.  **Docker y Despliegue:** Si te interesa la infraestructura, aprende Docker y herramientas de orquestación como Kubernetes o explora más a fondo las plataformas PaaS.
# 6.  **Contribuye:** Una vez que te sientas más cómodo, considera contribuir a Django o a alguna de las muchas librerías de su ecosistema. Es una excelente forma de aprender y devolver a la comunidad.
# 7.  **Mantente Curioso:** Sigue aprendiendo, lee blogs, asiste a meetups (si puedes), explora nuevas tecnologías.
#
# Has adquirido una habilidad muy valiosa. Django es un framework potente y demandado en la industria. Con la base de este curso y la práctica continua, estás en un excelente camino para convertirte en un desarrollador web competente.
#
# **¡Mucha suerte y feliz codificación con Django!**
#
# [Volver a la Tabla de Contenido](#Tabla_de_Contenido)
#
# ---
