# %% [markdown]
# # Python, Flask y Django

# %% [markdown]
# ## 3 Universidad Python con la IA de ChatGPT - De Cero a Experto!

# %% [markdown]
# ### Sección 1: Introducción al curso de Python con ChatGPT-Ia generativa

# %% [markdown]
# #### Bienvenida

# %% [markdown]
# Impartido por:
#     Ubaldo Acosta y Marcela Gamiño

# %% [markdown]
# #### Introducción al curso de chat GPT - IA Generativa

# %% [markdown]
# Chat GPT es una implementación que utiliza modelos de lenguaje de IA.
# GPT significa Generative Pre-Trained Transformer

# %% [markdown]
# #### Introducción a Chat-GPT

# %% [markdown]
# Registrarse en Chat-GPT

# %% [markdown]
# ChatGPT es un modelo de lenguaje desarrollado por OpenAI, capaz de generar texto coherente y relevante según las consultas que recibe. Utiliza técnicas avanzadas de aprendizaje automático para aplicaciones como asistencia virtual, generación de texto creativo, traducción, y más.

# %% [markdown]
# #### Característicvas de Chat-GPT

# %% [markdown]
# "ChatGPT 3.5" en la arquitectura GPT (Generative Pre-trained Transformer). Es capaz de generar texto coherente y relevante en respuesta a las consultas o instrucciones que recibe. Utiliza técnicas de aprendizaje automático para comprender y generar texto en varios contextos, lo que lo hace útil para una amplia gama de aplicaciones, como asistencia virtual, generación de texto creativo, traducción automática, entre otros.

# %% [markdown]
# #### ¿Qué es Python con Chat-GPT?

# %% [markdown]
# Python es un lenguaje de programación de alto nivel, interpretado y de propósito general. Fue creado por Guido van Rossum y lanzado en 1991. Es conocido por su sintaxis clara y fácil de aprender, lo que lo convierte en una excelente opción para principiantes. Pero no te dejes engañar por su sencillez: Python es increíblemente poderoso y versátil.
#
# Se utiliza en diversas áreas, como:
#
# Desarrollo web (con frameworks como Django y Flask).
#
# Análisis de datos y aprendizaje automático.
#
# Automatización de tareas y scripting.
#
# Creación de aplicaciones (desde herramientas gráficas hasta servicios en la nube).
#
# Investigación científica y muchas otras aplicaciones.

# %% [markdown]
# **Características de Python**
#
# Legibilidad:
# Python es conocido por tener una sintaxis clara y sencilla que se asemeja al lenguaje natural. Esto lo hace más fácil de leer y escribir, incluso para aquellos que son nuevos en la programación. Algunos aspectos clave de su legibilidad son:
#
# El uso de espacios en blanco para delimitar bloques de código, en lugar de llaves {}.
#
# Una cantidad mínima de símbolos y caracteres especiales.
#
# Un diseño explícito que fomenta el uso de nombres descriptivos para variables y funciones.
#
# La legibilidad no solo mejora la experiencia del programador, sino también facilita la colaboración en equipos, ya que el código es más entendible.
#
# Multiparadigma
# Python es un lenguaje de programación multiparadigma, lo que significa que admite diferentes estilos o paradigmas de programación. Entre los principales paradigmas que admite se encuentran:
#
# Programación imperativa: Enfocada en instrucciones paso a paso para manipular el estado del programa.
#
# Programación orientada a objetos (POO): Permite trabajar con clases y objetos, encapsular datos y lógica en estructuras organizadas.
#
# Programación funcional: Admite el uso de funciones como elementos primarios y herramientas como funciones lambda, map, filter, y reduce.
#
# Programación procedimental: Fomenta la creación de procedimientos o funciones reutilizables para organizar el código.
#
# Gracias a esta flexibilidad, Python se adapta a diferentes problemas y estilos de desarrollo según las necesidades del proyecto.
#
# Interpretación
# Python es un lenguaje interpretado, lo que significa que el código se ejecuta directamente, línea por línea, sin necesidad de ser compilado previamente a un archivo ejecutable. Algunas ventajas de ser interpretado incluyen:
#
# Facilidad para probar y depurar: Puedes ejecutar partes del código inmediatamente sin un ciclo largo de compilación.
#
# Portabilidad: El intérprete de Python puede ejecutarse en diversos sistemas operativos sin cambios en el código.
#
# Interactividad: Puedes usar un entorno interactivo (como la consola de Python) para probar fragmentos de código rápidamente.
#
# Sin embargo, una desventaja de los lenguajes interpretados es que suelen ser más lentos en comparación con los lenguajes compilados. Aun así, la simplicidad y versatilidad de Python lo hacen ideal para una amplia gama de aplicaciones.

# %% [markdown]
# Comunidad de Python
# La comunidad global de Python es enorme, activa y diversa. Aquí están algunos aspectos destacados:
#
# Colaboración y Apoyo:
#
# Hay millones de desarrolladores en todo el mundo que contribuyen a Python y ayudan a los demás a aprender.
#
# Foros como Stack Overflow, grupos en Reddit, Discord y comunidades locales ofrecen respuestas rápidas y apoyo para resolver problemas.
#
# Eventos y Conferencias:
#
# Python organiza eventos importantes como PyCon, que reúne a desarrolladores de todos los niveles para aprender, compartir y colaborar.
#
# También existen reuniones locales y grupos de usuarios de Python (PUGs), ideales para conectar con otros programadores en tu área.
#
# Documentación y Recursos:
#
# Python cuenta con una documentación oficial extensa, bien estructurada y disponible en múltiples idiomas.
#
# Hay tutoriales, cursos (gratuitos y pagos), libros, videos en YouTube y blogs que hacen más accesible el aprendizaje.
#
# Ecosistema de Python
# El ecosistema de Python se refiere a las herramientas, bibliotecas y recursos que amplían las capacidades del lenguaje. Aquí están los puntos clave:
#
# Bibliotecas y Frameworks:
#
# Python cuenta con decenas de miles de bibliotecas en su repositorio PyPI (Python Package Index), que cubren casi cualquier necesidad:
#
# Ciencia de datos: NumPy, pandas, Matplotlib.
#
# Inteligencia artificial: TensorFlow, PyTorch.
#
# Desarrollo web: Django, Flask.
#
# Automatización: Selenium, Scrapy.
#
# Testing: pytest, unittest.
#
# Compatibilidad y Extensibilidad:
#
# Es compatible con muchas tecnologías: bases de datos (SQL y NoSQL), sistemas operativos y servicios en la nube.
#
# También se integra fácilmente con lenguajes como C, C++ y Java para tareas específicas.
#
# Herramientas de Desarrollo:
#
# Entornos de desarrollo como PyCharm, Jupyter Notebook y Visual Studio Code son populares en la comunidad de Python.
#
# Además, hay múltiples herramientas para gestionar paquetes, como pip y poetry.
#
# Soporte Multiplataforma:
#
# Python funciona en Windows, macOS, Linux, y tiene implementaciones para sistemas específicos como Android e iOS.
#
# En resumen, la fortaleza de la comunidad y la riqueza del ecosistema hacen que Python sea ideal para casi cualquier proyecto, desde aplicaciones simples hasta sistemas complejos.

# %% [markdown]
# #### Temario del curso de Python con Chat-GPT

# %% [markdown]
# Introducción a Python
# Instalación y configuración del entorno (Python y editores como PyCharm o VS Code).
#
# Primeros pasos con Python: aprender sobre su sintaxis y estructura básica.
#
# Conceptos básicos de programación
# Declaración y uso de variables.
#
# Tipos de datos (enteros, flotantes, cadenas, listas, diccionarios, etc.).
#
# Estructuras de control: condicionales (if, elif, else) y bucles (for, while).
#
# Programación intermedia
# Funciones: definición, parámetros y valores de retorno.
#
# Funciones lambda y funciones integradas en Python.
#
# Manejo de excepciones y errores comunes.
#
# Programación Orientada a Objetos (POO)
# Conceptos básicos: clases y objetos.
#
# Herencia, encapsulamiento, polimorfismo y abstracción.
#
# Temas avanzados
# Manejo de archivos: lectura y escritura de archivos de texto.
#
# Interacción con bases de datos: conexión, operaciones CRUD.
#
# Introducción a desarrollo web con Python y Flask.
#
# Aplicaciones prácticas
# Interfaces gráficas con Tkinter: creación de aplicaciones de escritorio.
#
# Desarrollo de aplicaciones web con Flask: diseño y funcionalidad.
#
# Proyecto final: crear una aplicación completa integrando lo aprendido.
#
# Extras
# Introducción a bibliotecas populares como NumPy, Pandas y Matplotlib.
#
# Uso de herramientas de IA, como ChatGPT, para apoyo en desarrollo.

# %% [markdown]
# #### Instalación de Python con Chat-GPT

# %% [markdown]
# ##### Prompt:

# %% [markdown]
# > ###### ¿Cómo instalo Python en mi equipo?

# %% [markdown]
# ##### Respuesta:

# %% [markdown]
# > ###### Para instalar Python en tu computadora, sigue estos pasos dependiendo de tu sistema operativo:
#
# > **Windows**
#
# * Descarga ***Python***:
#
# * Ve a la página oficial de ***Python*** en *python.org*.
#
# * Haz clic en el botón *"Download Python X.X.X"* (la última versión disponible aparecerá allí).
#
# * Ejecuta el instalador:
#
# * Una vez descargado el archivo *.exe*, ejecútalo.
#
# * Marca la opción *"Add Python to PATH"* antes de comenzar la instalación.
#
# * Selecciona *"Install Now"* o *"Custom Installation"* (personalizado) si prefieres configurar opciones avanzadas.
#
# * Verifica la instalación:
#
# * Abre la terminal (*Tecla Windows + R*, escribe *cmd* y presiona *Enter*).
#
# * Escribe python *--version* o *py --version* para confirmar que ***Python*** está instalado.
#
# > **Mac**
#
# * Descarga ***Python***:
#
# * También puedes ir al sitio oficial *python.org* y descargar el instalador para ***macOS***.
#
# * Ejecuta el instalador:
#
# * Abre el archivo *.pkg* descargado y sigue las instrucciones en pantalla.
#
# * Verifica la instalación:
#
# * Abre el terminal (*Cmd + Espacio*, escribe *terminal*).
#
# * Escribe *python3 --version* para verificar la instalación.
#
# > **Linux**
#
# * Usa el gestor de paquetes:
#
# * **En distribuciones basadas en ***Debian/Ubuntu***, abre la terminal y ejecuta:**
#
# ```bash
#     sudo apt update
#     apt install python3
# ```
#
# * **Para distribuciones basadas en ***RedHat/Fedora***:**
# ```bash
#     sudo dnf install python3
# ```
#
# * Verifica la instalación:
#
# * Escribe `Python3 --version` en la terminal para confirmar.
#
# ¿Quieres también ayuda con el entorno de desarrollo, como ***PyCharm*** o **VS Code***? 😊
#
# ¿Cuáles son los primeros pasos que debo seguir con ***Python***?
# ¿Cuáles son los errores comunes al instalar ***Python***?
# ¿Qué entornos de desarrollo se recomiendan para ***Python***?

# %% [markdown]
# #### Instalación de Pycharm con Chat-GPT

# %% [markdown]
# ##### Prompt

# %% [markdown]
# > ###### ¿Cómo instalar PyCharm?

# %% [markdown]
# ##### Respuesta

# %% [markdown]
# > ###### Para instalar PyCharm, puedes seguir los pasos que se aplican según tu sistema operativo:
#
# 1. **Descarga PyCharm**
# * Visita la página oficial de ***JetBrains*** en este enlace. Hay dos versiones disponibles:
#
# * ***Community Edition***: Gratuita y suficiente para la mayoría de los proyectos básicos.
#
# * ***Professional Edition***: De pago, incluye funciones avanzadas como desarrollo web y herramientas adicionales.
#
# 2. **Instalación en *Windows***
# * Descarga el instalador para ***Windows*** desde el sitio oficial.
#
# * Abre el archivo descargado (.*exe*) y sigue los pasos del instalador.
#
# * En el proceso de instalación, puedes:
#
# * Crear accesos directos.
#
# * Asociar archivos .*py* con ***PyCharm***.
#
# * Finaliza y abre la aplicación.
#
# 3. **Instalación en macOS**
# * Descarga el archivo *.dmg* correspondiente desde el sitio oficial.
#
# * ,Abre el archivo *.dmg* y arrastra el ícono de ***PyCharm*** a la carpeta *Aplicaciones*.
#
# * Ejecuta ***PyCharm*** desde *Aplicaciones*.
#
# 4. **Instalación en Linux**
# * Descarga el archivo comprimido *.tar.gz* desde la página de ***JetBrains***.
#
# * Extrae el contenido con el siguiente comando en la terminal:
#
# ```bash
# tar -xvzf pycharm.tar.gz
# ```
# Ejecuta el script `pycharm.sh` ubicado en la carpeta extraída:
#
# ```bash
# ./pycharm.sh
# ```
#
# 5. **Configuración inicial**
# * Al abrir ***PyCharm*** por primera vez, selecciona un tema (oscuro o claro).
#
# * Configura el intérprete de ***Python***. ***PyCharm*** suele detectar automáticamente las versiones de ***Python*** instaladas en tu sistema.

# %% [markdown]
# #### Cambios en Pycharm

# %% [markdown]
# > Anteriormente, ***PyCharm*** contaba con dos campos separados: uno para ingresar el nombre del proyecto y otro para definir la ubicación donde se crearía.

# %% [markdown]
# > Ahora, con la nueva actualización, ambos se han unificado en un solo campo llamado Location. En este campo, debes ingresar tanto la ruta donde deseas guardar el proyecto, así como el nombre del mismo, escribiéndolo al final de la ruta.

# %% [markdown]
# #### `Hola mundo` con Python y ChatGPT

# %% [markdown]
# ##### Prompt

# %% [markdown]
# > Genérame un *hola mundo* con ***Python***.

# %% [markdown]
# ##### Respuesta

# %% [markdown]
# >---
# >```python
# > print("Hola, mundo!")
# >```
# >---

# %%
print ('Hola, mundo!')
# Out:
# Hola, mundo!

# %% [markdown]
# ##### Prompt

# %% [markdown]
# > ¿Qué es un *terminal* o *consola* en ***Python***?

# %% [markdown]
# ##### Respuesta

# %% [markdown]
# > * En el contexto de ***Python*** (y de la programación en general), un *terminal* o *consola* es una herramienta donde los desarrolladores pueden interactuar directamente con el *sistema operativo* o con un entorno de programación. Permite ejecutar comandos o código, recibir respuestas, y depurar aplicaciones.
#
# > * Cuando hablamos de ***Python***, la *consola* puede ser:
#
# > * Una *terminal* del *sistema operativo* (como la *línea de comandos* en ***Windows***, o la > *terminal* en ***Mac*** y ***Linux***) donde puedes ejecutar scripts de ***Python***. Por ejemplo, tras instalar ***Python***, puedes escribir `python` en el terminal para entrar al intérprete interactivo de ***Python***.
#
# > * Una *consola* interactiva de ***Python***: Es un *entorno* en el que puedes probar código ***Python*** línea por línea y ver los resultados inmediatamente. Esto incluye herramientas como el ***IDLE*** de ***Python*** o las consolas integradas en editores como PyCharm o VS Code.
#
# > * ¿Te gustaría saber cómo abrir uno o cómo utilizarlo? 😊

# %% [markdown]
# ##### Prompt

# %% [markdown]
# > ¿Qué es el programa de `Hola mundo?`?

# %% [markdown]
# ##### Respuesta

# %% [markdown]
# > * El *programa* de "Hola Mundo" es tradicionalmente el *primer* ejercicio que se realiza al aprender un nuevo *lenguaje* de *programación*. Su propósito es muy simple: mostrar el mensaje "Hola, Mundo" en la *pantalla*, o en la *consola* en el caso de ***Python***. Es como una introducción práctica al *lenguaje*, donde se prueba que todo está configurado correctamente y que el *código* puede ejecutarse.
# >
# > * En ***Python***, el programa "Hola Mundo" se ve así:
# >
# > ---
# > ```python
# >      print("Hola, mundo!")
# > ```
# >---
# >
# > Este *programa* te permite entender cómo funciona la estructura básica del *lenguaje*, cómo se utiliza la *función* `print()` y cómo se ejecuta el *código* en el *entorno* elegido. Es sencillo, pero es la puerta de entrada al mundo de la *programación*. 😊 ¿Te gustaría saber más sobre cómo funciona el *código* o avanzar con otro ejemplo?

# %% [markdown]
# #### Comentarios en Python

# %% [markdown]
# ##### Prompt

# %% [markdown]
# > ¿Qué es un comentario en ***Python***?

# %% [markdown]
# ##### Respuesta

# %% [markdown]
# > En ***Python***, un *comentario* es una línea de texto dentro del *código* que no se ejecuta. Se utiliza para explicar o aclarar el propósito del código, lo que ayuda a otros (o a ti mismo en el futuro) a entender mejor lo que hace. Es una herramienta clave para mantener un *código* limpio y legible.
# > Tipos de *comentarios* en ***Python***:
# Comentarios de una sola línea: Se crean con el carácter **#**. Todo lo que siga después del **#** en esa línea será un comentario.
# >
# > ---
# > ```python
# >     # Esto es un comentario de una sola línea
# >     print("Hola, mundo!")  # Esto imprime un saludo
# > ```
# >---
# >
# > *Comentarios de varias líneas* o ***docstrings***: Aunque ***Python*** no tiene una sintaxis directa para comentarios de varias líneas, puedes usar *comillas triples (''' o """)* como una solución. Sin embargo, técnicamente no son comentarios, sino cadenas de texto que no se asignan a ninguna variable y se ignoran al ejecutarse.
# >
# > ---
# >```python
# >    """
# >    Esto es un comentario de
# >    varias líneas usando
# >    comillas triples
# >    """
# >    print("Hola, mundo!")
# >```
# >---
# >
# > Los *comentarios* son esenciales para *documentar* el propósito y la lógica del código, especialmente en proyectos grandes o colaborativos. ¿Te gustaría saber cómo estructurar comentarios efectivos o cuándo es mejor utilizarlos? 😊

# %% [markdown]
# >```python
# >    # Este programa imprime un saludo en la consola.
# >    # La función print se utiliza para mostrar texto en pantalla.
# >
# >    print("Hola, mundo!")  # Aquí mostramos el mensaje "Hola, mundo!" en la consola.
# >```

# %% [markdown]
# #### Ejercicio propuesto: Preséntate con Python

# %% [markdown]
# ##### Prompt

# %% [markdown]
# >Un programa '*PresentateConPython*' que muestre mi nombre completo, mi edad y mi pais: Miguel Ángel Muñoz Cara, 55, España.

# %% [markdown]
# ##### Respuesta

# %% [markdown]
# >Aquí tienes un programa sencillo en Python llamado "PresentateConPython" que muestra tu nombre completo, edad y país:
# >
# >---
# > ```python
# >    # Programa: PresentateConPython
# >    # Este programa muestra el nombre completo, edad y país del usuario.
# >
# >    # Datos del usuario
# >    nombre_completo = "Miguel Ángel Muñoz Cara"
# >    edad = 55
# >    pais = "España"
# >
# >    # Mostrar presentación
# >    print("¡Hola! Mi nombre es:", nombre_completo)
# >    print("Tengo", edad, "años.")
# >    print("Soy de", pais, ".")
# >```
# >---
# >
# >Cuando ejecutes este código, debería mostrar la siguiente salida en la consola:
# >
# >¡Hola! Mi nombre es: Miguel Ángel Muñoz Cara
# >
# >Tengo 55 años.
# >
# >Soy de España.
#
# >¿Te gustaría ampliarlo con alguna funcionalidad adicional, como pedir los datos al usuario o personalizar la presentación? 😊

# %%
# Programa: PresentateConPython
# Este programa muestra el nombre completo, edad y país del usuario.

# Datos del usuario
nombre_completo = "Miguel Ángel Muñoz Cara"
edad = 55
pais = "España"

# Mostrar presentación
print("¡Hola! Mi nombre es:", nombre_completo)
print("Tengo", edad, "años.")
print("Soy de", pais, ".")
# Out:
# ¡Hola! Mi nombre es: Miguel Ángel Muñoz Cara
# Tengo 55 años.
# Soy de España .

# %% [markdown]
# #### Explicando que es Pep8 en Pythoncon ChatGPT

# %% [markdown]
# ##### Prompt

# %% [markdown]
# > ¿Qué es ***Pep8*** en ***Python***?

# %% [markdown]
# ##### Respuesta

# %% [markdown]
# > ***PEP 8*** es una guía de estilo oficial para escribir código en ***Python***. *PEP* significa *"Python Enhancement Proposal"* *(Propuesta de Mejora de Python*), y el *número 8* es *específico* de esta guía en particular. El propósito principal de ***PEP 8*** es fomentar la *consistencia* y la *legibilidad* en el *código* ***Python***, especialmente cuando varias personas colaboran en un proyecto.
# >
# >Principales aspectos de PEP 8:
# >
# >---
# >```python
# >    def funcion_ejemplo():
# >         print("Hola, mundo")
# >```
# >---
# >*Longitud de línea*:
# > * Limitar la longitud de las líneas a un máximo de *79 caracteres (o 72 en comentarios)*.
# >
# >*Espaciado*:
# >
# > * Evitar espacios adicionales dentro de *paréntesis*, *corchetes* o *llaves*.
# >
# > ---
# >```python
# >   lista = [1, 2, 3]  # Correcto
# >   lista = [ 1, 2, 3 ]  # Incorrecto
# >```
# >---
# > * Rodear los *operadores* con un espacio en ambos lados:
# >
# > ---
# >```python
# >    resultado = x + y  # Correcto
# >    resultado=x+y  # Incorrecto
# >```
# >---
# >Nombres de *variables*, *constantes* y *funciones*:
# >
# > * Usar ***snake_case*** para variables y funciones *(mi_variable, mi_funcion())*.
# >
# > * Usar ***mayúsculas*** para las constantes *(MI_CONSTANTE).
# >
# > * Usar ***CamelCase** para nombres de clases *(MiClase)*.
# >
# >*Comentarios*:
# >
# > * Los comentarios deben ser claros, concisos y útiles.
# >
# > * Evitar comentarios redundantes como:
# >
# > * Usar *docstrings* para documentar *funciones*, *clases* y *módulos*.
# > ---
# >```python
# >   x = x + 1  # Incrementar x por 1  (innecesario)
# >```
# >---
# >
# > * Usar *docstrings* para documentar funciones, clases y módulos.
# >
# >*Importaciones*:
# >
# > * Importar *módulos* en líneas separadas y al comienzo del archivo.
# >
# >---
# >```python
# >   import os
# >   import sys
# >```
# >---
# >
# >Espaciado en *funcione*s:
# >
# > * Dejar dos líneas en blanco antes de definir una *clase* o *función*.
# >
# >
# >Formateo y sangría, *indentaciones*:
# >
# > * Usar 4 espacios por nivel de sangría en lugar de tabulaciones.
# >
# > * Dejar una linea en blanco al final del *archivo*.
# >
# >***PEP 8*** no es obligatorio, pero es una buena práctica que mejora la calidad del código y facilita la colaboración. Si quieres probar la conformidad de tu código con ***PEP 8***, puedes usar herramientas como ***pylint*** o
# >***flake8***.
# >
# >¿Te gustaría ayuda con un ejemplo práctico o más detalles sobre una sección específica de ***PEP 8***? 😊

# %% [markdown]
# #### Ejercicio de codificación 1

# %% [markdown]
# >Bienvenidos a la Universidad de Programacion
# Manda a imprimir (mostrar) en consola el siguiente mensaje usando Python:
# >
# >
# >
# >Bienvenidos a tu curso de Python con ChatGPT
# >
# >
# >
# >Nota: El texto debe ser idéntico al mostrado, respetando acentos, mayúsculas y minúsculas, no agregar espacios, textos o saltos de línea innecesarios, de lo contrario la prueba a ejecutar podría fallar.
# >
# >Instrucciones de Ejecución:
# >
# > 1. Deben presionar el botón de "Ejecutar código" para ver su resultado,
# >
# > 2. Finalmente presionar el botón de  "Ejecutar pruebas" para que quede resuelto el ejercicio.
# >
# > Nota:
# >
# >Tu código podría estar correcto, pero recuerda que lo importante es el resultado de ejecutar la prueba, así que revisa nuevamente las instrucciones del ejercicio y respétalas por completo.
# >
# >Objetivos:
# >
# >Aprender a utilizar la función print y mostrar una cadena (texto) en la consola de Python

# %%
# Escribe tu código aquí
print ('Bienvenidos a tu curso de Python con ChatGPT')
# Out:
# Bienvenidos a tu curso de Python con ChatGPT

# %% [markdown]
# ### Sección 2: Variables en python con ChatGPT

# %% [markdown]
# #### Variables en Python con ChatGPT

# %% [markdown]
# ##### Prompt

# %% [markdown]
# > ¿Qué es una *variable* en ***Python***?

# %% [markdown]
# ##### Respuesta

# %% [markdown]
# >Una *variable* en ***Python*** es un lugar donde puedes almacenar *datos* para usarlos más adelante en tu *program*a. Es como una caja etiquetada que guarda un valor que puede ser modificado o reutilizado. Por ejemplo, podrías guardar un número, una cadena de texto, o incluso algo más complejo como una lista.
# >
# >Aquí hay un ejemplo básico:
# >
# >---
# >```python
# >    nombre = "Miguel"  # Almacenas el texto "Miguel" en la variable nombre
# >    edad = 25          # Almacenas el número 25 en la variable edad
# >    print(f"Hola {nombre}, tienes {edad} años.")  # Usas esas variables para imprimir un mensaje
# >```
# >---
# >
# >En ***Python***, no necesitas especificar el tipo de datos de la variable, porque el lenguaje lo detecta automáticamente.
# >
# >¿Quieres aprender más sobre cómo utilizarlas o algún caso específico? 😊

# %%
nombre = "Miguel"  # Almacenas el texto "Miguel" en la variable nombre
edad = 25          # Almacenas el número 25 en la variable edad
print(f"Hola {nombre}, tienes {edad} años.")  # Usas esas variables para imprimir un mensaje
# Out:
# Hola Miguel, tienes 25 años.

# %% [markdown]
# ##### Prompt

# %% [markdown]
# > ¿Cuál es la sintáxis para definir una *variable* en ***Python***?

# %% [markdown]
# ##### Respuesta

# %% [markdown]
# >¡Definir una *variable* en ***Python*** es súper sencillo! La sintaxis general consiste simplemente en asignar un valor a un nombre de *variable*, utilizando el *operador* =. Aquí tienes la estructura básica:
# >
# >---
# > ```python
# >    nombre_variable = valor
# >```
# >---
# >Ejemplos:
# >
# >---
# >```python
# >    edad = 30                 # Una variable de tipo entero
# >    nombre = "Miguel"         # Una variable de tipo cadena
# >    es_estudiante = True      # Una variable de tipo booleano
# >    precio = 9.99             # Una variable de tipo flotante
# >```
# >---
# >
# >Reglas a tener en cuenta:
# >
# >Nombres válidos: Solo puedes usar letras, números y el carácter _. No pueden comenzar con un número.
# >
# >Correcto: mi_variable, variable_123.
# >
# >Incorrecto: 123variable, var@ible.
# >
# >Sin palabras reservadas: No puedes usar palabras clave de ***Python*** (como if, else, True, None) como nombres de variable.
# >
# >Sensibilidad a mayúsculas y minúsculas: En ***Python**, miVariable y mivariable son diferentes.
# >
# >¿Te gustaría que te ayude con algunos ejemplos adicionales o ejercicios prácticos? 😊

# %% [markdown]
# #### Ejemplo de variables en Python

# %%
# Programa para definir variables en Python
nombre = 'Juan'
edad = 28
pais = 'México'

# Imprimimos o mostramos en consola los valores de cada variable
print('Nombre: ', nombre)
print('Edad: ', edad)
print('Pais: ', pais)
# Out:
# Nombre:  Juan
# Edad:  28
# Pais:  México

# %% [markdown]
# #### Modificación de variables

# %%
# Programa para definir variables en Python
nombre = 'Juan'
edad = 28
pais = 'México'

# Imprimimos o mostramos en consola los valores de cada variable
print('Nombre: ', nombre)
print('Edad: ', edad)
print('Pais: ', pais)

# Modificar los valores de una variable
nombre = 'Juan Carlos'
edad = 30
print('Nombre: ', nombre)
print('Edad: ', edad)
print('Pais: ', pais)

# en python el tipo es dinamico
edad = 'Treinta'
print('Edad: ', edad)

# Imprimir una variable no declarada anteriormente
telefono = '55668811'
print('Telefono: ', telefono)
# Out:
# Nombre:  Juan
# Edad:  28
# Pais:  México
# Nombre:  Juan Carlos
# Edad:  30
# Pais:  México
# Edad:  Treinta
# Telefono:  55668811

# %% [markdown]
# #### Reglas  para las Buenas Prácticas con Python y ChatGPT

# %% [markdown]
# ##### Prompt

# %% [markdown]
# > ¿Cuáles son las *Reglas y Buenas Prácticas* para definir variables en ***Python*** sin agregar parámetros, argumentos, ni funiciones.

# %% [markdown]
# ##### Respuesta

# %% [markdown]
# > ¡Claro! Aquí tienes un resumen de las *reglas y buenas prácticas* para definir *variables* en ***Python*** sin involucrar *parámetros*, *argumentos* o *funciones*:
# >
# >**Reglas básicas:**
# >
# > Nombre válido:
# >
# > * Usa solo letras, números y guiones bajos (_), pero el nombre no puede comenzar con un número.
# >
# >   Ejemplo: `mi_variable` es válido; `123variable` no lo es.
# >
# > * Sin *palabras reservadas*:
# >
# >   No utilices palabras clave de ***Python*** como *if*, *else*, *class*, etc. Puedes verificar las palabras reservadas con **keyword.kwlist**.
# >
# > * Sensibilidad a mayúsculas y minúsculas:
# >
# >    ***Python*** distingue entre `Variable` y `variable` (son diferentes).
# >
# >
# > **Buenas prácticas:**
# >
# >
# > Usa nombres descriptivos:
# >
# > * Dale a la variable un nombre claro que explique su propósito.
# >
# >    Ejemplo: Usa `precio_producto` en lugar de `x`.
# >
# > * Estilo **snake_case**:
# >
# >   Escribe los nombres de tus *variables* en minúsculas, separando palabras con guiones bajos.
# >
# >   Ejemplo: `nombre_cliente`.
# >
# > * vita abreviaturas innecesarias:
# >
# >   Prefiere claridad. Por ejemplo, usa `cantidad_total` en lugar de `ctd_t`.
# >
# > * Usa *constantes* para valores fijos:
# >
# >   Declara valores *constantes* en **mayúsculas**.
# >
# >   Ejemplo: `PI = 3.14159`.
# >
# >*Inicializa* siempre las *variables*:
# >
# > * Asegúrate de asignar un *valor inicial* en lugar de dejarlas indefinidas.
# >
# >Ejemplo:
# >
# > ---
# >```python
# >    total_precio = 0  # Inicializa antes de usar
# >```
# >---
# >
# >*Comentarios* claros:
# >Si el propósito de una *variable* no es obvio, explica su uso con *comentarios*.
# >
# >Ejemplo:
# >
# >---
# > ```python
# >    iva = 0.21  # Porcentaje de IVA aplicable en España.
# >```
# > ---
# >
# > Evita *variables globales* siempre que sea posible:
# >
# >Mantén tus *variables* dentro de un contexto específico (aunque no uses funciones, organiza tu código).
# >
# >Estas reglas garantizan que tu código sea limpio, legible y fácil de mantener. Si quieres practicar con >ejemplos específicos, ¡puedes pedírmelo! 😊
# >
# >

# %% [markdown]
# #### Ejemplo de reglas de Buenas Prácticas

# %% [markdown]
# ##### Prompt

# %% [markdown]
# > Genérame un ejemplo de Reglas y Buenas Prácticas de nombres de variables en Python

# %% [markdown]
# ##### Respuesta

# %% [markdown]
# >¡Claro, Miguel! Aquí tienes una lista de Reglas y Buenas Prácticas para nombrar variables en Python, acompañadas de ejemplos prácticos:
# >
# >Reglas básicas
# Nombres válidos: Solo se pueden usar letras, números y guiones bajos (_). El nombre no puede comenzar con un número.
# >
# >✅ Correcto: `mi_variable`, `variable123`.
# >
# >❌ Incorrecto: `123variable`, `mi-variable`.
# >
# >Evita palabras reservadas: No utilices palabras clave de ***Python*** como *if*, *else*, *class*, etc.
# >
# >---
# > ```python
# >    # Incorrecto
# >    class = 10  # Esto genera un error
# >```
# > ---
# >
# >Sensibilidad a mayúsculas: Python distingue entre mayúsculas y minúsculas, por lo que Variable y variable son diferentes.
# >
# >Buenas prácticas
# >Nombres descriptivos: Usa nombres claros que expliquen el propósito de la variable.
# >
# >✅ Ejemplo: `precio_producto`, `cantidad_total`.
# >
# >❌ Evita: `x`, `y`.
# >
# >Estilo **snake_case**: Escribe nombres de variables en minúsculas y usa guiones bajos para separar palabras.
# >
# > ---
# > ```python
# >     # Correcto
# >     nombre_cliente = "Miguel"
# >     # Incorrecto
# >     NombreCliente = "Miguel"
# > ```
# > ---
# >
# > Evita abreviaturas innecesarias: Prefiere claridad.
# >
# >✅ Claro: total_factura.
# >
# >❌ Poco claro: tfact.
# >
# >Usa *constantes* para valores fijos: Escribe las *constantes* en **mayúsculas**.
# >
# > ---
# > ```python
# >     PI = 3.14159
# >     TASA_IVA = 0.21
# > ```
# > ---
# >
# > Inicializa siempre las *variables*: Asigna un valor inicial para evitar errores.
# >
# > ---
# > ```python
# >     saldo_inicial = 0  # Esto evita problemas más adelante.
# > ```
# > ---
# >
# > Evita *variables globales*: Trata de mantener las *variables* dentro de un ámbito controlado.
# >
# > Comentarios claros: Documenta el propósito de una *variable* si no es evidente.
# >
# > ---
# > ```python
# >     # Porcentaje de IVA aplicado
# >     iva = 0.21
# > ```
# > ---
# >
# > Ejemplo Práctico
# >
# >---
# > ```python
# >     # Correcto: nombres descriptivos y claros
# >     nombre_completo = "Juan Pérez"
# >     edad_usuario = 30
# >     correo_electronico = "juan.perez@mail.com"
# >     saldo_cuenta = 1500.75
# >     # Incorrecto: poco claros o confusos
# >     x = "Juan"
# >     y = 30
# >     email = "juan.perez@mail.com"  # Muy genérico, no aporta contexto
# > ```
# > ---
# >
# > Con estas reglas y prácticas, tu código será más limpio, legible y mantenible. ¡Espero que te sirva como referencia! 🚀

# %%
# Ejemplo de reglas de variables
# Definicion de variables con nombres descriptivos
# Nombre_completo = "Juan Perez" no es buena practica
nombre_completo = "Juan Perez"
edad_usuario = 30
correo_electronico = "juan@mail.com"
saldo_cuenta = 1000.50

# Evitar usar nombres cortos o de una sola letra
contador = 5

# Evitar palabras reservadas
klass = 10

# %% [markdown]
# #### Tipos de Datos en Python con ChatGPT

# %% [markdown]
# ##### Prompt

# %% [markdown]
# > Tipos de datos en Python

# %% [markdown]
# ##### Respuesta

# %% [markdown]
# >¡Claro! Python es un lenguaje muy flexible y admite varios tipos de datos. Aquí tienes una lista de los principales tipos de datos en Python, junto con ejemplos:
# >
# > **Tipos de datos básicos**
# >
# > *Enteros (**int**)*: Representan números enteros, positivos o negativos.
# >
# > ---
# >
# > ```python
# >     edad = 25
# >     temperatura = -15
# > ```
# > ---
# >
# > *Números flotantes (**float**)*: Representan números con decimales.
# >
# > ---
# > ```python
# >     precio = 19.99
# >     pi = 3.14159
# > ```
# > ---
# >
# > *Cadenas de texto (**str**)*: Representan texto y caracteres.
# >
# > ---
# > ```python
# >     nombre = "Miguel"
# >     saludo = 'Hola, ¿cómo estás?'
# > ```
# > ---
# >
# > *Booleanos (**bool**)*: Representan valores lógicos: True o False.
# >
# > ---
# > ```python
# >     es_mayor_de_edad = True
# >     tiene_permisos = False
# > ```
# > ---
# >
# > *Datos complejos (**complex**)*: Representan números complejos (parte real e imaginaria).
# >
# > ---
# > ```python
# >     numero_complejo = 3 + 5j
# > ```
# > ---
# >
# > **Tipos de datos compuestos**
# >
# > *Listas (**list)***: Una colección ordenada y mutable de elementos.
# >
# > ---
# > ```python
# >     frutas = ["manzana", "plátano", "naranja"]
# >     numeros = [1, 2, 3, 4, 5]
#
# > Tuplas (tuple): Una colección ordenada pero inmutable.
# >
# > ---
# > ```python
# >     coordenadas = (40.7128, -74.0060)
# >     colores = ("rojo", "verde", "azul")
# > ```
# > ---
# >
# > *Diccionarios (**dict**)*: Pares clave-valor.
# >
# > ---
# > ```python
# >     persona = {"nombre": "Miguel", "edad": 30, "profesión": "programador"}
# > ```
# > ---
# >
# > *Conjuntos (**set**)*: Colección de elementos únicos y desordenados.
# >
# > ---
# > ```python
# >
# >     letras = {"a", "b", "c"}
# >     numeros_unicos = {1, 2, 3, 4, 5}
# > ```
# > ---
# >
# > **Otros tipos**
# >
# > *Bytes (**bytes**)*: Representan una secuencia de datos binarios.
# >
# > ---
# > ```python
# >     datos = b"Hola Mundo"
# > ```
# > ---
# >
# > *Ninguno (**NoneType**)*: Representa la ausencia de valor.
# >
# > ---
# > ```python
# >     respuesta = None
# > ```
# > ---
# > Con esta variedad de tipos de *datos*, ***Python*** te permite trabajar con casi cualquier tipo de información de forma eficiente. ¿Quieres profundizar en algún tipo en particular? 🚀

# %% [markdown]
# #### Ejemplos de tipos de datos en Python

# %% [markdown]
# ##### Prompt

# %% [markdown]
# > Dame un ejemplo de tipos de datos en Python sin incluir colecciones.

# %% [markdown]
# ##### Respuesta

# %% [markdown]
# > ¡Por supuesto! Aquí tienes algunos ejemplos de tipos de datos en Python que no son colecciones:
# >
# > **Entero (int)**: Representa números enteros. Ejemplo:
# >
# > ---
# > ```python
# >     edad = 25
# > ```
# > ---
# >
# > **Flotante (float)**: Representa números con decimales. Ejemplo:
# >
# > ---
# > ```python
# >     precio = 19.99
# >  ```
# > ---
# >
# > **Booleano (bool)**: Representa valores de verdad (True o False). Ejemplo:
# >
# > ---
# > ```python
# >     es_mayor_de_edad = True
# > ```
# > ---
# >
# > **Cadena de texto (str)**: Representa una secuencia de caracteres. Ejemplo:
# >
# > ---
# > ```python
# >     nombre = "Miguel"
# > ```
# > ---
# >
# > **Número complejo (complex)**: Representa números con parte real e imaginaria. Ejemplo:
# >
# > ---
# > ```python
# >     numero_complejo = 2 + 3j
# > ```
# > ---
# >
# > Estos tipos de *datos* básicos son fundamentales en ***Python*** y permiten la construcción de *programas*
# > más complejos. ¿Quieres que profundicemos en alguno en particular? 🚀

# %% [markdown]
# #### Ejercicio propuesto: Datos de un producto.

# %% [markdown]
# ##### Prompt

# %% [markdown]
# > Ejemplo de *Variables* en ***Python***
# >
# > Dado un producto de una tienda en línea, generar 3 *variables* para almacenar:
# >
# > El *nombre* del producto
# >
# > El *precio* del producto
# >
# > La *cantidad* disponible
# >
# > Finalmente, mandar a imprimir el valor de cada *variable*.

# %% [markdown]
# ##### Respuesta

# %% [markdown]
# >
# > ---
# > ``` python
# >     # Definir las variables
# >     nombre_producto = "Portátil Lenovo"
# >     precio_producto = 899.99
# >     cantidad_disponible = 15
# >
# >     # Imprimir los valores de las variables
# >     print("Nombre del producto:", nombre_producto)
# >     print("Precio del producto:", precio_producto)
# >     print("Cantidad disponible:", cantidad_disponible)
# > ```
# > ---

# %% [markdown]
# ##### Solución

# %% [markdown]
# > ---
# > ```python
# >     # Ejemplo de reglas de variables
# >     # Definicion de variables con nombres descriptivos
# >     #Nombre_completo = "Juan Perez" no es buena practica
# >     nombre_completo = "Juan Perez"
# >     edad_usuario = 30
# >     correo_electronico = "juan@mail.com"
# >     saldo_cuenta = 1000.50
# >
# >     # Evitar usar nombres cortos o de una sola letra
# >     contador = 5
# >
# >     # Evitar palabras reservadas
# >     klass = 10
# >
# > ```
# > ---

# %% [markdown]
# #### Ejercicio propuesto: Datos de un vehículo

# %% [markdown]
# ##### Prompt

# %% [markdown]
# > Datos de un Vehículo
# >
# > Dado una fábrica de producción de vehículos, se solicita almacenar la información de un vehículo en 3 *variables*:
# >
# > La marca del vehículo
# >
# > El modelo del vehículo
# >
# > El año de fabricación
# >
# > Finalmente, agregar algunos valores de ejemplo y mandar a imprimir el valor de cada *variable*.

# %% [markdown]
# ##### Respuesta

# %% [markdown]
# > ---
# > ```python
# >     # Definir las variables para el vehículo
# >     marca_vehiculo = "Toyota"
# >     modelo_vehiculo = "Corolla"
# >     año_fabricacion = 2022
# >
# >     # Imprimir los valores de las variables
# >     print("Marca del vehículo:", marca_vehiculo)
# >     print("Modelo del vehículo:", modelo_vehiculo)
# >     print("Año de fabricación:", año_fabricacion)
# > ```
# > ---

# %% [markdown]
# ##### Solución

# %% [markdown]
# > ---
# > ```python
# >     # Definir las variables para el vehículo
# >     marca_vehiculo = "Renault"
# >     modelo_vehiculo = "Megane"
# >     año_fabricacion = 2003
# >
# >     # Imprimir los valores de las variables
# >     print("Marca del vehículo:", marca_vehiculo)
# >     print("Modelo del vehículo:", modelo_vehiculo)
# >     print("Año de fabricación:", año_fabricacion)
# > ```
# > ---

# %% [markdown]
# #### Cadenas en Python

# %% [markdown]
# ##### Prompt

# %% [markdown]
# > Cadenas en Python

# %% [markdown]
# ##### Respuesta

# %% [markdown]
# > Las **cadenas en Python** (`str`) son uno de los tipos de datos fundamentales para trabajar con texto. Aquí te explico los aspectos clave:
# >
# > 1. **Definición y creación**
# > Una cadena es una secuencia de caracteres encerrada entre comillas simples (`'`), dobles (`"`), triples (`'''` o `"""` para varias líneas):
# >
# > ---
# > ```python
# >     texto_simple = "Hola, Miguel!"
# >     texto_multilinea = """Este es un texto
# >     que ocupa varias líneas."""
# > ```
# > ---
# >
# > 2. **Operaciones comunes**
# > Las cadenas permiten muchas operaciones útiles:
# > - **Concatenación** (`+`): Unir dos cadenas.
# > - **Repetición** (`*`): Repetir una cadena varias veces.
# > - **Longitud** (`len()`): Contar caracteres en una cadena.
# > - **Índices**: Acceder a caracteres individuales (`texto[0]` para el primero).
# > - **Slicing**: Extraer partes de una cadena (`texto[0:5]` para los primeros cinco caracteres).
# >
# > Ejemplo:
# >
# > ---
# > ```python
# >     nombre = "Miguel"
# >     mensaje = "Hola, " + nombre + "!"
# >     print(mensaje)  # Imprime "Hola, Miguel!"
# > ```
# > ---
# >
# > 3. **Métodos útiles**
# > Las cadenas tienen métodos integrados para manipularlas:
# > - `.upper()` → Convierte a mayúsculas
# > - `.lower()` → Convierte a minúsculas
# > - `.strip()` → Elimina espacios innecesarios
# > - `.replace("a", "o")` → Reemplaza caracteres
# > - `.split()` → Divide la cadena en partes
# >
# > Ejemplo:
# >
# > ---
# > ```python
# >     frase = "  Python es genial  "
# >     print(frase.strip().upper())  # "PYTHON ES GENIAL"
# > ```
# > ---
# >
# > 4. **Cadenas y formatos**
# > Python ofrece varias formas de formatear cadenas:
# > - **`f-strings`** (Recomendado desde Python 3.6):
# >
# > ---
# > ```python
# >     edad = 25
# >     print(f"Mi edad es {edad}")
# > ```
# > ---
# >
# > - **`.format()`** (Versión más antigua pero aún útil):
# >
# > ---
# > ```python
# >     print("Mi edad es {}".format(edad))
# > ```
# > ---
# >
# > Las cadenas son clave en programación, desde el procesamiento de datos hasta la construcción de interfaces y respuestas en aplicaciones web. 🚀
# >
# > Si quieres ver más ejemplos o trabajar con cadenas en tu cuaderno Jupyter, dime en qué dirección quieres enfocarte. 😃

# %% [markdown]
# #### Caracteres especiales en Python

# %% [markdown]
# ##### Prompt

# %% [markdown]
# > Caracteres especiales en Python

# %% [markdown]
# ##### Respuesta

# %% [markdown]
# > Las **cadenas en Python** (`str`) son uno de los tipos de datos fundamentales para trabajar con texto. Aquí te explico los aspectos clave:
# >
# > 1. **Definición y creación**
# > Una cadena es una secuencia de caracteres encerrada entre comillas simples (`'`), dobles (`"`), triples (`'''` o `"""` para varias líneas):
# >
# > ---
# > ```python
# >     texto_simple = "Hola, Miguel!"
# >     texto_multilinea = """Este es un texto
# >     que ocupa varias líneas."""
# > ```
# > ---
# >
# > 2. **Operaciones comunes**
# > Las cadenas permiten muchas operaciones útiles:
# > - **Concatenación** (`+`): Unir dos cadenas.
# > - **Repetición** (`*`): Repetir una cadena varias veces.
# > - **Longitud** (`len()`): Contar caracteres en una cadena.
# > - **Índices**: Acceder a caracteres individuales (`texto[0]` para el primero).
# > - **Slicing**: Extraer partes de una cadena (`texto[0:5]` para los primeros cinco caracteres).
# >
# > ---
# > ```python
# >     nombre = "Miguel"
# >     mensaje = "Hola, " + nombre + "!"
# >     print(mensaje)  # Imprime "Hola, Miguel!"
# > ```
# > ---
# >
# > 3. **Métodos útiles**
# > Las cadenas tienen métodos integrados para manipularlas:
# > - `.upper()` → Convierte a mayúsculas
# > - `.lower()` → Convierte a minúsculas
# > - `.strip()` → Elimina espacios innecesarios
# > - `.replace("a", "o")` → Reemplaza caracteres
# > - `.split()` → Divide la cadena en partes
# >
# > ---
# > ```python
# >     frase = "  Python es genial  "
# >     print(frase.strip().upper())  # "PYTHON ES GENIAL"
# > ```
# > ---
# >
# > 4. **Cadenas y formatos**
# > Python ofrece varias formas de formatear cadenas:
# > - **`f-strings`** (Recomendado desde Python 3.6):
# >
# > ---
# > ```python
# >     edad = 25
# >     print(f"Mi edad es {edad}")
# > ```
# > ---
# >
# > - **`.format()`** (Versión más antigua pero aún útil):
# >
# > ---
# > ```python
# >     print("Mi edad es {}".format(edad))
# > ```
# > ---
# >
# > Las cadenas son clave en programación, desde el procesamiento de datos hasta la construcción de interfaces y respuestas en aplicaciones web. 🚀
# >
# > Si quieres ver más ejemplos o trabajar con cadenas en tu cuaderno Jupyter, dime en qué dirección quieres enfocarte. 😃

# %% [markdown]
# #### Concatenación de cadenas en Python

# %% [markdown]
# ##### Prompt

# %% [markdown]
# > Concatenación de cadenas en ***Python***

# %% [markdown]
# ##### Respuesta

# %% [markdown]
# > Concatenación de cadenas en Python es el proceso de unir dos o más cadenas de texto para formar una sola. Se puede realizar de varias maneras:
# >
# > 1. **Uso del operador `+`**
# >    Es la forma más directa de concatenar cadenas.
# >
# > ---
# > ```python
# >     nombre = "Miguel"
# >     saludo = "Hola, " + nombre + "!"
# >     print(saludo)  # Imprime "Hola, Miguel!"
# > ```
# > ---
# >
# > 2. **Uso del operador `*` para repetir cadenas**
# >    Se puede multiplicar una cadena para repetir su contenido.
# >
# > ---
# > ```python
# >     mensaje = "Python! " * 3
# >     print(mensaje)  # Imprime "Python! Python! Python! "
# > ```
# > ---
# >
# > 3. **Concatenación con `join()`**
# >    Une elementos de una lista en una única cadena con un separador.
# >
# > ---
# > ```python
# >     palabras = ["Python", "es", "genial"]
# >     resultado = " ".join(palabras)
# >     print(resultado)  # Imprime "Python es genial"
# > ```
# > ---
# >
# > 4. **Uso de `f-strings` (recomendado desde Python 3.6)**
# >    Forma más moderna y eficiente de concatenar cadenas con variables.
# >
# > ---
# > ```python
# >     nombre = "Miguel"
# >     edad = 25
# >     print(f"Hola, {nombre}. Tienes {edad} años.")
# > ```
# > ---
# >
# > 5. **Uso de `.format()`**
# >    Otra manera de insertar valores dentro de una cadena.
# >
# > ---
# > ```python
# >     print("Hola, {}!".format("Miguel"))
# > ```
# > ---
# >
# > La concatenación es fundamental en la manipulación de texto dentro de Python, útil en creación de mensajes, procesamiento de datos y desarrollo web. 🚀
# >
# > Si necesitas más ejemplos o quieres aplicarlo en tu cuaderno Jupyter, dime cómo te puedo ayudar. 😃
# >

# %% [markdown]
# #### Formato de cadenas en Python

# %% [markdown]
# ##### Prompt

# %% [markdown]
# > Formato de cadenas en ***Python***.

# %% [markdown]
# ##### Respuesta

# %% [markdown]
# > Formato de cadenas en Python permite incluir valores dentro de una cadena de manera flexible y legible. Existen varias maneras de hacerlo:
# >
# > 1. **Uso de `f-strings` (Recomendado desde Python 3.6)**
# >    Permite insertar variables dentro de una cadena de manera intuitiva.
# >
# > ---
# > ```python
# >     nombre = "Miguel"
# >     edad = 25
# >     mensaje = f"Hola, {nombre}. Tienes {edad} años."
# >     print(mensaje)
# > ```
# > ---
# >
# > 2. **Uso de `.format()`**
# >    Método más antiguo pero aún útil para formatear cadenas.
# >
# > ---
# > ```python
# >     mensaje = "Hola, {}. Tienes {} años.".format("Miguel", 25)
# >     print(mensaje)
# > ```
# > ---
# >
# > 3. **Uso de `%` (Método tradicional, menos recomendado)**
# >    Se usa en versiones antiguas de Python.
# >
# > ---
# > ```python
# >     nombre = "Miguel"
# >     edad = 25
# >     mensaje = "Hola, %s. Tienes %d años." % (nombre, edad)
# >     print(mensaje)
# > ```
# > ---
# >
# > 4. **Uso de `.format()` con índices**
# >    Se pueden definir posiciones específicas.
# >
# > ---
# > ```python
# >     mensaje = "Hola, {0}. Tienes {1} años.".format("Miguel", 25)
# >     print(mensaje)
# > ```
# > ---
# >
# > 5. **Uso de `.format()` con nombres de variables**
# >    Se pueden definir nombres para mayor claridad.
# >
# > ---
# > ```python
# >     mensaje = "Hola, {nombre}. Tienes {edad} años.".format(nombre="Miguel", edad=25)
# >     print(mensaje)
# > ```
# > ---
# >
# > El formato de cadenas en Python es esencial para generar salidas dinámicas y bien estructuradas en programas. 🚀
# >
# > Si necesitas más ejemplos o ajustes para tu cuaderno Jupyter, dime cómo puedo ayudarte. 😃

# %% [markdown]
# #### Largo de una cadena en Python

# %% [markdown]
# ##### Prompt

# %% [markdown]
# > Obtener el largo de una cadena en ***Python***.

# %% [markdown]
# ##### Respuesta

# %% [markdown]
# > Obtener el largo de una cadena en ***Python***.
# >
# > Para obtener el largo de una cadena en ***Python***, se utiliza la función `len()`, que devuelve la cantidad de caracteres que contiene una cadena de texto.
# >
# > ---
# > ```python
# >     texto = "Hola, Miguel!"
# >     longitud = len(texto)
# >     print(f"La cadena tiene {longitud} caracteres.")
# > ```
# > ---
# >
# > Este método es útil para verificar el tamaño de una cadena, controlar la cantidad de caracteres ingresados por el usuario y manipular datos textuales en diversos contextos. 🚀
# >
# > Si necesitas más ejemplos o quieres aplicar este concepto en tu cuaderno Jupyter, dime cómo puedo ayudarte. 😃

# %% [markdown]
# #### Métodos Mayúsculas y Minúsculas en Python.

# %% [markdown]
# > Métodos Mayúsculas y Minúsculas en ***Python***.
# >
# > En Python, existen varios métodos para manipular el formato de mayúsculas y minúsculas en cadenas de texto. Estos métodos permiten convertir, verificar y modificar el contenido de una cadena de manera eficiente.
# >
# > 1. **Convertir a mayúsculas y minúsculas**
# >    - `.upper()` → Convierte todos los caracteres de la cadena a **mayúsculas**.
# >    - `.lower()` → Convierte todos los caracteres de la cadena a **minúsculas**.
# >
# > ---
# > ```python
# >     texto = "Hola, Miguel!"
# >     print(texto.upper())  # "HOLA, MIGUEL!"
# >     print(texto.lower())  # "hola, miguel!"
# > ```
# > ---
# >
# > 2. **Intercambiar mayúsculas y minúsculas**
# >    - `.swapcase()` → Cambia las letras mayúsculas por minúsculas y viceversa.
# >
# > ---
# > ```python
# >     texto = "Python Es Genial"
# >     print(texto.swapcase())  # "pYTHON eS gENIAL"
# > ```
# > ---
# >
# > 3. **Capitalizar texto**
# >    - `.capitalize()` → Convierte la primera letra de la cadena en mayúscula y el resto en minúsculas.
# >    - `.title()` → Convierte la primera letra de cada palabra en mayúscula.
# >
# > ---
# > ```python
# >     texto = "python es genial"
# >     print(texto.capitalize())  # "Python es genial"
# >     print(texto.title())  # "Python Es Genial"
# > ```
# > ---
# >
# > 4. **Verificar si una cadena está en mayúsculas o minúsculas**
# >    - `.isupper()` → Devuelve `True` si todos los caracteres están en mayúsculas.
# >    - `.islower()` → Devuelve `True` si todos los caracteres están en minúsculas.
# >
# > ---
# > ```python
# >     texto = "PYTHON"
# >     print(texto.isupper())  # True
# >     print(texto.islower())  # False
# > ```
# > ---
# >
# > Estos métodos son esenciales para la manipulación de texto en Python, especialmente en procesamiento de datos y validación de entradas. 🚀
# >
# > Si necesitas más ejemplos o quieres aplicarlos en tu cuaderno Jupyter, dime cómo puedo ayudarte. 😃

# %% [markdown]
# #### Manejo de subcadenas en Python

# %% [markdown]
# > **Manejo de subcadenas en Python**
# >
# > En Python, una **subcadena** es una parte de una cadena más grande. Se pueden extraer subcadenas utilizando la técnica de **slicing**, que permite seleccionar caracteres específicos dentro de una cadena.
# >
# > 1. **Obtener una subcadena por índice**
# >    Se usa la notación `[inicio:fin]`, donde `inicio` es el índice inicial y `fin` es el índice final (excluido).
# >
# > ---
# > ```python
# >     texto = "Python es genial"
# >     subcadena = texto[0:6]  # Extrae "Python"
# >     print(subcadena)
# > ```
# > ---
# >
# > 2. **Obtener una subcadena con índices negativos**
# >    Los índices negativos permiten contar desde el final de la cadena.
# >
# > ---
# > ```python
# >     texto = "Python es genial"
# >     subcadena = texto[-6:]  # Extrae "genial"
# >     print(subcadena)
# > ```
# > ---
# >
# > 3. **Obtener una subcadena con saltos**
# >    Se puede especificar un tercer valor `[inicio:fin:paso]` para definir el intervalo de extracción.
# >
# > ---
# > ```python
# >     texto = "Python es genial"
# >     subcadena = texto[0:12:2]  # Extrae "Pto sgn"
# >     print(subcadena)
# > ```
# > ---
# >
# > 4. **Verificar si una subcadena está dentro de una cadena**
# >    Se usa el operador `in` para comprobar si una subcadena está presente.
# >
# > ---
# > ```python
# >     texto = "Python es genial"
# >     print("Python" in texto)  # True
# >     print("Java" in texto)  # False
# > ```
# > ---
# >
# > 5. **Encontrar la posición de una subcadena**
# >    Se usa `.find()` para obtener el índice de la primera aparición de una subcadena.
# >
# > ---
# > ```python
# >     texto = "Python es genial"
# >     posicion = texto.find("es")
# >     print(posicion)  # Devuelve 7
# > ```
# > ---
# >
# > El manejo de subcadenas es esencial en Python para la manipulación de texto, búsqueda de patrones y procesamiento de datos. 🚀
# >
# > Si necesitas más ejemplos o quieres aplicarlo en tu cuaderno Jupyter, dime cómo puedo ayudarte. 😃

# %% [markdown]
# #### Capturar información por Consola en Python

# %% [markdown]
# > **Capturar información por Consola en Python**
# >
# > En Python, la función `input()` permite solicitar datos al usuario a través de la consola. La entrada siempre se almacena como una cadena (`str`), por lo que es necesario convertirla si se requiere otro tipo de dato.
# >
# > 1. **Capturar texto desde la consola**
# >    Se usa `input()` para recibir datos del usuario.
# >
# > ---
# > ```python
# >     nombre = input("¿Cuál es tu nombre? ")
# >     print(f"Hola, {nombre}!")
# > ```
# > ---
# >
# > 2. **Capturar números y convertirlos**
# >    Como `input()` devuelve una cadena, se debe convertir a `int` o `float` si se necesita un número.
# >
# > ---
# > ```python
# >     edad = int(input("¿Cuántos años tienes? "))
# >     print(f"Tienes {edad} años.")
# > ```
# > ---
# >
# > 3. **Capturar múltiples valores**
# >    Se pueden capturar varios valores separados por espacios y convertirlos en una lista.
# >
# > ---
# > ```python
# >     datos = input("Introduce tres números separados por espacios: ").split()
# >     numeros = [int(num) for num in datos]
# >     print(f"Números ingresados: {numeros}")
# > ```
# > ---
# >
# > 4. **Validar la entrada del usuario**
# >    Se puede verificar si la entrada es válida antes de procesarla.
# >
# > ---
# > ```python
# >     entrada = input("Introduce un número: ")
# >     if entrada.isdigit():
# >         numero = int(entrada)
# >         print(f"Has ingresado el número {numero}.")
# >     else:
# >         print("Entrada inválida, por favor ingresa un número.")
# > ```
# > ---
# >
# > Capturar información por consola es esencial en Python para interactuar con el usuario y procesar datos dinámicamente. 🚀
# >
# > Si necesitas más ejemplos o quieres aplicarlo en tu cuaderno Jupyter, dime cómo puedo ayudarte. 😃

# %% [markdown]
# #### Ejercicio Propuesto - Preséntate con Python (Nuevva versión)

# %% [markdown]
# > **Preséntate**
# >
# > Crea un programa para solicitar al usuario que proporcione por consola la siguiente información:
# >
# > - **Nombre**
# > - **Edad** (como un valor de tipo entero)
# > - **País**

# %% [markdown]
# ##### Respuesta

# %% [markdown]
# > **Programa: Preséntate en Python**
# >
# > Este programa solicita al usuario información básica a través de la consola y luego muestra un mensaje con los datos ingresados.
# >
# > ---
# > ```python
# >     # Solicitar datos al usuario
# >     nombre = input("¿Cuál es tu nombre? ")
# >     edad = int(input("¿Cuántos años tienes? "))
# >     pais = input("¿De qué país eres? ")
# >
# >     # Mostrar mensaje con los datos ingresados
# >     print(f"\nHola, {nombre}! Tienes {edad} años y eres de {pais}.")
# > ```
# > ---
# >
# > Este código captura información mediante `input()`, convierte la edad a un número entero y muestra el mensaje con los datos ingresados por el usuario. 🚀
# >
# > ¿Quieres agregar alguna funcionalidad extra, como validaciones o formatos de salida? 😃

# %% [markdown]
# ##### Solución propuesta

# %%
# Ejemplo para presentarte
print('*** Preséntate ***')
nombre = input('Ingresa tu nombre: ')
edad = int(input('Ingresa tu edad: '))
pais = input('Ingresa tu pais: ')
print('-----------------')
print(f'Nombre: {nombre}')
print(f'Edad: {edad}')
print(f'Pais: {pais}')
# Out:
# *** Preséntate ***
# Ingresa tu nombre:  Miguel
# Ingresa tu edad:  54
# Ingresa tu pais:  España
# -----------------
# Nombre: Miguel
# Edad: 54
# Pais: España

# %% [markdown]
# ### Sección 3: Operadores en Python

# %% [markdown]
# #### Operadores en Python

# %% [markdown]
# > **Operadores en Python**
# >
# > Los operadores en Python son símbolos que permiten realizar operaciones sobre valores y variables. Se clasifican en diferentes tipos según su función.
# >
# > 1. **Operadores aritméticos**
# >    Se utilizan para realizar cálculos matemáticos.
# >
# > ---
# > ```python
# >     a = 10
# >     b = 3
# >     print(a + b)  # Suma → 13
# >     print(a - b)  # Resta → 7
# >     print(a * b)  # Multiplicación → 30
# >     print(a / b)  # División → 3.3333
# >     print(a % b)  # Módulo → 1
# >     print(a ** b) # Potencia → 1000
# >     print(a // b) # División entera → 3
# > ```
# > ---
# >
# > 2. **Operadores de comparación**
# >    Comparan valores y devuelven `True` o `False`.
# >
# > ---
# > ```python
# >     x = 5
# >     y = 10
# >     print(x > y)  # False
# >     print(x < y)  # True
# >     print(x == y) # False
# >     print(x != y) # True
# >     print(x >= y) # False
# >     print(x <= y) # True
# > ```
# > ---
# >
# > 3. **Operadores lógicos**
# >    Se usan para combinar condiciones.
# >
# > ---
# > ```python
# >     a = True
# >     b = False
# >     print(a and b)  # False
# >     print(a or b)   # True
# >     print(not a)    # False
# > ```
# > ---
# >
# > 4. **Operadores de asignación**
# >    Asignan valores a variables.
# >
# > ---
# > ```python
# >     x = 10
# >     x += 5  # x = x + 5 → 15
# >     x -= 3  # x = x - 3 → 12
# >     x *= 2  # x = x * 2 → 24
# >     x /= 4  # x = x / 4 → 6.0
# > ```
# > ---
# >
# > 5. **Operadores de identidad**
# >    Comparan si dos objetos son el mismo en memoria.
# >
# > ---
# > ```python
# >     a = [1, 2, 3]
# >     b = a
# >     c = [1, 2, 3]
# >     print(a is b)  # True
# >     print(a is c)  # False
# >     print(a == c)  # True
# > ```
# > ---
# >
# > 6. **Operadores de pertenencia**
# >    Verifican si un valor está dentro de una secuencia.
# >
# > ---
# > ```python
# >     lista = [1, 2, 3, 4, 5]
# >     print(3 in lista)  # True
# >     print(6 not in lista)  # True
# > ```
# > ---
# >
# > Los operadores en Python son fundamentales para la manipulación de datos y la lógica de programación. 🚀
# >
# > Si necesitas más ejemplos o quieres aplicarlos en tu cuaderno Jupyter, dime cómo puedo ayudarte. 😃

# %% [markdown]
# #### Operadores de Asignación en Python

# %% [markdown]
# > **Operadores de Asignación en Python**
# >
# > Los operadores de asignación en Python permiten asignar valores a variables y realizar operaciones en una sola línea de código.
# >
# > 1. **Operador de asignación `=`**
# >    Asigna un valor a una variable.
# >
# > ---
# > ```python
# >     x = 10  # Asigna 10 a x
# > ```
# > ---
# >
# > 2. **Operadores de asignación compuestos**
# >    Combinan una operación matemática con la asignación.
# >
# > ---
# > ```python
# >     x = 10
# >     x += 5  # Equivalente a x = x + 5 → 15
# >     x -= 3  # Equivalente a x = x - 3 → 12
# >     x *= 2  # Equivalente a x = x * 2 → 24
# >     x /= 4  # Equivalente a x = x / 4 → 6.0
# > ```
# > ---
# >
# > 3. **Operadores de asignación con módulo y potencia**
# >    Permiten calcular el módulo y la potencia de una variable.
# >
# > ---
# > ```python
# >     x = 10
# >     x %= 3  # Equivalente a x = x % 3 → 1
# >     x **= 2 # Equivalente a x = x ** 2 → 100
# > ```
# > ---
# >
# > 4. **Operadores de asignación con división entera y desplazamiento de bits**
# >    Se usan para realizar divisiones enteras y operaciones con bits.
# >
# > ---
# > ```python
# >     x = 10
# >     x //= 3  # Equivalente a x = x // 3 → 3
# >     x <<= 2  # Equivalente a x = x << 2 → 40
# >     x >>= 1  # Equivalente a x = x >> 1 → 20
# > ```
# > ---
# >
# > Los operadores de asignación en Python optimizan el código y facilitan la manipulación de variables. 🚀
# >
# > Si necesitas más ejemplos o quieres aplicarlos en tu cuaderno Jupyter, dime cómo puedo ayudarte. 😃

# %% [markdown]
# #### Operadores de Asignación Compuesto en Python

# %% [markdown]
# > #### Operadores de asignación compuesto en Python
# >
# > Los operadores de asignación compuestos en Python permiten realizar una operación matemática y asignar el resultado a la misma variable en una sola línea de código.
# >
# > 1. **Suma y asignación (`+=`)**
# >    Suma el valor de la derecha a la variable y asigna el resultado.
# >
# > ---
# > ```python
# >     x = 10
# >     x += 5  # Equivalente a x = x + 5 → 15
# > ```
# > ---
# >
# > 2. **Resta y asignación (`-=`)**
# >    Resta el valor de la derecha a la variable y asigna el resultado.
# >
# > ---
# > ```python
# >     x = 20
# >     x -= 4  # Equivalente a x = x - 4 → 16
# > ```
# > ---
# >
# > 3. **Multiplicación y asignación (`*=`)**
# >    Multiplica la variable por el valor de la derecha y asigna el resultado.
# >
# > ---
# > ```python
# >     x = 5
# >     x *= 3  # Equivalente a x = x * 3 → 15
# > ```
# > ---
# >
# > 4. **División y asignación (`/=`)**
# >    Divide la variable por el valor de la derecha y asigna el resultado.
# >
# > ---
# > ```python
# >     x = 18
# >     x /= 3  # Equivalente a x = x / 3 → 6.0
# > ```
# > ---
# >
# > 5. **División entera y asignación (`//=`)**
# >    Realiza una división entera y asigna el resultado.
# >
# > ---
# > ```python
# >     x = 20
# >     x //= 3  # Equivalente a x = x // 3 → 6
# > ```
# > ---
# >
# > 6. **Módulo y asignación (`%=`)**
# >    Calcula el módulo y asigna el resultado.
# >
# > ---
# > ```python
# >     x = 10
# >     x %= 4  # Equivalente a x = x % 4 → 2
# > ```
# > ---
# >
# > 7. **Potencia y asignación (`**=`)**
# >    Eleva la variable a la potencia del valor de la derecha y asigna el resultado.
# >
# > ---
# > ```python
# >     x = 2
# >     x **= 3  # Equivalente a x = x ** 3 → 8
# > ```
# > ---
# >
# > 8. **Operadores de desplazamiento de bits (`<<=`, `>>=`)**
# >    Desplazan los bits de la variable a la izquierda o derecha.
# >
# > ---
# > ```python
# >     x = 4
# >     x <<= 2  # Equivalente a x = x << 2 → 16
# >     x >>= 1  # Equivalente a x = x >> 1 → 8
# > ```
# > ---
# >
# > Los operadores de asignación compuestos optimizan el código y facilitan la manipulación de variables en Python. 🚀
# >
# > Si necesitas más ejemplos o quieres aplicarlos en tu cuaderno Jupyter, dime cómo puedo ayudarte. 😃

# %% [markdown]
# #### Operadores de Comparación en Python

# %% [markdown]
# > **Operadores de Comparación en Python**
# >
# > Los operadores de comparación en Python permiten comparar dos valores y determinar si son iguales, diferentes, mayores o menores. Devuelven un resultado booleano (`True` o `False`).
# >
# > 1. **Operador de Igualdad (`==`)**
# >    Verifica si dos valores son iguales.
# >
# > ---
# > ```python
# >     a = 5
# >     b = 5
# >     print(a == b)  # True, porque 5 es igual a 5
# > ```
# > ---
# >
# > 2. **Operador de Desigualdad (`!=`)**
# >    Verifica si dos valores son diferentes.
# >
# > ---
# > ```python
# >     a = 5
# >     b = 3
# >     print(a != b)  # True, porque 5 no es igual a 3
# > ```
# > ---
# >
# > 3. **Operador Mayor que (`>`)**
# >    Comprueba si el valor de la izquierda es mayor que el de la derecha.
# >
# > ---
# > ```python
# >     a = 10
# >     b = 5
# >     print(a > b)  # True, porque 10 es mayor que 5
# > ```
# > ---
# >
# > 4. **Operador Menor que (`<`)**
# >    Comprueba si el valor de la izquierda es menor que el de la derecha.
# >
# > ---
# > ```python
# >     a = 3
# >     b = 7
# >     print(a < b)  # True, porque 3 es menor que 7
# > ```
# > ---
# >
# > 5. **Operador Mayor o Igual que (`>=`)**
# >    Verifica si el valor de la izquierda es mayor o igual que el de la derecha.
# >
# > ---
# > ```python
# >     a = 10
# >     b = 10
# >     print(a >= b)  # True, porque 10 es igual a 10
# > ```
# > ---
# >
# > 6. **Operador Menor o Igual que (`<=`)**
# >    Verifica si el valor de la izquierda es menor o igual que el de la derecha.
# >
# > ---
# > ```python
# >     a = 5
# >     b = 7
# >     print(a <= b)  # True, porque 5 es menor que 7
# > ```
# > ---
# >
# > Los operadores de comparación son fundamentales en Python para evaluar condiciones en estructuras de control como `if`, `while` y `for`. 🚀
# >
# > Si necesitas más ejemplos o quieres aplicarlos en tu cuaderno Jupyter, dime cómo puedo ayudarte. 😃

# %% [markdown]
# #### Operador Lógico 'and' en Python

# %% [markdown]
# > **Operador Lógico 'and' en Python**
# >
# > El operador lógico `and` en Python se utiliza para evaluar si **dos condiciones son verdaderas**. Si ambas son `True`, el resultado será `True`; de lo contrario, será `False`.
# >
# > 1. **Ejemplo básico con valores booleanos**
# >    Se evalúan dos condiciones y se devuelve `True` solo si ambas son `True`.
# >
# > ---
# > ```python
# >     print(True and True)  # True
# >     print(True and False) # False
# >     print(False and True) # False
# >     print(False and False) # False
# > ```
# > ---
# >
# > 2. **Uso en estructuras condicionales**
# >    Se puede utilizar `and` para combinar múltiples condiciones en una sentencia `if`.
# >
# > ---
# > ```python
# >     edad = 25
# >     tiene_identificacion = True
# >
# >     if edad >= 18 and tiene_identificacion:
# >         print("Puedes ingresar.")
# >     else:
# >         print("Acceso denegado.")
# > ```
# > ---
# >
# > 3. **Evaluación de expresiones con `and`**
# >    Se pueden combinar múltiples condiciones en una sola expresión.
# >
# > ---
# > ```python
# >     a = 10
# >     b = 20
# >     c = 30
# >
# >     resultado = a < b and b < c
# >     print(resultado)  # True
# > ```
# > ---
# >
# > 4. **Precedencia del operador `and`**
# >    En expresiones con múltiples operadores, `and` tiene menor prioridad que `or`, pero mayor que `not`.
# >
# > ---
# > ```python
# >     print(True or False and False)  # True
# >     print(not False and True)  # True
# > ```
# > ---
# >
# > El operador `and` es fundamental en Python para evaluar condiciones compuestas y controlar el flujo de ejecución en programas. 🚀
# >
# > Si necesitas más ejemplos o quieres aplicarlo en tu cuaderno Jupyter, dime cómo puedo ayudarte. 😃

# %% [markdown]
# #### Ejercicio - Sistema de Descuentos VIP con Python

# %% [markdown]
# > **Sistema Descuentos VIP**
# >
# > Una tienda de supermercado ofrece un descuento especial a clientes que compran 10 o más artículos por día y además sean miembros de la tienda.
# >
# > El sistema debe solicitar al cliente que indique cuántos artículos ha comprado en el día y preguntarle si cuenta con la membresía de la tienda.
# >
# > En caso de haber comprado 10 o más productos y ser miembro de la tienda.

# %% [markdown]
# >
# > Este programa solicita información al usuario sobre la cantidad de productos comprados y si es miembro de la tienda. Luego verifica si cumple con los requisitos para recibir el descuento especial.
# >
# > ---
# > ```python
# >     # Solicitar datos al usuario
# >     productos = int(input("¿Cuántos productos has comprado hoy? "))
# >     membresia = input("¿Eres miembro de la tienda? (sí/no): ").strip().lower()
# >
# >     # Verificar si el usuario es elegible para el descuento
# >     if productos >= 10 and membresia == "sí":
# >         print("\n¡Felicidades! Has recibido el descuento VIP.")
# >     else:
# >         print("\nLo sentimos, no cumples con los requisitos para el descuento.")
# > ```
# > ---
# >
# > Este código utiliza `input()` para obtener los datos del usuario, convierte la respuesta a minúsculas y verifica si el usuario es elegible para el descuento. 🚀
# >
# > ¿Te gustaría agregar alguna funcionalidad adicional, como un porcentaje de descuento específico? 😃

# %% [markdown]
# ##### Solución propuesta

# %%
print('*** Sistema Descuentos VIP ***')

NO_PRODUCTOS_DESCUENTO = 10
cantidad_productos = int(input('Cuantos productos compraste hoy? '))
tiene_membresia = input('Cuentas con la membresia de la tienda (Si/No)? ')

es_elegible_descuento = (cantidad_productos >= NO_PRODUCTOS_DESCUENTO
                         and tiene_membresia.lower() == "si")

print(f'Tienes acceso al descuento VIP? {es_elegible_descuento}')
# Out:
# *** Sistema Descuentos VIP ***
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 4
#       1 print('*** Sistema Descuentos VIP ***')
#       3 NO_PRODUCTOS_DESCUENTO = 10
# ----> 4 cantidad_productos = int(input('Cuantos productos compraste hoy? '))
#       5 tiene_membresia = input('Cuentas con la membresia de la tienda (Si/No)? ')
#       7 es_elegible_descuento = (cantidad_productos >= NO_PRODUCTOS_DESCUENTO
#       8                          and tiene_membresia.lower() == "si")
#
# File /data/user/0/ru.iiec.pydroid3/files/aarch64-linux-android/lib/python3.13/site-packages/ipykernel/kernelbase.py:1282, in Kernel.raw_input(self, prompt)
#    1280     msg = "raw_input was called, but this frontend does not support input requests."
#    1281     raise StdinNotImplementedError(msg)
# -> 1282 return self._input_request(
#    1283     str(prompt),
# ...

# %% [markdown]
# #### Operador Lógico 'or' en Python

# %% [markdown]
# > **Operador Lógico 'or' en Python**
# >
# > El operador lógico `or` en Python se utiliza para evaluar si **al menos una de las condiciones es verdadera**. Si una de ellas es `True`, el resultado será `True`; solo será `False` si ambas condiciones son `False`.
# >
# > 1. **Ejemplo básico con valores booleanos**
# >    Se evalúan dos condiciones y se devuelve `True` si al menos una es `True`.
# >
# > ---
# > ```python
# >     print(True or True)  # True
# >     print(True or False) # True
# >     print(False or True) # True
# >     print(False or False) # False
# > ```
# > ---
# >
# > 2. **Uso en estructuras condicionales**
# >    Se puede utilizar `or` para combinar múltiples condiciones en una sentencia `if`.
# >
# > ---
# > ```python
# >     es_finde = True
# >     hace_buen_tiempo = False
# >
# >     if es_finde or hace_buen_tiempo:
# >         print("¡Vamos a salir!")
# >     else:
# >         print("Mejor quedarse en casa.")
# > ```
# > ---
# >
# > 3. **Evaluación de expresiones con `or`**
# >    Se pueden combinar múltiples condiciones en una sola expresión.
# >
# > ---
# > ```python
# >     edad = 16
# >     tiene_permiso = True
# >
# >     puede_conducir = edad >= 18 or tiene_permiso
# >     print(puede_conducir)  # True
# > ```
# > ---
# >
# > 4. **Precedencia del operador `or`**
# >    En expresiones con múltiples operadores, `or` tiene menor prioridad que `and`, pero mayor que `not`.
# >
# > ---
# > ```python
# >     print(True and False or True)  # True
# >     print(not False or False)  # True
# > ```
# > ---
# >
# > El operador `or` es fundamental en Python para evaluar condiciones compuestas y controlar el flujo de ejecución en programas. 🚀
# >
# > Si necesitas más ejemplos o quieres aplicarlo en tu cuaderno Jupyter, dime cómo puedo ayudarte. 😃

# %% [markdown]
# #### Ejercicio - Préstamo de libros con Python

# %% [markdown]
# > **Sistema Préstamo de Libros**
# >
# > Se pide crear un sistema para una biblioteca, la cual desea prestar libros si cumple con cualquiera de las siguientes condiciones.
# >
# > 1. El usuario tiene credencial de estudiante.
# > 2. El usuario vive a no más de 3km a la redonda.
# >
# > Si cumple con cualquiera de estas condiciones, se le puede prestar el libro.

# %% [markdown]
# > **Programa: Sistema Préstamo de Libros**
# >
# > Este programa solicita al usuario información sobre su credencial de estudiante y su distancia a la biblioteca, luego verifica si cumple con los requisitos para el préstamo de libros.
# >
# > ---
# > ```python
# >     # Solicitar datos al usuario
# >     tiene_credencial = input("¿Tienes credencial de estudiante? (sí/no): ").strip().lower()
# >     distancia = float(input("¿Cuántos kilómetros vives de la biblioteca? "))
# >
# >     # Verificar si el usuario es elegible para el préstamo
# >     if tiene_credencial == "sí" or distancia <= 3:
# >         print("\n¡Puedes solicitar el préstamo del libro!")
# >     else:
# >         print("\nLo sentimos, no cumples con los requisitos para el préstamo.")
# > ```
# > ---
# >
# > Este código permite ingresar los datos del usuario y aplicar la lógica con `or` para verificar si es elegible para el préstamo de libros. 🚀
# >
# > ¿Te gustaría agregar alguna mejora, como una validación adicional o una lista de libros disponibles? 😃

# %% [markdown]
# ##### Solución propuesta

# %%
print('*** Sistema Prestamo de Libros ***')

DISTANCIA_PERMITIDA_KM = 3
tiene_credencial = input('Cuentas con credencial de estudiante (Si/No)? ')
distancia_biblioteca_km = int(input('A cuantos km vives de la biblioteca? '))

es_elegible_prestamo = (tiene_credencial.lower() == 'si'
                        or distancia_biblioteca_km <= DISTANCIA_PERMITIDA_KM)

print(f'Eres elegible para prestamo de libros? {es_elegible_prestamo}')

# %% [markdown]
# #### Operador Lógico 'not' en Python

# %% [markdown]
# > **Operador Lógico 'not' en Python**
# >
# > El operador lógico `not` en Python se utiliza para **negar** una condición. Convierte `True` en `False` y `False` en `True`, lo que permite invertir el resultado de una expresión booleana.
# >
# > 1. **Ejemplo básico con valores booleanos**
# >    Se evalúa una condición y se devuelve el valor opuesto.
# >
# > ---
# > ```python
# >     print(not True)  # False
# >     print(not False) # True
# > ```
# > ---
# >
# > 2. **Uso en estructuras condicionales**
# >    Se puede utilizar `not` para verificar si una condición **no** se cumple.
# >
# > ---
# > ```python
# >     es_finde = False
# >
# >     if not es_finde:
# >         print("Hoy es día laboral.")
# >     else:
# >         print("Es fin de semana.")
# > ```
# > ---
# >
# > 3. **Negación de expresiones booleanas**
# >    Se pueden negar comparaciones para cambiar su resultado.
# >
# > ---
# > ```python
# >     edad = 16
# >     puede_conducir = edad >= 18
# >
# >     if not puede_conducir:
# >         print("No puedes conducir aún.")
# > ```
# > ---
# >
# > 4. **Uso combinado con otros operadores lógicos**
# >    Se puede combinar `not` con `and` y `or` para crear expresiones más complejas.
# >
# > ---
# > ```python
# >     es_dia = True
# >     es_noche = not es_dia  # False
# >
# >     tiene_permiso = False
# >     puede_entrar = not tiene_permiso or es_dia
# >     print(puede_entrar)  # True
# > ```
# > ---
# >
# > El operador `not` es útil para invertir condiciones y mejorar la lógica en Python. 🚀
# >
# > Si necesitas más ejemplos o quieres aplicarlo en tu cuaderno Jupyter, dime cómo puedo ayudarte. 😃

# %% [markdown]
# > **Generación de Ticket de Venta**
# >
# > Supongamos que compramos varios artículos en el supermercado y queremos obtener el ticket de venta total, incluyendo impuestos.
# >
# > El sistema solicitará el precio de cada producto a comprar y el usuario deberá indicar su precio (valor decimal).
# >
# > El sistema debe realizar la suma de cada producto, calcular el impuesto y finalmente imprimir el total de la compra.

# %% [markdown]
# > **Programa: Generación de Ticket de Venta**
# >
# > Este programa solicita los precios de los productos comprados y calcula el total con impuestos.
# >
# > ---
# > ```python
# >     # Definir tasa de impuesto
# >     IMPUESTO = 0.08  # 8% de impuesto
# >
# >     # Solicitar precios al usuario
# >     precios = []
# >     while True:
# >         entrada = input("Introduce el precio del producto (o escribe 'fin' para terminar): ").strip().lower()
# >         if entrada == "fin":
# >             break
# >         try:
# >             precio = float(entrada)
# >             precios.append(precio)
# >         except ValueError:
# >             print("Por favor, ingresa un número válido.")
# >
# >     # Calcular total y impuestos
# >     subtotal = sum(precios)
# >     total_impuesto = subtotal * IMPUESTO
# >     total_pago = subtotal + total_impuesto
# >
# >     # Mostrar resultados
# >     print("\n--- Ticket de Venta ---")
# >     print(f"Subtotal: ${subtotal:.2f}")
# >     print(f"Impuesto (8%): ${total_impuesto:.2f}")
# >     print(f"Total a pagar: ${total_pago:.2f}")
# > ```
# > ---
# >
# > Este código permite ingresar los precios de los productos, calcular el subtotal, aplicar el impuesto del 8% y mostrar el total de la compra. 🚀
# >
# > ¿Te gustaría añadir una funcionalidad extra, como categorías de productos o descuentos especiales? 😃

# %% [markdown]
# ##### Solución propuesta

# %%
# Total de la compra en el supermercado

print('*** Generacion Ticket de Venta ***')
precio_leche = float(input('Precio leche: '))
precio_pan = float(input('Precio pan: '))
precio_lechuga = float(input('Precio lechuga: '))
precio_platanos = float(input('Precio platanos: '))

# Calculo del subtotal (sin impuestos)
subtotal = precio_leche + precio_pan + precio_lechuga + precio_platanos

# Calculo con impuesto (16%)
impuesto = subtotal * 0.16

# Calculo total de la compra (con impuestos)
costo_total_compra = subtotal + impuesto
print(f'''
Subtotal: ${subtotal:.2f}
Impuesto (16%): ${impuesto:.2f}
Costo total de la compra: ${costo_total_compra:.2f}''')

# %% [markdown]
# #### Precedencia de Operadores en Python

# %% [markdown]
# > **Precedencia de Operadores en Python**
# >
# > La **precedencia de operadores** en Python determina el orden en que se evalúan las expresiones con múltiples operadores. Algunos operadores tienen mayor precedencia que otros, lo que significa que se evalúan primero.
# >
# > 1. **Orden de precedencia de operadores**
# >    Python evalúa los operadores en el siguiente orden, de mayor a menor precedencia:
# >
# > ---
# > ```python
# >     # Ejemplo de precedencia
# >     resultado = 2 + 3 * 4 ** 2
# >     print(resultado)  # 50
# > ```
# > ---
# >
# > 2. **Lista de operadores en orden de precedencia**
# >    - **Exponentes (`**`)** → Se evalúan primero.
# >    - **Operadores unarios (`+`, `-`, `~`)** → Se aplican después.
# >    - **Multiplicación, División, Módulo y División Entera (`*`, `/`, `//`, `%`)**.
# >    - **Suma y Resta (`+`, `-`)**.
# >    - **Operadores de desplazamiento (`<<`, `>>`)**.
# >    - **Operadores de bit a bit (`&`, `^`, `|`)**.
# >    - **Operadores de comparación (`<`, `<=`, `>`, `>=`, `==`, `!=`)**.
# >    - **Operadores de pertenencia (`in`, `not in`) y de identidad (`is`, `is not`)**.
# >    - **Operadores lógicos (`not`, `and`, `or`)** → Se evalúan al final.
# >
# > ---
# > ```python
# >     # Ejemplo con paréntesis para cambiar la precedencia
# >     resultado = (2 + 3) * 4 ** 2
# >     print(resultado)  # 80
# > ```
# > ---
# >
# > 3. **Uso de paréntesis para modificar la precedencia**
# >    Se pueden usar paréntesis para cambiar el orden de evaluación.
# >
# > ---
# > ```python
# >     resultado = (5 + 2) * 3
# >     print(resultado)  # 21
# > ```
# > ---
# >
# > Comprender la **precedencia de operadores** es fundamental para evitar resultados inesperados en cálculos y expresiones en Python. 🚀
# >
# > Si necesitas más ejemplos o quieres aplicarlo en tu cuaderno Jupyter, dime cómo puedo ayudarte. 😃

# %% [markdown]
# > **Valor Dentro de Rango**
# >
# > Solicitar al usuario un valor entre 0 y 5 e indicarle si el valor proporcionado está dentro del rango.
# >
# > Se deben definir 2 constantes:
# > - `VALOR_MINIMO = 0`
# > - `VALOR_MAXIMO = 5`
# >
# > Y debemos comprobar si el valor proporcionado se encuentra en el rango entre `0` y `5`.
# >
# > Finalmente, se debe imprimir: **Valor dentro de rango: True/False**

# %% [markdown]
# > **Programa: Comprobación de Valor en Rango**
# >
# > Este programa solicita un valor al usuario y verifica si está dentro del rango definido.
# >
# > ---
# > ```python
# >     # Definir constantes
# >     VALOR_MINIMO = 0
# >     VALOR_MAXIMO = 5
# >
# >     # Solicitar un número al usuario
# >     valor = int(input("Introduce un número entre 0 y 5: "))
# >
# >     # Comprobar si el número está dentro del rango
# >     en_rango = VALOR_MINIMO <= valor <= VALOR_MAXIMO
# >
# >     # Mostrar resultado
# >     print(f"\nValor dentro de rango: {en_rango}")
# > ```
# > ---
# >
# > Este código define los límites mínimos y máximos, solicita un número al usuario y verifica si está dentro del rango usando una comparación lógica. 🚀
# >
# > ¿Te gustaría agregar algún mensaje adicional en caso de que el valor esté fuera del rango? 😃

# %% [markdown]
# ##### Solución Propuesta

# %%
print('*** Valor Dentro Rango ***')
# Condiciones
MINIMO = 0
MAXIMO = 5

# Solicitamos un valor entre 0 y 5
dato = int(input('Proporciona un dato entre 0 y 5: '))

# Verificamos si estamos dentro de rango
#dentro_rango = dato >= MINIMO and dato <= MAXIMO
dentro_rango = MINIMO <= dato <= MAXIMO
print(f'Valor dentro de rango? {dentro_rango}')

# %% [markdown]
# ### Sección 4: Sentencias de decisión

# %% [markdown]
# #### Sentencias de decisión en Python

# %% [markdown]
# > **Sentencias de Decisión en Python**
# >
# > Las **sentencias de decisión** en Python permiten ejecutar diferentes bloques de código según condiciones específicas. Se utilizan para controlar el flujo del programa y tomar decisiones basadas en valores o expresiones booleanas.
# >
# > 1. **Sentencia `if`**
# >    Ejecuta un bloque de código si la condición es verdadera.
# >
# > ---
# > ```python
# >     edad = 18
# >     if edad >= 18:
# >         print("Eres mayor de edad.")
# > ```
# > ---
# >
# > 2. **Sentencia `if-else`**
# >    Define un bloque alternativo si la condición es falsa.
# >
# > ---
# > ```python
# >     edad = 16
# >     if edad >= 18:
# >         print("Eres mayor de edad.")
# >     else:
# >         print("Eres menor de edad.")
# > ```
# > ---
# >
# > 3. **Sentencia `if-elif-else`**
# >    Permite evaluar múltiples condiciones en secuencia.
# >
# > ---
# > ```python
# >     temperatura = 25
# >     if temperatura > 30:
# >         print("Hace mucho calor.")
# >     elif temperatura > 20:
# >         print("El clima es agradable.")
# >     else:
# >         print("Hace frío.")
# > ```
# > ---
# >
# > 4. **Sentencias de decisión anidadas**
# >    Se pueden incluir estructuras `if` dentro de otras para evaluar condiciones más complejas.
# >
# > ---
# > ```python
# >     edad = 20
# >     tiene_identificacion = True
# >
# >     if edad >= 18:
# >         if tiene_identificacion:
# >             print("Puedes ingresar.")
# >         else:
# >             print("Necesitas identificación.")
# >     else:
# >         print("Eres menor de edad.")
# > ```
# > ---
# >
# > Las **sentencias de decisión** son esenciales para la lógica de programación en Python, permitiendo ejecutar acciones según condiciones específicas. 🚀
# >
# > Si necesitas más ejemplos o quieres aplicarlos en tu cuaderno Jupyter, dime cómo puedo ayudarte. 😃

# %% [markdown]
# #### Sentencia 'if-else' en Python

# %% [markdown]
# > **Sentencia 'if-else' en Python**
# >
# > La sentencia `if-else` en Python permite ejecutar un bloque de código si una condición es verdadera y otro bloque alternativo si la condición es falsa.
# >
# > 1. **Sintaxis básica de `if-else`**
# >    Se evalúa una condición y se ejecuta el bloque correspondiente.
# >
# > ---
# > ```python
# >     edad = 18
# >     if edad >= 18:
# >         print("Eres mayor de edad.")
# >     else:
# >         print("Eres menor de edad.")
# > ```
# > ---
# >
# > 2. **Uso de `if-else` con múltiples condiciones**
# >    Se pueden combinar varias condiciones dentro de la estructura.
# >
# > ---
# > ```python
# >     temperatura = 25
# >     if temperatura > 30:
# >         print("Hace mucho calor.")
# >     else:
# >         print("El clima es agradable o frío.")
# > ```
# > ---
# >
# > 3. **Sentencias `if-else` anidadas**
# >    Se pueden incluir estructuras `if` dentro de otras para evaluar condiciones más complejas.
# >
# > ---
# > ```python
# >     edad = 20
# >     tiene_identificacion = True
# >
# >     if edad >= 18:
# >         if tiene_identificacion:
# >             print("Puedes ingresar.")
# >         else:
# >             print("Necesitas identificación.")
# >     else:
# >         print("Eres menor de edad.")
# > ```
# > ---
# >
# > La sentencia `if-else` es fundamental en Python para la toma de decisiones y el control del flujo del programa. 🚀
# >
# > Si necesitas más ejemplos o quieres aplicarlos en tu cuaderno Jupyter, dime cómo puedo ayudarte. 😃

# %% [markdown]
# #### Sentencia 'if-elif-else' en Python

# %% [markdown]
# > **Sentencia 'if-elif-else' en Python**
# >
# > La sentencia `if-elif-else` en Python permite evaluar múltiples condiciones en secuencia. Se ejecuta el primer bloque de código cuya condición sea verdadera y, si ninguna lo es, se ejecuta el bloque `else`.
# >
# > 1. **Sintaxis básica de `if-elif-else`**
# >    Se evalúan varias condiciones en orden.
# >
# > ---
# > ```python
# >     temperatura = 25
# >     if temperatura > 30:
# >         print("Hace mucho calor.")
# >     elif temperatura > 20:
# >         print("El clima es agradable.")
# >     else:
# >         print("Hace frío.")
# > ```
# > ---
# >
# > 2. **Uso de `if-elif-else` con múltiples condiciones**
# >    Se pueden combinar varias verificaciones dentro de la estructura.
# >
# > ---
# > ```python
# >     nota = 85
# >     if nota >= 90:
# >         print("Excelente")
# >     elif nota >= 80:
# >         print("Muy bien")
# >     elif nota >= 70:
# >         print("Bien")
# >     else:
# >         print("Necesitas mejorar")
# > ```
# > ---
# >
# > 3. **Sentencias `if-elif-else` anidadas**
# >    Se pueden incluir estructuras `if` dentro de otras para evaluar condiciones más complejas.
# >
# > ---
# > ```python
# >     edad = 20
# >     tiene_identificacion = True
# >
# >     if edad >= 18:
# >         if tiene_identificacion:
# >             print("Puedes ingresar.")
# >         else:
# >             print("Necesitas identificación.")
# >     else:
# >         print("Eres menor de edad.")
# > ```
# > ---
# >
# > La sentencia `if-elif-else` es fundamental en Python para la toma de decisiones y el control del flujo del programa. 🚀
# >
# > Si necesitas más ejemplos o quieres aplicarlos en tu cuaderno Jupyter, dime cómo puedo ayudarte. 😃

# %% [markdown]
# #### Ejercicio Propuesto - Sistema de Descuentos de una Tienda en Línea

# %% [markdown]
# > **Sistema de Descuentos en una Tienda en Línea**
# >
# > Crear un sistema que ofrezca **descuentos** dependiendo del monto de la compra, o si el cliente es **miembro** de la tienda.
# >
# > Se deben revisar las siguientes condiciones:
#
# > Si ha comprado más de **$1,000** y es miembro → **Descuento de 10%**.
#
# > Si solo es miembro de la tienda → **Descuento de 5%**.
#
# > Si no es miembro ni compró mas de **$1,000**  → **Descuento del 0%**

# %% [markdown]
# > **Programa: Sistema de Descuentos en Tienda**
# >
# > Este programa solicita al usuario el monto de su compra y si es miembro de la tienda, luego calcula el descuento correspondiente.
# >
# > ---
# > ```python
# > # Solicitar datos al usuario
# > monto = float(input("Introduce el monto total de tu compra: "))
# > es_miembro = input("¿Eres miembro de la tienda? (sí/no): ").strip().lower()
# >
# > # Determinar el descuento
# > if monto > 1000 and es_miembro == "sí":
# >     descuento = 0.10  # 10% de descuento
# > elif es_miembro == "sí":
# >     descuento = 0.05  # 5% de descuento
# > else:
# >     descuento = 0.00  # Sin descuento
# >
# > # Calcular total con descuento
# > monto_descuento = monto * descuento
# > monto_final = monto - monto_descuento
# >
# > # Mostrar resultados
# > print("\n--- Ticket de Compra ---")
# > print(f"Subtotal: ${monto:.2f}")
# > print(f"Descuento aplicado: ${monto_descuento:.2f}")
# > print(f"Total a pagar: ${monto_final:.2f}")
# > ```
# > ---
# >
# > Este código solicita la compra y la membresía del usuario, determina el descuento según las condiciones dadas y calcula el total final. 🚀
# >
# > ¿Te gustaría agregar alguna funcionalidad adicional, como categorías de productos o niveles de membresía? 😃

# %%
print('*** Sistema de Descuentos ***')

# Condiciones
MONTO_COMPRA_DESC = 1000

monto_compra = float(input('Cual fue el monto de tu compra? '))
es_miembro = input('Eres miembro de la tienda (si/no)? ')

descuento = 0
# Verificar los datos del cliente
if monto_compra >= MONTO_COMPRA_DESC and es_miembro.lower() == 'si':
    descuento = 0.1 # Descuento del 10%
elif es_miembro.lower() == 'si':
    descuento = .05 # Descuento del 5%
elif monto_compra >= MONTO_COMPRA_DESC:
    descuento = .03 # Descuento del 3%
else:
    descuento = 0

# Hacemos los calculos respectivos
if descuento != 0:
    monto_descuento = monto_compra * descuento
    monto_final = monto_compra - monto_descuento
    print(f'\nFelicidades, has obtenido un descuento del {descuento * 100:.0f}%')
    print(f'Monto de la compra: ${monto_compra:.2f}')
    print(f'Monto del descuento: ${monto_descuento:.2f}')
    print(f'Monto final de la compra con descuento: ${monto_final:.2f}')
else:
    print(f'\nNo obtuviste ningún tipo de descuento')
    print(f'Te invitamos a hacerte miembro de la tienda')
    print(f'Monto final de la compra: ${monto_compra:.2f}')

# %% [markdown]
# #### Operador Ternario en Python

# %% [markdown]
# > **Operador Ternario en Python**
# >
# > El **operador ternario** en Python permite evaluar una condición en una sola línea de código, simplificando la estructura `if-else`. Su sintaxis es:
# >
# > ---
# > ```python
# > resultado = valor_si_verdadero if condicion else valor_si_falso
# > ```
# > ---
# >
# > 1. **Ejemplo básico**
# >    Evalúa una condición y asigna un resultado según sea `True` o `False`.
# >
# > ---
# > ```python
# > edad = 20
# > mensaje = "Mayor de edad" if edad >= 18 else "Menor de edad"
# > print(mensaje)  # "Mayor de edad"
# > ```
# > ---
# >
# > 2. **Uso con funciones**
# >    Se puede utilizar dentro de funciones para retornar valores.
# >
# > ---
# > ```python
# > def verificar_par(numero):
# >     return "Par" if numero % 2 == 0 else "Impar"
# >
# > print(verificar_par(7))  # "Impar"
# > ```
# > ---
# >
# > 3. **Anidación de operadores ternarios**
# >    Se pueden encadenar múltiples condiciones dentro de una misma expresión.
# >
# > ---
# > ```python
# > nota = 85
# > estado = "Excelente" if nota >= 90 else "Bueno" if nota >= 80 else "Regular"
# > print(estado)  # "Bueno"
# > ```
# > ---
# >
# > El operador ternario es útil para escribir código más compacto y legible, aunque debe usarse con moderación para evitar expresiones difíciles de entender. 🚀
# >
# > Si necesitas más ejemplos o quieres aplicarlo en tu cuaderno Jupyter, dime cómo puedo ayudarte. 😃

# %% [markdown]
# #### Ejercicio Propuesto - Estación del año con Python

# %% [markdown]
# > **Identifica la Estación del Año**
# >
# > Se solicita proporcionar el valor de un mes (valor numérico entre 1 y 12) e indicar la estación del año según lo siguiente:
# >
# > - **Meses 1, 2 o 12** → **Invierno**
# > - **Meses 3, 4 o 5** → **Primavera**
# > - **Meses 6, 7 u 8** → **Verano**
# > - **Meses 9, 10 u 11** → **Otoño**
# > - **Cualquier otro valor** → **Estación Desconocida**

# %% [markdown]
# > **Programa: Identifica la Estación del Año**
# >
# > Este programa solicita al usuario que introduzca un número de mes y determina la estación correspondiente.
# >
# > ---
# > ```python
# >     # Solicitar el mes al usuario
# >     mes = int(input("Introduce el número del mes (1-12): "))
# >
# >     # Determinar la estación del año
# >     if mes in [1, 2, 12]:
# >         estacion = "Invierno"
# >     elif mes in [3, 4, 5]:
# >         estacion = "Primavera"
# >     elif mes in [6, 7, 8]:
# >         estacion = "Verano"
# >     elif mes in [9, 10, 11]:
# >         estacion = "Otoño"
# >     else:
# >         estacion = "Estación desconocida"
# >
# >     # Mostrar resultado
# >     print(f"\nLa estación del año correspondiente es: {estacion}")
# > ```
# > ---
# >
# > Este código permite ingresar un número de mes y determina la estación del año correspondiente, asegurando que los valores estén dentro del rango válido. 🚀
# >
# > ¿Te gustaría agregar una funcionalidad adicional, como validaciones o mensajes personalizados? 😃

# %% [markdown]
# ##### Solución Propuesta

# %%
print('*** Estacion del Año ***')

mes = int(input('Proporciona el valor del mes (1-12): '))
estacion = ''
# Revision del mes proporcionado
if mes == 1 or mes == 2 or mes == 12:
    estacion = 'Invierno'
elif mes == 3 or mes == 4 or mes == 5:
    estacion = 'Primavera'
elif mes == 6 or mes == 7 or mes == 8:
    estacion = 'Verano'
elif mes == 9 or mes == 10 or mes == 11:
    estacion = 'Otoño'
else:
    estacion = 'Estacion desconocida'
# Imprimimos el resultado
print(f'La estación para el mes {mes} es {estacion}')

# %% [markdown]
# ### Sección 5: Ciclos en Python

# %% [markdown]
# #### Ciclos en Python

# %% [markdown]
# > **Ciclos en Python**
# >
# > Los **ciclos** en Python permiten repetir la ejecución de un bloque de código varias veces, lo que es útil para automatizar tareas repetitivas. Existen dos tipos principales de ciclos en Python:
# >
# > 1. **Ciclo `while`**
# >    Se ejecuta mientras una condición sea verdadera.
# >
# > ---
# > ```python
# >     contador = 1
# >     while contador <= 5:
# >         print(f"Iteración {contador}")
# >         contador += 1
# > ```
# > ---
# >
# > 2. **Ciclo `for`**
# >    Se usa para recorrer elementos de una secuencia como listas o rangos.
# >
# > ---
# > ```python
# >     for i in range(1, 6):
# >         print(f"Iteración {i}")
# > ```
# > ---
# >
# > 3. **Uso de `break` y `continue`**
# >    - `break`: Termina el ciclo antes de que se cumpla la condición.
# >    - `continue`: Salta la iteración actual y pasa a la siguiente.
# >
# > ---
# > ```python
# >     for i in range(1, 6):
# >         if i == 3:
# >             break  # Detiene el ciclo en la tercera iteración
# >         print(f"Iteración {i}")
# > ```
# > ---
# >
# > ---
# > ```python
# >     for i in range(1, 6):
# >         if i == 3:
# >             continue  # Salta la tercera iteración
# >         print(f"Iteración {i}")
# > ```
# > ---
# >
# > Los ciclos en Python son fundamentales para la programación eficiente y permiten automatizar procesos repetitivos. 🚀
# >
# > Si necesitas más ejemplos o quieres aplicarlos en tu cuaderno Jupyter, dime cómo puedo ayudarte. 😃

# %% [markdown]
# #### Imprimir Valores del 1 al 5 - ciclo while en Python

# %% [markdown]
# > **Imprimir Valores del 1 al 5 - ciclo while en Python**
# >
# > El ciclo `while` en Python permite ejecutar un bloque de código repetidamente mientras una condición sea verdadera. En este caso, imprimiremos los valores del **1 al 5** utilizando `while`.
# >
# > ---
# > ```python
# >     contador = 1
# >     while contador <= 5:
# >         print(contador)
# >         contador += 1
# > ```
# > ---
# >
# > 1. **Explicación del código:**
# >    - Se inicializa `contador` en `1`.
# >    - Se ejecuta el ciclo `while` mientras `contador` sea menor o igual a `5`.
# >    - En cada iteración, se imprime el valor de `contador` y luego se incrementa en `1`.
# >    - Cuando `contador` llega a `6`, la condición `contador <= 5` es falsa y el ciclo termina.
# >
# > ---
# > ```python
# >     # Salida esperada:
# >     1
# >     2
# >     3
# >     4
# >     5
# > ```
# > ---
# >
# > Este método es útil para recorrer rangos de números sin necesidad de usar `for`. 🚀
# >
# > ¿Te gustaría agregar alguna funcionalidad extra, como imprimir los números en orden inverso o con un paso diferente? 😃

# %% [markdown]
# ##### Solución Propuesta

# %%
print('*** Ciclo while ***')

# Imprimir los valores del 1 al 5
contador = 1
VALOR_MAXIMO = 5
while contador <= VALOR_MAXIMO:
    print(f'Contador: {contador}')
    contador += 1  # contador = contador + 1

# %% [markdown]
# #### Imprimir Valores del 1 al 5 - ciclo for en Python

# %% [markdown]
# > **Imprimir Valores del 1 al 5 - ciclo for en Python**
# >
# > El ciclo `for` en Python permite recorrer una secuencia de valores y ejecutar un bloque de código en cada iteración. En este caso, imprimiremos los valores del **1 al 5** utilizando `for`.
# >
# > ---
# > ```python
# >     for i in range(1, 6):
# >         print(i)
# > ```
# > ---
# >
# > 1. **Explicación del código:**
# >    - `range(1, 6)` genera los números del **1 al 5** (el límite superior `6` no se incluye).
# >    - En cada iteración, `i` toma un valor de la secuencia y se imprime con `print(i)`.
# >    - Cuando `i` llega a `5`, el ciclo termina.
# >
# > ---
# > ```python
# >     # Salida esperada:
# >     1
# >     2
# >     3
# >     4
# >     5
# > ```
# > ---
# >
# > Este método es útil para recorrer rangos de números de manera eficiente. 🚀
# >
# > ¿Te gustaría agregar alguna funcionalidad extra, como imprimir los números en orden inverso o con un paso diferente? 😃

# %%
print('*** Ciclo for ***')

# Imprimir del 1 al 5
for contador in range(1, 6): # 1 al 5
    print(contador)

# %% [markdown]
# #### Iterar una cadena en Python

# %% [markdown]
# > **Iterar una cadena en Python**
# >
# > En Python, se puede recorrer una cadena de caracteres utilizando un ciclo `for`, lo que permite acceder a cada carácter individualmente.
# >
# > 1. **Iteración básica con `for`**
# >    Se recorre la cadena carácter por carácter.
# >
# > ---
# > ```python
# >     texto = "Python"
# >     for caracter in texto:
# >         print(caracter)
# > ```
# > ---
# >
# > 2. **Iteración con índice**
# >    Se usa `range()` para acceder a cada carácter con su índice.
# >
# > ---
# > ```python
# >     texto = "Python"
# >     for i in range(len(texto)):
# >         print(f"Índice {i}: {texto[i]}")
# > ```
# > ---
# >
# > 3. **Iteración inversa**
# >    Se recorre la cadena en orden inverso.
# >
# > ---
# > ```python
# >     texto = "Python"
# >     for caracter in reversed(texto):
# >         print(caracter)
# > ```
# > ---
# >
# > 4. **Iteración con `enumerate()`**
# >    Se obtiene el índice y el carácter en cada iteración.
# >
# > ---
# > ```python
# >     texto = "Python"
# >     for i, caracter in enumerate(texto):
# >         print(f"Índice {i}: {caracter}")
# > ```
# > ---
# >
# > Iterar sobre una cadena en Python es útil para manipular texto y realizar operaciones sobre cada carácter. 🚀
# >
# > Si necesitas más ejemplos o quieres aplicarlo en tu cuaderno Jupyter, dime cómo puedo ayudarte. 😃

# %% [markdown]
# #### Ejecución Paso a Paso de un Ciclo While

# %% [markdown]
# > **Ejecución Paso a Paso de un Ciclo While**
# >
# > El **ciclo `while`** en Python permite ejecutar un bloque de código repetidamente mientras una condición sea verdadera. Aquí tienes una **ejecución paso a paso** de un ciclo `while`:
# >
# > 1. **Definir una variable de control**
# >    Antes de iniciar el ciclo, se define una variable que servirá como contador.
# >
# > ---
# > ```python
# > contador = 1
# > ```
# > ---
# >
# > 2. **Escribir la condición en `while`**
# >    El ciclo se ejecutará mientras la condición sea verdadera.
# >
# > ---
# > ```python
# > while contador <= 5:
# > ```
# > ---
# >
# > Esto significa que el código dentro del `while` se ejecutará mientras `contador` sea menor o igual a `5`.
# >
# > 3. **Ejecutar el bloque de código dentro del `while`**
# >    Dentro del ciclo, se imprime el valor de `contador`.
# >
# > ---
# > ```python
# > print(f"Iteración {contador}")
# > ```
# > ---
# >
# > 4. **Modificar la variable de control**
# >    Para evitar un **bucle infinito**, se incrementa el valor de `contador` en cada iteración.
# >
# > ---
# > ```python
# > contador += 1
# > ```
# > ---
# >
# > 5. **Código completo**
# >
# > ---
# > ```python
# > contador = 1
# >
# > while contador <= 5:
# >     print(f"Iteración {contador}")
# >     contador += 1
# > ```
# > ---
# >
# > 6. **Salida esperada**
# >
# > ---
# > ```plaintext
# > Iteración 1
# > Iteración 2
# > Iteración 3
# > Iteración 4
# > Iteración 5
# > ```
# > ---
# >
# > Este proceso garantiza que el ciclo se ejecute **cinco veces** y luego termine cuando `contador` sea **6**, ya que la condición `contador <= 5` será falsa. 🚀
# >
# > Si necesitas más ejemplos o quieres aplicarlo en tu cuaderno Jupyter, dime cómo puedo ayudarte. 😃

# %% [markdown]
# #### Suma acumulada en Python

# %% [markdown]
# > **Ejercicio Acumulador Suma**
# >
# > Realizar la suma de los primeros 5 números utilizando un ciclo `while`:
# >
# > ---
# > ```plaintext
# > 1 + 2 = 3
# > 3 + 3 = 6
# > 6 + 4 = 10
# > 10 + 5 = 15
# > ```
# > ---
# >
# > **Programa en Python: Suma Acumulada**
# >
# > ---
# > ```python
# >     # Inicializar variables
# >     acumulador = 0
# >     numero = 1
# >
# >     # Ejecutar ciclo while hasta el número 5
# >     while numero <= 5:
# >         acumulador += numero
# >         print(f"Suma acumulada: {acumulador}")
# >         numero += 1
# > ```
# > ---
# >
# > **Salida esperada:**
# >
# > ---
# > ```plaintext
# > Suma acumulada: 1
# > Suma acumulada: 3
# > Suma acumulada: 6
# > Suma acumulada: 10
# > Suma acumulada: 15
# > ```
# > ---
# >
# > Este programa utiliza un acumulador para realizar la suma progresiva de los números del `1` al `5`, asegurando una ejecución paso a paso dentro del `while`. 🚀
# >
# > ¿Quieres modificarlo para que sume más números o incluya validaciones adicionales? 😃

# %%
print('*** Suma Acumulada ***')

# Sumar los primeros 5 numeros
MAXIMO = 5
acumulador_suma = 0
numero = 1
while numero <= MAXIMO:
    # Imprimir lo que se va a sumar
    print(f'(acumulador_suma + numero) -> {acumulador_suma} + {numero}')
    # Ejecuta la suma iterativa o acumulada
    acumulador_suma += numero
    numero += 1
    # Imprimir el resultado parcial
    print(f'Suma parcial acumulada: {acumulador_suma}\n')

print(f'\nResultado suma acumulada: {acumulador_suma}')

# %% [markdown]
# #### Menú Iterativo en Python

# %% [markdown]
# > **Menú Iterativo en Python**
# >
# > Un **menú iterativo** en Python permite al usuario seleccionar opciones repetidamente hasta que decida salir. Se implementa comúnmente con un ciclo `while` y una estructura de control `if-elif-else`.
# >
# > ---
# > ```python
# >     while True:
# >         print("\n*** Sistema de Administración de Cuentas ***")
# >         print("1. Crear cuenta")
# >         print("2. Eliminar cuenta")
# >         print("3. Salir")
# >
# >         opcion = input("Escoge una opción: ")
# >
# >         if opcion == "1":
# >             print("Has seleccionado 'Crear cuenta'.")
# >         elif opcion == "2":
# >             print("Has seleccionado 'Eliminar cuenta'.")
# >         elif opcion == "3":
# >             print("Saliendo del sistema...")
# >             break
# >         else:
# >             print("Opción no válida. Inténtalo de nuevo.")
# > ```
# > ---
# >
# > **Explicación del código:**
# > - Se usa un ciclo `while True` para mantener el menú activo hasta que el usuario elija salir.
# > - Se muestran las opciones del menú en cada iteración.
# > - Se captura la opción del usuario con `input()`.
# > - Se usa `if-elif-else` para ejecutar la acción correspondiente.
# > - La opción `"3"` usa `break` para salir del ciclo.
# >
# > Este método es útil para sistemas interactivos como cajeros automáticos, gestión de cuentas o aplicaciones de administración. 🚀
# >
# > ¿Te gustaría agregar más opciones o mejorar la interfaz del menú? 😃

# %% [markdown]
# ##### Solución propuesta

# %%
print('*** Sistema de Administración de Cuentas ***')

salir = False
while not salir:
    print(f'''Menu:
    1. Crear cuenta
    2. Eliminar cuenta
    3. Salir''')
    opcion = int(input('Escoje una opción: '))
    if opcion == 1:
        print('Creando tu cuenta...\n')
    elif opcion == 2:
        print('Eliminando tu cuenta...\n')
    elif opcion == 3:
        print('Saliendo del sistema. Hasta pronto...\n')
        salir = True
    else:
        print('Opción inválida, selecciona otra opción...\n')

# %% [markdown]
# #### Ejercicio Propuesto - Cajero Automático en Python

# %% [markdown]
# > **Aplicación Cajero Automático**
# >
# > Se solicita crear una aplicación de **Cajero Automático** que permita al usuario realizar las siguientes operaciones:
# >
# > - **Depositar dinero**
# > - **Retirar dinero**
# > - **Consultar saldo**
# >
# > El saldo inicial del usuario puede ser **$1,000.00**.
# > Cuando el usuario **retira dinero**, se descuenta del saldo.
# > Cuando el usuario **depósita dinero**, se incrementa el saldo.

# %% [markdown]
# > **Programa: Cajero Automático en Python**
# >
# > Este programa permite realizar depósitos, retiros y consultar el saldo de una cuenta.
# >
# > ---
# > ```python
# > # Inicializar saldo
# > saldo = 1000.0
# >
# > while True:
# >     print("\n*** Cajero Automático ***")
# >     print("1. Depositar dinero")
# >     print("2. Retirar dinero")
# >     print("3. Consultar saldo")
# >     print("4. Salir")
# >
# >     opcion = input("Selecciona una opción: ")
# >
# >     if opcion == "1":
# >         monto = float(input("Introduce el monto a depositar: "))
# >         saldo += monto
# >         print(f"Depósito realizado. Saldo actual: ${saldo:.2f}")
# >
# >     elif opcion == "2":
# >         monto = float(input("Introduce el monto a retirar: "))
# >         if monto <= saldo:
# >             saldo -= monto
# >             print(f"Retiro realizado. Saldo actual: ${saldo:.2f}")
# >         else:
# >             print("Saldo insuficiente.")
# >
# >     elif opcion == "3":
# >         print(f"Tu saldo actual es: ${saldo:.2f}")
# >
# >     elif opcion == "4":
# >         print("Saliendo del sistema. ¡Hasta pronto!")
# >         break
# >
# >     else:
# >         print("Opción inválida. Inténtalo de nuevo.")
# > ```
# > ---
# >
# > **Explicación del código:**
# > - Se inicia con un saldo de `$1,000.00`.
# > - Se usa un **menú iterativo** para permitir al usuario interactuar con el cajero.
# > - Se usa `if-elif-else` para gestionar las opciones del usuario.
# > - Se valida el saldo antes de permitir un retiro.
# > - La opción `"4"` usa `break` para salir del sistema.
# >
# > 🚀 Con esta aplicación, el usuario puede gestionar su saldo de manera sencilla.
# >
# > ¿Te gustaría agregar más funcionalidades, como transferencia de saldo o historial de movimientos? 😃

# %%
# Inicializar saldo
saldo = 1000.0

while True:
    print("\n*** Cajero Automático ***")
    print("1. Depositar dinero")
    print("2. Retirar dinero")
    print("3. Consultar saldo")
    print("4. Salir")

    opcion = input("Selecciona una opción: ")

    if opcion == "1":
        monto = float(input("Introduce el monto a depositar: "))
        saldo += monto
        print(f"Depósito realizado. Saldo actual: ${saldo:.2f}")
    
    elif opcion == "2":
        monto = float(input("Introduce el monto a retirar: "))
        if monto <= saldo:
            saldo -= monto
            print(f"Retiro realizado. Saldo actual: ${saldo:.2f}")
        else:
            print("Saldo insuficiente.")
    
    elif opcion == "3":
        print(f"Tu saldo actual es: ${saldo:.2f}")
    
    elif opcion == "4":
        print("Saliendo del sistema. ¡Hasta pronto!")
        break
    
    else:
        print("Opción inválida. Inténtalo de nuevo.")

# %% [markdown]
# ##### Solución Propuesta

# %%
print('*** Aplicacion de Cajero Automático ***')

saldo = 1000 # saldo inicial
salir = False
while not salir:
    print(f'''Operaciones que puedes realizar:
    1. Consultar Saldo
    2. Retirar
    3. Despositar
    4. Salir''')
    opcion = int(input('Escoje una opción: '))
    if opcion == 1:
        print(f'Tu saldo actual es: ${saldo:.2f}\n')
    elif opcion == 2:
        retiro = float(input('Ingresa el monto a retirar: '))
        # Validacion
        if retiro <= saldo:
            saldo -= retiro  # saldo = saldo - retiro
            print(f'Tu nuevo saldo es: ${saldo:.2f}\n')
        else:
            print(f'No cuentas con el saldo suficiente. Saldo actual ${saldo:.2f}\n')
    elif opcion == 3:
        deposito = float(input('Ingresa el monto a depositar: '))
        saldo += deposito  # saldo = saldo + deposito
        print(f'Tu nuevo saldo es: ${saldo:.2f}\n')
    elif opcion == 4:
        print('Saliendo del cajero automático. Hasta pronto!')
        salir = True
    else:
        print('Opción inválida. Selecciona otra opción\n')

# %% [markdown]
# #### Ejemplo Validación de un formulario en Python

# %% [markdown]
# > **Ejemplo: Validación de un Formulario en Python con `while`**
# >
# > En Python, podemos utilizar un **ciclo `while`** para validar la entrada de datos en un formulario, asegurándonos de que el usuario ingrese información correcta antes de continuar.
# >
# > ---
# > ```python
# > while True:
# >     nombre = input("Introduce tu nombre: ").strip()
# >     if nombre.isalpha():
# >         break
# >     print("Error: El nombre solo debe contener letras.")
# >
# > while True:
# >     edad = input("Introduce tu edad: ").strip()
# >     if edad.isdigit() and int(edad) > 0:
# >         break
# >     print("Error: La edad debe ser un número positivo.")
# >
# > print(f"\nRegistro exitoso: Nombre: {nombre}, Edad: {edad}")
# > ```
# > ---
# >
# > **Explicación del código:**
# > - Se usa un **ciclo `while True`** para repetir la solicitud de datos hasta que el usuario ingrese valores válidos.
# > - Se valida que el **nombre** solo contenga letras con `.isalpha()`.
# > - Se verifica que la **edad** sea un número positivo con `.isdigit()` y `int(edad) > 0`.
# > - Se usa `break` para salir del ciclo cuando la entrada es correcta.
# >
# > 🚀 Este método es útil para formularios interactivos y garantiza que los datos ingresados sean válidos.
# >
# > ¿Te gustaría agregar más validaciones, como correo electrónico o número de teléfono? 😃

# %%
while True:
    nombre = input("Introduce tu nombre: ").strip()
    if nombre.isalpha():
        break
    print("Error: El nombre solo debe contener letras.")

while True:
    edad = input("Introduce tu edad: ").strip()
    if edad.isdigit() and int(edad) > 0:
        break
    print("Error: La edad debe ser un número positivo.")

print(f"\nRegistro exitoso: Nombre: {nombre}, Edad: {edad}")

# %% [markdown]
# #### Ejemplo ciclo for en Python

# %% [markdown]
# > **Ejemplo de Ciclo `for` en Python**
# >
# > El ciclo `for` en Python permite recorrer una secuencia de elementos y ejecutar un bloque de código para cada uno de ellos. Se usa comúnmente para iterar sobre listas, tuplas, cadenas y rangos numéricos.
# >
# > ---
# > ```python
# >     # Iterar sobre una lista
# >     frutas = ["Manzana", "Banana", "Cereza"]
# >     for fruta in frutas:
# >         print(fruta)
# > ```
# > ---
# >
# > **Salida esperada:**
# > ```
# > Manzana
# > Banana
# > Cereza
# > ```
# >
# > ---
# > ```python
# >     # Iterar sobre un rango de números
# >     for i in range(1, 6):
# >         print(f"Número: {i}")
# > ```
# > ---
# >
# > **Salida esperada:**
# > ```
# > Número: 1
# > Número: 2
# > Número: 3
# > Número: 4
# > Número: 5
# > ```
# >
# > ---
# > ```python
# >     # Iterar sobre una cadena de texto
# >     palabra = "Python"
# >     for letra in palabra:
# >         print(letra)
# > ```
# > ---
# >
# > **Salida esperada:**
# > ```
# > P
# > y
# > t
# > h
# > o
# > n
# > ```
# >
# > 🚀 El ciclo `for` es una herramienta poderosa para recorrer estructuras de datos en Python.
# >
# > ¿Te gustaría ver más ejemplos o aplicar el ciclo `for` en un problema específico? 😃

# %% [markdown]
# #### Ejercicio Propuesto - Dibujar Triángulo en Python

# %% [markdown]
# > **Ejercicio Propuesto - Dibujar Triángulo en Python usando `for` y asteriscos**
# >
# > Se solicita crear un programa en Python que dibuje un **triángulo de asteriscos** utilizando un **ciclo `for`**.
# >
# > ---
# > ```python
# > altura = int(input("Introduce la altura del triángulo: "))
# >
# > for i in range(1, altura + 1):
# >     print("*" * i)
# > ```
# > ---
# >
# > **Explicación del código:**
# > - Se solicita al usuario la **altura** del triángulo.
# > - Se usa un **ciclo `for`** para iterar desde `1` hasta la altura ingresada.
# > - En cada iteración, se imprime una cantidad de `*` igual al número de la iteración.
# >
# > **Ejemplo de salida para altura = 5:**
# >
# > ---
# > ```plaintext
# > *
# > **
# > ***
# > ****
# > *****
# > ```
# > ---
# >
# > 🚀 Este ejercicio es una excelente práctica para comprender el uso de ciclos `for` y la manipulación de cadenas en Python.
# >
# > ¿Te gustaría modificar el código para dibujar un triángulo invertido o centrado? 😃

# %% [markdown]
# > **Dibujar un Triángulo Equilátero en Python usando `for` y asteriscos**
# >
# > Se solicita crear un programa en Python que dibuje un **triángulo equilátero de asteriscos** utilizando un **ciclo `for`**.
# >
# > ---
# > ```python
# > altura = int(input("Introduce la altura del triángulo: "))
# >
# > for i in range(1, altura + 1):
# >     espacios = " " * (altura - i)
# >     asteriscos = "*" * (2 * i - 1)
# >     print(espacios + asteriscos)
# > ```
# > ---
# >
# > **Explicación del código:**
# > - Se solicita al usuario la **altura** del triángulo.
# > - Se usa un **ciclo `for`** para iterar desde `1` hasta la altura ingresada.
# > - Se calculan los **espacios** para centrar el triángulo.
# > - Se calculan los **asteriscos** para formar la figura.
# > - Se imprime la línea con espacios y asteriscos correctamente alineados.
# >
# > **Ejemplo de salida para altura = 5:**
# >
# > ---
# > ```plaintext
# >     *
# >    ***
# >   *****
# >  *******
# > *********
# > ```
# > ---
# >
# > 🚀 Este ejercicio es una excelente práctica para comprender el uso de ciclos `for`, manipulación de cadenas y alineación de texto en Python.
# >
# > ¿Te gustaría modificar el código para dibujar un triángulo invertido o agregar bordes adicionales? 😃

# %% [markdown]
# ##### Solución Propuesta

# %%
print('*** Dibujar Triángulo Simétrico ***')

numero_de_filas = int(input('Proporciona el número de filas: '))

# Iterar sobre cada fila del triángulo
for fila in range(1, numero_de_filas + 1):
    espacios_en_blanco = " " * (numero_de_filas - fila) # Calculo de la cantidad de espacios en blanco
    caracteres = '*' * (2 * fila - 1) # Calcular la cantidad de caracteres para la fila actual
    print(f'{espacios_en_blanco}{caracteres}') # Imprimiendo espacios y asteriscos

# %% [markdown]
# ### Sección 6: Colecciones en Python

# %% [markdown]
# #### Colecciones en Python

# %% [markdown]
# > **Colecciones en Python**
# >
# > En Python, las **colecciones** son estructuras de datos que permiten almacenar y manipular múltiples elementos bajo un mismo nombre. Existen varios tipos de colecciones, cada una con características específicas.
# >
# > ---
# > **1. Listas (`list`)**
# > Son colecciones ordenadas y mutables que permiten almacenar cualquier tipo de dato.
# >
# > ---
# > ```python
# > lista = ["Python", "Java", "C++"]
# > lista.append("JavaScript")  # Agregar un elemento
# > print(lista)  # ['Python', 'Java', 'C++', 'JavaScript']
# > ```
# > ---
# >
# > **2. Tuplas (`tuple`)**
# > Son colecciones ordenadas pero **inmutables**, lo que significa que no pueden modificarse después de su creación.
# >
# > ---
# > ```python
# > tupla = ("Python", "Java", "C++")
# > print(tupla[0])  # 'Python'
# > ```
# > ---
# >
# > **3. Diccionarios (`dict`)**
# > Son colecciones que almacenan pares clave-valor, permitiendo acceso rápido a los datos.
# >
# > ---
# > ```python
# > diccionario = {"nombre": "Python", "version": 3.10}
# > print(diccionario["nombre"])  # 'Python'
# > ```
# > ---
# >
# > **4. Conjuntos (`set`)**
# > Son colecciones **no ordenadas** y **sin elementos duplicados**.
# >
# > ---
# > ```python
# > conjunto = {"Python", "Java", "C++", "Python"}
# > print(conjunto)  # {'Python', 'Java', 'C++'}
# > ```
# > ---
# >
# > **5. Módulo `collections`**
# > Python ofrece el módulo `collections`, que proporciona estructuras avanzadas como `deque`, `Counter`, `OrderedDict`, entre otros.
# >
# > ---
# > ```python
# > from collections import Counter
# > lista = ["Python", "Java", "Python", "C++"]
# > contador = Counter(lista)
# > print(contador)  # Counter({'Python': 2, 'Java': 1, 'C++': 1})
# > ```
# > ---
# >
# > 🚀 Las colecciones en Python son fundamentales para la manipulación de datos y la optimización de código.
# >
# > ¿Te gustaría profundizar en alguna de estas estructuras o ver ejemplos más avanzados? 😃

# %% [markdown]
# #### Listas en Python

# %% [markdown]
# > **Listas en Python**
# >
# > Las **listas** en Python son estructuras de datos que permiten almacenar múltiples valores en un solo objeto. Son **ordenadas**, **mutables** y pueden contener elementos de diferentes tipos.
# >
# > ---
# > **1. Crear una lista en Python**
# > Se pueden definir listas con corchetes `[]` o usando la función `list()`.
# >
# > ---
# > ```python
# > lista1 = [1, 2, 3, 4, 5]
# > lista2 = list(("Python", "Java", "C++"))
# > print(lista1)  # [1, 2, 3, 4, 5]
# > print(lista2)  # ['Python', 'Java', 'C++']
# > ```
# > ---
# >
# > **2. Acceder a elementos de una lista**
# > Se pueden obtener elementos individuales usando índices.
# >
# > ---
# > ```python
# > lista = ["Python", "Java", "C++"]
# > print(lista[0])  # 'Python'
# > print(lista[-1])  # 'C++' (último elemento)
# > ```
# > ---
# >
# > **3. Modificar elementos de una lista**
# > Las listas son **mutables**, lo que significa que sus elementos pueden cambiarse.
# >
# > ---
# > ```python
# > lista = ["Python", "Java", "C++"]
# > lista[1] = "JavaScript"
# > print(lista)  # ['Python', 'JavaScript', 'C++']
# > ```
# > ---
# >
# > **4. Agregar y eliminar elementos**
# > Se pueden usar métodos como `append()`, `insert()`, `remove()` y `pop()`.
# >
# > ---
# > ```python
# > lista = ["Python", "Java"]
# > lista.append("C++")  # Agregar al final
# > lista.insert(1, "JavaScript")  # Insertar en posición específica
# > lista.remove("Java")  # Eliminar por valor
# > print(lista)  # ['Python', 'JavaScript', 'C++']
# > ```
# > ---
# >
# > **5. Iterar sobre una lista**
# > Se puede recorrer una lista con un ciclo `for`.
# >
# > ---
# > ```python
# > lista = ["Python", "Java", "C++"]
# > for lenguaje in lista:
# >     print(lenguaje)
# > ```
# > ---
# >
# > **6. Ordenar y invertir listas**
# > Se pueden usar `sort()` y `reverse()`.
# >
# > ---
# > ```python
# > lista = [3, 1, 4, 2]
# > lista.sort()  # Ordenar de menor a mayor
# > lista.reverse()  # Invertir el orden
# > print(lista)  # [4, 3, 2, 1]
# > ```
# > ---
# >
# > 🚀 Las listas en Python son una herramienta poderosa para almacenar y manipular datos.
# >
# > ¿Te gustaría ver ejemplos más avanzados o aprender sobre listas anidadas? 😃

# %%
print('*** Manejo de Listas ***')

mi_lista = [1, 2, 3, 4, 5]

# Accedemos a un elemento por indice
print(f'Accedemos al valor del indice 4: {mi_lista[4]}')
print(f'Accedemos al último indice de la lista: {mi_lista[-1]}')


# Modificamos el elemento de la lista
mi_lista[1] = 10
print(f'Modificamos el valor del indice 1: {mi_lista[1]}')

# Agregar un nuevo elemento al final de la lista
mi_lista.append(6)
print(mi_lista)

# Añadimos un elemento en un índice específico
mi_lista.insert(2, 10)

# Eliminar elementos de la lista
# Usando el metodo remove
mi_lista.remove(5)  # Remueve el elemento con el valor 5 (no es un indice, sino valor)
print(mi_lista)
# Removemos por indice
mi_lista.pop(1)  # Elimina el elemento con el indice 1 de la lista
print(mi_lista)
# Eliminamos usando la palabra del
del mi_lista[2]
print(mi_lista)

# Longitud de la lista
print(f'Largo de la lista: {len(mi_lista)}')

# Obtener una sublista
sublista = mi_lista[1:3] # obtiene na lista del indice 1 al 2 (no incluye el 3)
print(f'Sublista: {sublista}')

# %% [markdown]
# #### Iterar una lista en Python

# %% [markdown]
# > **Iterar una lista en Python**
# >
# > En Python, se pueden recorrer listas utilizando diferentes métodos, como `for`, `while` y funciones específicas.
# >
# > 1. **Iteración con `for`**
# >    Se recorre cada elemento de la lista directamente.
# >
# > ---
# > ```python
# > lista = ["Python", "Java", "C++"]
# > for elemento in lista:
# >     print(elemento)
# > ```
# > ---
# >
# > 2. **Iteración con `while`**
# >    Se usa un índice para recorrer la lista.
# >
# > ---
# > ```python
# > lista = ["Python", "Java", "C++"]
# > i = 0
# > while i < len(lista):
# >     print(lista[i])
# >     i += 1
# > ```
# > ---
# >
# > 3. **Iteración con `enumerate()`**
# >    Se obtiene el índice y el valor en cada iteración.
# >
# > ---
# > ```python
# > lista = ["Python", "Java", "C++"]
# > for i, elemento in enumerate(lista):
# >     print(f"Índice {i}: {elemento}")
# > ```
# > ---
# >
# > 4. **Iteración con `map()`**
# >    Se aplica una función a cada elemento de la lista.
# >
# > ---
# > ```python
# > lista = ["Python", "Java", "C++"]
# > def mostrar(elemento):
# >     print(f"Lenguaje: {elemento}")
# >
# > list(map(mostrar, lista))
# > ```
# > ---
# >
# > 🚀 Iterar listas en Python es fundamental para manipular datos de manera eficiente.
# >
# > ¿Te gustaría ver ejemplos más avanzados o aplicar la iteración en un problema específico? 😃

# %%
print('*** Manejo de Listas ***')

nombres = ['Karla', 'Juan', 'Laura']

for nombre in nombres:
    print(nombre)

lista_heterogenea = [100, True, 'Ivonne']

print()
for elemento in lista_heterogenea:
    print(elemento)

# %% [markdown]
# #### Ejercicio de un Playlist dinámico en Python

# %% [markdown]
# > **Ejercicio de un Playlist Dinámico en Python**
# >
# > Se solicita crear un programa en Python que permita gestionar una **playlist dinámica**, donde el usuario pueda **agregar, eliminar y mostrar canciones**.
# >
# > ---
# > ```python
# > # Inicializar la playlist como una lista vacía
# > playlist = []
# >
# > while True:
# >     print("\n*** Playlist Dinámica ***")
# >     print("1. Agregar canción")
# >     print("2. Eliminar canción")
# >     print("3. Mostrar playlist")
# >     print("4. Salir")
# >
# >     opcion = input("Selecciona una opción: ")
# >
# >     if opcion == "1":
# >         cancion = input("Introduce el nombre de la canción: ")
# >         playlist.append(cancion)
# >         print(f"Canción '{cancion}' agregada a la playlist.")
# >
# >     elif opcion == "2":
# >         cancion = input("Introduce el nombre de la canción a eliminar: ")
# >         if cancion in playlist:
# >             playlist.remove(cancion)
# >             print(f"Canción '{cancion}' eliminada de la playlist.")
# >         else:
# >             print("La canción no está en la playlist.")
# >
# >     elif opcion == "3":
# >         print("\nPlaylist actual:")
# >         if playlist:
# >             for i, cancion in enumerate(playlist, 1):
# >                 print(f"{i}. {cancion}")
# >         else:
# >             print("La playlist está vacía.")
# >
# >     elif opcion == "4":
# >         print("Saliendo del sistema. ¡Hasta pronto!")
# >         break
# >
# >     else:
# >         print("Opción inválida. Inténtalo de nuevo.")
# > ```
# > ---
# >
# > **Explicación del código:**
# > - Se usa una **lista** para almacenar las canciones de la playlist.
# > - Se usa un **menú iterativo** para permitir al usuario gestionar la playlist.
# > - Se usa `append()` para agregar canciones y `remove()` para eliminarlas.
# > - Se muestra la playlist con un ciclo `for`.
# > - La opción `"4"` usa `break` para salir del sistema.
# >
# > 🚀 Con esta aplicación, el usuario puede gestionar su playlist de manera sencilla.
# >
# > ¿Te gustaría agregar más funcionalidades, como ordenar las canciones o guardar la playlist en un archivo? 😃

# %%
# Inicializar la playlist como una lista vacía
playlist = []

while True:
    print("\n*** Playlist Dinámica ***")
    print("1. Agregar canción")
    print("2. Eliminar canción")
    print("3. Mostrar playlist")
    print("4. Salir")

    opcion = input("Selecciona una opción: ")

    if opcion == "1":
        cancion = input("Introduce el nombre de la canción: ")
        playlist.append(cancion)
        print(f"Canción '{cancion}' agregada a la playlist.")
    
    elif opcion == "2":
        cancion = input("Introduce el nombre de la canción a eliminar: ")
        if cancion in playlist:
            playlist.remove(cancion)
            print(f"Canción '{cancion}' eliminada de la playlist.")
        else:
            print("La canción no está en la playlist.")
    
    elif opcion == "3":
        print("\nPlaylist actual:")
        if playlist:
            for i, cancion in enumerate(playlist, 1):
                print(f"{i}. {cancion}")
        else:
            print("La playlist está vacía.")
     
    elif opcion == "4":
        print("Saliendo del sistema. ¡Hasta pronto!")
        break
    
    else:
        print("Opción inválida. Inténtalo de nuevo.")

# %%
print('*** Playlist ***')

# Aqui se define la lista
lista_reproduccion = []
numero_canciones = int(input('Cuantas canciones deseas agregar: '))

# Iteramos cada elemento de la lista para agregar un nuevo elemento
for indice in range(numero_canciones):
    cancion = input(f'Proporciona la cancion {indice + 1}: ')
    lista_reproduccion.append(cancion)

# Ordenar la lista en orden alfabetico en orden ascendente
lista_reproduccion.sort()
#lista_reproduccion.sort(reverse=True) # orden descendente

# Mostrar la lista de canciones
print(f'\n Lista de Reproducción en orden Alfabético: ')
for cancion in lista_reproduccion:
    print(f'- {cancion}')

#print(f'Lista de canciones: {lista_reproduccion}')

# %% [markdown]
# #### Tuplas en Python

# %% [markdown]
# > **Tuplas en Python**
# >
# > Las **tuplas** en Python son estructuras de datos similares a las listas, pero con la diferencia de que son **inmutables**, lo que significa que no pueden modificarse después de su creación.
# >
# > ---
# > **1. Crear una tupla en Python**
# > Se pueden definir tuplas con paréntesis `()` o usando la función `tuple()`.
# >
# > ---
# > ```python
# > tupla1 = (1, 2, 3, 4, 5)
# > tupla2 = tuple(["Python", "Java", "C++"])
# > print(tupla1)  # (1, 2, 3, 4, 5)
# > print(tupla2)  # ('Python', 'Java', 'C++')
# > ```
# > ---
# >
# > **2. Acceder a elementos de una tupla**
# > Se pueden obtener elementos individuales usando índices.
# >
# > ---
# > ```python
# > tupla = ("Python", "Java", "C++")
# > print(tupla[0])  # 'Python'
# > print(tupla[-1])  # 'C++' (último elemento)
# > ```
# > ---
# >
# > **3. Desempaquetado de tuplas**
# > Se pueden asignar los valores de una tupla a variables individuales.
# >
# > ---
# > ```python
# > tupla = ("Python", "Java", "C++")
# > lenguaje1, lenguaje2, lenguaje3 = tupla
# > print(lenguaje1)  # 'Python'
# > print(lenguaje2)  # 'Java'
# > print(lenguaje3)  # 'C++'
# > ```
# > ---
# >
# > **4. Métodos de las tuplas**
# > Aunque son inmutables, las tuplas tienen algunos métodos útiles.
# >
# > ---
# > ```python
# > tupla = (1, 2, 3, 1, 2, 1)
# > print(tupla.count(1))  # Cuenta cuántas veces aparece el número 1
# > print(tupla.index(3))  # Devuelve el índice donde se encuentra el número 3
# > ```
# > ---
# >
# > **5. Conversión entre listas y tuplas**
# > Se pueden convertir listas en tuplas y viceversa.
# >
# > ---
# > ```python
# > lista = [1, 2, 3]
# > tupla = tuple(lista)
# > print(tupla)  # (1, 2, 3)
# >
# > nueva_lista = list(tupla)
# > print(nueva_lista)  # [1, 2, 3]
# > ```
# > ---
# >
# > 🚀 Las tuplas en Python son útiles cuando se necesita almacenar datos que no deben cambiar.
# >
# > ¿Te gustaría ver ejemplos más avanzados o aprender sobre tuplas anidadas? 😃

# %%
print('*** Manejo de Tuplas ***')

mi_tupla = (1, 2, 3, 4, 5)
# Las siguientes operaciones no estan permitidas
# mi_tupla[1] = 10
# mi_tupla.append(6)

print(mi_tupla)

# Iteramos los elementos de una tupla
for elemento in mi_tupla:
    print(elemento)

# Crear una tupla para representar una coordenada x, y
coordenadas = (3, 5)

# Acceder a los elementos de la tupla
print(f'\nCoordenada x: {coordenadas[0]}')
print(f'Coordenada y: {coordenadas[1]}')

# Crear una tupla de solo un elemento (unitaria)
tupla_un_elemento = 10,  # si no se pone la coma, no es una tupla sino un tipo entero individual
# tupla_un_elemento. # observar lo que despliega 

tupla_anidada = (1, (2, 3), (4, 5))
print(tupla_anidada[1])  # Salida: (2, 3)

# %% [markdown]
# #### Desempaquetamiento (unpacking) de tuplas en Python

# %% [markdown]
# > **Desempaquetamiento (Unpacking) de Tuplas en Python**
# >
# > El **desempaquetamiento de tuplas** en Python permite asignar los valores de una tupla a múltiples variables de manera sencilla y eficiente.
# >
# > ---
# > **1. Desempaquetamiento básico**
# > Se asignan los valores de la tupla a variables individuales.
# >
# > ---
# > ```python
# > tupla = ("Python", "Java", "C++")
# > lenguaje1, lenguaje2, lenguaje3 = tupla
# > print(lenguaje1)  # 'Python'
# > print(lenguaje2)  # 'Java'
# > print(lenguaje3)  # 'C++'
# > ```
# > ---
# >
# > **2. Desempaquetamiento con `*` (capturar múltiples valores)**
# > Se usa `*` para capturar varios elementos en una lista.
# >
# > ---
# > ```python
# > tupla = ("Python", "Java", "C++", "JavaScript", "Ruby")
# > lenguaje1, lenguaje2, *otros = tupla
# > print(lenguaje1)  # 'Python'
# > print(lenguaje2)  # 'Java'
# > print(otros)  # ['C++', 'JavaScript', 'Ruby']
# > ```
# > ---
# >
# > **3. Desempaquetamiento en funciones**
# > Se puede usar en funciones para recibir múltiples valores.
# >
# > ---
# > ```python
# > def mostrar_datos(nombre, edad, ciudad):
# >     print(f"Nombre: {nombre}, Edad: {edad}, Ciudad: {ciudad}")
# >
# > datos = ("Miguel", 30, "Madrid")
# > mostrar_datos(*datos)
# > ```
# > ---
# >
# > **4. Desempaquetamiento con `enumerate()`**
# > Se usa `enumerate()` para obtener el índice y el valor de una tupla.
# >
# > ---
# > ```python
# > tupla = ("Python", "Java", "C++")
# > for i, lenguaje in enumerate(tupla):
# >     print(f"Índice {i}: {lenguaje}")
# > ```
# > ---
# >
# > 🚀 El desempaquetamiento de tuplas en Python es una técnica poderosa para simplificar el código y mejorar la legibilidad.
# >
# > ¿Te gustaría ver ejemplos más avanzados o aprender sobre desempaquetamiento en listas? 😃

# %%
print('*** Desempaquetado de Tuplas ***')  # unpacking

producto = ('P001', 'Camisa', 20.00)

# Desempaquetamos cada valor en variables independientes
id, descripcion, precio = producto

print(f'Tupla completa: {producto}')
# Valores independientes ya desempaquetados
print(f'Producto: id = {id}, descripcion = {descripcion}, precio = {precio}')

# %% [markdown]
# #### Combinación de Listas y Tuplas en Python

# %% [markdown]
# > **Combinación de Listas y Tuplas en Python**
# >
# > En Python, se pueden combinar **listas** y **tuplas** para aprovechar las ventajas de ambas estructuras de datos. Aquí tienes algunos ejemplos de cómo hacerlo:
# >
# > ---
# > **1. Convertir una tupla en lista**
# > Se puede transformar una tupla en una lista para modificar sus elementos.
# >
# > ---
# > ```python
# > tupla = (1, 2, 3)
# > lista = list(tupla)
# > lista.append(4)
# > print(lista)  # [1, 2, 3, 4]
# > ```
# > ---
# >
# > **2. Convertir una lista en tupla**
# > Se puede convertir una lista en tupla para hacerla inmutable.
# >
# > ---
# > ```python
# > lista = [1, 2, 3, 4]
# > tupla = tuple(lista)
# > print(tupla)  # (1, 2, 3, 4)
# > ```
# > ---
# >
# > **3. Mezclar listas y tuplas en una misma estructura**
# > Se pueden combinar listas y tuplas dentro de una lista o una tupla.
# >
# > ---
# > ```python
# > datos = [("Juan", 25), ("Ana", 30), ("Luis", 22)]
# > print(datos[0])  # ('Juan', 25)
# > print(datos[1][1])  # 30
# > ```
# > ---
# >
# > **4. Iterar sobre una lista de tuplas**
# > Se puede recorrer una lista que contiene tuplas.
# >
# > ---
# > ```python
# > datos = [("Juan", 25), ("Ana", 30), ("Luis", 22)]
# > for nombre, edad in datos:
# >     print(f"{nombre} tiene {edad} años.")
# > ```
# > ---
# >
# > **5. Unir listas y tuplas con `zip()`**
# > Se pueden combinar listas y tuplas con `zip()`.
# >
# > ---
# > ```python
# > nombres = ["Juan", "Ana", "Luis"]
# > edades = (25, 30, 22)
# > combinados = list(zip(nombres, edades))
# > print(combinados)  # [('Juan', 25), ('Ana', 30), ('Luis', 22)]
# > ```
# > ---
# >
# > 🚀 La combinación de listas y tuplas en Python permite estructurar datos de manera flexible y eficiente.
# >
# > ¿Te gustaría ver ejemplos más avanzados o aplicar esto en un problema específico? 😃

# %%
print('*** Combinación Listas y Tuplas ***')

# Definir una lista que almacena tuplas de productos
productos = [
    ('P001', 'Camiseta', 20.00),
    ('P002', 'Jeans', 30.00),
    ('P003', 'Sudadera', 40.00)
]

# Imprimimos la informacion de cada producto
# y calculamos el precio total
precio_total = 0

print(f'Información de los productos: ')
for producto in productos:
    #print(producto)
    id, descripcion, precio = producto  # unpacking
    print(f'Producto: id = {id}, descripcion = {descripcion}, precio = {precio}')
    precio_total += precio # producto[2] para obtener el precio

print(f'Precio total de los productos: {precio_total}')

# %% [markdown]
# #### Sets (conjuntos) en Python

# %% [markdown]
# > **Sets (Conjuntos) en Python**
# >
# > Los **sets** en Python son colecciones **no ordenadas** de elementos **únicos**, lo que significa que no permiten duplicados. Son útiles para operaciones matemáticas como **unión, intersección y diferencia**.
# >
# > ---
# > **1. Crear un set en Python**
# > Se pueden definir sets con llaves `{}` o usando la función `set()`.
# >
# > ---
# > ```python
# > conjunto1 = {1, 2, 3, 4, 5}
# > conjunto2 = set(["Python", "Java", "C++"])
# > print(conjunto1)  # {1, 2, 3, 4, 5}
# > print(conjunto2)  # {'Python', 'Java', 'C++'}
# > ```
# > ---
# >
# > **2. Agregar y eliminar elementos**
# > Se pueden usar `add()`, `remove()` y `discard()`.
# >
# > ---
# > ```python
# > conjunto = {1, 2, 3}
# > conjunto.add(4)  # Agregar un elemento
# > conjunto.remove(2)  # Eliminar un elemento
# > print(conjunto)  # {1, 3, 4}
# > ```
# > ---
# >
# > **3. Operaciones con sets**
# > Se pueden realizar operaciones matemáticas como unión, intersección y diferencia.
# >
# > ---
# > ```python
# > conjuntoA = {1, 2, 3, 4}
# > conjuntoB = {3, 4, 5, 6}
# >
# > print(conjuntoA | conjuntoB)  # Unión: {1, 2, 3, 4, 5, 6}
# > print(conjuntoA & conjuntoB)  # Intersección: {3, 4}
# > print(conjuntoA - conjuntoB)  # Diferencia: {1, 2}
# > ```
# > ---
# >
# > **4. Verificar pertenencia**
# > Se usa `in` para comprobar si un elemento está en el set.
# >
# > ---
# > ```python
# > conjunto = {1, 2, 3, 4}
# > print(2 in conjunto)  # True
# > print(5 in conjunto)  # False
# > ```
# > ---
# >
# > 🚀 Los sets en Python son ideales para eliminar duplicados y realizar operaciones matemáticas eficientes.
# >
# > ¿Te gustaría ver ejemplos más avanzados o aprender sobre conjuntos anidados? 😃

# %%
# Set (conjunto)

print('*** Manejo de Sets ***')

# Crear un conjunto
mi_set = {1, 2, 3, 4, 5, 4}

print(f'Mi set: {mi_set}')

# Agregar elementos al conjunto
mi_set.add(6)
mi_set.add(7)

# Intentar agregar un elemento duplicado
mi_set.add(3)

# Eliminar un elemento del conjunto
mi_set.remove(4)

print(f'Mi set: {mi_set}')

# Iterar los elementos del set
for elemento in mi_set:
    print(elemento, end=' ')

# Comprobar si existe un elemento en el set
print(f'\n{4 in mi_set}')

# Obtener la longitud
print(len(mi_set))

# %% [markdown]
# #### Ejercicio Boletín Informativo Dinámico en Python

# %% [markdown]
# > **Ejercicio: Boletín Informativo Dinámico usando Conjuntos en Python**
# >
# > Se solicita crear un programa en Python que permita gestionar un **boletín informativo**, donde el usuario pueda **agregar, eliminar y mostrar noticias** utilizando **conjuntos (`set`)**.
# >
# > ---
# > ```python
# > # Inicializar el boletín como un conjunto vacío
# > boletin = set()
# >
# > while True:
# >     print("\n*** Boletín Informativo ***")
# >     print("1. Agregar noticia")
# >     print("2. Eliminar noticia")
# >     print("3. Mostrar boletín")
# >     print("4. Salir")
# >
# >     opcion = input("Selecciona una opción: ")
# >
# >     if opcion == "1":
# >         noticia = input("Introduce la noticia: ")
# >         boletin.add(noticia)
# >         print(f"Noticia agregada: {noticia}")
# >
# >     elif opcion == "2":
# >         noticia = input("Introduce la noticia a eliminar: ")
# >         if noticia in boletin:
# >             boletin.remove(noticia)
# >             print(f"Noticia eliminada: {noticia}")
# >         else:
# >             print("La noticia no está en el boletín.")
# >
# >     elif opcion == "3":
# >         print("\nBoletín Informativo:")
# >         if boletin:
# >             for noticia in boletin:
# >                 print(f"- {noticia}")
# >         else:
# >             print("El boletín está vacío.")
# >
# >     elif opcion == "4":
# >         print("Saliendo del sistema. ¡Hasta pronto!")
# >         break
# >
# >     else:
# >         print("Opción inválida. Inténtalo de nuevo.")
# > ```
# > ---
# >
# > **Explicación del código:**
# > - Se usa un **conjunto (`set`)** para almacenar las noticias del boletín, evitando duplicados.
# > - Se usa un **menú iterativo** para permitir al usuario gestionar el boletín.
# > - Se usa `add()` para agregar noticias y `remove()` para eliminarlas.
# > - Se muestra el boletín con un ciclo `for`.
# > - La opción `"4"` usa `break` para salir del sistema.
# >
# > 🚀 Con esta aplicación, el usuario puede gestionar su boletín de manera sencilla y eficiente.
# >
# > ¿Te gustaría agregar más funcionalidades, como ordenar las noticias o guardar el boletín en un archivo? 😃

# %%
# print('*** Boletín Informativo ***')

# Definimos el set inicial
#suscriptores = {} #aqui se esta definiendo un diccionario vacio, esto no nos sirve
suscriptores = set()

numero_suscriptores = int(input('Proporciona el número de suscriptores iniciales: '))
for _ in range(numero_suscriptores):
    suscriptores.add(input('Nuevo suscriptor (email): '))

print(f'Lista de suscriptores inicial: {suscriptores}')

# Verificar si un nuevo suscriptor ya está en la lista
nuevo_suscriptor = input('Proporciona el nuevo suscriptor: ')
if nuevo_suscriptor in suscriptores:
    print(f'El nuevo suscriptor ya está en la lista {nuevo_suscriptor}')
else:
    suscriptores.add(nuevo_suscriptor)
    print(f'El nuevo suscriptor se ha agregado a la lista {nuevo_suscriptor}')

# Eliminar un suscriptor existente
suscriptor_eliminar = input('Proporciona el suscriptor a eliminar: ')
suscriptores.remove(suscriptor_eliminar)
print(f'El suscriptor {suscriptor_eliminar} ha sido eliminado de la lista')
print(f'Lista de suscriptores: {suscriptores}')

# Verificar la cantidad total de suscriptores
print(f'Cantidad total suscriptores: {len(suscriptores)}')

# Mostrar todos los suscriptores
print(f'--- Lista de suscriptores ---')
for suscriptor in suscriptores:
    print(f'- {suscriptor}')

# %% [markdown]
# #### Diccionarios en Python

# %% [markdown]
# > **Diccionarios en Python**
# >
# > Los **diccionarios** en Python son estructuras de datos que almacenan información en **pares clave-valor**, permitiendo un acceso rápido y eficiente a los datos.
# >
# > ---
# > **1. Crear un diccionario en Python**
# > Se pueden definir diccionarios con llaves `{}` o usando la función `dict()`.
# >
# > ---
# > ```python
# > diccionario = {"nombre": "Miguel", "edad": 30, "ciudad": "Madrid"}
# > print(diccionario)  # {'nombre': 'Miguel', 'edad': 30, 'ciudad': 'Madrid'}
# > ```
# > ---
# >
# > **2. Acceder a elementos de un diccionario**
# > Se pueden obtener valores individuales usando claves.
# >
# > ---
# > ```python
# > print(diccionario["nombre"])  # 'Miguel'
# > print(diccionario.get("edad"))  # 30
# > ```
# > ---
# >
# > **3. Modificar elementos de un diccionario**
# > Se pueden actualizar valores o agregar nuevas claves.
# >
# > ---
# > ```python
# > diccionario["edad"] = 31  # Modificar valor existente
# > diccionario["profesion"] = "Ingeniero"  # Agregar nueva clave
# > print(diccionario)  # {'nombre': 'Miguel', 'edad': 31, 'ciudad': 'Madrid', 'profesion': 'Ingeniero'}
# > ```
# > ---
# >
# > **4. Iterar sobre un diccionario**
# > Se pueden recorrer claves y valores con `for`.
# >
# > ---
# > ```python
# > for clave, valor in diccionario.items():
# >     print(f"{clave}: {valor}")
# > ```
# > ---
# >
# > **5. Métodos útiles de los diccionarios**
# > - `keys()`: Obtiene todas las claves.
# > - `values()`: Obtiene todos los valores.
# > - `items()`: Obtiene pares clave-valor.
# > - `pop()`: Elimina una clave específica.
# > - `clear()`: Vacía el diccionario.
# >
# > ---
# > ```python
# > print(diccionario.keys())  # dict_keys(['nombre', 'edad', 'ciudad', 'profesion'])
# > print(diccionario.values())  # dict_values(['Miguel', 31, 'Madrid', 'Ingeniero'])
# > diccionario.pop("ciudad")  # Elimina 'ciudad'
# > print(diccionario)  # {'nombre': 'Miguel', 'edad': 31, 'profesion': 'Ingeniero'}
# > ```
# > ---
# >
# > 🚀 Los diccionarios en Python son fundamentales para la manipulación de datos y la optimización de código.
# >
# > ¿Te gustaría ver ejemplos más avanzados o aprender sobre diccionarios anidados? 😃

# %% [markdown]
# #### Ejercicio Propuesto - Agenda de Contactos

# %% [markdown]
# > **Ejercicio Propuesto - Agenda de Contactos**
# >
# > Se solicita crear un programa en Python que permita gestionar una **agenda de contactos**, donde el usuario pueda **agregar, eliminar, buscar y visualizar contactos**.
# >
# > ---
# > ```python
# > # Inicializar la agenda como un diccionario vacío
# > agenda = {}
# >
# > while True:
# >     print("\n*** Agenda de Contactos ***")
# >     print("1. Agregar contacto")
# >     print("2. Eliminar contacto")
# >     print("3. Buscar contacto")
# >     print("4. Mostrar agenda")
# >     print("5. Salir")
# >
# >     opcion = input("Selecciona una opción: ")
# >
# >     if opcion == "1":
# >         nombre = input("Introduce el nombre del contacto: ")
# >         telefono = input("Introduce el número de teléfono: ")
# >         agenda[nombre] = telefono
# >         print(f"Contacto agregado: {nombre} - {telefono}")
# >
# >     elif opcion == "2":
# >         nombre = input("Introduce el nombre del contacto a eliminar: ")
# >         if nombre in agenda:
# >             del agenda[nombre]
# >             print(f"Contacto eliminado: {nombre}")
# >         else:
# >             print("El contacto no está en la agenda.")
# >
# >     elif opcion == "3":
# >         nombre = input("Introduce el nombre del contacto a buscar: ")
# >         if nombre in agenda:
# >             print(f"{nombre}: {agenda[nombre]}")
# >         else:
# >             print("El contacto no está en la agenda.")
# >
# >     elif opcion == "4":
# >         print("\nAgenda de Contactos:")
# >         if agenda:
# >             for nombre, telefono in agenda.items():
# >                 print(f"{nombre}: {telefono}")
# >         else:
# >             print("La agenda está vacía.")
# >
# >     elif opcion == "5":
# >         print("Saliendo del sistema. ¡Hasta pronto!")
# >         break
# >
# >     else:
# >         print("Opción inválida. Inténtalo de nuevo.")
# > ```
# > ---
# >
# > **Explicación del código:**
# > - Se usa un **diccionario (`dict`)** para almacenar los contactos de la agenda.
# > - Se usa un **menú iterativo** para permitir al usuario gestionar la agenda.
# > - Se usa `agenda[nombre] = telefono` para agregar contactos y `del agenda[nombre]` para eliminarlos.
# > - Se muestra la agenda con un ciclo `for`.
# > - La opción `"5"` usa `break` para salir del sistema.
# >
# > 🚀 Con esta aplicación, el usuario puede gestionar su agenda de manera sencilla y eficiente.
# >
# > ¿Te gustaría agregar más funcionalidades, como ordenar los contactos o exportar la agenda a un archivo? 😃

# %%
# Inicializar la agenda como un diccionario vacío
agenda = {}

while True:
    print("\n*** Agenda de Contactos ***")
    print("1. Agregar contacto")
    print("2. Eliminar contacto")
    print("3. Buscar contacto")
    print("4. Mostrar agenda")
    print("5. Salir")

    opcion = input("Selecciona una opción: ")

    if opcion == "1":
        nombre = input("Introduce el nombre del contacto: ")
        telefono = input("Introduce el número de teléfono: ")
        agenda[nombre] = telefono
        print(f"Contacto agregado: {nombre} - {telefono}")
    
    elif opcion == "2":
        nombre = input("Introduce el nombre del contacto a eliminar: ")
        if nombre in agenda:
            del agenda[nombre]
            print(f"Contacto eliminado: {nombre}")
        else:
            print("El contacto no está en la agenda.")
    
    elif opcion == "3":
        nombre = input("Introduce el nombre del contacto a buscar: ")
        if nombre in agenda:
            print(f"{nombre}: {agenda[nombre]}")
        else:
            print("El contacto no está en la agenda.")
    
    elif opcion == "4":
        print("\nAgenda de Contactos:")
        if agenda:
            for nombre, telefono in agenda.items():
                print(f"{nombre}: {telefono}")
        else:
            print("La agenda está vacía.")
    
    elif opcion == "5":
        print("Saliendo del sistema. ¡Hasta pronto!")
        break
    
    else:
        print("Opción inválida. Inténtalo de nuevo.")

# %% [markdown]
# #### Combinación de  Listas y Diccionarios en Python

# %% [markdown]
# > **Combinación de Listas y Diccionarios en Python**
# >
# > En Python, se pueden combinar **listas** y **diccionarios** para estructurar datos de manera flexible y eficiente. Aquí tienes algunos ejemplos de cómo hacerlo:
# >
# > ---
# > **1. Convertir una lista en un diccionario**
# > Se puede transformar una lista en un diccionario usando `zip()`.
# >
# > ---
# > ```python
# > claves = ["nombre", "edad", "ciudad"]
# > valores = ["Miguel", 30, "Madrid"]
# > diccionario = dict(zip(claves, valores))
# > print(diccionario)  # {'nombre': 'Miguel', 'edad': 30, 'ciudad': 'Madrid'}
# > ```
# > ---
# >
# > **2. Crear una lista de diccionarios**
# > Se pueden combinar listas y diccionarios dentro de una lista.
# >
# > ---
# > ```python
# > contactos = [
# >     {"nombre": "Juan", "telefono": "123456"},
# >     {"nombre": "Ana", "telefono": "789012"},
# >     {"nombre": "Luis", "telefono": "345678"}
# > ]
# > print(contactos[1]["nombre"])  # 'Ana'
# > ```
# > ---
# >
# > **3. Iterar sobre una lista de diccionarios**
# > Se puede recorrer una lista que contiene diccionarios.
# >
# > ---
# > ```python
# > contactos = [
# >     {"nombre": "Juan", "telefono": "123456"},
# >     {"nombre": "Ana", "telefono": "789012"},
# >     {"nombre": "Luis", "telefono": "345678"}
# > ]
# > for contacto in contactos:
# >     print(f"{contacto['nombre']} - {contacto['telefono']}")
# > ```
# > ---
# >
# > **4. Agregar elementos a una lista de diccionarios**
# > Se pueden añadir nuevos diccionarios a una lista.
# >
# > ---
# > ```python
# > contactos.append({"nombre": "Carlos", "telefono": "987654"})
# > print(contactos)
# > ```
# > ---
# >
# > 🚀 La combinación de listas y diccionarios en Python permite estructurar datos de manera flexible y eficiente.
# >
# > ¿Te gustaría ver ejemplos más avanzados o aplicar esto en un problema específico? 😃

# %% [markdown]
# #### Ejercicio Propuesto - Sistema de Inventarios en Python

# %% [markdown]
# > **Ejercicio Propuesto - Gestión de Inventario en Python**
# >
# > Se solicita crear un programa en Python que gestione el inventario de un almacén, utilizando **listas y diccionarios** para almacenar los productos y sus detalles.
# >
# > ---
# > **📌 Requisitos del programa:**
# > - Mantener un registro de productos en una lista.
# > - Cada producto tendrá un diccionario con `id`, `nombre`, `precio` y `cantidad disponible`.
# > - Permitir agregar, eliminar y visualizar productos.
# >
# > ---
# > ```python
# > # Inicializar el inventario como una lista vacía
# > inventario = []
# >
# > while True:
# >     print("\n*** Gestión de Inventario ***")
# >     print("1. Agregar producto")
# >     print("2. Eliminar producto")
# >     print("3. Mostrar inventario")
# >     print("4. Salir")
# >
# >     opcion = input("Selecciona una opción: ")
# >
# >     if opcion == "1":
# >         id_producto = input("Introduce el ID del producto: ")
# >         nombre = input("Introduce el nombre del producto: ")
# >         precio = float(input("Introduce el precio: "))
# >         cantidad = int(input("Introduce la cantidad disponible: "))
# >
# >         producto = {
# >             "id": id_producto,
# >             "nombre": nombre,
# >             "precio": precio,
# >             "cantidad": cantidad
# >         }
# >
# >         inventario.append(producto)
# >         print(f"Producto agregado: {nombre} - ID: {id_producto}, Precio: ${precio:.2f}, Cantidad: {cantidad}")
# >
# >     elif opcion == "2":
# >         id_producto = input("Introduce el ID del producto a eliminar: ")
# >         encontrado = False
# >
# >         for producto in inventario:
# >             if producto["id"] == id_producto:
# >                 inventario.remove(producto)
# >                 print(f"Producto eliminado: {producto['nombre']}")
# >                 encontrado = True
# >                 break
# >
# >         if not encontrado:
# >             print("El producto no está en el inventario.")
# >
# >     elif opcion == "3":
# >         print("\nInventario Actual:")
# >         if inventario:
# >             for producto in inventario:
# >                 print(f"ID: {producto['id']} - {producto['nombre']} - Precio: ${producto['precio']:.2f} - Cantidad: {producto['cantidad']}")
# >         else:
# >             print("El inventario está vacío.")
# >
# >     elif opcion == "4":
# >         print("Saliendo del sistema. ¡Hasta pronto!")
# >         break
# >
# >     else:
# >         print("Opción inválida. Inténtalo de nuevo.")
# > ```
# > ---
# >
# > **✅ Explicación del código:**
# > - Se usa una **lista** para almacenar los productos.
# > - Cada producto es un **diccionario** con `id`, `nombre`, `precio` y `cantidad`.
# > - Se usa un **menú iterativo** para gestionar el inventario.
# > - Se agrega un producto con `append()`, se elimina con `remove()`, y se muestra con un ciclo `for`.
# > - Se usa `break` para salir del sistema.
# >
# > 🚀 Con esta aplicación, el usuario puede gestionar su inventario de manera sencilla y eficiente.
# >
# > ¿Te gustaría agregar más funcionalidades, como ordenar los productos o exportar el inventario a un archivo? 😃

# %%
# Inicializar el inventario como una lista vacía
inventario = []

while True:
    print("\n*** Gestión de Inventario ***")
    print("1. Agregar producto")
    print("2. Eliminar producto")
    print("3. Mostrar inventario")
    print("4. Salir")

    opcion = input("Selecciona una opción: ")

    if opcion == "1":
        id_producto = input("Introduce el ID del producto: ")
        nombre = input("Introduce el nombre del producto: ")
        precio = float(input("Introduce el precio: "))
        cantidad = int(input("Introduce la cantidad disponible: "))
        
        producto = {
            "id": id_producto,
            "nombre": nombre,
            "precio": precio,
            "cantidad": cantidad
        }
        
        inventario.append(producto)
        print(f"Producto agregado: {nombre} - ID: {id_producto}, Precio: ${precio:.2f}, Cantidad: {cantidad}")
    
    elif opcion == "2":
        id_producto = input("Introduce el ID del producto a eliminar: ")
        encontrado = False
        
        for producto in inventario:
            if producto["id"] == id_producto:
                inventario.remove(producto)
                print(f"Producto eliminado: {producto['nombre']}")
                encontrado = True
                break
        
        if not encontrado:
            print("El producto no está en el inventario.")
    
    elif opcion == "3":
        print("\nInventario Actual:")
        if inventario:
            for producto in inventario:
                print(f"ID: {producto['id']} - {producto['nombre']} - Precio: ${producto['precio']:.2f} - Cantidad: {producto['cantidad']}")
        else:
            print("El inventario está vacío.")
    
    elif opcion == "4":
        print("Saliendo del sistema. ¡Hasta pronto!")
        break
    
    else:
        print("Opción inválida. Inténtalo de nuevo.")

# %% [markdown]
# ### Sección 7: Funciones en Python

# %% [markdown]
# #### Funciones en Python

# %% [markdown]
# > **Funciones en Python**
# >
# > Las **funciones** en Python son bloques de código reutilizables que permiten estructurar programas de manera modular y eficiente.
# >
# > ---
# > **📌 Características de las funciones:**
# > - Se definen con la palabra clave `def`.
# > - Pueden recibir parámetros y devolver valores.
# > - Ayudan a organizar el código y evitar la repetición.
# >
# > ---
# > **1. Definir una función en Python**
# > Se usa `def` seguido del nombre de la función y paréntesis `()`.
# >
# > ---
# > ```python
# > def saludar():
# >     print("¡Hola, bienvenido a Python!")
# >
# > saludar()  # Llamada a la función
# > ```
# > ---
# >
# > **2. Funciones con parámetros**
# > Se pueden recibir valores como entrada para realizar operaciones con ellos.
# >
# > ---
# > ```python
# > def sumar(a, b):
# >     return a + b
# >
# > resultado = sumar(5, 3)
# > print(resultado)  # Salida: 8
# > ```
# > ---
# >
# > **3. Valores predeterminados en parámetros**
# > Se pueden asignar valores por defecto a los parámetros de una función.
# >
# > ---
# > ```python
# > def presentar(nombre="Invitado"):
# >     print(f"Hola, {nombre}!")
# >
# > presentar()  # Salida: Hola, Invitado!
# > presentar("Miguel")  # Salida: Hola, Miguel!
# > ```
# > ---
# >
# > **4. Funciones con múltiples argumentos (`*args` y `**kwargs`)**
# > Se usa `*args` para argumentos posicionales y `**kwargs` para argumentos con nombre.
# >
# > ---
# > ```python
# > def mostrar_datos(*args, **kwargs):
# >     print("Datos:", args)
# >     print("Información adicional:", kwargs)
# >
# > mostrar_datos(1, 2, 3, nombre="Miguel", edad=30)
# > ```
# > ---
# >
# > **5. Funciones recursivas**
# > Una función puede llamarse a sí misma para resolver problemas como el cálculo de factorial.
# >
# > ---
# > ```python
# > def factorial(n):
# >     if n == 0 or n == 1:
# >         return 1
# >     return n * factorial(n - 1)
# >
# > print(factorial(5))  # Salida: 120
# > ```
# > ---
# >
# > 🚀 Las funciones en Python permiten estructurar el código de manera clara y reutilizable.
# >
# > ¿Te gustaría ver ejemplos más avanzados o aplicar funciones en un problema específico? 😃

# %% [markdown]
# #### Función sumar en Python

# %% [markdown]
# > **Función `sumar()` en Python**
# >
# > La función `sumar()` en Python permite realizar la suma de dos o más números de manera sencilla. Se puede definir manualmente o utilizar la función incorporada `sum()`.
# >
# > ---
# > **📌 Definir una función `sumar()` personalizada**
# > Se puede crear una función que reciba dos números y devuelva su suma.
# >
# > ---
# > ```python
# > def sumar(a, b):
# >     return a + b
# >
# > resultado = sumar(5, 3)
# > print(resultado)  # Salida: 8
# > ```
# > ---
# >
# > **📌 Usar la función `sum()` de Python**
# > Python incluye la función `sum()` para sumar los elementos de una lista o tupla.
# >
# > ---
# > ```python
# > numeros = [1, 2, 3, 4, 5]
# > resultado = sum(numeros)
# > print(resultado)  # Salida: 15
# > ```
# > ---
# >
# > **📌 Sumar números ingresados por el usuario**
# > Se pueden solicitar números al usuario y sumarlos.
# >
# > ---
# > ```python
# > num1 = float(input("Introduce el primer número: "))
# > num2 = float(input("Introduce el segundo número: "))
# > print(f"La suma es: {num1 + num2}")
# > ```
# > ---
# >
# > 🚀 La función `sumar()` en Python es útil para realizar cálculos matemáticos de manera eficiente.
# >
# > ¿Te gustaría ver ejemplos más avanzados o aplicar la función en un problema específico? 😃

# %% [markdown]
# #### Función saludar con retorno de valor

# %% [markdown]
# > **Función `saludar()` con retorno de valor**
# >
# > En Python, una función puede **retornar** un valor en lugar de simplemente imprimirlo. Esto permite reutilizar la salida en otras partes del programa.
# >
# > ---
# > **📌 Definir una función con `return`**
# > La función `saludar()` devolverá un mensaje en lugar de imprimirlo directamente.
# >
# > ---
# > ```python
# > def saludar(nombre):
# >     return f"¡Hola, {nombre}! Bienvenido a Python."
# >
# > mensaje = saludar("Miguel")
# > print(mensaje)  # Salida: ¡Hola, Miguel! Bienvenido a Python.
# > ```
# > ---
# >
# > **📌 Uso del retorno en otra función**
# > Se puede utilizar el valor retornado dentro de otra función.
# >
# > ---
# > ```python
# > def saludar(nombre):
# >     return f"¡Hola, {nombre}!"
# >
# > def despedir(nombre):
# >     saludo = saludar(nombre)
# >     return f"{saludo} ¡Hasta pronto!"
# >
# > print(despedir("Miguel"))  # Salida: ¡Hola, Miguel! ¡Hasta pronto!
# > ```
# > ---
# >
# > **📌 Usar el valor retornado en una operación**
# > Se puede almacenar el valor en una variable y procesarlo más adelante.
# >
# > ---
# > ```python
# > def obtener_saludo(nombre):
# >     return f"Saludos, {nombre}"
# >
# > saludo_usuario = obtener_saludo("Ana")
# > print(saludo_usuario.upper())  # SALUDOS, ANA
# > ```
# > ---
# >
# > 🚀 La función `saludar()` con retorno de valor permite reutilizar el mensaje de saludo de forma flexible y efectiva.
# >
# > ¿Te gustaría ver ejemplos más avanzados o aplicar esta función en un proyecto específico? 😃

# %% [markdown]
# #### Modo debug en Visual Studio Code

# %% [markdown]
# > **Modo Debug en Visual Studio Code**
# >
# > El **modo debug** en Visual Studio Code permite ejecutar código paso a paso, identificar errores y analizar el comportamiento de un programa en tiempo real.
# >
# > ---
# > **📌 Características principales:**
# > - **Breakpoints (puntos de interrupción)**: Detienen la ejecución en una línea específica para inspeccionar variables.
# > - **Call Stack (pila de llamadas)**: Muestra el orden de ejecución de funciones.
# > - **Watch (observador de variables)**: Monitorea valores específicos durante la ejecución.
# > - **Debug Console (consola de depuración)**: Ejecuta comandos y evalúa expresiones en tiempo real.
# >
# > ---
# > **🚀 Cómo activar el modo debug en Visual Studio Code**
# >
# > ---
# > ```python
# > 1. **Abrir el archivo** que deseas depurar.
# > 2. **Agregar un breakpoint** haciendo clic en el margen izquierdo junto al número de línea.
# > 3. **Ejecutar el modo debug** presionando `F5` o seleccionando "Run and Debug" en la barra lateral.
# > 4. **Inspeccionar variables y flujo de ejecución** usando la consola de depuración.
# > ```
# > ---
# >
# > **✅ Consejos para depuración efectiva:**
# > - Usa `print()` para visualizar valores antes de ejecutar el debug.
# > - Configura `launch.json` para personalizar el entorno de depuración.
# > - Activa el **modo paso a paso** para ver cada línea ejecutada.
# >
# > 🚀 Con estas herramientas, puedes encontrar errores y optimizar tu código fácilmente.
# >
# > ¿Te gustaría ayuda con un caso específico de depuración en tu código? 😃

# %% [markdown]
# #### Módulo función sumar en Python

# %% [markdown]
# > **Módulo para la función `sumar()` en Python**
# >
# > En Python, se pueden crear módulos para organizar funciones y reutilizar código. Aquí te muestro cómo definir un módulo con la función `sumar()`.
# >
# > ---
# > **📌 Creación de un módulo en Python**
# > Un módulo es un archivo `.py` que contiene funciones y puede ser importado en otros programas.
# >
# > ---
# > ```python
# > # Crear un archivo llamado "operaciones.py"
# >
# > def sumar(a, b):
# >     return a + b
# > ```
# > ---
# >
# > **📌 Importar el módulo en otro archivo**
# > Se puede importar el módulo y usar la función `sumar()`.
# >
# > ---
# > ```python
# > import operaciones
# >
# > resultado = operaciones.sumar(5, 3)
# > print(resultado)  # Salida: 8
# > ```
# > ---
# >
# > **📌 Importar solo la función `sumar()`**
# > Se puede importar solo la función específica en lugar de todo el módulo.
# >
# > ---
# > ```python
# > from operaciones import sumar
# >
# > print(sumar(10, 4))  # Salida: 14
# > ```
# > ---
# >
# > **📌 Uso de módulos en proyectos grandes**
# > Los módulos permiten estructurar el código en archivos separados, facilitando la organización y reutilización.
# >
# > 🚀 Con este módulo, puedes usar la función `sumar()` en diferentes programas sin repetir código.
# >
# > ¿Te gustaría agregar más funciones matemáticas al módulo? 😃

# %% [markdown]
# #### Argumentos por Nombre en Python

# %% [markdown]
# > **Argumentos por Nombre en Python**
# >
# > En Python, los **argumentos por nombre** permiten pasar valores a una función especificando el nombre del parámetro, en lugar de depender de su posición.
# >
# > ---
# > **📌 Características de los argumentos por nombre:**
# > - Se asignan explícitamente a los parámetros de la función.
# > - Permiten cambiar el orden de los argumentos sin afectar la ejecución.
# > - Mejoran la legibilidad del código.
# >
# > ---
# > **1. Uso básico de argumentos por nombre**
# > Se pueden pasar valores a una función especificando el nombre del parámetro.
# >
# > ---
# > ```python
# > def presentar(nombre, edad, ciudad):
# >     print(f"Hola, soy {nombre}, tengo {edad} años y vivo en {ciudad}.")
# >
# > presentar(nombre="Miguel", edad=30, ciudad="Madrid")
# > ```
# > ---
# >
# > **2. Mezcla de argumentos posicionales y por nombre**
# > Se pueden combinar ambos tipos de argumentos en una llamada a función.
# >
# > ---
# > ```python
# > presentar("Ana", edad=25, ciudad="Barcelona")
# > ```
# > ---
# >
# > **3. Orden flexible de argumentos por nombre**
# > Al usar argumentos por nombre, el orden de los parámetros no importa.
# >
# > ---
# > ```python
# > presentar(ciudad="Sevilla", nombre="Luis", edad=40)
# > ```
# > ---
# >
# > **4. Uso con valores predeterminados**
# > Se pueden definir valores por defecto en los parámetros de una función.
# >
# > ---
# > ```python
# > def presentar(nombre, edad=18, ciudad="Madrid"):
# >     print(f"Hola, soy {nombre}, tengo {edad} años y vivo en {ciudad}.")
# >
# > presentar(nombre="Carlos")  # Usa valores predeterminados para edad y ciudad
# > ```
# > ---
# >
# > 🚀 Los argumentos por nombre en Python mejoran la claridad y flexibilidad del código.
# >
# > ¿Te gustaría ver ejemplos más avanzados o aplicar esto en un problema específico? 😃

# %% [markdown]
# #### Regresar varios nombres (tupla) en una función

# %% [markdown]
# > **Retornar varios ítems con tuplas en una función en Python**
# >
# > En Python, una función puede devolver múltiples valores utilizando una **tupla**. Esto permite retornar varios ítems sin necesidad de definir múltiples variables.
# >
# > ---
# > **📌 Uso básico de retorno múltiple con tupla**
# > Se pueden retornar varios valores separándolos con comas.
# >
# > ---
# > ```python
# > def obtener_datos():
# >     nombre = "Miguel"
# >     edad = 30
# >     ciudad = "Madrid"
# >     return nombre, edad, ciudad  # Retorna una tupla automáticamente
# >
# > datos = obtener_datos()
# > print(datos)  # Salida: ('Miguel', 30, 'Madrid')
# > ```
# > ---
# >
# > **📌 Desempaquetar valores de la tupla retornada**
# > Se pueden asignar los valores a variables individuales.
# >
# > ---
# > ```python
# > nombre, edad, ciudad = obtener_datos()
# > print(nombre)  # Salida: Miguel
# > print(edad)    # Salida: 30
# > print(ciudad)  # Salida: Madrid
# > ```
# > ---
# >
# > **📌 Retornar tuplas dinámicas con parámetros**
# > Se pueden definir valores en función de parámetros recibidos.
# >
# > ---
# > ```python
# > def calcular_datos(a, b):
# >     suma = a + b
# >     resta = a - b
# >     return suma, resta
# >
# > resultado = calcular_datos(8, 3)
# > print(resultado)  # Salida: (11, 5)
# > ```
# > ---
# >
# > 🚀 Retornar múltiples valores con tuplas en Python mejora la organización y flexibilidad del código.
# >
# > ¿Te gustaría ver ejemplos más avanzados o aplicar esto en un problema específico? 😃

# %% [markdown]
# #### Coordenadas con una Tupla en Python

# %% [markdown]
# > **Coordenadas con una Tupla en Python**
# >
# > En Python, las **tuplas** son útiles para representar **coordenadas** en un sistema bidimensional (x, y) o tridimensional (x, y, z). Son estructuras **inmutables**, lo que significa que no pueden modificarse después de su creación.
# >
# > ---
# > **📌 Definir una tupla de coordenadas en Python**
# > Se pueden almacenar coordenadas dentro de una tupla.
# >
# > ---
# > ```python
# > coordenada_2d = (10, 20)  # Coordenadas (x, y)
# > coordenada_3d = (10, 20, 5)  # Coordenadas (x, y, z)
# > print(coordenada_2d)  # Salida: (10, 20)
# > print(coordenada_3d)  # Salida: (10, 20, 5)
# > ```
# > ---
# >
# > **📌 Acceder a los valores de una tupla de coordenadas**
# > Se pueden obtener los valores individuales mediante índices.
# >
# > ---
# > ```python
# > x = coordenada_2d[0]
# > y = coordenada_2d[1]
# > print(f"X: {x}, Y: {y}")  # Salida: X: 10, Y: 20
# > ```
# > ---
# >
# > **📌 Desempaquetar coordenadas en variables**
# > Se pueden asignar los valores de la tupla directamente.
# >
# > ---
# > ```python
# > x, y, z = coordenada_3d
# > print(f"X: {x}, Y: {y}, Z: {z}")  # Salida: X: 10, Y: 20, Z: 5
# > ```
# > ---
# >
# > **📌 Uso de tuplas de coordenadas en cálculos**
# > Se pueden operar con coordenadas en funciones.
# >
# > ---
# > ```python
# > def mover(coordenada, dx, dy):
# >     x, y = coordenada
# >     nueva_coordenada = (x + dx, y + dy)
# >     return nueva_coordenada
# >
# > nueva_posicion = mover((5, 8), 3, 4)
# > print(nueva_posicion)  # Salida: (8, 12)
# > ```
# > ---
# >
# > 🚀 Las tuplas son ideales para almacenar coordenadas en Python de manera eficiente.
# >
# > ¿Te gustaría aplicar esto en gráficos, juegos o mapas? 😃

# %% [markdown]
# #### Argumentos Variables *args en Python

# %% [markdown]
# > **Argumentos Variables `*args` en Python**
# >
# > En Python, `*args` permite pasar un número **variable** de argumentos a una función. Estos argumentos se almacenan en una **tupla**, lo que permite iterarlos fácilmente.
# >
# > ---
# > **📌 Características de `*args`:**
# > - Permite enviar múltiples valores sin definirlos explícitamente en los parámetros.
# > - Se almacena como una **tupla** dentro de la función.
# > - Se usa cuando no se conoce la cantidad exacta de argumentos que se recibirán.
# >
# > ---
# > **1. Uso básico de `*args`**
# > Se pueden pasar múltiples valores a una función sin definirlos previamente.
# >
# > ---
# > ```python
# > def sumar(*args):
# >     return sum(args)
# >
# > print(sumar(1, 2, 3, 4, 5))  # Salida: 15
# > ```
# > ---
# >
# > **2. Iterar sobre `*args`**
# > Se pueden recorrer los valores dentro de la función.
# >
# > ---
# > ```python
# > def mostrar_numeros(*args):
# >     for numero in args:
# >         print(numero)
# >
# > mostrar_numeros(10, 20, 30)
# > ```
# > ---
# >
# > **3. Mezcla de argumentos normales y `*args`**
# > Se pueden combinar argumentos fijos con `*args`.
# >
# > ---
# > ```python
# > def multiplicar(factor, *args):
# >     return [factor * num for num in args]
# >
# > print(multiplicar(2, 1, 2, 3))  # Salida: [2, 4, 6]
# > ```
# > ---
# >
# > **4. Uso de `*args` con otros parámetros**
# > Se pueden definir parámetros antes y después de `*args`.
# >
# > ---
# > ```python
# > def datos_personales(nombre, edad, *otros):
# >     print(f"Nombre: {nombre}, Edad: {edad}")
# >     print("Otros datos:", otros)
# >
# > datos_personales("Miguel", 30, "Madrid", "Ingeniero")
# > ```
# > ---
# >
# > 🚀 `*args` en Python es útil para funciones flexibles y reutilizables.
# >
# > ¿Te gustaría ver ejemplos más avanzados o aplicar esto en un problema específico? 😃

# %% [markdown]
# #### Ejemplo Suma con Argumentos Variables

# %% [markdown]
# > **Ejemplo de Suma con Argumentos Variables (`*args`) en Python**
# >
# > En Python, `*args` permite pasar múltiples valores a una función sin definir previamente el número exacto de argumentos. Esto es útil para realizar **sumas dinámicas**.
# >
# > ---
# > **📌 Definir una función `sumar()` con `*args`**
# > Se pueden sumar varios valores enviados como argumentos.
# >
# > ---
# > ```python
# > def sumar(*args):
# >     return sum(args)
# >
# > print(sumar(2, 4, 6, 8))  # Salida: 20
# > print(sumar(10, 20))  # Salida: 30
# > print(sumar())  # Salida: 0 (suma de una tupla vacía)
# > ```
# > ---
# >
# > **📌 Iterar sobre `*args` antes de sumar**
# > Se puede recorrer los argumentos antes de sumarlos.
# >
# > ---
# > ```python
# > def sumar(*args):
# >     total = 0
# >     for num in args:
# >         total += num
# >     return total
# >
# > print(sumar(5, 15, 25))  # Salida: 45
# > ```
# > ---
# >
# > **📌 Mezcla de argumentos normales y `*args`**
# > Se pueden combinar valores fijos con múltiples argumentos variables.
# >
# > ---
# > ```python
# > def sumar_con_multiplicador(multiplicador, *args):
# >     return multiplicador * sum(args)
# >
# > print(sumar_con_multiplicador(2, 1, 2, 3))  # Salida: 12 (doble de la suma)
# > ```
# > ---
# >
# > 🚀 `*args` es útil para realizar operaciones matemáticas sin restricciones en el número de argumentos.
# >
# > ¿Te gustaría aplicar esto en un caso más avanzado? 😃

# %% [markdown]
# #### Ejemplo Imprimir Información con Argumentos Variables (diccionarios)

# %% [markdown]
# > **Ejemplo: Imprimir Información con Argumentos Variables (`**kwargs`) en Python**
# >
# > En Python, `**kwargs` permite pasar múltiples argumentos con nombre a una función en forma de **diccionario**. Esto es útil para imprimir información flexible y estructurada.
# >
# > ---
# > **📌 Uso básico de `**kwargs`**
# > Se pueden recibir múltiples parámetros con nombre dentro de un diccionario.
# >
# > ---
# > ```python
# > def mostrar_info(**kwargs):
# >     for clave, valor in kwargs.items():
# >         print(f"{clave}: {valor}")
# >
# > mostrar_info(nombre="Miguel", edad=30, ciudad="Madrid")
# > ```
# > ---
# > **Salida:**
# > ```
# > nombre: Miguel
# > edad: 30
# > ciudad: Madrid
# > ```
# > ---
# >
# > **📌 Iterar sobre `**kwargs` para mostrar información estructurada**
# > Se pueden recorrer los elementos de `kwargs` y aplicar formatos personalizados.
# >
# > ---
# > ```python
# > def mostrar_datos(**kwargs):
# >     print("\nInformación del usuario:")
# >     for clave, valor in kwargs.items():
# >         print(f"- {clave.capitalize()}: {valor}")
# >
# > mostrar_datos(nombre="Ana", edad=25, profesion="Ingeniera")
# > ```
# > ---
# > **Salida:**
# > ```
# > Información del usuario:
# > - Nombre: Ana
# > - Edad: 25
# > - Profesion: Ingeniera
# > ```
# > ---
# >
# > **📌 Combinación de argumentos normales y `**kwargs`**
# > Se pueden definir parámetros fijos antes de los argumentos variables.
# >
# > ---
# > ```python
# > def perfil_usuario(id_usuario, **kwargs):
# >     print(f"ID Usuario: {id_usuario}")
# >     for clave, valor in kwargs.items():
# >         print(f"{clave}: {valor}")
# >
# > perfil_usuario(101, nombre="Carlos", edad=40, pais="España")
# > ```
# > ---
# >
# > 🚀 `**kwargs` en Python es útil para imprimir datos dinámicos y estructurados sin restricciones en el número de parámetros.
# >
# > ¿Te gustaría aplicar esto en un caso más avanzado? 😃

# %% [markdown]
# #### Funciones Recursivas en Python

# %% [markdown]
# > **Funciones Recursivas en Python**
# >
# > En Python, una **función recursiva** es aquella que se llama a sí misma dentro de su definición. Se usa para resolver problemas que pueden dividirse en subproblemas más pequeños.
# >
# > ---
# > **📌 Características de las funciones recursivas:**
# > - Se llaman a sí mismas dentro de su código.
# > - Deben tener un **caso base** para evitar llamadas infinitas.
# > - Son útiles para problemas como el cálculo de factorial y la serie de Fibonacci.
# >
# > ---
# > **1. Ejemplo de función recursiva: Factorial**
# > Se usa recursión para calcular el factorial de un número.
# >
# > ---
# > ```python
# > def factorial(n):
# >     if n == 0 or n == 1:
# >         return 1
# >     return n * factorial(n - 1)
# >
# > print(factorial(5))  # Salida: 120
# > ```
# > ---
# >
# > **2. Ejemplo de función recursiva: Serie de Fibonacci**
# > Se usa recursión para calcular el término `n` de la serie de Fibonacci.
# >
# > ---
# > ```python
# > def fibonacci(n):
# >     if n <= 1:
# >         return n
# >     return fibonacci(n - 1) + fibonacci(n - 2)
# >
# > print(fibonacci(6))  # Salida: 8
# > ```
# > ---
# >
# > **3. Importancia del caso base en recursión**
# > Sin un caso base, la función entraría en un **bucle infinito** y causaría un error.
# >
# > ---
# > ```python
# > def cuenta_regresiva(n):
# >     if n <= 0:
# >         print("¡Fin!")
# >         return
# >     print(n)
# >     cuenta_regresiva(n - 1)
# >
# > cuenta_regresiva(5)
# > ```
# > ---
# >
# > 🚀 Las funciones recursivas en Python son poderosas para resolver problemas matemáticos y estructurales.
# >
# > ¿Te gustaría ver ejemplos más avanzados o aplicar recursión en un problema específico? 😃

# %% [markdown]
# #### Ejemplo de Función Recursivas

# %% [markdown]
# > **Ejemplo de Función Recursiva en Python**
# >
# > Una **función recursiva** se llama a sí misma para resolver problemas que pueden dividirse en partes más pequeñas. Es esencial definir un **caso base** para evitar bucles infinitos.
# >
# > ---
# > **📌 Ejemplo: Factorial de un número**
# > Se usa recursión para calcular el factorial de un número `n`.
# >
# > ---
# > ```python
# > def factorial(n):
# >     if n == 0 or n == 1:
# >         return 1
# >     return n * factorial(n - 1)
# >
# > print(factorial(5))  # Salida: 120
# > ```
# > ---
# >
# > **📌 Ejemplo: Serie de Fibonacci**
# > Se usa recursión para calcular el término `n` de la serie de Fibonacci.
# >
# > ---
# > ```python
# > def fibonacci(n):
# >     if n <= 1:
# >         return n
# >     return fibonacci(n - 1) + fibonacci(n - 2)
# >
# > print(fibonacci(6))  # Salida: 8
# > ```
# > ---
# >
# > **📌 Ejemplo: Cuenta regresiva**
# > Se usa recursión para imprimir una cuenta regresiva hasta llegar a cero.
# >
# > ---
# > ```python
# > def cuenta_regresiva(n):
# >     if n <= 0:
# >         print("¡Fin!")
# >         return
# >     print(n)
# >     cuenta_regresiva(n - 1)
# >
# > cuenta_regresiva(5)
# > ```
# > ---
# >
# > 🚀 Las funciones recursivas en Python son muy útiles para problemas matemáticos y estructurales.
# >
# > ¿Te gustaría ver ejemplos más avanzados o aplicar recursión en un problema específico? 😃

# %% [markdown]
# #### Ejercicio Propuesto - Factorial de un número

# %% [markdown]
# > **Ejercicio Propuesto - Factorial de un Número**
# >
# > Se solicita crear un programa en Python que calcule el **factorial** de un número ingresado por el usuario, utilizando una función recursiva.
# >
# > ---
# > **📌 Requisitos del programa:**
# > - Solicitar un número al usuario.
# > - Implementar una función recursiva para calcular el factorial.
# > - Mostrar el resultado en pantalla.
# >
# > ---
# > ```python
# > def factorial(n):
# >     if n == 0 or n == 1:
# >         return 1
# >     return n * factorial(n - 1)
# >
# > numero = int(input("Introduce un número: "))
# > resultado = factorial(numero)
# > print(f"El factorial de {numero} es {resultado}")
# > ```
# > ---
# >
# > **✅ Explicación del código:**
# > - Se define la función `factorial(n)`, que se llama a sí misma hasta llegar al caso base (`n == 0` o `n == 1`).
# > - Se solicita un número al usuario con `input()`.
# > - Se calcula el factorial llamando a la función recursiva.
# > - Se muestra el resultado en pantalla.
# >
# > 🚀 Con esta aplicación, el usuario puede calcular el factorial de cualquier número de manera eficiente.
# >
# > ¿Te gustaría agregar más funcionalidades, como validar la entrada o calcular factoriales de varios números? 😃

# %% [markdown]
# ### Sección 8: Programación Orientada a Objetos (POO) en Python

# %% [markdown]
# #### Clases y Objetos en Python
#
# ##### ¿Qué es una clase?
# Una clase es un molde o plantilla que define las características y comportamientos que tendrán los objetos creados a partir de ella. Las clases permiten agrupar atributos (datos) y métodos (funciones) que actúan sobre esos datos, facilitando la organización y reutilización del código.
#
# ```python
# # Definición de una clase básica
# class Persona:
#     def __init__(self, nombre, edad):
#         self.nombre = nombre  # Atributo de instancia
#         self.edad = edad      # Atributo de instancia
#
#     def saludar(self):
#         print(f"Hola, me llamo {self.nombre} y tengo {self.edad} años.")
# ```
#
# En este ejemplo, la clase `Persona` tiene un constructor (`__init__`) que inicializa los atributos `nombre` y `edad`. También contiene un método `saludar` que realiza una acción.
#
# ---
#
# ##### ¿Qué es un objeto?
# Un objeto es una instancia de una clase. Cuando se crea un objeto, este hereda los atributos y métodos definidos en la clase, permitiendo su uso y manipulación.
#
# ```python
# # Crear un objeto a partir de la clase Persona
# persona1 = Persona("Miguel", 25)
# persona1.saludar()  # Salida: Hola, me llamo Miguel y tengo 25 años.
# ```
#
# Aquí, `persona1` es un objeto creado a partir de la clase `Persona`. Tiene sus propios valores para los atributos `nombre` y `edad`.
#
# ---
#
# ##### Métodos y atributos
# - **Atributos:** Son las variables asociadas a una clase o a un objeto. Pueden ser definidos en el constructor o directamente en la clase.
# - **Métodos:** Son funciones que realizan acciones y están asociadas a la clase o al objeto.
#
# ```python
# # Agregar más funcionalidad a la clase Persona
# class Persona:
#     especie = "Humano"  # Atributo de clase, compartido por todos los objetos
#
#     def __init__(self, nombre, edad):
#         self.nombre = nombre
#         self.edad = edad
#
#     def es_adulto(self):
#         return self.edad >= 18
#
# # Crear un objeto y usar atributos y métodos
# persona2 = Persona("Laura", 17)
# print(persona2.es_adulto())  # Salida: False
# print(persona2.especie)      # Salida: Humano
# ```
#
# En este caso, `especie` es un atributo de clase compartido por todos los objetos, mientras que `edad` es un atributo único para cada objeto.
#
# ---
#
# ##### Herencia de clases
# La herencia permite crear una nueva clase basada en una existente, reutilizando y extendiendo su funcionalidad.
#
# ```python
# # Clase base
# class Animal:
#     def __init__(self, nombre):
#         self.nombre = nombre
#
#     def sonido(self):
#         pass  # Método vacío que será sobrescrito por las clases hijas
#
# # Clase hija
# class Perro(Animal):
#     def sonido(self):
#         return "Ladra"
#
# # Crear un objeto de la clase Perro
# mi_perro = Perro("Max")
# print(f"{mi_perro.nombre} {mi_perro.sonido()}")  # Salida: Max Ladra
# ```
#
# En este ejemplo, `Perro` hereda de la clase `Animal` y sobrescribe el método `sonido`.
#
# ---
#
# ##### Encapsulación
# La encapsulación es el principio de restringir el acceso directo a ciertos atributos y métodos, protegiendo la integridad de los datos.
#
# ```python
# class CuentaBancaria:
#     def __init__(self, saldo):
#         self.__saldo = saldo  # Atributo privado
#
#     def depositar(self, monto):
#         if monto > 0:
#             self.__saldo += monto
#
#     def obtener_saldo(self):
#         return self.__saldo
#
# # Uso de la clase
# mi_cuenta = CuentaBancaria(100)
# mi_cuenta.depositar(50)
# print(mi_cuenta.obtener_saldo())  # Salida: 150
# ```
#
# En este caso, `__saldo` es un atributo privado y no puede ser accedido directamente desde fuera de la clase. Para modificarlo o consultarlo, se utilizan métodos específicos como `depositar` y `obtener_saldo`.

# %% [markdown]
# #### Creación de Clases en Python
#
# ##### Definición básica
# Para crear una clase en Python, se utiliza la palabra clave `class`. Es importante que el nombre de la clase siga la convención **CamelCase** (cada palabra comienza con letra mayúscula, sin espacios ni guiones bajos). El cuerpo de la clase incluye la definición de atributos y métodos, los cuales determinan su funcionalidad.
#
# ```python
# class Persona:
#     pass  # Clase vacía; sin implementación inicial.
# ```
#
# ##### Constructor (`__init__`)
# El constructor `__init__` es el método especial que se ejecuta automáticamente al crear un objeto. Es el lugar donde se inicializan los atributos de la clase. Dentro del constructor, el primer parámetro siempre debe ser `self`, que hace referencia al objeto creado.
#
# ```python
# class Persona:
#     def __init__(self, nombre, edad):
#         self.nombre = nombre
#         self.edad = edad
# ```
#
# El uso de `self` permite que los atributos definidos en el constructor estén vinculados al objeto creado. Por ejemplo, `self.nombre` será único para cada instancia de la clase.
#
# ##### Atributos
# Los atributos son variables asociadas a la clase que almacenan información sobre el estado del objeto. Existen dos tipos:
# 1. **Atributos de clase:** Compartidos por todas las instancias de la clase.
# 2. **Atributos de instancia:** Específicos de cada objeto creado.
#
# ```python
# class Coche:
#     ruedas = 4  # Atributo de clase
#
#     def __init__(self, marca, modelo):
#         self.marca = marca  # Atributo de instancia
#         self.modelo = modelo
# ```
#
# En este ejemplo, `ruedas` es un atributo de clase (común para todos los objetos) mientras que `marca` y `modelo` son atributos de instancia.
#
# ##### Métodos
# Los métodos son funciones definidas dentro de la clase que realizan acciones relacionadas con los datos de la misma. Todos los métodos llevan `self` como primer parámetro.
#
# ```python
# class Persona:
#     def __init__(self, nombre, edad):
#         self.nombre = nombre
#         self.edad = edad
#
#     def saludar(self):
#         print(f"Hola, me llamo {self.nombre} y tengo {self.edad} años.")
# ```
#
# El método `saludar` utiliza los atributos de instancia para mostrar información específica del objeto.
#
# ##### Métodos de clase y estáticos
# Además de los métodos de instancia (que operan sobre objetos individuales), existen:
# 1. **Métodos de clase:** Utilizan el decorador `@classmethod` y trabajan con atributos de clase.
# 2. **Métodos estáticos:** Utilizan el decorador `@staticmethod` y no requieren acceso ni a atributos de instancia ni de clase.
#
# ```python
# class Calculadora:
#     @classmethod
#     def informacion(cls):
#         print("Soy una calculadora básica.")
#
#     @staticmethod
#     def sumar(a, b):
#         return a + b
# ```
#
# El método `informacion` accede al contexto de la clase mediante `cls`, mientras que `sumar` es un método independiente.
#
# ##### Herencia de clases
# Cuando se crea una clase que hereda características de otra, se define una relación de herencia. La clase base se utiliza como punto de partida para construir nuevas clases con funcionalidad adicional.
#
# ```python
# class Animal:
#     def __init__(self, especie):
#         self.especie = especie
#
# class Perro(Animal):
#     def __init__(self, especie, raza):
#         super().__init__(especie)
#         self.raza = raza
# ```
#
# Aquí, la clase `Perro` hereda del `Animal`, reutilizando el constructor con `super()`.

# %% [markdown]
# #### Creación de Objetos
#
# ##### ¿Qué es un objeto?
# Un objeto es una instancia de una clase. Es la representación concreta de los atributos y métodos definidos en una clase. Los objetos se crean para dar vida y utilidad a las clases, permitiendo trabajar con datos específicos y realizar acciones definidas en sus métodos.
#
# ---
#
# ##### Cómo crear un objeto
# La creación de un objeto, también conocida como instanciación, se realiza utilizando el nombre de la clase seguido de paréntesis. Si la clase tiene un constructor (`__init__`), se deben proporcionar los argumentos requeridos.
#
# ```python
# # Definir una clase
# class Persona:
#     def __init__(self, nombre, edad):
#         self.nombre = nombre
#         self.edad = edad
#
# # Crear un objeto
# persona1 = Persona("Miguel", 30)  # Instanciación de la clase Persona
# ```
#
# En este ejemplo, `persona1` es un objeto creado a partir de la clase `Persona`, con `nombre` y `edad` inicializados a `"Miguel"` y `30`.
#
# ---
#
# ##### Acceso a atributos
# Una vez creado el objeto, los atributos definidos en la clase se pueden acceder y modificar utilizando la notación de punto.
#
# ```python
# # Acceso a atributos del objeto
# print(persona1.nombre)  # Salida: Miguel
# print(persona1.edad)    # Salida: 30
#
# # Modificar atributos
# persona1.edad = 31
# print(persona1.edad)    # Salida: 31
# ```
#
# ---
#
# ##### Llamada a métodos
# Los métodos de la clase se invocan utilizando la notación de punto, llamándolos desde el objeto.
#
# ```python
# # Definición de un método en la clase
# class Persona:
#     def __init__(self, nombre, edad):
#         self.nombre = nombre
#         self.edad = edad
#
#     def saludar(self):
#         print(f"Hola, me llamo {self.nombre}.")
#
# # Llamar al método desde el objeto
# persona1.saludar()  # Salida: Hola, me llamo Miguel.
# ```
#
# ---
#
# ##### Múltiples objetos de la misma clase
# Cada objeto creado a partir de una clase es independiente y tiene sus propios valores para los atributos.
#
# ```python
# # Crear múltiples objetos
# persona2 = Persona("Laura", 25)
# persona3 = Persona("Carlos", 40)
#
# # Cada objeto tiene sus propios datos
# print(persona2.nombre)  # Salida: Laura
# print(persona3.edad)    # Salida: 40
# ```
#
# ---
#
# ##### Ejemplo completo
# ```python
# class Coche:
#     def __init__(self, marca, modelo):
#         self.marca = marca
#         self.modelo = modelo
#
#     def describir(self):
#         return f"{self.marca} {self.modelo}"
#
# # Crear objetos
# coche1 = Coche("Toyota", "Corolla")
# coche2 = Coche("Honda", "Civic")
#
# # Acceder a atributos y métodos
# print(coche1.describir())  # Salida: Toyota Corolla
# print(coche2.describir())  # Salida: Honda Civic
# ```
#
# Este ejemplo demuestra cómo crear, acceder y trabajar con objetos. Cada objeto almacena datos específicos y puede ejecutar métodos definidos en la clase.

# %% [markdown]
# #### Constructores en Python
#
# ##### ¿Qué es un constructor?
# Un constructor es un método especial en Python que se ejecuta automáticamente cuando se crea un objeto de una clase. Su propósito principal es inicializar los atributos del objeto y establecer su estado inicial. En Python, el constructor se define mediante el método especial `__init__`.
#
# ---
#
# ##### Sintaxis del constructor
# El método `__init__` es el constructor en Python. Siempre debe recibir al menos un parámetro, llamado convencionalmente `self`, que hace referencia al objeto que se está creando.
#
# ```python
# class Persona:
#     def __init__(self, nombre, edad):
#         self.nombre = nombre  # Inicialización del atributo 'nombre'
#         self.edad = edad      # Inicialización del atributo 'edad'
# ```
#
# En este ejemplo, el constructor `__init__` recibe dos parámetros (`nombre` y `edad`) que se asignan a los atributos de la clase mediante `self`.
#
# ---
#
# ##### Uso del constructor
# El constructor se invoca automáticamente al instanciar la clase. No es necesario llamarlo directamente.
#
# ```python
# # Definición de la clase
# class Persona:
#     def __init__(self, nombre, edad):
#         self.nombre = nombre
#         self.edad = edad
#
# # Creación de un objeto
# persona1 = Persona("Miguel", 30)
# print(persona1.nombre)  # Salida: Miguel
# print(persona1.edad)    # Salida: 30
# ```
#
# ---
#
# ##### Constructor con valores por defecto
# Es posible definir valores por defecto para los parámetros del constructor. Esto permite crear objetos sin proporcionar todos los argumentos.
#
# ```python
# class Persona:
#     def __init__(self, nombre="Sin nombre", edad=0):
#         self.nombre = nombre
#         self.edad = edad
#
# # Crear objetos con y sin pasar argumentos
# persona1 = Persona()
# persona2 = Persona("Laura", 25)
#
# print(persona1.nombre)  # Salida: Sin nombre
# print(persona2.nombre)  # Salida: Laura
# ```
#
# ---
#
# ##### Constructor sin parámetros
# El constructor también puede definirse sin parámetros adicionales, aparte de `self`, si no es necesario inicializar atributos.
#
# ```python
# class Coche:
#     def __init__(self):
#         self.marca = "Desconocida"
#         self.modelo = "Desconocido"
#
# coche1 = Coche()
# print(coche1.marca)  # Salida: Desconocida
# ```
#
# ---
#
# ##### Varios constructores (no directamente soportado en Python)
# Python no soporta múltiples constructores en el sentido tradicional, pero es posible simular este comportamiento utilizando valores por defecto o condicionales dentro del constructor.
#
# ```python
# class Persona:
#     def __init__(self, nombre=None, edad=None):
#         if nombre and edad:
#             self.nombre = nombre
#             self.edad = edad
#         else:
#             self.nombre = "Desconocido"
#             self.edad = 0
#
# persona1 = Persona()
# persona2 = Persona("Miguel", 30)
#
# print(persona1.nombre)  # Salida: Desconocido
# print(persona2.nombre)  # Salida: Miguel
# ```
#
# ---
#
# ##### Inicialización avanzada en el constructor
# Los constructores también pueden incluir lógica más compleja, como validaciones, cálculos o inicialización de estructuras de datos.
#
# ```python
# class Rectangulo:
#     def __init__(self, base, altura):
#         if base <= 0 or altura <= 0:
#             raise ValueError("La base y la altura deben ser mayores que cero.")
#         self.base = base
#         self.altura = altura
#         self.area = self.base * self.altura  # Cálculo directo en el constructor
#
# rectangulo = Rectangulo(5, 10)
# print(rectangulo.area)  # Salida: 50
# ```
#
# ---
#
# ##### Constructor con herencia
# En clases que heredan de otra clase, es posible invocar el constructor de la clase base utilizando `super()`.
#
# ```python
# class Animal:
#     def __init__(self, especie):
#         self.especie = especie
#
# class Perro(Animal):
#     def __init__(self, especie, raza):
#         super().__init__(especie)  # Llamar al constructor de la clase base
#         self.raza = raza
#
# perro = Perro("Canino", "Labrador")
# print(perro.especie)  # Salida: Canino
# print(perro.raza)     # Salida: Labrador
# ```
#
# ---
#
# Este tema cubre diferentes aspectos del uso de constructores en Python, desde su definición básica hasta usos más avanzados, adaptándose a diversas necesidades en el diseño de clases.

# %% [markdown]
# #### Manejo de Memoria en Python
#
# ##### Asignación y Liberación de Memoria
# En Python, el manejo de memoria se realiza automáticamente mediante un sistema que administra la asignación dinámica y la liberación de memoria cuando los objetos ya no se utilizan. Python organiza la memoria en:
# 1. **Stack:** Contiene variables locales y las llamadas a funciones.
# 2. **Heap:** Almacena objetos creados dinámicamente, como listas, diccionarios y otros tipos de datos.
#
# ---
#
# ##### Espacios de Memoria y Referencias
# Cada variable en Python es un puntero a un objeto almacenado en memoria. Los objetos son gestionados en el heap y las variables simplemente actúan como referencias. Esto implica que múltiples referencias pueden apuntar al mismo objeto en memoria.
#
# ```python
# a = [1, 2, 3]
# b = a  # 'b' apunta al mismo objeto que 'a'
# ```
#
# En el ejemplo anterior, tanto `a` como `b` comparten el mismo espacio de memoria del objeto `[1, 2, 3]`.
#
# ---
#
# ##### El Método `id`
# El método `id` en Python devuelve la dirección de memoria única de un objeto. Este valor es un número entero que identifica el objeto mientras está en uso en el programa.
#
# ```python
# x = 42
# print(id(x))  # Devuelve la dirección de memoria de 'x'
# ```
#
# ---
#
# ##### Combinación de `id` con `hex`
# La combinación del método `id` con `hex` permite ver la dirección de memoria del objeto en formato hexadecimal, lo cual es útil para depuración avanzada o análisis de memoria.
#
# ```python
# x = 42
# print(hex(id(x)))  # Devuelve la dirección de memoria en formato hexadecimal
# ```
#
# En este ejemplo, `hex(id(x))` convierte la dirección de memoria de `x` en una representación más legible.
#
# ---
#
# ##### Contador de Referencias
# Python gestiona la memoria utilizando un contador de referencias. Cada objeto tiene un contador que indica cuántas variables o referencias apuntan a él. Cuando el contador llega a cero, el objeto es eliminado.
#
# ```python
# import sys
#
# a = [1, 2, 3]
# print(sys.getrefcount(a))  # Muestra cuántas referencias apuntan al objeto
# ```
#
# El módulo `sys` permite analizar el contador de referencias de cualquier objeto.
#
# ---
#
# ##### Recolección de Basura
# Además del contador de referencias, Python utiliza un sistema de **recolección de basura** para eliminar objetos no accesibles, como aquellos que forman ciclos de referencia.
#
# ```python
# import gc
#
# # Forzar la recolección de basura
# gc.collect()
# ```
#
# La recolección de basura se ejecuta automáticamente, pero puede ser forzada manualmente utilizando el módulo `gc`.
#
# ---
#
# ##### Optimización del Uso de Memoria
# Python utiliza varias técnicas para reducir el uso de memoria y mejorar el rendimiento:
# 1. **Internado de cadenas:** Las cadenas pequeñas y los enteros se reutilizan.
# 2. **Generadores:** Procesan grandes cantidades de datos sin almacenarlos completamente en memoria.
# 3. **Pools de enteros:** Enteros dentro de un rango predefinido se almacenan de forma optimizada.
#
# ```python
# def generador():
#     for i in range(100):
#         yield i
#
# gen = generador()
# print(next(gen))  # Salida: 0
# ```
#
# Los generadores son una excelente herramienta para ahorrar memoria en operaciones que involucran grandes cantidades de datos.
#
# ---
#
# ##### Validación de Ciclos de Referencias
# En Python, los ciclos de referencia pueden aparecer cuando los objetos se refieren entre sí, formando estructuras cerradas. Esto puede impedir que los objetos sean recolectados por el sistema de basura.
#
# ```python
# class Nodo:
#     def __init__(self, valor):
#         self.valor = valor
#         self.referencia = None
#
# a = Nodo(10)
# b = Nodo(20)
# a.referencia = b
# b.referencia = a
# ```
#
# En este ejemplo, los objetos `a` y `b` forman un ciclo de referencia. Aunque no son directamente accesibles, el sistema de recolección de basura puede detectarlos y eliminarlos.
#
# ---
#
# ##### Buenas Prácticas para Manejo de Memoria
# 1. Utilizar estructuras de datos eficientes, como `deque` para operaciones con listas.
# 2. Liberar memoria explícitamente usando `del` para eliminar referencias.
# 3. Usar generadores para manejar grandes conjuntos de datos.
# 4. Optimizar las cadenas y enteros en operaciones repetitivas.
#
# El uso del método `id`, combinado con herramientas como `hex` y el módulo `sys`, permite comprender cómo Python maneja la memoria y ayuda a optimizar los recursos del programa.

# %% [markdown]
# #### Encapsulamiento en Python
#
# El encapsulamiento es un principio de la programación orientada a objetos que permite restringir el acceso a ciertos atributos y métodos de una clase, protegiendo los datos internos del objeto. En Python, el encapsulamiento se implementa utilizando convenciones de nombres que determinan la visibilidad de los atributos y métodos.
#
# ##### Niveles de Acceso
#
# Python define tres niveles de acceso para los atributos y métodos de una clase:
#
# - **Público:** Se puede acceder directamente desde fuera de la clase.
# - **Protegido:** Se indica con un guion bajo (`_`) antes del nombre del atributo o método. Sugiere que no debe modificarse fuera de la clase, pero sigue siendo accesible.
# - **Privado:** Se indica con dos guiones bajos (`__`) antes del nombre del atributo o método. Python lo transforma internamente (`name mangling`) para dificultar su acceso externo.
#
# ```python
# class Ejemplo:
#     def __init__(self):
#         self.publico = "Accesible desde fuera"
#         self._protegido = "Debe usarse con precaución"
#         self.__privado = "Oculto fuera de la clase"
#
#     def mostrar_atributos(self):
#         print(self.publico)
#         print(self._protegido)
#         print(self.__privado)
#
# objeto = Ejemplo()
# print(objeto.publico)  # Accesible desde fuera
# print(objeto._protegido)  # No recomendado, pero posible
# # print(objeto.__privado)  # Error: atributo privado
# ```
#
# ##### Acceso a Atributos Privados
#
# Aunque los atributos privados no son directamente accesibles desde fuera de la clase, pueden ser manipulados mediante métodos internos, conocidos como **getter** y **setter**.
#
# ```python
# class CuentaBancaria:
#     def __init__(self, titular, saldo):
#         self.titular = titular
#         self.__saldo = saldo
#
#     def obtener_saldo(self):  # Getter
#         return self.__saldo
#
#     def modificar_saldo(self, cantidad):  # Setter
#         if cantidad >= 0:
#             self.__saldo = cantidad
#
# cuenta = CuentaBancaria("Luis", 1000)
# print(cuenta.obtener_saldo())  # 1000
# cuenta.modificar_saldo(2000)
# print(cuenta.obtener_saldo())  # 2000
# ```
#
# ##### Name Mangling
#
# Python renombra internamente los atributos privados agregando el nombre de la clase como prefijo, lo que evita modificaciones accidentales.
#
# ```python
# class Prueba:
#     def __init__(self):
#         self.__oculto = "Valor privado"
#
# objeto = Prueba()
# print(objeto._Prueba__oculto)  # Acceso indirecto, pero no recomendado
# ```
#
# El encapsulamiento mejora la seguridad del código y mantiene la integridad de los datos al evitar modificaciones inesperadas. Es una práctica clave en el desarrollo de sistemas que requieren control sobre los atributos y métodos de los objetos.

# %% [markdown]
# #### Atributos de clase en Python
#
# Los atributos de clase son variables que pertenecen a la propia clase y no a una instancia específica de ella. Todos los objetos creados a partir de una clase comparten los mismos atributos de clase, lo que los hace útiles para almacenar valores globales o contar instancias.
#
# ##### Declaración de atributos de clase
#
# Los atributos de clase se declaran dentro del cuerpo de la clase, pero fuera de los métodos. Se accede a ellos utilizando el nombre de la clase o a través de una instancia.
#
# ```python
# class Contador:
#     total = 0  # Atributo de clase
#
#     def __init__(self):
#         Contador.total += 1
#
# print(Contador.total)  # 0
# obj1 = Contador()
# obj2 = Contador()
# print(Contador.total)  # 2
# ```
#
# En este ejemplo, el atributo `total` es compartido por todas las instancias de `Contador`, y su valor se incrementa cada vez que se crea un nuevo objeto.
#
# ##### Acceso a atributos de clase
#
# Los atributos de clase pueden ser accedidos directamente desde la clase o a través de una instancia.
#
# ```python
# class Configuracion:
#     version = "1.0"
#
# print(Configuracion.version)  # 1.0
# objeto = Configuracion()
# print(objeto.version)  # 1.0
# ```
#
# Si el atributo de clase se modifica usando el nombre de la clase, el cambio afecta a todas las instancias.
#
# ```python
# Configuracion.version = "2.0"
# print(objeto.version)  # 2.0
# ```
#
# ##### Diferencia entre atributos de clase y atributos de instancia
#
# Mientras que los atributos de clase son compartidos, los atributos de instancia son exclusivos de cada objeto.
#
# ```python
# class Usuario:
#     contador = 0  # Atributo de clase
#
#     def __init__(self, nombre):
#         self.nombre = nombre  # Atributo de instancia
#         Usuario.contador += 1
#
# usuario1 = Usuario("Ana")
# usuario2 = Usuario("Juan")
# print(Usuario.contador)  # 2
# print(usuario1.nombre)  # Ana
# print(usuario2.nombre)  # Juan
# ```
#
# El uso de atributos de clase permite definir valores comunes y estados globales dentro de un programa sin necesidad de mantenerlos en variables externas. Su correcta aplicación mejora la eficiencia y organización del código.

# %% [markdown]
# #### Métodos de clase en Python
#
# Los métodos de clase son funciones que operan sobre la clase en sí misma y no sobre instancias específicas. Se utilizan principalmente para trabajar con atributos de clase o para proporcionar constructores alternativos.
#
# ##### Definición de un método de clase
#
# Un método de clase se define utilizando el decorador `@classmethod`. El primer parámetro del método debe ser `cls`, que representa la clase.
#
# ```python
# class Configuracion:
#     version = "1.0"
#
#     @classmethod
#     def cambiar_version(cls, nueva_version):
#         cls.version = nueva_version
#
# print(Configuracion.version)  # 1.0
# Configuracion.cambiar_version("2.0")
# print(Configuracion.version)  # 2.0
# ```
#
# En este ejemplo, el método `cambiar_version` modifica el atributo de clase `version`.
#
# ##### Acceso a métodos de clase
#
# Los métodos de clase pueden ser llamados tanto desde la clase como desde una instancia.
#
# ```python
# class Contador:
#     total = 0
#
#     @classmethod
#     def incrementar(cls):
#         cls.total += 1
#
# Contador.incrementar()
# print(Contador.total)  # 1
#
# objeto = Contador()
# objeto.incrementar()
# print(Contador.total)  # 2
# ```
#
# El método `incrementar` afecta al atributo de clase `total`, independientemente de si se llama desde la clase o desde una instancia.
#
# ##### Métodos de clase como constructores alternativos
#
# Los métodos de clase también pueden actuar como constructores alternativos, permitiendo crear instancias de la clase de formas diferentes.
#
# ```python
# class Persona:
#     def __init__(self, nombre, edad):
#         self.nombre = nombre
#         self.edad = edad
#
#     @classmethod
#     def desde_cadena(cls, cadena):
#         nombre, edad = cadena.split("-")
#         return cls(nombre, int(edad))
#
# persona1 = Persona("Juan", 30)
# persona2 = Persona.desde_cadena("Ana-25")
#
# print(persona1.nombre, persona1.edad)  # Juan 30
# print(persona2.nombre, persona2.edad)  # Ana 25
# ```
#
# En este ejemplo, el método `desde_cadena` permite crear un objeto `Persona` a partir de una cadena de texto.
#
# Los métodos de clase son herramientas poderosas para trabajar con atributos compartidos y para proporcionar flexibilidad en la creación de objetos.

# %% [markdown]
# #### Métodos de instancia en Python
#
# Los métodos de instancia son funciones definidas dentro de una clase que operan sobre los atributos específicos de cada objeto. Se utilizan para manipular los datos y el comportamiento de una instancia en particular.
#
# ##### Definición de un método de instancia
#
# Los métodos de instancia reciben `self` como primer parámetro, que representa la instancia actual de la clase.
#
# ```python
# class Persona:
#     def __init__(self, nombre, edad):
#         self.nombre = nombre
#         self.edad = edad
#
#     def presentar(self):
#         return f"Hola, mi nombre es {self.nombre} y tengo {self.edad} años."
#
# persona1 = Persona("Juan", 30)
# print(persona1.presentar())  # Hola, mi nombre es Juan y tengo 30 años.
# ```
#
# Aquí, el método `presentar` utiliza los atributos de `persona1`, mostrando información específica de la instancia.
#
# ##### Acceso y modificación de atributos
#
# Los métodos de instancia pueden acceder y modificar los atributos del objeto.
#
# ```python
# class CuentaBancaria:
#     def __init__(self, titular, saldo):
#         self.titular = titular
#         self.saldo = saldo
#
#     def depositar(self, cantidad):
#         self.saldo += cantidad
#         return f"Depósito realizado. Nuevo saldo: {self.saldo}"
#
#     def retirar(self, cantidad):
#         if cantidad <= self.saldo:
#             self.saldo -= cantidad
#             return f"Retiro exitoso. Saldo restante: {self.saldo}"
#         else:
#             return "Fondos insuficientes."
#
# cuenta = CuentaBancaria("Ana", 1000)
# print(cuenta.depositar(500))  # Depósito realizado. Nuevo saldo: 1500
# print(cuenta.retirar(200))  # Retiro exitoso. Saldo restante: 1300
# ```
#
# ##### Diferencia entre métodos de instancia y métodos de clase
#
# Mientras que los métodos de clase trabajan con atributos compartidos entre todas las instancias, los métodos de instancia operan sobre datos individuales de cada objeto.
#
# ```python
# class Producto:
#     impuesto = 0.1  # Atributo de clase
#
#     def __init__(self, nombre, precio):
#         self.nombre = nombre
#         self.precio = precio
#
#     def calcular_precio_final(self):
#         return self.precio + (self.precio * Producto.impuesto)
#
# producto1 = Producto("Laptop", 1000)
# producto2 = Producto("Teléfono", 500)
#
# print(producto1.calcular_precio_final())  # 1100.0
# print(producto2.calcular_precio_final())  # 550.0
# ```
#
# Los métodos de instancia permiten que cada objeto tenga un comportamiento único, manipulando sus atributos sin afectar a otras instancias de la misma clase.
# Estos métodos son fundamentales para definir acciones específicas que cada objeto puede realizar dentro de un programa.

# %% [markdown]
# #### Herencia en Python
#
# La herencia es un mecanismo fundamental de la **Programación Orientada a Objetos (POO)** que permite que una clase hija herede atributos y métodos de una clase padre. Gracias a la herencia, se pueden reutilizar características comunes sin necesidad de duplicar código, facilitando la organización y mantenimiento del software.
#
# ##### Tipos de herencia
#
# Python admite varios tipos de herencia, cada uno con sus propias características y aplicaciones.
#
# - **Herencia simple**
#   1. Una clase hija hereda directamente de una única clase padre. Es el tipo de herencia más común y permite extender o modificar el comportamiento de la clase base.
#   2. Ejemplo:
#
#      ```python
#      class Animal:
#          def __init__(self, nombre):
#              self.nombre = nombre
#
#          def hacer_sonido(self):
#              return "Hace un sonido genérico"
#
#      class Perro(Animal):
#          def hacer_sonido(self):
#              return "Ladra"
#
#      # Creación de instancias
#      animal = Animal("Criatura")
#      perro = Perro("Firulais")
#
#      print(animal.hacer_sonido())  # Output: Hace un sonido genérico
#      print(perro.hacer_sonido())   # Output: Ladra
#      ```
#
# - **Herencia múltiple**
#   1. Una clase hija puede heredar de múltiples clases padre. Se utiliza cuando se desea combinar funcionalidades de diferentes clases base.
#   2. Ejemplo:
#
#      ```python
#      class Ave:
#          def volar(self):
#              return "Puede volar"
#
#      class Mamifero:
#          def amamantar(self):
#              return "Amamanta a sus crías"
#
#      class Murcielago(Ave, Mamifero):
#          def sonido(self):
#              return "Chilla"
#
#      murcielago = Murcielago()
#      print(murcielago.volar())       # Output: Puede volar
#      print(murcielago.amamantar())   # Output: Amamanta a sus crías
#      print(murcielago.sonido())      # Output: Chilla
#      ```
#
#   - **Consideraciones sobre la herencia múltiple**
#     - **Conflictos de métodos**
#       Si las clases padre tienen métodos con el mismo nombre, Python sigue el orden de definición de las clases en la herencia.
#
#       ```python
#       class ClaseA:
#           def saludar(self):
#               return "Hola desde ClaseA"
#
#       class ClaseB:
#           def saludar(self):
#               return "Hola desde ClaseB"
#
#       class ClaseC(ClaseA, ClaseB):
#           pass
#
#       objeto = ClaseC()
#       print(objeto.saludar())  # Output: Hola desde ClaseA
#       ```
#
#     - **Uso del MRO (Method Resolution Order)**
#       Python resuelve la herencia múltiple mediante el **C3 Linearization**, una técnica que define el orden de búsqueda de métodos.
#       Se puede visualizar con `mro()`.
#
#       ```python
#       print(ClaseC.mro())
#       # Output: [<class '__main__.ClaseC'>, <class '__main__.ClaseA'>, <class '__main__.ClaseB'>, <class 'object'>]
#       ```
#
#       - *Alternativa con composición*
#         En algunos casos, es mejor utilizar **composición** en lugar de herencia múltiple para reducir la complejidad y mejorar la claridad del código.
#         Se evita la ambigüedad al no compartir métodos entre clases padre.
#
#         ```python
#         class Motor:
#             def arrancar(self):
#                 return "El motor ha arrancado"
#
#         class Coche:
#             def __init__(self):
#                 self.motor = Motor()  # Composición en lugar de herencia
#
#             def encender(self):
#                 return self.motor.arrancar()
#
#         coche = Coche()
#         print(coche.encender())  # Output: El motor ha arrancado
#         ```
#
# ##### Uso del método `super()`
#
# El método `super()` en Python permite a una clase hija llamar métodos de la clase padre. Esto evita duplicaciones de código y facilita la reutilización de funcionalidades dentro de la jerarquía de clases.
#
# - **Llamada al constructor de la clase padre con `super()`**
#
#   ```python
#   class Persona:
#       def __init__(self, nombre):
#           self.nombre = nombre
#
#       def saludar(self):
#           return f"Hola, soy {self.nombre}"
#
#   class Estudiante(Persona):
#       def __init__(self, nombre, carrera):
#           super().__init__(nombre)  # Llamada al constructor de la clase padre
#           self.carrera = carrera
#
#       def presentar(self):
#           return f"{super().saludar()} y estudio {self.carrera}"
#
#   estudiante = Estudiante("Miguel", "Informática")
#   print(estudiante.presentar())  # Output: Hola, soy Miguel y estudio Informática
#   ```
#
# - **Uso de `super()` en métodos sobrescritos**
#
#   ```python
#   class Animal:
#       def sonido(self):
#           return "Hace un sonido"
#
#   class Perro(Animal):
#       def sonido(self):
#           return f"{super().sonido()} pero específicamente, ladra"
#
#   perro = Perro()
#   print(perro.sonido())  # Output: Hace un sonido pero específicamente, ladra
#   ```
#
# ##### Sobrescritura de métodos
#
# Cuando una clase hija necesita modificar el comportamiento de un método heredado, puede sobrescribirlo definiéndolo nuevamente en la clase hija.
#
# - **Ejemplo de sobrescritura de métodos**
#
#   ```python
#   class Figura:
#       def area(self):
#           return "Área no definida"
#
#   class Cuadrado(Figura):
#       def __init__(self, lado):
#           self.lado = lado
#
#       def area(self):
#           return self.lado ** 2
#
#   cuadrado = Cuadrado(4)
#   print(cuadrado.area())  # Output: 16
#   ```
#
# En este caso, la clase `Cuadrado` sobrescribe el método `area()` de `Figura`, proporcionando una implementación específica.
#
# La herencia en Python es una técnica potente que permite reutilizar código y estructurar aplicaciones de manera más clara. Sin embargo, es importante emplearla de manera adecuada, asegurando que la relación entre clases sea lógica y aprovechando herramientas como `super()` y la sobrescritura de métodos para mejorar la mantenibilidad del software.

# %% [markdown]
# #### Polimorfismo en Python
#
# El **polimorfismo** es un principio fundamental de la **Programación Orientada a Objetos (POO)** que permite que objetos de diferentes clases sean tratados como si pertenecieran a una misma clase base. Esto se logra mediante la sobrescritura de métodos y la implementación de métodos comunes en distintas clases.
#
# ##### Concepto de polimorfismo
#
# El polimorfismo permite que múltiples clases compartan una misma interfaz, facilitando el uso de métodos de manera uniforme sin importar la clase específica del objeto.
#
# - **Ejemplo básico de polimorfismo**
#
#   ```python
#   class Animal:
#       def sonido(self):
#           return "Hace un sonido"
#
#   class Perro(Animal):
#       def sonido(self):
#           return "Ladra"
#
#   class Gato(Animal):
#       def sonido(self):
#           return "Maúlla"
#
#   # Uso del polimorfismo
#   def hacer_sonido(animal):
#       print(animal.sonido())
#
#   perro = Perro()
#   gato = Gato()
#
#   hacer_sonido(perro)  # Output: Ladra
#   hacer_sonido(gato)   # Output: Maúlla
#   ```
#
# ##### Tipos de polimorfismo en Python
#
# - **Polimorfismo en funciones**
#   1. Se pueden definir funciones que aceptan múltiples tipos de objetos sin necesidad de especificar su clase exacta.
#   2. Ejemplo:
#
#      ```python
#      class Circulo:
#          def area(self):
#              return "Área del círculo"
#
#      class Cuadrado:
#          def area(self):
#              return "Área del cuadrado"
#
#      def calcular_area(figura):
#          print(figura.area())
#
#      circulo = Circulo()
#      cuadrado = Cuadrado()
#
#      calcular_area(circulo)  # Output: Área del círculo
#      calcular_area(cuadrado) # Output: Área del cuadrado
#      ```
#
# - **Polimorfismo en clases heredadas**
#   1. Las clases hijas pueden sobrescribir métodos de la clase padre, permitiendo comportamientos específicos.
#   2. Ejemplo:
#
#      ```python
#      class Empleado:
#          def salario(self):
#              return "Salario estándar"
#
#      class Gerente(Empleado):
#          def salario(self):
#              return "Salario más bonificaciones"
#
#      class Obrero(Empleado):
#          def salario(self):
#              return "Salario base"
#
#      def mostrar_salario(empleado):
#          print(empleado.salario())
#
#      gerente = Gerente()
#      obrero = Obrero()
#
#      mostrar_salario(gerente)  # Output: Salario más bonificaciones
#      mostrar_salario(obrero)   # Output: Salario base
#      ```
#
# ##### Clases abstractas y polimorfismo
#
# Las clases abstractas permiten definir una interfaz común que otras clases deben implementar, facilitando el polimorfismo. En Python, se pueden crear utilizando `ABC` (Abstract Base Classes).
#
# - **Ejemplo de clases abstractas y polimorfismo**
#
#   ```python
#   from abc import ABC, abstractmethod
#
#   class Vehiculo(ABC):
#       @abstractmethod
#       def mover(self):
#           pass
#
#   class Coche(Vehiculo):
#       def mover(self):
#           return "El coche está en movimiento"
#
#   class Bicicleta(Vehiculo):
#       def mover(self):
#           return "La bicicleta está en movimiento"
#
#   def iniciar_movimiento(vehiculo):
#       print(vehiculo.mover())
#
#   coche = Coche()
#   bicicleta = Bicicleta()
#
#   iniciar_movimiento(coche)      # Output: El coche está en movimiento
#   iniciar_movimiento(bicicleta)  # Output: La bicicleta está en movimiento
#   ```
#
# El polimorfismo es una técnica esencial en la POO que permite diseñar sistemas más flexibles y reutilizables. Gracias a su implementación, es posible trabajar con distintos tipos de objetos sin necesidad de conocer su estructura interna, mejorando así la escalabilidad y mantenimiento del código. Además, el uso de clases abstractas refuerza este principio al garantizar una interfaz común que las clases concretas deben implementar.

# %% [markdown]
# ### Sección 9: Temas Avanzados en Python

# %% [markdown]
# #### Comprensión de Listas en Python
#
# La **comprensión de listas** es una técnica poderosa en Python que permite crear listas de manera concisa y eficiente. Utiliza una sintaxis compacta para generar listas sin necesidad de usar bucles `for` explícitos.
#
# ##### Sintaxis básica de comprensión de listas
#
# ```python
# [nueva_expresión for elemento in iterable if condición]
# ```
#
# ##### Ejemplos de comprensión de listas
#
# - **Crear una lista de cuadrados de números del 1 al 10**
#
#   ```python
#   cuadrados = [x**2 for x in range(1, 11)]
#   print(cuadrados)
#   # Output: [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]
#   ```
#
# - **Filtrar números pares en una lista**
#
#   ```python
#   pares = [x for x in range(1, 11) if x % 2 == 0]
#   print(pares)
#   # Output: [2, 4, 6, 8, 10]
#   ```
#
# - **Convertir una lista de palabras a mayúsculas**
#
#   ```python
#   palabras = ["python", "listas", "comprensión"]
#   mayusculas = [palabra.upper() for palabra in palabras]
#   print(mayusculas)
#   # Output: ['PYTHON', 'LISTAS', 'COMPRENSIÓN']
#   ```
#
# ##### Comprensión de listas con múltiples condiciones
#
# Se pueden agregar varias condiciones para obtener listas más específicas.
#
# - **Obtener números pares mayores a 5**
#
#   ```python
#   pares_mayores_5 = [x for x in range(1, 11) if x % 2 == 0 and x > 5]
#   print(pares_mayores_5)
#   # Output: [6, 8, 10]
#   ```
#
# ##### Comprensión de listas con estructuras anidadas
#
# También es posible usar comprensión de listas para manejar listas dentro de listas.
#
# - **Generar una matriz 3x3**
#
#   ```python
#   matriz = [[x for x in range(1, 4)] for y in range(3)]
#   print(matriz)
#   # Output: [[1, 2, 3], [1, 2, 3], [1, 2, 3]]
#   ```
#
# ##### Uso de comprensión de listas con funciones
#
# Podemos aplicar funciones dentro de la comprensión de listas para transformar los datos.
#
# - **Calcular la longitud de cada palabra en una lista**
#
#   ```python
#   palabras = ["Python", "comprensión", "listas"]
#   longitudes = [len(palabra) for palabra in palabras]
#   print(longitudes)
#   # Output: [6, 11, 6]
#   ```
#
# La comprensión de listas es una herramienta poderosa para escribir código más limpio y eficiente. Su uso adecuado mejora la legibilidad y el rendimiento en la manipulación de listas en Python.

# %% [markdown]
# #### Función `zip()` en Python
#
# La función `zip()` en Python se utiliza para combinar múltiples iterables (listas, tuplas, etc.) en pares o grupos de elementos correspondientes. Retorna un objeto **zip**, que puede ser convertido en una lista o tupla.
#
# ##### Sintaxis básica
#
# ```python
# zip(iterable1, iterable2, ...)
# ```
#
# ##### Ejemplos de uso
#
# - **Emparejar elementos de dos listas**
#
#   ```python
#   nombres = ["Ana", "Carlos", "Elena"]
#   edades = [25, 30, 22]
#
#   resultado = list(zip(nombres, edades))
#   print(resultado)
#   # Output: [('Ana', 25), ('Carlos', 30), ('Elena', 22)]
#   ```
#
# - **Iterar sobre múltiples listas simultáneamente**
#
#   ```python
#   colores = ["rojo", "verde", "azul"]
#   objetos = ["manzana", "hoja", "mar"]
#
#   for color, objeto in zip(colores, objetos):
#       print(f"{color} → {objeto}")
#
#   # Output:
#   # rojo → manzana
#   # verde → hoja
#   # azul → mar
#   ```
#
# ##### Manejo de listas de diferente longitud
#
# Si los iterables tienen distinta cantidad de elementos, `zip()` solo empareja hasta el tamaño del iterable más corto.
#
# ```python
# lista1 = [1, 2, 3, 4]
# lista2 = ["a", "b"]
#
# resultado = list(zip(lista1, lista2))
# print(resultado)
# # Output: [(1, 'a'), (2, 'b')]
# ```
#
# ##### Uso de `zip()` con `*` para descomprimir listas
#
# La función `zip()` también puede utilizarse para descomprimir listas usando el operador `*`.
#
# ```python
# pares = [(1, 'a'), (2, 'b'), (3, 'c')]
# numeros, letras = zip(*pares)
#
# print(numeros)  # Output: (1, 2, 3)
# print(letras)   # Output: ('a', 'b', 'c')
# ```
#
# ##### Uso avanzado con `dict()`
#
# Podemos convertir el resultado de `zip()` en un diccionario.
#
# ```python
# claves = ["nombre", "edad", "ciudad"]
# valores = ["Miguel", 28, "Madrid"]
#
# diccionario = dict(zip(claves, valores))
# print(diccionario)
# # Output: {'nombre': 'Miguel', 'edad': 28, 'ciudad': 'Madrid'}
# ```
#
# La función `zip()` es una herramienta útil para combinar datos de diferentes estructuras de manera sencilla y eficiente, facilitando la manipulación y organización de información en Python.

# %% [markdown]
# #### Manejo de Cadenas en Python
#
# Las **cadenas de texto** en Python son secuencias de caracteres utilizadas para almacenar y manipular texto. Se pueden definir utilizando comillas simples (`'Texto'`), dobles (`"Texto"`) o triples (`'''Texto'''`). Además de permitir la manipulación de texto, Python ofrece múltiples métodos que facilitan la gestión y transformación de cadenas.
#
# ##### Creación y manipulación de cadenas
#
# ```python
# cadena = "Hola, Python!"
# print(cadena)  # Output: Hola, Python!
# ```
#
# ##### Operaciones básicas con cadenas
#
# - **Concatenación**
#
#   ```python
#   parte1 = "Hola"
#   parte2 = "Mundo"
#   resultado = parte1 + " " + parte2
#   print(resultado)  # Output: Hola Mundo
#   ```
#
# - **Repetición de cadenas**
#
#   ```python
#   repetir = "Python " * 3
#   print(repetir)  # Output: Python Python Python
#   ```
#
# - **Acceder a caracteres individuales**
#
#   ```python
#   texto = "Python"
#   print(texto[0])  # Output: P
#   print(texto[-1]) # Output: n
#   ```
#
# ##### Métodos útiles para manipulación de cadenas
#
# - **Convertir a mayúsculas y minúsculas**
#
#   ```python
#   texto = "Python es genial"
#   print(texto.upper())   # Output: PYTHON ES GENIAL
#   print(texto.lower())   # Output: python es genial
#   ```
#
# - **Eliminar espacios al inicio y al final**
#
#   ```python
#   texto = "  Python  "
#   print(texto.strip())  # Output: Python
#   ```
#
# - **Reemplazar texto**
#
#   ```python
#   texto = "Hola Mundo"
#   print(texto.replace("Mundo", "Python"))  # Output: Hola Python
#   ```
#
# - **Dividir cadenas**
#
#   ```python
#   texto = "Python,Java,C++"
#   lista_lenguajes = texto.split(",")
#   print(lista_lenguajes)  # Output: ['Python', 'Java', 'C++']
#   ```
#
# ##### Uso de `join()` para unir cadenas
#
# - **Convertir una lista en una cadena**
#
#   ```python
#   palabras = ["Hola", "Mundo", "Python"]
#   resultado = " ".join(palabras)
#   print(resultado)  # Output: Hola Mundo Python
#   ```
#
# ##### Formateo de cadenas
#
# - **Uso de `f-strings`**
#
#   ```python
#   nombre = "Miguel"
#   edad = 30
#   print(f"Hola, mi nombre es {nombre} y tengo {edad} años.")
#   # Output: Hola, mi nombre es Miguel y tengo 30 años.
#   ```
#
# ##### Verificación de contenido en cadenas
#
# - **Comprobar si una subcadena está presente**
#
#   ```python
#   texto = "Programación en Python"
#   print("Python" in texto)  # Output: True
#   print("Java" not in texto)  # Output: True
#   ```
#
# ##### Slicing en cadenas
#
# Python permite acceder a fragmentos de una cadena mediante **slicing**.
#
# ```python
# texto = "Programación en Python"
# print(texto[0:11])  # Output: Programación
# print(texto[-6:])   # Output: Python
# ```
#
# ##### Cadenas de varias líneas
#
# Se pueden definir cadenas de varias líneas utilizando comillas triples.
#
# ```python
# mensaje = """Este es un mensaje
# que ocupa varias líneas
# en Python."""
# print(mensaje)
# ```
#
# ##### Conversión de tipos con cadenas
#
# - **Convertir números a cadenas**
#
#   ```python
#   numero = 42
#   cadena_numero = str(numero)
#   print(cadena_numero)  # Output: '42'
#   ```
#
# - **Convertir cadenas a números**
#
#   ```python
#   cadena = "56"
#   numero = int(cadena)
#   print(numero * 2)  # Output: 112
#   ```
#
# ##### Expresiones regulares en cadenas
#
# Python permite trabajar con expresiones regulares para encontrar, reemplazar y manipular texto de manera avanzada.
#
# ```python
# import re
#
# texto = "Python es un lenguaje poderoso"
# resultado = re.search(r"lenguaje", texto)
# print(resultado.group())  # Output: lenguaje
# ```
#
# El manejo de cadenas es esencial en Python, ya que permite interactuar con texto de manera eficiente y estructurada. Desde operaciones básicas hasta manipulación avanzada con expresiones regulares, Python ofrece múltiples herramientas para trabajar con texto de forma efectiva.

# %% [markdown]
# #### Funciones Lambda en Python
#
# Las **funciones lambda** en Python son funciones anónimas que permiten definir pequeñas funciones en una sola línea sin necesidad de utilizar la palabra clave `def`. Son útiles para operaciones rápidas y se usan comúnmente en combinación con funciones de orden superior.
#
# ##### Definición y sintaxis
#
# Una función lambda sigue la siguiente estructura:
#
# ```python
# lambda argumentos: expresión
# ```
#
# - **Ejemplo básico de función lambda**
#
#   ```python
#   suma = lambda x, y: x + y
#   print(suma(5, 3))  # Output: 8
#   ```
#
# - **Ejemplo de función lambda con un solo argumento**
#
#   ```python
#   cuadrado = lambda x: x**2
#   print(cuadrado(4))  # Output: 16
#   ```
#
# ##### Uso de funciones lambda con funciones de orden superior
#
# Las funciones lambda suelen combinarse con `map()`, `filter()` y `reduce()` para procesar listas y otros iterables de manera eficiente.
#
# - **`map()`: Aplicar una función a todos los elementos de un iterable**
#   `map()` toma una función y un iterable, aplicando la función a cada elemento del iterable y devolviendo un objeto `map`.
#
#   ```python
#   numeros = [1, 2, 3, 4, 5]
#   cuadrados = list(map(lambda x: x**2, numeros))
#   print(cuadrados)  # Output: [1, 4, 9, 16, 25]
#   ```
#
# - **`filter()`: Filtrar elementos de un iterable según una condición**
#   `filter()` toma una función y un iterable, devolviendo solo los elementos que cumplen la condición de la función.
#
#   ```python
#   numeros = [1, 2, 3, 4, 5, 6]
#   pares = list(filter(lambda x: x % 2 == 0, numeros))
#   print(pares)  # Output: [2, 4, 6]
#   ```
#
# - **`reduce()`: Reducir un iterable a un único valor**
#   `reduce()` aplica una función acumulativa sobre los elementos de un iterable y devuelve un único valor.
#
#   ```python
#   from functools import reduce
#   numeros = [1, 2, 3, 4, 5]
#   suma_total = reduce(lambda x, y: x + y, numeros)
#   print(suma_total)  # Output: 15
#   ```
#
# ##### Funciones lambda con múltiples argumentos
#
# Las funciones lambda pueden aceptar varios argumentos, igual que una función normal.
#
# ```python
# multiplicar = lambda x, y, z: x * y * z
# print(multiplicar(2, 3, 4))  # Output: 24
# ```
#
# ##### Funciones lambda con condicionales
#
# Es posible agregar condiciones dentro de una función lambda usando expresiones ternarias.
#
# ```python
# mayor = lambda x, y: x if x > y else y
# print(mayor(5, 3))  # Output: 5
# ```
#
# ##### Funciones lambda dentro de listas y diccionarios
#
# También es posible almacenar funciones lambda dentro de estructuras de datos.
#
# ```python
# operaciones = {
#     "suma": lambda x, y: x + y,
#     "resta": lambda x, y: x - y,
#     "multiplicacion": lambda x, y: x * y
# }
#
# print(operaciones["suma"](5, 3))  # Output: 8
# print(operaciones["multiplicacion"](4, 2))  # Output: 8
# ```
#
# ##### Comparación entre funciones lambda y funciones normales
#
# Las funciones lambda son útiles para expresiones cortas, pero si el código necesita varias operaciones o mayor legibilidad, es recomendable usar funciones normales.
#
# ```python
# # Usando función lambda
# multiplicar = lambda x, y: x * y
#
# # Usando una función tradicional
# def multiplicar_tradicional(x, y):
#     return x * y
#
# print(multiplicar(3, 4))               # Output: 12
# print(multiplicar_tradicional(3, 4))   # Output: 12
# ```
#
# Las funciones lambda en Python son una herramienta poderosa para simplificar el código en operaciones breves y reutilizables. Su combinación con funciones de orden superior las hace ideales para manipulación de datos y optimización de procesos en una sola línea. Además, permiten escribir código más compacto sin comprometer la funcionalidad.

# %% [markdown]
# #### Ordenamiento (`sorted()`) en Python
#
# El **ordenamiento** es una técnica fundamental en Python para organizar datos en listas, tuplas y otros iterables. La función `sorted()` permite realizar ordenamientos personalizados mediante distintos criterios.
#
# ##### Uso básico de `sorted()`
#
# ```python
# numeros = [5, 2, 9, 1, 7]
# ordenados = sorted(numeros)
# print(ordenados)  # Output: [1, 2, 5, 7, 9]
# ```
#
# ##### Ordenamiento en orden inverso
#
# ```python
# numeros = [5, 2, 9, 1, 7]
# ordenados_desc = sorted(numeros, reverse=True)
# print(ordenados_desc)  # Output: [9, 7, 5, 2, 1]
# ```
#
# ##### Ordenamiento de cadenas
#
# ```python
# palabras = ["banana", "manzana", "cereza"]
# ordenadas = sorted(palabras)
# print(ordenadas)  # Output: ['banana', 'cereza', 'manzana']
# ```
#
# ##### Ordenamiento personalizado con `key`
#
# ```python
# palabras = ["banana", "manzana", "cereza"]
# ordenadas_por_longitud = sorted(palabras, key=len)
# print(ordenadas_por_longitud)  # Output: ['cereza', 'banana', 'manzana']
# ```
#
# ```python
# estudiantes = [
#     {"nombre": "Ana", "edad": 22},
#     {"nombre": "Carlos", "edad": 20},
#     {"nombre": "Elena", "edad": 25}
# ]
# ordenados_por_edad = sorted(estudiantes, key=lambda x: x["edad"])
# print(ordenados_por_edad)
# # Output: [{'nombre': 'Carlos', 'edad': 20}, {'nombre': 'Ana', 'edad': 22}, {'nombre': 'Elena', 'edad': 25}]
# ```
#
# ##### Diferencias entre `sorted()` y `list.sort()`
#
# | Método       | Devuelve una nueva lista | Modifica el original |
# |-------------|-------------------------|----------------------|
# | `sorted()`  | Sí                      | No                  |
# | `list.sort()` | No                      | Sí                  |
#
# ```python
# numeros = [5, 2, 9, 1, 7]
# numeros.sort()
# print(numeros)  # Output: [1, 2, 5, 7, 9]
# ```
#
# ##### Ordenamiento de diccionarios con `sorted()`
#
# ```python
# diccionario = {"b": 2, "c": 1, "a": 3}
# ordenado_por_clave = dict(sorted(diccionario.items()))
# print(ordenado_por_clave)
# # Output: {'a': 3, 'b': 2, 'c': 1}
# ```
#
# ```python
# ordenado_por_valor = dict(sorted(diccionario.items(), key=lambda x: x[1]))
# print(ordenado_por_valor)
# # Output: {'c': 1, 'b': 2, 'a': 3}
# ```
#
# ```python
# ordenado_descendente = dict(sorted(diccionario.items(), key=lambda x: x[1], reverse=True))
# print(ordenado_descendente)
# # Output: {'a': 3, 'b': 2, 'c': 1}
# ```
#
# ##### Ordenamiento con estructuras más complejas
#
# ```python
# productos = [("Manzana", 5), ("Plátano", 2), ("Cereza", 8)]
# ordenados_por_precio = sorted(productos, key=lambda x: x[1])
# print(ordenados_por_precio)
# # Output: [('Plátano', 2), ('Manzana', 5), ('Cereza', 8)]
# ```
#
# ```python
# datos = [[3, "Carlos"], [1, "Ana"], [2, "Elena"]]
# ordenados = sorted(datos, key=lambda x: x[0])
# print(ordenados)
# # Output: [[1, 'Ana'], [2, 'Elena'], [3, 'Carlos']]
# ```
#
# ##### Conclusión
#
# La función `sorted()` es una herramienta versátil y eficiente para ordenar listas, tuplas y diccionarios en Python. Gracias al uso del parámetro `key`, se pueden personalizar los criterios de ordenamiento, lo que permite manipular estructuras de datos de manera avanzada. Su correcto uso mejora la legibilidad y eficiencia del código.

# %% [markdown]
# #### Generadores en Python
#
# Los **generadores** en Python permiten producir valores **bajo demanda**, sin necesidad de almacenar todos los datos en memoria. Son útiles para manejar grandes volúmenes de información, mejorar la eficiencia del código y optimizar el uso de recursos.
#
# ##### Creación de un generador con `yield`
#
# Un generador se define como una función que, en lugar de `return`, usa `yield` para **pausar** la ejecución y reanudarla en cada llamada.
#
# ```python
# def contador(n):
#     i = 0
#     while i < n:
#         yield i  # Devuelve el valor actual de i y pausa la ejecución
#         i += 1
#
# # Uso del generador
# gen = contador(5)
# print(list(gen))  # Output: [0, 1, 2, 3, 4]
# ```
#
# ##### Diferencia entre `return` y `yield`
#
# | Característica | `return` | `yield` |
# |--------------|---------|---------|
# | Detiene la función | Sí | No |
# | Devuelve un valor | Sí | Sí, pero genera una secuencia |
# | Se puede iterar | No | Sí |
#
# ---
#
# ##### Iterar un generador con `next()`
#
# Cada vez que se llama a `next()`, el generador **reanuda** la ejecución desde el último `yield` y **pausa** nuevamente al encontrar otro `yield`.
#
# ```python
# gen = contador(3)
# print(next(gen))  # Output: 0
# print(next(gen))  # Output: 1
# print(next(gen))  # Output: 2
# ```
#
# Cuando se llega al límite definido por el generador, se lanza la excepción `StopIteration`.
#
# ---
#
# ##### Generadores con expresiones
#
# Se pueden crear generadores en una sola línea, similar a las **comprensiones de listas**, pero sin almacenar todos los elementos en memoria.
#
# ```python
# gen = (x**2 for x in range(5))
# print(list(gen))  # Output: [0, 1, 4, 9, 16]
# ```
#
# ---
#
# ##### ¿Qué ocurre si imprimimos directamente un generador?
#
# Si hacemos `print(gen)` sin iterarlo, veremos que Python solo nos mostrará que `gen` es un **objeto generador**, sin los valores generados:
#
# ```python
# print(gen)
# # Output: <generator object contador at 0x...>
# ```
#
# Para visualizar los valores generados, debemos **iterar** el generador o convertirlo a una lista:
#
# ```python
# print(list(gen))  # Output: [0, 1, 4, 9, 16]
# ```
#
# Si intentamos imprimir `list(gen)` por segunda vez, obtendremos una lista vacía `[]`, porque el generador **ya ha sido consumido**.
#
# ---
#
# ##### Uso práctico de generadores
#
# Los generadores son útiles en escenarios donde el consumo de memoria es un factor crítico.
#
# - **Generar una secuencia infinita**
#
#   ```python
#   def infinito():
#       i = 0
#       while True:
#           yield i
#           i += 1
#
#   gen = infinito()
#   print(next(gen))  # Output: 0
#   print(next(gen))  # Output: 1
#   ```
#
# - **Leer archivos línea por línea sin cargar todo en memoria**
#
#   ```python
#   def leer_archivo(nombre):
#       with open(nombre, "r") as archivo:
#           for linea in archivo:
#               yield linea.strip()
#
#   gen = leer_archivo("datos.txt")
#   for linea in gen:
#       print(linea)
#   ```
#
# ---
#
# ##### Conclusión
#
# Los generadores en Python permiten procesar grandes volúmenes de datos sin cargar todo en memoria. Gracias a `yield`, la ejecución se **pausa y reanuda** de manera eficiente, lo que los hace ideales para manejar flujos de datos o iteraciones largas.
# Su correcto uso mejora el rendimiento y la eficiencia del código. Además, al imprimir un generador sin iterarlo, Python solo muestra que es un **objeto generador**, por lo que es necesario convertirlo a una lista o iterarlo para ver los valores generados.

# %% [markdown]
# #### Expresiones Generadoras en Python
#
# Las **expresiones generadoras** en Python son una alternativa concisa a las funciones generadoras, permitiendo crear generadores en una sola línea con una sintaxis similar a las **comprensiones de listas**, pero sin almacenar todos los valores en memoria.
#
# ##### Creación de una expresión generadora
#
# Se pueden definir expresiones generadoras usando paréntesis `()` en lugar de corchetes `[]`.
#
# ```python
# gen = (x**2 for x in range(5))
# print(list(gen))  # Output: [0, 1, 4, 9, 16]
# ```
#
# ##### Diferencia entre listas y expresiones generadoras
#
# | Característica | Comprensión de listas | Expresión generadora |
# |--------------|---------------------|---------------------|
# | Devuelve | Lista completa | Generador |
# | Almacena datos | Sí | No |
# | Consumo de memoria | Alto | Bajo |
#
# ```python
# lista = [x**2 for x in range(1000000)]  # Ocupa más memoria
# gen = (x**2 for x in range(1000000))    # Genera valores bajo demanda
# ```
#
# ---
#
# ##### Uso de `next()` en expresiones generadoras
#
# Las expresiones generadoras se pueden iterar con `next()`.
#
# ```python
# gen = (x for x in range(3))
# print(next(gen))  # Output: 0
# print(next(gen))  # Output: 1
# print(next(gen))  # Output: 2
# ```
#
# Cuando se llega al final, se lanza `StopIteration`.
#
# ---
#
# ##### Ventajas de las expresiones generadoras
#
# - **Menor uso de memoria**
#   ```python
#   import sys
#   lista = [x**2 for x in range(1000000)]
#   gen = (x**2 for x in range(1000000))
#
#   print(sys.getsizeof(lista))  # Output: tamaño en bytes de la lista
#   print(sys.getsizeof(gen))  # Output: tamaño del generador (mucho menor)
#   ```
#
# - **Útiles para procesar datos grandes**
#   ```python
#   def leer_archivo(nombre):
#       return (linea.strip() for linea in open(nombre))
#
#   for linea in leer_archivo("datos.txt"):
#       print(linea)
#   ```
#
# ---
#
# ##### Conclusión
#
# Las expresiones generadoras permiten definir generadores de manera compacta y eficiente, sin almacenar todos los valores en memoria. Son ideales para procesar grandes volúmenes de datos con un consumo mínimo de recursos.
# Si el programa requiere iteraciones sobre grandes conjuntos de datos, usar expresiones generadoras **optimiza el rendimiento** sin afectar la funcionalidad.

# %% [markdown]
# #### Decoradores en Python
#
# Los **decoradores** en Python permiten modificar el comportamiento de una función sin alterar su código fuente. Son ampliamente utilizados para estructurar mejor el código y hacer funciones más reutilizables.
#
# ##### **Código de ejemplo con explicaciones línea por línea**
#
# A continuación se presenta un decorador en Python que modifica el comportamiento de una función antes y después de su ejecución.
#
# ```python
# # Definición del decorador
# def decorador(funcion):
#     def funcion_modificada():
#         print("Antes de ejecutar la función")  # Mensaje antes de ejecutar la función original
#         funcion()  # Llamada a la función decorada (ejecuta su código)
#         print("Después de ejecutar la función")  # Mensaje después de ejecutar la función original
#     return funcion_modificada  # Se devuelve la función modificada para su uso
# ```
#
# **Explicación línea por línea:**
# 1️⃣ `def decorador(funcion):` → Define la función decoradora que recibe una función como argumento.
# 2️⃣ `def funcion_modificada():` → Dentro del decorador, se define una nueva función que agregará comportamiento adicional.
# 3️⃣ `print("Antes de ejecutar la función")` → Se ejecuta antes de la función original.
# 4️⃣ `funcion()` → Llama a la función que ha sido decorada, ejecutando su código.
# 5️⃣ `print("Después de ejecutar la función")` → Se ejecuta después de la función original.
# 6️⃣ `return funcion_modificada` → Retorna la nueva función con modificaciones.
#
# ---
#
# ##### **Aplicación del decorador**
#
# Ahora aplicamos el decorador a una función llamada `saludar` usando `@decorador`.
#
# ```python
# @decorador  # Aplica el decorador a la función saludar
# def saludar():
#     print("Hola, mundo!")  # Mensaje de la función original
# ```
#
# **Explicación línea por línea:**
# 1️⃣ `@decorador` → Indica que la función `saludar` será modificada por `decorador`.
# 2️⃣ `def saludar():` → Define la función original.
# 3️⃣ `print("Hola, mundo!")` → Mensaje que imprime la función sin decorador.
#
# ---
#
# ##### **Ejecución de la función decorada**
#
# Finalmente, llamamos a la función `saludar()`, que ahora está decorada.
#
# ```python
# saludar()
# ```
#
# **Salida esperada:**
# ```
# Antes de ejecutar la función
# Hola, mundo!
# Después de ejecutar la función
# ```
#
# **Explicación del flujo de ejecución:**
# ✅ Se ejecuta `print("Antes de ejecutar la función")`.
# ✅ Se ejecuta `print("Hola, mundo!")` dentro de `saludar()`.
# ✅ Se ejecuta `print("Después de ejecutar la función")`.
#
# ---
#
# ##### **Conclusión**
#
# El decorador ha modificado la función `saludar()` sin alterar su código original. Ahora, cada vez que llamemos `saludar()`, se imprimirá un mensaje antes y después de su ejecución.
# Este mecanismo es clave en **programación avanzada**, permitiendo reutilizar código sin modificar la lógica interna de las funciones decoradas.

# %% [markdown]
# #### Función `sum()` y `next()` en Python
#
# Las funciones **`sum()`** y **`next()`** en Python son herramientas fundamentales para la manipulación de iterables.
# - **`sum()`** permite sumar elementos de una secuencia de manera eficiente.
# - **`next()`** se usa para obtener elementos de un iterador **uno a uno**, sin necesidad de recorrer toda la estructura.
#
# ---
#
# ##### **Función `sum()`**
#
# La función **`sum()`** permite calcular la suma de los elementos de un iterable como listas o tuplas.
#
# ```python
# numeros = [1, 2, 3, 4, 5]
# resultado = sum(numeros)
# print(resultado)  # Output: 15
# ```
#
# ##### **Uso con un valor inicial**
#
# Podemos añadir un valor inicial opcional al cálculo.
#
# ```python
# resultado = sum(numeros, 10)
# print(resultado)  # Output: 25
# ```
#
# ##### **Uso con generadores**
#
# Cuando se utiliza **`sum()`** con generadores, los valores son procesados **bajo demanda**, sin almacenar grandes listas en memoria.
#
# ```python
# resultado = sum(x**2 for x in range(4))
# print(resultado)  # Output: 14 (0² + 1² + 2² + 3²)
# ```
#
# ---
#
# ##### **Función `next()`**
#
# La función **`next()`** permite obtener el siguiente elemento de un iterador o generador.
#
# ```python
# gen = (x**2 for x in range(3))
#
# print(next(gen))  # Output: 0
# print(next(gen))  # Output: 1
# print(next(gen))  # Output: 4
# ```
#
# Cada vez que llamamos **`next(gen)`**, el generador devuelve el siguiente valor **y se pausa** hasta la próxima llamada.
#
# ---
#
# ##### **Qué ocurre si se excede el límite del generador**
#
# Si un generador **se ha agotado**, **`next()`** lanza una excepción `StopIteration`.
#
# ```python
# gen = (x for x in range(3))
#
# print(next(gen))  # Output: 0
# print(next(gen))  # Output: 1
# print(next(gen))  # Output: 2
# print(next(gen))  # Error: StopIteration
# ```
#
# Para evitar errores, podemos definir un **valor predeterminado** que se usará cuando el iterador no tenga más elementos.
#
# ```python
# numeros = iter([10, 20, 30])
# print(next(numeros, "Fin"))  # Output: 10
# print(next(numeros, "Fin"))  # Output: 20
# print(next(numeros, "Fin"))  # Output: 30
# print(next(numeros, "Fin"))  # Output: Fin (cuando no hay más valores)
# ```
#
# ---
#
# ##### **Conclusión**
#
# Las funciones **`sum()`** y **`next()`** son esenciales para el manejo de iterables en Python.
# - **`sum()`** permite sumar elementos de una secuencia de forma flexible y eficiente.
# - **`next()`** se utiliza para recorrer iteradores **paso a paso**, con opción de definir un valor predeterminado en caso de agotamiento.
#
# Su correcto uso mejora la manipulación de estructuras de datos y optimiza el rendimiento del código.
# Si necesitas más detalles sobre algún caso específico, dime cómo prefieres que lo enfoquemos. 😊

# %% [markdown]
# #### Manejo de Excepciones en Python
#
# Las **excepciones** en Python son errores que ocurren durante la ejecución de un programa y pueden interrumpir su flujo normal. El **manejo de excepciones** permite detectar, gestionar y corregir estos errores para evitar fallos inesperados.
#
# ---
#
# ##### **Concepto de Excepciones**
#
# Las excepciones ocurren cuando Python encuentra un problema que impide continuar la ejecución. Algunos ejemplos comunes son:
#
# - **División por cero (`ZeroDivisionError`)**
#   ```python
#   resultado = 10 / 0  # Error: ZeroDivisionError
#   ```
#
# - **Acceso a una variable no definida (`NameError`)**
#   ```python
#   print(valor)  # Error: NameError (la variable no existe)
#   ```
#
# - **Índice fuera de rango en listas (`IndexError`)**
#   ```python
#   lista = [1, 2, 3]
#   print(lista[5])  # Error: IndexError
#   ```
#
# ---
#
# ##### **Manejo de Excepciones con `try` y `except`**
#
# Se usa `try` para intentar ejecutar un bloque de código y `except` para capturar cualquier excepción.
#
# ```python
# try:
#     resultado = 10 / 0
# except ZeroDivisionError:
#     print("Error: No se puede dividir por cero.")
# ```
#
# **Salida:**
# ```
# Error: No se puede dividir por cero.
# ```
#
# ---
#
# ##### **Capturar múltiples excepciones**
#
# Podemos manejar distintos tipos de errores en un mismo bloque `try`.
#
# ```python
# try:
#     lista = [1, 2, 3]
#     print(lista[5])  # Error: IndexError
# except ZeroDivisionError:
#     print("Error: División por cero.")
# except IndexError:
#     print("Error: Índice fuera de rango.")
# except Exception as e:  # Captura cualquier otro error
#     print(f"Error desconocido: {e}")
# ```
#
# ---
#
# ##### **Uso de `else` y `finally` en Excepciones**
#
# El bloque `else` se ejecuta si **no se produce una excepción**, y `finally` se ejecuta **siempre**, haya o no error.
#
# ```python
# try:
#     resultado = 10 / 2
# except ZeroDivisionError:
#     print("Error: División por cero.")
# else:
#     print("La operación se realizó correctamente.")
# finally:
#     print("Finalizando proceso.")
# ```
#
# **Salida:**
# ```
# La operación se realizó correctamente.
# Finalizando proceso.
# ```
#
# ---
#
# ##### **Generar excepciones con `raise`**
#
# Podemos lanzar excepciones manualmente usando `raise`.
#
# ```python
# def verificar_edad(edad):
#     if edad < 18:
#         raise ValueError("Debes ser mayor de edad.")
#     return "Acceso permitido"
#
# try:
#     print(verificar_edad(15))
# except ValueError as e:
#     print(f"Error: {e}")
# ```
#
# **Salida:**
# ```
# Error: Debes ser mayor de edad.
# ```
#
# ---
#
# ##### **Definir excepciones personalizadas**
#
# Es posible crear nuestras propias excepciones heredando de `Exception`.
#
# ```python
# class ErrorPersonalizado(Exception):
#     pass
#
# try:
#     raise ErrorPersonalizado("Este es un error personalizado.")
# except ErrorPersonalizado as e:
#     print(f"Error detectado: {e}")
# ```
#
# **Salida:**
# ```
# Error detectado: Este es un error personalizado.
# ```
#
# ---
#
# ##### **Conclusión**
#
# El **manejo de excepciones** es esencial para escribir código **robusto y seguro** en Python. Usar `try-except` permite controlar errores, mejorar la experiencia del usuario y evitar fallos inesperados en el programa. Además, `raise` y las excepciones personalizadas permiten adaptarse a situaciones específicas.
# Un buen diseño de manejo de excepciones contribuye a la **estabilidad y mantenibilidad** del código.

# %% [markdown]
# ### Sección 10: Manejo de Archivos en Python

# %% [markdown]
# #### Manejo de archivos en Python
#
# El **manejo de archivos** en Python permite leer, escribir y modificar archivos en distintos formatos. Es una funcionalidad esencial para almacenar y recuperar datos de manera eficiente.
#
# ---
#
# ##### **Apertura y cierre de archivos**
#
# Para trabajar con archivos en Python, se usa la función `open()` con diferentes modos de apertura.
#
# ```python
# archivo = open("datos.txt", "r")  # Abre el archivo en modo lectura
# contenido = archivo.read()  # Lee todo el contenido
# archivo.close()  # Cierra el archivo después de leer
# ```
#
# ---
#
# ##### **Modos de apertura de archivos**
#
# | Modo | Descripción |
# |------|------------|
# | `"r"` | Lectura (error si el archivo no existe) |
# | `"w"` | Escritura (borra contenido previo o crea archivo nuevo) |
# | `"a"` | Escritura en modo agregar (no borra el contenido existente) |
# | `"x"` | Creación exclusiva (error si el archivo existe) |
# | `"rb"` | Lectura en modo binario |
# | `"wb"` | Escritura en modo binario |
#
# ---
#
# ##### **Lectura de archivos**
#
# Se pueden leer archivos línea por línea para optimizar el uso de memoria.
#
# ```python
# with open("datos.txt", "r") as archivo:
#     for linea in archivo:
#         print(linea.strip())  # Elimina espacios y saltos de línea
# ```
#
# ---
#
# ##### **Escritura de archivos**
#
# Se usa el modo `"w"` para escribir en archivos, reemplazando su contenido.
#
# ```python
# with open("nuevo.txt", "w") as archivo:
#     archivo.write("Hola, Python!\n")
#     archivo.write("Este es un archivo de prueba.")
# ```
#
# ---
#
# ##### **Agregar contenido a un archivo**
#
# El modo `"a"` permite agregar contenido sin borrar datos previos.
#
# ```python
# with open("nuevo.txt", "a") as archivo:
#     archivo.write("\nNueva línea añadida.")
# ```
#
# ---
#
# ##### **Lectura y escritura en archivos binarios**
#
# ```python
# # Lectura binaria
# with open("imagen.png", "rb") as archivo:
#     datos = archivo.read()
#
# # Escritura binaria
# with open("copia.png", "wb") as archivo:
#     archivo.write(datos)
# ```
#
# ---
#
# ##### **Manejo de excepciones al trabajar con archivos**
#
# Es recomendable usar `try-except` para evitar errores si un archivo no existe.
#
# ```python
# try:
#     with open("archivo_inexistente.txt", "r") as archivo:
#         contenido = archivo.read()
# except FileNotFoundError:
#     print("Error: El archivo no existe.")
# ```
#
# ---
#
# ##### **Conclusión**
#
# El manejo de archivos en Python permite leer, escribir y modificar datos de manera eficiente.
# - La función `open()` permite abrir archivos en distintos modos.
# - Es recomendable usar `with open()` para manejar archivos, evitando errores por falta de cierre.
# - Se pueden gestionar archivos de texto y binarios, con opciones para lectura y escritura.
# Su uso adecuado mejora la organización de datos y optimiza el almacenamiento de información.

# %% [markdown]
# #### Creación de Archivos en Python
#
# Python permite la **creación de archivos** para almacenar información en distintos formatos. Se pueden generar archivos de texto, binarios y específicos como CSV o JSON.
#
# ---
#
# ##### **Crear un archivo de texto**
#
# Se usa el modo `"w"` para crear un archivo nuevo. Si el archivo ya existe, su contenido **se sobrescribe**.
#
# ```python
# with open("nuevo_archivo.txt", "w") as archivo:
#     archivo.write("Este es un archivo de texto creado con Python.\n")
#     archivo.write("La programación es poderosa.")
# ```
#
# ---
#
# ##### **Crear un archivo en modo agregar (`"a"`)**
#
# El modo `"a"` permite añadir contenido **sin borrar** el existente.
#
# ```python
# with open("nuevo_archivo.txt", "a") as archivo:
#     archivo.write("\nNueva línea agregada.")
# ```
#
# ---
#
# ##### **Crear un archivo de texto línea por línea**
#
# El método `writelines()` permite escribir múltiples líneas en un archivo.
#
# ```python
# lineas = ["Python es fácil de aprender.\n", "Soporta múltiples paradigmas.\n", "Es muy utilizado en ciencia de datos.\n"]
#
# with open("info.txt", "w") as archivo:
#     archivo.writelines(lineas)
# ```
#
# ---
#
# ##### **Crear archivos binarios**
#
# Para trabajar con archivos binarios, se usa el modo `"wb"`.
#
# ```python
# datos = b'\x00\xFF\x10\x80'  # Datos binarios de ejemplo
#
# with open("datos.bin", "wb") as archivo:
#     archivo.write(datos)
# ```
#
# ---
#
# ##### **Crear archivos JSON**
#
# Python permite almacenar datos estructurados en formato JSON usando el módulo `json`.
#
# ```python
# import json
#
# datos = {"nombre": "Ana", "edad": 25, "activo": True}
#
# with open("datos.json", "w") as archivo:
#     json.dump(datos, archivo, indent=4)
# ```
#
# ---
#
# ##### **Manejo de excepciones en la creación de archivos**
#
# Es recomendable usar `try-except` para evitar errores.
#
# ```python
# try:
#     with open("nuevo_archivo.txt", "x") as archivo:  # `x` crea un archivo, falla si ya existe
#         archivo.write("Creación con modo exclusivo.")
# except FileExistsError:
#     print("Error: El archivo ya existe.")
# ```
#
# ---
#
# ##### **Conclusión**
#
# Python permite la **creación de archivos** con distintos formatos para almacenar información de manera eficiente.
# - Se usa `open()` con modos `"w"`, `"a"` y `"x"` según el propósito.
# - `writelines()` facilita la escritura de múltiples líneas.
# - Se pueden crear archivos binarios y JSON para datos estructurados.
# Un manejo adecuado garantiza la **organización y persistencia de la información**.

# %% [markdown]
# #### Bloque `with` en Python
#
# El **bloque `with`** en Python se utiliza para gestionar **contextos** de manera eficiente, asegurando que los recursos sean liberados correctamente después de su uso. Es comúnmente utilizado para manipular archivos y manejar conexiones.
#
# ---
#
# ##### **Uso del bloque `with` en archivos**
#
# El uso de `with` **automatiza el cierre** del archivo después de su ejecución, evitando errores por falta de cierre manual.
#
# ```python
# with open("datos.txt", "r") as archivo:
#     contenido = archivo.read()
#     print(contenido)  # Muestra el contenido del archivo
# ```
#
# El archivo **se cierra automáticamente** cuando el bloque `with` finaliza.
#
# ---
#
# ##### **Ventajas del bloque `with`**
#
# | Sin `with` | Con `with` |
# |------------|-----------|
# | Requiere cerrar manualmente el archivo | Cierra el archivo automáticamente |
# | Puede generar errores si olvidamos `close()` | Evita problemas de acceso concurrente |
# | Menos eficiente en el manejo de recursos | Optimiza el uso de memoria |
#
# Ejemplo sin `with`:
#
# ```python
# archivo = open("datos.txt", "r")
# contenido = archivo.read()
# archivo.close()
# ```
#
# Ejemplo con `with`:
#
# ```python
# with open("datos.txt", "r") as archivo:
#     contenido = archivo.read()
# ```
#
# ---
#
# ##### **Uso de `with` con múltiples archivos**
#
# El bloque `with` permite trabajar con varios archivos simultáneamente.
#
# ```python
# with open("archivo1.txt", "r") as archivo1, open("archivo2.txt", "w") as archivo2:
#     contenido = archivo1.read()
#     archivo2.write(contenido)
# ```
#
# ---
#
# ##### **Uso de `with` en conexiones y operaciones con bases de datos**
#
# El bloque `with` también se utiliza en la gestión de conexiones, asegurando que sean cerradas correctamente.
#
# ```python
# import sqlite3
#
# with sqlite3.connect("base_datos.db") as conexion:
#     cursor = conexion.cursor()
#     cursor.execute("CREATE TABLE IF NOT EXISTS usuarios (id INTEGER, nombre TEXT)")
# ```
#
# ---
#
# ##### **Manejo de excepciones dentro de `with`**
#
# Podemos usar `try-except` dentro de `with` para capturar errores.
#
# ```python
# try:
#     with open("archivo_inexistente.txt", "r") as archivo:
#         contenido = archivo.read()
# except FileNotFoundError:
#     print("Error: El archivo no existe.")
# ```
#
# ---
#
# ##### **Conclusión**
#
# El **bloque `with`** en Python facilita el manejo de archivos, conexiones y otros recursos, asegurando que sean **liberados correctamente**. Su uso optimiza el código, reduce errores y mejora la seguridad en operaciones de lectura y escritura.
# Implementarlo correctamente garantiza **un código más eficiente y seguro**.

# %% [markdown]
# #### Creación de Archivos en Modo Exclusivo
#
# El **modo exclusivo (`"x"`)** en Python permite crear archivos de manera segura, evitando sobrescribir archivos existentes. Si el archivo ya existe, Python lanza un **error**.
#
# ---
#
# ##### **Uso del modo exclusivo (`"x"`)**
#
# El modo `"x"` crea un archivo nuevo y lanza `FileExistsError` si el archivo ya está presente.
#
# ```python
# try:
#     with open("archivo_exclusivo.txt", "x") as archivo:
#         archivo.write("Este archivo fue creado en modo exclusivo.")
# except FileExistsError:
#     print("Error: El archivo ya existe.")
# ```
#
# Si `archivo_exclusivo.txt` ya existe, el programa **evita la sobreescritura**.
#
# ---
#
# ##### **Diferencia entre `"x"` y `"w"`**
#
# | Modo | Comportamiento |
# |------|---------------|
# | `"w"` | Sobrescribe el archivo si existe |
# | `"x"` | Genera error si el archivo ya existe |
#
# Ejemplo con `"w"` (sobrescribirá el contenido existente):
#
# ```python
# with open("archivo.txt", "w") as archivo:
#     archivo.write("Este archivo se ha sobrescrito.")
# ```
#
# Ejemplo con `"x"` (fallará si el archivo existe):
#
# ```python
# with open("archivo.txt", "x") as archivo:
#     archivo.write("Este archivo solo se crea si no existe.")
# ```
#
# ---
#
# ##### **Uso del modo exclusivo en aplicaciones prácticas**
#
# El modo `"x"` es útil cuando se necesita **crear archivos de forma segura**, evitando la pérdida de información por sobrescritura accidental.
#
# Ejemplo: Registro único de logs.
#
# ```python
# try:
#     with open("log_inicio.txt", "x") as archivo:
#         archivo.write("Inicio de sesión registrado.\n")
# except FileExistsError:
#     print("El registro de inicio ya ha sido creado.")
# ```
#
# ---
#
# ##### **Conclusión**
#
# El modo exclusivo (`"x"`) en Python permite crear archivos **sin sobrescribir información existente**.
# - Es útil cuando se requiere protección contra pérdida de datos.
# - Si el archivo ya existe, Python **lanza un error** en lugar de sobrescribirlo.
# - Se recomienda usar `try-except` para manejar excepciones y evitar fallos inesperados.
# Su implementación es clave en aplicaciones que requieren seguridad en la manipulación de archivos.

# %% [markdown]
# #### Leer un Archivo en Python
#
# Python permite la **lectura de archivos** para recuperar información almacenada. Se puede leer todo el contenido, procesar línea por línea o manipular datos de manera eficiente.
#
# ---
#
# ##### **Abrir y leer un archivo**
#
# La función `open()` se usa para abrir archivos en modo lectura (`"r"`).
#
# ```python
# with open("datos.txt", "r") as archivo:
#     contenido = archivo.read()
#     print(contenido)  # Muestra el contenido completo del archivo
# ```
#
# El bloque `with` **cierra automáticamente** el archivo después de leerlo.
#
# ---
#
# ##### **Leer línea por línea con `readline()`**
#
# Se puede leer el archivo de forma progresiva usando `readline()`.
#
# ```python
# with open("datos.txt", "r") as archivo:
#     primera_linea = archivo.readline()
#     print(primera_linea)  # Muestra solo la primera línea del archivo
# ```
#
# ---
#
# ##### **Leer todas las líneas con `readlines()`**
#
# El método `readlines()` devuelve una lista con todas las líneas del archivo.
#
# ```python
# with open("datos.txt", "r") as archivo:
#     lineas = archivo.readlines()
#     print(lineas)  # Lista con cada línea del archivo
# ```
#
# ---
#
# ##### **Iterar sobre un archivo línea por línea**
#
# Es recomendable leer archivos con un bucle para ahorrar memoria.
#
# ```python
# with open("datos.txt", "r") as archivo:
#     for linea in archivo:
#         print(linea.strip())  # Elimina espacios y saltos de línea
# ```
#
# ---
#
# ##### **Manejo de excepciones en la lectura de archivos**
#
# Se recomienda usar `try-except` para evitar errores si el archivo no existe.
#
# ```python
# try:
#     with open("archivo_inexistente.txt", "r") as archivo:
#         contenido = archivo.read()
# except FileNotFoundError:
#     print("Error: El archivo no existe.")
# ```
#
# ---
#
# ##### **Conclusión**
#
# Python ofrece diversas opciones para **leer archivos** de manera eficiente.
# - `read()` permite recuperar todo el contenido.
# - `readline()` lee línea por línea.
# - `readlines()` devuelve una lista con todas las líneas.
# - Iterar con un `for` optimiza el uso de memoria.
# Un manejo adecuado garantiza la correcta recuperación de información y mejora la eficiencia del código.

# %% [markdown]
# #### Anexar un Archivo en Python
#
# El **modo anexar (`"a"`)** en Python permite agregar contenido a un archivo **sin borrar** la información existente. Es útil para mantener registros, logs o actualizar archivos sin perder datos previos.
#
# ---
#
# ##### **Agregar contenido a un archivo existente**
#
# El modo `"a"` abre un archivo y agrega nueva información al final.
#
# ```python
# with open("archivo.txt", "a") as archivo:
#     archivo.write("\nNueva línea añadida.")
# ```
#
# Si `archivo.txt` no existe, Python lo **creará automáticamente**.
#
# ---
#
# ##### **Diferencia entre `"a"` y `"w"`**
#
# | Modo | Comportamiento |
# |------|---------------|
# | `"w"` | Sobrescribe el archivo si existe |
# | `"a"` | Agrega contenido sin borrar datos previos |
#
# Ejemplo con `"w"` (sobrescribirá el archivo):
#
# ```python
# with open("archivo.txt", "w") as archivo:
#     archivo.write("Este archivo ha sido reemplazado.")
# ```
#
# Ejemplo con `"a"` (mantendrá el contenido anterior y añadirá texto nuevo):
#
# ```python
# with open("archivo.txt", "a") as archivo:
#     archivo.write("\nEste texto ha sido anexado.")
# ```
#
# ---
#
# ##### **Anexar múltiples líneas con `writelines()`**
#
# Se pueden agregar varias líneas a la vez usando `writelines()`.
#
# ```python
# lineas = ["\nLínea adicional 1\n", "Línea adicional 2\n"]
#
# with open("archivo.txt", "a") as archivo:
#     archivo.writelines(lineas)
# ```
#
# ---
#
# ##### **Uso práctico en registros y logs**
#
# Es útil en registros de eventos o archivos de logs para añadir información sin perder datos.
#
# ```python
# import datetime
#
# with open("log.txt", "a") as archivo:
#     archivo.write(f"\nRegistro de acceso: {datetime.datetime.now()}")
# ```
#
# ---
#
# ##### **Manejo de excepciones al anexar archivos**
#
# Es recomendable usar `try-except` para evitar errores.
#
# ```python
# try:
#     with open("archivo.txt", "a") as archivo:
#         archivo.write("\nActualización segura.")
# except IOError:
#     print("Error: No se pudo escribir en el archivo.")
# ```
#
# ---
#
# ##### **Conclusión**
#
# El modo **anexar (`"a"`)** en Python es ideal para agregar información sin eliminar datos existentes.
# - Se usa `write()` o `writelines()` para actualizar archivos.
# - Es útil en registros y logs para mantener datos históricos.
# - Se recomienda manejar excepciones para evitar errores de escritura.
# Su implementación garantiza una **gestión eficiente y segura** de archivos de texto.

# %% [markdown]
# ### Sección 11:Conexión a Base de Datos con Python

# %% [markdown]
# #### Bases de Datos en Python
#
# Python ofrece múltiples herramientas para trabajar con **bases de datos**, permitiendo interactuar con sistemas como SQLite, MySQL, PostgreSQL y más. Gracias a sus módulos integrados y bibliotecas adicionales, se facilita la conexión, consulta y manipulación de datos.
#
# ---
#
# ##### SQLite: Bases de datos integradas
#
# SQLite es un sistema de bases de datos ligero integrado en Python a través del módulo `sqlite3`. No requiere instalación adicional y es ideal para aplicaciones pequeñas.
#
# - **Conexión y creación de una base de datos**
#   ```python
#   import sqlite3
#
#   conexion = sqlite3.connect("mi_base.db")
#   cursor = conexion.cursor()
#
#   cursor.execute("""
#   CREATE TABLE IF NOT EXISTS usuarios (
#       id INTEGER PRIMARY KEY,
#       nombre TEXT NOT NULL,
#       edad INTEGER
#   )
#   """)
#
#   conexion.commit()
#   conexion.close()
#   ```
#
# - **Insertar datos en SQLite**
#   ```python
#   conexion = sqlite3.connect("mi_base.db")
#   cursor = conexion.cursor()
#
#   cursor.execute("INSERT INTO usuarios (nombre, edad) VALUES (?, ?)", ("Juan", 30))
#   cursor.execute("INSERT INTO usuarios (nombre, edad) VALUES (?, ?)", ("Ana", 25))
#
#   conexion.commit()
#   conexion.close()
#   ```
#
# - **Consultar datos desde SQLite**
#   ```python
#   conexion = sqlite3.connect("mi_base.db")
#   cursor = conexion.cursor()
#
#   cursor.execute("SELECT * FROM usuarios")
#   usuarios = cursor.fetchall()
#
#   for usuario in usuarios:
#       print(usuario)
#
#   conexion.close()
#   ```
#
# ---
#
# ##### MySQL: Bases de datos relacionales
#
# MySQL es un sistema de gestión de bases de datos relacional ampliamente utilizado, conocido por su velocidad, escalabilidad y robustez. Python cuenta con bibliotecas como `mysql-connector`, `PyMySQL` y `SQLAlchemy` para trabajar con MySQL.
#
# - **Instalación de `mysql-connector`**
#   ```bash
#   pip install mysql-connector-python
#   ```
#
# - **Conexión a MySQL**
#   ```python
#   import mysql.connector
#
#   conexion = mysql.connector.connect(
#       host="localhost",
#       user="tu_usuario",
#       password="tu_contraseña",
#       database="mi_base"
#   )
#
#   conexion.close()
#   ```
#
# - **Crear una base de datos y tablas en MySQL**
#   ```python
#   conexion = mysql.connector.connect(
#       host="localhost",
#       user="tu_usuario",
#       password="tu_contraseña"
#   )
#
#   cursor = conexion.cursor()
#
#   cursor.execute("CREATE DATABASE IF NOT EXISTS mi_base")
#   cursor.execute("USE mi_base")
#
#   cursor.execute("""
#   CREATE TABLE IF NOT EXISTS usuarios (
#       id INT AUTO_INCREMENT PRIMARY KEY,
#       nombre VARCHAR(255) NOT NULL,
#       edad INT NOT NULL
#   )
#   """)
#
#   conexion.commit()
#   conexion.close()
#   ```
#
# - **Insertar datos en MySQL**
#   ```python
#   conexion = mysql.connector.connect(
#       host="localhost",
#       user="tu_usuario",
#       password="tu_contraseña",
#       database="mi_base"
#   )
#
#   cursor = conexion.cursor()
#
#   sql = "INSERT INTO usuarios (nombre, edad) VALUES (%s, %s)"
#   valores = [("Juan", 30), ("Ana", 25), ("Luis", 40)]
#
#   cursor.executemany(sql, valores)
#   conexion.commit()
#   conexion.close()
#   ```
#
# - **Consultar datos desde MySQL**
#   ```python
#   conexion = mysql.connector.connect(
#       host="localhost",
#       user="tu_usuario",
#       password="tu_contraseña",
#       database="mi_base"
#   )
#
#   cursor = conexion.cursor()
#
#   cursor.execute("SELECT * FROM usuarios")
#   resultado = cursor.fetchall()
#
#   for fila in resultado:
#       print(fila)
#
#   conexion.close()
#   ```
#
# - **Actualizar y eliminar datos en MySQL**
#   ```python
#   cursor.execute("UPDATE usuarios SET edad = %s WHERE nombre = %s", (35, "Juan"))
#   cursor.execute("DELETE FROM usuarios WHERE nombre = %s", ("Ana",))
#   ```
#
# ---
#
# ##### Buenas prácticas al usar bases de datos
#
# - Usar consultas parametrizadas para proteger contra inyecciones SQL.
# - Cerrar conexiones con `conexion.close()` para liberar recursos.
# - Manejar errores con `try-except` durante la conexión y las consultas.
#
# ---
#
# ##### Conclusión
#
# Python facilita el manejo de bases de datos utilizando SQLite para aplicaciones ligeras y MySQL para proyectos más complejos. Ambas opciones permiten realizar operaciones como creación, inserción, consulta y eliminación de datos de manera eficiente, asegurando la integridad y seguridad de la información.

# %% [markdown]
# #### Instalación de MySQL
#
# La instalación de **MySQL** varía según el sistema operativo, pero generalmente incluye descargar el software desde el sitio oficial, configurarlo e iniciar el servidor. A continuación, se describe cómo instalar MySQL en diferentes plataformas.
#
# ---
#
# ##### Windows
#
# 1. **Descargar el instalador oficial**
#    Ve a la página oficial de MySQL y descarga el instalador de MySQL Community (MySQL Installer):
#    [https://dev.mysql.com/downloads/](https://dev.mysql.com/downloads/)
#
# 2. **Ejecutar el instalador**
#    Inicia el instalador y selecciona la versión deseada de MySQL. Escoge el tipo de instalación:
#    - Developer Default: Incluye las herramientas necesarias para desarrolladores.
#    - Server Only: Instala solo el servidor de MySQL.
#
# 3. **Configurar MySQL**
#    Durante la instalación:
#    - Configura una contraseña para el usuario `root`.
#    - Selecciona el modo de autenticación recomendado.
#    - Configura el número de puerto (3306 por defecto).
#
# 4. **Finalizar la instalación**
#    Completa el proceso y verifica que el servidor se ejecuta correctamente desde el **MySQL Workbench** o la línea de comandos.
#
# ---
#
# ##### macOS
#
# 1. **Usar Homebrew**
#    Si tienes Homebrew instalado, la instalación es sencilla. Abre la terminal y ejecuta:
#    ```bash
#    brew install mysql
#    ```
#
# 2. **Iniciar el servidor**
#    Una vez instalado, inicia el servicio de MySQL:
#    ```bash
#    brew services start mysql
#    ```
#
# 3. **Configurar MySQL**
#    Accede al cliente de MySQL para configurar el usuario `root` y establecer una contraseña:
#    ```bash
#    mysql_secure_installation
#    ```
#
# 4. **Verificar la instalación**
#    Comprueba que MySQL está funcionando ejecutando:
#    ```bash
#    mysql --version
#    ```
#
# ---
#
# ##### Linux
#
# En distribuciones basadas en Debian como Ubuntu:
#
# 1. **Actualizar repositorios**
#    ```bash
#    sudo apt update
#    ```
#
# 2. **Instalar MySQL**
#    ```bash
#    sudo apt install mysql-server
#    ```
#
# 3. **Configurar MySQL**
#    Ejecuta el asistente de configuración:
#    ```bash
#    sudo mysql_secure_installation
#    ```
#    Durante este proceso, se te pedirá que configures una contraseña para `root` y ajustes otros parámetros de seguridad.
#
# 4. **Iniciar el servicio**
#    Verifica que el servicio de MySQL está activo:
#    ```bash
#    sudo systemctl status mysql
#    ```
#
# ---
#
# ##### Comprobación de la instalación
#
# En todos los sistemas operativos, puedes acceder al cliente de MySQL desde la terminal o consola y verificar la conexión:
# ```bash
# mysql -u root -p
# ```
# Esto abrirá una sesión interactiva en MySQL después de ingresar la contraseña configurada para el usuario `root`.
#
# ---
#
# ##### Conclusión
#
# Instalar MySQL es un proceso sencillo y bien documentado, con herramientas que facilitan la configuración inicial. Tras la instalación, es importante verificar que el servidor funciona correctamente y que las configuraciones de seguridad están activadas. Esto garantiza una base sólida para el desarrollo de aplicaciones y el manejo de datos.

# %% [markdown]
# #### Sentencia SELECT en MySQL
#
# La sentencia **`SELECT`** en MySQL se utiliza para recuperar datos de una o más tablas dentro de una base de datos. Es una de las herramientas principales para consultar información y permite aplicar filtros, ordenar resultados y realizar operaciones avanzadas como agrupamientos y uniones.
#
# ---
#
# ##### Sintaxis básica
#
# ```sql
# SELECT columna1, columna2, ...
# FROM nombre_tabla;
# ```
#
# Para seleccionar todas las columnas de una tabla, usa el carácter `*`:
#
# ```sql
# SELECT *
# FROM nombre_tabla;
# ```
#
# ---
#
# ##### Filtrar resultados con `WHERE`
#
# Se pueden aplicar filtros a los resultados usando la cláusula `WHERE`.
#
# ```sql
# SELECT *
# FROM usuarios
# WHERE edad > 30;
# ```
#
# Otros operadores comunes:
# - Igualdad: `=`
# - Diferencia: `!=`
# - Comparaciones: `<`, `>`, `<=`, `>=`
# - Lógica: `AND`, `OR`, `NOT`
#
# ---
#
# ##### Ordenar resultados con `ORDER BY`
#
# Para ordenar los resultados, se usa la cláusula `ORDER BY`.
#
# ```sql
# SELECT *
# FROM usuarios
# ORDER BY edad ASC;  -- Orden ascendente
# ```
#
# Para ordenar de manera descendente:
#
# ```sql
# SELECT *
# FROM usuarios
# ORDER BY edad DESC;
# ```
#
# ---
#
# ##### Limitar el número de resultados con `LIMIT`
#
# Para limitar la cantidad de registros recuperados:
#
# ```sql
# SELECT *
# FROM usuarios
# LIMIT 5;
# ```
#
# También puedes combinar `LIMIT` con un desplazamiento inicial:
#
# ```sql
# SELECT *
# FROM usuarios
# LIMIT 5 OFFSET 10;  -- Los siguientes 5 registros después de los primeros 10
# ```
#
# ---
#
# ##### Seleccionar valores únicos con `DISTINCT`
#
# Si quieres evitar duplicados en los resultados, usa `DISTINCT`.
#
# ```sql
# SELECT DISTINCT nombre
# FROM usuarios;
# ```
#
# ---
#
# ##### Agrupación de datos con `GROUP BY`
#
# La cláusula `GROUP BY` se utiliza para agrupar filas con valores similares.
#
# ```sql
# SELECT edad, COUNT(*)
# FROM usuarios
# GROUP BY edad;
# ```
#
# ---
#
# ##### Filtrar grupos con `HAVING`
#
# Mientras `WHERE` filtra filas antes del agrupamiento, `HAVING` filtra grupos después.
#
# ```sql
# SELECT edad, COUNT(*)
# FROM usuarios
# GROUP BY edad
# HAVING COUNT(*) > 2;
# ```
#
# ---
#
# ##### Uso de funciones de agregación
#
# MySQL incluye funciones para realizar cálculos en los datos:
# - `COUNT()`: Cuenta filas
# - `SUM()`: Suma valores
# - `AVG()`: Promedio
# - `MIN()`: Mínimo
# - `MAX()`: Máximo
#
# Ejemplo:
#
# ```sql
# SELECT AVG(edad) AS promedio_edad
# FROM usuarios;
# ```
#
# ---
#
# ##### Uniones de tablas (`JOIN`)
#
# Para consultar datos de múltiples tablas relacionadas, se utilizan uniones.
#
# **INNER JOIN**: Recupera filas comunes entre ambas tablas.
# ```sql
# SELECT usuarios.nombre, pedidos.fecha
# FROM usuarios
# INNER JOIN pedidos ON usuarios.id = pedidos.usuario_id;
# ```
#
# **LEFT JOIN**: Recupera todas las filas de la tabla izquierda, incluso si no hay coincidencias.
# ```sql
# SELECT usuarios.nombre, pedidos.fecha
# FROM usuarios
# LEFT JOIN pedidos ON usuarios.id = pedidos.usuario_id;
# ```
#
# **RIGHT JOIN**: Similar a `LEFT JOIN`, pero para la tabla derecha.
#
# ---
#
# ##### Subconsultas (`SUBQUERY`)
#
# Una subconsulta se utiliza como parte de otra consulta para proporcionar resultados adicionales.
# ```sql
# SELECT nombre
# FROM usuarios
# WHERE id IN (SELECT usuario_id FROM pedidos WHERE fecha > '2023-01-01');
# ```
#
# ---
#
# ##### Conclusión
#
# La sentencia **`SELECT`** en MySQL es una herramienta poderosa para consultar y manipular datos en una base de datos. A través de las distintas cláusulas y funciones, se pueden realizar consultas personalizadas y avanzadas para extraer la información requerida de manera eficiente.

# %% [markdown]
# #### Sentencia SELECT en MySQL
#
# La sentencia **`SELECT`** en MySQL se utiliza para recuperar datos de una o más tablas dentro de una base de datos. Es una de las herramientas principales para consultar información y permite aplicar filtros, ordenar resultados y realizar operaciones avanzadas como agrupamientos y uniones.
#
# ---
#
# ##### Sintaxis básica
#
# ```sql
# SELECT columna1, columna2, ...
# FROM nombre_tabla;
# ```
#
# Para seleccionar todas las columnas de una tabla, usa el carácter `*`:
#
# ```sql
# SELECT *
# FROM nombre_tabla;
# ```
#
# ---
#
# ##### Filtrar resultados con `WHERE`
#
# Se pueden aplicar filtros a los resultados usando la cláusula `WHERE`.
#
# ```sql
# SELECT *
# FROM usuarios
# WHERE edad > 30;
# ```
#
# Otros operadores comunes:
# - Igualdad: `=`
# - Diferencia: `!=`
# - Comparaciones: `<`, `>`, `<=`, `>=`
# - Lógica: `AND`, `OR`, `NOT`
#
# ---
#
# ##### Ordenar resultados con `ORDER BY`
#
# Para ordenar los resultados, se usa la cláusula `ORDER BY`.
#
# ```sql
# SELECT *
# FROM usuarios
# ORDER BY edad ASC;  -- Orden ascendente
# ```
#
# Para ordenar de manera descendente:
#
# ```sql
# SELECT *
# FROM usuarios
# ORDER BY edad DESC;
# ```
#
# ---
#
# ##### Limitar el número de resultados con `LIMIT`
#
# Para limitar la cantidad de registros recuperados:
#
# ```sql
# SELECT *
# FROM usuarios
# LIMIT 5;
# ```
#
# También puedes combinar `LIMIT` con un desplazamiento inicial:
#
# ```sql
# SELECT *
# FROM usuarios
# LIMIT 5 OFFSET 10;  -- Los siguientes 5 registros después de los primeros 10
# ```
#
# ---
#
# ##### Seleccionar valores únicos con `DISTINCT`
#
# Si quieres evitar duplicados en los resultados, usa `DISTINCT`.
#
# ```sql
# SELECT DISTINCT nombre
# FROM usuarios;
# ```
#
# ---
#
# ##### Agrupación de datos con `GROUP BY`
#
# La cláusula `GROUP BY` se utiliza para agrupar filas con valores similares.
#
# ```sql
# SELECT edad, COUNT(*)
# FROM usuarios
# GROUP BY edad;
# ```
#
# ---
#
# ##### Filtrar grupos con `HAVING`
#
# Mientras `WHERE` filtra filas antes del agrupamiento, `HAVING` filtra grupos después.
#
# ```sql
# SELECT edad, COUNT(*)
# FROM usuarios
# GROUP BY edad
# HAVING COUNT(*) > 2;
# ```
#
# ---
#
# ##### Uso de funciones de agregación
#
# MySQL incluye funciones para realizar cálculos en los datos:
# - `COUNT()`: Cuenta filas
# - `SUM()`: Suma valores
# - `AVG()`: Promedio
# - `MIN()`: Mínimo
# - `MAX()`: Máximo
#
# Ejemplo:
#
# ```sql
# SELECT AVG(edad) AS promedio_edad
# FROM usuarios;
# ```
#
# ---
#
# ##### Uniones de tablas (`JOIN`)
#
# Para consultar datos de múltiples tablas relacionadas, se utilizan uniones.
#
# **INNER JOIN**: Recupera filas comunes entre ambas tablas.
# ```sql
# SELECT usuarios.nombre, pedidos.fecha
# FROM usuarios
# INNER JOIN pedidos ON usuarios.id = pedidos.usuario_id;
# ```
#
# **LEFT JOIN**: Recupera todas las filas de la tabla izquierda, incluso si no hay coincidencias.
# ```sql
# SELECT usuarios.nombre, pedidos.fecha
# FROM usuarios
# LEFT JOIN pedidos ON usuarios.id = pedidos.usuario_id;
# ```
#
# **RIGHT JOIN**: Similar a `LEFT JOIN`, pero para la tabla derecha.
#
# ---
#
# ##### Subconsultas (`SUBQUERY`)
#
# Una subconsulta se utiliza como parte de otra consulta para proporcionar resultados adicionales.
# ```sql
# SELECT nombre
# FROM usuarios
# WHERE id IN (SELECT usuario_id FROM pedidos WHERE fecha > '2023-01-01');
# ```
#
# ---
#
# ##### Conclusión
#
# La sentencia **`SELECT`** en MySQL es una herramienta poderosa para consultar y manipular datos en una base de datos. A través de las distintas cláusulas y funciones, se pueden realizar consultas personalizadas y avanzadas para extraer la información requerida de manera eficiente.

# %% [markdown]
# #### Sentencias UPDATE y DELETE en MySQL
#
# Las sentencias **`UPDATE`** y **`DELETE`** en MySQL se utilizan para modificar y eliminar registros dentro de una tabla. Ambas operaciones son fundamentales para mantener la integridad y consistencia de los datos en una base de datos.
#
# ---
#
# ##### Sentencia UPDATE
#
# La sentencia **`UPDATE`** modifica los valores de una o más columnas en una tabla, aplicando condiciones opcionales con `WHERE`.
#
# - **Sintaxis básica**:
#   ```sql
#   UPDATE nombre_tabla
#   SET columna1 = valor1, columna2 = valor2, ...
#   WHERE condicion;
#   ```
#
# - **Ejemplo**: Actualizar un registro específico.
#   ```sql
#   UPDATE usuarios
#   SET edad = 31
#   WHERE nombre = 'Juan';
#   ```
#
# - **Actualizar múltiples columnas**:
#   ```sql
#   UPDATE usuarios
#   SET nombre = 'Juan Pérez', edad = 32
#   WHERE id = 1;
#   ```
#
# - **Actualizar todos los registros**:
#   Si se omite la cláusula `WHERE`, todos los registros de la tabla serán afectados.
#   ```sql
#   UPDATE usuarios
#   SET activo = 1;
#   ```
#
# ---
#
# ##### Sentencia DELETE
#
# La sentencia **`DELETE`** elimina uno o más registros de una tabla según una condición. A diferencia de `TRUNCATE`, que elimina todos los datos, `DELETE` permite aplicar filtros con `WHERE`.
#
# - **Sintaxis básica**:
#   ```sql
#   DELETE FROM nombre_tabla
#   WHERE condicion;
#   ```
#
# - **Ejemplo**: Eliminar un registro específico.
#   ```sql
#   DELETE FROM usuarios
#   WHERE id = 1;
#   ```
#
# - **Eliminar múltiples registros**:
#   ```sql
#   DELETE FROM usuarios
#   WHERE edad > 40;
#   ```
#
# - **Eliminar todos los registros**:
#   Si se omite la cláusula `WHERE`, todos los registros serán eliminados.
#   ```sql
#   DELETE FROM usuarios;
#   ```
#
# ---
#
# ##### Buenas prácticas
#
# - **Usar `WHERE` cuidadosamente**: Ambas sentencias pueden alterar o eliminar grandes volúmenes de datos si se omite la condición.
# - **Realizar pruebas previas**: Ejecutar consultas con `SELECT` antes de aplicar `UPDATE` o `DELETE` para asegurarse de que los registros afectados son los deseados.
# - **Realizar copias de seguridad**: Asegúrate de contar con un respaldo de los datos antes de realizar modificaciones importantes.
#
# ---
#
# ##### Conclusión
#
# Las sentencias **`UPDATE`** y **`DELETE`** son herramientas esenciales para la administración de bases de datos en MySQL. Su uso adecuado permite mantener datos precisos y consistentes, evitando errores que puedan comprometer la información. La implementación correcta junto con buenas prácticas asegura una manipulación segura y eficiente de los datos.

# %% [markdown]
# #### Sentencias CRUD en MySQL Workbench
#
# Las operaciones CRUD (**Create**, **Read**, **Update** y **Delete**) son fundamentales para el manejo de datos en una base de datos. MySQL Workbench es una herramienta gráfica que facilita la ejecución y diseño de estas sentencias en MySQL.
#
# ---
#
# ##### Create: Crear registros
#
# Para crear registros en una tabla:
#
# 1. Abre MySQL Workbench y selecciona tu base de datos en el esquema.
# 2. Usa la sentencia `INSERT INTO` en el editor SQL para agregar datos.
#
# ```sql
# INSERT INTO usuarios (nombre, edad)
# VALUES ('Juan', 30);
# ```
#
# 3. Ejecuta la consulta presionando el botón de "rayo" o `Ctrl+Enter`.
# 4. Verifica el resultado en la tabla correspondiente del esquema.
#
# ---
#
# ##### Read: Leer registros
#
# Para consultar datos de una tabla:
#
# 1. Abre el editor SQL en MySQL Workbench.
# 2. Usa la sentencia `SELECT` para recuperar datos.
#
# ```sql
# SELECT *
# FROM usuarios;
# ```
#
# 3. Ejecuta la consulta y observa los resultados en la sección inferior, donde se muestran las filas recuperadas.
#
# Opciones avanzadas:
# - Filtrar datos con `WHERE`.
#   ```sql
#   SELECT *
#   FROM usuarios
#   WHERE edad > 30;
#   ```
# - Ordenar resultados con `ORDER BY`.
#   ```sql
#   SELECT *
#   FROM usuarios
#   ORDER BY edad ASC;
#   ```
#
# ---
#
# ##### Update: Actualizar registros
#
# Para modificar los datos existentes:
#
# 1. Usa la sentencia `UPDATE` en el editor SQL.
#
# ```sql
# UPDATE usuarios
# SET edad = 31
# WHERE nombre = 'Juan';
# ```
#
# 2. Ejecuta la consulta y verifica que los cambios se reflejan en la tabla de la base de datos.
#
# ---
#
# ##### Delete: Eliminar registros
#
# Para borrar datos específicos:
#
# 1. Usa la sentencia `DELETE` en el editor SQL.
#
# ```sql
# DELETE FROM usuarios
# WHERE id = 1;
# ```
#
# 2. Ejecuta la consulta y asegúrate de que los registros eliminados desaparecen de la tabla.
#
# ---
#
# ##### Buenas prácticas al usar operaciones CRUD
#
# - Usa siempre cláusulas `WHERE` con las sentencias `UPDATE` y `DELETE` para evitar modificar o eliminar toda la tabla por error.
# - Realiza pruebas previas con `SELECT` para verificar los registros que serán afectados.
# - Haz copias de seguridad antes de realizar cambios importantes en la base de datos.
#
# ---
#
# ##### Conclusión
#
# Las operaciones CRUD son esenciales para gestionar datos en MySQL. MySQL Workbench facilita la ejecución de estas sentencias gracias a su interfaz intuitiva y su capacidad para mostrar los resultados de manera gráfica y organizada. Un uso responsable garantiza la integridad y consistencia de los datos.

# %% [markdown]
# #### Conector MySQL y Python
#
# Python permite interactuar con bases de datos MySQL utilizando bibliotecas como **`mysql-connector`**, una opción oficial que facilita las operaciones con bases de datos relacionales. Aquí se detalla cómo usar el conector para conectar, consultar y manipular datos.
#
# ---
#
# ##### Instalación de `mysql-connector-python`
#
# Para instalar el conector de MySQL en Python, usa `pip`:
#
# ```bash
# pip install mysql-connector-python
# ```
#
# ---
#
# ##### Conexión a la base de datos
#
# Para establecer una conexión con una base de datos MySQL, usa la clase `connect` del módulo `mysql.connector`.
#
# ```python
# import mysql.connector
#
# conexion = mysql.connector.connect(
#     host="localhost",       # Dirección del servidor
#     user="tu_usuario",      # Nombre de usuario
#     password="tu_contraseña",  # Contraseña del usuario
#     database="mi_base"      # Nombre de la base de datos
# )
#
# print("Conexión exitosa!")
# conexion.close()
# ```
#
# ---
#
# ##### Consultar datos (SELECT)
#
# Usa un cursor para ejecutar consultas SQL y recuperar datos.
#
# ```python
# cursor = conexion.cursor()
#
# cursor.execute("SELECT * FROM usuarios")
# resultado = cursor.fetchall()
#
# for fila in resultado:
#     print(fila)
#
# cursor.close()
# ```
#
# ---
#
# ##### Insertar datos
#
# Inserta datos en la base de datos usando sentencias parametrizadas para evitar inyecciones SQL.
#
# ```python
# sql = "INSERT INTO usuarios (nombre, edad) VALUES (%s, %s)"
# valores = ("Juan", 30)
#
# cursor.execute(sql, valores)
# conexion.commit()
#
# print(f"Registro insertado con ID {cursor.lastrowid}")
# ```
#
# ---
#
# ##### Actualizar datos
#
# Modifica datos existentes mediante la sentencia `UPDATE` y valores parametrizados.
#
# ```python
# sql = "UPDATE usuarios SET edad = %s WHERE nombre = %s"
# valores = (35, "Juan")
#
# cursor.execute(sql, valores)
# conexion.commit()
#
# print(f"Registros actualizados: {cursor.rowcount}")
# ```
#
# ---
#
# ##### Eliminar datos
#
# Usa la sentencia `DELETE` para eliminar registros específicos.
#
# ```python
# sql = "DELETE FROM usuarios WHERE nombre = %s"
# valores = ("Juan",)
#
# cursor.execute(sql, valores)
# conexion.commit()
#
# print(f"Registros eliminados: {cursor.rowcount}")
# ```
#
# ---
#
# ##### Manejo de errores
#
# Es importante manejar errores para garantizar que la aplicación no falle inesperadamente.
#
# ```python
# try:
#     conexion = mysql.connector.connect(
#         host="localhost",
#         user="tu_usuario",
#         password="tu_contraseña",
#         database="mi_base"
#     )
#     cursor = conexion.cursor()
#     cursor.execute("SELECT * FROM tabla_inexistente")
# except mysql.connector.Error as error:
#     print(f"Error: {error}")
# finally:
#     if conexion.is_connected():
#         conexion.close()
# ```
#
# ---
#
# ##### Cierre de conexiones
#
# Asegúrate siempre de cerrar la conexión y el cursor para liberar recursos.
#
# ```python
# cursor.close()
# conexion.close()
# ```
#
# ---
#
# ##### Conclusión
#
# El conector **MySQL** y Python ofrecen una integración eficiente para interactuar con bases de datos relacionales. Su uso permite realizar operaciones CRUD de manera segura y flexible, facilitando el desarrollo de aplicaciones que requieran almacenamiento y consulta de datos estructurados. Implementar prácticas como el manejo de errores y consultas parametrizadas garantiza mayor seguridad y robustez.

# %% [markdown]
# #### Sentencia SELECT desde Python a MySQL
#
# La sentencia **`SELECT`** se utiliza en Python junto con el conector MySQL para consultar y recuperar datos de una base de datos MySQL. Este proceso implica establecer una conexión, ejecutar la consulta y trabajar con los resultados obtenidos.
#
# ---
#
# ##### Configuración inicial
#
# 1. Instala el conector MySQL si aún no lo tienes:
#    ```bash
#    pip install mysql-connector-python
#    ```
#
# 2. Importa la biblioteca en tu script de Python:
#    ```python
#    import mysql.connector
#    ```
#
# ---
#
# ##### Consultar datos básicos con `SELECT`
#
# 1. **Conexión a la base de datos**:
#    Establece la conexión con tu servidor MySQL.
#    ```python
#    conexion = mysql.connector.connect(
#        host="localhost",
#        user="tu_usuario",
#        password="tu_contraseña",
#        database="mi_base"
#    )
#    ```
#
# 2. **Ejecuta la consulta `SELECT`**:
#    Usa un cursor para ejecutar la consulta y recuperar los datos.
#    ```python
#    cursor = conexion.cursor()
#
#    cursor.execute("SELECT * FROM usuarios")
#
#    resultado = cursor.fetchall()  # Recupera todas las filas
#    ```
#
# 3. **Procesa los resultados**:
#    Itera sobre las filas recuperadas para trabajar con los datos.
#    ```python
#    for fila in resultado:
#        print(fila)  # Cada fila es una tupla
#    ```
#
# 4. **Cierra el cursor y la conexión**:
#    Libera los recursos cuando termines.
#    ```python
#    cursor.close()
#    conexion.close()
#    ```
#
# ---
#
# ##### Filtrar resultados con `WHERE`
#
# Agrega condiciones para limitar los datos recuperados.
# ```python
# cursor.execute("SELECT nombre, edad FROM usuarios WHERE edad > %s", (30,))
# resultado = cursor.fetchall()
#
# for fila in resultado:
#     print(f"Nombre: {fila[0]}, Edad: {fila[1]}")
# ```
#
# ---
#
# ##### Ordenar resultados con `ORDER BY`
#
# Añade una cláusula para ordenar los datos.
# ```python
# cursor.execute("SELECT nombre, edad FROM usuarios ORDER BY edad DESC")
# resultado = cursor.fetchall()
#
# for fila in resultado:
#     print(f"Nombre: {fila[0]}, Edad: {fila[1]}")
# ```
#
# ---
#
# ##### Limitar el número de resultados con `LIMIT`
#
# Recupera un número específico de filas.
# ```python
# cursor.execute("SELECT * FROM usuarios LIMIT 5")
# resultado = cursor.fetchall()
#
# for fila in resultado:
#     print(fila)
# ```
#
# ---
#
# ##### Uso seguro con consultas parametrizadas
#
# Evita inyecciones SQL usando placeholders (`%s`) para pasar parámetros.
# ```python
# cursor.execute("SELECT * FROM usuarios WHERE nombre = %s", ("Juan",))
# resultado = cursor.fetchall()
#
# for fila in resultado:
#     print(fila)
# ```
#
# ---
#
# ##### Manejo de errores
#
# Captura excepciones para manejar errores de conexión o consulta.
# ```python
# try:
#     conexion = mysql.connector.connect(
#         host="localhost",
#         user="tu_usuario",
#         password="tu_contraseña",
#         database="mi_base"
#     )
#     cursor = conexion.cursor()
#     cursor.execute("SELECT * FROM usuarios")
#     resultado = cursor.fetchall()
#     for fila in resultado:
#         print(fila)
# except mysql.connector.Error as error:
#     print(f"Error: {error}")
# finally:
#     if conexion.is_connected():
#         cursor.close()
#         conexion.close()
# ```
#
# ---
#
# ##### Conclusión
#
# Usar la sentencia **`SELECT`** desde Python para conectarse a MySQL es una forma efectiva de consultar y trabajar con datos. La combinación de consultas parametrizadas, manejo de errores y una buena gestión de recursos asegura que las operaciones sean seguras y eficientes.

# %% [markdown]
# #### Sentencia SELECT desde Python a MySQL
#
# La sentencia **`SELECT`** se utiliza en Python junto con el conector MySQL para consultar y recuperar datos de una base de datos MySQL. Este proceso implica establecer una conexión, ejecutar la consulta y trabajar con los resultados obtenidos.
#
# ---
#
# ##### Configuración inicial
#
# 1. Instala el conector MySQL si aún no lo tienes:
#    ```bash
#    pip install mysql-connector-python
#    ```
#
# 2. Importa la biblioteca en tu script de Python:
#    ```python
#    import mysql.connector
#    ```
#
# ---
#
# ##### Consultar datos básicos con `SELECT`
#
# 1. **Conexión a la base de datos**:
#    Establece la conexión con tu servidor MySQL.
#    ```python
#    conexion = mysql.connector.connect(
#        host="localhost",
#        user="tu_usuario",
#        password="tu_contraseña",
#        database="mi_base"
#    )
#    ```
#
# 2. **Ejecuta la consulta `SELECT`**:
#    Usa un cursor para ejecutar la consulta y recuperar los datos.
#    ```python
#    cursor = conexion.cursor()
#
#    cursor.execute("SELECT * FROM usuarios")
#
#    resultado = cursor.fetchall()  # Recupera todas las filas
#    ```
#
# 3. **Procesa los resultados**:
#    Itera sobre las filas recuperadas para trabajar con los datos.
#    ```python
#    for fila in resultado:
#        print(fila)  # Cada fila es una tupla
#    ```
#
# 4. **Cierra el cursor y la conexión**:
#    Libera los recursos cuando termines.
#    ```python
#    cursor.close()
#    conexion.close()
#    ```
#
# ---
#
# ##### Filtrar resultados con `WHERE`
#
# Agrega condiciones para limitar los datos recuperados.
# ```python
# cursor.execute("SELECT nombre, edad FROM usuarios WHERE edad > %s", (30,))
# resultado = cursor.fetchall()
#
# for fila in resultado:
#     print(f"Nombre: {fila[0]}, Edad: {fila[1]}")
# ```
#
# ---
#
# ##### Ordenar resultados con `ORDER BY`
#
# Añade una cláusula para ordenar los datos.
# ```python
# cursor.execute("SELECT nombre, edad FROM usuarios ORDER BY edad DESC")
# resultado = cursor.fetchall()
#
# for fila in resultado:
#     print(f"Nombre: {fila[0]}, Edad: {fila[1]}")
# ```
#
# ---
#
# ##### Limitar el número de resultados con `LIMIT`
#
# Recupera un número específico de filas.
# ```python
# cursor.execute("SELECT * FROM usuarios LIMIT 5")
# resultado = cursor.fetchall()
#
# for fila in resultado:
#     print(fila)
# ```
#
# ---
#
# ##### Uso seguro con consultas parametrizadas
#
# Evita inyecciones SQL usando placeholders (`%s`) para pasar parámetros.
# ```python
# cursor.execute("SELECT * FROM usuarios WHERE nombre = %s", ("Juan",))
# resultado = cursor.fetchall()
#
# for fila in resultado:
#     print(fila)
# ```
#
# ---
#
# ##### Manejo de errores
#
# Captura excepciones para manejar errores de conexión o consulta.
# ```python
# try:
#     conexion = mysql.connector.connect(
#         host="localhost",
#         user="tu_usuario",
#         password="tu_contraseña",
#         database="mi_base"
#     )
#     cursor = conexion.cursor()
#     cursor.execute("SELECT * FROM usuarios")
#     resultado = cursor.fetchall()
#     for fila in resultado:
#         print(fila)
# except mysql.connector.Error as error:
#     print(f"Error: {error}")
# finally:
#     if conexion.is_connected():
#         cursor.close()
#         conexion.close()
# ```
#
# ---
#
# ##### Conclusión
#
# Usar la sentencia **`SELECT`** desde Python para conectarse a MySQL es una forma efectiva de consultar y trabajar con datos. La combinación de consultas parametrizadas, manejo de errores y una buena gestión de recursos asegura que las operaciones sean seguras y eficientes.

# %% [markdown]
# #### Sentencia INSERT desde Python a MySQL
#
# La sentencia **`INSERT`** permite agregar registros en una tabla de MySQL desde Python. Utilizar valores parametrizados garantiza seguridad y previene vulnerabilidades como la inyección SQL.
#
# ---
#
# ##### Configuración inicial
#
# 1. Instala el conector MySQL:
#    ```bash
#    pip install mysql-connector-python
#    ```
#
# 2. Importa el módulo necesario en tu archivo Python:
#    ```python
#    import mysql.connector
#    ```
#
# ---
#
# ##### Insertar un único registro
#
# 1. **Establecer conexión y crear un cursor**:
#    Conéctate a la base de datos y crea un cursor para ejecutar consultas.
#    ```python
#    conexion = mysql.connector.connect(
#        host="localhost",
#        user="tu_usuario",
#        password="tu_contraseña",
#        database="mi_base"
#    )
#    cursor = conexion.cursor()
#    ```
#
# 2. **Escribir y ejecutar la consulta `INSERT`**:
#    Utiliza placeholders (`%s`) para una inserción segura:
#    ```python
#    sql = "INSERT INTO usuarios (nombre, edad) VALUES (%s, %s)"
#    valores = ("Juan", 30)
#
#    cursor.execute(sql, valores)
#    conexion.commit()
#
#    print(f"Registro insertado con ID: {cursor.lastrowid}")
#    ```
#
# 3. **Cerrar la conexión**:
#    Libera los recursos después de completar la operación:
#    ```python
#    cursor.close()
#    conexion.close()
#    ```
#
# ---
#
# ##### Insertar múltiples registros
#
# Usa el método `executemany()` para insertar varios registros en una sola operación:
# ```python
# sql = "INSERT INTO usuarios (nombre, edad) VALUES (%s, %s)"
# valores = [
#     ("Ana", 25),
#     ("Luis", 40),
#     ("María", 35)
# ]
#
# cursor.executemany(sql, valores)
# conexion.commit()
#
# print(f"Registros insertados: {cursor.rowcount}")
# ```
#
# ---
#
# ##### Manejo de errores
#
# Captura excepciones relacionadas con la conexión o la consulta:
# ```python
# try:
#     conexion = mysql.connector.connect(
#         host="localhost",
#         user="tu_usuario",
#         password="tu_contraseña",
#         database="mi_base"
#     )
#     cursor = conexion.cursor()
#
#     sql = "INSERT INTO usuarios (nombre, edad) VALUES (%s, %s)"
#     valores = ("Carlos", 28)
#
#     cursor.execute(sql, valores)
#     conexion.commit()
#
#     print(f"Registro insertado con ID: {cursor.lastrowid}")
# except mysql.connector.Error as error:
#     print(f"Error: {error}")
# finally:
#     if conexion.is_connected():
#         cursor.close()
#         conexion.close()
# ```
#
# ---
#
# ##### Inserción con valores predeterminados
#
# Si algunas columnas tienen valores predeterminados definidos en la tabla, puedes omitirlas en la consulta:
# ```python
# sql = "INSERT INTO usuarios (nombre) VALUES (%s)"
# valores = ("Sofía",)
#
# cursor.execute(sql, valores)
# conexion.commit()
# ```
#
# ---
#
# ##### Conclusión
#
# La sentencia **`INSERT`** es esencial para agregar datos en MySQL desde Python. Utilizar métodos seguros como consultas parametrizadas y manejar errores asegura un código fiable. Además, la capacidad de insertar múltiples registros de manera eficiente ahorra tiempo en operaciones masivas. La gestión correcta de recursos y el uso de valores predeterminados garantizan una implementación robusta y flexible.

# %% [markdown]
# #### Sentencia UPDATE desde Python a MySQL
#
# La sentencia **`UPDATE`** se utiliza para modificar registros en una tabla de MySQL desde un script en Python. Es útil para actualizar valores específicos o múltiples columnas dentro de una base de datos.
#
# ---
#
# ##### Configuración inicial
#
# 1. Asegúrate de instalar el conector MySQL:
#    ```bash
#    pip install mysql-connector-python
#    ```
#
# 2. Importa la biblioteca necesaria:
#    ```python
#    import mysql.connector
#    ```
#
# ---
#
# ##### Actualizar un registro específico
#
# 1. **Establecer conexión y crear un cursor**:
#    ```python
#    conexion = mysql.connector.connect(
#        host="localhost",
#        user="tu_usuario",
#        password="tu_contraseña",
#        database="mi_base"
#    )
#    cursor = conexion.cursor()
#    ```
#
# 2. **Escribir y ejecutar la consulta `UPDATE`**:
#    Usa placeholders (`%s`) para valores parametrizados.
#    ```python
#    sql = "UPDATE usuarios SET edad = %s WHERE nombre = %s"
#    valores = (31, "Juan")
#
#    cursor.execute(sql, valores)
#    conexion.commit()
#
#    print(f"Registros actualizados: {cursor.rowcount}")
#    ```
#
# 3. **Cerrar la conexión**:
#    Libera recursos una vez realizada la operación.
#    ```python
#    cursor.close()
#    conexion.close()
#    ```
#
# ---
#
# ##### Actualizar múltiples columnas
#
# Se pueden modificar varias columnas en una única operación:
# ```python
# sql = "UPDATE usuarios SET nombre = %s, edad = %s WHERE id = %s"
# valores = ("Juan Pérez", 32, 1)
#
# cursor.execute(sql, valores)
# conexion.commit()
#
# print(f"Registros actualizados: {cursor.rowcount}")
# ```
#
# ---
#
# ##### Actualizar todos los registros
#
# Si se omite la cláusula `WHERE`, la sentencia afectará a todos los registros de la tabla:
# ```python
# sql = "UPDATE usuarios SET activo = %s"
# valores = (1,)
#
# cursor.execute(sql, valores)
# conexion.commit()
#
# print(f"Registros actualizados: {cursor.rowcount}")
# ```
#
# ---
#
# ##### Manejo de errores
#
# Es importante capturar excepciones para prevenir fallos inesperados:
# ```python
# try:
#     conexion = mysql.connector.connect(
#         host="localhost",
#         user="tu_usuario",
#         password="tu_contraseña",
#         database="mi_base"
#     )
#     cursor = conexion.cursor()
#
#     sql = "UPDATE usuarios SET edad = %s WHERE nombre = %s"
#     valores = (31, "Juan")
#
#     cursor.execute(sql, valores)
#     conexion.commit()
#     print(f"Registros actualizados: {cursor.rowcount}")
# except mysql.connector.Error as error:
#     print(f"Error: {error}")
# finally:
#     if conexion.is_connected():
#         cursor.close()
#         conexion.close()
# ```
#
# ---
#
# ##### Conclusión
#
# La sentencia **`UPDATE`** desde Python permite modificar registros de manera eficiente y segura en una base de datos MySQL. Implementar consultas parametrizadas y manejar errores asegura que las operaciones sean fiables y robustas, garantizando una gestión correcta de los datos.

# %% [markdown]
# #### Sentencia DELETE desde Python a MySQL
#
# La sentencia **`DELETE`** permite eliminar registros específicos en una tabla de MySQL desde un script en Python. Para evitar errores y proteger la integridad de los datos, es crucial usar esta sentencia con precisión y responsabilidad.
#
# ---
#
# ##### Configuración inicial
#
# 1. Instala el conector MySQL si aún no lo tienes:
#    ```bash
#    pip install mysql-connector-python
#    ```
#
# 2. Importa el módulo necesario:
#    ```python
#    import mysql.connector
#    ```
#
# ---
#
# ##### Eliminar un registro específico
#
# 1. **Establecer conexión y crear un cursor**:
#    ```python
#    conexion = mysql.connector.connect(
#        host="localhost",
#        user="tu_usuario",
#        password="tu_contraseña",
#        database="mi_base"
#    )
#    cursor = conexion.cursor()
#    ```
#
# 2. **Escribir y ejecutar la consulta `DELETE`**:
#    Usa placeholders (`%s`) para realizar una consulta parametrizada.
#    ```python
#    sql = "DELETE FROM usuarios WHERE id = %s"
#    valores = (1,)
#
#    cursor.execute(sql, valores)
#    conexion.commit()
#
#    print(f"Registros eliminados: {cursor.rowcount}")
#    ```
#
# 3. **Cerrar la conexión**:
#    ```python
#    cursor.close()
#    conexion.close()
#    ```
#
# ---
#
# ##### Eliminar múltiples registros
#
# Filtra los registros a eliminar utilizando condiciones con `WHERE`:
# ```python
# sql = "DELETE FROM usuarios WHERE edad > %s"
# valores = (30,)
#
# cursor.execute(sql, valores)
# conexion.commit()
#
# print(f"Registros eliminados: {cursor.rowcount}")
# ```
#
# ---
#
# ##### Eliminar todos los registros de una tabla
#
# Si deseas eliminar todos los registros, asegúrate de no omitir la cláusula `WHERE` a menos que sea intencionado.
# ```python
# sql = "DELETE FROM usuarios"
#
# cursor.execute(sql)
# conexion.commit()
#
# print(f"Todos los registros han sido eliminados: {cursor.rowcount}")
# ```
#
# ---
#
# ##### Manejo de errores
#
# Captura posibles errores relacionados con la conexión o la consulta:
# ```python
# try:
#     conexion = mysql.connector.connect(
#         host="localhost",
#         user="tu_usuario",
#         password="tu_contraseña",
#         database="mi_base"
#     )
#     cursor = conexion.cursor()
#
#     sql = "DELETE FROM usuarios WHERE nombre = %s"
#     valores = ("Carlos",)
#
#     cursor.execute(sql, valores)
#     conexion.commit()
#
#     print(f"Registros eliminados: {cursor.rowcount}")
# except mysql.connector.Error as error:
#     print(f"Error: {error}")
# finally:
#     if conexion.is_connected():
#         cursor.close()
#         conexion.close()
# ```
#
# ---
#
# ##### Buenas prácticas
#
# - Usa siempre cláusulas **`WHERE`** para evitar eliminar registros por accidente.
# - Realiza pruebas previas con una consulta **`SELECT`** para confirmar los registros que serán afectados.
# - Haz una copia de seguridad antes de realizar cambios importantes en la base de datos.
#
# ---
#
# ##### Conclusión
#
# La sentencia **`DELETE`** desde Python facilita la eliminación de registros en MySQL, pero debe utilizarse con cuidado para evitar pérdidas de datos inesperadas. Seguir buenas prácticas como el uso de consultas parametrizadas y el manejo de errores asegura un código confiable y seguro.

# %% [markdown]
# #### Concepto de Pool de Conexiones
#
# El **Pool de Conexiones** es una técnica utilizada en la gestión de bases de datos para optimizar la interacción entre aplicaciones y el servidor de base de datos. En lugar de abrir y cerrar una conexión cada vez que se realiza una operación, se reutilizan conexiones previamente abiertas, almacenadas en un conjunto llamado "pool". Esto mejora el rendimiento y reduce la carga en el servidor.
#
# ---
#
# ##### Características principales del Pool de Conexiones
#
# - **Reutilización de conexiones**: Las conexiones abiertas permanecen disponibles para futuras solicitudes.
# - **Reducción de latencia**: Minimiza el tiempo necesario para abrir nuevas conexiones.
# - **Gestión eficiente de recursos**: Permite manejar múltiples solicitudes sin saturar el servidor.
#
# ---
#
# ##### Ventajas del Pool de Conexiones
#
# - **Mayor rendimiento**: Reduce el costo de abrir y cerrar conexiones repetidamente.
# - **Escalabilidad**: Facilita el manejo de aplicaciones con alto volumen de usuarios.
# - **Seguridad**: Configura límites en el número de conexiones simultáneas para evitar sobrecargas.
#
# ---
#
# ##### Funcionamiento del Pool de Conexiones
#
# 1. **Creación del pool**: Se establece un conjunto de conexiones al iniciar la aplicación.
# 2. **Asignación**: Cuando una solicitud necesita acceder a la base de datos, se le asigna una conexión disponible en el pool.
# 3. **Liberación**: Tras completar la operación, la conexión se devuelve al pool para ser reutilizada.
# 4. **Renovación**: Si una conexión falla o expira, el pool la reemplaza con una nueva.
#
# ---
#
# ##### Implementación en Python con MySQL
#
# Para usar un pool de conexiones con Python y MySQL, puedes emplear el módulo `mysql.connector`.
#
# **Ejemplo básico de implementación**:
# ```python
# import mysql.connector
# from mysql.connector import pooling
#
# # Crear el pool de conexiones
# pool = mysql.connector.pooling.MySQLConnectionPool(
#     pool_name="mi_pool",
#     pool_size=5,  # Número máximo de conexiones
#     host="localhost",
#     user="tu_usuario",
#     password="tu_contraseña",
#     database="mi_base"
# )
#
# # Obtener una conexión desde el pool
# conexion = pool.get_connection()
# cursor = conexion.cursor()
#
# # Ejecutar una consulta
# cursor.execute("SELECT * FROM usuarios")
# resultado = cursor.fetchall()
#
# for fila in resultado:
#     print(fila)
#
# # Liberar recursos
# cursor.close()
# conexion.close()
# ```
#
# ---
#
# ##### Conclusión
#
# El Pool de Conexiones es una técnica esencial para optimizar el acceso a bases de datos en aplicaciones que manejan múltiples usuarios y solicitudes. Su implementación garantiza un uso eficiente de los recursos, mejora el rendimiento y reduce el tiempo de respuesta, contribuyendo al desarrollo de sistemas escalables y robustos.

# %% [markdown]
# #### Patrón de Diseño DAO (Data Access Object)
#
# El **Patrón de Diseño DAO (Data Access Object)** es una estrategia utilizada en el desarrollo de software para separar la lógica de acceso a datos del resto de la aplicación. Este patrón organiza el acceso a la base de datos mediante objetos dedicados a interactuar con los datos, proporcionando una capa de abstracción que mejora la mantenibilidad y escalabilidad del sistema.
#
# ---
#
# ##### Características principales
#
# - **Abstracción**: Encapsula la lógica de acceso a la base de datos en un objeto dedicado.
# - **Independencia**: Separa el código de la base de datos del resto de la aplicación, facilitando cambios en la fuente de datos.
# - **Reutilización**: El código de acceso a datos puede reutilizarse en varias partes de la aplicación.
# - **Mantenimiento**: Simplifica las modificaciones en el sistema, permitiendo cambios en la lógica de acceso sin afectar otros componentes.
#
# ---
#
# ##### Ventajas del patrón DAO
#
# 1. **Separación de preocupaciones**: La lógica de negocios y el acceso a datos se manejan en capas independientes.
# 2. **Facilidad de migración**: Cambiar el sistema de base de datos es más sencillo al tener una capa de acceso dedicada.
# 3. **Testabilidad**: Permite pruebas unitarias de la lógica de acceso a datos sin depender de otras partes de la aplicación.
# 4. **Flexibilidad**: Admite múltiples tecnologías de bases de datos sin modificar la capa de negocio.
#
# ---
#
# ##### Implementación del Patrón DAO en Python
#
# El patrón DAO puede implementarse creando clases dedicadas para interactuar con los datos.
#
# 1. **Definición de la entidad (modelo)**:
#    Se define una clase que representa los datos.
#    ```python
#    class Usuario:
#        def __init__(self, id, nombre, edad):
#            self.id = id
#            self.nombre = nombre
#            self.edad = edad
#    ```
#
# 2. **Implementación de la clase DAO**:
#    Crea una clase para manejar las operaciones de acceso a la base de datos.
#    ```python
#    import mysql.connector
#
#    class UsuarioDAO:
#        def __init__(self, conexion):
#            self.conexion = conexion
#
#        def obtener_todos(self):
#            cursor = self.conexion.cursor()
#            cursor.execute("SELECT id, nombre, edad FROM usuarios")
#            resultados = cursor.fetchall()
#            cursor.close()
#            return [Usuario(*fila) for fila in resultados]
#
#        def insertar(self, usuario):
#            cursor = self.conexion.cursor()
#            sql = "INSERT INTO usuarios (nombre, edad) VALUES (%s, %s)"
#            valores = (usuario.nombre, usuario.edad)
#            cursor.execute(sql, valores)
#            self.conexion.commit()
#            cursor.close()
#
#        def actualizar(self, usuario):
#            cursor = self.conexion.cursor()
#            sql = "UPDATE usuarios SET nombre = %s, edad = %s WHERE id = %s"
#            valores = (usuario.nombre, usuario.edad, usuario.id)
#            cursor.execute(sql, valores)
#            self.conexion.commit()
#            cursor.close()
#
#        def eliminar(self, usuario_id):
#            cursor = self.conexion.cursor()
#            sql = "DELETE FROM usuarios WHERE id = %s"
#            cursor.execute(sql, (usuario_id,))
#            self.conexion.commit()
#            cursor.close()
#    ```
#
# 3. **Uso del DAO**:
#    Utiliza la clase DAO para interactuar con los datos desde la lógica de negocio.
#    ```python
#    conexion = mysql.connector.connect(
#        host="localhost",
#        user="tu_usuario",
#        password="tu_contraseña",
#        database="mi_base"
#    )
#
#    usuario_dao = UsuarioDAO(conexion)
#
#    # Insertar un nuevo usuario
#    nuevo_usuario = Usuario(None, "Juan", 30)
#    usuario_dao.insertar(nuevo_usuario)
#
#    # Obtener todos los usuarios
#    usuarios = usuario_dao.obtener_todos()
#    for usuario in usuarios:
#        print(f"ID: {usuario.id}, Nombre: {usuario.nombre}, Edad: {usuario.edad}")
#
#    # Actualizar un usuario
#    usuarios[0].nombre = "Juan Pérez"
#    usuario_dao.actualizar(usuarios[0])
#
#    # Eliminar un usuario
#    usuario_dao.eliminar(usuarios[0].id)
#
#    conexion.close()
#    ```
#
# ---
#
# ##### Conclusión
#
# El **Patrón DAO** mejora la arquitectura de una aplicación al encapsular la lógica de acceso a datos en una capa separada. Su implementación en Python garantiza una estructura modular y flexible, facilitando la escalabilidad, mantenimiento y pruebas del sistema. Este enfoque es ideal para aplicaciones que interactúan frecuentemente con bases de datos.

# %% [markdown]
# #### Método Seleccionar en una Clase DAO
#
# El método **Seleccionar** en una clase DAO (Data Access Object) es responsable de recuperar datos de una base de datos, encapsulando la lógica de acceso. Este método utiliza consultas SQL, típicamente con la sentencia `SELECT`, y devuelve los resultados en un formato estructurado, como una lista de objetos.
#
# ---
#
# ##### Implementación del Método Seleccionar
#
# A continuación, se presenta un ejemplo de cómo implementar el método `seleccionar` en una clase DAO utilizando Python y el conector MySQL.
#
# 1. **Definición de la entidad (modelo)**:
#    La entidad representa las filas de la tabla de la base de datos como objetos.
#    ```python
#    class Usuario:
#        def __init__(self, id, nombre, edad):
#            self.id = id
#            self.nombre = nombre
#            self.edad = edad
#    ```
#
# 2. **Clase DAO con el método `seleccionar`**:
#    Este método recupera todos los registros de la tabla `usuarios`.
#    ```python
#    import mysql.connector
#
#    class UsuarioDAO:
#        def __init__(self, conexion):
#            self.conexion = conexion
#
#        def seleccionar_todos(self):
#            cursor = self.conexion.cursor()
#            cursor.execute("SELECT id, nombre, edad FROM usuarios")
#            resultados = cursor.fetchall()
#            cursor.close()
#            # Retornar objetos de la clase Usuario
#            return [Usuario(*fila) for fila in resultados]
#    ```
#
# 3. **Uso del método `seleccionar_todos`**:
#    Una vez configurada la conexión y el DAO, puedes invocar el método para recuperar los datos.
#    ```python
#    # Establecer conexión
#    conexion = mysql.connector.connect(
#        host="localhost",
#        user="tu_usuario",
#        password="tu_contraseña",
#        database="mi_base"
#    )
#
#    # Instanciar DAO
#    usuario_dao = UsuarioDAO(conexion)
#
#    # Llamar al método seleccionar
#    usuarios = usuario_dao.seleccionar_todos()
#
#    # Procesar resultados
#    for usuario in usuarios:
#        print(f"ID: {usuario.id}, Nombre: {usuario.nombre}, Edad: {usuario.edad}")
#
#    # Cerrar conexión
#    conexion.close()
#    ```
#
# ---
#
# ##### Filtrar resultados con condiciones
#
# Si deseas que el método seleccione datos con un filtro específico, puedes usar parámetros en la consulta SQL.
#
# ```python
#    def seleccionar_por_edad(self, edad_minima):
#        cursor = self.conexion.cursor()
#        sql = "SELECT id, nombre, edad FROM usuarios WHERE edad >= %s"
#        cursor.execute(sql, (edad_minima,))
#        resultados = cursor.fetchall()
#        cursor.close()
#        return [Usuario(*fila) for fila in resultados]
# ```
#
# Ejemplo de uso:
#
# ```python
# usuarios_mayores = usuario_dao.seleccionar_por_edad(30)
# for usuario in usuarios_mayores:
#     print(f"ID: {usuario.id}, Nombre: {usuario.nombre}, Edad: {usuario.edad}")
# ```
#
# ---
#
# ##### Manejo de errores
#
# Es importante agregar manejo de excepciones para garantizar que el sistema no falle si ocurre un problema durante la consulta.
#
# ```python
#    def seleccionar_todos(self):
#        try:
#            cursor = self.conexion.cursor()
#            cursor.execute("SELECT id, nombre, edad FROM usuarios")
#            resultados = cursor.fetchall()
#            return [Usuario(*fila) for fila in resultados]
#        except mysql.connector.Error as error:
#            print(f"Error al seleccionar datos: {error}")
#            return []
#        finally:
#            cursor.close()
# ```
#
# ---
#
# ##### Conclusión
#
# El método **Seleccionar** en una clase DAO simplifica el acceso a los datos al encapsular la lógica de consulta. Con esta implementación, puedes recuperar registros de manera estructurada, aplicando filtros según sea necesario, mientras mantienes un código limpio y modular que es fácil de mantener y escalar.

# %% [markdown]
# #### Método Insertar en una Clase DAO
#
# El método **Insertar** en una clase DAO (Data Access Object) se utiliza para agregar nuevos registros en una base de datos. Este método encapsula la lógica de inserción dentro de una clase específica, facilitando la reutilización y manteniendo la independencia entre la lógica de negocio y el acceso a datos.
#
# ---
#
# ##### Implementación del Método Insertar
#
# A continuación, se presenta un ejemplo de cómo implementar el método `insertar` en una clase DAO utilizando Python y el conector MySQL.
#
# 1. **Definición de la entidad (modelo)**:
#    Define una clase que represente los datos a insertar en la base de datos.
#    ```python
#    class Usuario:
#        def __init__(self, id, nombre, edad):
#            self.id = id
#            self.nombre = nombre
#            self.edad = edad
#    ```
#
# 2. **Clase DAO con el método `insertar`**:
#    Crea el método que ejecutará la operación de inserción en la base de datos.
#    ```python
#    import mysql.connector
#
#    class UsuarioDAO:
#        def __init__(self, conexion):
#            self.conexion = conexion
#
#        def insertar(self, usuario):
#            cursor = self.conexion.cursor()
#            sql = "INSERT INTO usuarios (nombre, edad) VALUES (%s, %s)"
#            valores = (usuario.nombre, usuario.edad)
#            cursor.execute(sql, valores)
#            self.conexion.commit()
#            cursor.close()
#            print(f"Usuario {usuario.nombre} insertado con éxito.")
#    ```
#
# 3. **Uso del método `insertar`**:
#    Una vez configurada la conexión, puedes crear objetos de la entidad y usar el método para insertar datos.
#    ```python
#    # Establecer conexión
#    conexion = mysql.connector.connect(
#        host="localhost",
#        user="tu_usuario",
#        password="tu_contraseña",
#        database="mi_base"
#    )
#
#    # Instanciar DAO
#    usuario_dao = UsuarioDAO(conexion)
#
#    # Crear un nuevo usuario y usar el método insertar
#    nuevo_usuario = Usuario(None, "Juan", 30)
#    usuario_dao.insertar(nuevo_usuario)
#
#    # Cerrar conexión
#    conexion.close()
#    ```
#
# ---
#
# ##### Inserción múltiple
#
# Si necesitas insertar varios registros en una sola operación, puedes adaptar el método para aceptar una lista de objetos.
# ```python
#    def insertar_varios(self, usuarios):
#        cursor = self.conexion.cursor()
#        sql = "INSERT INTO usuarios (nombre, edad) VALUES (%s, %s)"
#        valores = [(usuario.nombre, usuario.edad) for usuario in usuarios]
#        cursor.executemany(sql, valores)
#        self.conexion.commit()
#        cursor.close()
#        print("Usuarios insertados con éxito.")
# ```
#
# Ejemplo de uso:
# ```python
# usuarios = [
#     Usuario(None, "Ana", 25),
#     Usuario(None, "Luis", 40),
#     Usuario(None, "María", 35)
# ]
# usuario_dao.insertar_varios(usuarios)
# ```
#
# ---
#
# ##### Manejo de errores
#
# Es importante agregar manejo de excepciones para garantizar que la aplicación no falle si ocurre un problema durante la inserción.
# ```python
#    def insertar(self, usuario):
#        try:
#            cursor = self.conexion.cursor()
#            sql = "INSERT INTO usuarios (nombre, edad) VALUES (%s, %s)"
#            valores = (usuario.nombre, usuario.edad)
#            cursor.execute(sql, valores)
#            self.conexion.commit()
#            print(f"Usuario {usuario.nombre} insertado con éxito.")
#        except mysql.connector.Error as error:
#            print(f"Error al insertar usuario: {error}")
#        finally:
#            cursor.close()
# ```
#
# ---
#
# ##### Conclusión
#
# El método **Insertar** en una clase DAO organiza y centraliza la lógica de inserción en una base de datos. Esta implementación asegura un código modular y reutilizable, facilitando la interacción con los datos de manera segura y eficiente. Además, la posibilidad de manejar inserciones múltiples y errores garantiza un sistema robusto y adaptable.

# %% [markdown]
# #### Método Actualizar en una Clase DAO
#
# El método **Actualizar** en una clase DAO (Data Access Object) permite modificar registros existentes en una base de datos. Este método encapsula la lógica de actualización, asegurando que los cambios se realicen de manera segura y organizada dentro de una capa dedicada de acceso a datos.
#
# ---
#
# ##### Implementación del Método Actualizar
#
# Aquí te muestro cómo implementar el método `actualizar` en una clase DAO utilizando Python y el conector MySQL.
#
# 1. **Definición de la entidad (modelo)**:
#    Define una clase que represente los datos que se actualizarán en la base de datos.
#    ```python
#    class Usuario:
#        def __init__(self, id, nombre, edad):
#            self.id = id
#            self.nombre = nombre
#            self.edad = edad
#    ```
#
# 2. **Clase DAO con el método `actualizar`**:
#    El método actualiza un registro específico en la tabla.
#    ```python
#    import mysql.connector
#
#    class UsuarioDAO:
#        def __init__(self, conexion):
#            self.conexion = conexion
#
#        def actualizar(self, usuario):
#            cursor = self.conexion.cursor()
#            sql = "UPDATE usuarios SET nombre = %s, edad = %s WHERE id = %s"
#            valores = (usuario.nombre, usuario.edad, usuario.id)
#            cursor.execute(sql, valores)
#            self.conexion.commit()
#            cursor.close()
#            print(f"Usuario con ID {usuario.id} actualizado con éxito.")
#    ```
#
# 3. **Uso del método `actualizar`**:
#    Usa el método para modificar los datos de un objeto existente.
#    ```python
#    # Establecer conexión
#    conexion = mysql.connector.connect(
#        host="localhost",
#        user="tu_usuario",
#        password="tu_contraseña",
#        database="mi_base"
#    )
#
#    # Instanciar DAO
#    usuario_dao = UsuarioDAO(conexion)
#
#    # Crear un usuario existente y actualizarlo
#    usuario_existente = Usuario(1, "Juan Pérez", 32)
#    usuario_dao.actualizar(usuario_existente)
#
#    # Cerrar conexión
#    conexion.close()
#    ```
#
# ---
#
# ##### Actualizar múltiples registros
#
# Puedes extender el método para actualizar varios registros si es necesario. Por ejemplo, con una lista de objetos:
# ```python
#    def actualizar_varios(self, usuarios):
#        cursor = self.conexion.cursor()
#        sql = "UPDATE usuarios SET nombre = %s, edad = %s WHERE id = %s"
#        for usuario in usuarios:
#            valores = (usuario.nombre, usuario.edad, usuario.id)
#            cursor.execute(sql, valores)
#        self.conexion.commit()
#        cursor.close()
#        print("Usuarios actualizados con éxito.")
# ```
#
# Ejemplo de uso:
# ```python
# usuarios = [
#     Usuario(1, "Ana García", 28),
#     Usuario(2, "Luis Méndez", 42),
#     Usuario(3, "María López", 35)
# ]
# usuario_dao.actualizar_varios(usuarios)
# ```
#
# ---
#
# ##### Manejo de errores
#
# Es importante implementar manejo de errores para evitar problemas durante la actualización.
# ```python
#    def actualizar(self, usuario):
#        try:
#            cursor = self.conexion.cursor()
#            sql = "UPDATE usuarios SET nombre = %s, edad = %s WHERE id = %s"
#            valores = (usuario.nombre, usuario.edad, usuario.id)
#            cursor.execute(sql, valores)
#            self.conexion.commit()
#            print(f"Usuario con ID {usuario.id} actualizado con éxito.")
#        except mysql.connector.Error as error:
#            print(f"Error al actualizar usuario: {error}")
#        finally:
#            cursor.close()
# ```
#
# ---
#
# ##### Conclusión
#
# El método **Actualizar** en una clase DAO organiza la lógica de modificación de datos, permitiendo realizar cambios precisos y seguros en una base de datos. Su implementación, junto con manejo de errores, asegura un acceso eficiente y confiable a los datos dentro de aplicaciones que interactúan con bases de datos relacionales.

# %% [markdown]
# #### Método Eliminar en una Clase DAO
#
# El método **Eliminar** en una clase DAO (Data Access Object) se utiliza para remover registros de una base de datos. Este enfoque encapsula la lógica de eliminación, manteniendo el acceso a datos organizado, seguro y modular.
#
# ---
#
# ##### Implementación del Método Eliminar
#
# A continuación, se detalla cómo implementar el método `eliminar` en una clase DAO utilizando Python y el conector MySQL.
#
# 1. **Definición de la entidad (modelo)**:
#    En este caso, utilizaremos la entidad `Usuario` para referirnos a los datos de la base de datos.
#    ```python
#    class Usuario:
#        def __init__(self, id, nombre, edad):
#            self.id = id
#            self.nombre = nombre
#            self.edad = edad
#    ```
#
# 2. **Clase DAO con el método `eliminar`**:
#    El método elimina un registro específico basado en su ID u otro criterio único.
#    ```python
#    import mysql.connector
#
#    class UsuarioDAO:
#        def __init__(self, conexion):
#            self.conexion = conexion
#
#        def eliminar(self, usuario_id):
#            cursor = self.conexion.cursor()
#            sql = "DELETE FROM usuarios WHERE id = %s"
#            valores = (usuario_id,)
#            cursor.execute(sql, valores)
#            self.conexion.commit()
#            cursor.close()
#            print(f"Usuario con ID {usuario_id} eliminado con éxito.")
#    ```
#
# 3. **Uso del método `eliminar`**:
#    Utiliza el método para eliminar un registro específico en la tabla.
#    ```python
#    # Establecer conexión
#    conexion = mysql.connector.connect(
#        host="localhost",
#        user="tu_usuario",
#        password="tu_contraseña",
#        database="mi_base"
#    )
#
#    # Instanciar DAO
#    usuario_dao = UsuarioDAO(conexion)
#
#    # Eliminar un usuario por su ID
#    usuario_dao.eliminar(1)
#
#    # Cerrar conexión
#    conexion.close()
#    ```
#
# ---
#
# ##### Eliminación basada en otros criterios
#
# Puedes adaptar el método para eliminar registros basados en condiciones diferentes, como el nombre.
# ```python
#    def eliminar_por_nombre(self, nombre):
#        cursor = self.conexion.cursor()
#        sql = "DELETE FROM usuarios WHERE nombre = %s"
#        valores = (nombre,)
#        cursor.execute(sql, valores)
#        self.conexion.commit()
#        cursor.close()
#        print(f"Usuarios con nombre {nombre} eliminados con éxito.")
# ```
#
# Ejemplo de uso:
# ```python
# usuario_dao.eliminar_por_nombre("Carlos")
# ```
#
# ---
#
# ##### Manejo de errores
#
# Es fundamental manejar errores durante la eliminación para evitar inconsistencias en los datos.
# ```python
#    def eliminar(self, usuario_id):
#        try:
#            cursor = self.conexion.cursor()
#            sql = "DELETE FROM usuarios WHERE id = %s"
#            valores = (usuario_id,)
#            cursor.execute(sql, valores)
#            self.conexion.commit()
#            print(f"Usuario con ID {usuario_id} eliminado con éxito.")
#        except mysql.connector.Error as error:
#            print(f"Error al eliminar usuario: {error}")
#        finally:
#            cursor.close()
# ```
#
# ---
#
# ##### Buenas prácticas
#
# - **Verificación previa**: Usa una consulta `SELECT` antes de eliminar registros para confirmar la existencia de los datos.
# - **Cláusulas `WHERE`**: Siempre utiliza filtros para evitar eliminar toda la tabla por error.
# - **Copia de seguridad**: Realiza respaldos periódicos de la base de datos para prevenir pérdidas irreversibles.
#
# ---
#
# ##### Conclusión
#
# El método **Eliminar** en una clase DAO facilita la administración de datos al encapsular la lógica de remoción en una capa dedicada. Su implementación modular asegura que la aplicación sea más mantenible, segura y adaptable a futuras modificaciones en la base de datos.

# %% [markdown]
# ### Sección 12: Interfaces Gráficas con Tkinter (GUI)

# %% [markdown]
# #### Introducción a Tkinter
#
# **Tkinter** es la biblioteca estándar de Python para desarrollar interfaces gráficas de usuario (GUI). Ofrece una forma sencilla y eficiente de crear ventanas, botones, cuadros de texto, menús y otros elementos gráficos interactivos.
#
# ---
#
# ##### Características principales de Tkinter
#
# - **Integración nativa**: Tkinter viene integrado con Python, por lo que no requiere instalación adicional.
# - **Elementos básicos GUI**: Incluye widgets comunes como botones, etiquetas, cuadros de texto, y listas desplegables.
# - **Personalización**: Permite modificar propiedades de los widgets como colores, tamaños, fuentes y posiciones.
# - **Portabilidad**: Las aplicaciones creadas con Tkinter funcionan en múltiples sistemas operativos.
#
# ---
#
# ##### Ventajas de Tkinter
#
# - **Facilidad de uso**: Ideal para principiantes debido a su simplicidad y documentación extensa.
# - **Interactividad**: Permite gestionar eventos como clics y entradas de teclado.
# - **Compatibilidad**: Funciona en Python 2 y 3.
# - **Extensibilidad**: Se puede combinar con otras bibliotecas de Python para aplicaciones más avanzadas.
#
# ---
#
# ##### Conceptos básicos
#
# Para empezar con Tkinter, primero importa la biblioteca. Luego, crea una ventana principal y añade widgets.
#
# 1. **Importar Tkinter**
#    ```python
#    import tkinter as tk
#    ```
#
# 2. **Crear la ventana principal**
#    ```python
#    ventana = tk.Tk()
#    ventana.title("Mi primera GUI")
#    ventana.mainloop()
#    ```
#
# 3. **Añadir widgets**
#    Ejemplo de un botón y una etiqueta:
#    ```python
#    etiqueta = tk.Label(ventana, text="¡Hola, Tkinter!")
#    etiqueta.pack()
#
#    boton = tk.Button(ventana, text="Haz clic aquí", command=lambda: print("Botón presionado"))
#    boton.pack()
#    ```
#
# ---
#
# ##### Widgets comunes en Tkinter
#
# - **Label**: Mostrar texto.
# - **Button**: Botones interactivos.
# - **Entry**: Cuadros de entrada de texto.
# - **Canvas**: Área para dibujar figuras y gráficos.
# - **Frame**: Contenedor para agrupar widgets.
#
# Ejemplo básico:
# ```python
# import tkinter as tk
#
# ventana = tk.Tk()
#
# etiqueta = tk.Label(ventana, text="Etiqueta")
# etiqueta.pack()
#
# entrada = tk.Entry(ventana)
# entrada.pack()
#
# boton = tk.Button(ventana, text="Enviar", command=lambda: print(entrada.get()))
# boton.pack()
#
# ventana.mainloop()
# ```
#
# ---
#
# ##### Personalización
#
# Los widgets pueden personalizarse usando opciones como `bg` para color de fondo, `fg` para color de texto, y `font` para modificar fuentes.
# ```python
# etiqueta = tk.Label(ventana, text="Texto personalizado", bg="blue", fg="white", font=("Arial", 16))
# etiqueta.pack()
# ```
#
# ---
#
# ##### Gestión de diseño
#
# Tkinter permite organizar los widgets en la ventana usando tres métodos:
# 1. **pack()**: Coloca widgets uno debajo del otro o al costado.
# 2. **grid()**: Usa una cuadrícula de filas y columnas.
#    ```python
#    etiqueta.grid(row=0, column=0)
#    entrada.grid(row=1, column=0)
#    boton.grid(row=2, column=0)
#    ```
# 3. **place()**: Ubica widgets con coordenadas exactas.
#    ```python
#    etiqueta.place(x=50, y=20)
#    ```
#
# ---
#
# ##### Conclusión
#
# **Tkinter** es una herramienta poderosa y sencilla para crear interfaces gráficas en Python. Con su conjunto de widgets y capacidades de personalización, es ideal para desarrollar aplicaciones interactivas de manera rápida y eficiente. Además, su compatibilidad y portabilidad lo convierten en una opción popular para proyectos de cualquier escala.  ¡Perfecto para empezar a construir tus propias aplicaciones GUI!

# %% [markdown]
# #### Creación de una Ventana con Tkinter
#
# Crear una ventana con **Tkinter** es el primer paso para desarrollar una interfaz gráfica en Python. Tkinter proporciona una forma sencilla y rápida de gestionar elementos gráficos como botones, etiquetas y cuadros de texto.
#
# ---
#
# ##### Configuración inicial
#
# 1. **Importar la biblioteca Tkinter**
#    ```python
#    import tkinter as tk
#    ```
#
# 2. **Crear la ventana principal**
#    ```python
#    ventana = tk.Tk()
#    ventana.title("Mi Aplicación")
#    ventana.mainloop()
#    ```
#
# El método `tk.Tk()` inicializa la ventana, y `mainloop()` mantiene la ejecución hasta que el usuario la cierre.
#
# ---
#
# ##### Personalización de la ventana
#
# Puedes modificar propiedades como tamaño, color de fondo y diseño.
#
# - **Definir tamaño y posición**:
#   ```python
#   ventana.geometry("400x300")  # Ancho x Alto
#   ```
#
# - **Establecer color de fondo**:
#   ```python
#   ventana.configure(bg="lightblue")
#   ```
#
# - **Evitar que la ventana cambie de tamaño**:
#   ```python
#   ventana.resizable(False, False)
#   ```
#
# ---
#
# ##### Agregar elementos a la ventana
#
# 1. **Etiqueta**
#    ```python
#    etiqueta = tk.Label(ventana, text="¡Bienvenido a Tkinter!", font=("Arial", 14))
#    etiqueta.pack()
#    ```
#
# 2. **Botón con evento**
#    ```python
#    def mostrar_mensaje():
#        print("Botón presionado")
#
#    boton = tk.Button(ventana, text="Presionar", command=mostrar_mensaje)
#    boton.pack()
#    ```
#
# 3. **Cuadro de entrada**
#    ```python
#    entrada = tk.Entry(ventana)
#    entrada.pack()
#    ```
#
# ---
#
# ##### Diseño de la ventana
#
# Para organizar los elementos en la ventana, puedes usar diferentes métodos de diseño:
# - `pack()`: Coloca widgets de forma secuencial.
# - `grid()`: Organiza widgets en filas y columnas.
# - `place()`: Ubica widgets con coordenadas específicas.
#
# Ejemplo con `grid()`:
# ```python
# etiqueta.grid(row=0, column=0)
# entrada.grid(row=1, column=0)
# boton.grid(row=2, column=0)
# ```
#
# ---
#
# ##### Conclusión
#
# Crear una ventana con **Tkinter** es un proceso sencillo y flexible. Al personalizar el diseño y agregar widgets interactivos, puedes desarrollar aplicaciones gráficas intuitivas y funcionales. Tkinter es una excelente opción para comenzar en el desarrollo de interfaces GUI con Python.

# %% [markdown]
# #### Manejo de Etiquetas con Tkinter
#
# Las **etiquetas (`Label`)** en Tkinter son elementos fundamentales para mostrar texto o imágenes en una interfaz gráfica. Se utilizan comúnmente para indicar información estática en la aplicación, como títulos, descripciones y mensajes al usuario.
#
# ---
#
# ##### Creación de una etiqueta
#
# Para agregar una etiqueta en una ventana Tkinter, usa `Label`.
# ```python
# import tkinter as tk
#
# ventana = tk.Tk()
# ventana.title("Ejemplo de Etiquetas")
#
# # Crear etiqueta
# etiqueta = tk.Label(ventana, text="¡Bienvenido a Tkinter!")
#
# # Mostrar etiqueta en la ventana
# etiqueta.pack()
#
# ventana.mainloop()
# ```
#
# ---
#
# ##### Personalización de etiquetas
#
# Puedes modificar el diseño de una etiqueta con diferentes atributos.
#
# - **Fuente y tamaño**:
#   ```python
#   etiqueta = tk.Label(ventana, text="Texto personalizado", font=("Arial", 16))
#   ```
#
# - **Color de fondo (`bg`) y color de texto (`fg`)**:
#   ```python
#   etiqueta = tk.Label(ventana, text="Fondo azul", bg="blue", fg="white")
#   ```
#
# - **Alineación del texto (`justify`)**:
#   ```python
#   etiqueta = tk.Label(ventana, text="Texto alineado a la izquierda", justify="left")
#   ```
#
# - **Cambio dinámico de texto (`config`)**:
#   ```python
#   etiqueta.config(text="Nuevo texto")
#   ```
#
# ---
#
# ##### Ubicación de etiquetas en la ventana
#
# Tkinter ofrece diferentes métodos para posicionar etiquetas:
#
# 1. **`pack()`**: Ubicación automática en la ventana.
#    ```python
#    etiqueta.pack()
#    ```
#
# 2. **`grid()`**: Organización en filas y columnas.
#    ```python
#    etiqueta.grid(row=0, column=0)
#    ```
#
# 3. **`place()`**: Posicionamiento exacto con coordenadas.
#    ```python
#    etiqueta.place(x=50, y=20)
#    ```
#
# ---
#
# ##### Uso de etiquetas con imágenes
#
# Las etiquetas pueden contener imágenes en lugar de texto.
# ```python
# from tkinter import PhotoImage
#
# imagen = PhotoImage(file="imagen.png")
# etiqueta = tk.Label(ventana, image=imagen)
# etiqueta.pack()
# ```
#
# ---
#
# ##### Conclusión
#
# Las etiquetas en Tkinter permiten mostrar información de manera clara y estructurada en una interfaz gráfica. Su capacidad de personalización y posicionamiento facilita el desarrollo de aplicaciones visuales interactivas. Al combinarlas con otros widgets, se pueden diseñar interfaces más completas y funcionales.
# ¡Explora las opciones y crea interfaces atractivas con Tkinter!

# %% [markdown]
# #### Manejo de Botones con Tkinter
#
# Los **botones (`Button`)** en Tkinter son elementos clave para crear una interfaz interactiva, permitiendo ejecutar acciones cuando el usuario los presiona.
#
# ---
#
# ##### Creación de un botón básico
#
# Para añadir un botón en una ventana Tkinter:
# ```python
# import tkinter as tk
#
# ventana = tk.Tk()
# ventana.title("Ejemplo de Botones")
#
# # Crear botón
# boton = tk.Button(ventana, text="Haz clic aquí")
#
# # Mostrar el botón en la ventana
# boton.pack()
#
# ventana.mainloop()
# ```
#
# ---
#
# ##### Agregar funcionalidad con `command`
#
# Usa `command` para definir una función que se ejecutará cuando el botón sea presionado.
# ```python
# def mostrar_mensaje():
#     print("Botón presionado")
#
# boton = tk.Button(ventana, text="Presionar", command=mostrar_mensaje)
# boton.pack()
# ```
#
# ---
#
# ##### Personalización de botones
#
# Puedes modificar el estilo del botón con diferentes atributos:
#
# - **Color de fondo y color de texto**
#   ```python
#   boton = tk.Button(ventana, text="Presionar", bg="blue", fg="white")
#   ```
#
# - **Fuente y tamaño**
#   ```python
#   boton = tk.Button(ventana, text="Presionar", font=("Arial", 14))
#   ```
#
# - **Deshabilitar el botón**
#   ```python
#   boton = tk.Button(ventana, text="No disponible", state="disabled")
#   ```
#
# - **Modificar tamaño del botón**
#   ```python
#   boton = tk.Button(ventana, text="Grande", width=20, height=3)
#   ```
#
# ---
#
# ##### Cambio dinámico del texto del botón
#
# Puedes cambiar el texto del botón con `config()`:
# ```python
# def cambiar_texto():
#     boton.config(text="Texto cambiado")
#
# boton = tk.Button(ventana, text="Presionar", command=cambiar_texto)
# boton.pack()
# ```
#
# ---
#
# ##### Ubicación de botones en la ventana
#
# Tkinter ofrece distintos métodos para posicionar botones:
#
# 1. **`pack()`**: Ubicación automática en la ventana.
#    ```python
#    boton.pack()
#    ```
#
# 2. **`grid()`**: Organización en filas y columnas.
#    ```python
#    boton.grid(row=1, column=0)
#    ```
#
# 3. **`place()`**: Posicionamiento exacto con coordenadas.
#    ```python
#    boton.place(x=50, y=30)
#    ```
#
# ---
#
# ##### Conclusión
#
# Los **botones** en Tkinter permiten la interacción del usuario dentro de la aplicación. Gracias a su versatilidad, se pueden personalizar, organizar y asociar a funciones que ejecuten diversas acciones. La correcta implementación de estos elementos mejora la experiencia del usuario y hace que la interfaz sea más intuitiva y dinámica.
# ¡Listo para empezar a crear aplicaciones interactivas con Tkinter!

# %% [markdown]
# #### Manejo de Cajas con Tkinter
#
# Las **cajas de entrada (`Entry`)** en Tkinter permiten a los usuarios ingresar texto en una interfaz gráfica. Son ampliamente utilizadas en formularios, búsquedas y otros elementos interactivos.
#
# ---
#
# ##### Creación de una caja de entrada
#
# Para agregar un campo de texto en una ventana de Tkinter:
# ```python
# import tkinter as tk
#
# ventana = tk.Tk()
# ventana.title("Ejemplo de Cajas de Entrada")
#
# # Crear caja de entrada
# entrada = tk.Entry(ventana)
#
# # Mostrar caja en la ventana
# entrada.pack()
#
# ventana.mainloop()
# ```
#
# ---
#
# ##### Recuperar el contenido de una caja de entrada
#
# El método `.get()` permite obtener el texto ingresado por el usuario.
# ```python
# def mostrar_texto():
#     texto = entrada.get()
#     print(f"Texto ingresado: {texto}")
#
# boton = tk.Button(ventana, text="Mostrar", command=mostrar_texto)
# boton.pack()
# ```
#
# ---
#
# ##### Personalización de cajas de entrada
#
# Las cajas de texto pueden personalizarse con diferentes opciones:
#
# - **Ancho del campo**
#   ```python
#   entrada = tk.Entry(ventana, width=30)
#   ```
#
# - **Texto inicial (`insert()`)**
#   ```python
#   entrada.insert(0, "Escribe aquí...")
#   ```
#
# - **Tipo de texto (`show`)**
#   Ocultar caracteres (ejemplo: contraseñas).
#   ```python
#   entrada = tk.Entry(ventana, show="*")
#   ```
#
# - **Deshabilitar la caja (`state`)**
#   ```python
#   entrada = tk.Entry(ventana, state="disabled")
#   ```
#
# ---
#
# ##### Manejo de eventos con cajas de entrada
#
# Puedes detectar cambios en el texto con `bind()`.
# ```python
# def evento_escribir(evento):
#     print("Texto modificado:", entrada.get())
#
# entrada.bind("<KeyRelease>", evento_escribir)
# ```
#
# ---
#
# ##### Ubicación de cajas en la ventana
#
# Las cajas de entrada pueden posicionarse con distintos métodos:
# - **`pack()`**: Ubicación automática.
# - **`grid()`**: Organización en filas y columnas.
#   ```python
#   entrada.grid(row=0, column=0)
#   ```
# - **`place()`**: Posicionamiento con coordenadas.
#   ```python
#   entrada.place(x=50, y=20)
#   ```
#
# ---
#
# ##### Conclusión
#
# Las **cajas de entrada** en Tkinter son esenciales para recibir información del usuario en aplicaciones interactivas. Su personalización y capacidad de gestión de eventos permiten crear interfaces más funcionales y dinámicas. Con un correcto uso, mejoran la experiencia del usuario y la eficiencia del programa.
# ¡Listo para empezar a recibir datos en tu aplicación con Tkinter!

# %% [markdown]
# #### Manejo de Grid con Tkinter
#
# El sistema **`grid()`** en Tkinter permite organizar widgets en una ventana utilizando una cuadrícula de filas y columnas. Es una alternativa más flexible al método `pack()` y facilita la alineación de elementos en la interfaz.
#
# ---
#
# ##### Características de `grid()`
#
# - **Distribución organizada**: Ubica elementos en posiciones específicas dentro de una tabla.
# - **Alineación precisa**: Permite ajustar el tamaño de cada celda y sus márgenes.
# - **Uso de filas y columnas**: Cada widget se coloca en una coordenada determinada.
#
# ---
#
# ##### Uso básico de `grid()`
#
# Ejemplo de cómo colocar widgets en una cuadrícula.
# ```python
# import tkinter as tk
#
# ventana = tk.Tk()
# ventana.title("Ejemplo de Grid")
#
# # Crear etiquetas y campos de entrada
# tk.Label(ventana, text="Nombre:").grid(row=0, column=0)
# entrada_nombre = tk.Entry(ventana)
# entrada_nombre.grid(row=0, column=1)
#
# tk.Label(ventana, text="Edad:").grid(row=1, column=0)
# entrada_edad = tk.Entry(ventana)
# entrada_edad.grid(row=1, column=1)
#
# # Botón de enviar
# boton = tk.Button(ventana, text="Enviar")
# boton.grid(row=2, column=0, columnspan=2)  # Ocupa 2 columnas
#
# ventana.mainloop()
# ```
#
# ---
#
# ##### Parámetros adicionales
#
# - **`row` y `column`**: Especifican la fila y columna donde se coloca un widget.
# - **`padx` y `pady`**: Añaden espacio alrededor del widget.
#   ```python
#   entrada_nombre.grid(row=0, column=1, padx=10, pady=5)
#   ```
# - **`sticky`**: Ajusta la expansión del widget dentro de su celda.
#   ```python
#   etiqueta.grid(row=0, column=0, sticky="w")  # Alineado a la izquierda
#   ```
# - **`columnspan` y `rowspan`**: Permiten que un widget ocupe varias filas o columnas.
#   ```python
#   boton.grid(row=2, column=0, columnspan=2)
#   ```
#
# ---
#
# ##### Ventajas de `grid()` frente a `pack()`
#
# | Característica | `grid()` | `pack()` |
# |---------------|---------|----------|
# | Organización | Basada en filas y columnas | Apilado automático |
# | Posicionamiento | Preciso | Limitado |
# | Expansión | Admite `sticky` | Depende de `fill` |
# | Adaptabilidad | Fácil de estructurar formularios | Útil para listas verticales |
#
# ---
#
# ##### Conclusión
#
# El método **`grid()`** en Tkinter permite diseñar interfaces más estructuradas y organizadas, facilitando la alineación y distribución de elementos. Su combinación con parámetros como `sticky`, `padx`, `pady` y `columnspan` ofrece un control preciso sobre el diseño de la aplicación.
# ¡Perfecto para construir formularios y paneles bien organizados!

# %% [markdown]
# #### Configuración del Grid en Tkinter
#
# El sistema **`grid()`** en Tkinter permite una organización precisa de los widgets mediante filas y columnas. Configurar correctamente el `grid()` mejora la estructura y apariencia de la interfaz gráfica.
#
# ---
#
# ##### Configurar tamaño y expansión
#
# Puedes ajustar el tamaño de las filas y columnas para mejorar la distribución de los elementos.
#
# - **Definir tamaño mínimo de columna y fila**
#   ```python
#   ventana.grid_columnconfigure(0, minsize=100)
#   ventana.grid_rowconfigure(0, minsize=50)
#   ```
#
# - **Expansión automática (`weight`)**
#   Permite que una columna o fila crezca dinámicamente cuando la ventana cambia de tamaño.
#   ```python
#   ventana.grid_columnconfigure(1, weight=1)
#   ventana.grid_rowconfigure(2, weight=2)
#   ```
#
# ---
#
# ##### Alineación de elementos con `sticky`
#
# El parámetro **`sticky`** define la posición dentro de la celda (`N`, `S`, `E`, `W`).
#
# Ejemplo de alineación:
# ```python
# etiqueta.grid(row=0, column=0, sticky="w")  # Alineado a la izquierda
# boton.grid(row=1, column=1, sticky="e")  # Alineado a la derecha
# ```
#
# ---
#
# ##### Espaciado entre widgets (`padx` y `pady`)
#
# Define márgenes internos entre elementos:
# ```python
# entrada.grid(row=2, column=0, padx=10, pady=5)
# ```
#
# ---
#
# ##### Ocupando varias columnas y filas
#
# Para permitir que un widget ocupe más espacio dentro del grid, usa `columnspan` y `rowspan`:
# ```python
# boton.grid(row=3, column=0, columnspan=2)  # Ocupa 2 columnas
# ```
#
# ---
#
# ##### Conclusión
#
# La **configuración del `grid()`** en Tkinter permite ajustar el diseño de la interfaz con mayor precisión y control sobre los espacios entre elementos. Comprender `sticky`, `weight`, `padx`, `pady` y `columnspan` permite crear aplicaciones más organizadas y visualmente atractivas.
#
# ¡En el siguiente capítulo exploraremos más sobre coordenadas en `grid()`! 🚀

# %% [markdown]
# #### Coordenadas del Grid en Tkinter
#
# El sistema **`grid()`** en Tkinter organiza los widgets en una cuadrícula de filas y columnas, permitiendo una distribución precisa en la interfaz.
#
# ---
#
# ##### Definir coordenadas en el Grid
#
# Cada widget colocado con `grid()` debe especificar su posición usando `row` (fila) y `column` (columna).
#
# Ejemplo básico:
# ```python
# import tkinter as tk
#
# ventana = tk.Tk()
# ventana.title("Ejemplo de Coordenadas en Grid")
#
# # Crear etiquetas y ubicarlas en coordenadas específicas
# tk.Label(ventana, text="Fila 0, Columna 0").grid(row=0, column=0)
# tk.Label(ventana, text="Fila 0, Columna 1").grid(row=0, column=1)
# tk.Label(ventana, text="Fila 1, Columna 0").grid(row=1, column=0)
# tk.Label(ventana, text="Fila 1, Columna 1").grid(row=1, column=1)
#
# ventana.mainloop()
# ```
#
# ---
#
# ##### Alinear elementos con `sticky`
#
# El argumento **`sticky`** permite ajustar la ubicación del widget dentro de su celda:
# - `"N"`: Alineado arriba
# - `"S"`: Alineado abajo
# - `"E"`: Alineado a la derecha
# - `"W"`: Alineado a la izquierda
# - `"NSWE"`: Expansión completa dentro de la celda
#
# Ejemplo:
# ```python
# tk.Label(ventana, text="Izquierda").grid(row=0, column=0, sticky="w")
# tk.Label(ventana, text="Derecha").grid(row=0, column=1, sticky="e")
# ```
#
# ---
#
# ##### Uso de múltiples filas y columnas
#
# Para hacer que un widget ocupe varias filas o columnas, usa `columnspan` y `rowspan`.
# ```python
# boton = tk.Button(ventana, text="Botón grande")
# boton.grid(row=2, column=0, columnspan=2)  # Ocupa dos columnas
# ```
#
# ---
#
# ##### Conclusión
#
# Las coordenadas en **`grid()`** permiten estructurar la interfaz de manera organizada y precisa. Utilizando `row`, `column`, `sticky`, `columnspan` y `rowspan`, puedes distribuir los elementos de forma eficiente para crear una interfaz clara y bien diseñada.
#
# ¡En el siguiente capítulo exploraremos más sobre el manejo de márgenes en `grid()`! 🚀

# %% [markdown]
# #### Manejo de Márgenes del Grid en Tkinter
#
# En Tkinter, el sistema **`grid()`** permite organizar los elementos en filas y columnas dentro de una ventana, pero para mejorar la legibilidad y estética de la interfaz, es fundamental manejar correctamente los márgenes y espacios.
#
# ---
#
# ##### Uso de `padx` y `pady`
#
# Los márgenes **horizontales (`padx`)** y **verticales (`pady`)** controlan el espacio alrededor de un widget dentro de su celda.
#
# Ejemplo:
# ```python
# import tkinter as tk
#
# ventana = tk.Tk()
# ventana.title("Márgenes en Grid")
#
# tk.Label(ventana, text="Texto con márgenes").grid(row=0, column=0, padx=20, pady=10)
#
# ventana.mainloop()
# ```
# En este ejemplo, el texto tendrá **20 píxeles de espacio horizontal** y **10 píxeles de espacio vertical**.
#
# ---
#
# ##### Expansión automática con `sticky`
#
# Si quieres que el widget se **extienda** dentro de la celda, usa `sticky` junto con los márgenes:
# ```python
# tk.Label(ventana, text="Expansión completa").grid(row=1, column=0, padx=10, pady=5, sticky="NSWE")
# ```
# Esto hace que la etiqueta ocupe toda la celda mientras mantiene un margen.
#
# ---
#
# ##### Espaciado entre filas y columnas
#
# Puedes definir el tamaño mínimo y la expansión de las filas y columnas usando `grid_columnconfigure()` y `grid_rowconfigure()`:
# ```python
# ventana.grid_columnconfigure(0, minsize=100, weight=1)
# ventana.grid_rowconfigure(0, minsize=50, weight=1)
# ```
# Esto garantiza que la celda tenga un tamaño mínimo de **100x50 píxeles** y se expanda dinámicamente cuando la ventana cambie de tamaño.
#
# ---
#
# ##### Conclusión
#
# El manejo de márgenes en **`grid()`** en Tkinter permite mejorar la distribución de los elementos dentro de la interfaz. Utilizar `padx`, `pady`, `sticky` y la configuración de filas y columnas asegura un diseño más equilibrado y profesional.
#
# ¿Listo para diseñar interfaces más elegantes y organizadas con Tkinter? 🚀

# %% [markdown]
# #### Manejo de Tablas en Tkinter
#
# El manejo de **tablas** en Tkinter se realiza utilizando el widget `Treeview` del módulo `ttk`. Este componente permite organizar y mostrar información en formato tabular, lo que facilita la presentación de datos estructurados dentro de una aplicación gráfica.
#
# ---
#
# ##### Características del `Treeview`
#
# - **Estructura de filas y columnas**, similar a una tabla.
# - **Encabezados personalizables** para cada columna.
# - **Soporte para selección de registros** y eventos asociados.
# - **Posibilidad de agregar barras de desplazamiento** en caso de grandes volúmenes de datos.
# - **Opciones de organización jerárquica**, permitiendo elementos anidados dentro de la tabla.
#
# ---
#
# ##### Creación de una tabla con `Treeview`
#
# Para implementar una tabla en una interfaz Tkinter, se debe instanciar un objeto `Treeview`, definir sus columnas y establecer los encabezados.
#
# ```python
# import tkinter as tk
# from tkinter import ttk
#
# # Crear la ventana principal
# ventana = tk.Tk()
# ventana.title("Tabla en Tkinter")
#
# # Crear el Treeview
# tabla = ttk.Treeview(ventana, columns=("ID", "Nombre", "Edad"), show="headings")
#
# # Definir encabezados de columna
# tabla.heading("ID", text="ID")
# tabla.heading("Nombre", text="Nombre")
# tabla.heading("Edad", text="Edad")
#
# # Insertar datos en la tabla
# datos = [(1, "Ana", 25), (2, "Luis", 40), (3, "María", 35)]
# for fila in datos:
#     tabla.insert("", tk.END, values=fila)
#
# # Mostrar tabla en la ventana
# tabla.pack()
#
# ventana.mainloop()
# ```
#
# ---
#
# ##### Personalización de la tabla
#
# Para mejorar la apariencia y funcionalidad del `Treeview`, puedes configurar diferentes opciones:
#
# - **Definir el ancho de las columnas:**
#   ```python
#   tabla.column("ID", width=50)
#   tabla.column("Nombre", width=150)
#   tabla.column("Edad", width=100)
#   ```
#
# - **Agregar una barra de desplazamiento vertical:**
#   ```python
#   scrollbar = ttk.Scrollbar(ventana, orient="vertical", command=tabla.yview)
#   tabla.configure(yscroll=scrollbar.set)
#   scrollbar.pack(side="right", fill="y")
#   ```
#
# - **Modificar el estilo visual:**
#   ```python
#   style = ttk.Style()
#   style.configure("Treeview", font=("Arial", 12), background="lightgray", foreground="black")
#   ```
#
# ---
#
# ##### Interacción con la tabla
#
# El `Treeview` permite que el usuario seleccione filas y ejecute acciones sobre ellas.
#
# - **Mostrar la selección actual:**
#   ```python
#   def mostrar_seleccion():
#       seleccion = tabla.selection()
#       for item in seleccion:
#           valores = tabla.item(item, "values")
#           print(f"Seleccionado: {valores}")
#
#   boton_seleccionar = tk.Button(ventana, text="Mostrar selección", command=mostrar_seleccion)
#   boton_seleccionar.pack()
#   ```
#
# - **Eliminar un registro:**
#   ```python
#   def eliminar_seleccion():
#       seleccion = tabla.selection()
#       for item in seleccion:
#           tabla.delete(item)
#
#   boton_eliminar = tk.Button(ventana, text="Eliminar fila", command=eliminar_seleccion)
#   boton_eliminar.pack()
#   ```
#
# - **Modificar un registro:**
#   ```python
#   def modificar_seleccion():
#       seleccion = tabla.selection()
#       if seleccion:
#           tabla.item(seleccion[0], values=("Nuevo ID", "Nuevo Nombre", 99))
#
#   boton_modificar = tk.Button(ventana, text="Modificar fila", command=modificar_seleccion)
#   boton_modificar.pack()
#   ```
#
# ---
#
# ##### Carga de datos dinámicos
#
# Si la tabla debe manejar información proveniente de una base de datos, los datos pueden cargarse dinámicamente.
#
# ```python
# import mysql.connector
#
# conexion = mysql.connector.connect(
#     host="localhost",
#     user="tu_usuario",
#     password="tu_contraseña",
#     database="mi_base"
# )
#
# cursor = conexion.cursor()
# cursor.execute("SELECT id, nombre, edad FROM usuarios")
# datos = cursor.fetchall()
#
# for fila in datos:
#     tabla.insert("", tk.END, values=fila)
#
# cursor.close()
# conexion.close()
# ```
#
# ---
#
# ##### Comparación `Treeview` vs `Grid`
#
# | Característica | `Treeview` | `Grid` (usando Label y Entry) |
# |---------------|-----------|--------------------|
# | Organización | Basada en filas y columnas | Cuadrícula de filas y columnas |
# | Expansión | Admite Scroll y múltiples columnas | Menos flexible |
# | Interactividad | Permite selección y modificación | Requiere trabajo adicional |
# | Uso | Ideal para bases de datos | Útil para formularios |
#
# ---
#
# ##### Conclusión
#
# El widget **Treeview** en Tkinter es una alternativa eficaz para presentar datos en formato tabular dentro de una GUI. Su capacidad de personalización, junto con funciones de selección, modificación y eliminación de datos, permite construir interfaces interactivas y escalables.
#
# Este enfoque es ideal para aplicaciones que necesitan mostrar información estructurada, ya sea desde archivos, listas o bases de datos. ¡Explora todas las posibilidades y mejora la presentación de datos en tus proyectos con Tkinter!

# %% [markdown]
# #### Programación Orientada a Objetos (POO) y Tkinter
#
# La **Programación Orientada a Objetos (POO)** es un paradigma de desarrollo que organiza el código en torno a **clases** y **objetos**, permitiendo una estructura modular, reutilizable y más fácil de mantener. En el contexto de **Tkinter**, la POO facilita la construcción de interfaces gráficas organizadas, encapsulando la lógica de la aplicación en clases que manejan los diferentes elementos visuales.
#
# ---
#
# ##### Características de la POO
#
# - **Encapsulamiento:** Los atributos y métodos están agrupados dentro de una clase, protegiendo la manipulación directa de datos.
# - **Herencia:** Posibilidad de que una clase hija herede atributos y métodos de una clase padre.
# - **Polimorfismo:** Capacidad de usar un mismo método en múltiples clases con distintas implementaciones.
# - **Modularidad:** Organización del código en clases independientes, facilitando su mantenimiento y reutilización.
#
# ---
#
# ##### Implementación de POO en Tkinter
#
# La POO en Tkinter permite estructurar la interfaz en clases que gestionan sus propios elementos gráficos y eventos.
#
# Ejemplo básico de una aplicación Tkinter usando clases:
#
# ```python
# import tkinter as tk
#
# class Aplicacion:
#     def __init__(self, ventana):
#         self.ventana = ventana
#         self.ventana.title("Ejemplo POO en Tkinter")
#
#         self.etiqueta = tk.Label(ventana, text="¡Bienvenido!", font=("Arial", 14))
#         self.etiqueta.pack()
#
#         self.boton = tk.Button(ventana, text="Cerrar", command=self.ventana.quit)
#         self.boton.pack()
#
# # Crear la ventana y ejecutar la aplicación
# ventana = tk.Tk()
# app = Aplicacion(ventana)
# ventana.mainloop()
# ```
#
# ---
#
# ##### Ventajas de usar POO en Tkinter
#
# - **Código más estructurado:** Se pueden organizar elementos de la GUI en clases individuales.
# - **Facilidad de mantenimiento:** Las modificaciones se aplican en una única clase sin afectar el resto del código.
# - **Reutilización de código:** Se pueden crear nuevas interfaces reutilizando clases previamente definidas.
# - **Interfaz más escalable:** Permite agregar funcionalidades sin alterar la estructura existente.
#
# ---
#
# ##### Creación de una interfaz modular con POO
#
# Se pueden crear clases separadas para los diferentes componentes de la aplicación, lo que facilita la reutilización y mejora la organización.
#
# ```python
# class VentanaPrincipal:
#     def __init__(self, ventana):
#         self.ventana = ventana
#         self.ventana.title("Interfaz Modular")
#
#         self.crear_widgets()
#
#     def crear_widgets(self):
#         etiqueta = tk.Label(self.ventana, text="Interfaz con POO", font=("Arial", 12))
#         etiqueta.pack()
#
#         boton = tk.Button(self.ventana, text="Salir", command=self.ventana.quit)
#         boton.pack()
#
# ventana = tk.Tk()
# app = VentanaPrincipal(ventana)
# ventana.mainloop()
# ```
#
# ---
#
# ##### Herencia en Tkinter
#
# La herencia permite extender una clase sin necesidad de redefinir toda su funcionalidad.
#
# ```python
# class VentanaBase(tk.Tk):
#     def __init__(self):
#         super().__init__()
#         self.title("Ventana Base")
#         self.geometry("300x200")
#
# class VentanaSecundaria(VentanaBase):
#     def __init__(self):
#         super().__init__()
#         etiqueta = tk.Label(self, text="Esta es una ventana secundaria", font=("Arial", 12))
#         etiqueta.pack()
#
# ventana = VentanaSecundaria()
# ventana.mainloop()
# ```
#
# ---
#
# ##### Conclusión
#
# La **Programación Orientada a Objetos** en Tkinter permite desarrollar aplicaciones más organizadas, reutilizables y escalables. Gracias a la estructura basada en clases, se facilita el mantenimiento del código y la expansión de funcionalidades sin comprometer la arquitectura de la aplicación.
#
# Esta metodología es fundamental para construir interfaces gráficas eficientes y estructuradas, mejorando la modularidad y la reutilización de código dentro de proyectos de desarrollo.

# %% [markdown]
# #### Ventanas y POO con Tkinter
#
# La **Programación Orientada a Objetos (POO)** en **Tkinter** permite estructurar interfaces gráficas dentro de clases organizadas, facilitando la reutilización del código, el mantenimiento y la escalabilidad de la aplicación.
#
# ---
#
# ##### Características de POO en Tkinter
#
# - **Encapsulamiento:** Cada ventana se define dentro de una clase, agrupando sus atributos y métodos.
# - **Herencia:** Permite extender funcionalidades en clases derivadas sin modificar la base.
# - **Modularidad:** La interfaz se divide en múltiples clases, mejorando su organización.
# - **Reutilización:** Se pueden crear componentes reutilizables dentro de una aplicación.
#
# ---
#
# ##### Creación de una ventana con POO
#
# Para manejar ventanas en Tkinter usando POO, se define una clase que contenga los elementos de la GUI.
#
# ```python
# import tkinter as tk
#
# class Ventana:
#     def __init__(self, root):
#         self.root = root
#         self.root.title("Ventana con POO")
#
#         etiqueta = tk.Label(root, text="Interfaz con POO", font=("Arial", 14))
#         etiqueta.pack()
#
#         boton = tk.Button(root, text="Cerrar", command=root.quit)
#         boton.pack()
#
# # Crear la ventana principal
# root = tk.Tk()
# app = Ventana(root)
# root.mainloop()
# ```
#
# ---
#
# ##### Ventanas secundarias con POO
#
# Se pueden crear **ventanas secundarias** dentro de una aplicación, manejándolas desde una clase dedicada.
#
# ```python
# class VentanaSecundaria:
#     def __init__(self):
#         self.ventana = tk.Toplevel()
#         self.ventana.title("Ventana secundaria")
#
#         etiqueta = tk.Label(self.ventana, text="Esta es una ventana secundaria")
#         etiqueta.pack()
#
#         boton_cerrar = tk.Button(self.ventana, text="Cerrar", command=self.ventana.destroy)
#         boton_cerrar.pack()
#
# # Uso de la ventana secundaria
# def abrir_ventana():
#     VentanaSecundaria()
#
# root = tk.Tk()
# root.title("Ventana Principal")
#
# boton = tk.Button(root, text="Abrir ventana secundaria", command=abrir_ventana)
# boton.pack()
#
# root.mainloop()
# ```
#
# ---
#
# ##### Herencia en Ventanas Tkinter
#
# Es posible crear una **ventana base** y extender su funcionalidad mediante **herencia**, evitando la repetición de código.
#
# ```python
# class VentanaBase(tk.Tk):
#     def __init__(self):
#         super().__init__()
#         self.title("Ventana Base")
#         self.geometry("300x200")
#
# class VentanaPersonalizada(VentanaBase):
#     def __init__(self):
#         super().__init__()
#         etiqueta = tk.Label(self, text="Ventana creada con herencia", font=("Arial", 12))
#         etiqueta.pack()
#
# ventana = VentanaPersonalizada()
# ventana.mainloop()
# ```
#
# ---
#
# ##### Gestión de múltiples ventanas en una aplicación
#
# Para una aplicación con varias ventanas, se puede utilizar un **controlador** que maneje la transición entre ellas.
#
# ```python
# class Aplicacion:
#     def __init__(self, root):
#         self.root = root
#         self.root.title("Gestión de ventanas")
#
#         boton = tk.Button(root, text="Abrir nueva ventana", command=self.abrir_ventana)
#         boton.pack()
#
#     def abrir_ventana(self):
#         nueva_ventana = tk.Toplevel(self.root)
#         nueva_ventana.title("Otra ventana")
#         tk.Label(nueva_ventana, text="Ventana secundaria").pack()
#
# root = tk.Tk()
# app = Aplicacion(root)
# root.mainloop()
# ```
#
# ---
#
# ##### Conclusión
#
# El uso de **POO en Tkinter** permite organizar ventanas dentro de clases reutilizables y escalables. Esto facilita el mantenimiento del código y la gestión de múltiples interfaces dentro de una misma aplicación. La herencia, el encapsulamiento y la modularidad ayudan a construir interfaces eficientes y bien estructuradas, mejorando la experiencia de desarrollo.
# Esta técnica es fundamental para proyectos que requieren una gestión flexible y ordenada de las ventanas en Tkinter.

# %% [markdown]
# ### Sección 13 - Aplicaciones Web con Flask, HTML, CSS y Bootstrap

# %% [markdown]
# #### Introducción a HTML
#
# **HTML (HyperText Markup Language)** es el lenguaje de marcado estándar utilizado para la creación de páginas web. Su función principal es estructurar el contenido de una página mediante etiquetas que organizan textos, imágenes, enlaces y otros elementos multimedia.
#
# ---
#
# ##### Características principales de HTML
#
# - **Estructura jerárquica:** Utiliza etiquetas anidadas para definir la organización del contenido.
# - **Interpretado por navegadores:** Los navegadores web leen y procesan el código HTML para mostrarlo de manera visual.
# - **Lenguaje de marcado:** No es un lenguaje de programación, sino un sistema basado en etiquetas que describe el contenido.
# - **Independiente de plataforma:** Funciona en cualquier sistema operativo y navegador moderno.
# - **Compatible con tecnologías web:** Se integra con **CSS** (para estilos) y **JavaScript** (para interacción).
#
# ---
#
# ##### Estructura básica de un documento HTML
#
# Un archivo HTML tiene una estructura estándar que contiene las secciones esenciales de una página web:
#
# ```html
# <!DOCTYPE html>
# <html lang="es">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Mi Página Web</title>
# </head>
# <body>
#     <h1>Bienvenido a mi página web</h1>
#     <p>Este es un ejemplo de una estructura básica en HTML.</p>
# </body>
# </html>
# ```
#
# **Explicación del código:**
# - **`<!DOCTYPE html>`**: Define el tipo de documento como HTML5.
# - **`<html>`**: Contenedor principal de la página.
# - **`<head>`**: Sección que contiene la configuración, enlaces a estilos y metadatos.
# - **`<meta charset="UTF-8">`**: Define la codificación de caracteres.
# - **`<meta name="viewport">`**: Garantiza la correcta visualización en dispositivos móviles.
# - **`<title>`**: Define el título de la página.
# - **`<body>`**: Contiene el contenido visible de la página.
#
# ---
#
# ##### Principales etiquetas en HTML
#
# 1. **Etiquetas de encabezado**: Definen títulos y subtítulos de la página.
# ```html
#    <h1>Título principal</h1>
#    <h2>Subtítulo</h2>
#    <h3>Encabezado más pequeño</h3>
# ```
#
# 2. **Etiquetas de párrafo y texto**: Utilizadas para organizar contenido textual.
#    ```html
#    <p>Este es un párrafo.</p>
#    <b>Negrita</b> <i>Cursiva</i> <u>Subrayado</u>
#    ```
#
# 3. **Listas ordenadas y desordenadas**: Organizan elementos en listas.
#    ```html
#    <ul>
#        <li>Elemento 1</li>
#        <li>Elemento 2</li>
#    </ul>
#
#    <ol>
#        <li>Primer elemento</li>
#        <li>Segundo elemento</li>
#    </ol>
#    ```
#
# 4. **Enlaces y navegación**: Permiten crear hipervínculos.
#    ```html
#    <a href="https://www.example.com">Visitar sitio web</a>
#    ```
#
# 5. **Imágenes**: Se usan para mostrar gráficos en la página.
#    ```html
#    <img src="imagen.jpg" alt="Descripción de la imagen">
#    ```
#
# ---
#
# ##### Formularios en HTML
#
# Los formularios permiten la captura de datos por parte del usuario, como registros e inicios de sesión.
#
# ```html
# <form action="/procesar" method="POST">
#     <label for="nombre">Nombre:</label>
#     <input type="text" id="nombre" name="nombre">
#
#     <label for="email">Correo:</label>
#     <input type="email" id="email" name="email">
#
#     <input type="submit" value="Enviar">
# </form>
# ```
#
# **Componentes del formulario:**
# - **`<form>`**: Contenedor del formulario.
# - **`<input>`**: Campo de entrada de datos (texto, email, botón, etc.).
# - **`<label>`**: Etiqueta asociada a un campo de entrada.
# - **`action` y `method`**: Definen el destino y tipo de envío de los datos.
#
# ---
#
# ##### Tablas en HTML
#
# Las tablas son útiles para estructurar datos en filas y columnas.
#
# ```html
# <table border="1">
#     <tr>
#         <th>Nombre</th>
#         <th>Edad</th>
#     </tr>
#     <tr>
#         <td>Ana</td>
#         <td>25</td>
#     </tr>
#     <tr>
#         <td>Luis</td>
#         <td>40</td>
#     </tr>
# </table>
# ```
#
# **Componentes de la tabla:**
# - **`<table>`**: Contenedor de la tabla.
# - **`<tr>`**: Fila de la tabla.
# - **`<th>`**: Encabezado de columna.
# - **`<td>`**: Celda de datos.
#
# ---
#
# ##### Conclusión
#
# **HTML** es la base de la creación de páginas web. Su estructura basada en etiquetas permite definir el contenido y organizarlo de manera eficiente. A través de formularios, tablas y elementos multimedia, se pueden desarrollar interfaces web funcionales.
#
# En las próximas secciones, exploraremos cómo **CSS** mejora el diseño visual y **Bootstrap** agiliza la maquetación de páginas.
# Continuamos con la evolución del desarrollo web.

# %% [markdown]
# #### Hola Mundo con HTML
#
# El **Hola Mundo** es el primer programa que se suele escribir al aprender un nuevo lenguaje de programación. En **HTML**, este consiste en una estructura básica de documento que muestra un mensaje en la página web.
#
# ---
#
# ##### Estructura básica de HTML
#
# Un documento HTML debe contener los elementos esenciales para que el navegador lo interprete correctamente.
#
# ```html
# <!DOCTYPE html>
# <html lang="es">
# <head>
#     <meta charset="UTF-8">
#     <title>Hola Mundo</title>
# </head>
# <body>
#     <h1>¡Hola Mundo!</h1>
#     <p>Esta es mi primera página web con HTML.</p>
# </body>
# </html>
# ```
#
# ---
#
# ##### Explicación del código
#
# - **`<!DOCTYPE html>`**: Define el documento como **HTML5**.
# - **`<html lang="es">`**: Indica que el contenido está en español.
# - **`<head>`**: Contiene meta-información y el título de la página.
# - **`<meta charset="UTF-8">`**: Asegura que el texto se muestre correctamente en cualquier idioma.
# - **`<title>`**: Define el título de la ventana del navegador.
# - **`<body>`**: Contiene el contenido visible de la página web.
# - **`<h1>`**: Muestra un encabezado principal con el texto **"¡Hola Mundo!"**.
# - **`<p>`**: Define un párrafo con un mensaje de bienvenida.
#
# ---
#
# ##### Visualización del código
#
# Para ver la página en el navegador:
# 1. Guarda el código con el nombre **hola_mundo.html**.
# 2. Abre el archivo en cualquier navegador web.
#
# ---
#
# ##### Variaciones de "Hola Mundo" en HTML
#
# Se pueden incluir más elementos para mejorar la presentación.
#
# **Ejemplo con colores y estilos:**
# ```html
# <!DOCTYPE html>
# <html lang="es">
# <head>
#     <meta charset="UTF-8">
#     <title>Hola Mundo Estilizado</title>
#     <style>
#         body { background-color: lightblue; text-align: center; }
#         h1 { color: darkblue; }
#         p { font-size: 18px; }
#     </style>
# </head>
# <body>
#     <h1>¡Hola Mundo!</h1>
#     <p>Bienvenido a mi primera página con diseño básico en HTML.</p>
# </body>
# </html>
# ```
#
# ---
#
# ##### Conclusión
#
# El **Hola Mundo en HTML** es el primer paso para aprender a estructurar páginas web. Con una sintaxis sencilla, se pueden crear documentos que luego pueden mejorarse con **CSS** para diseño y **JavaScript** para interacción.
#
# Este ejercicio es fundamental para entender los principios básicos de la web.
# A partir de aquí, se puede explorar más sobre la creación de sitios dinámicos y atractivos.

# %% [markdown]
# #### Links en HTML
#
# Los **links** en HTML permiten crear hipervínculos que conectan diferentes páginas web, archivos, correos electrónicos o secciones dentro de un mismo documento. Estos enlaces se implementan mediante la etiqueta `<a>`.
#
# ---
#
# ##### Creación de enlaces básicos
#
# Para agregar un enlace, se usa la etiqueta `<a>` con el atributo `href`, que define la dirección de destino.
#
# ```html
# <a href="https://www.ejemplo.com">Visitar Ejemplo</a>
# ```
# Este código muestra un enlace que redirige a **www.ejemplo.com** cuando se hace clic.
#
# ---
#
# ##### Enlaces internos
#
# Los enlaces internos conectan diferentes secciones dentro del mismo sitio web.
#
# ```html
# <a href="pagina2.html">Ir a Página 2</a>
# ```
# Este enlace abre **pagina2.html** dentro del mismo dominio.
#
# ---
#
# ##### Enlaces dentro de la misma página
#
# Los enlaces pueden dirigir a un punto específico dentro de la misma página usando **anclas**.
#
# ```html
# <a href="#seccion">Ir a la sección</a>
#
# <h2 id="seccion">Sección Importante</h2>
# ```
# El `id="seccion"` marca la ubicación y el enlace llevará al usuario directamente a esa sección.
#
# ---
#
# ##### Enlaces para descargar archivos
#
# Se pueden crear enlaces que permitan la descarga de archivos al usuario.
#
# ```html
# <a href="documento.pdf" download>Descargar PDF</a>
# ```
# El atributo `download` indica que el archivo **documento.pdf** se descargará en lugar de abrirse en el navegador.
#
# ---
#
# ##### Enlaces para enviar correos electrónicos
#
# Es posible crear enlaces que abran el cliente de correo con un destinatario predefinido.
#
# ```html
# <a href="mailto:correo@ejemplo.com">Enviar correo</a>
# ```
# Este enlace abrirá el servicio de correo del usuario con la dirección **correo@ejemplo.com**.
#
# ---
#
# ##### Control de enlaces con atributos adicionales
#
# - **Abrir en una nueva pestaña (`target="_blank"`)**
#   ```html
#   <a href="https://www.ejemplo.com" target="_blank">Abrir en nueva pestaña</a>
#   ```
# - **Relación del enlace (`rel="nofollow"`)**
#   ```html
#   <a href="https://www.ejemplo.com" rel="nofollow">No seguir enlace</a>
#   ```
# - **Enlace estilizado con CSS (`class="enlace-destacado"`)**
#   ```html
#   <a href="https://www.ejemplo.com" class="enlace-destacado">Estilo personalizado</a>
#   ```
#
# ---
#
# ##### Conclusión
#
# Los **enlaces en HTML** son fundamentales para la navegación web, permitiendo la conexión entre páginas, descargas y correos electrónicos. A través de atributos como `href`, `target`, `rel` y `download`, se pueden personalizar los enlaces según su función en la página.
#
# El uso adecuado de links mejora la accesibilidad y la experiencia de usuario en cualquier sitio web.
# Es un componente esencial en el desarrollo de páginas interactivas y bien estructuradas.

# %% [markdown]
# #### Introducción a CSS
#
# **CSS (Cascading Style Sheets)** es un lenguaje utilizado para definir el diseño y la presentación de páginas web. Permite aplicar estilos a los elementos HTML, controlando aspectos como colores, fuentes, márgenes y posiciones.
#
# ---
#
# ##### Características de CSS
#
# - **Separación de contenido y diseño:** Facilita la gestión y actualización de los estilos sin modificar el código HTML.
# - **Herencia y cascada:** Los estilos se aplican siguiendo una jerarquía en la que los elementos pueden heredar propiedades de sus contenedores.
# - **Selectores eficientes:** Permiten definir reglas de estilo para distintos elementos mediante clases, identificadores y atributos.
# - **Compatibilidad con dispositivos:** Posibilita el diseño adaptable mediante **media queries** para mejorar la experiencia en distintos tamaños de pantalla.
#
# ---
#
# ##### Sintaxis básica de CSS
#
# Un archivo CSS define reglas de estilo que se aplican a los elementos HTML.
# ```css
# body {
#     background-color: lightblue;
#     font-family: Arial, sans-serif;
# }
#
# h1 {
#     color: darkblue;
#     font-size: 24px;
# }
# ```
# Las reglas contienen:
# - **Selector:** Define los elementos a los que se aplicará el estilo (`body`, `h1`).
# - **Propiedades:** Especifican el aspecto visual (`background-color`, `font-size`).
# - **Valores:** Determinan el estilo exacto (`lightblue`, `24px`).
#
# ---
#
# ##### Formas de aplicar CSS
#
# 1. **CSS en línea:** Se define directamente en los elementos HTML con el atributo `style`.
#    ```html
#    <p style="color: red; font-size: 16px;">Texto con estilo</p>
#    ```
#
# 2. **CSS interno:** Se coloca dentro de la etiqueta `<style>` en el documento HTML.
#    ```html
#    <style>
#        p { color: green; }
#    </style>
#    ```
#
# 3. **CSS externo:** Se define en un archivo separado (`styles.css`) y se vincula con `<link>`.
#    ```html
#    <link rel="stylesheet" href="styles.css">
#    ```
#
# ---
#
# ##### Selectores en CSS
#
# CSS permite seleccionar elementos con diferentes métodos:
#
# - **Por etiqueta:**
#   ```css
#   h1 { color: blue; }
#   ```
#
# - **Por clase:**
#   ```css
#   .texto-grande { font-size: 20px; }
#   ```
#
# - **Por ID:**
#   ```css
#   #titulo { font-weight: bold; }
#   ```
#
# - **Selectores combinados:**
#   ```css
#   div p { color: gray; }
#   ```
#
# ---
#
# ##### Diseño adaptable con CSS
#
# **Media queries** permiten modificar el diseño en función del tamaño de la pantalla.
# ```css
# @media (max-width: 600px) {
#     body { background-color: lightgray; }
# }
# ```
# Esto cambia el fondo a **gris** si el ancho de la pantalla es menor a **600px**.
#
# ---
#
# ##### Conclusión
#
# CSS es una herramienta fundamental para mejorar la presentación de páginas web, permitiendo personalizar colores, fuentes y estructuras de manera eficiente. Su combinación con HTML y **media queries** facilita el diseño adaptable, garantizando una visualización óptima en distintos dispositivos.
#
# En las próximas secciones, profundizaremos en el uso de **Bootstrap** para optimizar el diseño y mejorar la estética de los sitios web.
# CSS es clave para crear páginas modernas y atractivas.

# %% [markdown]
# #### Estilos Internos en CSS
#
# Los **estilos internos** en **CSS** permiten definir reglas de diseño directamente dentro de un documento HTML, sin necesidad de un archivo externo. Se colocan dentro de la etiqueta `<style>` en la sección `<head>` de la página.
#
# ---
#
# ##### Características de los estilos internos
#
# - **Aplicación específica:** Los estilos solo afectan el documento actual, sin modificar otros archivos.
# - **Integración directa en HTML:** Se escriben dentro de la estructura del documento, facilitando la prueba de estilos.
# - **Mayor prioridad:** Sobrescriben los estilos externos cuando hay conflictos.
# - **Útil para páginas individuales:** Ideal para documentos con pocos estilos, evitando crear un archivo CSS externo.
#
# ---
#
# ##### Implementación de estilos internos
#
# Ejemplo de uso de **estilos internos** dentro de una página HTML:
# ```html
# <!DOCTYPE html>
# <html lang="es">
# <head>
#     <meta charset="UTF-8">
#     <title>Estilos Internos en CSS</title>
#     <style>
#         body {
#             background-color: lightgray;
#             font-family: Arial, sans-serif;
#         }
#         h1 {
#             color: darkblue;
#             text-align: center;
#         }
#         p {
#             font-size: 18px;
#             color: darkred;
#         }
#     </style>
# </head>
# <body>
#     <h1>Ejemplo de Estilos Internos</h1>
#     <p>Este párrafo usa estilos internos definidos en la etiqueta `<style>`.</p>
# </body>
# </html>
# ```
#
# ---
#
# ##### Explicación del código
#
# - **Ubicación:** Los estilos se colocan dentro de `<style>` en la sección `<head>`.
# - **Selector `body`:** Modifica el fondo y la fuente del documento.
# - **Selector `h1`:** Establece el color y alineación del título.
# - **Selector `p`:** Ajusta el tamaño y color del texto en los párrafos.
#
# ---
#
# ##### Ventajas y desventajas de los estilos internos
#
# **Ventajas:**
# - No requiere un archivo CSS externo.
# - Fácil de usar para pruebas rápidas.
# - Tiene mayor prioridad sobre los estilos externos.
#
# **Desventajas:**
# - Dificulta la reutilización de estilos en múltiples páginas.
# - Puede hacer que el código HTML sea menos organizado.
# - No es óptimo para proyectos grandes.
#
# ---
#
# ##### Comparación con otros métodos de CSS
#
# | Tipo de Estilos | Aplicación | Reutilización | Rendimiento |
# |----------------|------------|---------------|-------------|
# | Internos (`<style>`) | Solo en el documento | No reutilizable | Medio |
# | Externos (`.css`) | Se enlaza a múltiples páginas | Reutilizable | Óptimo |
# | En línea (`style=""`) | Solo en un elemento | No reutilizable | Bajo |
#
# ---
#
# ##### Conclusión
#
# Los **estilos internos en CSS** son útiles para definir reglas de diseño en una única página sin necesidad de archivos adicionales. Sin embargo, para proyectos más grandes, es recomendable utilizar **CSS externo** para mejorar la organización y la reutilización de estilos.
#
# En los siguientes apartados, exploraremos los **estilos externos** y otras técnicas avanzadas de CSS.
# CSS es clave para crear páginas web bien estructuradas y visualmente atractivas.

# %% [markdown]
# #### Estilos Externos en CSS
#
# Los **estilos externos** en **CSS** permiten definir reglas de diseño en un archivo separado (`.css`), facilitando la reutilización y mantenimiento del código. Este enfoque es ideal para proyectos grandes, ya que mantiene la estructura HTML limpia y organizada.
#
# ---
#
# ##### Características de los estilos externos
#
# - **Separación de contenido y presentación:** Mejora la organización del código al mantener el diseño en archivos distintos.
# - **Reutilización en múltiples páginas:** Un solo archivo CSS puede aplicarse a varias páginas web.
# - **Carga más eficiente:** Los navegadores almacenan el archivo CSS en caché, reduciendo el tiempo de carga.
# - **Mayor facilidad de mantenimiento:** Se pueden modificar los estilos sin tocar el código HTML.
#
# ---
#
# ##### Implementación de estilos externos
#
# Para aplicar **CSS externo**, se crea un archivo separado (`styles.css`) y se vincula con el documento HTML mediante la etiqueta `<link>`.
#
# **Archivo `styles.css`:**
# ```css
# body {
#     background-color: lightgray;
#     font-family: Arial, sans-serif;
# }
#
# h1 {
#     color: darkblue;
#     text-align: center;
# }
#
# p {
#     font-size: 18px;
#     color: darkred;
# }
# ```
#
# **Archivo `index.html`:**
# ```html
# <!DOCTYPE html>
# <html lang="es">
# <head>
#     <meta charset="UTF-8">
#     <title>Estilos Externos en CSS</title>
#     <link rel="stylesheet" href="styles.css">
# </head>
# <body>
#     <h1>Ejemplo de Estilos Externos</h1>
#     <p>Este párrafo usa estilos definidos en un archivo externo.</p>
# </body>
# </html>
# ```
#
# ---
#
# ##### Explicación del código
#
# - **Ubicación del archivo CSS:** Se coloca en la misma carpeta del archivo HTML o en un directorio separado (`css/` por ejemplo).
# - **Vinculación con `<link>`:** El atributo `rel="stylesheet"` indica que es una hoja de estilos y `href="styles.css"` define su ubicación.
# - **Definición centralizada de estilos:** Todos los estilos se manejan desde un único archivo, evitando código repetitivo dentro del HTML.
#
# ---
#
# ##### Ventajas y desventajas de los estilos externos
#
# **Ventajas:**
# - Facilita la gestión de diseño en proyectos grandes.
# - Permite modificar la apariencia sin tocar el HTML.
# - Optimiza la velocidad de carga mediante el uso de caché.
#
# **Desventajas:**
# - La página necesita cargar el archivo CSS adicional.
# - Sin conexión a internet, los estilos pueden no aplicarse en algunos casos.
#
# ---
#
# ##### Comparación con otros métodos de CSS
#
# | Tipo de Estilos | Aplicación | Reutilización | Organización |
# |----------------|------------|---------------|-------------|
# | Externos (`.css`) | En varias páginas | Alto | Excelente |
# | Internos (`<style>`) | Solo en el documento | Bajo | Medio |
# | En línea (`style=""`) | Solo en un elemento | Nulo | Bajo |
#
# ---
#
# ##### Conclusión
#
# Los **estilos externos en CSS** son la mejor opción para gestionar el diseño de sitios web de manera estructurada y eficiente. Separar el código HTML del CSS mejora la mantenibilidad y la reutilización, optimizando la presentación de múltiples páginas dentro de un proyecto.
#
# En los siguientes apartados, exploraremos cómo mejorar el diseño con **Bootstrap**, una herramienta que facilita la creación de interfaces modernas y responsivas.
# CSS externo es clave para desarrollar sitios bien estructurados y escalables.

# %% [markdown]
# #### Clases y Selectores en CSS
#
# Los **selectores en CSS** permiten aplicar estilos a elementos específicos de una página web. Dentro de estos selectores, las **clases** permiten definir reglas reutilizables que pueden aplicarse a múltiples elementos HTML sin necesidad de duplicar código.
#
# ---
#
# ##### Tipos de selectores en CSS
#
# CSS ofrece distintos tipos de selectores para aplicar estilos de manera precisa:
#
# - **Selector por etiqueta:** Aplica estilos a todos los elementos de un mismo tipo.
#
#   ```css
#   h1 {
#       color: blue;
#   }
#   ```
#
#   Este estilo afectará a todos los títulos `<h1>` de la página.
#
# - **Selector por clase:** Se define con un punto (`.`) y se puede aplicar a múltiples elementos.
#
#   ```css
#   .destacado {
#       color: red;
#       font-weight: bold;
#   }
#   ```
#
#   ```html
#   <p class="destacado">Texto con clase CSS</p>
#   <span class="destacado">Otro elemento con clase</span>
#   ```
#
#   Ambos elementos tendrán el mismo estilo sin importar su tipo.
#
# - **Selector por ID:** Se define con un `#` y solo se aplica a un elemento único.
#
#   ```css
#   #titulo {
#       font-size: 24px;
#       text-align: center;
#   }
#   ```
#
# ```html
#   <h1 id="titulo">Encabezado único</h1>
# ```
#
# - **Selector combinado:** Permite aplicar estilos solo a elementos dentro de otros.
#
#   ```css
#   div p {
#       color: gray;
#   }
#   ```
#
#   ```html
#   <div>
#       <p>Este párrafo dentro de div será gris.</p>
#   </div>
#   ```
#
# ---
#
# ##### Uso de múltiples clases
#
# Un elemento HTML puede tener más de una clase, combinando diferentes estilos.
#
# ```html
# <p class="destacado resaltado">Texto con múltiples clases</p>
# ```
#
# ```css
# .destacado {
#     font-weight: bold;
# }
#
# .resaltado {
#     background-color: yellow;
# }
# ```
#
# Este texto será **negrita** y tendrá un **fondo amarillo**.
#
# ---
#
# ##### Selectores avanzados
#
# 1. **Selector universal (`*`)**: Aplica estilos a todos los elementos.
#
#    ```css
#    * {
#        margin: 0;
#        padding: 0;
#    }
#    ```
#
# 2. **Selector de atributos**: Aplica estilos a elementos con atributos específicos.
#
#    ```css
#    input[type="text"] {
#        border: 2px solid blue;
#    }
#    ```
#
# 3. **Selector de pseudo-clases**: Modifica elementos en estados específicos.
#
#    ```css
#    a:hover {
#        color: green;
#    }
#    ```
#
# ---
#
# ##### Conclusión
#
# Los **selectores en CSS** permiten aplicar estilos de manera eficiente y organizada a los elementos HTML. Gracias al uso de clases e IDs, se pueden crear diseños modulares y reutilizables, mejorando la gestión visual del sitio web.
#
# En los siguientes apartados exploraremos **CSS avanzado**, optimizando el diseño y la interacción de las páginas web.
# La correcta aplicación de selectores es clave para mejorar la presentación de cualquier sitio web.

# %% [markdown]
# #### Introducción a Bootstrap
#
# **Bootstrap** es un framework de código abierto diseñado para facilitar el desarrollo de sitios web responsivos y modernos. Proporciona una colección de estilos predefinidos, componentes y utilidades que permiten crear interfaces atractivas sin necesidad de escribir código CSS desde cero.
#
# ---
#
# ##### Características principales de Bootstrap
#
# - **Diseño responsivo:** Se adapta automáticamente a distintos tamaños de pantalla.
# - **Componentes predefinidos:** Botones, formularios, tarjetas, barras de navegación y más.
# - **Sistema de rejilla flexible:** Permite organizar el contenido en columnas y filas.
# - **Compatibilidad con navegadores:** Funciona en todos los navegadores modernos.
# - **Integración con JavaScript:** Incluye funcionalidades interactivas como modales y carruseles.
#
# ---
#
# ##### Instalación de Bootstrap
#
# Para utilizar Bootstrap en un proyecto, existen varias opciones:
#
# 1. **CDN (sin descarga):**
#    ```html
#    <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/bootstrap@5.0.2/dist/css/bootstrap.min.css">
#    <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.0.2/dist/js/bootstrap.bundle.min.js"></script>
#    ```
#    Esta opción carga Bootstrap desde un servidor externo sin necesidad de instalar archivos localmente.
#
# 2. **Descarga manual:**
#    Se pueden descargar los archivos desde la página oficial de [Bootstrap](https://getbootstrap.com/docs/4.0/getting-started/introduction/) y agregarlos al proyecto.
#
# 3. **Instalación con npm:**
#    ```sh
#    npm install bootstrap
#    ```
#    Útil para proyectos que utilizan herramientas de desarrollo modernas.
#
# ---
#
# ##### Sistema de rejilla en Bootstrap
#
# Bootstrap utiliza un sistema de **grid** basado en 12 columnas, lo que permite organizar el contenido de manera flexible.
#
# Ejemplo de estructura de columnas:
# ```html
# <div class="container">
#     <div class="row">
#         <div class="col-md-6">Columna 1</div>
#         <div class="col-md-6">Columna 2</div>
#     </div>
# </div>
# ```
# - **`container`**: Contenedor principal.
# - **`row`**: Fila que agrupa columnas.
# - **`col-md-6`**: Define una columna que ocupa 6 de las 12 columnas disponibles en pantallas medianas.
#
# ---
#
# ##### Componentes básicos de Bootstrap
#
# Bootstrap incluye una variedad de componentes listos para usar:
#
# - **Botones:**
#   ```html
#   <button class="btn btn-primary">Botón Azul</button>
#   ```
#
# - **Formularios:**
#   ```html
#   <input type="text" class="form-control" placeholder="Escribe aquí">
#   ```
#
# - **Tarjetas:**
#   ```html
#   <div class="card">
#       <div class="card-body">
#           Contenido de la tarjeta
#       </div>
#   </div>
#   ```
#
# - **Barras de navegación:**
#   ```html
#   <nav class="navbar navbar-light bg-light">
#       <a class="navbar-brand" href="#">Inicio</a>
#   </nav>
#   ```
#
# ---
#
# ##### Conclusión
#
# **Bootstrap** es una herramienta poderosa para desarrollar sitios web modernos y responsivos de manera rápida y eficiente. Su sistema de rejilla, componentes predefinidos y compatibilidad con JavaScript lo convierten en una opción ideal para diseñadores y desarrolladores web.
#
# En los siguientes apartados, exploraremos más sobre el uso avanzado de Bootstrap y su integración con **HTML, CSS y JavaScript** para mejorar la experiencia de usuario.
# Bootstrap es clave para crear interfaces atractivas y funcionales.

# %% [markdown]
# #### Hola Mundo con Bootstrap
#
# El **Hola Mundo** es el primer paso para aprender a utilizar **Bootstrap**, un framework que facilita la creación de sitios web responsivos y modernos. En este ejemplo, se mostrará cómo estructurar una página básica con Bootstrap.
#
# ---
#
# ##### Configuración inicial
#
# Para utilizar Bootstrap, se debe incluir su hoja de estilos y scripts en el documento HTML. Se recomienda usar la versión alojada en un **CDN** para evitar descargas adicionales.
#
# ```html
# <!DOCTYPE html>
# <html lang="es">
# <head>
#     <meta charset="UTF-8">
#     <title>Hola Mundo con Bootstrap</title>
#     <meta name="viewport" content="width=device-width, initial-scale=1">
#     <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/bootstrap@5.0.2/dist/css/bootstrap.min.css">
#     <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.0.2/dist/js/bootstrap.bundle.min.js"></script>
# </head>
# <body>
#     <div class="container text-center mt-5">
#         <h1 class="text-primary">¡Hola Mundo con Bootstrap!</h1>
#         <p class="lead">Este es un ejemplo básico de una página con Bootstrap.</p>
#         <button class="btn btn-success">Haz clic aquí</button>
#     </div>
# </body>
# </html>
# ```
#
# ---
#
# ##### Explicación del código
#
# - **`<meta name="viewport">`**: Permite que la página se adapte a dispositivos móviles.
# - **`<link rel="stylesheet">`**: Carga la hoja de estilos de Bootstrap desde un CDN.
# - **`<script>`**: Incluye los scripts de Bootstrap para funcionalidades interactivas.
# - **`container`**: Define un contenedor centralizado con márgenes automáticos.
# - **`text-center`**: Centra el contenido dentro del contenedor.
# - **`mt-5`**: Agrega un margen superior para mejorar la presentación.
# - **`text-primary`**: Aplica un color azul al título.
# - **`lead`**: Estiliza el párrafo con un tamaño de fuente más grande.
# - **`btn btn-success`**: Crea un botón verde con estilos predefinidos.
#
# ---
#
# ##### Variaciones del Hola Mundo
#
# Bootstrap permite modificar fácilmente el diseño con clases adicionales.
#
# **Ejemplo con fondo y bordes:**
# ```html
# <div class="container bg-light border rounded p-4">
#     <h1 class="text-danger">¡Hola Mundo con Bootstrap!</h1>
#     <p class="text-muted">Ejemplo con fondo y bordes.</p>
# </div>
# ```
#
# ---
#
# ##### Conclusión
#
# El **Hola Mundo con Bootstrap** es una excelente manera de comenzar a trabajar con este framework. Gracias a su sistema de clases predefinidas, se pueden crear interfaces atractivas y responsivas con poco esfuerzo.
#
# En los siguientes apartados, exploraremos más sobre el **sistema de rejilla**, **componentes avanzados** y **personalización de estilos** en Bootstrap.
# Bootstrap es clave para desarrollar sitios web modernos y eficientes.

# %% [markdown]
# #### Tabla HTML con Bootstrap
#
# Las **tablas en Bootstrap** permiten organizar y presentar datos de manera estructurada con estilos predefinidos. Bootstrap proporciona clases para mejorar la apariencia y funcionalidad de las tablas, haciéndolas más legibles y responsivas.
#
# ---
#
# ##### Creación de una tabla básica
#
# Para definir una tabla con Bootstrap, se usa la clase `.table`.
#
# ```html
# <table class="table">
#     <thead>
#         <tr>
#             <th>#</th>
#             <th>Nombre</th>
#             <th>Edad</th>
#             <th>Ciudad</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>1</td>
#             <td>Ana</td>
#             <td>25</td>
#             <td>Madrid</td>
#         </tr>
#         <tr>
#             <td>2</td>
#             <td>Luis</td>
#             <td>30</td>
#             <td>Barcelona</td>
#         </tr>
#         <tr>
#             <td>3</td>
#             <td>María</td>
#             <td>28</td>
#             <td>Sevilla</td>
#         </tr>
#     </tbody>
# </table>
# ```
#
# ---
#
# ##### Estilos adicionales para tablas
#
# Bootstrap ofrece varias clases para mejorar la presentación de las tablas:
#
# - **`table-striped`**: Alterna colores en las filas.
# - **`table-bordered`**: Agrega bordes a la tabla.
# - **`table-hover`**: Resalta filas al pasar el cursor.
# - **`table-dark`**: Aplica un fondo oscuro.
#
# Ejemplo con estilos adicionales:
# ```html
# <table class="table table-striped table-bordered table-hover">
#     <thead class="thead-dark">
#         <tr>
#             <th>#</th>
#             <th>Producto</th>
#             <th>Precio</th>
#             <th>Cantidad</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>1</td>
#             <td>Teclado</td>
#             <td>25€</td>
#             <td>10</td>
#         </tr>
#         <tr>
#             <td>2</td>
#             <td>Ratón</td>
#             <td>15€</td>
#             <td>20</td>
#         </tr>
#     </tbody>
# </table>
# ```
#
# ---
#
# ##### Tablas responsivas
#
# Para hacer que una tabla sea **responsiva**, se debe envolver en un contenedor con la clase `.table-responsive`.
#
# ```html
# <div class="table-responsive">
#     <table class="table table-striped">
#         <thead>
#             <tr>
#                 <th>#</th>
#                 <th>Nombre</th>
#                 <th>Correo</th>
#                 <th>Teléfono</th>
#             </tr>
#         </thead>
#         <tbody>
#             <tr>
#                 <td>1</td>
#                 <td>Carlos</td>
#                 <td>carlos@email.com</td>
#                 <td>123456789</td>
#             </tr>
#         </tbody>
#     </table>
# </div>
# ```
#
# ---
#
# ##### Conclusión
#
# Las **tablas en Bootstrap** permiten organizar datos de manera clara y profesional, con opciones de personalización como colores, bordes y efectos visuales. Además, su capacidad responsiva garantiza una correcta visualización en dispositivos móviles.
#
# Bootstrap facilita la creación de interfaces modernas y funcionales, optimizando la presentación de información en sitios web.
# Para más detalles, puedes consultar la documentación oficial de [Bootstrap](https://getbootstrap.com/docs/4.0/content/tables/).

# %% [markdown]
# #### Introducción a Flask
#
# **Flask** es un **microframework** de desarrollo web para **Python**, diseñado para ser ligero y flexible. Se basa en **Werkzeug** y **Jinja2**, permitiendo la creación de aplicaciones web y servicios RESTful de manera sencilla.
#
# ---
#
# ##### Características principales de Flask
#
# - **Minimalista y modular:** No impone una estructura rígida, permitiendo agregar solo los componentes necesarios.
# - **Sistema de rutas intuitivo:** Facilita la creación de URLs y la gestión de peticiones HTTP.
# - **Soporte para plantillas:** Usa **Jinja2** para generar contenido dinámico en páginas web.
# - **Extensible:** Permite integrar bases de datos, autenticación y otras funcionalidades mediante extensiones.
# - **Compatible con WSGI:** Se adapta a servidores web como **Gunicorn** y **uWSGI**.
#
# ---
#
# ##### Instalación de Flask
#
# Para instalar Flask, se usa **pip**, el gestor de paquetes de Python:
# ```sh
# pip install flask
# ```
# Una vez instalado, se puede verificar la versión con:
# ```sh
# python -m flask --version
# ```
#
# ---
#
# ##### Creación de una aplicación Flask
#
# El siguiente código muestra una aplicación Flask básica que responde con **"¡Hola Mundo!"** cuando se accede a la raíz (`/`).
#
# ```python
# from flask import Flask
#
# app = Flask(__name__)
#
# @app.route("/")
# def hello():
#     return "¡Hola Mundo!"
#
# if __name__ == "__main__":
#     app.run(debug=True)
# ```
#
# **Explicación del código:**
# - Se importa **Flask** y se crea una instancia de la aplicación.
# - Se define una ruta (`@app.route("/")`) que responde con un mensaje.
# - Se ejecuta la aplicación con `app.run(debug=True)`, activando el modo de depuración.
#
# ---
#
# ##### Estructura de un proyecto Flask
#
# Por convención, los proyectos Flask tienen la siguiente estructura:
# ```
# /mi_proyecto
# │── app.py  # Archivo principal
# │── static/  # Archivos estáticos (CSS, JS, imágenes)
# │── templates/  # Plantillas HTML con Jinja2
# │── requirements.txt  # Dependencias del proyecto
# │── venv/  # Entorno virtual
# ```
#
# ---
#
# ##### Conclusión
#
# **Flask** es una excelente opción para desarrollar aplicaciones web en **Python**, gracias a su simplicidad y flexibilidad. Su enfoque modular permite construir desde pequeños servicios hasta aplicaciones complejas con facilidad.
#
# En los siguientes apartados, exploraremos más sobre **rutas, plantillas y bases de datos** en Flask.
# Flask es clave para el desarrollo web ágil y eficiente.

# %% [markdown]
# #### Hola Mundo con Flask
#
# El **Hola Mundo** es el primer paso para aprender a utilizar **Flask**, un microframework de Python para el desarrollo de aplicaciones web. En este ejemplo, se mostrará cómo estructurar una aplicación básica con Flask en Flask con ...](https://www.desarrollolibre.net/blog/flask/tutorial-para-crear-tu-primera-aplicacion-web-hola-mundo-en-flask-con-python-3).
#
# ---
#
# ##### Instalación de Flask
#
# Para instalar Flask, se usa **pip**, el gestor de paquetes de Python:
# ```sh
# pip install flask
# ```
# Una vez instalado, se puede verificar la versión con:
# ```sh
# python -m flask --version
# ```
#
# ---
#
# ##### Creación de una aplicación Flask
#
# El siguiente código muestra una aplicación Flask básica que responde con **"¡Hola Mundo!"** cuando se accede a la raíz (`/`).
#
# ```python
# from flask import Flask
#
# app = Flask(__name__)
#
# @app.route("/")
# def hello():
#     return "¡Hola Mundo!"
#
# if __name__ == "__main__":
#     app.run(debug=True)
# ```
#
# ---
#
# ##### Explicación del código
#
# - **Importación de Flask:** Se importa el módulo `Flask` para crear la aplicación.
# - **Instancia de la aplicación:** `app = Flask(__name__)` inicializa la aplicación Flask.
# - **Definición de ruta:** `@app.route("/")` indica que la función `hello()` responderá a las solicitudes en la raíz (`/`).
# - **Ejecución de la aplicación:** `app.run(debug=True)` inicia el servidor en modo depuración.
#
# ---
#
# ##### Ejecución de la aplicación
#
# Para ejecutar la aplicación, guarda el código en un archivo llamado `app.py` y corre el siguiente comando en la terminal:
# ```sh
# python app.py
# ```
# Esto iniciará un servidor local en `http://127.0.0.1:5000/`, donde se podrá ver el mensaje **"¡Hola Mundo!"** en el navegador en Flask con ...](https://www.desarrollolibre.net/blog/flask/tutorial-para-crear-tu-primera-aplicacion-web-hola-mundo-en-flask-con-python-3).
#
# ---
#
# ##### Conclusión
#
# El **Hola Mundo con Flask** es una excelente manera de comenzar a trabajar con este framework. Gracias a su sistema de rutas y su simplicidad, se pueden desarrollar aplicaciones web de manera rápida y eficiente.
#
# En los siguientes apartados, exploraremos más sobre **rutas dinámicas, plantillas con Jinja2 y conexión con bases de datos** en Flask.
# Flask es clave para el desarrollo web ágil y escalable.

# %% [markdown]
# #### Varias rutas en Flask
#
# En **Flask**, se pueden definir múltiples rutas para gestionar diferentes páginas o funcionalidades dentro de una aplicación web. Esto permite estructurar mejor el código y facilitar la navegación entre distintos endpoints.
#
# ---
#
# ##### Definición de múltiples rutas
#
# Flask permite asociar varias rutas a una misma función utilizando el decorador `@app.route()`.
#
# ```python
# from flask import Flask
#
# app = Flask(__name__)
#
# @app.route("/")
# @app.route("/inicio")
# def home():
#     return "Bienvenido a la página principal"
#
# @app.route("/contacto")
# def contacto():
#     return "Página de contacto"
#
# if __name__ == "__main__":
#     app.run(debug=True)
# ```
#
# ---
#
# ##### Rutas con parámetros
#
# Las rutas pueden incluir **parámetros dinámicos** para manejar contenido variable.
#
# ```python
# @app.route("/usuario/<nombre>")
# def usuario(nombre):
#     return f"Hola, {nombre}!"
# ```
#
# Ejemplo de acceso:
# - `http://127.0.0.1:5000/usuario/Ana` → Respuesta: **Hola, Ana!**
# - `http://127.0.0.1:5000/usuario/Luis` → Respuesta: **Hola, Luis!**
#
# ---
#
# ##### Métodos HTTP en rutas
#
# Flask permite definir rutas que acepten distintos **métodos HTTP** (`GET`, `POST`, etc.).
#
# ```python
# @app.route("/formulario", methods=["GET", "POST"])
# def formulario():
#     if request.method == "POST":
#         return "Formulario enviado"
#     return "Mostrar formulario"
# ```
#
# ---
#
# ##### Uso de Blueprints para múltiples rutas
#
# Para organizar mejor una aplicación con muchas rutas, se pueden usar **Blueprints**.
#
# ```python
# from flask import Blueprint
#
# usuarios_bp = Blueprint("usuarios", __name__)
#
# @usuarios_bp.route("/perfil")
# def perfil():
#     return "Perfil de usuario"
#
# @usuarios_bp.route("/configuracion")
# def configuracion():
#     return "Configuración de usuario"
# ```
#
# Luego, se registra el **Blueprint** en la aplicación principal:
# ```python
# app.register_blueprint(usuarios_bp, url_prefix="/usuarios")
# ```
#
# ---
#
# ##### Conclusión
#
# El manejo de **múltiples rutas en Flask** permite estructurar aplicaciones web de manera eficiente, facilitando la navegación y la gestión de contenido dinámico.
# El uso de **parámetros, métodos HTTP y Blueprints** mejora la organización y escalabilidad del proyecto.
# Flask es una herramienta poderosa para el desarrollo web en Python.

# %% [markdown]
# #### Respuesta de Contenido HTML en Flask
#
# En **Flask**, se pueden renderizar páginas HTML utilizando el motor de plantillas **Jinja2**, lo que permite generar contenido dinámico y estructurado dentro de una aplicación web.
#
# ---
#
# ##### Renderización de contenido HTML
#
# Para devolver contenido HTML desde Flask, se usa la función `render_template()`, que carga archivos HTML desde la carpeta `templates`.
#
# ```python
# from flask import Flask, render_template
#
# app = Flask(__name__)
#
# @app.route("/")
# def home():
#     return render_template("index.html")
#
# if __name__ == "__main__":
#     app.run(debug=True)
# ```
#
# **Estructura del proyecto:**
# ```
# /mi_proyecto
# │── app.py
# │── templates/
# │   ├── index.html
# ```
#
# **Archivo `index.html`:**
# ```html
# <!DOCTYPE html>
# <html lang="es">
# <head>
#     <meta charset="UTF-8">
#     <title>Página Flask</title>
# </head>
# <body>
#     <h1>Bienvenido a Flask</h1>
#     <p>Este es un ejemplo de contenido HTML renderizado desde Flask.</p>
# </body>
# </html>
# ```
#
# ---
#
# ##### Pasar variables a una plantilla
#
# Flask permite enviar datos dinámicos a una plantilla HTML mediante `render_template()`.
#
# ```python
# @app.route("/usuario/<nombre>")
# def usuario(nombre):
#     return render_template("usuario.html", nombre=nombre)
# ```
#
# **Archivo `usuario.html`:**
# ```html
# <h1>Hola, {{ nombre }}</h1>
# ```
#
# Si accedes a `http://127.0.0.1:5000/usuario/Ana`, la página mostrará **"Hola, Ana"**.
#
# ---
#
# ##### Uso de condicionales y bucles en HTML con Flask
#
# Jinja2 permite incluir lógica dentro de las plantillas.
#
# ```html
# {% if nombre %}
#     <h1>Bienvenido, {{ nombre }}</h1>
# {% else %}
#     <h1>Bienvenido, visitante</h1>
# {% endif %}
# ```
#
# ```html
# <ul>
#     {% for item in lista %}
#         <li>{{ item }}</li>
#     {% endfor %}
# </ul>
# ```
#
# ---
#
# ##### Conclusión
#
# Flask facilita la renderización de contenido HTML mediante **Jinja2**, permitiendo la creación de páginas dinámicas con variables, condicionales y bucles.
# Este enfoque mejora la organización del código y la presentación de datos en aplicaciones web.
# Flask es una herramienta poderosa para el desarrollo de sitios interactivos y escalables.

# %% [markdown]
# #### Manejo de Parámetros en Flask
#
# En **Flask**, los parámetros permiten recibir datos desde la URL o mediante solicitudes HTTP, facilitando la interacción con el usuario y la manipulación de información dentro de la aplicación.
#
# ---
#
# ##### Parámetros en rutas
#
# Flask permite definir rutas con **parámetros dinámicos**, los cuales se capturan mediante `<variable>` en la URL.
#
# ```python
# from flask import Flask
#
# app = Flask(__name__)
#
# @app.route("/usuario/<nombre>")
# def usuario(nombre):
#     return f"Hola, {nombre}!"
#
# if __name__ == "__main__":
#     app.run(debug=True)
# ```
#
# Ejemplo de acceso:
# - `http://127.0.0.1:5000/usuario/Ana` → Respuesta: **Hola, Ana!**
# - `http://127.0.0.1:5000/usuario/Luis` → Respuesta: **Hola, Luis!**
#
# ---
#
# ##### Parámetros con tipos específicos
#
# Se pueden definir tipos de datos en los parámetros para restringir su formato.
#
# ```python
# @app.route("/producto/<int:id>")
# def producto(id):
#     return f"Producto con ID: {id}"
# ```
#
# Ejemplo de acceso:
# - `http://127.0.0.1:5000/producto/5` → Respuesta: **Producto con ID: 5**
# - `http://127.0.0.1:5000/producto/abc` → Error, ya que `abc` no es un número entero.
#
# ---
#
# ##### Parámetros en solicitudes GET
#
# Los parámetros en **GET** se envían en la URL y se capturan con `request.args.get()`.
#
# ```python
# from flask import request
#
# @app.route("/buscar")
# def buscar():
#     consulta = request.args.get("q", "Sin consulta")
#     return f"Resultado de búsqueda: {consulta}"
# ```
#
# Ejemplo de acceso:
# - `http://127.0.0.1:5000/buscar?q=Flask` → Respuesta: **Resultado de búsqueda: Flask**
# - `http://127.0.0.1:5000/buscar` → Respuesta: **Resultado de búsqueda: Sin consulta**
#
# ---
#
# ##### Parámetros en solicitudes POST
#
# Los parámetros en **POST** se envían en el cuerpo de la solicitud y se capturan con `request.form.get()`.
#
# ```python
# @app.route("/login", methods=["POST"])
# def login():
#     usuario = request.form.get("usuario")
#     contraseña = request.form.get("contraseña")
#     return f"Usuario: {usuario}, Contraseña: {contraseña}"
# ```
#
# ---
#
# ##### Conclusión
#
# El **manejo de parámetros en Flask** permite recibir datos desde la URL y formularios, facilitando la interacción con el usuario.
# El uso de **parámetros dinámicos, GET y POST** mejora la flexibilidad y funcionalidad de las aplicaciones web.
# Flask es una herramienta poderosa para el desarrollo de sitios interactivos y escalables.

# %% [markdown]
# #### Manejo de Grid con Bootstrap
#
# El **sistema de grid en Bootstrap** es una herramienta esencial para el diseño web moderno. Permite crear diseños flexibles y adaptables mediante el uso de columnas organizadas en filas - Oregoom.com](https://oregoom.com/bootstrap/grid/).
#
# ---
#
# ##### Características del sistema de Grid
#
# - **Basado en Flexbox**, lo que permite una distribución flexible de los elementos.
# - **Sistema de 12 columnas**, adaptable a distintos tamaños de pantalla.
# - **Clases predefinidas** para controlar el tamaño y comportamiento de las columnas.
# - **Diseño responsivo**, ajustando automáticamente el contenido según el dispositivo.
#
# ---
#
# ##### Estructura básica del Grid
#
# Para crear una estructura de **grid**, se usa la clase `.row` para definir filas y `.col-*` para las columnas - Oregoom.com](https://oregoom.com/bootstrap/grid/).
#
# ```html
# <div class="container">
#     <div class="row">
#         <div class="col">Columna 1</div>
#         <div class="col">Columna 2</div>
#         <div class="col">Columna 3</div>
#     </div>
# </div>
# ```
#
# ---
#
# ##### Clases del sistema de Grid
#
# Bootstrap ofrece diferentes clases para definir el tamaño de las columnas según el dispositivo - Oregoom.com](https://oregoom.com/bootstrap/grid/):
#
# - **`.col-`** → Extra pequeño (menos de 576px).
# - **`.col-sm-`** → Pequeño (≥576px).
# - **`.col-md-`** → Mediano (≥768px).
# - **`.col-lg-`** → Grande (≥992px).
# - **`.col-xl-`** → Extra grande (≥1200px).
# - **`.col-xxl-`** → Extra extra grande (≥1400px).
#
# Ejemplo de columnas responsivas:
# ```html
# <div class="row">
#     <div class="col-sm-6 col-md-4 col-lg-3">Columna adaptable</div>
#     <div class="col-sm-6 col-md-4 col-lg-3">Columna adaptable</div>
# </div>
# ```
#
# ---
#
# ##### Grid automático
#
# Si no se especifica el tamaño de las columnas, Bootstrap las distribuirá equitativamente.
#
# ```html
# <div class="row">
#     <div class="col">Columna 1</div>
#     <div class="col">Columna 2</div>
#     <div class="col">Columna 3</div>
# </div>
# ```
#
# ---
#
# ##### Conclusión
#
# El **sistema de grid en Bootstrap** permite crear diseños flexibles y responsivos con facilidad. Gracias a su estructura basada en **Flexbox**, se pueden organizar elementos de manera eficiente en distintos dispositivos - Oregoom.com](https://oregoom.com/bootstrap/grid/).
# Bootstrap es una herramienta clave para el desarrollo de interfaces modernas y adaptables.

# %% [markdown]
# #### Instalación de WTForms y Flask
#
# **WTForms** es una biblioteca de Python que facilita la creación y validación de formularios en aplicaciones web. Se integra con **Flask** mediante la extensión **Flask-WTF**, que proporciona protección contra ataques CSRF y soporte para formularios dinámicos.
#
# ---
#
# ##### Instalación de Flask
#
# Para instalar Flask, se usa **pip**, el gestor de paquetes de Python:
# ```sh
# pip install flask
# ```
#
# ---
#
# ##### Instalación de WTForms y Flask-WTF
#
# Para instalar **WTForms** y su integración con Flask, se ejecuta el siguiente comando:
# ```sh
# pip install flask-wtf wtforms
# ```
#
# ---
#
# ##### Creación de un formulario con WTForms
#
# Ejemplo de un formulario básico en Flask usando **WTForms**:
#
# ```python
# from flask import Flask, render_template, request
# from flask_wtf import FlaskForm
# from wtforms import StringField, SubmitField
# from wtforms.validators import DataRequired
#
# app = Flask(__name__)
# app.config['SECRET_KEY'] = 'clave_secreta'
#
# class FormularioEjemplo(FlaskForm):
#     nombre = StringField('Nombre', validators=[DataRequired()])
#     enviar = SubmitField('Enviar')
#
# @app.route("/", methods=["GET", "POST"])
# def index():
#     form = FormularioEjemplo()
#     if form.validate_on_submit():
#         return f"Hola, {form.nombre.data}!"
#     return render_template("index.html", form=form)
#
# if __name__ == "__main__":
#     app.run(debug=True)
# ```
#
# ---
#
# ##### Creación de la plantilla HTML
#
# **Archivo `templates/index.html`:**
# ```html
# <!DOCTYPE html>
# <html lang="es">
# <head>
#     <meta charset="UTF-8">
#     <title>Formulario con WTForms</title>
# </head>
# <body>
#     <form method="POST">
#         {{ form.hidden_tag() }}
#         <p>{{ form.nombre.label }} {{ form.nombre() }}</p>
#         <p>{{ form.enviar() }}</p>
#     </form>
# </body>
# </html>
# ```
#
# ---
#
# ##### Conclusión
#
# La instalación de **WTForms y Flask-WTF** permite gestionar formularios de manera eficiente en aplicaciones Flask.
# Gracias a su integración con **validaciones y protección CSRF**, se pueden crear formularios seguros y dinámicos.
# Flask y WTForms son herramientas clave para el desarrollo web en Python.
# Puedes encontrar más información en [CertiDevs](https://certidevs.com/tutorial-flask-mvc-wtforms-validacion-formularios) y [Junco TIC](https://juncotic.com/flask-wtf-manejo-de-formularios/).

# %% [markdown]
# #### Creación de la clase Form con WTForms y Flask
#
# En **Flask**, la biblioteca **WTForms** permite definir formularios de manera estructurada y con validaciones integradas. Para utilizarla, se debe crear una clase que represente el formulario y sus campos.
#
# ---
#
# ##### Instalación de Flask-WTF
#
# Para instalar **Flask-WTF**, que integra WTForms con Flask, se usa **pip**:
# ```sh
# pip install flask-wtf wtforms
# ```
#
# ---
#
# ##### Definición de la clase Form
#
# Para crear un formulario, se define una clase que hereda de `FlaskForm` y contiene los campos necesarios.
#
# ```python
# from flask_wtf import FlaskForm
# from wtforms import StringField, PasswordField, SubmitField
# from wtforms.validators import DataRequired
#
# class LoginForm(FlaskForm):
#     username = StringField('Nombre de usuario', validators=[DataRequired()])
#     password = PasswordField('Contraseña', validators=[DataRequired()])
#     submit = SubmitField('Iniciar sesión')
# ```
#
# ---
#
# ##### Uso del formulario en Flask
#
# El formulario se instancia en una ruta y se renderiza en una plantilla HTML.
#
# ```python
# from flask import Flask, render_template, request
# from forms import LoginForm
#
# app = Flask(__name__)
# app.config['SECRET_KEY'] = 'clave_secreta'
#
# @app.route("/login", methods=["GET", "POST"])
# def login():
#     form = LoginForm()
#     if form.validate_on_submit():
#         return f"Bienvenido, {form.username.data}!"
#     return render_template("login.html", form=form)
#
# if __name__ == "__main__":
#     app.run(debug=True)
# ```
#
# ---
#
# ##### Plantilla HTML para el formulario
#
# **Archivo `templates/login.html`:**
# ```html
# <!DOCTYPE html>
# <html lang="es">
# <head>
#     <meta charset="UTF-8">
#     <title>Login con WTForms</title>
# </head>
# <body>
#     <form method="POST">
#         {{ form.hidden_tag() }}
#         <p>{{ form.username.label }} {{ form.username() }}</p>
#         <p>{{ form.password.label }} {{ form.password() }}</p>
#         <p>{{ form.submit() }}</p>
#     </form>
# </body>
# </html>
# ```
#
# ---
#
# ##### Conclusión
#
# La creación de formularios con **WTForms y Flask** permite gestionar datos de manera segura y estructurada.
# Gracias a **validaciones y protección CSRF**, se pueden construir formularios eficientes y escalables en aplicaciones web.
# Flask-WTF es una herramienta clave para el desarrollo de interfaces interactivas en Python.
# Puedes encontrar más información en [Junco TIC](https://juncotic.com/flask-wtf-manejo-de-formularios/) y [J2LOGO](https://j2logo.com/tutorial-flask-leccion-3-formularios-wtforms/).

# %% [markdown]
# # DESARROLLO WEB BACKEND CON PYTHON

# %% [markdown]
# ## Django

# %% [markdown]
# ### Sección 1: Introducción

# %% [markdown]
# #### Presentación del curso

# %% [markdown]
# Requisitos previos:
#
# * Python
# * HTML
# * Un IDE integrado cualquiera
# * Bootstrap 4
# *
